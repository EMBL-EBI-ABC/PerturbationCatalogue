# %% [markdown]
# # Import

# %%
import pandas as pd

import sys

sys.path.append("../../")
from curation_tools.curation_tools import CuratedDataset
from curation_tools.perturbseq_anndata_schema import ObsSchema, VarSchema

from curation_tools.unified_metadata_schema.unified_metadata_schema import Experiment

# %% [markdown]
# # Initialise the dataset object

# %%
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    data_source_link="https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad",
    noncurated_path="../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad",
)

# %% [markdown]
# # Download the dataset

# %%
cur_data.download_data()
cur_data.load_data()
# show the data
cur_data.show_obs()
# Out:
# File ../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad already exists. Skipping download.
# Loading data from ../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad
# Observation data:
# DataFrame shape: (65337, 15)
# --------------------------------------------------
#                    perturbation  read count  UMI count tissue_type cell_line  \
# cell_barcode
# AAACATACAAGATG   63(mod)_pBA580       282.0        8.0   cell_line      K562
# AAACATACACCTAG      OST4_pDS353       331.0        7.0   cell_line      K562
# AAACATACTTCCCG   SEC61A1_pDS031       285.0       10.0   cell_line      K562
# AAACATTGAAACAG    EIF2B4_pDS491      1036.0       30.0   cell_line      K562
# AAACATTGCAGCTA      SRPR_pDS482       863.0       25.0   cell_line      K562
# ...                         ...         ...        ...         ...       ...
# TTTGCATGCTTTAC     STT3A_pDS011       476.0       17.0   cell_line      K562
# TTTGCATGGAGGAC  ARHGAP22_pDS458       539.0       19.0   cell_line      K562
# TTTGCATGTAGAGA   63(mod)_pBA580       647.0       35.0   cell_line      K562
# TTTGCATGTCAAGC    KCTD16_pDS096        98.0        4.0   cell_line      K562
# TTTGCATGTGGAGG    SAMM50_pDS156       427.0       14.0   cell_line      K562
#
#                 cancer                       disease perturbation_type  \
# cell_barcode
# AAACATACAAGATG    True  chronic myelogenous leukemia            CRISPR
# AAACATACACCTAG    True  chronic myelogenous leukemia            CRISPR
# AAACATACTTCCCG    True  chronic myelogenous leukemia            CRISPR
# AAACATTGAAACAG    True  chronic myelogenous leukemia            CRISPR
# AAACATTGCAGCTA    True  chronic myelogenous leukemia            CRISPR
# ...                ...                           ...               ...
# TTTGCATGCTTTAC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGGAGGAC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTAGAGA    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTCAAGC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTGGAGG    True  chronic myelogenous leukemia            CRISPR
#
#                     celltype organism  ncounts  ngenes  percent_mito  \
# cell_barcode
# AAACATACAAGATG  lymphoblasts    human   8866.0    2914      4.917663
# AAACATACACCTAG  lymphoblasts    human  13785.0    3818      4.468626
# AAACATACTTCCCG  lymphoblasts    human   7569.0    2616      5.060113
# AAACATTGAAACAG  lymphoblasts    human  13834.0    3488      5.052769
# AAACATTGCAGCTA  lymphoblasts    human  15507.0    3620      4.514091
# ...                      ...      ...      ...     ...           ...
# TTTGCATGCTTTAC  lymphoblasts    human  14524.0    3356      5.996971
# TTTGCATGGAGGAC  lymphoblasts    human  11685.0    2961      4.612751
# TTTGCATGTAGAGA  lymphoblasts    human  16610.0    3473      7.242625
# TTTGCATGTCAAGC  lymphoblasts    human  14473.0    3431      7.296345
# TTTGCATGTGGAGG  lymphoblasts    human  16843.0    3719      5.919373
#
#                 percent_ribo  nperts
# cell_barcode
# AAACATACAAGATG     21.306112       2
# AAACATACACCTAG     19.492201       2
# AAACATACTTCCCG     23.199894       2
# AAACATTGAAACAG     28.733555       2
# AAACATTGCAGCTA     26.729864       2
# ...                      ...     ...
# TTTGCATGCTTTAC     22.679703       2
# TTTGCATGGAGGAC     26.983313       2
# TTTGCATGTAGAGA     26.207104       2
# TTTGCATGTCAAGC     20.755890       2
# TTTGCATGTGGAGG     20.097370       2
#
# [65337 rows x 15 columns]
# --------------------------------------------------

# %%
cur_data.show_var()
# Out:
# Variable data:
# DataFrame shape: (32738, 3)
# --------------------------------------------------
#                    ensembl_id  ncounts  ncells
# gene_symbol
# MIR1302-10    ENSG00000243485     11.0      11
# FAM138A       ENSG00000237613      0.0       0
# OR4F5         ENSG00000186092      0.0       0
# RP11-34P13.7  ENSG00000238009      0.0       0
# RP11-34P13.8  ENSG00000239945     43.0      43
# ...                       ...      ...     ...
# AC145205.1    ENSG00000215635      0.0       0
# BAGE5         ENSG00000268590      0.0       0
# CU459201.1    ENSG00000251180      0.0       0
# AC002321.2    ENSG00000215616      0.0       0
# AC002321.1    ENSG00000215611      0.0       0
#
# [32738 rows x 3 columns]
# --------------------------------------------------

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot="obs", column="perturbation")
# Out:
# Unique values in adata.obs.perturbation: 115
# --------------------------------------------------
# {nan,
#  '*',
#  '62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# ### Drop NAs

# %%
cur_data.remove_na(slot="obs", column="perturbation")
# Out:
# Removed 2613 NA entries from column perturbation of adata.obs

# %% [markdown]
# ### Drop "*" entries

# %%
cur_data.remove_entries(slot="obs", column="perturbation", to_remove=r"\*")
# Out:
# Removed 101 entries \* from column perturbation of adata.obs

# %%
cur_data.show_unique(slot="obs", column="perturbation")
# Out:
# Unique values in adata.obs.perturbation: 113
# --------------------------------------------------
# {'62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# ### Rename `perturbation` to `perturbation_name`

# %%
cur_data.rename_columns(slot="obs", name_dict={"perturbation": "perturbation_name"})
# Out:
# Renamed columns in adata.obs: {'perturbation': 'perturbation_name'}

# %% [markdown]
# ### Add guide RNA information

# %%
# download the protospacer sequences data from supplementary information Table S1
# https://ars.els-cdn.com/content/image/1-s2.0-S0092867416316609-mmc1.xlsx

guides_df = pd.read_csv("../supplementary/adamson_2016_pilot.csv", header=1)
display(guides_df)

guides_dict_vecid = (
    guides_df[["Perturb-seq_Vector_ID", "Protospacer"]]
    .dropna()
    .set_index("Perturb-seq_Vector_ID", drop=True)["Protospacer"]
    .to_dict()
)

guides_dict_vecid
# Out:
#              Gene           Protospacer Guide_ID (synonymous with sgGuide_ID)  \
# 0            AARS  GAGGGCGGCCTACCTCTCCT                                   NaN
# 1    AMIGO3/GMPPB  GGAACGCGACACCGGGTAGA                                   NaN
# 2    AMIGO3/GMPPB  GGGGCCAGCAGCCGTCTACC                                   NaN
# 3        ARHGAP22  GGTCCGTCCGGAGCCAGGAG                                   NaN
# 4           ASCC3  GACGCAAAGACGCACAGACC                                   NaN
# ..            ...                   ...                                   ...
# 97          YIPF5  GTGACACGTAGCAACGGGGC                                   NaN
# 98            NaN  GGCCAAACGTGCCCTGACGG                             NegCtrl-1
# 99            NaN  GCGATGGGGGGGTGGGTAGC                             NegCtrl-2
# 100           NaN  GACGACTAGTTAGGCGTGTA                             NegCtrl-3
# 101           NaN  GCCTTGGCTAAACCGCTCCC                           NegCtrl-hU6
#
#     Perturb-seq_Vector_ID  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0                  pDS381         NaN         NaN         NaN
# 1                  pDS391         NaN         NaN         NaN
# 2                  pDS434         NaN         NaN         NaN
# 3                  pDS458         NaN         NaN         NaN
# 4                  pDS051         NaN         NaN         NaN
# ..                    ...         ...         ...         ...
# 97                 pDS226         NaN         NaN         NaN
# 98                    NaN         NaN         NaN         NaN
# 99                    NaN         NaN         NaN         NaN
# 100                   NaN         NaN         NaN         NaN
# 101                   NaN         NaN         NaN         NaN
#
# [102 rows x 7 columns]
# {'pDS381': 'GAGGGCGGCCTACCTCTCCT',
#  'pDS391': 'GGAACGCGACACCGGGTAGA',
#  'pDS434': 'GGGGCCAGCAGCCGTCTACC',
#  'pDS458': 'GGTCCGTCCGGAGCCAGGAG',
#  'pDS051': 'GACGCAAAGACGCACAGACC',
#  'pDS052': 'GCGCACAGACCCGGCGAGGA',
#  'pDS055': 'GAGTCTCCGCAAGGCCCCGG',
#  'pDS468': 'GTAGGAGCCTCGGGCGCGCT',
#  'pDS460': 'GAGCCATGGCAGATTCCTCC',
#  'pDS006': 'GCGACGTCCGAGCATTCCA',
#  'pDS024': 'GCGCTGGTGGTCGATCGTG',
#  'pDS065': 'GCGGCTATGAACCGCAGCAG',
#  'pDS462': 'GGATGCTGTGGTGTCCACAG',
#  'pDS499': 'GACCTTGCGTGCAGTTATGT',
#  'pDS495': 'GTGAGACCCCAGGGTCGGGA',
#  'pDS382': 'GTGGGTCCTTCGGCAGGAGG',
#  'pDS041': 'GCGGTCCACAAAGGCTCAGA',
#  'pDS042': 'GGTAGGCGCGGCTGACCGGT',
#  'pDS383': 'GGCGCCCAGCGGAGCTAATC',
#  'pDS026': 'GGGCGCCTGTGCTTGAGGTT',
#  'pDS074': 'GCTTGCCTGGAACTCCTGTA',
#  'pDS463': 'GTAGCTGCCTTCAGCCTTCAC',
#  'pDS508': 'GCCATTGGGCTGTCAGTCAG',
#  'pDS491': 'GCTGAGGGCGATGGCTGCTG',
#  'pDS386': 'GAGACTTGCTTCCCCCTCAC',
#  'pDS390': 'GTCACTGTAGGTGCGGCCCA',
#  'pDS494': 'GGCAGCCTCGGCCCGAGTCC',
#  'pDS043': 'GCAGGGCTCGCGCAGTTACC',
#  'pDS506': 'GCAGGGCCGCGCGCAGGCGAG',
#  'pDS466': 'GCTCAAGTGGACAGCCGGGA',
#  'pDS087': 'GTCATCCTCACCGTCACGGC',
#  'pDS017': 'GCGACGGTGAGGTCGACGC',
#  'pDS371': 'GGCGACGGTGAGGTCGACGC',
#  'pDS088': 'GGGATAAATGGAGGAGTACG',
#  'pDS089': 'GGACAGCGTGCGAGCTCCGG',
#  'pDS090': 'GGCGCGTGCGCCCTCTTACT',
#  'pDS091': 'GCGGAGGACCCCGCTCTCAG',
#  'pDS393': 'GGGGCCCGCGTGGATCTCTA',
#  'pDS002': 'GGGCCGCGTGAGGGGACACCA',
#  'pDS110': 'GGGGCCCCATCGGCTTCCGT',
#  'pDS096': 'GGTTTCTCAGACCTAGGTGA',
#  'pDS027': 'GACTTGGAGGCGGTGCGGCG',
#  'pDS394': 'GCAGCACCGGCAAGCAACCC',
#  'pDS124': 'GCGAGCAAGGAGCCCCCGGC',
#  'pDS498': 'GTCTGGCTGGTCGCACCCGG',
#  'pDS395': 'GGGCCAGTCCCTAAGCACGT',
#  'pDS396': 'GCAGCGGCGACCGGAGCGGT',
#  'pDS353': 'GGCTTGTTCGCTGGTGGCGT',
#  'pDS397': 'GGGCGCCGCCGGGACAGCGG',
#  'pDS029': 'GGGCAACCTAGCAGCTCCTC',
#  'pDS398': 'GTTTTCAGCAGAGACGTAGA',
#  'pDS488': 'GCCGTCCCGGAGACCCGGTC',
#  'pDS478': 'GCTGGCGCCCAGCAAAGGCT',
#  'pDS510': 'GCGCGCTCAGTGAGAGGAAA',
#  'pDS156': 'GCTGCCTCGCAGAGCTGCCC',
#  'pDS467': 'GGGCGCAGTGCGGCGGTCAC',
#  'pDS159': 'GGCCGGAGGACCCGGAGCTA',
#  'pDS160': 'GGCCTTAGCTCCGGGTCCTC',
#  'pDS031': 'GCTGTGCAGTGGAACGCGCT',
#  'pDS032': 'GTGCTAGCCCGGCGGCAAG',
#  'pDS033': 'GTACGGAGCCCCCGAAAGAC',
#  'pDS162': 'GGCGGACGGATAGAAAGTTA',
#  'pDS440': 'GCTCCAGTGCTACGTGTCCC',
#  'pDS218': 'GGTGCAGAGCGTGGTCGTGG',
#  'pDS373': 'GGTGGTGGCTGAGTCCGTGG',
#  'pDS046': 'GGTCGCATGCAGCTCCTATG',
#  'pDS219': 'GCCGGGAAAGGAGAGGATCC',
#  'pDS433': 'GAGATGTCCGGGTAGCGCCA',
#  'pDS479': 'GCGGCGGACCCGGCCCTAGG',
#  'pDS401': 'GTCAGACAAGTCGGAGGGGA',
#  'pDS402': 'GGCCGGTCCGCCGCCGGAAC',
#  'pDS403': 'GAGAAGCAGGTCCCAGGCGG',
#  'pDS505': 'GCCTCCAAGATGGCGAGCGG',
#  'pDS482': 'GGCGAACGCGGCCTGAATTCC',
#  'pDS404': 'GGCCACCCGGCGCGAGTCCG',
#  'pDS011': 'GGGAGCCCCGCGGATCGTTT',
#  'pDS442': 'GGCGCTGGGTTCCTGGTGAGT',
#  'pDS405': 'GGAGGAGCCAAGAGGCGGGT',
#  'pDS496': 'GCCGCGGAGACCCGCCCCAG',
#  'pDS284': 'GAAGTAGGCGCTGGCAACGC',
#  'pDS430': 'GCGGCACCAGCCACTCCGCA',
#  'pDS036': 'GAGACTCGTTCACCACCGA',
#  'pDS175': 'GTGAGGCCGAAGCCAGGACC',
#  'pDS038': 'GCAGCCACATCACCCTTCCG',
#  'pDS407': 'GAAGGCTGGAAGACGAGGTA',
#  'pDS408': 'GTCCGGATCCTGTTAGACAC',
#  'pDS410': 'GTGACTCGCAGTAGACGCGG',
#  'pDS040': 'GCGGTAAGCAAACACTTACA',
#  'pDS411': 'GTCCGCGGAGCGACGACCGG',
#  'pDS186': 'GGGTGCAGGGGACCGCGTCA',
#  'pDS226': 'GTGACACGTAGCAACGGGGC'}

# %%
# extract vector IDs from perturbation_names
cur_data.create_columns(
    slot="obs",
    col_dict={
        "vector_id": cur_data.adata.obs["perturbation_name"].str.split("_").str[1]
    },
)

cur_data.show_unique(slot="obs", column="vector_id")
# Out:
# Column vector_id added to adata.obs
# Unique values in adata.obs.vector_id: 113
# --------------------------------------------------
# {'pBA572',
#  'pBA573',
#  'pBA574',
#  'pBA575',
#  'pBA576',
#  'pBA577',
#  'pBA578',
#  'pBA579',
#  'pBA580',
#  'pBA581',
#  'pBA582',
#  'pBA586',
#  'pBA608',
#  'pDS001',
#  'pDS002',
#  'pDS003',
#  'pDS004',
#  'pDS005',
#  'pDS006',
#  'pDS007',
#  'pDS008',
#  'pDS009',
#  'pDS010',
#  'pDS011',
#  'pDS017',
#  'pDS024',
#  'pDS026',
#  'pDS027',
#  'pDS029',
#  'pDS031',
#  'pDS032',
#  'pDS033',
#  'pDS036',
#  'pDS038',
#  'pDS040',
#  'pDS041',
#  'pDS042',
#  'pDS043',
#  'pDS044',
#  'pDS046',
#  'pDS051',
#  'pDS052',
#  'pDS055',
#  'pDS065',
#  'pDS074',
#  'pDS087',
#  'pDS088',
#  'pDS089',
#  'pDS090',
#  'pDS091',
#  'pDS096',
#  'pDS110',
#  'pDS124',
#  'pDS156',
#  'pDS159',
#  'pDS160',
#  'pDS162',
#  'pDS175',
#  'pDS186',
#  'pDS218',
#  'pDS219',
#  'pDS226',
#  'pDS284',
#  'pDS353',
#  'pDS371',
#  'pDS373',
#  'pDS381',
#  'pDS382',
#  'pDS383',
#  'pDS386',
#  'pDS390',
#  'pDS391',
#  'pDS393',
#  'pDS394',
#  'pDS395',
#  'pDS396',
#  'pDS397',
#  'pDS398',
#  'pDS401',
#  'pDS402',
#  'pDS403',
#  'pDS404',
#  'pDS405',
#  'pDS407',
#  'pDS408',
#  'pDS410',
#  'pDS411',
#  'pDS430',
#  'pDS433',
#  'pDS434',
#  'pDS440',
#  'pDS442',
#  'pDS458',
#  'pDS460',
#  'pDS462',
#  'pDS463',
#  'pDS466',
#  'pDS467',
#  'pDS468',
#  'pDS478',
#  'pDS479',
#  'pDS482',
#  'pDS488',
#  'pDS491',
#  'pDS494',
#  'pDS495',
#  'pDS496',
#  'pDS498',
#  'pDS499',
#  'pDS505',
#  'pDS506',
#  'pDS508',
#  'pDS510'}
# --------------------------------------------------

# %%
cur_data.map_values_from_column(
    ref_col="vector_id", target_col="guide_sequence", map_dict=guides_dict_vecid
)
# Out:
# Column guide_sequence created in adata.obs
# Mapped value pDS381 in column vector_id to GAGGGCGGCCTACCTCTCCT in column guide_sequence of adata.obs
# Mapped value pDS391 in column vector_id to GGAACGCGACACCGGGTAGA in column guide_sequence of adata.obs
# Mapped value pDS434 in column vector_id to GGGGCCAGCAGCCGTCTACC in column guide_sequence of adata.obs
# Mapped value pDS458 in column vector_id to GGTCCGTCCGGAGCCAGGAG in column guide_sequence of adata.obs
# Mapped value pDS051 in column vector_id to GACGCAAAGACGCACAGACC in column guide_sequence of adata.obs
# Mapped value pDS052 in column vector_id to GCGCACAGACCCGGCGAGGA in column guide_sequence of adata.obs
# Mapped value pDS055 in column vector_id to GAGTCTCCGCAAGGCCCCGG in column guide_sequence of adata.obs
# Mapped value pDS468 in column vector_id to GTAGGAGCCTCGGGCGCGCT in column guide_sequence of adata.obs
# Mapped value pDS460 in column vector_id to GAGCCATGGCAGATTCCTCC in column guide_sequence of adata.obs
# Mapped value pDS006 in column vector_id to GCGACGTCCGAGCATTCCA in column guide_sequence of adata.obs
# Mapped value pDS024 in column vector_id to GCGCTGGTGGTCGATCGTG in column guide_sequence of adata.obs
# Mapped value pDS065 in column vector_id to GCGGCTATGAACCGCAGCAG in column guide_sequence of adata.obs
# Mapped value pDS462 in column vector_id to GGATGCTGTGGTGTCCACAG in column guide_sequence of adata.obs
# Mapped value pDS499 in column vector_id to GACCTTGCGTGCAGTTATGT in column guide_sequence of adata.obs
# Mapped value pDS495 in column vector_id to GTGAGACCCCAGGGTCGGGA in column guide_sequence of adata.obs
# Mapped value pDS382 in column vector_id to GTGGGTCCTTCGGCAGGAGG in column guide_sequence of adata.obs
# Mapped value pDS041 in column vector_id to GCGGTCCACAAAGGCTCAGA in column guide_sequence of adata.obs
# Mapped value pDS042 in column vector_id to GGTAGGCGCGGCTGACCGGT in column guide_sequence of adata.obs
# Mapped value pDS383 in column vector_id to GGCGCCCAGCGGAGCTAATC in column guide_sequence of adata.obs
# Mapped value pDS026 in column vector_id to GGGCGCCTGTGCTTGAGGTT in column guide_sequence of adata.obs
# Mapped value pDS074 in column vector_id to GCTTGCCTGGAACTCCTGTA in column guide_sequence of adata.obs
# Mapped value pDS463 in column vector_id to GTAGCTGCCTTCAGCCTTCAC in column guide_sequence of adata.obs
# Mapped value pDS508 in column vector_id to GCCATTGGGCTGTCAGTCAG in column guide_sequence of adata.obs
# Mapped value pDS491 in column vector_id to GCTGAGGGCGATGGCTGCTG in column guide_sequence of adata.obs
# Mapped value pDS386 in column vector_id to GAGACTTGCTTCCCCCTCAC in column guide_sequence of adata.obs
# Mapped value pDS390 in column vector_id to GTCACTGTAGGTGCGGCCCA in column guide_sequence of adata.obs
# Mapped value pDS494 in column vector_id to GGCAGCCTCGGCCCGAGTCC in column guide_sequence of adata.obs
# Mapped value pDS043 in column vector_id to GCAGGGCTCGCGCAGTTACC in column guide_sequence of adata.obs
# Mapped value pDS506 in column vector_id to GCAGGGCCGCGCGCAGGCGAG in column guide_sequence of adata.obs
# Mapped value pDS466 in column vector_id to GCTCAAGTGGACAGCCGGGA in column guide_sequence of adata.obs
# Mapped value pDS087 in column vector_id to GTCATCCTCACCGTCACGGC in column guide_sequence of adata.obs
# Mapped value pDS017 in column vector_id to GCGACGGTGAGGTCGACGC in column guide_sequence of adata.obs
# Mapped value pDS371 in column vector_id to GGCGACGGTGAGGTCGACGC in column guide_sequence of adata.obs
# Mapped value pDS088 in column vector_id to GGGATAAATGGAGGAGTACG in column guide_sequence of adata.obs
# Mapped value pDS089 in column vector_id to GGACAGCGTGCGAGCTCCGG in column guide_sequence of adata.obs
# Mapped value pDS090 in column vector_id to GGCGCGTGCGCCCTCTTACT in column guide_sequence of adata.obs
# Mapped value pDS091 in column vector_id to GCGGAGGACCCCGCTCTCAG in column guide_sequence of adata.obs
# Mapped value pDS393 in column vector_id to GGGGCCCGCGTGGATCTCTA in column guide_sequence of adata.obs
# Mapped value pDS002 in column vector_id to GGGCCGCGTGAGGGGACACCA in column guide_sequence of adata.obs
# Mapped value pDS110 in column vector_id to GGGGCCCCATCGGCTTCCGT in column guide_sequence of adata.obs
# Mapped value pDS096 in column vector_id to GGTTTCTCAGACCTAGGTGA in column guide_sequence of adata.obs
# Mapped value pDS027 in column vector_id to GACTTGGAGGCGGTGCGGCG in column guide_sequence of adata.obs
# Mapped value pDS394 in column vector_id to GCAGCACCGGCAAGCAACCC in column guide_sequence of adata.obs
# Mapped value pDS124 in column vector_id to GCGAGCAAGGAGCCCCCGGC in column guide_sequence of adata.obs
# Mapped value pDS498 in column vector_id to GTCTGGCTGGTCGCACCCGG in column guide_sequence of adata.obs
# Mapped value pDS395 in column vector_id to GGGCCAGTCCCTAAGCACGT in column guide_sequence of adata.obs
# Mapped value pDS396 in column vector_id to GCAGCGGCGACCGGAGCGGT in column guide_sequence of adata.obs
# Mapped value pDS353 in column vector_id to GGCTTGTTCGCTGGTGGCGT in column guide_sequence of adata.obs
# Mapped value pDS397 in column vector_id to GGGCGCCGCCGGGACAGCGG in column guide_sequence of adata.obs
# Mapped value pDS029 in column vector_id to GGGCAACCTAGCAGCTCCTC in column guide_sequence of adata.obs
# Mapped value pDS398 in column vector_id to GTTTTCAGCAGAGACGTAGA in column guide_sequence of adata.obs
# Mapped value pDS488 in column vector_id to GCCGTCCCGGAGACCCGGTC in column guide_sequence of adata.obs
# Mapped value pDS478 in column vector_id to GCTGGCGCCCAGCAAAGGCT in column guide_sequence of adata.obs
# Mapped value pDS510 in column vector_id to GCGCGCTCAGTGAGAGGAAA in column guide_sequence of adata.obs
# Mapped value pDS156 in column vector_id to GCTGCCTCGCAGAGCTGCCC in column guide_sequence of adata.obs
# Mapped value pDS467 in column vector_id to GGGCGCAGTGCGGCGGTCAC in column guide_sequence of adata.obs
# Mapped value pDS159 in column vector_id to GGCCGGAGGACCCGGAGCTA in column guide_sequence of adata.obs
# Mapped value pDS160 in column vector_id to GGCCTTAGCTCCGGGTCCTC in column guide_sequence of adata.obs
# Mapped value pDS031 in column vector_id to GCTGTGCAGTGGAACGCGCT in column guide_sequence of adata.obs
# Mapped value pDS032 in column vector_id to GTGCTAGCCCGGCGGCAAG in column guide_sequence of adata.obs
# Mapped value pDS033 in column vector_id to GTACGGAGCCCCCGAAAGAC in column guide_sequence of adata.obs
# Mapped value pDS162 in column vector_id to GGCGGACGGATAGAAAGTTA in column guide_sequence of adata.obs
# Mapped value pDS440 in column vector_id to GCTCCAGTGCTACGTGTCCC in column guide_sequence of adata.obs
# Mapped value pDS218 in column vector_id to GGTGCAGAGCGTGGTCGTGG in column guide_sequence of adata.obs
# Mapped value pDS373 in column vector_id to GGTGGTGGCTGAGTCCGTGG in column guide_sequence of adata.obs
# Mapped value pDS046 in column vector_id to GGTCGCATGCAGCTCCTATG in column guide_sequence of adata.obs
# Mapped value pDS219 in column vector_id to GCCGGGAAAGGAGAGGATCC in column guide_sequence of adata.obs
# Mapped value pDS433 in column vector_id to GAGATGTCCGGGTAGCGCCA in column guide_sequence of adata.obs
# Mapped value pDS479 in column vector_id to GCGGCGGACCCGGCCCTAGG in column guide_sequence of adata.obs
# Mapped value pDS401 in column vector_id to GTCAGACAAGTCGGAGGGGA in column guide_sequence of adata.obs
# Mapped value pDS402 in column vector_id to GGCCGGTCCGCCGCCGGAAC in column guide_sequence of adata.obs
# Mapped value pDS403 in column vector_id to GAGAAGCAGGTCCCAGGCGG in column guide_sequence of adata.obs
# Mapped value pDS505 in column vector_id to GCCTCCAAGATGGCGAGCGG in column guide_sequence of adata.obs
# Mapped value pDS482 in column vector_id to GGCGAACGCGGCCTGAATTCC in column guide_sequence of adata.obs
# Mapped value pDS404 in column vector_id to GGCCACCCGGCGCGAGTCCG in column guide_sequence of adata.obs
# Mapped value pDS011 in column vector_id to GGGAGCCCCGCGGATCGTTT in column guide_sequence of adata.obs
# Mapped value pDS442 in column vector_id to GGCGCTGGGTTCCTGGTGAGT in column guide_sequence of adata.obs
# Mapped value pDS405 in column vector_id to GGAGGAGCCAAGAGGCGGGT in column guide_sequence of adata.obs
# Mapped value pDS496 in column vector_id to GCCGCGGAGACCCGCCCCAG in column guide_sequence of adata.obs
# Mapped value pDS284 in column vector_id to GAAGTAGGCGCTGGCAACGC in column guide_sequence of adata.obs
# Mapped value pDS430 in column vector_id to GCGGCACCAGCCACTCCGCA in column guide_sequence of adata.obs
# Mapped value pDS036 in column vector_id to GAGACTCGTTCACCACCGA in column guide_sequence of adata.obs
# Mapped value pDS175 in column vector_id to GTGAGGCCGAAGCCAGGACC in column guide_sequence of adata.obs
# Mapped value pDS038 in column vector_id to GCAGCCACATCACCCTTCCG in column guide_sequence of adata.obs
# Mapped value pDS407 in column vector_id to GAAGGCTGGAAGACGAGGTA in column guide_sequence of adata.obs
# Mapped value pDS408 in column vector_id to GTCCGGATCCTGTTAGACAC in column guide_sequence of adata.obs
# Mapped value pDS410 in column vector_id to GTGACTCGCAGTAGACGCGG in column guide_sequence of adata.obs
# Mapped value pDS040 in column vector_id to GCGGTAAGCAAACACTTACA in column guide_sequence of adata.obs
# Mapped value pDS411 in column vector_id to GTCCGCGGAGCGACGACCGG in column guide_sequence of adata.obs
# Mapped value pDS186 in column vector_id to GGGTGCAGGGGACCGCGTCA in column guide_sequence of adata.obs
# Mapped value pDS226 in column vector_id to GTGACACGTAGCAACGGGGC in column guide_sequence of adata.obs

# %% [markdown]
# ### Extract perturbation symbols

# %% [markdown]
# #### Add `perturbation_target_symbol` column based on the `perturbation_name`

# %%
cur_data.create_columns(
    slot="obs",
    col_dict={"perturbed_target_symbol": cur_data.adata.obs["perturbation_name"]},
    overwrite=True,
)
cur_data.show_unique(slot="obs", column="perturbed_target_symbol")
# Out:
# Column perturbed_target_symbol added to adata.obs
# Unique values in adata.obs.perturbed_target_symbol: 113
# --------------------------------------------------
# {'62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# #### Clean up `perturbation_target_symbol` column

# %%
cur_data.replace_entries(
    slot="obs",
    column="perturbed_target_symbol",
    map_dict={
        r"62\(mod\).*": "control_nontargeting",
        r"63\(mod\).*": "control_nontargeting",
        r"Gal4-4.*": "control_nontargeting",
        r"_(pD|pB).*": "",
    }
)


cur_data.show_unique(slot="obs", column="perturbed_target_symbol")
# Out:
# Replaced '62\(mod\).*' with 'control_nontargeting' in column perturbed_target_symbol of adata.obs
# Replaced '63\(mod\).*' with 'control_nontargeting' in column perturbed_target_symbol of adata.obs
# Replaced 'Gal4-4.*' with 'control_nontargeting' in column perturbed_target_symbol of adata.obs
# Replaced '_(pD|pB).*' with '' in column perturbed_target_symbol of adata.obs
# Unique values in adata.obs.perturbed_target_symbol: 91
# --------------------------------------------------
# {'AARS',
#  'AMIGO3',
#  'ARHGAP22',
#  'ASCC3',
#  'ATF4',
#  'ATF6',
#  'ATP5B',
#  'C7orf26',
#  'CAD',
#  'CARS',
#  'CCND3',
#  'CHERP',
#  'COPB1',
#  'COPZ1',
#  'DAD1',
#  'DARS',
#  'DDOST',
#  'DDRGK1',
#  'DERL2',
#  'DHDDS',
#  'DNAJC19',
#  'EIF2AK3',
#  'EIF2B2',
#  'EIF2B3',
#  'EIF2B4',
#  'EIF2S1',
#  'ERN1',
#  'FARSB',
#  'FECH',
#  'GBF1',
#  'GMPPB',
#  'GNPNAT1',
#  'HARS',
#  'HSD17B12',
#  'HSPA5',
#  'HSPA9',
#  'HYOU1',
#  'IARS2',
#  'IDH3A',
#  'IER3IP1',
#  'KCTD16',
#  'MANF',
#  'MARS',
#  'MRGBP',
#  'MRPL39',
#  'MTHFD1',
#  'NEDD8',
#  'OST4',
#  'P4HB',
#  'PDIA6',
#  'PPWD1',
#  'PSMA1',
#  'PSMD12',
#  'PSMD4',
#  'PTDSS1',
#  'QARS',
#  'SAMM50',
#  'SARS',
#  'SCYL1',
#  'SEC61A1',
#  'SEC61B',
#  'SEC61G',
#  'SEC63',
#  'SEL1L',
#  'SLC35B1',
#  'SLC39A7',
#  'SLMO2',
#  'SOCS1',
#  'SPCS2',
#  'SPCS3',
#  'SRP68',
#  'SRP72',
#  'SRPR',
#  'SRPRB',
#  'STT3A',
#  'SYVN1',
#  'TARS',
#  'TELO2',
#  'TIMM23',
#  'TIMM44',
#  'TMED10',
#  'TMED2',
#  'TMEM167A',
#  'TTI1',
#  'TTI2',
#  'UFL1',
#  'UFM1',
#  'XBP1',
#  'XRN1',
#  'YIPF5',
#  'control_nontargeting'}
# --------------------------------------------------
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/Perturbseq/curation_notebooks/../../curation_tools/curation_tools.py:282: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   if df[column].str.contains(old_val).any():

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot="obs",
    input_column="perturbed_target_symbol",
    input_column_type="gene_symbol",
    multiple_entries=False
)
# Out:
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/Perturbseq/curation_notebooks/../../curation_tools/curation_tools.py:1216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df["synonyms"] = map_df["synonyms"].str.split("|")
# Mapped potential synonyms in perturbed_target_symbol of the provided dataframe to gene symbols
# Converted 62611/62623 gene symbols/ENSG IDs to standardized gene symbols/ENSG IDs
# --------------------------------------------------

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
cur_data.count_entries(
    slot="obs",
    input_column="perturbed_target_symbol",
    count_column_name="perturbed_target_number",
    sep="|",
)
# Out:
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number

# %%
cur_data.show_obs(
    ["perturbation_name", "perturbed_target_symbol", "perturbed_target_ensg"]
)
# Out:
# Observation data:
# DataFrame shape: (62623, 3)
# --------------------------------------------------
#                perturbation_name perturbed_target_symbol perturbed_target_ensg
# index
# AAACATACAAGATG    63(mod)_pBA580    control_nontargeting  control_nontargeting
# AAACATACACCTAG       OST4_pDS353                    OST4       ENSG00000228474
# AAACATACTTCCCG    SEC61A1_pDS031                 SEC61A1       ENSG00000058262
# AAACATTGAAACAG     EIF2B4_pDS491                  EIF2B4       ENSG00000115211
# AAACATTGCAGCTA       SRPR_pDS482                   SRPRA       ENSG00000182934
# ...                          ...                     ...                   ...
# TTTGCATGCTTTAC      STT3A_pDS011                   STT3A       ENSG00000134910
# TTTGCATGGAGGAC   ARHGAP22_pDS458                ARHGAP22       ENSG00000128805
# TTTGCATGTAGAGA    63(mod)_pBA580    control_nontargeting  control_nontargeting
# TTTGCATGTCAAGC     KCTD16_pDS096                  KCTD16       ENSG00000183775
# TTTGCATGTGGAGG     SAMM50_pDS156                  SAMM50       ENSG00000100347
#
# [62623 rows x 3 columns]
# --------------------------------------------------

# %% [markdown]
# ### Add treatment information

# %% [markdown]
# Add treatment information with the dataset

# %%
cur_data.create_columns(
    slot="obs", col_dict={"treatment_label": None, "treatment_id": None}
)
# Out:
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs

# %% [markdown]
# ### Add perturbation information

# %%
cur_data.create_columns(
    slot="obs",
    col_dict={"perturbation_type_label": "CRISPRi", "perturbation_type_id": None},
)
# Out:
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs

# %% [markdown]
# ### Add timepoint information

# %%
cur_data.create_columns(
    slot="obs",
    col_dict={"timepoint": "P0DT0H0M0S"},
)
# Out:
# Column timepoint added to adata.obs

# %% [markdown]
# ### Add model system information

# %%
cur_data.create_columns(
    slot="obs", col_dict={"model_system_label": "cell line", "model_system_id": None}
)
# Out:
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs

# %% [markdown]
# ### Add tissue information

# %%
cur_data.create_columns(slot="obs", col_dict={"tissue": "blood"})

cur_data.standardize_ontology(
    input_column="tissue",
    column_type="term_name",
    ontology_type="tissue",
    overwrite=True,
)
# Out:
# Column tissue added to adata.obs
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower name_lower     ontology_id
# 0        blood              blood      blood  UBERON:0000178
# --------------------------------------------------

# %% [markdown]
# ### Add cell type information

# %%
cur_data.standardize_ontology(
    input_column="celltype", column_type="term_name", ontology_type="cell_type"
)
# Out:
# Mapped 1 cell_type ontology terms from `celltype` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#    input_column input_column_lower    name_lower ontology_id
# 0  lymphoblasts       lymphoblasts  lymphoblasts  CL:0017005
# --------------------------------------------------

# %% [markdown]
# ### Add cell line information

# %%
cur_data.standardize_ontology(
    input_column="cell_line", column_type="term_name", ontology_type="cell_line"
)
# Out:
# Mapped 1 cell_line ontology terms from `cell_line` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower name_lower  ontology_id
# 0         K562               k562       k562  CLO:0007050
# --------------------------------------------------

# %% [markdown]
# ### Add disease information

# %%
cur_data.standardize_ontology(
    input_column="disease", column_type="term_name", ontology_type="disease"
)
# Out:
# Mapped 1 disease ontology terms from `disease` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                    input_column            input_column_lower  \
# 0  chronic myelogenous leukemia  chronic myelogenous leukemia
#
#                      name_lower    ontology_id
# 0  chronic myelogenous leukemia  MONDO:0011996
# --------------------------------------------------

# %% [markdown]
# ### Add species information

# %%
cur_data.create_columns(slot="obs", col_dict={"species": "Homo sapiens"})
# Out:
# Column species added to adata.obs

# %% [markdown]
# ### Add sex information

# %%
cur_data.create_columns(slot="obs", col_dict={"sex_label": "female", "sex_id": None})
# Out:
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs

# %% [markdown]
# ### Add developmental stage information

# %%
cur_data.create_columns(
    slot="obs",
    col_dict={"developmental_stage_label": "adult", "developmental_stage_id": None},
)
# Out:
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot="obs")
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot="obs")
# Out:
# adata.obs is valid according to the obs_schema.
# Validated data:
#       perturbation_name        perturbed_target_coord  \
# 0        63(mod)_pBA580                           NaN
# 1           OST4_pDS353     chr2:27070472-27071654;-1
# 2        SEC61A1_pDS031    chr3:128051641-128071705;1
# 3         EIF2B4_pDS491     chr2:27364352-27370338;-1
# 4           SRPR_pDS482  chr11:126262938-126269144;-1
# ...                 ...                           ...
# 62618      STT3A_pDS011   chr11:125591712-125625215;1
# 62619   ARHGAP22_pDS458    chr10:48446036-48656265;-1
# 62620    63(mod)_pBA580                           NaN
# 62621     KCTD16_pDS096    chr5:144170873-144485686;1
# 62622     SAMM50_pDS156     chr22:43955442-44010531;1
#
#        perturbed_target_number perturbed_target_ensg perturbed_target_symbol  \
# 0                            1  control_nontargeting    control_nontargeting
# 1                            1       ENSG00000228474                    OST4
# 2                            1       ENSG00000058262                 SEC61A1
# 3                            1       ENSG00000115211                  EIF2B4
# 4                            1       ENSG00000182934                   SRPRA
# ...                        ...                   ...                     ...
# 62618                        1       ENSG00000134910                   STT3A
# 62619                        1       ENSG00000128805                ARHGAP22
# 62620                        1  control_nontargeting    control_nontargeting
# 62621                        1       ENSG00000183775                  KCTD16
# 62622                        1       ENSG00000100347                  SAMM50
#
#       perturbed_target_biotype         guide_sequence perturbation_type_label  \
# 0                          NaN                    nan                 CRISPRi
# 1               protein_coding   GGCTTGTTCGCTGGTGGCGT                 CRISPRi
# 2               protein_coding   GCTGTGCAGTGGAACGCGCT                 CRISPRi
# 3               protein_coding   GCTGAGGGCGATGGCTGCTG                 CRISPRi
# 4               protein_coding  GGCGAACGCGGCCTGAATTCC                 CRISPRi
# ...                        ...                    ...                     ...
# 62618           protein_coding   GGGAGCCCCGCGGATCGTTT                 CRISPRi
# 62619           protein_coding   GGTCCGTCCGGAGCCAGGAG                 CRISPRi
# 62620                      NaN                    nan                 CRISPRi
# 62621           protein_coding   GGTTTCTCAGACCTAGGTGA                 CRISPRi
# 62622           protein_coding   GCTGCCTCGCAGAGCTGCCC                 CRISPRi
#
#       perturbation_type_id   timepoint  ... cell_type_label cell_type_id  \
# 0                     None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 1                     None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 2                     None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 3                     None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 4                     None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# ...                    ...         ...  ...             ...          ...
# 62618                 None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 62619                 None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 62620                 None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 62621                 None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
# 62622                 None  P0DT0H0M0S  ...     lymphoblast   CL:0017005
#
#       cell_line_label cell_line_id sex_label sex_id developmental_stage_label  \
# 0          K 562 cell  CLO:0007050    female   None                     adult
# 1          K 562 cell  CLO:0007050    female   None                     adult
# 2          K 562 cell  CLO:0007050    female   None                     adult
# 3          K 562 cell  CLO:0007050    female   None                     adult
# 4          K 562 cell  CLO:0007050    female   None                     adult
# ...               ...          ...       ...    ...                       ...
# 62618      K 562 cell  CLO:0007050    female   None                     adult
# 62619      K 562 cell  CLO:0007050    female   None                     adult
# 62620      K 562 cell  CLO:0007050    female   None                     adult
# 62621      K 562 cell  CLO:0007050    female   None                     adult
# 62622      K 562 cell  CLO:0007050    female   None                     adult
#
#       developmental_stage_id                                    disease_label  \
# 0                       None  chronic myelogenous leukemia, BCR-ABL1 positive
# 1                       None  chronic myelogenous leukemia, BCR-ABL1 positive
# 2                       None  chronic myelogenous leukemia, BCR-ABL1 positive
# 3                       None  chronic myelogenous leukemia, BCR-ABL1 positive
# 4                       None  chronic myelogenous leukemia, BCR-ABL1 positive
# ...                      ...                                              ...
# 62618                   None  chronic myelogenous leukemia, BCR-ABL1 positive
# 62619                   None  chronic myelogenous leukemia, BCR-ABL1 positive
# 62620                   None  chronic myelogenous leukemia, BCR-ABL1 positive
# 62621                   None  chronic myelogenous leukemia, BCR-ABL1 positive
# 62622                   None  chronic myelogenous leukemia, BCR-ABL1 positive
#
#           disease_id
# 0      MONDO:0011996
# 1      MONDO:0011996
# 2      MONDO:0011996
# 3      MONDO:0011996
# 4      MONDO:0011996
# ...              ...
# 62618  MONDO:0011996
# 62619  MONDO:0011996
# 62620  MONDO:0011996
# 62621  MONDO:0011996
# 62622  MONDO:0011996
#
# [62623 rows x 27 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.show_var()
# Out:
# Variable data:
# DataFrame shape: (32738, 3)
# --------------------------------------------------
#                    ensembl_id  ncounts  ncells
# gene_symbol
# MIR1302-10    ENSG00000243485     11.0      11
# FAM138A       ENSG00000237613      0.0       0
# OR4F5         ENSG00000186092      0.0       0
# RP11-34P13.7  ENSG00000238009      0.0       0
# RP11-34P13.8  ENSG00000239945     43.0      43
# ...                       ...      ...     ...
# AC145205.1    ENSG00000215635      0.0       0
# BAGE5         ENSG00000268590      0.0       0
# CU459201.1    ENSG00000251180      0.0       0
# AC002321.2    ENSG00000215616      0.0       0
# AC002321.1    ENSG00000215611      0.0       0
#
# [32738 rows x 3 columns]
# --------------------------------------------------

# %%
cur_data.standardize_genes(
    slot="var", input_column="ensembl_id", input_column_type="ensembl_gene_id"
)
# Out:
# Converted 30168/32738 gene symbols/ENSG IDs to standardized gene symbols/ENSG IDs
# --------------------------------------------------

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot="var")
# Out:
# adata.var is valid according to the var_schema.
# Validated data:
#               ensembl_gene_id  gene_symbol
# index
# MIR1302-10    ENSG00000243485  MIR1302-2HG
# FAM138A       ENSG00000237613      FAM138A
# OR4F5         ENSG00000186092        OR4F5
# RP11-34P13.7  ENSG00000238009         None
# RP11-34P13.8  ENSG00000239945         None
# ...                       ...          ...
# AC145205.1    ENSG00000215635         None
# BAGE5         ENSG00000268590         None
# CU459201.1    ENSG00000251180         None
# AC002321.2    ENSG00000215616         None
# AC002321.1    ENSG00000215611         None
#
# [32738 rows x 2 columns]

# %% [markdown]
# # Metadata curation

# %% [markdown]
# ### Auto-populate available metadata

# %%
cur_data.populate_exp_metadata()
# Out:
# Experiment metadata populated with available fields from adata.obs:
# --------------------------------------------------
# {'associated_diseases': [{'term_id': 'MONDO:0011996',
#                           'term_label': 'chronic myelogenous leukemia, '
#                                         'BCR-ABL1 positive'}],
#  'experiment': {'number_of_perturbed_entities': 62623,
#                 'number_of_perturbed_targets': 89,
#                 'perturbation_type': [{'term_id': None,
#                                        'term_label': 'CRISPRi'}],
#                 'perturbed_target_biotype': ['protein_coding',
#                                              'processed_pseudogene'],
#                 'perturbed_targets': ['control_nontargeting',
#                                       'ENSG00000228474',
#                                       'ENSG00000058262',
#                                       'ENSG00000115211',
#                                       'ENSG00000182934',
#                                       'ENSG00000134049',
#                                       'ENSG00000145817',
#                                       'ENSG00000170445',
#                                       'ENSG00000101166',
#                                       'ENSG00000129562',
#                                       'ENSG00000265354',
#                                       'ENSG00000115866',
#                                       'ENSG00000176020',
#                                       'ENSG00000112249',
#                                       'ENSG00000166411',
#                                       'ENSG00000205981',
#                                       'ENSG00000120686',
#                                       'ENSG00000067704',
#                                       'ENSG00000136628',
#                                       'ENSG00000185338',
#                                       'ENSG00000014123',
#                                       'ENSG00000198171',
#                                       'ENSG00000134910',
#                                       'ENSG00000100347',
#                                       'ENSG00000106803',
#                                       'ENSG00000128805',
#                                       'ENSG00000118363',
#                                       'ENSG00000101189',
#                                       'ENSG00000071537',
#                                       'ENSG00000173540',
#                                       'ENSG00000185624',
#                                       'ENSG00000143870',
#                                       'ENSG00000183775',
#                                       'ENSG00000110955',
#                                       'ENSG00000112576',
#                                       'ENSG00000172071',
#                                       'ENSG00000110619',
#                                       'ENSG00000159352',
#                                       'ENSG00000113013',
#                                       'ENSG00000149428',
#                                       'ENSG00000100714',
#                                       'ENSG00000102794',
#                                       'ENSG00000174695',
#                                       'ENSG00000100522',
#                                       'ENSG00000129696',
#                                       'ENSG00000112473',
#                                       'ENSG00000072849',
#                                       'ENSG00000129559',
#                                       'ENSG00000113407',
#                                       'ENSG00000100726',
#                                       'ENSG00000025796',
#                                       'ENSG00000107862',
#                                       'ENSG00000154719',
#                                       'ENSG00000116120',
#                                       'ENSG00000145050',
#                                       'ENSG00000166986',
#                                       'ENSG00000149084',
#                                       'ENSG00000162298',
#                                       'ENSG00000066926',
#                                       'ENSG00000119718',
#                                       'ENSG00000031698',
#                                       'ENSG00000101407',
#                                       'ENSG00000114127',
#                                       'ENSG00000044574',
#                                       'ENSG00000167881',
#                                       'ENSG00000174780',
#                                       'ENSG00000181374',
#                                       'ENSG00000134001',
#                                       'ENSG00000104980',
#                                       'ENSG00000156471',
#                                       'ENSG00000244038',
#                                       'ENSG00000121073',
#                                       'ENSG00000132432',
#                                       'ENSG00000144867',
#                                       'ENSG00000170348',
#                                       'ENSG00000128272',
#                                       'ENSG00000070785',
#                                       'ENSG00000129083',
#                                       'ENSG00000085872',
#                                       'ENSG00000090861',
#                                       'ENSG00000113593',
#                                       'ENSG00000117682',
#                                       'ENSG00000111481',
#                                       'ENSG00000178607',
#                                       'ENSG00000086598',
#                                       'ENSG00000129128',
#                                       'ENSG00000197170',
#                                       'ENSG00000129084',
#                                       'ENSG00000118217',
#                                       'ENSG00000249947'],
#                 'timepoints': ['P0DT0H0M0S'],
#                 'treatments': [{'term_id': None, 'term_label': None}]},
#  'model_system': {'cell_line': [{'term_id': 'CLO:0007050',
#                                  'term_label': 'K 562 cell'}],
#                   'cell_type': [{'term_id': 'CL:0017005',
#                                  'term_label': 'lymphoblast'}],
#                   'developmental_stage': [{'term_id': None,
#                                            'term_label': 'adult'}],
#                   'model_system': [{'term_id': None,
#                                     'term_label': 'cell line'}],
#                   'sex': [{'term_id': None, 'term_label': 'female'}],
#                   'tissue': [{'term_id': 'UBERON:0000178',
#                               'term_label': 'blood'}]}}
# --------------------------------------------------

# %% [markdown]
# ### Manually curate metadata

# %% [markdown]
# Study details

# %%
cur_data.add_exp_metadata(
    metadata_slot="study",
    metadata={
        "title": "A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response",
        "study_uri": "https://doi.org/10.1016/j.cell.2016.11.048",
        "year": 2016,
        "first_author": {"first_name": "Britt", "last_name": "Adamson"},
        "last_author": {"first_name": "Jonathan", "last_name": "Weissman"},
    },
)
# Out:
# Metadata for 'study' successfully validated:
# --------------------------------------------------
# {'first_author': {'first_name': 'Britt', 'last_name': 'Adamson'},
#  'last_author': {'first_name': 'Jonathan', 'last_name': 'Weissman'},
#  'study_uri': 'https://doi.org/10.1016/j.cell.2016.11.048',
#  'title': 'A Multiplexed Single-Cell CRISPR Screening Platform Enables '
#           'Systematic Dissection of the Unfolded Protein Response',
#  'year': 2016}
# --------------------------------------------------

# %% [markdown]
# Experiment details

# %%
cur_data.add_exp_metadata(
    metadata_slot="experiment",
    metadata={
        "title": "63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.",
        "summary": "Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.",
        "replicates": "none",
        "number_of_samples": 1,
    },
)
# Out:
# Metadata for 'experiment' successfully validated:
# --------------------------------------------------
# {'number_of_perturbed_entities': 62623,
#  'number_of_perturbed_targets': 89,
#  'number_of_samples': 1,
#  'perturbation_type': [{'term_id': None, 'term_label': 'CRISPRi'}],
#  'perturbed_target_biotype': ['protein_coding', 'processed_pseudogene'],
#  'perturbed_targets': ['control_nontargeting',
#                        'ENSG00000228474',
#                        'ENSG00000058262',
#                        'ENSG00000115211',
#                        'ENSG00000182934',
#                        'ENSG00000134049',
#                        'ENSG00000145817',
#                        'ENSG00000170445',
#                        'ENSG00000101166',
#                        'ENSG00000129562',
#                        'ENSG00000265354',
#                        'ENSG00000115866',
#                        'ENSG00000176020',
#                        'ENSG00000112249',
#                        'ENSG00000166411',
#                        'ENSG00000205981',
#                        'ENSG00000120686',
#                        'ENSG00000067704',
#                        'ENSG00000136628',
#                        'ENSG00000185338',
#                        'ENSG00000014123',
#                        'ENSG00000198171',
#                        'ENSG00000134910',
#                        'ENSG00000100347',
#                        'ENSG00000106803',
#                        'ENSG00000128805',
#                        'ENSG00000118363',
#                        'ENSG00000101189',
#                        'ENSG00000071537',
#                        'ENSG00000173540',
#                        'ENSG00000185624',
#                        'ENSG00000143870',
#                        'ENSG00000183775',
#                        'ENSG00000110955',
#                        'ENSG00000112576',
#                        'ENSG00000172071',
#                        'ENSG00000110619',
#                        'ENSG00000159352',
#                        'ENSG00000113013',
#                        'ENSG00000149428',
#                        'ENSG00000100714',
#                        'ENSG00000102794',
#                        'ENSG00000174695',
#                        'ENSG00000100522',
#                        'ENSG00000129696',
#                        'ENSG00000112473',
#                        'ENSG00000072849',
#                        'ENSG00000129559',
#                        'ENSG00000113407',
#                        'ENSG00000100726',
#                        'ENSG00000025796',
#                        'ENSG00000107862',
#                        'ENSG00000154719',
#                        'ENSG00000116120',
#                        'ENSG00000145050',
#                        'ENSG00000166986',
#                        'ENSG00000149084',
#                        'ENSG00000162298',
#                        'ENSG00000066926',
#                        'ENSG00000119718',
#                        'ENSG00000031698',
#                        'ENSG00000101407',
#                        'ENSG00000114127',
#                        'ENSG00000044574',
#                        'ENSG00000167881',
#                        'ENSG00000174780',
#                        'ENSG00000181374',
#                        'ENSG00000134001',
#                        'ENSG00000104980',
#                        'ENSG00000156471',
#                        'ENSG00000244038',
#                        'ENSG00000121073',
#                        'ENSG00000132432',
#                        'ENSG00000144867',
#                        'ENSG00000170348',
#                        'ENSG00000128272',
#                        'ENSG00000070785',
#                        'ENSG00000129083',
#                        'ENSG00000085872',
#                        'ENSG00000090861',
#                        'ENSG00000113593',
#                        'ENSG00000117682',
#                        'ENSG00000111481',
#                        'ENSG00000178607',
#                        'ENSG00000086598',
#                        'ENSG00000129128',
#                        'ENSG00000197170',
#                        'ENSG00000129084',
#                        'ENSG00000118217',
#                        'ENSG00000249947'],
#  'replicates': 'none',
#  'summary': 'Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs '
#             'targeting UPR genes in K562 cells.',
#  'timepoints': ['P0DT0H0M0S'],
#  'title': '63000 chronic myeloid leukemia (K562) cells transfected with a UPR '
#           'sensor gene-targeting gRNAs.',
#  'treatments': [{'term_id': None, 'term_label': None}]}
# --------------------------------------------------

# %% [markdown]
# Perturbation details

# %%
cur_data.add_exp_metadata(
    metadata_slot="perturbation",
    metadata={
        "library_generation_type": {
            "term_id": "EFO:0022868",
            "term_label": "endogenous",
        },
        "library_generation_method": {
            "term_id": "EFO:0022895",
            "term_label": "dCas9-KRAB",
        },
        "enzyme_delivery_method": {
            "term_id": None,
            "term_label": "retroviral transduction",
        },
        "library_delivery_method": {
            "term_id": None,
            "term_label": "lentiviral transduction",
        },
        "enzyme_integration_state": {
            "term_id": None,
            "term_label": "random locus integration",
        },
        "library_integration_state": {
            "term_id": None,
            "term_label": "random locus integration",
        },
        "enzyme_expression_control": {
            "term_id": None,
            "term_label": "constitutive expression",
        },
        "library_expression_control": {
            "term_id": None,
            "term_label": "constitutive expression",
        },
        "library": {
            "library_name": "custom",
            "accession": None,
            "library_format": {
                "term_id": None,
                "term_label": "pooled",
            },
            "library_scope": {
                "term_id": None,
                "term_label": "focused",
            },
            "library_perturbation_type": [
                {
                    "term_id": None,
                    "term_label": "inhibition",
                },
            ],
            "manufacturer": "Weissman",
            "lentiviral_generation": "3",
            "grnas_per_gene": "1",
            "total_grnas": "91",
            "total_variants": None,
        },
    },
)
# Out:
# Metadata for 'perturbation' successfully validated:
# --------------------------------------------------
# {'enzyme_delivery_method': {'term_id': None,
#                             'term_label': 'retroviral transduction'},
#  'enzyme_expression_control': {'term_id': None,
#                                'term_label': 'constitutive expression'},
#  'enzyme_integration_state': {'term_id': None,
#                               'term_label': 'random locus integration'},
#  'library': {'accession': None,
#              'grnas_per_target': None,
#              'lentiviral_generation': '3',
#              'library_format': {'term_id': None, 'term_label': 'pooled'},
#              'library_name': 'custom',
#              'library_perturbation_type': [{'term_id': None,
#                                             'term_label': 'inhibition'}],
#              'library_scope': {'term_id': None, 'term_label': 'focused'},
#              'manufacturer': 'Weissman',
#              'total_grnas': '91',
#              'total_variants': None},
#  'library_delivery_method': {'term_id': None,
#                              'term_label': 'lentiviral transduction'},
#  'library_expression_control': {'term_id': None,
#                                 'term_label': 'constitutive expression'},
#  'library_generation_method': {'term_id': 'EFO:0022895',
#                                'term_label': 'dCas9-KRAB'},
#  'library_generation_type': {'term_id': 'EFO:0022868',
#                              'term_label': 'endogenous'},
#  'library_integration_state': {'term_id': None,
#                                'term_label': 'random locus integration'}}
# --------------------------------------------------

# %% [markdown]
# Assay details

# %%
cur_data.add_exp_metadata(
    metadata_slot="assay",
    metadata={
        "readout_dimensionality": {
            "term_id": None,
            "term_label": "high-dimensional assay",
        },
        "readout_type": {
            "term_id": None,
            "term_label": "transcriptomic",
        },
        "readout_technology": {
            "term_id": None,
            "term_label": "single-cell rna-seq",
        },
        "method_name": {
            "term_id": None,
            "term_label": "Perturb-seq",
        },
        "method_uri": None,
        "sequencing_library_kit": {
            "term_id": None,
            "term_label": "10x Genomics Single Cell 3-prime",
        },
        "sequencing_platform": {"term_id": None, "term_label": "Illumina HiSeq 4000"},
        "sequencing_strategy": {"term_id": None, "term_label": "barcode sequencing"},
        "software_counts": {"term_id": None, "term_label": "CellRanger"},
        "software_analysis": {"term_id": None, "term_label": "MAGeCK"},
        "reference_genome": {
            "term_id": None,
            "term_label": "GRCh37",
        },
    },
)
# Out:
# Metadata for 'assay' successfully validated:
# --------------------------------------------------
# {'method_name': {'term_id': None, 'term_label': 'Perturb-seq'},
#  'method_uri': None,
#  'readout_dimensionality': {'term_id': None,
#                             'term_label': 'high-dimensional assay'},
#  'readout_technology': {'term_id': None, 'term_label': 'single-cell rna-seq'},
#  'readout_type': {'term_id': None, 'term_label': 'transcriptomic'},
#  'reference_genome': {'term_id': None, 'term_label': 'GRCh37'},
#  'sequencing_library_kit': {'term_id': None,
#                             'term_label': '10x Genomics Single Cell 3-prime'},
#  'sequencing_platform': {'term_id': None, 'term_label': 'Illumina HiSeq 4000'},
#  'sequencing_strategy': {'term_id': None, 'term_label': 'barcode sequencing'},
#  'software_analysis': {'term_id': None, 'term_label': 'MAGeCK'},
#  'software_counts': {'term_id': None, 'term_label': 'CellRanger'}}
# --------------------------------------------------

# %% [markdown]
# Model system details

# %%
cur_data.add_exp_metadata(
    metadata_slot="model_system",
    metadata={
        "species": "Homo sapiens",
        "passage_number": None,
    },
)
# Out:
# Metadata for 'model_system' successfully validated:
# --------------------------------------------------
# {'cell_line': [{'term_id': 'CLO:0007050', 'term_label': 'K 562 cell'}],
#  'cell_type': [{'term_id': 'CL:0017005', 'term_label': 'lymphoblast'}],
#  'developmental_stage': [{'term_id': None, 'term_label': 'adult'}],
#  'model_system': [{'term_id': None, 'term_label': 'cell line'}],
#  'passage_number': None,
#  'sex': [{'term_id': None, 'term_label': 'female'}],
#  'species': 'Homo sapiens',
#  'tissue': [{'term_id': 'UBERON:0000178', 'term_label': 'blood'}]}
# --------------------------------------------------

# %% [markdown]
# Associated dataset details

# %%
cur_data.add_exp_metadata(
    metadata_slot="associated_datasets",
    metadata=[
        {
            "dataset_accession": "GSM2406677",
            "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681",
            "dataset_description": "Barcode, cell identities, raw gene expression matrix",
            "dataset_file_name": "GSM2406677_10X010",
        },
        {
            "dataset_accession": "GSM2406677_10X005",
            "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad",
            "dataset_description": "Processed .h5ad file",
            "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad",
        },
    ],
)
# Out:
# Metadata for 'associated_datasets' successfully validated:
# --------------------------------------------------
# [{'dataset_accession': 'GSM2406677',
#   'dataset_description': 'Barcode, cell identities, raw gene expression matrix',
#   'dataset_file_name': 'GSM2406677_10X010',
#   'dataset_uri': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681'},
#  {'dataset_accession': 'GSM2406677_10X005',
#   'dataset_description': 'Processed .h5ad file',
#   'dataset_file_name': 'AdamsonWeissman2016_GSM2406681_10X010.h5ad',
#   'dataset_uri': 'https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad'}]
# --------------------------------------------------

# %% [markdown]
# ### Validate metadata

# %%
cur_data.validate_exp_metadata()
# Out:
# Experiment metadata successfully validated:
# --------------------------------------------------
# {'assay': {'method_name': {'term_id': None, 'term_label': 'Perturb-seq'},
#            'method_uri': None,
#            'readout_dimensionality': {'term_id': None,
#                                       'term_label': 'high-dimensional assay'},
#            'readout_technology': {'term_id': None,
#                                   'term_label': 'single-cell rna-seq'},
#            'readout_type': {'term_id': None, 'term_label': 'transcriptomic'},
#            'reference_genome': {'term_id': None, 'term_label': 'GRCh37'},
#            'sequencing_library_kit': {'term_id': None,
#                                       'term_label': '10x Genomics Single Cell '
#                                                     '3-prime'},
#            'sequencing_platform': {'term_id': None,
#                                    'term_label': 'Illumina HiSeq 4000'},
#            'sequencing_strategy': {'term_id': None,
#                                    'term_label': 'barcode sequencing'},
#            'software_analysis': {'term_id': None, 'term_label': 'MAGeCK'},
#            'software_counts': {'term_id': None, 'term_label': 'CellRanger'}},
#  'associated_datasets': [{'dataset_accession': 'GSM2406677',
#                           'dataset_description': 'Barcode, cell identities, '
#                                                  'raw gene expression matrix',
#                           'dataset_file_name': 'GSM2406677_10X010',
#                           'dataset_uri': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681'},
#                          {'dataset_accession': 'GSM2406677_10X005',
#                           'dataset_description': 'Processed .h5ad file',
#                           'dataset_file_name': 'AdamsonWeissman2016_GSM2406681_10X010.h5ad',
#                           'dataset_uri': 'https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad'}],
#  'associated_diseases': [{'term_id': 'MONDO:0011996',
#                           'term_label': 'chronic myelogenous leukemia, '
#                                         'BCR-ABL1 positive'}],
#  'experiment': {'number_of_perturbed_entities': 62623,
#                 'number_of_perturbed_targets': 89,
#                 'number_of_samples': 1,
#                 'perturbation_type': [{'term_id': None,
#                                        'term_label': 'CRISPRi'}],
#                 'perturbed_target_biotype': ['protein_coding',
#                                              'processed_pseudogene'],
#                 'perturbed_targets': ['control_nontargeting',
#                                       'ENSG00000228474',
#                                       'ENSG00000058262',
#                                       'ENSG00000115211',
#                                       'ENSG00000182934',
#                                       'ENSG00000134049',
#                                       'ENSG00000145817',
#                                       'ENSG00000170445',
#                                       'ENSG00000101166',
#                                       'ENSG00000129562',
#                                       'ENSG00000265354',
#                                       'ENSG00000115866',
#                                       'ENSG00000176020',
#                                       'ENSG00000112249',
#                                       'ENSG00000166411',
#                                       'ENSG00000205981',
#                                       'ENSG00000120686',
#                                       'ENSG00000067704',
#                                       'ENSG00000136628',
#                                       'ENSG00000185338',
#                                       'ENSG00000014123',
#                                       'ENSG00000198171',
#                                       'ENSG00000134910',
#                                       'ENSG00000100347',
#                                       'ENSG00000106803',
#                                       'ENSG00000128805',
#                                       'ENSG00000118363',
#                                       'ENSG00000101189',
#                                       'ENSG00000071537',
#                                       'ENSG00000173540',
#                                       'ENSG00000185624',
#                                       'ENSG00000143870',
#                                       'ENSG00000183775',
#                                       'ENSG00000110955',
#                                       'ENSG00000112576',
#                                       'ENSG00000172071',
#                                       'ENSG00000110619',
#                                       'ENSG00000159352',
#                                       'ENSG00000113013',
#                                       'ENSG00000149428',
#                                       'ENSG00000100714',
#                                       'ENSG00000102794',
#                                       'ENSG00000174695',
#                                       'ENSG00000100522',
#                                       'ENSG00000129696',
#                                       'ENSG00000112473',
#                                       'ENSG00000072849',
#                                       'ENSG00000129559',
#                                       'ENSG00000113407',
#                                       'ENSG00000100726',
#                                       'ENSG00000025796',
#                                       'ENSG00000107862',
#                                       'ENSG00000154719',
#                                       'ENSG00000116120',
#                                       'ENSG00000145050',
#                                       'ENSG00000166986',
#                                       'ENSG00000149084',
#                                       'ENSG00000162298',
#                                       'ENSG00000066926',
#                                       'ENSG00000119718',
#                                       'ENSG00000031698',
#                                       'ENSG00000101407',
#                                       'ENSG00000114127',
#                                       'ENSG00000044574',
#                                       'ENSG00000167881',
#                                       'ENSG00000174780',
#                                       'ENSG00000181374',
#                                       'ENSG00000134001',
#                                       'ENSG00000104980',
#                                       'ENSG00000156471',
#                                       'ENSG00000244038',
#                                       'ENSG00000121073',
#                                       'ENSG00000132432',
#                                       'ENSG00000144867',
#                                       'ENSG00000170348',
#                                       'ENSG00000128272',
#                                       'ENSG00000070785',
#                                       'ENSG00000129083',
#                                       'ENSG00000085872',
#                                       'ENSG00000090861',
#                                       'ENSG00000113593',
#                                       'ENSG00000117682',
#                                       'ENSG00000111481',
#                                       'ENSG00000178607',
#                                       'ENSG00000086598',
#                                       'ENSG00000129128',
#                                       'ENSG00000197170',
#                                       'ENSG00000129084',
#                                       'ENSG00000118217',
#                                       'ENSG00000249947'],
#                 'replicates': 'none',
#                 'summary': 'Perturb-seq was applied to a small CRISPRi library '
#                            'of 91 sgRNAs targeting UPR genes in K562 cells.',
#                 'timepoints': ['P0DT0H0M0S'],
#                 'title': '63000 chronic myeloid leukemia (K562) cells '
#                          'transfected with a UPR sensor gene-targeting gRNAs.',
#                 'treatments': [{'term_id': None, 'term_label': None}]},
#  'model_system': {'cell_line': [{'term_id': 'CLO:0007050',
#                                  'term_label': 'K 562 cell'}],
#                   'cell_type': [{'term_id': 'CL:0017005',
#                                  'term_label': 'lymphoblast'}],
#                   'developmental_stage': [{'term_id': None,
#                                            'term_label': 'adult'}],
#                   'model_system': [{'term_id': None,
#                                     'term_label': 'cell line'}],
#                   'passage_number': None,
#                   'sex': [{'term_id': None, 'term_label': 'female'}],
#                   'species': 'Homo sapiens',
#                   'tissue': [{'term_id': 'UBERON:0000178',
#                               'term_label': 'blood'}]},
#  'perturbation': {'enzyme_delivery_method': {'term_id': None,
#                                              'term_label': 'retroviral '
#                                                            'transduction'},
#                   'enzyme_expression_control': {'term_id': None,
#                                                 'term_label': 'constitutive '
#                                                               'expression'},
#                   'enzyme_integration_state': {'term_id': None,
#                                                'term_label': 'random locus '
#                                                              'integration'},
#                   'library': {'accession': None,
#                               'grnas_per_target': None,
#                               'lentiviral_generation': '3',
#                               'library_format': {'term_id': None,
#                                                  'term_label': 'pooled'},
#                               'library_name': 'custom',
#                               'library_perturbation_type': [{'term_id': None,
#                                                              'term_label': 'inhibition'}],
#                               'library_scope': {'term_id': None,
#                                                 'term_label': 'focused'},
#                               'manufacturer': 'Weissman',
#                               'total_grnas': '91',
#                               'total_variants': None},
#                   'library_delivery_method': {'term_id': None,
#                                               'term_label': 'lentiviral '
#                                                             'transduction'},
#                   'library_expression_control': {'term_id': None,
#                                                  'term_label': 'constitutive '
#                                                                'expression'},
#                   'library_generation_method': {'term_id': 'EFO:0022895',
#                                                 'term_label': 'dCas9-KRAB'},
#                   'library_generation_type': {'term_id': 'EFO:0022868',
#                                               'term_label': 'endogenous'},
#                   'library_integration_state': {'term_id': None,
#                                                 'term_label': 'random locus '
#                                                               'integration'}},
#  'study': {'first_author': {'first_name': 'Britt', 'last_name': 'Adamson'},
#            'last_author': {'first_name': 'Jonathan', 'last_name': 'Weissman'},
#            'study_uri': 'https://doi.org/10.1016/j.cell.2016.11.048',
#            'title': 'A Multiplexed Single-Cell CRISPR Screening Platform '
#                     'Enables Systematic Dissection of the Unfolded Protein '
#                     'Response',
#            'year': 2016}}
# --------------------------------------------------

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data()
# Out:
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/Perturbseq/curation_notebooks/../../curation_tools/curation_tools.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# Curated data saved to ../curated/h5ad/adamson_2016_upr_perturb_seq_curated.h5ad
