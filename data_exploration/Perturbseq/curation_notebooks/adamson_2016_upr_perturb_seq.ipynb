# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)

# %% [markdown]
# # Download the dataset

# %%
noncurated_path = "../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad"
download_file(
    url="https://zenodo.org/record/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad",
    dest_path=noncurated_path
)
# Out:
# 2026-04-28 11:10:57,386 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): zenodo.org:443
# 2026-04-28 11:10:57,475 DEBUG urllib3.connectionpool: https://zenodo.org:443 "GET /record/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad HTTP/1.1" 301 317
# 2026-04-28 11:10:57,556 DEBUG urllib3.connectionpool: https://zenodo.org:443 "GET /records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad HTTP/1.1" 200 471286951
# Downloaded https://zenodo.org/record/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad to ../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad

# %% [markdown]
# # Initialise the dataset object

# %%
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# 2026-04-28 11:12:14,784 DEBUG h5py._conv: Creating converter from 3 to 5
# Loading data from ../non_curated/h5ad/adamson_2016_upr_perturb_seq.h5ad

# %%
cur_data.show_var()
# Out:
# Variable data:
# DataFrame shape: (32738, 3)
# --------------------------------------------------
#                    ensembl_id  ncounts  ncells
# gene_symbol
# MIR1302-10    ENSG00000243485     11.0      11
# FAM138A       ENSG00000237613      0.0       0
# OR4F5         ENSG00000186092      0.0       0
# RP11-34P13.7  ENSG00000238009      0.0       0
# RP11-34P13.8  ENSG00000239945     43.0      43
# ...                       ...      ...     ...
# AC145205.1    ENSG00000215635      0.0       0
# BAGE5         ENSG00000268590      0.0       0
# CU459201.1    ENSG00000251180      0.0       0
# AC002321.2    ENSG00000215616      0.0       0
# AC002321.1    ENSG00000215611      0.0       0
#
# [32738 rows x 3 columns]
# --------------------------------------------------

# %%
cur_data.adata.obs
# Out:
#                    perturbation  read count  UMI count tissue_type cell_line  \
# cell_barcode
# AAACATACAAGATG   63(mod)_pBA580       282.0        8.0   cell_line      K562
# AAACATACACCTAG      OST4_pDS353       331.0        7.0   cell_line      K562
# AAACATACTTCCCG   SEC61A1_pDS031       285.0       10.0   cell_line      K562
# AAACATTGAAACAG    EIF2B4_pDS491      1036.0       30.0   cell_line      K562
# AAACATTGCAGCTA      SRPR_pDS482       863.0       25.0   cell_line      K562
# ...                         ...         ...        ...         ...       ...
# TTTGCATGCTTTAC     STT3A_pDS011       476.0       17.0   cell_line      K562
# TTTGCATGGAGGAC  ARHGAP22_pDS458       539.0       19.0   cell_line      K562
# TTTGCATGTAGAGA   63(mod)_pBA580       647.0       35.0   cell_line      K562
# TTTGCATGTCAAGC    KCTD16_pDS096        98.0        4.0   cell_line      K562
# TTTGCATGTGGAGG    SAMM50_pDS156       427.0       14.0   cell_line      K562
#
#                 cancer                       disease perturbation_type  \
# cell_barcode
# AAACATACAAGATG    True  chronic myelogenous leukemia            CRISPR
# AAACATACACCTAG    True  chronic myelogenous leukemia            CRISPR
# AAACATACTTCCCG    True  chronic myelogenous leukemia            CRISPR
# AAACATTGAAACAG    True  chronic myelogenous leukemia            CRISPR
# AAACATTGCAGCTA    True  chronic myelogenous leukemia            CRISPR
# ...                ...                           ...               ...
# TTTGCATGCTTTAC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGGAGGAC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTAGAGA    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTCAAGC    True  chronic myelogenous leukemia            CRISPR
# TTTGCATGTGGAGG    True  chronic myelogenous leukemia            CRISPR
#
#                     celltype organism  ncounts  ngenes  percent_mito  \
# cell_barcode
# AAACATACAAGATG  lymphoblasts    human   8866.0    2914      4.917663
# AAACATACACCTAG  lymphoblasts    human  13785.0    3818      4.468626
# AAACATACTTCCCG  lymphoblasts    human   7569.0    2616      5.060113
# AAACATTGAAACAG  lymphoblasts    human  13834.0    3488      5.052769
# AAACATTGCAGCTA  lymphoblasts    human  15507.0    3620      4.514091
# ...                      ...      ...      ...     ...           ...
# TTTGCATGCTTTAC  lymphoblasts    human  14524.0    3356      5.996971
# TTTGCATGGAGGAC  lymphoblasts    human  11685.0    2961      4.612751
# TTTGCATGTAGAGA  lymphoblasts    human  16610.0    3473      7.242625
# TTTGCATGTCAAGC  lymphoblasts    human  14473.0    3431      7.296345
# TTTGCATGTGGAGG  lymphoblasts    human  16843.0    3719      5.919373
#
#                 percent_ribo  nperts
# cell_barcode
# AAACATACAAGATG     21.306112       2
# AAACATACACCTAG     19.492201       2
# AAACATACTTCCCG     23.199894       2
# AAACATTGAAACAG     28.733555       2
# AAACATTGCAGCTA     26.729864       2
# ...                      ...     ...
# TTTGCATGCTTTAC     22.679703       2
# TTTGCATGGAGGAC     26.983313       2
# TTTGCATGTAGAGA     26.207104       2
# TTTGCATGTCAAGC     20.755890       2
# TTTGCATGTGGAGG     20.097370       2
#
# [65337 rows x 15 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Add cell barcodes to the obs slot

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.astype(str)

print(cur_data.adata.obs[['cell_barcode']].head())
# Out:
#                   cell_barcode
# cell_barcode
# AAACATACAAGATG  AAACATACAAGATG
# AAACATACACCTAG  AAACATACACCTAG
# AAACATACTTCCCG  AAACATACTTCCCG
# AAACATTGAAACAG  AAACATTGAAACAG
# AAACATTGCAGCTA  AAACATTGCAGCTA

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot="obs", column="perturbation")
# Out:
# Unique values in adata.obs.perturbation: 115
# --------------------------------------------------
# {nan,
#  '*',
#  '62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# ### Drop NAs

# %%
cur_data.remove_na(slot="obs", column="perturbation")
# Out:
# Removed 2613 NA entries from column perturbation of adata.obs

# %% [markdown]
# ### Drop "*" entries

# %%
cur_data.remove_entries(slot="obs", column="perturbation", to_remove=r"\*")
# Out:
# Removed 101 entries \* from column perturbation of adata.obs

# %%
cur_data.show_unique(slot="obs", column="perturbation")
# Out:
# Unique values in adata.obs.perturbation: 113
# --------------------------------------------------
# {'62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# ### Rename `perturbation` to `perturbation_name`

# %%
cur_data.rename_columns(slot="obs", name_dict={"perturbation": "perturbation_name"})
# Out:
# Renamed columns in adata.obs: {'perturbation': 'perturbation_name'}

# %% [markdown]
# ### Add guide RNA information

# %%
# download the protospacer sequences data from supplementary information Table S1
# https://ars.els-cdn.com/content/image/1-s2.0-S0092867416316609-mmc1.xlsx

guides_df = pd.read_csv("../supplementary/adamson_2016_pilot.csv", header=1)
display(guides_df)

guides_dict_vecid = (
    guides_df[["Perturb-seq_Vector_ID", "Protospacer"]]
    .dropna()
    .set_index("Perturb-seq_Vector_ID", drop=True)["Protospacer"]
    .to_dict()
)

guides_dict_vecid
# Out:
#              Gene           Protospacer Guide_ID (synonymous with sgGuide_ID)  \
# 0            AARS  GAGGGCGGCCTACCTCTCCT                                   NaN
# 1    AMIGO3/GMPPB  GGAACGCGACACCGGGTAGA                                   NaN
# 2    AMIGO3/GMPPB  GGGGCCAGCAGCCGTCTACC                                   NaN
# 3        ARHGAP22  GGTCCGTCCGGAGCCAGGAG                                   NaN
# 4           ASCC3  GACGCAAAGACGCACAGACC                                   NaN
# ..            ...                   ...                                   ...
# 97          YIPF5  GTGACACGTAGCAACGGGGC                                   NaN
# 98            NaN  GGCCAAACGTGCCCTGACGG                             NegCtrl-1
# 99            NaN  GCGATGGGGGGGTGGGTAGC                             NegCtrl-2
# 100           NaN  GACGACTAGTTAGGCGTGTA                             NegCtrl-3
# 101           NaN  GCCTTGGCTAAACCGCTCCC                           NegCtrl-hU6
#
#     Perturb-seq_Vector_ID  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0                  pDS381         NaN         NaN         NaN
# 1                  pDS391         NaN         NaN         NaN
# 2                  pDS434         NaN         NaN         NaN
# 3                  pDS458         NaN         NaN         NaN
# 4                  pDS051         NaN         NaN         NaN
# ..                    ...         ...         ...         ...
# 97                 pDS226         NaN         NaN         NaN
# 98                    NaN         NaN         NaN         NaN
# 99                    NaN         NaN         NaN         NaN
# 100                   NaN         NaN         NaN         NaN
# 101                   NaN         NaN         NaN         NaN
#
# [102 rows x 7 columns]
# {'pDS381': 'GAGGGCGGCCTACCTCTCCT',
#  'pDS391': 'GGAACGCGACACCGGGTAGA',
#  'pDS434': 'GGGGCCAGCAGCCGTCTACC',
#  'pDS458': 'GGTCCGTCCGGAGCCAGGAG',
#  'pDS051': 'GACGCAAAGACGCACAGACC',
#  'pDS052': 'GCGCACAGACCCGGCGAGGA',
#  'pDS055': 'GAGTCTCCGCAAGGCCCCGG',
#  'pDS468': 'GTAGGAGCCTCGGGCGCGCT',
#  'pDS460': 'GAGCCATGGCAGATTCCTCC',
#  'pDS006': 'GCGACGTCCGAGCATTCCA',
#  'pDS024': 'GCGCTGGTGGTCGATCGTG',
#  'pDS065': 'GCGGCTATGAACCGCAGCAG',
#  'pDS462': 'GGATGCTGTGGTGTCCACAG',
#  'pDS499': 'GACCTTGCGTGCAGTTATGT',
#  'pDS495': 'GTGAGACCCCAGGGTCGGGA',
#  'pDS382': 'GTGGGTCCTTCGGCAGGAGG',
#  'pDS041': 'GCGGTCCACAAAGGCTCAGA',
#  'pDS042': 'GGTAGGCGCGGCTGACCGGT',
#  'pDS383': 'GGCGCCCAGCGGAGCTAATC',
#  'pDS026': 'GGGCGCCTGTGCTTGAGGTT',
#  'pDS074': 'GCTTGCCTGGAACTCCTGTA',
#  'pDS463': 'GTAGCTGCCTTCAGCCTTCAC',
#  'pDS508': 'GCCATTGGGCTGTCAGTCAG',
#  'pDS491': 'GCTGAGGGCGATGGCTGCTG',
#  'pDS386': 'GAGACTTGCTTCCCCCTCAC',
#  'pDS390': 'GTCACTGTAGGTGCGGCCCA',
#  'pDS494': 'GGCAGCCTCGGCCCGAGTCC',
#  'pDS043': 'GCAGGGCTCGCGCAGTTACC',
#  'pDS506': 'GCAGGGCCGCGCGCAGGCGAG',
#  'pDS466': 'GCTCAAGTGGACAGCCGGGA',
#  'pDS087': 'GTCATCCTCACCGTCACGGC',
#  'pDS017': 'GCGACGGTGAGGTCGACGC',
#  'pDS371': 'GGCGACGGTGAGGTCGACGC',
#  'pDS088': 'GGGATAAATGGAGGAGTACG',
#  'pDS089': 'GGACAGCGTGCGAGCTCCGG',
#  'pDS090': 'GGCGCGTGCGCCCTCTTACT',
#  'pDS091': 'GCGGAGGACCCCGCTCTCAG',
#  'pDS393': 'GGGGCCCGCGTGGATCTCTA',
#  'pDS002': 'GGGCCGCGTGAGGGGACACCA',
#  'pDS110': 'GGGGCCCCATCGGCTTCCGT',
#  'pDS096': 'GGTTTCTCAGACCTAGGTGA',
#  'pDS027': 'GACTTGGAGGCGGTGCGGCG',
#  'pDS394': 'GCAGCACCGGCAAGCAACCC',
#  'pDS124': 'GCGAGCAAGGAGCCCCCGGC',
#  'pDS498': 'GTCTGGCTGGTCGCACCCGG',
#  'pDS395': 'GGGCCAGTCCCTAAGCACGT',
#  'pDS396': 'GCAGCGGCGACCGGAGCGGT',
#  'pDS353': 'GGCTTGTTCGCTGGTGGCGT',
#  'pDS397': 'GGGCGCCGCCGGGACAGCGG',
#  'pDS029': 'GGGCAACCTAGCAGCTCCTC',
#  'pDS398': 'GTTTTCAGCAGAGACGTAGA',
#  'pDS488': 'GCCGTCCCGGAGACCCGGTC',
#  'pDS478': 'GCTGGCGCCCAGCAAAGGCT',
#  'pDS510': 'GCGCGCTCAGTGAGAGGAAA',
#  'pDS156': 'GCTGCCTCGCAGAGCTGCCC',
#  'pDS467': 'GGGCGCAGTGCGGCGGTCAC',
#  'pDS159': 'GGCCGGAGGACCCGGAGCTA',
#  'pDS160': 'GGCCTTAGCTCCGGGTCCTC',
#  'pDS031': 'GCTGTGCAGTGGAACGCGCT',
#  'pDS032': 'GTGCTAGCCCGGCGGCAAG',
#  'pDS033': 'GTACGGAGCCCCCGAAAGAC',
#  'pDS162': 'GGCGGACGGATAGAAAGTTA',
#  'pDS440': 'GCTCCAGTGCTACGTGTCCC',
#  'pDS218': 'GGTGCAGAGCGTGGTCGTGG',
#  'pDS373': 'GGTGGTGGCTGAGTCCGTGG',
#  'pDS046': 'GGTCGCATGCAGCTCCTATG',
#  'pDS219': 'GCCGGGAAAGGAGAGGATCC',
#  'pDS433': 'GAGATGTCCGGGTAGCGCCA',
#  'pDS479': 'GCGGCGGACCCGGCCCTAGG',
#  'pDS401': 'GTCAGACAAGTCGGAGGGGA',
#  'pDS402': 'GGCCGGTCCGCCGCCGGAAC',
#  'pDS403': 'GAGAAGCAGGTCCCAGGCGG',
#  'pDS505': 'GCCTCCAAGATGGCGAGCGG',
#  'pDS482': 'GGCGAACGCGGCCTGAATTCC',
#  'pDS404': 'GGCCACCCGGCGCGAGTCCG',
#  'pDS011': 'GGGAGCCCCGCGGATCGTTT',
#  'pDS442': 'GGCGCTGGGTTCCTGGTGAGT',
#  'pDS405': 'GGAGGAGCCAAGAGGCGGGT',
#  'pDS496': 'GCCGCGGAGACCCGCCCCAG',
#  'pDS284': 'GAAGTAGGCGCTGGCAACGC',
#  'pDS430': 'GCGGCACCAGCCACTCCGCA',
#  'pDS036': 'GAGACTCGTTCACCACCGA',
#  'pDS175': 'GTGAGGCCGAAGCCAGGACC',
#  'pDS038': 'GCAGCCACATCACCCTTCCG',
#  'pDS407': 'GAAGGCTGGAAGACGAGGTA',
#  'pDS408': 'GTCCGGATCCTGTTAGACAC',
#  'pDS410': 'GTGACTCGCAGTAGACGCGG',
#  'pDS040': 'GCGGTAAGCAAACACTTACA',
#  'pDS411': 'GTCCGCGGAGCGACGACCGG',
#  'pDS186': 'GGGTGCAGGGGACCGCGTCA',
#  'pDS226': 'GTGACACGTAGCAACGGGGC'}

# %%
# extract vector IDs from perturbation_names
cur_data.create_columns(
    slot="obs",
    col_dict={
        "vector_id": cur_data.adata.obs["perturbation_name"].str.split("_").str[1]
    },
)

cur_data.show_unique(slot="obs", column="vector_id")
# Out:
# Column vector_id added to adata.obs
# Unique values in adata.obs.vector_id: 113
# --------------------------------------------------
# {'pBA572',
#  'pBA573',
#  'pBA574',
#  'pBA575',
#  'pBA576',
#  'pBA577',
#  'pBA578',
#  'pBA579',
#  'pBA580',
#  'pBA581',
#  'pBA582',
#  'pBA586',
#  'pBA608',
#  'pDS001',
#  'pDS002',
#  'pDS003',
#  'pDS004',
#  'pDS005',
#  'pDS006',
#  'pDS007',
#  'pDS008',
#  'pDS009',
#  'pDS010',
#  'pDS011',
#  'pDS017',
#  'pDS024',
#  'pDS026',
#  'pDS027',
#  'pDS029',
#  'pDS031',
#  'pDS032',
#  'pDS033',
#  'pDS036',
#  'pDS038',
#  'pDS040',
#  'pDS041',
#  'pDS042',
#  'pDS043',
#  'pDS044',
#  'pDS046',
#  'pDS051',
#  'pDS052',
#  'pDS055',
#  'pDS065',
#  'pDS074',
#  'pDS087',
#  'pDS088',
#  'pDS089',
#  'pDS090',
#  'pDS091',
#  'pDS096',
#  'pDS110',
#  'pDS124',
#  'pDS156',
#  'pDS159',
#  'pDS160',
#  'pDS162',
#  'pDS175',
#  'pDS186',
#  'pDS218',
#  'pDS219',
#  'pDS226',
#  'pDS284',
#  'pDS353',
#  'pDS371',
#  'pDS373',
#  'pDS381',
#  'pDS382',
#  'pDS383',
#  'pDS386',
#  'pDS390',
#  'pDS391',
#  'pDS393',
#  'pDS394',
#  'pDS395',
#  'pDS396',
#  'pDS397',
#  'pDS398',
#  'pDS401',
#  'pDS402',
#  'pDS403',
#  'pDS404',
#  'pDS405',
#  'pDS407',
#  'pDS408',
#  'pDS410',
#  'pDS411',
#  'pDS430',
#  'pDS433',
#  'pDS434',
#  'pDS440',
#  'pDS442',
#  'pDS458',
#  'pDS460',
#  'pDS462',
#  'pDS463',
#  'pDS466',
#  'pDS467',
#  'pDS468',
#  'pDS478',
#  'pDS479',
#  'pDS482',
#  'pDS488',
#  'pDS491',
#  'pDS494',
#  'pDS495',
#  'pDS496',
#  'pDS498',
#  'pDS499',
#  'pDS505',
#  'pDS506',
#  'pDS508',
#  'pDS510'}
# --------------------------------------------------

# %%
cur_data.map_values_from_column(
    ref_col="vector_id", target_col="guide_sequence", map_dict=guides_dict_vecid
)
# Out:
# Column guide_sequence created in adata.obs
# Mapped value pDS381 in column vector_id to GAGGGCGGCCTACCTCTCCT in column guide_sequence of adata.obs
# Mapped value pDS391 in column vector_id to GGAACGCGACACCGGGTAGA in column guide_sequence of adata.obs
# Mapped value pDS434 in column vector_id to GGGGCCAGCAGCCGTCTACC in column guide_sequence of adata.obs
# Mapped value pDS458 in column vector_id to GGTCCGTCCGGAGCCAGGAG in column guide_sequence of adata.obs
# Mapped value pDS051 in column vector_id to GACGCAAAGACGCACAGACC in column guide_sequence of adata.obs
# Mapped value pDS052 in column vector_id to GCGCACAGACCCGGCGAGGA in column guide_sequence of adata.obs
# Mapped value pDS055 in column vector_id to GAGTCTCCGCAAGGCCCCGG in column guide_sequence of adata.obs
# Mapped value pDS468 in column vector_id to GTAGGAGCCTCGGGCGCGCT in column guide_sequence of adata.obs
# Mapped value pDS460 in column vector_id to GAGCCATGGCAGATTCCTCC in column guide_sequence of adata.obs
# Mapped value pDS006 in column vector_id to GCGACGTCCGAGCATTCCA in column guide_sequence of adata.obs
# Mapped value pDS024 in column vector_id to GCGCTGGTGGTCGATCGTG in column guide_sequence of adata.obs
# Mapped value pDS065 in column vector_id to GCGGCTATGAACCGCAGCAG in column guide_sequence of adata.obs
# Mapped value pDS462 in column vector_id to GGATGCTGTGGTGTCCACAG in column guide_sequence of adata.obs
# Mapped value pDS499 in column vector_id to GACCTTGCGTGCAGTTATGT in column guide_sequence of adata.obs
# Mapped value pDS495 in column vector_id to GTGAGACCCCAGGGTCGGGA in column guide_sequence of adata.obs
# Mapped value pDS382 in column vector_id to GTGGGTCCTTCGGCAGGAGG in column guide_sequence of adata.obs
# Mapped value pDS041 in column vector_id to GCGGTCCACAAAGGCTCAGA in column guide_sequence of adata.obs
# Mapped value pDS042 in column vector_id to GGTAGGCGCGGCTGACCGGT in column guide_sequence of adata.obs
# Mapped value pDS383 in column vector_id to GGCGCCCAGCGGAGCTAATC in column guide_sequence of adata.obs
# Mapped value pDS026 in column vector_id to GGGCGCCTGTGCTTGAGGTT in column guide_sequence of adata.obs
# Mapped value pDS074 in column vector_id to GCTTGCCTGGAACTCCTGTA in column guide_sequence of adata.obs
# Mapped value pDS463 in column vector_id to GTAGCTGCCTTCAGCCTTCAC in column guide_sequence of adata.obs
# Mapped value pDS508 in column vector_id to GCCATTGGGCTGTCAGTCAG in column guide_sequence of adata.obs
# Mapped value pDS491 in column vector_id to GCTGAGGGCGATGGCTGCTG in column guide_sequence of adata.obs
# Mapped value pDS386 in column vector_id to GAGACTTGCTTCCCCCTCAC in column guide_sequence of adata.obs
# Mapped value pDS390 in column vector_id to GTCACTGTAGGTGCGGCCCA in column guide_sequence of adata.obs
# Mapped value pDS494 in column vector_id to GGCAGCCTCGGCCCGAGTCC in column guide_sequence of adata.obs
# Mapped value pDS043 in column vector_id to GCAGGGCTCGCGCAGTTACC in column guide_sequence of adata.obs
# Mapped value pDS506 in column vector_id to GCAGGGCCGCGCGCAGGCGAG in column guide_sequence of adata.obs
# Mapped value pDS466 in column vector_id to GCTCAAGTGGACAGCCGGGA in column guide_sequence of adata.obs
# Mapped value pDS087 in column vector_id to GTCATCCTCACCGTCACGGC in column guide_sequence of adata.obs
# Mapped value pDS017 in column vector_id to GCGACGGTGAGGTCGACGC in column guide_sequence of adata.obs
# Mapped value pDS371 in column vector_id to GGCGACGGTGAGGTCGACGC in column guide_sequence of adata.obs
# Mapped value pDS088 in column vector_id to GGGATAAATGGAGGAGTACG in column guide_sequence of adata.obs
# Mapped value pDS089 in column vector_id to GGACAGCGTGCGAGCTCCGG in column guide_sequence of adata.obs
# Mapped value pDS090 in column vector_id to GGCGCGTGCGCCCTCTTACT in column guide_sequence of adata.obs
# Mapped value pDS091 in column vector_id to GCGGAGGACCCCGCTCTCAG in column guide_sequence of adata.obs
# Mapped value pDS393 in column vector_id to GGGGCCCGCGTGGATCTCTA in column guide_sequence of adata.obs
# Mapped value pDS002 in column vector_id to GGGCCGCGTGAGGGGACACCA in column guide_sequence of adata.obs
# Mapped value pDS110 in column vector_id to GGGGCCCCATCGGCTTCCGT in column guide_sequence of adata.obs
# Mapped value pDS096 in column vector_id to GGTTTCTCAGACCTAGGTGA in column guide_sequence of adata.obs
# Mapped value pDS027 in column vector_id to GACTTGGAGGCGGTGCGGCG in column guide_sequence of adata.obs
# Mapped value pDS394 in column vector_id to GCAGCACCGGCAAGCAACCC in column guide_sequence of adata.obs
# Mapped value pDS124 in column vector_id to GCGAGCAAGGAGCCCCCGGC in column guide_sequence of adata.obs
# Mapped value pDS498 in column vector_id to GTCTGGCTGGTCGCACCCGG in column guide_sequence of adata.obs
# Mapped value pDS395 in column vector_id to GGGCCAGTCCCTAAGCACGT in column guide_sequence of adata.obs
# Mapped value pDS396 in column vector_id to GCAGCGGCGACCGGAGCGGT in column guide_sequence of adata.obs
# Mapped value pDS353 in column vector_id to GGCTTGTTCGCTGGTGGCGT in column guide_sequence of adata.obs
# Mapped value pDS397 in column vector_id to GGGCGCCGCCGGGACAGCGG in column guide_sequence of adata.obs
# Mapped value pDS029 in column vector_id to GGGCAACCTAGCAGCTCCTC in column guide_sequence of adata.obs
# Mapped value pDS398 in column vector_id to GTTTTCAGCAGAGACGTAGA in column guide_sequence of adata.obs
# Mapped value pDS488 in column vector_id to GCCGTCCCGGAGACCCGGTC in column guide_sequence of adata.obs
# Mapped value pDS478 in column vector_id to GCTGGCGCCCAGCAAAGGCT in column guide_sequence of adata.obs
# Mapped value pDS510 in column vector_id to GCGCGCTCAGTGAGAGGAAA in column guide_sequence of adata.obs
# Mapped value pDS156 in column vector_id to GCTGCCTCGCAGAGCTGCCC in column guide_sequence of adata.obs
# Mapped value pDS467 in column vector_id to GGGCGCAGTGCGGCGGTCAC in column guide_sequence of adata.obs
# Mapped value pDS159 in column vector_id to GGCCGGAGGACCCGGAGCTA in column guide_sequence of adata.obs
# Mapped value pDS160 in column vector_id to GGCCTTAGCTCCGGGTCCTC in column guide_sequence of adata.obs
# Mapped value pDS031 in column vector_id to GCTGTGCAGTGGAACGCGCT in column guide_sequence of adata.obs
# Mapped value pDS032 in column vector_id to GTGCTAGCCCGGCGGCAAG in column guide_sequence of adata.obs
# Mapped value pDS033 in column vector_id to GTACGGAGCCCCCGAAAGAC in column guide_sequence of adata.obs
# Mapped value pDS162 in column vector_id to GGCGGACGGATAGAAAGTTA in column guide_sequence of adata.obs
# Mapped value pDS440 in column vector_id to GCTCCAGTGCTACGTGTCCC in column guide_sequence of adata.obs
# Mapped value pDS218 in column vector_id to GGTGCAGAGCGTGGTCGTGG in column guide_sequence of adata.obs
# Mapped value pDS373 in column vector_id to GGTGGTGGCTGAGTCCGTGG in column guide_sequence of adata.obs
# Mapped value pDS046 in column vector_id to GGTCGCATGCAGCTCCTATG in column guide_sequence of adata.obs
# Mapped value pDS219 in column vector_id to GCCGGGAAAGGAGAGGATCC in column guide_sequence of adata.obs
# Mapped value pDS433 in column vector_id to GAGATGTCCGGGTAGCGCCA in column guide_sequence of adata.obs
# Mapped value pDS479 in column vector_id to GCGGCGGACCCGGCCCTAGG in column guide_sequence of adata.obs
# Mapped value pDS401 in column vector_id to GTCAGACAAGTCGGAGGGGA in column guide_sequence of adata.obs
# Mapped value pDS402 in column vector_id to GGCCGGTCCGCCGCCGGAAC in column guide_sequence of adata.obs
# Mapped value pDS403 in column vector_id to GAGAAGCAGGTCCCAGGCGG in column guide_sequence of adata.obs
# Mapped value pDS505 in column vector_id to GCCTCCAAGATGGCGAGCGG in column guide_sequence of adata.obs
# Mapped value pDS482 in column vector_id to GGCGAACGCGGCCTGAATTCC in column guide_sequence of adata.obs
# Mapped value pDS404 in column vector_id to GGCCACCCGGCGCGAGTCCG in column guide_sequence of adata.obs
# Mapped value pDS011 in column vector_id to GGGAGCCCCGCGGATCGTTT in column guide_sequence of adata.obs
# Mapped value pDS442 in column vector_id to GGCGCTGGGTTCCTGGTGAGT in column guide_sequence of adata.obs
# Mapped value pDS405 in column vector_id to GGAGGAGCCAAGAGGCGGGT in column guide_sequence of adata.obs
# Mapped value pDS496 in column vector_id to GCCGCGGAGACCCGCCCCAG in column guide_sequence of adata.obs
# Mapped value pDS284 in column vector_id to GAAGTAGGCGCTGGCAACGC in column guide_sequence of adata.obs
# Mapped value pDS430 in column vector_id to GCGGCACCAGCCACTCCGCA in column guide_sequence of adata.obs
# Mapped value pDS036 in column vector_id to GAGACTCGTTCACCACCGA in column guide_sequence of adata.obs
# Mapped value pDS175 in column vector_id to GTGAGGCCGAAGCCAGGACC in column guide_sequence of adata.obs
# Mapped value pDS038 in column vector_id to GCAGCCACATCACCCTTCCG in column guide_sequence of adata.obs
# Mapped value pDS407 in column vector_id to GAAGGCTGGAAGACGAGGTA in column guide_sequence of adata.obs
# Mapped value pDS408 in column vector_id to GTCCGGATCCTGTTAGACAC in column guide_sequence of adata.obs
# Mapped value pDS410 in column vector_id to GTGACTCGCAGTAGACGCGG in column guide_sequence of adata.obs
# Mapped value pDS040 in column vector_id to GCGGTAAGCAAACACTTACA in column guide_sequence of adata.obs
# Mapped value pDS411 in column vector_id to GTCCGCGGAGCGACGACCGG in column guide_sequence of adata.obs
# Mapped value pDS186 in column vector_id to GGGTGCAGGGGACCGCGTCA in column guide_sequence of adata.obs
# Mapped value pDS226 in column vector_id to GTGACACGTAGCAACGGGGC in column guide_sequence of adata.obs

# %%
cur_data.adata.obs[['perturbation_name', 'guide_sequence']]
# Out:
#                perturbation_name         guide_sequence
# cell_barcode
# AAACATACAAGATG    63(mod)_pBA580                    nan
# AAACATACACCTAG       OST4_pDS353   GGCTTGTTCGCTGGTGGCGT
# AAACATACTTCCCG    SEC61A1_pDS031   GCTGTGCAGTGGAACGCGCT
# AAACATTGAAACAG     EIF2B4_pDS491   GCTGAGGGCGATGGCTGCTG
# AAACATTGCAGCTA       SRPR_pDS482  GGCGAACGCGGCCTGAATTCC
# ...                          ...                    ...
# TTTGCATGCTTTAC      STT3A_pDS011   GGGAGCCCCGCGGATCGTTT
# TTTGCATGGAGGAC   ARHGAP22_pDS458   GGTCCGTCCGGAGCCAGGAG
# TTTGCATGTAGAGA    63(mod)_pBA580                    nan
# TTTGCATGTCAAGC     KCTD16_pDS096   GGTTTCTCAGACCTAGGTGA
# TTTGCATGTGGAGG     SAMM50_pDS156   GCTGCCTCGCAGAGCTGCCC
#
# [62623 rows x 2 columns]

# %% [markdown]
# ### Extract perturbation symbols

# %% [markdown]
# #### Add `perturbation_target_symbol` column based on the `perturbation_name`

# %%
cur_data.create_columns(
    slot="obs", col_dict={"perturbed_target_symbol_input": cur_data.adata.obs["perturbation_name"]},
    overwrite=True
)
cur_data.show_unique(slot = 'obs', column = 'perturbed_target_symbol_input')
# Out:
# Column perturbed_target_symbol_input added to adata.obs
# Unique values in adata.obs.perturbed_target_symbol_input: 113
# --------------------------------------------------
# {'62(mod)_pBA581',
#  '63(mod)_pBA580',
#  'AARS_pDS381',
#  'AMIGO3_pDS434',
#  'ARHGAP22_pDS458',
#  'ASCC3_pDS051',
#  'ASCC3_pDS052',
#  'ATF4_pBA576',
#  'ATF4_pBA577',
#  'ATF4_pBA608',
#  'ATF6_pBA586',
#  'ATP5B_pDS055',
#  'C7orf26_pDS004',
#  'CAD_pDS468',
#  'CARS_pDS460',
#  'CCND3_pDS005',
#  'CCND3_pDS006',
#  'CHERP_pDS024',
#  'COPB1_pDS065',
#  'COPZ1_pDS462',
#  'DAD1_pDS499',
#  'DARS_pDS495',
#  'DDOST_pDS382',
#  'DDRGK1_pDS041',
#  'DERL2_pDS042',
#  'DHDDS_pDS383',
#  'DNAJC19_pDS026',
#  'DNAJC19_pDS074',
#  'EIF2AK3_pBA572',
#  'EIF2AK3_pBA573',
#  'EIF2B2_pDS463',
#  'EIF2B3_pDS508',
#  'EIF2B4_pDS491',
#  'EIF2S1_pDS386',
#  'ERN1_pBA574',
#  'ERN1_pBA575',
#  'FARSB_pDS390',
#  'FECH_pDS494',
#  'GBF1_pDS043',
#  'GBF1_pDS044',
#  'GMPPB_pDS391',
#  'GNPNAT1_pDS506',
#  'Gal4-4(mod)_pBA582',
#  'HARS_pDS466',
#  'HSD17B12_pDS087',
#  'HSPA5_pDS017',
#  'HSPA5_pDS371',
#  'HSPA9_pDS088',
#  'HYOU1_pDS089',
#  'IARS2_pDS090',
#  'IARS2_pDS091',
#  'IDH3A_pDS393',
#  'IER3IP1_pDS002',
#  'IER3IP1_pDS003',
#  'IER3IP1_pDS110',
#  'KCTD16_pDS096',
#  'MANF_pDS027',
#  'MARS_pDS394',
#  'MRGBP_pDS124',
#  'MRPL39_pDS498',
#  'MTHFD1_pDS395',
#  'NEDD8_pDS396',
#  'OST4_pDS353',
#  'P4HB_pDS397',
#  'PDIA6_pDS029',
#  'PPWD1_pDS398',
#  'PSMA1_pDS007',
#  'PSMD12_pDS008',
#  'PSMD12_pDS009',
#  'PSMD4_pDS488',
#  'PTDSS1_pDS478',
#  'QARS_pDS510',
#  'SAMM50_pDS156',
#  'SARS_pDS467',
#  'SCYL1_pDS159',
#  'SCYL1_pDS160',
#  'SEC61A1_pDS031',
#  'SEC61A1_pDS032',
#  'SEC61B_pDS033',
#  'SEC61B_pDS162',
#  'SEC61G_pDS440',
#  'SEC63_pDS218',
#  'SEL1L_pDS373',
#  'SLC35B1_pDS046',
#  'SLC39A7_pDS219',
#  'SLMO2_pDS433',
#  'SOCS1_pDS479',
#  'SPCS2_pDS401',
#  'SPCS3_pDS402',
#  'SRP68_pDS403',
#  'SRP72_pDS505',
#  'SRPRB_pDS404',
#  'SRPR_pDS482',
#  'STT3A_pDS010',
#  'STT3A_pDS011',
#  'SYVN1_pDS442',
#  'TARS_pDS405',
#  'TELO2_pDS496',
#  'TIMM23_pDS284',
#  'TIMM44_pDS430',
#  'TMED10_pDS036',
#  'TMED2_pDS175',
#  'TMEM167A_pDS038',
#  'TTI1_pDS407',
#  'TTI2_pDS408',
#  'UFL1_pDS410',
#  'UFM1_pDS040',
#  'XBP1_pBA578',
#  'XBP1_pBA579',
#  'XRN1_pDS411',
#  'YIPF5_pDS001',
#  'YIPF5_pDS186',
#  'YIPF5_pDS226'}
# --------------------------------------------------

# %% [markdown]
# #### Clean up `perturbation_target_symbol` column

# %%
cur_data.replace_entries(
    slot="obs",
    column="perturbed_target_symbol_input",
    map_dict={
        r"62\(mod\).*": "control_nontargeting",
        r"63\(mod\).*": "control_nontargeting",
        r"Gal4-4.*": "control_nontargeting",
        r"_(pD|pB).*": "",
    }
)

cur_data.replace_entries(
    slot="obs",
    column="perturbed_target_symbol_input",
    map_dict={
        "CONTROL_NONTARGETING": "control_nontargeting"
    }
)

cur_data.show_unique(slot="obs", column="perturbed_target_symbol_input")
# Out:
# Replaced '62\(mod\).*' with 'control_nontargeting' in column perturbed_target_symbol_input of adata.obs
# Replaced '63\(mod\).*' with 'control_nontargeting' in column perturbed_target_symbol_input of adata.obs
# Replaced 'Gal4-4.*' with 'control_nontargeting' in column perturbed_target_symbol_input of adata.obs
# Replaced '_(pD|pB).*' with '' in column perturbed_target_symbol_input of adata.obs
# Replaced 'CONTROL_NONTARGETING' with 'control_nontargeting' in column perturbed_target_symbol_input of adata.obs
# Unique values in adata.obs.perturbed_target_symbol_input: 91
# --------------------------------------------------
# {'AARS',
#  'AMIGO3',
#  'ARHGAP22',
#  'ASCC3',
#  'ATF4',
#  'ATF6',
#  'ATP5B',
#  'C7ORF26',
#  'CAD',
#  'CARS',
#  'CCND3',
#  'CHERP',
#  'COPB1',
#  'COPZ1',
#  'DAD1',
#  'DARS',
#  'DDOST',
#  'DDRGK1',
#  'DERL2',
#  'DHDDS',
#  'DNAJC19',
#  'EIF2AK3',
#  'EIF2B2',
#  'EIF2B3',
#  'EIF2B4',
#  'EIF2S1',
#  'ERN1',
#  'FARSB',
#  'FECH',
#  'GBF1',
#  'GMPPB',
#  'GNPNAT1',
#  'HARS',
#  'HSD17B12',
#  'HSPA5',
#  'HSPA9',
#  'HYOU1',
#  'IARS2',
#  'IDH3A',
#  'IER3IP1',
#  'KCTD16',
#  'MANF',
#  'MARS',
#  'MRGBP',
#  'MRPL39',
#  'MTHFD1',
#  'NEDD8',
#  'OST4',
#  'P4HB',
#  'PDIA6',
#  'PPWD1',
#  'PSMA1',
#  'PSMD12',
#  'PSMD4',
#  'PTDSS1',
#  'QARS',
#  'SAMM50',
#  'SARS',
#  'SCYL1',
#  'SEC61A1',
#  'SEC61B',
#  'SEC61G',
#  'SEC63',
#  'SEL1L',
#  'SLC35B1',
#  'SLC39A7',
#  'SLMO2',
#  'SOCS1',
#  'SPCS2',
#  'SPCS3',
#  'SRP68',
#  'SRP72',
#  'SRPR',
#  'SRPRB',
#  'STT3A',
#  'SYVN1',
#  'TARS',
#  'TELO2',
#  'TIMM23',
#  'TIMM44',
#  'TMED10',
#  'TMED2',
#  'TMEM167A',
#  'TTI1',
#  'TTI2',
#  'UFL1',
#  'UFM1',
#  'XBP1',
#  'XRN1',
#  'YIPF5',
#  'control_nontargeting'}
# --------------------------------------------------
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:609: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   if df[column].str.upper().str.contains(old_val.upper()).any():

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_target_symbol_input',
    input_column_type='gene_symbol',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Mapping gene symbols: 100%|███████████████████████████████████████| 91/91 [00:00<00:00, 4549.41it/s]
# --------------------------------------------------
# Successfully mapped 91 out of 91 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: []
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
cur_data.count_entries(
    slot="obs",
    input_column="perturbed_target_symbol",
    count_column_name="perturbed_target_number",
    sep="|",
)
# Out:
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.show_obs(['perturbation_name', 'perturbed_target_chromosome_encoding'])
# Out:
# Observation data:
# DataFrame shape: (62623, 2)
# --------------------------------------------------
#       perturbation_name  perturbed_target_chromosome_encoding
# index
# 0        63(mod)_pBA580                                     0
# 1           OST4_pDS353                                     2
# 2        SEC61A1_pDS031                                     3
# 3         EIF2B4_pDS491                                     2
# 4           SRPR_pDS482                                    11
# ...                 ...                                   ...
# 62618      STT3A_pDS011                                    11
# 62619   ARHGAP22_pDS458                                    10
# 62620    63(mod)_pBA580                                     0
# 62621     KCTD16_pDS096                                     5
# 62622     SAMM50_pDS156                                    22
#
# [62623 rows x 2 columns]
# --------------------------------------------------

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # treatment
        "treatment_label": None, 
        "treatment_id": None,
        # perturbation type
        "perturbation_type_label": "CRISPRi", 
        "perturbation_type_id": None,
        "data_modality": "CRISPR screen",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,
        # model system
        "model_system_label": "cell_line",
        "model_system_id": None,
        # replicates
        "technical_replicate": None,
        "biological_replicate": None,
        
        'tissue': 'blood',
        "timepoint": "P0DT0H0M0S",
        
        "species": "Homo sapiens",
        "sex_label": "female", 
        "sex_id": None,
        "developmental_stage_label": "adult", 
        "developmental_stage_id": None,

        "study_title": "A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response",
        "study_uri": "https://doi.org/10.1016/j.cell.2016.11.048",
        "study_year": 2016,
        "first_author": "Britt Adamson",
        "last_author": "Jonathan Weissman",
        
        "experiment_title": "63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.",
        "experiment_summary": "Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.",
        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_coord'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],
        
        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": "EFO:0022895",
        "library_generation_method_label": "dCas9-KRAB",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "retrovirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",
        
        "library_manufacturer": "Weissman",
        "library_lentiviral_generation": "3",
        "library_grnas_per_target": "1",
        "library_total_grnas": "91",
        "library_total_variants": None,
        
        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "10x Genomics Single Cell 3-prime",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Illumina HiSeq 4000",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "MAGeCK",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh37",
        
        "license_label": "CC BY 4.0",
        "license_id": "SWO:1000065",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "GSM2406677",
                "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681",
                "dataset_description": "Barcode, cell identities, raw gene expression matrix",
                "dataset_file_name": "GSM2406677_10X010",
            },
            {
                "dataset_accession": "GSM2406677_10X005",
                "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad",
                "dataset_description": "Processed .h5ad file",
                "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Column tissue added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#       tissue_type  percent_ribo  read count cell_line perturbation_type  \
# index
# 0       cell_line     21.306112       282.0      K562            CRISPR
# 1       cell_line     19.492201       331.0      K562            CRISPR
# 2       cell_line     23.199894       285.0      K562            CRISPR
# 3       cell_line     28.733555      1036.0      K562            CRISPR
# 4       cell_line     26.729864       863.0      K562            CRISPR
# ...           ...           ...         ...       ...               ...
# 62618   cell_line     22.679703       476.0      K562            CRISPR
# 62619   cell_line     26.983313       539.0      K562            CRISPR
# 62620   cell_line     26.207104       647.0      K562            CRISPR
# 62621   cell_line     20.755890        98.0      K562            CRISPR
# 62622   cell_line     20.097370       427.0      K562            CRISPR
#
#       vector_id  nperts      celltype                       disease  \
# index
# 0        pBA580       2  lymphoblasts  chronic myelogenous leukemia
# 1        pDS353       2  lymphoblasts  chronic myelogenous leukemia
# 2        pDS031       2  lymphoblasts  chronic myelogenous leukemia
# 3        pDS491       2  lymphoblasts  chronic myelogenous leukemia
# 4        pDS482       2  lymphoblasts  chronic myelogenous leukemia
# ...         ...     ...           ...                           ...
# 62618    pDS011       2  lymphoblasts  chronic myelogenous leukemia
# 62619    pDS458       2  lymphoblasts  chronic myelogenous leukemia
# 62620    pBA580       2  lymphoblasts  chronic myelogenous leukemia
# 62621    pDS096       2  lymphoblasts  chronic myelogenous leukemia
# 62622    pDS156       2  lymphoblasts  chronic myelogenous leukemia
#
#       perturbed_target_symbol_input  ...  sequencing_strategy_label  \
# index                                ...
# 0              control_nontargeting  ...         barcode sequencing
# 1                              OST4  ...         barcode sequencing
# 2                           SEC61A1  ...         barcode sequencing
# 3                            EIF2B4  ...         barcode sequencing
# 4                              SRPR  ...         barcode sequencing
# ...                             ...  ...                        ...
# 62618                         STT3A  ...         barcode sequencing
# 62619                      ARHGAP22  ...         barcode sequencing
# 62620          control_nontargeting  ...         barcode sequencing
# 62621                        KCTD16  ...         barcode sequencing
# 62622                        SAMM50  ...         barcode sequencing
#
#        software_counts_id software_counts_label  software_analysis_id  \
# index
# 0                    None            CellRanger                  None
# 1                    None            CellRanger                  None
# 2                    None            CellRanger                  None
# 3                    None            CellRanger                  None
# 4                    None            CellRanger                  None
# ...                   ...                   ...                   ...
# 62618                None            CellRanger                  None
# 62619                None            CellRanger                  None
# 62620                None            CellRanger                  None
# 62621                None            CellRanger                  None
# 62622                None            CellRanger                  None
#
#        software_analysis_label reference_genome_id reference_genome_label  \
# index
# 0                       MAGeCK                None                 GRCh37
# 1                       MAGeCK                None                 GRCh37
# 2                       MAGeCK                None                 GRCh37
# 3                       MAGeCK                None                 GRCh37
# 4                       MAGeCK                None                 GRCh37
# ...                        ...                 ...                    ...
# 62618                   MAGeCK                None                 GRCh37
# 62619                   MAGeCK                None                 GRCh37
# 62620                   MAGeCK                None                 GRCh37
# 62621                   MAGeCK                None                 GRCh37
# 62622                   MAGeCK                None                 GRCh37
#
#        license_label   license_id  \
# index
# 0          CC BY 4.0  SWO:1000065
# 1          CC BY 4.0  SWO:1000065
# 2          CC BY 4.0  SWO:1000065
# 3          CC BY 4.0  SWO:1000065
# 4          CC BY 4.0  SWO:1000065
# ...              ...          ...
# 62618      CC BY 4.0  SWO:1000065
# 62619      CC BY 4.0  SWO:1000065
# 62620      CC BY 4.0  SWO:1000065
# 62621      CC BY 4.0  SWO:1000065
# 62622      CC BY 4.0  SWO:1000065
#
#                                      associated_datasets
# index
# 0      [{"dataset_accession": "GSM2406677", "dataset_...
# 1      [{"dataset_accession": "GSM2406677", "dataset_...
# 2      [{"dataset_accession": "GSM2406677", "dataset_...
# 3      [{"dataset_accession": "GSM2406677", "dataset_...
# 4      [{"dataset_accession": "GSM2406677", "dataset_...
# ...                                                  ...
# 62618  [{"dataset_accession": "GSM2406677", "dataset_...
# 62619  [{"dataset_accession": "GSM2406677", "dataset_...
# 62620  [{"dataset_accession": "GSM2406677", "dataset_...
# 62621  [{"dataset_accession": "GSM2406677", "dataset_...
# 62622  [{"dataset_accession": "GSM2406677", "dataset_...
#
# [62623 rows x 110 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower name_lower     ontology_id
# 0        blood              blood      blood  UBERON:0000178
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='celltype',
    column_type='term_name',
    ontology_type='cell_type'
)
# Out:
# Mapped 1 cell_type ontology terms from `celltype` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#    input_column input_column_lower    name_lower ontology_id
# 0  lymphoblasts       lymphoblasts  lymphoblasts  CL:0017005
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell line information

# %%
cur_data.standardize_ontology(
    input_column='cell_line',
    column_type='term_name',
    ontology_type='cell_line'
)
# Out:
# Mapped 1 cell_line ontology terms from `cell_line` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower name_lower  ontology_id
# 0         K562               k562       k562  CLO:0007050
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease',
    column_type='term_name',
    ontology_type='disease'
)
# Out:
# Mapped 1 disease ontology terms from `disease` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                    input_column            input_column_lower  \
# 0  chronic myelogenous leukemia  chronic myelogenous leukemia
#
#                      name_lower    ontology_id
# 0  chronic myelogenous leukemia  MONDO:0011996
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs')
# Out:
# 2026-04-28 11:17:35,517 DEBUG curation_tools.curation_tools: Applying dtype casting on adata.obs for columns: ['dataset_id', 'sample_id', 'cell_barcode', 'data_modality', 'significant', 'significance_criteria', 'perturbation_name', 'perturbed_target_coord', 'perturbed_target_chromosome', 'perturbed_target_chromosome_encoding', 'perturbed_target_number', 'perturbed_target_ensg', 'perturbed_target_symbol', 'perturbed_target_biotype', 'guide_sequence', 'perturbation_type_label', 'perturbation_type_id', 'timepoint', 'treatment_label', 'treatment_id', 'technical_replicate', 'biological_replicate', 'model_system_label', 'model_system_id', 'species', 'tissue_label', 'tissue_id', 'cell_type_label', 'cell_type_id', 'cell_line_label', 'cell_line_id', 'sex_label', 'sex_id', 'developmental_stage_label', 'developmental_stage_id', 'disease_label', 'disease_id', 'study_title', 'study_uri', 'study_year', 'first_author', 'last_author', 'experiment_title', 'experiment_summary', 'number_of_perturbed_targets', 'number_of_perturbed_samples', 'library_generation_type_id', 'library_generation_type_label', 'library_generation_method_id', 'library_generation_method_label', 'enzyme_delivery_method_id', 'enzyme_delivery_method_label', 'library_delivery_method_id', 'library_delivery_method_label', 'enzyme_integration_state_id', 'enzyme_integration_state_label', 'library_integration_state_id', 'library_integration_state_label', 'enzyme_expression_control_id', 'enzyme_expression_control_label', 'library_expression_control_id', 'library_expression_control_label', 'library_name', 'library_uri', 'library_format_id', 'library_format_label', 'library_scope_id', 'library_scope_label', 'library_perturbation_type_id', 'library_perturbation_type_label', 'library_manufacturer', 'library_lentiviral_generation', 'library_grnas_per_target', 'library_total_grnas', 'library_total_variants', 'readout_dimensionality_id', 'readout_dimensionality_label', 'readout_type_id', 'readout_type_label', 'readout_technology_id', 'readout_technology_label', 'method_name_id', 'method_name_label', 'method_uri', 'sequencing_library_kit_id', 'sequencing_library_kit_label', 'sequencing_platform_id', 'sequencing_platform_label', 'sequencing_strategy_id', 'sequencing_strategy_label', 'software_counts_id', 'software_counts_label', 'software_analysis_id', 'software_analysis_label', 'score_interpretation', 'reference_genome_id', 'reference_genome_label', 'associated_datasets', 'license_label', 'license_id']
# 2026-04-28 11:17:37,337 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
# 2026-04-28 11:17:37,355 DEBUG curation_tools.curation_tools: Validated adata.obs preview (shape=(62623, 100)):
#                      dataset_id sample_id    cell_barcode  data_modality significant significance_criteria perturbation_name        perturbed_target_coord perturbed_target_chromosome  perturbed_target_chromosome_encoding  perturbed_target_number perturbed_target_ensg perturbed_target_symbol perturbed_target_biotype         guide_sequence perturbation_type_label perturbation_type_id   timepoint treatment_label treatment_id technical_replicate biological_replicate model_system_label model_system_id       species tissue_label       tissue_id cell_type_label cell_type_id cell_line_label cell_line_id sex_label sex_id developmental_stage_label developmental_stage_id                                    disease_label     disease_id                                                                                                         study_title                                   study_uri  study_year   first_author        last_author                                                                                 experiment_title                                                                                  experiment_summary number_of_perturbed_targets number_of_perturbed_samples library_generation_type_id library_generation_type_label library_generation_method_id library_generation_method_label enzyme_delivery_method_id enzyme_delivery_method_label library_delivery_method_id library_delivery_method_label enzyme_integration_state_id enzyme_integration_state_label library_integration_state_id library_integration_state_label enzyme_expression_control_id    enzyme_expression_control_label library_expression_control_id   library_expression_control_label library_name library_uri library_format_id library_format_label library_scope_id library_scope_label library_perturbation_type_id library_perturbation_type_label library_manufacturer library_lentiviral_generation library_grnas_per_target library_total_grnas  library_total_variants readout_dimensionality_id readout_dimensionality_label readout_type_id readout_type_label readout_technology_id readout_technology_label method_name_id method_name_label method_uri sequencing_library_kit_id      sequencing_library_kit_label sequencing_platform_id sequencing_platform_label sequencing_strategy_id sequencing_strategy_label software_counts_id software_counts_label software_analysis_id software_analysis_label score_interpretation reference_genome_id reference_genome_label                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 associated_datasets license_label   license_id
# 0  adamson_2016_upr_perturb_seq         1  AAACATACAAGATG  CRISPR screen        <NA>                  <NA>    63(mod)_pBA580          control_nontargeting        control_nontargeting                                     0                        1  control_nontargeting    control_nontargeting     control_nontargeting                    nan                 CRISPRi                 <NA>  P0DT0H0M0S            <NA>         <NA>                <NA>                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response  https://doi.org/10.1016/j.cell.2016.11.048        2016  Britt Adamson  Jonathan Weissman  63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.  Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.                          91                       62623                EFO:0022868                    endogenous                  EFO:0022895                      dCas9-KRAB                      <NA>      retrovirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition             Weissman                             3                        1                  91                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime                   <NA>       Illumina HiSeq 4000                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  MAGeCK                 <NA>                <NA>                 GRCh37  [{"dataset_accession": "GSM2406677", "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681", "dataset_description": "Barcode, cell identities, raw gene expression matrix", "dataset_file_name": "GSM2406677_10X010"}, {"dataset_accession": "GSM2406677_10X005", "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad", "dataset_description": "Processed .h5ad file", "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad"}]     CC BY 4.0  SWO:1000065
# 1  adamson_2016_upr_perturb_seq         2  AAACATACACCTAG  CRISPR screen        <NA>                  <NA>       OST4_pDS353     chr2:27070470-27071685;-1                           2                                     2                        1       ENSG00000228474                    OST4           protein_coding   GGCTTGTTCGCTGGTGGCGT                 CRISPRi                 <NA>  P0DT0H0M0S            <NA>         <NA>                <NA>                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response  https://doi.org/10.1016/j.cell.2016.11.048        2016  Britt Adamson  Jonathan Weissman  63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.  Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.                          91                       62623                EFO:0022868                    endogenous                  EFO:0022895                      dCas9-KRAB                      <NA>      retrovirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition             Weissman                             3                        1                  91                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime                   <NA>       Illumina HiSeq 4000                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  MAGeCK                 <NA>                <NA>                 GRCh37  [{"dataset_accession": "GSM2406677", "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681", "dataset_description": "Barcode, cell identities, raw gene expression matrix", "dataset_file_name": "GSM2406677_10X010"}, {"dataset_accession": "GSM2406677_10X005", "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad", "dataset_description": "Processed .h5ad file", "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad"}]     CC BY 4.0  SWO:1000065
# 2  adamson_2016_upr_perturb_seq         3  AAACATACTTCCCG  CRISPR screen        <NA>                  <NA>    SEC61A1_pDS031    chr3:128051641-128071705;1                           3                                     3                        1       ENSG00000058262                 SEC61A1           protein_coding   GCTGTGCAGTGGAACGCGCT                 CRISPRi                 <NA>  P0DT0H0M0S            <NA>         <NA>                <NA>                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response  https://doi.org/10.1016/j.cell.2016.11.048        2016  Britt Adamson  Jonathan Weissman  63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.  Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.                          91                       62623                EFO:0022868                    endogenous                  EFO:0022895                      dCas9-KRAB                      <NA>      retrovirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition             Weissman                             3                        1                  91                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime                   <NA>       Illumina HiSeq 4000                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  MAGeCK                 <NA>                <NA>                 GRCh37  [{"dataset_accession": "GSM2406677", "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681", "dataset_description": "Barcode, cell identities, raw gene expression matrix", "dataset_file_name": "GSM2406677_10X010"}, {"dataset_accession": "GSM2406677_10X005", "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad", "dataset_description": "Processed .h5ad file", "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad"}]     CC BY 4.0  SWO:1000065
# 3  adamson_2016_upr_perturb_seq         4  AAACATTGAAACAG  CRISPR screen        <NA>                  <NA>     EIF2B4_pDS491     chr2:27363420-27370400;-1                           2                                     2                        1       ENSG00000115211                  EIF2B4           protein_coding   GCTGAGGGCGATGGCTGCTG                 CRISPRi                 <NA>  P0DT0H0M0S            <NA>         <NA>                <NA>                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response  https://doi.org/10.1016/j.cell.2016.11.048        2016  Britt Adamson  Jonathan Weissman  63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.  Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.                          91                       62623                EFO:0022868                    endogenous                  EFO:0022895                      dCas9-KRAB                      <NA>      retrovirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition             Weissman                             3                        1                  91                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime                   <NA>       Illumina HiSeq 4000                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  MAGeCK                 <NA>                <NA>                 GRCh37  [{"dataset_accession": "GSM2406677", "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681", "dataset_description": "Barcode, cell identities, raw gene expression matrix", "dataset_file_name": "GSM2406677_10X010"}, {"dataset_accession": "GSM2406677_10X005", "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad", "dataset_description": "Processed .h5ad file", "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad"}]     CC BY 4.0  SWO:1000065
# 4  adamson_2016_upr_perturb_seq         5  AAACATTGCAGCTA  CRISPR screen        <NA>                  <NA>       SRPR_pDS482  chr11:126262912-126269144;-1                          11                                    11                        1       ENSG00000182934                   SRPRA           protein_coding  GGCGAACGCGGCCTGAATTCC                 CRISPRi                 <NA>  P0DT0H0M0S            <NA>         <NA>                <NA>                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  A Multiplexed Single-Cell CRISPR Screening Platform Enables Systematic Dissection of the Unfolded Protein Response  https://doi.org/10.1016/j.cell.2016.11.048        2016  Britt Adamson  Jonathan Weissman  63000 chronic myeloid leukemia (K562) cells transfected with a UPR sensor gene-targeting gRNAs.  Perturb-seq was applied to a small CRISPRi library of 91 sgRNAs targeting UPR genes in K562 cells.                          91                       62623                EFO:0022868                    endogenous                  EFO:0022895                      dCas9-KRAB                      <NA>      retrovirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition             Weissman                             3                        1                  91                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime                   <NA>       Illumina HiSeq 4000                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  MAGeCK                 <NA>                <NA>                 GRCh37  [{"dataset_accession": "GSM2406677", "dataset_uri": "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2406681", "dataset_description": "Barcode, cell identities, raw gene expression matrix", "dataset_file_name": "GSM2406677_10X010"}, {"dataset_accession": "GSM2406677_10X005", "dataset_uri": "https://zenodo.org/records/7041849/files/AdamsonWeissman2016_GSM2406681_10X010.h5ad", "dataset_description": "Processed .h5ad file", "dataset_file_name": "AdamsonWeissman2016_GSM2406681_10X010.h5ad"}]     CC BY 4.0  SWO:1000065
#                          dataset_id sample_id    cell_barcode  data_modality  \
# 0      adamson_2016_upr_perturb_seq         1  AAACATACAAGATG  CRISPR screen
# 1      adamson_2016_upr_perturb_seq         2  AAACATACACCTAG  CRISPR screen
# 2      adamson_2016_upr_perturb_seq         3  AAACATACTTCCCG  CRISPR screen
# 3      adamson_2016_upr_perturb_seq         4  AAACATTGAAACAG  CRISPR screen
# 4      adamson_2016_upr_perturb_seq         5  AAACATTGCAGCTA  CRISPR screen
# ...                             ...       ...             ...            ...
# 62618  adamson_2016_upr_perturb_seq     62619  TTTGCATGCTTTAC  CRISPR screen
# 62619  adamson_2016_upr_perturb_seq     62620  TTTGCATGGAGGAC  CRISPR screen
# 62620  adamson_2016_upr_perturb_seq     62621  TTTGCATGTAGAGA  CRISPR screen
# 62621  adamson_2016_upr_perturb_seq     62622  TTTGCATGTCAAGC  CRISPR screen
# 62622  adamson_2016_upr_perturb_seq     62623  TTTGCATGTGGAGG  CRISPR screen
#
#       significant significance_criteria perturbation_name  \
# 0            <NA>                  <NA>    63(mod)_pBA580
# 1            <NA>                  <NA>       OST4_pDS353
# 2            <NA>                  <NA>    SEC61A1_pDS031
# 3            <NA>                  <NA>     EIF2B4_pDS491
# 4            <NA>                  <NA>       SRPR_pDS482
# ...           ...                   ...               ...
# 62618        <NA>                  <NA>      STT3A_pDS011
# 62619        <NA>                  <NA>   ARHGAP22_pDS458
# 62620        <NA>                  <NA>    63(mod)_pBA580
# 62621        <NA>                  <NA>     KCTD16_pDS096
# 62622        <NA>                  <NA>     SAMM50_pDS156
#
#              perturbed_target_coord perturbed_target_chromosome  \
# 0              control_nontargeting        control_nontargeting
# 1         chr2:27070470-27071685;-1                           2
# 2        chr3:128051641-128071705;1                           3
# 3         chr2:27363420-27370400;-1                           2
# 4      chr11:126262912-126269144;-1                          11
# ...                             ...                         ...
# 62618   chr11:125591712-125625215;1                          11
# 62619    chr10:48446036-48656265;-1                          10
# 62620          control_nontargeting        control_nontargeting
# 62621    chr5:144170873-144485686;1                           5
# 62622     chr22:43955399-44010531;1                          22
#
#        perturbed_target_chromosome_encoding  ...  software_counts_id  \
# 0                                         0  ...                <NA>
# 1                                         2  ...                <NA>
# 2                                         3  ...                <NA>
# 3                                         2  ...                <NA>
# 4                                        11  ...                <NA>
# ...                                     ...  ...                 ...
# 62618                                    11  ...                <NA>
# 62619                                    10  ...                <NA>
# 62620                                     0  ...                <NA>
# 62621                                     5  ...                <NA>
# 62622                                    22  ...                <NA>
#
#       software_counts_label software_analysis_id software_analysis_label  \
# 0                CellRanger                 <NA>                  MAGeCK
# 1                CellRanger                 <NA>                  MAGeCK
# 2                CellRanger                 <NA>                  MAGeCK
# 3                CellRanger                 <NA>                  MAGeCK
# 4                CellRanger                 <NA>                  MAGeCK
# ...                     ...                  ...                     ...
# 62618            CellRanger                 <NA>                  MAGeCK
# 62619            CellRanger                 <NA>                  MAGeCK
# 62620            CellRanger                 <NA>                  MAGeCK
# 62621            CellRanger                 <NA>                  MAGeCK
# 62622            CellRanger                 <NA>                  MAGeCK
#
#       score_interpretation reference_genome_id reference_genome_label  \
# 0                     <NA>                <NA>                 GRCh37
# 1                     <NA>                <NA>                 GRCh37
# 2                     <NA>                <NA>                 GRCh37
# 3                     <NA>                <NA>                 GRCh37
# 4                     <NA>                <NA>                 GRCh37
# ...                    ...                 ...                    ...
# 62618                 <NA>                <NA>                 GRCh37
# 62619                 <NA>                <NA>                 GRCh37
# 62620                 <NA>                <NA>                 GRCh37
# 62621                 <NA>                <NA>                 GRCh37
# 62622                 <NA>                <NA>                 GRCh37
#
#                                      associated_datasets license_label  \
# 0      [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 1      [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 2      [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 3      [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 4      [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# ...                                                  ...           ...
# 62618  [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 62619  [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 62620  [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 62621  [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
# 62622  [{"dataset_accession": "GSM2406677", "dataset_...     CC BY 4.0
#
#         license_id
# 0      SWO:1000065
# 1      SWO:1000065
# 2      SWO:1000065
# 3      SWO:1000065
# 4      SWO:1000065
# ...            ...
# 62618  SWO:1000065
# 62619  SWO:1000065
# 62620  SWO:1000065
# 62621  SWO:1000065
# 62622  SWO:1000065
#
# [62623 rows x 100 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.show_var()
# Out:
# Variable data:
# DataFrame shape: (32738, 3)
# --------------------------------------------------
#                    ensembl_id  ncounts  ncells
# gene_symbol
# MIR1302-10    ENSG00000243485     11.0      11
# FAM138A       ENSG00000237613      0.0       0
# OR4F5         ENSG00000186092      0.0       0
# RP11-34P13.7  ENSG00000238009      0.0       0
# RP11-34P13.8  ENSG00000239945     43.0      43
# ...                       ...      ...     ...
# AC145205.1    ENSG00000215635      0.0       0
# BAGE5         ENSG00000268590      0.0       0
# CU459201.1    ENSG00000251180      0.0       0
# AC002321.2    ENSG00000215616      0.0       0
# AC002321.1    ENSG00000215611      0.0       0
#
# [32738 rows x 3 columns]
# --------------------------------------------------

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="ensembl_id",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# 2026-04-28 11:17:54,895 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Missing Ensembl IDs: ['ENSG00000163113', 'ENSG00000225070', 'ENSG00000261470', 'ENSG00000242687', 'ENSG00000268217', 'ENSG00000227468', 'ENSG00000260951', 'ENSG00000215642', 'ENSG00000228561', 'ENSG00000243012', 'ENSG00000255160', 'ENSG00000270168', 'ENSG00000242924', 'ENSG00000270949', 'ENSG00000227021', 'ENSG00000231054', 'ENSG00000260982', 'ENSG00000225085', 'ENSG00000273266', 'ENSG00000272971', 'ENSG00000240355', 'ENSG00000171282', 'ENSG00000269402', 'ENSG00000165390', 'ENSG00000250174', 'ENSG00000272675', 'ENSG00000267531', 'ENSG00000269554', 'ENSG00000254148', 'ENSG00000260071', 'ENSG00000255318', 'ENSG00000254427', 'ENSG00000235475', 'ENSG00000213865', 'ENSG00000237461', 'ENSG00000255208', 'ENSG00000254998', 'ENSG00000214871', 'ENSG00000267906', 'ENSG00000229481', 'ENSG00000215764', 'ENSG00000269866', 'ENSG00000272524', 'ENSG00000272658', 'ENSG00000258268', 'ENSG00000198750', 'ENSG00000268397', 'ENSG00000256892', 'ENSG00000206176', 'ENSG00000233798', 'ENSG00000268046', 'ENSG00000269290', 'ENSG00000228255', 'ENSG00000265091', 'ENSG00000235822', 'ENSG00000155282', 'ENSG00000248478', 'ENSG00000268730', 'ENSG00000221995', 'ENSG00000258946', 'ENSG00000203886', 'ENSG00000254082', 'ENSG00000224819', 'ENSG00000268519', 'ENSG00000251314', 'ENSG00000267279', 'ENSG00000267380', 'ENSG00000270160', 'ENSG00000006075', 'ENSG00000254286', 'ENSG00000223907', 'ENSG00000240440', 'ENSG00000232498', 'ENSG00000229628', 'ENSG00000180081', 'ENSG00000269282', 'ENSG00000271649', 'ENSG00000234810', 'ENSG00000254364', 'ENSG00000269679', 'ENSG00000273366', 'ENSG00000174093', 'ENSG00000267848', 'ENSG00000261445', 'ENSG00000228682', 'ENSG00000256923', 'ENSG00000255740', 'ENSG00000249335', 'ENSG00000253839', 'ENSG00000233517', 'ENSG00000253891', 'ENSG00000220023', 'ENSG00000264072', 'ENSG00000116883', 'ENSG00000243944', 'ENSG00000226377', 'ENSG00000272369', 'ENSG00000238091', 'ENSG00000271911', 'ENSG00000230055', 'ENSG00000181689', 'ENSG00000204513', 'ENSG00000267683', 'ENSG00000263975', 'ENSG00000259606', 'ENSG00000261273', 'ENSG00000234449', 'ENSG00000236166', 'ENSG00000267981', 'ENSG00000267988', 'ENSG00000262890', 'ENSG00000233342', 'ENSG00000204377', 'ENSG00000240240', 'ENSG00000272070', 'ENSG00000256530', 'ENSG00000161570', 'ENSG00000272644', 'ENSG00000235209', 'ENSG00000242631', 'ENSG00000183086', 'ENSG00000230156', 'ENSG00000235398', 'ENSG00000130201', 'ENSG00000225597', 'ENSG00000233074', 'ENSG00000139656', 'ENSG00000268000', 'ENSG00000236008', 'ENSG00000256725', 'ENSG00000260396', 'ENSG00000237291', 'ENSG00000248986', 'ENSG00000272102', 'ENSG00000238106', 'ENSG00000257877', 'ENSG00000257164', 'ENSG00000230058', 'ENSG00000272225', 'ENSG00000272993', 'ENSG00000272341', 'ENSG00000224638', 'ENSG00000242185', 'ENSG00000268355', 'ENSG00000233840', 'ENSG00000228704', 'ENSG00000236262', 'ENSG00000258808', 'ENSG00000251532', 'ENSG00000268781', 'ENSG00000250269', 'ENSG00000271788', 'ENSG00000224867', 'ENSG00000269339', 'ENSG00000227192', 'ENSG00000259820', 'ENSG00000138293', 'ENSG00000181013', 'ENSG00000224218', 'ENSG00000235733', 'ENSG00000235999', 'ENSG00000230998', 'ENSG00000225278', 'ENSG00000230610', 'ENSG00000233094', 'ENSG00000230381', 'ENSG00000267667', 'ENSG00000248753', 'ENSG00000266927', 'ENSG00000137259', 'ENSG00000249643', 'ENSG00000244522', 'ENSG00000229964', 'ENSG00000268861', 'ENSG00000237658', 'ENSG00000270067', 'ENSG00000226524', 'ENSG00000268662', 'ENSG00000128802', 'ENSG00000258927', 'ENSG00000236082', 'ENSG00000196355', 'ENSG00000215067', 'ENSG00000254120', 'ENSG00000239265', 'ENSG00000231997', 'ENSG00000230493', 'ENSG00000268091', 'ENSG00000239446', 'ENSG00000215700', 'ENSG00000269979', 'ENSG00000268050', 'ENSG00000253369', 'ENSG00000257654', 'ENSG00000251554', 'ENSG00000257742', 'ENSG00000249677', 'ENSG00000253872', 'ENSG00000230939', 'ENSG00000017373', 'ENSG00000273481', 'ENSG00000214921', 'ENSG00000231616', 'ENSG00000224303', 'ENSG00000256763', 'ENSG00000224201', 'ENSG00000227925', 'ENSG00000267020', 'ENSG00000215298', 'ENSG00 ...
# 2577 unmapped ENSG IDs identified; splitting into chunks of 500.
# Processing IDs 1 to 500...
# 2026-04-28 11:19:03,558 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 94247
# 2026-04-28 11:19:03,564 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Processing IDs 501 to 1000...
# 2026-04-28 11:20:15,769 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 94715
# 2026-04-28 11:20:15,778 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Processing IDs 1001 to 1500...
# 2026-04-28 11:21:06,568 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 93868
# 2026-04-28 11:21:06,573 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Processing IDs 1501 to 2000...
# 2026-04-28 11:21:59,688 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 94315
# 2026-04-28 11:21:59,697 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Processing IDs 2001 to 2500...
# 2026-04-28 11:22:28,178 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 95135
# 2026-04-28 11:22:28,186 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Processing IDs 2501 to 2577...
# 2026-04-28 11:22:43,853 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 14286
# Fetched latest Ensembl IDs: {'ENSG00000163113': nan, 'ENSG00000225070': nan, 'ENSG00000261470': 'ENSG00000261749', 'ENSG00000242687': nan, 'ENSG00000268217': nan, 'ENSG00000227468': nan, 'ENSG00000260951': 'ENSG00000233824', 'ENSG00000215642': nan, 'ENSG00000228561': 'ENSG00000228221', 'ENSG00000243012': nan, 'ENSG00000255160': 'ENSG00000255308', 'ENSG00000270168': nan, 'ENSG00000242924': nan, 'ENSG00000270949': nan, 'ENSG00000227021': 'ENSG00000223874', 'ENSG00000231054': nan, 'ENSG00000260982': nan, 'ENSG00000225085': 'ENSG00000290551', 'ENSG00000273266': nan, 'ENSG00000272971': 'ENSG00000229953', 'ENSG00000240355': 'ENSG00000230680', 'ENSG00000171282': nan, 'ENSG00000269402': nan, 'ENSG00000165390': 'ENSG00000265190', 'ENSG00000250174': 'ENSG00000239523', 'ENSG00000272675': nan, 'ENSG00000267531': nan, 'ENSG00000269554': nan, 'ENSG00000254148': nan, 'ENSG00000260071': 'ENSG00000261617', 'ENSG00000255318': nan, 'ENSG00000254427': 'ENSG00000255267', 'ENSG00000235475': nan, 'ENSG00000213865': nan, 'ENSG00000237461': 'ENSG00000271086', 'ENSG00000255208': nan, 'ENSG00000254998': nan, 'ENSG00000214871': nan, 'ENSG00000267906': nan, 'ENSG00000229481': nan, 'ENSG00000215764': nan, 'ENSG00000269866': nan, 'ENSG00000272524': nan, 'ENSG00000272658': nan, 'ENSG00000258268': nan, 'ENSG00000198750': nan, 'ENSG00000268397': nan, 'ENSG00000256892': nan, 'ENSG00000206176': nan, 'ENSG00000233798': nan, 'ENSG00000268046': nan, 'ENSG00000269290': nan, 'ENSG00000228255': 'ENSG00000225233', 'ENSG00000265091': 'ENSG00000264575', 'ENSG00000235822': nan, 'ENSG00000155282': nan, 'ENSG00000248478': nan, 'ENSG00000268730': nan, 'ENSG00000221995': 'ENSG00000196535', 'ENSG00000258946': nan, 'ENSG00000203886': nan, 'ENSG00000254082': nan, 'ENSG00000224819': 'ENSG00000288902', 'ENSG00000268519': nan, 'ENSG00000251314': 'ENSG00000153113', 'ENSG00000267279': 'ENSG00000267175', 'ENSG00000267380': nan, 'ENSG00000270160': nan, 'ENSG00000006075': nan, 'ENSG00000254286': nan, 'ENSG00000223907': nan, 'ENSG00000240440': 'ENSG00000223725', 'ENSG00000232498': nan, 'ENSG00000229628': 'ENSG00000237471', 'ENSG00000180081': nan, 'ENSG00000269282': nan, 'ENSG00000271649': nan, 'ENSG00000234810': 'ENSG00000233079', 'ENSG00000254364': 'ENSG00000253666', 'ENSG00000269679': nan, 'ENSG00000273366': nan, 'ENSG00000174093': nan, 'ENSG00000267848': nan, 'ENSG00000261445': 'ENSG00000290413', 'ENSG00000228682': nan, 'ENSG00000256923': nan, 'ENSG00000255740': nan, 'ENSG00000249335': 'ENSG00000249352', 'ENSG00000253839': nan, 'ENSG00000233517': 'ENSG00000272568', 'ENSG00000253891': 'ENSG00000253535', 'ENSG00000220023': nan, 'ENSG00000264072': 'ENSG00000266604', 'ENSG00000116883': nan, 'ENSG00000243944': 'ENSG00000244541', 'ENSG00000226377': 'ENSG00000236377', 'ENSG00000272369': 'ENSG00000257261', 'ENSG00000238091': nan, 'ENSG00000271911': 'ENSG00000271727', 'ENSG00000230055': nan, 'ENSG00000181689': nan, 'ENSG00000204513': nan, 'ENSG00000267683': 'ENSG00000267339', 'ENSG00000263975': nan, 'ENSG00000259606': nan, 'ENSG00000261273': 'ENSG00000260420', 'ENSG00000234449': nan, 'ENSG00000236166': 'ENSG00000228495', 'ENSG00000267981': nan, 'ENSG00000267988': nan, 'ENSG00000262890': nan, 'ENSG00000233342': 'ENSG00000231863', 'ENSG00000204377': nan, 'ENSG00000240240': 'ENSG00000290718', 'ENSG00000272070': 'ENSG00000288095', 'ENSG00000256530': nan, 'ENSG00000161570': 'ENSG00000271503', 'ENSG00000272644': nan, 'ENSG00000235209': 'ENSG00000288106', 'ENSG00000242631': nan, 'ENSG00000183086': nan, 'ENSG00000230156': 'ENSG00000272274', 'ENSG00000235398': nan, 'ENSG00000130201': nan, 'ENSG00000225597': nan, 'ENSG00000233074': nan, 'ENSG00000139656': 'ENSG00000226519', 'ENSG00000268000': nan, 'ENSG00000236008': 'ENSG00000236790', 'ENSG00000256725': nan, 'ENSG00000260396': nan, 'ENSG00000237291': nan, 'ENSG00000248986': nan, 'ENSG00000272102': nan, 'ENSG00000238106': nan, 'ENSG00000257877': nan, 'ENSG00000257164': 'ENSG00000257114', 'ENSG00000230058': nan, 'ENSG00000272225': nan, 'ENSG00000272993':  ...
# --------------------------------------------------
# Successfully mapped 32738 out of 32738 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# Because such a large number of ENSG are unmapped, replace the unmapped ones with the original IDs

# %%
cur_data.adata.var
# Out:
#        ncounts       ensembl_id  ncells  ensembl_gene_id   gene_symbol  \
# index
# 0         11.0  ENSG00000243485      11  ENSG00000243485   MIR1302-2HG
# 1          0.0  ENSG00000237613       0  ENSG00000237613       FAM138A
# 2          0.0  ENSG00000186092       0  ENSG00000186092         OR4F5
# 3          0.0  ENSG00000238009       0  ENSG00000241860  RP11-34P13.7
# 4         43.0  ENSG00000239945      43  ENSG00000239945  RP11-34P13.8
# ...        ...              ...     ...              ...           ...
# 32733      0.0  ENSG00000215635       0  ENSG00000215635    AC145205.1
# 32734      0.0  ENSG00000268590       0  ENSG00000268590         BAGE5
# 32735      0.0  ENSG00000251180       0  ENSG00000251180    CU459201.1
# 32736      0.0  ENSG00000215616       0  ENSG00000215616    AC002321.2
# 32737      0.0  ENSG00000215611       0  ENSG00000215611    AC002321.1
#
#       original_index
# index
# 0         MIR1302-10
# 1            FAM138A
# 2              OR4F5
# 3       RP11-34P13.7
# 4       RP11-34P13.8
# ...              ...
# 32733     AC145205.1
# 32734          BAGE5
# 32735     CU459201.1
# 32736     AC002321.2
# 32737     AC002321.1
#
# [32738 rows x 6 columns]

# %%
cur_data.adata.var.loc[cur_data.adata.var['gene_symbol'].isna(), 'gene_symbol'] = cur_data.adata.var.loc[
    cur_data.adata.var['gene_symbol'].isna(), 'original_index']

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot="var")
# Out:
# 2026-04-28 11:23:51,982 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
# 2026-04-28 11:23:51,985 DEBUG curation_tools.curation_tools: Validated adata.var preview (shape=(32738, 2)):
#        ensembl_gene_id   gene_symbol
# index
# 0      ENSG00000243485   MIR1302-2HG
# 1      ENSG00000237613       FAM138A
# 2      ENSG00000186092         OR4F5
# 3      ENSG00000241860  RP11-34P13.7
# 4      ENSG00000239945  RP11-34P13.8
#        ensembl_gene_id   gene_symbol
# index
# 0      ENSG00000243485   MIR1302-2HG
# 1      ENSG00000237613       FAM138A
# 2      ENSG00000186092         OR4F5
# 3      ENSG00000241860  RP11-34P13.7
# 4      ENSG00000239945  RP11-34P13.8
# ...                ...           ...
# 32733  ENSG00000215635    AC145205.1
# 32734  ENSG00000268590         BAGE5
# 32735  ENSG00000251180    CU459201.1
# 32736  ENSG00000215616    AC002321.2
# 32737  ENSG00000215611    AC002321.1
#
# [32738 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data_h5ad()
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ... storing 'dataset_id' as categorical
# ... storing 'data_modality' as categorical
# ... storing 'significance_criteria' as categorical
# ... storing 'perturbation_name' as categorical
# ... storing 'perturbed_target_coord' as categorical
# ... storing 'perturbed_target_chromosome' as categorical
# ... storing 'perturbed_target_ensg' as categorical
# ... storing 'perturbed_target_symbol' as categorical
# ... storing 'perturbed_target_biotype' as categorical
# ... storing 'guide_sequence' as categorical
# ... storing 'perturbation_type_label' as categorical
# ... storing 'perturbation_type_id' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'treatment_label' as categorical
# ... storing 'treatment_id' as categorical
# ... storing 'technical_replicate' as categorical
# ... storing 'biological_replicate' as categorical
# ... storing 'model_system_label' as categorical
# ... storing 'model_system_id' as categorical
# ... storing 'species' as categorical
# ... storing 'tissue_label' as categorical
# ... storing 'tissue_id' as categorical
# ... storing 'cell_type_label' as categorical
# ... storing 'cell_type_id' as categorical
# ... storing 'cell_line_label' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'sex_label' as categorical
# ... storing 'sex_id' as categorical
# ... storing 'developmental_stage_label' as categorical
# ... storing 'developmental_stage_id' as categorical
# ... storing 'disease_label' as categorical
# ... storing 'disease_id' as categorical
# ... storing 'study_title' as categorical
# ... storing 'study_uri' as categorical
# ... storing 'first_author' as categorical
# ... storing 'last_author' as categorical
# ... storing 'experiment_title' as categorical
# ... storing 'experiment_summary' as categorical
# ... storing 'number_of_perturbed_targets' as categorical
# ... storing 'number_of_perturbed_samples' as categorical
# ... storing 'library_generation_type_id' as categorical
# ... storing 'library_generation_type_label' as categorical
# ... storing 'library_generation_method_id' as categorical
# ... storing 'library_generation_method_label' as categorical
# ... storing 'enzyme_delivery_method_id' as categorical
# ... storing 'enzyme_delivery_method_label' as categorical
# ... storing 'library_delivery_method_id' as categorical
# ... storing 'library_delivery_method_label' as categorical
# ... storing 'enzyme_integration_state_id' as categorical
# ... storing 'enzyme_integration_state_label' as categorical
# ... storing 'library_integration_state_id' as categorical
# ... storing 'library_integration_state_label' as categorical
# ... storing 'enzyme_expression_control_id' as categorical
# ... storing 'enzyme_expression_control_label' as categorical
# ... storing 'library_expression_control_id' as categorical
# ... storing 'library_expression_control_label' as categorical
# ... storing 'library_name' as categorical
# ... storing 'library_uri' as categorical
# ... storing 'library_format_id' as categorical
# ... storing 'library_format_label' as categorical
# ... storing 'library_scope_id' as categorical
# ... storing 'library_scope_label' as categorical
# ... storing 'library_perturbation_type_id' as categorical
# ... storing 'library_perturbation_type_label' as categorical
# ... storing 'library_manufacturer' as categorical
# ... storing 'library_lentiviral_generation' as categorical
# ... storing 'library_grnas_per_target' as categorical
# ... storing 'library_total_grnas' as categorical
# ... storing 'readout_dimensionality_id' as categorical
# ... storing 'readout_dimensionality_label' as categorical
# ... storing 'readout_type_id' as categorical
# ... storing 'readout_type_label' as categorical
# ... storing 'readout_technology_id' as categorical
# ... storing 'readout_technology_label' as categorical
# ... storing 'method_name_id' as categorical
# ... storing 'method_name_label' as categorical
# ... storing 'method_uri' as categorical
# ... storing 'sequencing_library_kit_id' as categorical
# ... storing 'sequencing_library_kit_label' as categorical
# ... storing 'sequencing_platform_id' as categorical
# ... storing 'sequencing_platform_label' as categorical
# ... storing 'sequencing_strategy_id' as categorical
# ... storing 'sequencing_strategy_label' as categorical
# ... storing 'software_counts_id' as categorical
# ... storing 'software_counts_label' as categorical
# ... storing 'software_analysis_id' as categorical
# ... storing 'software_analysis_label' as categorical
# ... storing 'score_interpretation' as categorical
# ... storing 'reference_genome_id' as categorical
# ... storing 'reference_genome_label' as categorical
# ... storing 'associated_datasets' as categorical
# ... storing 'license_label' as categorical
# ... storing 'license_id' as categorical
# ... storing 'ensembl_gene_id' as categorical
# ... storing 'gene_symbol' as categorical
# 2026-04-28 11:23:57,849 DEBUG h5py._conv: Creating converter from 5 to 3
# ✅ Curated h5ad data saved to ../curated/h5ad/adamson_2016_upr_perturb_seq_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/adamson_2016_upr_perturb_seq_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
upload_parquet_to_bq(
    parquet_path='../curated/parquet/adamson_2016_upr_perturb_seq_curated_metadata.parquet',
    bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
    bq_table_name='metadata',
    key_columns=['dataset_id', 'sample_id'],
    verbose=True
)
# Out:
# 2026-04-28 11:24:24,533 DEBUG google.auth._default: Checking '' for explicit credentials as part of auth process...
# 2026-04-28 11:24:24,533 DEBUG google.auth._default: Checking Cloud SDK credentials as part of auth process...
# 2026-04-28 11:24:25,511 DEBUG google.auth._default: Checking '' for explicit credentials as part of auth process...
# 2026-04-28 11:24:25,513 DEBUG google.auth._default: Checking Cloud SDK credentials as part of auth process...
# 2026-04-28 11:24:26,322 DEBUG google.cloud.bigquery.opentelemetry_tracing: This service is instrumented using OpenTelemetry. OpenTelemetry or one of its components could not be imported; please add compatible versions of opentelemetry-api and opentelemetry-instrumentation packages in order to get BigQuery Tracing data.
# 2026-04-28 11:24:26,324 DEBUG urllib3.util.retry: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2026-04-28 11:24:26,328 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2026-04-28 11:24:26,382 DEBUG urllib3.connectionpool: https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# 2026-04-28 11:24:26,385 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): bigquery.googleapis.com:443
# 2026-04-28 11:24:26,644 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# Staging table: loading `.parquet` file ../curated/parquet/adamson_2016_upr_perturb_seq_curated_metadata.parquet to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging...
# 2026-04-28 11:24:27,122 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?uploadType=resumable HTTP/1.1" 200 0
# 2026-04-28 11:24:27,841 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "PUT /upload/bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?uploadType=resumable&upload_id=AAVLpEgjqmtD8nNasaEnVgbqDjsu3cqr9vRkd5NKsB6mh2G3TuNXOomhvxeDfLpP8bzjtDJ-8GwJKgNhReijHRZBxj5K9RDK2qsvXcen88OhfQ HTTP/1.1" 200 14124
# 2026-04-28 11:24:28,014 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/369bd0a1-fda7-4520-bc86-1b3f86f4407b?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:28,566 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/369bd0a1-fda7-4520-bc86-1b3f86f4407b?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:30,078 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/369bd0a1-fda7-4520-bc86-1b3f86f4407b?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:30,282 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata_staging?prettyPrint=false HTTP/1.1" 200 None
# Staging table: loaded 62623 rows to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# 2026-04-28 11:24:32,335 DEBUG urllib3.util.retry: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2026-04-28 11:24:32,337 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2026-04-28 11:24:32,397 DEBUG urllib3.connectionpool: https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# 2026-04-28 11:24:32,399 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): bigquery.googleapis.com:443
# 2026-04-28 11:24:32,796 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:32,883 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/66b80c60-35b9-49f6-a575-7af478edce2c?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,006 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/66b80c60-35b9-49f6-a575-7af478edce2c?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,099 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/66b80c60-35b9-49f6-a575-7af478edce2c?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,436 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,547 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/a2c9eda6-de2f-4089-b423-b3cbd5ce89f3?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,711 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/a2c9eda6-de2f-4089-b423-b3cbd5ce89f3?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:33,837 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/a2c9eda6-de2f-4089-b423-b3cbd5ce89f3?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:34,480 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:34,598 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/47e97c66-7a66-41cd-8c43-d4ac0028dd5c?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:37,248 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/47e97c66-7a66-41cd-8c43-d4ac0028dd5c?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:37,395 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/47e97c66-7a66-41cd-8c43-d4ac0028dd5c?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:37,592 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# 2026-04-28 11:24:37,728 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:38,221 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:38,376 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/f8007782-fb43-4559-9d96-7792e7fe4326?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:42,664 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/f8007782-fb43-4559-9d96-7792e7fe4326?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:42,735 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/f8007782-fb43-4559-9d96-7792e7fe4326?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-28 11:24:42,914 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "DELETE /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata_staging?prettyPrint=false HTTP/1.1" 204 0
# Merge completed: staging → prj-ext-dev-pertcat-437314.perturb_seq.metadata with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/adamson_2016_upr_perturb_seq_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
# Out:
# WARNING: Parallel composite upload was turned ON to get the best performance on
# uploading large objects. If you would like to opt-out and instead
# perform a normal upload, run:
# `gcloud config set storage/parallel_composite_upload_enabled False`
# If you would like to disable this warning, run:
# `gcloud config set storage/parallel_composite_upload_enabled True`
# Note that with parallel composite uploads, your object might be
# uploaded as a composite object
# (https://cloud.google.com/storage/docs/composite-objects), which means
# that any user who downloads your object will need to use crc32c
# checksums to verify data integrity. gcloud storage is capable of
# computing crc32c checksums, but this might pose a problem for other
# clients.
#
# Copying file://../curated/h5ad/adamson_2016_upr_perturb_seq_curated.h5ad to gs://perturbation-catalogue-lake/perturbseq/curated/adamson_2016_upr_perturb_seq_curated.h5ad
#   Completed files 32/1 | 1.7GiB/1.7GiB | 273.4MiB/s
#
# Average throughput: 303.7MiB/s
