# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)
# show all columns
pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.12/dist-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# # Download data

# %%
# !aws s3 cp --no-sign-request s3://genome-scale-tcell-perturb-seq/marson2025_data/GWCD4i.pseudobulk_merged.h5ad /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad
# !mv /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/GWCD4i.pseudobulk_merged.h5ad /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/zhu_2025_pseudobulk.h5ad
# Out:
# download: s3://genome-scale-tcell-perturb-seq/marson2025_data/GWCD4i.pseudobulk_merged.h5ad to Perturbseq/non_curated/h5ad/GWCD4i.pseudobulk_merged.h5ad

# %% [markdown]
# # Initialise the dataset object

# %%
noncurated_path = '/content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/zhu_2025_pseudobulk.h5ad'
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/zhu_2025_pseudobulk.h5ad

# %%
cur_data.adata
# Out:
# AnnData object with n_obs × n_vars = 278684 × 18129
#     obs: '10xrun_id', 'donor_id', 'culture_condition', 'guide_id', 'perturbed_gene_name', 'perturbed_gene_id', 'guide_type', 'n_cells', 'total_counts', 'keep_min_cells', 'keep_effective_guides', 'keep_total_counts', 'keep_for_DE', 'keep_test_genes', 'log10_n_cells'
#     var: 'gene_ids', 'gene_name'

# %%
cur_data.adata.obs
# Out:
#                            10xrun_id   donor_id culture_condition guide_id  \
# CD4i_R2_D1_Stim48hr_A1BG-1   CD4i_R2  CE0008162          Stim48hr   A1BG-1
# CD4i_R2_D1_Stim48hr_A1BG-2   CD4i_R2  CE0008162          Stim48hr   A1BG-2
# CD4i_R2_D1_Stim48hr_A2M-1    CD4i_R2  CE0008162          Stim48hr    A2M-1
# CD4i_R2_D1_Stim48hr_A2M-2    CD4i_R2  CE0008162          Stim48hr    A2M-2
# CD4i_R2_D1_Stim48hr_AAAS-1   CD4i_R2  CE0008162          Stim48hr   AAAS-1
# ...                              ...        ...               ...      ...
# CD4i_R2_D4_Rest_ZYX-1        CD4i_R2  CE0006864              Rest    ZYX-1
# CD4i_R2_D4_Rest_ZYX-2        CD4i_R2  CE0006864              Rest    ZYX-2
# CD4i_R2_D4_Rest_ZYX-3        CD4i_R2  CE0006864              Rest    ZYX-3
# CD4i_R2_D4_Rest_ZZEF1-1      CD4i_R2  CE0006864              Rest  ZZEF1-1
# CD4i_R2_D4_Rest_ZZEF1-2      CD4i_R2  CE0006864              Rest  ZZEF1-2
#
#                            perturbed_gene_name perturbed_gene_id guide_type  \
# CD4i_R2_D1_Stim48hr_A1BG-1                A1BG   ENSG00000121410  targeting
# CD4i_R2_D1_Stim48hr_A1BG-2                A1BG   ENSG00000121410  targeting
# CD4i_R2_D1_Stim48hr_A2M-1                  A2M   ENSG00000175899  targeting
# CD4i_R2_D1_Stim48hr_A2M-2                  A2M   ENSG00000175899  targeting
# CD4i_R2_D1_Stim48hr_AAAS-1                AAAS   ENSG00000094914  targeting
# ...                                        ...               ...        ...
# CD4i_R2_D4_Rest_ZYX-1                      ZYX   ENSG00000159840  targeting
# CD4i_R2_D4_Rest_ZYX-2                      ZYX   ENSG00000159840  targeting
# CD4i_R2_D4_Rest_ZYX-3                      ZYX   ENSG00000159840  targeting
# CD4i_R2_D4_Rest_ZZEF1-1                  ZZEF1   ENSG00000074755  targeting
# CD4i_R2_D4_Rest_ZZEF1-2                  ZZEF1   ENSG00000074755  targeting
#
#                             n_cells  total_counts  keep_min_cells  \
# CD4i_R2_D1_Stim48hr_A1BG-1     26.0      326500.0            True
# CD4i_R2_D1_Stim48hr_A1BG-2    160.0     2313880.0            True
# CD4i_R2_D1_Stim48hr_A2M-1       1.0       23782.0           False
# CD4i_R2_D1_Stim48hr_A2M-2      22.0      330204.0            True
# CD4i_R2_D1_Stim48hr_AAAS-1     95.0     1389867.0            True
# ...                             ...           ...             ...
# CD4i_R2_D4_Rest_ZYX-1           1.0       11009.0           False
# CD4i_R2_D4_Rest_ZYX-2          39.0      318693.0            True
# CD4i_R2_D4_Rest_ZYX-3          31.0      247297.0            True
# CD4i_R2_D4_Rest_ZZEF1-1       100.0     1050023.0            True
# CD4i_R2_D4_Rest_ZZEF1-2        55.0      405467.0            True
#
#                             keep_effective_guides  keep_total_counts  \
# CD4i_R2_D1_Stim48hr_A1BG-1                   True               True
# CD4i_R2_D1_Stim48hr_A1BG-2                   True               True
# CD4i_R2_D1_Stim48hr_A2M-1                    True               True
# CD4i_R2_D1_Stim48hr_A2M-2                    True               True
# CD4i_R2_D1_Stim48hr_AAAS-1                   True               True
# ...                                           ...                ...
# CD4i_R2_D4_Rest_ZYX-1                        True               True
# CD4i_R2_D4_Rest_ZYX-2                        True               True
# CD4i_R2_D4_Rest_ZYX-3                        True               True
# CD4i_R2_D4_Rest_ZZEF1-1                      True               True
# CD4i_R2_D4_Rest_ZZEF1-2                      True               True
#
#                             keep_for_DE  keep_test_genes  log10_n_cells
# CD4i_R2_D1_Stim48hr_A1BG-1         True             True       1.414973
# CD4i_R2_D1_Stim48hr_A1BG-2         True             True       2.204120
# CD4i_R2_D1_Stim48hr_A2M-1         False             True       0.000000
# CD4i_R2_D1_Stim48hr_A2M-2          True             True       1.342423
# CD4i_R2_D1_Stim48hr_AAAS-1         True             True       1.977724
# ...                                 ...              ...            ...
# CD4i_R2_D4_Rest_ZYX-1             False             True       0.000000
# CD4i_R2_D4_Rest_ZYX-2              True             True       1.591065
# CD4i_R2_D4_Rest_ZYX-3              True             True       1.491362
# CD4i_R2_D4_Rest_ZZEF1-1            True             True       2.000000
# CD4i_R2_D4_Rest_ZZEF1-2            True             True       1.740363
#
# [278684 rows x 15 columns]

# %%
cur_data.adata.var
# Out:
#                         gene_ids gene_name
# CUSTOM001_PuroR  CUSTOM001_PuroR     PuroR
# ENSG00000000003  ENSG00000000003    TSPAN6
# ENSG00000000005  ENSG00000000005      TNMD
# ENSG00000000419  ENSG00000000419      DPM1
# ENSG00000000457  ENSG00000000457     SCYL3
# ...                          ...       ...
# ENSG00000291110  ENSG00000291110   TRIM16L
# ENSG00000291122  ENSG00000291122  CASTOR3P
# ENSG00000291135  ENSG00000291135   FCGR1BP
# ENSG00000291145  ENSG00000291145   PPP5D1P
# ENSG00000291237  ENSG00000291237      SOD2
#
# [18129 rows x 2 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Add `index` as `perturbation_name`

# %%
cur_data.adata.obs['perturbation_name'] = cur_data.adata.obs.index

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'perturbation_name')
# Out:
# Streaming output truncated to the last 5000 lines.
#  'CD4i_R2_D4_Stim8hr_SPPL3-1',
#  'CD4i_R2_D4_Stim8hr_SPPL3-2',
#  'CD4i_R2_D4_Stim8hr_SPR-1',
#  'CD4i_R2_D4_Stim8hr_SPR-2',
#  'CD4i_R2_D4_Stim8hr_SPRED2-1',
#  'CD4i_R2_D4_Stim8hr_SPRED2-2',
#  'CD4i_R2_D4_Stim8hr_SPRN-1',
#  'CD4i_R2_D4_Stim8hr_SPRN-2',
#  'CD4i_R2_D4_Stim8hr_SPRTN-2',
#  'CD4i_R2_D4_Stim8hr_SPRY1-1',
#  'CD4i_R2_D4_Stim8hr_SPRY1-2',
#  'CD4i_R2_D4_Stim8hr_SPRY2-1',
#  'CD4i_R2_D4_Stim8hr_SPRY2-2',
#  'CD4i_R2_D4_Stim8hr_SPRYD3-1',
#  'CD4i_R2_D4_Stim8hr_SPRYD3-2',
#  'CD4i_R2_D4_Stim8hr_SPRYD4-1',
#  'CD4i_R2_D4_Stim8hr_SPRYD4-2',
#  'CD4i_R2_D4_Stim8hr_SPRYD7-1',
#  'CD4i_R2_D4_Stim8hr_SPRYD7-2',
#  'CD4i_R2_D4_Stim8hr_SPSB1-1',
#  'CD4i_R2_D4_Stim8hr_SPSB1-2',
#  'CD4i_R2_D4_Stim8hr_SPSB2-1',
#  'CD4i_R2_D4_Stim8hr_SPSB2-2',
#  'CD4i_R2_D4_Stim8hr_SPSB3-1',
#  'CD4i_R2_D4_Stim8hr_SPSB3-2',
#  'CD4i_R2_D4_Stim8hr_SPTAN1-1',
#  'CD4i_R2_D4_Stim8hr_SPTAN1-2',
#  'CD4i_R2_D4_Stim8hr_SPTB-1',
#  'CD4i_R2_D4_Stim8hr_SPTB-2',
#  'CD4i_R2_D4_Stim8hr_SPTBN1-1',
#  'CD4i_R2_D4_Stim8hr_SPTBN1-2',
#  'CD4i_R2_D4_Stim8hr_SPTBN5-1',
#  'CD4i_R2_D4_Stim8hr_SPTBN5-2',
#  'CD4i_R2_D4_Stim8hr_SPTLC1-1',
#  'CD4i_R2_D4_Stim8hr_SPTLC1-2',
#  'CD4i_R2_D4_Stim8hr_SPTLC2-1',
#  'CD4i_R2_D4_Stim8hr_SPTLC2-2',
#  'CD4i_R2_D4_Stim8hr_SPTSSA-1',
#  'CD4i_R2_D4_Stim8hr_SPTSSA-2',
#  'CD4i_R2_D4_Stim8hr_SPTSSB-1',
#  'CD4i_R2_D4_Stim8hr_SPTY2D1-1',
#  'CD4i_R2_D4_Stim8hr_SPTY2D1-2',
#  'CD4i_R2_D4_Stim8hr_SPZ1-1',
#  'CD4i_R2_D4_Stim8hr_SPZ1-2',
#  'CD4i_R2_D4_Stim8hr_SQLE-1',
#  'CD4i_R2_D4_Stim8hr_SQLE-2',
#  'CD4i_R2_D4_Stim8hr_SQOR-1',
#  'CD4i_R2_D4_Stim8hr_SQOR-2',
#  'CD4i_R2_D4_Stim8hr_SQSTM1-1',
#  'CD4i_R2_D4_Stim8hr_SQSTM1-2',
#  'CD4i_R2_D4_Stim8hr_SRA1-1',
#  'CD4i_R2_D4_Stim8hr_SRA1-2',
#  'CD4i_R2_D4_Stim8hr_SRBD1-1',
#  'CD4i_R2_D4_Stim8hr_SRC-1',
#  'CD4i_R2_D4_Stim8hr_SRC-2',
#  'CD4i_R2_D4_Stim8hr_SRCAP-1',
#  'CD4i_R2_D4_Stim8hr_SRCAP-2',
#  'CD4i_R2_D4_Stim8hr_SRD5A1-1',
#  'CD4i_R2_D4_Stim8hr_SRD5A1-2',
#  'CD4i_R2_D4_Stim8hr_SRD5A3-1',
#  'CD4i_R2_D4_Stim8hr_SRD5A3-2',
#  'CD4i_R2_D4_Stim8hr_SREBF1-1',
#  'CD4i_R2_D4_Stim8hr_SREBF2-1',
#  'CD4i_R2_D4_Stim8hr_SREBF2-2',
#  'CD4i_R2_D4_Stim8hr_SREK1-1',
#  'CD4i_R2_D4_Stim8hr_SREK1-2',
#  'CD4i_R2_D4_Stim8hr_SREK1IP1-1',
#  'CD4i_R2_D4_Stim8hr_SREK1IP1-2',
#  'CD4i_R2_D4_Stim8hr_SRF-1',
#  'CD4i_R2_D4_Stim8hr_SRF-2',
#  'CD4i_R2_D4_Stim8hr_SRFBP1-1',
#  'CD4i_R2_D4_Stim8hr_SRFBP1-2',
#  'CD4i_R2_D4_Stim8hr_SRGAP1-1',
#  'CD4i_R2_D4_Stim8hr_SRGAP1-2',
#  'CD4i_R2_D4_Stim8hr_SRGAP2-1',
#  'CD4i_R2_D4_Stim8hr_SRGAP2-2',
#  'CD4i_R2_D4_Stim8hr_SRGAP2B-1',
#  'CD4i_R2_D4_Stim8hr_SRGAP2B-2',
#  'CD4i_R2_D4_Stim8hr_SRGAP2C-1',
#  'CD4i_R2_D4_Stim8hr_SRGAP2C-2',
#  'CD4i_R2_D4_Stim8hr_SRGAP3-1',
#  'CD4i_R2_D4_Stim8hr_SRGAP3-2',
#  'CD4i_R2_D4_Stim8hr_SRGN-1',
#  'CD4i_R2_D4_Stim8hr_SRGN-2',
#  'CD4i_R2_D4_Stim8hr_SRI-1',
#  'CD4i_R2_D4_Stim8hr_SRI-2',
#  'CD4i_R2_D4_Stim8hr_SRM-1',
#  'CD4i_R2_D4_Stim8hr_SRM-2',
#  'CD4i_R2_D4_Stim8hr_SRP14-1',
#  'CD4i_R2_D4_Stim8hr_SRP14-2',
#  'CD4i_R2_D4_Stim8hr_SRP19-1',
#  'CD4i_R2_D4_Stim8hr_SRP54-1',
#  'CD4i_R2_D4_Stim8hr_SRP54-2',
#  'CD4i_R2_D4_Stim8hr_SRP68-2',
#  'CD4i_R2_D4_Stim8hr_SRP72-2',
#  'CD4i_R2_D4_Stim8hr_SRP9-1',
#  'CD4i_R2_D4_Stim8hr_SRP9-2',
#  'CD4i_R2_D4_Stim8hr_SRPK1-1',
#  'CD4i_R2_D4_Stim8hr_SRPK1-2',
#  'CD4i_R2_D4_Stim8hr_SRPK2-1',
#  'CD4i_R2_D4_Stim8hr_SRPK2-2',
#  'CD4i_R2_D4_Stim8hr_SRPRA-1',
#  'CD4i_R2_D4_Stim8hr_SRPRA-2',
#  'CD4i_R2_D4_Stim8hr_SRPRB-1',
#  'CD4i_R2_D4_Stim8hr_SRPRB-2',
#  'CD4i_R2_D4_Stim8hr_SRR-1',
#  'CD4i_R2_D4_Stim8hr_SRR-2',
#  'CD4i_R2_D4_Stim8hr_SRRD-1',
#  'CD4i_R2_D4_Stim8hr_SRRD-2',
#  'CD4i_R2_D4_Stim8hr_SRRM1-1',
#  'CD4i_R2_D4_Stim8hr_SRRM1-2',
#  'CD4i_R2_D4_Stim8hr_SRSF10-1',
#  'CD4i_R2_D4_Stim8hr_SRSF10-2',
#  'CD4i_R2_D4_Stim8hr_SRSF11-1',
#  'CD4i_R2_D4_Stim8hr_SRSF11-2',
#  'CD4i_R2_D4_Stim8hr_SRSF2-1',
#  'CD4i_R2_D4_Stim8hr_SRSF2-2',
#  'CD4i_R2_D4_Stim8hr_SRSF3-1',
#  'CD4i_R2_D4_Stim8hr_SRSF4-1',
#  'CD4i_R2_D4_Stim8hr_SRSF4-2',
#  'CD4i_R2_D4_Stim8hr_SRSF5-1',
#  'CD4i_R2_D4_Stim8hr_SRSF5-2',
#  'CD4i_R2_D4_Stim8hr_SRSF6-1',
#  'CD4i_R2_D4_Stim8hr_SRSF6-2',
#  'CD4i_R2_D4_Stim8hr_SRSF7-1',
#  'CD4i_R2_D4_Stim8hr_SRSF7-2',
#  'CD4i_R2_D4_Stim8hr_SRSF8-1',
#  'CD4i_R2_D4_Stim8hr_SRSF8-2',
#  'CD4i_R2_D4_Stim8hr_SRSF9-1',
#  'CD4i_R2_D4_Stim8hr_SRSF9-2',
#  'CD4i_R2_D4_Stim8hr_SRXN1-1',
#  'CD4i_R2_D4_Stim8hr_SRXN1-2',
#  'CD4i_R2_D4_Stim8hr_SRY-1',
#  'CD4i_R2_D4_Stim8hr_SRY-2',
#  'CD4i_R2_D4_Stim8hr_SS18-1',
#  'CD4i_R2_D4_Stim8hr_SS18-2',
#  'CD4i_R2_D4_Stim8hr_SS18L1-1',
#  'CD4i_R2_D4_Stim8hr_SS18L2-1',
#  'CD4i_R2_D4_Stim8hr_SS18L2-2',
#  'CD4i_R2_D4_Stim8hr_SSB-1',
#  'CD4i_R2_D4_Stim8hr_SSB-2',
#  'CD4i_R2_D4_Stim8hr_SSBP1-1',
#  'CD4i_R2_D4_Stim8hr_SSBP1-2',
#  'CD4i_R2_D4_Stim8hr_SSBP2-1',
#  'CD4i_R2_D4_Stim8hr_SSBP2-2',
#  'CD4i_R2_D4_Stim8hr_SSBP3-1',
#  'CD4i_R2_D4_Stim8hr_SSBP3-2',
#  'CD4i_R2_D4_Stim8hr_SSBP4-1',
#  'CD4i_R2_D4_Stim8hr_SSBP4-2',
#  'CD4i_R2_D4_Stim8hr_SSH1-1',
#  'CD4i_R2_D4_Stim8hr_SSH1-2',
#  'CD4i_R2_D4_Stim8hr_SSH2-1',
#  'CD4i_R2_D4_Stim8hr_SSH2-2',
#  'CD4i_R2_D4_Stim8hr_SSH3-1',
#  'CD4i_R2_D4_Stim8hr_SSH3-2',
#  'CD4i_R2_D4_Stim8hr_SSNA1-1',
#  'CD4i_R2_D4_Stim8hr_SSNA1-2',
#  'CD4i_R2_D4_Stim8hr_SSR1-1',
#  'CD4i_R2_D4_Stim8hr_SSR1-2',
#  'CD4i_R2_D4_Stim8hr_SSR2-1',
#  'CD4i_R2_D4_Stim8hr_SSR2-2',
#  'CD4i_R2_D4_Stim8hr_SSR3-1',
#  'CD4i_R2_D4_Stim8hr_SSR3-2',
#  'CD4i_R2_D4_Stim8hr_SSR4-1',
#  'CD4i_R2_D4_Stim8hr_SSR4-2',
#  'CD4i_R2_D4_Stim8hr_SSRP1-2',
#  'CD4i_R2_D4_Stim8hr_SSSCA1-1',
#  'CD4i_R2_D4_Stim8hr_SSSCA1-2',
#  'CD4i_R2_D4_Stim8hr_SSTR3-1',
#  'CD4i_R2_D4_Stim8hr_SSTR3-2',
#  'CD4i_R2_D4_Stim8hr_SSU72-1',
#  'CD4i_R2_D4_Stim8hr_SSU72-2',
#  'CD4i_R2_D4_Stim8hr_SSX2IP-1',
#  'CD4i_R2_D4_Stim8hr_SSX2IP-2',
#  'CD4i_R2_D4_Stim8hr_ST13-1',
#  'CD4i_R2_D4_Stim8hr_ST13-2',
#  'CD4i_R2_D4_Stim8hr_ST14-1',
#  'CD4i_R2_D4_Stim8hr_ST14-2',
#  'CD4i_R2_D4_Stim8hr_ST18-1',
#  'CD4i_R2_D4_Stim8hr_ST18-2',
#  'CD4i_R2_D4_Stim8hr_ST20-1',
#  'CD4i_R2_D4_Stim8hr_ST20-2',
#  'CD4i_R2_D4_Stim8hr_ST20-MTHFS-1',
#  'CD4i_R2_D4_Stim8hr_ST20-MTHFS-2',
#  'CD4i_R2_D4_Stim8hr_ST3GAL1-1',
#  'CD4i_R2_D4_Stim8hr_ST3GAL1-2',
#  'CD4i_R2_D4_Stim8hr_ST3GAL2-1',
#  'CD4i_R2_D4_Stim8hr_ST3GAL2-2',
#  'CD4i_R2_D4_Stim8hr_ST3GAL3-1',
#  'CD4i_R2_D4_Stim8hr_ST3GAL3-2',
#  'CD4i_R2_D4_Stim8hr_ST3GAL4-1',
#  'CD4i_R2_D4_Stim8hr_ST3GAL4-2',
#  'CD4i_R2_D4_Stim8hr_ST3GAL5-1',
#  'CD4i_R2_D4_Stim8hr_ST3GAL5-2',
#  'CD4i_R2_D4_Stim8hr_ST5-1',
#  'CD4i_R2_D4_Stim8hr_ST5-2',
#  'CD4i_R2_D4_Stim8hr_ST6GAL1-1',
#  'CD4i_R2_D4_Stim8hr_ST6GAL1-2',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC1-1',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC1-2',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC3-1',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC3-2',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC4-1',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC4-2',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC6-1',
#  'CD4i_R2_D4_Stim8hr_ST6GALNAC6-2',
#  'CD4i_R2_D4_Stim8hr_ST7-1',
#  'CD4i_R2_D4_Stim8hr_ST7-2',
#  'CD4i_R2_D4_Stim8hr_ST7L-1',
#  'CD4i_R2_D4_Stim8hr_ST7L-2',
#  'CD4i_R2_D4_Stim8hr_ST8SIA1-1',
#  'CD4i_R2_D4_Stim8hr_ST8SIA1-2',
#  'CD4i_R2_D4_Stim8hr_ST8SIA4-1',
#  'CD4i_R2_D4_Stim8hr_ST8SIA4-2',
#  'CD4i_R2_D4_Stim8hr_STAB1-1',
#  'CD4i_R2_D4_Stim8hr_STAB1-2',
#  'CD4i_R2_D4_Stim8hr_STAC3-1',
#  'CD4i_R2_D4_Stim8hr_STAC3-2',
#  'CD4i_R2_D4_Stim8hr_STAG1-1',
#  'CD4i_R2_D4_Stim8hr_STAG1-2',
#  'CD4i_R2_D4_Stim8hr_STAG2-1',
#  'CD4i_R2_D4_Stim8hr_STAG2-2',
#  'CD4i_R2_D4_Stim8hr_STAG3-1',
#  'CD4i_R2_D4_Stim8hr_STAG3-2',
#  'CD4i_R2_D4_Stim8hr_STAM-1',
#  'CD4i_R2_D4_Stim8hr_STAM-2',
#  'CD4i_R2_D4_Stim8hr_STAM2-1',
#  'CD4i_R2_D4_Stim8hr_STAM2-2',
#  'CD4i_R2_D4_Stim8hr_STAMBP-1',
#  'CD4i_R2_D4_Stim8hr_STAMBP-2',
#  'CD4i_R2_D4_Stim8hr_STAMBPL1-1',
#  'CD4i_R2_D4_Stim8hr_STAMBPL1-2',
#  'CD4i_R2_D4_Stim8hr_STAP1-1',
#  'CD4i_R2_D4_Stim8hr_STAP1-2',
#  'CD4i_R2_D4_Stim8hr_STAP2-1',
#  'CD4i_R2_D4_Stim8hr_STAP2-2',
#  'CD4i_R2_D4_Stim8hr_STARD10-1',
#  'CD4i_R2_D4_Stim8hr_STARD10-2',
#  'CD4i_R2_D4_Stim8hr_STARD3-1',
#  'CD4i_R2_D4_Stim8hr_STARD3-2',
#  'CD4i_R2_D4_Stim8hr_STARD3NL-1',
#  'CD4i_R2_D4_Stim8hr_STARD3NL-2',
#  'CD4i_R2_D4_Stim8hr_STARD4-1',
#  'CD4i_R2_D4_Stim8hr_STARD4-2',
#  'CD4i_R2_D4_Stim8hr_STARD5-1',
#  'CD4i_R2_D4_Stim8hr_STARD5-2',
#  'CD4i_R2_D4_Stim8hr_STARD7-1',
#  'CD4i_R2_D4_Stim8hr_STARD7-2',
#  'CD4i_R2_D4_Stim8hr_STARD9-1',
#  'CD4i_R2_D4_Stim8hr_STARD9-2',
#  'CD4i_R2_D4_Stim8hr_STAT1-1',
#  'CD4i_R2_D4_Stim8hr_STAT1-2',
#  'CD4i_R2_D4_Stim8hr_STAT2-1',
#  'CD4i_R2_D4_Stim8hr_STAT2-2',
#  'CD4i_R2_D4_Stim8hr_STAT3-1',
#  'CD4i_R2_D4_Stim8hr_STAT3-2',
#  'CD4i_R2_D4_Stim8hr_STAT4-1',
#  'CD4i_R2_D4_Stim8hr_STAT4-2',
#  'CD4i_R2_D4_Stim8hr_STAT5A-1',
#  'CD4i_R2_D4_Stim8hr_STAT5A-2',
#  'CD4i_R2_D4_Stim8hr_STAT5B-1',
#  'CD4i_R2_D4_Stim8hr_STAT5B-2',
#  'CD4i_R2_D4_Stim8hr_STAT6-1',
#  'CD4i_R2_D4_Stim8hr_STAT6-2',
#  'CD4i_R2_D4_Stim8hr_STATH-1',
#  'CD4i_R2_D4_Stim8hr_STATH-2',
#  'CD4i_R2_D4_Stim8hr_STAU1-1',
#  'CD4i_R2_D4_Stim8hr_STAU1-2',
#  'CD4i_R2_D4_Stim8hr_STAU2-1',
#  'CD4i_R2_D4_Stim8hr_STAU2-2',
#  'CD4i_R2_D4_Stim8hr_STC2-1',
#  'CD4i_R2_D4_Stim8hr_STC2-2',
#  'CD4i_R2_D4_Stim8hr_STEAP4-1',
#  'CD4i_R2_D4_Stim8hr_STEAP4-2',
#  'CD4i_R2_D4_Stim8hr_STIL-1',
#  'CD4i_R2_D4_Stim8hr_STIL-2',
#  'CD4i_R2_D4_Stim8hr_STIM1-2',
#  'CD4i_R2_D4_Stim8hr_STIM2-1',
#  'CD4i_R2_D4_Stim8hr_STIM2-2',
#  'CD4i_R2_D4_Stim8hr_STIP1-1',
#  'CD4i_R2_D4_Stim8hr_STIP1-2',
#  'CD4i_R2_D4_Stim8hr_STK10-1',
#  'CD4i_R2_D4_Stim8hr_STK10-2',
#  'CD4i_R2_D4_Stim8hr_STK11-1',
#  'CD4i_R2_D4_Stim8hr_STK11-2',
#  'CD4i_R2_D4_Stim8hr_STK11IP-1',
#  'CD4i_R2_D4_Stim8hr_STK11IP-2',
#  'CD4i_R2_D4_Stim8hr_STK16-1',
#  'CD4i_R2_D4_Stim8hr_STK16-2',
#  'CD4i_R2_D4_Stim8hr_STK17A-1',
#  'CD4i_R2_D4_Stim8hr_STK17A-2',
#  'CD4i_R2_D4_Stim8hr_STK17B-1',
#  'CD4i_R2_D4_Stim8hr_STK17B-2',
#  'CD4i_R2_D4_Stim8hr_STK19-1',
#  'CD4i_R2_D4_Stim8hr_STK19-2',
#  'CD4i_R2_D4_Stim8hr_STK24-1',
#  'CD4i_R2_D4_Stim8hr_STK24-2',
#  'CD4i_R2_D4_Stim8hr_STK25-1',
#  'CD4i_R2_D4_Stim8hr_STK25-2',
#  'CD4i_R2_D4_Stim8hr_STK26-1',
#  'CD4i_R2_D4_Stim8hr_STK26-2',
#  'CD4i_R2_D4_Stim8hr_STK3-1',
#  'CD4i_R2_D4_Stim8hr_STK3-2',
#  'CD4i_R2_D4_Stim8hr_STK32C-1',
#  'CD4i_R2_D4_Stim8hr_STK32C-2',
#  'CD4i_R2_D4_Stim8hr_STK35-1',
#  'CD4i_R2_D4_Stim8hr_STK35-2',
#  'CD4i_R2_D4_Stim8hr_STK36-1',
#  'CD4i_R2_D4_Stim8hr_STK36-2',
#  'CD4i_R2_D4_Stim8hr_STK38-1',
#  'CD4i_R2_D4_Stim8hr_STK38-2',
#  'CD4i_R2_D4_Stim8hr_STK38L-1',
#  'CD4i_R2_D4_Stim8hr_STK38L-2',
#  'CD4i_R2_D4_Stim8hr_STK39-1',
#  'CD4i_R2_D4_Stim8hr_STK39-2',
#  'CD4i_R2_D4_Stim8hr_STK4-1',
#  'CD4i_R2_D4_Stim8hr_STK4-2',
#  'CD4i_R2_D4_Stim8hr_STK40-1',
#  'CD4i_R2_D4_Stim8hr_STK40-2',
#  'CD4i_R2_D4_Stim8hr_STMN1-1',
#  'CD4i_R2_D4_Stim8hr_STMN1-2',
#  'CD4i_R2_D4_Stim8hr_STMN3-1',
#  'CD4i_R2_D4_Stim8hr_STMN3-2',
#  'CD4i_R2_D4_Stim8hr_STMP1-1',
#  'CD4i_R2_D4_Stim8hr_STMP1-2',
#  'CD4i_R2_D4_Stim8hr_STN1-1',
#  'CD4i_R2_D4_Stim8hr_STN1-2',
#  'CD4i_R2_D4_Stim8hr_STOM-1',
#  'CD4i_R2_D4_Stim8hr_STOM-2',
#  'CD4i_R2_D4_Stim8hr_STOML1-1',
#  'CD4i_R2_D4_Stim8hr_STOML1-2',
#  'CD4i_R2_D4_Stim8hr_STOML2-1',
#  'CD4i_R2_D4_Stim8hr_STOML2-3',
#  'CD4i_R2_D4_Stim8hr_STON1-1',
#  'CD4i_R2_D4_Stim8hr_STON1-2',
#  'CD4i_R2_D4_Stim8hr_STON2-1',
#  'CD4i_R2_D4_Stim8hr_STON2-2',
#  'CD4i_R2_D4_Stim8hr_STOX1-1',
#  'CD4i_R2_D4_Stim8hr_STOX1-2',
#  'CD4i_R2_D4_Stim8hr_STPG1-1',
#  'CD4i_R2_D4_Stim8hr_STPG1-2',
#  'CD4i_R2_D4_Stim8hr_STRADA-1',
#  'CD4i_R2_D4_Stim8hr_STRADA-2',
#  'CD4i_R2_D4_Stim8hr_STRADB-1',
#  'CD4i_R2_D4_Stim8hr_STRADB-2',
#  'CD4i_R2_D4_Stim8hr_STRAP-1',
#  'CD4i_R2_D4_Stim8hr_STRAP-2',
#  'CD4i_R2_D4_Stim8hr_STRBP-1',
#  'CD4i_R2_D4_Stim8hr_STRBP-2',
#  'CD4i_R2_D4_Stim8hr_STRIP1-1',
#  'CD4i_R2_D4_Stim8hr_STRIP1-2',
#  'CD4i_R2_D4_Stim8hr_STRIP2-1',
#  'CD4i_R2_D4_Stim8hr_STRIP2-2',
#  'CD4i_R2_D4_Stim8hr_STRN-1',
#  'CD4i_R2_D4_Stim8hr_STRN-2',
#  'CD4i_R2_D4_Stim8hr_STRN3-1',
#  'CD4i_R2_D4_Stim8hr_STRN3-2',
#  'CD4i_R2_D4_Stim8hr_STRN4-1',
#  'CD4i_R2_D4_Stim8hr_STRN4-2',
#  'CD4i_R2_D4_Stim8hr_STS-1',
#  'CD4i_R2_D4_Stim8hr_STS-2',
#  'CD4i_R2_D4_Stim8hr_STT3A-1',
#  'CD4i_R2_D4_Stim8hr_STT3A-2',
#  'CD4i_R2_D4_Stim8hr_STT3B-1',
#  'CD4i_R2_D4_Stim8hr_STT3B-2',
#  'CD4i_R2_D4_Stim8hr_STUB1-1',
#  'CD4i_R2_D4_Stim8hr_STUB1-2',
#  'CD4i_R2_D4_Stim8hr_STUM-1',
#  'CD4i_R2_D4_Stim8hr_STUM-2',
#  'CD4i_R2_D4_Stim8hr_STX10-1',
#  'CD4i_R2_D4_Stim8hr_STX10-2',
#  'CD4i_R2_D4_Stim8hr_STX11-1',
#  'CD4i_R2_D4_Stim8hr_STX11-2',
#  'CD4i_R2_D4_Stim8hr_STX12-1',
#  'CD4i_R2_D4_Stim8hr_STX12-2',
#  'CD4i_R2_D4_Stim8hr_STX16-1',
#  'CD4i_R2_D4_Stim8hr_STX16-2',
#  'CD4i_R2_D4_Stim8hr_STX17-1',
#  'CD4i_R2_D4_Stim8hr_STX1A-1',
#  'CD4i_R2_D4_Stim8hr_STX1A-2',
#  'CD4i_R2_D4_Stim8hr_STX1B-1',
#  'CD4i_R2_D4_Stim8hr_STX1B-2',
#  'CD4i_R2_D4_Stim8hr_STX2-1',
#  'CD4i_R2_D4_Stim8hr_STX2-2',
#  'CD4i_R2_D4_Stim8hr_STX3-2',
#  'CD4i_R2_D4_Stim8hr_STX4-1',
#  'CD4i_R2_D4_Stim8hr_STX4-2',
#  'CD4i_R2_D4_Stim8hr_STX5-1',
#  'CD4i_R2_D4_Stim8hr_STX6-1',
#  'CD4i_R2_D4_Stim8hr_STX6-2',
#  'CD4i_R2_D4_Stim8hr_STX7-1',
#  'CD4i_R2_D4_Stim8hr_STX7-2',
#  'CD4i_R2_D4_Stim8hr_STX8-1',
#  'CD4i_R2_D4_Stim8hr_STX8-2',
#  'CD4i_R2_D4_Stim8hr_STXBP1-1',
#  'CD4i_R2_D4_Stim8hr_STXBP1-2',
#  'CD4i_R2_D4_Stim8hr_STXBP2-1',
#  'CD4i_R2_D4_Stim8hr_STXBP2-2',
#  'CD4i_R2_D4_Stim8hr_STXBP3-1',
#  'CD4i_R2_D4_Stim8hr_STXBP3-2',
#  'CD4i_R2_D4_Stim8hr_STXBP4-1',
#  'CD4i_R2_D4_Stim8hr_STXBP4-2',
#  'CD4i_R2_D4_Stim8hr_STXBP5-1',
#  'CD4i_R2_D4_Stim8hr_STXBP5-2',
#  'CD4i_R2_D4_Stim8hr_STYX-1',
#  'CD4i_R2_D4_Stim8hr_STYX-2',
#  'CD4i_R2_D4_Stim8hr_STYXL1-1',
#  'CD4i_R2_D4_Stim8hr_STYXL1-2',
#  'CD4i_R2_D4_Stim8hr_SUB1-1',
#  'CD4i_R2_D4_Stim8hr_SUB1-2',
#  'CD4i_R2_D4_Stim8hr_SUCLA2-1',
#  'CD4i_R2_D4_Stim8hr_SUCLA2-2',
#  'CD4i_R2_D4_Stim8hr_SUCLG1-1',
#  'CD4i_R2_D4_Stim8hr_SUCLG1-2',
#  'CD4i_R2_D4_Stim8hr_SUCLG2-1',
#  'CD4i_R2_D4_Stim8hr_SUCLG2-2',
#  'CD4i_R2_D4_Stim8hr_SUCO-1',
#  'CD4i_R2_D4_Stim8hr_SUCO-2',
#  'CD4i_R2_D4_Stim8hr_SUDS3-1',
#  'CD4i_R2_D4_Stim8hr_SUDS3-2',
#  'CD4i_R2_D4_Stim8hr_SUFU-1',
#  'CD4i_R2_D4_Stim8hr_SUFU-2',
#  'CD4i_R2_D4_Stim8hr_SUGP1-1',
#  'CD4i_R2_D4_Stim8hr_SUGP1-2',
#  'CD4i_R2_D4_Stim8hr_SUGP2-1',
#  'CD4i_R2_D4_Stim8hr_SUGP2-2',
#  'CD4i_R2_D4_Stim8hr_SUGT1-1',
#  'CD4i_R2_D4_Stim8hr_SUGT1-2',
#  'CD4i_R2_D4_Stim8hr_SULF2-1',
#  'CD4i_R2_D4_Stim8hr_SULF2-2',
#  'CD4i_R2_D4_Stim8hr_SULT1A1-1',
#  'CD4i_R2_D4_Stim8hr_SULT1A1-2',
#  'CD4i_R2_D4_Stim8hr_SULT1A3-1',
#  'CD4i_R2_D4_Stim8hr_SULT1A3-2',
#  'CD4i_R2_D4_Stim8hr_SULT1A4-1',
#  'CD4i_R2_D4_Stim8hr_SULT1A4-2',
#  'CD4i_R2_D4_Stim8hr_SULT1B1-1',
#  'CD4i_R2_D4_Stim8hr_SULT1B1-2',
#  'CD4i_R2_D4_Stim8hr_SUMF1-1',
#  'CD4i_R2_D4_Stim8hr_SUMF1-2',
#  'CD4i_R2_D4_Stim8hr_SUMF2-1',
#  'CD4i_R2_D4_Stim8hr_SUMF2-2',
#  'CD4i_R2_D4_Stim8hr_SUMO1-1',
#  'CD4i_R2_D4_Stim8hr_SUMO1-2',
#  'CD4i_R2_D4_Stim8hr_SUMO2-1',
#  'CD4i_R2_D4_Stim8hr_SUMO2-2',
#  'CD4i_R2_D4_Stim8hr_SUMO3-1',
#  'CD4i_R2_D4_Stim8hr_SUMO3-2',
#  'CD4i_R2_D4_Stim8hr_SUMO4-1',
#  'CD4i_R2_D4_Stim8hr_SUMO4-2',
#  'CD4i_R2_D4_Stim8hr_SUN1-1',
#  'CD4i_R2_D4_Stim8hr_SUN1-2',
#  'CD4i_R2_D4_Stim8hr_SUN2-1',
#  'CD4i_R2_D4_Stim8hr_SUN2-2',
#  'CD4i_R2_D4_Stim8hr_SUOX-1',
#  'CD4i_R2_D4_Stim8hr_SUOX-2',
#  'CD4i_R2_D4_Stim8hr_SUPT20H-1',
#  'CD4i_R2_D4_Stim8hr_SUPT20H-2',
#  'CD4i_R2_D4_Stim8hr_SUPT3H-1',
#  'CD4i_R2_D4_Stim8hr_SUPT3H-2',
#  'CD4i_R2_D4_Stim8hr_SUPT4H1-1',
#  'CD4i_R2_D4_Stim8hr_SUPT4H1-2',
#  'CD4i_R2_D4_Stim8hr_SUPT6H-2',
#  'CD4i_R2_D4_Stim8hr_SUPT7L-1',
#  'CD4i_R2_D4_Stim8hr_SUPT7L-2',
#  'CD4i_R2_D4_Stim8hr_SUPV3L1-1',
#  'CD4i_R2_D4_Stim8hr_SUPV3L1-2',
#  'CD4i_R2_D4_Stim8hr_SURF1-1',
#  'CD4i_R2_D4_Stim8hr_SURF1-2',
#  'CD4i_R2_D4_Stim8hr_SURF2-1',
#  'CD4i_R2_D4_Stim8hr_SURF2-2',
#  'CD4i_R2_D4_Stim8hr_SURF4-1',
#  'CD4i_R2_D4_Stim8hr_SURF4-2',
#  'CD4i_R2_D4_Stim8hr_SURF6-1',
#  'CD4i_R2_D4_Stim8hr_SURF6-2',
#  'CD4i_R2_D4_Stim8hr_SUSD1-1',
#  'CD4i_R2_D4_Stim8hr_SUSD1-2',
#  'CD4i_R2_D4_Stim8hr_SUSD3-1',
#  'CD4i_R2_D4_Stim8hr_SUSD3-2',
#  'CD4i_R2_D4_Stim8hr_SUSD4-1',
#  'CD4i_R2_D4_Stim8hr_SUSD4-2',
#  'CD4i_R2_D4_Stim8hr_SUSD6-1',
#  'CD4i_R2_D4_Stim8hr_SUSD6-2',
#  'CD4i_R2_D4_Stim8hr_SUV39H1-1',
#  'CD4i_R2_D4_Stim8hr_SUV39H1-2',
#  'CD4i_R2_D4_Stim8hr_SUV39H2-1',
#  'CD4i_R2_D4_Stim8hr_SUV39H2-2',
#  'CD4i_R2_D4_Stim8hr_SUZ12-1',
#  'CD4i_R2_D4_Stim8hr_SUZ12-2',
#  'CD4i_R2_D4_Stim8hr_SV2A-1',
#  'CD4i_R2_D4_Stim8hr_SV2A-2',
#  'CD4i_R2_D4_Stim8hr_SVBP-1',
#  'CD4i_R2_D4_Stim8hr_SVIL-1',
#  'CD4i_R2_D4_Stim8hr_SVIL-2',
#  'CD4i_R2_D4_Stim8hr_SVIP-1',
#  'CD4i_R2_D4_Stim8hr_SVIP-2',
#  'CD4i_R2_D4_Stim8hr_SWAP70-1',
#  'CD4i_R2_D4_Stim8hr_SWAP70-2',
#  'CD4i_R2_D4_Stim8hr_SWI5-1',
#  'CD4i_R2_D4_Stim8hr_SWSAP1-1',
#  'CD4i_R2_D4_Stim8hr_SWSAP1-2',
#  'CD4i_R2_D4_Stim8hr_SWT1-1',
#  'CD4i_R2_D4_Stim8hr_SWT1-2',
#  'CD4i_R2_D4_Stim8hr_SYAP1-1',
#  'CD4i_R2_D4_Stim8hr_SYCE1L-1',
#  'CD4i_R2_D4_Stim8hr_SYCE1L-2',
#  'CD4i_R2_D4_Stim8hr_SYCE2-1',
#  'CD4i_R2_D4_Stim8hr_SYCE2-2',
#  'CD4i_R2_D4_Stim8hr_SYCP2-1',
#  'CD4i_R2_D4_Stim8hr_SYCP2-2',
#  'CD4i_R2_D4_Stim8hr_SYDE2-1',
#  'CD4i_R2_D4_Stim8hr_SYDE2-2',
#  'CD4i_R2_D4_Stim8hr_SYF2-1',
#  'CD4i_R2_D4_Stim8hr_SYF2-2',
#  'CD4i_R2_D4_Stim8hr_SYK-1',
#  'CD4i_R2_D4_Stim8hr_SYK-2',
#  'CD4i_R2_D4_Stim8hr_SYMPK-2',
#  'CD4i_R2_D4_Stim8hr_SYNC-1',
#  'CD4i_R2_D4_Stim8hr_SYNC-2',
#  'CD4i_R2_D4_Stim8hr_SYNCRIP-1',
#  'CD4i_R2_D4_Stim8hr_SYNCRIP-2',
#  'CD4i_R2_D4_Stim8hr_SYNE1-1',
#  'CD4i_R2_D4_Stim8hr_SYNE1-2',
#  'CD4i_R2_D4_Stim8hr_SYNE2-1',
#  'CD4i_R2_D4_Stim8hr_SYNE2-2',
#  'CD4i_R2_D4_Stim8hr_SYNE3-1',
#  'CD4i_R2_D4_Stim8hr_SYNE3-2',
#  'CD4i_R2_D4_Stim8hr_SYNE4-1',
#  'CD4i_R2_D4_Stim8hr_SYNE4-2',
#  'CD4i_R2_D4_Stim8hr_SYNGAP1-1',
#  'CD4i_R2_D4_Stim8hr_SYNGAP1-2',
#  'CD4i_R2_D4_Stim8hr_SYNGR1-1',
#  'CD4i_R2_D4_Stim8hr_SYNGR1-2',
#  'CD4i_R2_D4_Stim8hr_SYNGR2-1',
#  'CD4i_R2_D4_Stim8hr_SYNGR2-2',
#  'CD4i_R2_D4_Stim8hr_SYNGR3-1',
#  'CD4i_R2_D4_Stim8hr_SYNGR3-2',
#  'CD4i_R2_D4_Stim8hr_SYNJ1-1',
#  'CD4i_R2_D4_Stim8hr_SYNJ1-2',
#  'CD4i_R2_D4_Stim8hr_SYNJ2-1',
#  'CD4i_R2_D4_Stim8hr_SYNJ2-2',
#  'CD4i_R2_D4_Stim8hr_SYNJ2BP-2',
#  'CD4i_R2_D4_Stim8hr_SYNJ2BP-COX16-1',
#  'CD4i_R2_D4_Stim8hr_SYNJ2BP-COX16-2',
#  'CD4i_R2_D4_Stim8hr_SYNM-1',
#  'CD4i_R2_D4_Stim8hr_SYNM-2',
#  'CD4i_R2_D4_Stim8hr_SYNRG-1',
#  'CD4i_R2_D4_Stim8hr_SYNRG-2',
#  'CD4i_R2_D4_Stim8hr_SYP-1',
#  'CD4i_R2_D4_Stim8hr_SYP-2',
#  'CD4i_R2_D4_Stim8hr_SYPL1-1',
#  'CD4i_R2_D4_Stim8hr_SYPL1-2',
#  'CD4i_R2_D4_Stim8hr_SYS1-2',
#  'CD4i_R2_D4_Stim8hr_SYT11-1',
#  'CD4i_R2_D4_Stim8hr_SYT11-2',
#  'CD4i_R2_D4_Stim8hr_SYTL1-1',
#  'CD4i_R2_D4_Stim8hr_SYTL1-2',
#  'CD4i_R2_D4_Stim8hr_SYTL2-1',
#  'CD4i_R2_D4_Stim8hr_SYTL2-2',
#  'CD4i_R2_D4_Stim8hr_SYTL3-1',
#  'CD4i_R2_D4_Stim8hr_SYTL3-2',
#  'CD4i_R2_D4_Stim8hr_SYVN1-1',
#  'CD4i_R2_D4_Stim8hr_SYVN1-2',
#  'CD4i_R2_D4_Stim8hr_SZRD1-1',
#  'CD4i_R2_D4_Stim8hr_SZRD1-2',
#  'CD4i_R2_D4_Stim8hr_SZT2-2',
#  'CD4i_R2_D4_Stim8hr_TAB1-1',
#  'CD4i_R2_D4_Stim8hr_TAB1-2',
#  'CD4i_R2_D4_Stim8hr_TAB2-1',
#  'CD4i_R2_D4_Stim8hr_TAB2-2',
#  'CD4i_R2_D4_Stim8hr_TAB3-1',
#  'CD4i_R2_D4_Stim8hr_TAB3-2',
#  'CD4i_R2_D4_Stim8hr_TAC4-1',
#  'CD4i_R2_D4_Stim8hr_TAC4-2',
#  'CD4i_R2_D4_Stim8hr_TACC1-1',
#  'CD4i_R2_D4_Stim8hr_TACC1-2',
#  'CD4i_R2_D4_Stim8hr_TACC2-1',
#  'CD4i_R2_D4_Stim8hr_TACC2-2',
#  'CD4i_R2_D4_Stim8hr_TACC3-2',
#  'CD4i_R2_D4_Stim8hr_TACO1-1',
#  'CD4i_R2_D4_Stim8hr_TACO1-2',
#  'CD4i_R2_D4_Stim8hr_TACR2-1',
#  'CD4i_R2_D4_Stim8hr_TACR2-2',
#  'CD4i_R2_D4_Stim8hr_TADA1-1',
#  'CD4i_R2_D4_Stim8hr_TADA1-3',
#  'CD4i_R2_D4_Stim8hr_TADA2A-1',
#  'CD4i_R2_D4_Stim8hr_TADA2A-2',
#  'CD4i_R2_D4_Stim8hr_TADA2B-1',
#  'CD4i_R2_D4_Stim8hr_TADA2B-2',
#  'CD4i_R2_D4_Stim8hr_TADA3-1',
#  'CD4i_R2_D4_Stim8hr_TADA3-2',
#  'CD4i_R2_D4_Stim8hr_TAF1-2',
#  'CD4i_R2_D4_Stim8hr_TAF11-1',
#  'CD4i_R2_D4_Stim8hr_TAF11-2',
#  'CD4i_R2_D4_Stim8hr_TAF12-1',
#  'CD4i_R2_D4_Stim8hr_TAF12-2',
#  'CD4i_R2_D4_Stim8hr_TAF13-1',
#  'CD4i_R2_D4_Stim8hr_TAF13-2',
#  'CD4i_R2_D4_Stim8hr_TAF15-1',
#  'CD4i_R2_D4_Stim8hr_TAF15-2',
#  'CD4i_R2_D4_Stim8hr_TAF1B-1',
#  'CD4i_R2_D4_Stim8hr_TAF1B-2',
#  'CD4i_R2_D4_Stim8hr_TAF1C-1',
#  'CD4i_R2_D4_Stim8hr_TAF1C-2',
#  'CD4i_R2_D4_Stim8hr_TAF1D-1',
#  'CD4i_R2_D4_Stim8hr_TAF1D-2',
#  'CD4i_R2_D4_Stim8hr_TAF2-1',
#  'CD4i_R2_D4_Stim8hr_TAF2-2',
#  'CD4i_R2_D4_Stim8hr_TAF3-1',
#  'CD4i_R2_D4_Stim8hr_TAF3-2',
#  'CD4i_R2_D4_Stim8hr_TAF4-1',
#  'CD4i_R2_D4_Stim8hr_TAF4-2',
#  'CD4i_R2_D4_Stim8hr_TAF4B-1',
#  'CD4i_R2_D4_Stim8hr_TAF4B-2',
#  'CD4i_R2_D4_Stim8hr_TAF5L-1',
#  'CD4i_R2_D4_Stim8hr_TAF5L-2',
#  'CD4i_R2_D4_Stim8hr_TAF6-1',
#  'CD4i_R2_D4_Stim8hr_TAF6-2',
#  'CD4i_R2_D4_Stim8hr_TAF6L-1',
#  'CD4i_R2_D4_Stim8hr_TAF6L-2',
#  'CD4i_R2_D4_Stim8hr_TAF7-1',
#  'CD4i_R2_D4_Stim8hr_TAF8-1',
#  'CD4i_R2_D4_Stim8hr_TAF9-1',
#  'CD4i_R2_D4_Stim8hr_TAF9-2',
#  'CD4i_R2_D4_Stim8hr_TAF9B-1',
#  'CD4i_R2_D4_Stim8hr_TAF9B-2',
#  'CD4i_R2_D4_Stim8hr_TAGAP-1',
#  'CD4i_R2_D4_Stim8hr_TAGAP-2',
#  'CD4i_R2_D4_Stim8hr_TAGLN-1',
#  'CD4i_R2_D4_Stim8hr_TAGLN-2',
#  'CD4i_R2_D4_Stim8hr_TAGLN2-2',
#  'CD4i_R2_D4_Stim8hr_TAGLN3-1',
#  'CD4i_R2_D4_Stim8hr_TAGLN3-2',
#  'CD4i_R2_D4_Stim8hr_TAL1-1',
#  'CD4i_R2_D4_Stim8hr_TAL1-2',
#  'CD4i_R2_D4_Stim8hr_TAL2-1',
#  'CD4i_R2_D4_Stim8hr_TAL2-2',
#  'CD4i_R2_D4_Stim8hr_TALDO1-1',
#  'CD4i_R2_D4_Stim8hr_TALDO1-2',
#  'CD4i_R2_D4_Stim8hr_TAMM41-1',
#  'CD4i_R2_D4_Stim8hr_TANC2-1',
#  'CD4i_R2_D4_Stim8hr_TANC2-2',
#  'CD4i_R2_D4_Stim8hr_TANGO2-1',
#  'CD4i_R2_D4_Stim8hr_TANGO2-2',
#  'CD4i_R2_D4_Stim8hr_TANGO6-1',
#  'CD4i_R2_D4_Stim8hr_TANGO6-2',
#  'CD4i_R2_D4_Stim8hr_TANK-1',
#  'CD4i_R2_D4_Stim8hr_TANK-2',
#  'CD4i_R2_D4_Stim8hr_TAOK1-1',
#  'CD4i_R2_D4_Stim8hr_TAOK1-2',
#  'CD4i_R2_D4_Stim8hr_TAOK2-1',
#  'CD4i_R2_D4_Stim8hr_TAOK2-2',
#  'CD4i_R2_D4_Stim8hr_TAOK3-1',
#  'CD4i_R2_D4_Stim8hr_TAOK3-2',
#  'CD4i_R2_D4_Stim8hr_TAP1-1',
#  'CD4i_R2_D4_Stim8hr_TAP1-2',
#  'CD4i_R2_D4_Stim8hr_TAP2-1',
#  'CD4i_R2_D4_Stim8hr_TAP2-2',
#  'CD4i_R2_D4_Stim8hr_TAPBP-1',
#  'CD4i_R2_D4_Stim8hr_TAPBP-2',
#  'CD4i_R2_D4_Stim8hr_TAPBPL-1',
#  'CD4i_R2_D4_Stim8hr_TAPBPL-2',
#  'CD4i_R2_D4_Stim8hr_TAPT1-1',
#  'CD4i_R2_D4_Stim8hr_TAPT1-2',
#  'CD4i_R2_D4_Stim8hr_TARBP1-1',
#  'CD4i_R2_D4_Stim8hr_TARBP1-2',
#  'CD4i_R2_D4_Stim8hr_TARBP2-1',
#  'CD4i_R2_D4_Stim8hr_TARBP2-2',
#  'CD4i_R2_D4_Stim8hr_TARDBP-1',
#  'CD4i_R2_D4_Stim8hr_TARDBP-2',
#  'CD4i_R2_D4_Stim8hr_TARS-1',
#  'CD4i_R2_D4_Stim8hr_TARS2-1',
#  'CD4i_R2_D4_Stim8hr_TARS2-2',
#  'CD4i_R2_D4_Stim8hr_TARSL2-1',
#  'CD4i_R2_D4_Stim8hr_TARSL2-2',
#  'CD4i_R2_D4_Stim8hr_TAS2R14-1',
#  'CD4i_R2_D4_Stim8hr_TAS2R14-2',
#  'CD4i_R2_D4_Stim8hr_TAS2R20-1',
#  'CD4i_R2_D4_Stim8hr_TAS2R20-2',
#  'CD4i_R2_D4_Stim8hr_TAS2R4-1',
#  'CD4i_R2_D4_Stim8hr_TAS2R4-2',
#  'CD4i_R2_D4_Stim8hr_TAS2R5-1',
#  'CD4i_R2_D4_Stim8hr_TAS2R5-2',
#  'CD4i_R2_D4_Stim8hr_TASP1-1',
#  'CD4i_R2_D4_Stim8hr_TASP1-2',
#  'CD4i_R2_D4_Stim8hr_TATDN1-1',
#  'CD4i_R2_D4_Stim8hr_TATDN1-2',
#  'CD4i_R2_D4_Stim8hr_TATDN2-1',
#  'CD4i_R2_D4_Stim8hr_TATDN2-2',
#  'CD4i_R2_D4_Stim8hr_TATDN3-1',
#  'CD4i_R2_D4_Stim8hr_TATDN3-2',
#  'CD4i_R2_D4_Stim8hr_TAX1BP1-1',
#  'CD4i_R2_D4_Stim8hr_TAX1BP1-2',
#  'CD4i_R2_D4_Stim8hr_TAX1BP3-1',
#  'CD4i_R2_D4_Stim8hr_TAX1BP3-2',
#  'CD4i_R2_D4_Stim8hr_TAZ-1',
#  'CD4i_R2_D4_Stim8hr_TAZ-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D1-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D1-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D10A-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D10A-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D10B-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D10B-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D10C-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D10C-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D13-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D13-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D14-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D14-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D15-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D15-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D16-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D16-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D17-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D17-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D19-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D19-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D2-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D2-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D20-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D20-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D22A-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D22A-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D22B-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D22B-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D23-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D23-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D24-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D24-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D25-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D25-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D2B-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D2B-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D31-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D31-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D32-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D32-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D3B-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D3L-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D3L-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D4-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D4-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D5-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D5-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D7-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D8-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D8-2',
#  'CD4i_R2_D4_Stim8hr_TBC1D9B-1',
#  'CD4i_R2_D4_Stim8hr_TBC1D9B-2',
#  'CD4i_R2_D4_Stim8hr_TBCA-1',
#  'CD4i_R2_D4_Stim8hr_TBCA-2',
#  'CD4i_R2_D4_Stim8hr_TBCB-1',
#  'CD4i_R2_D4_Stim8hr_TBCCD1-1',
#  'CD4i_R2_D4_Stim8hr_TBCCD1-2',
#  'CD4i_R2_D4_Stim8hr_TBCE-2',
#  'CD4i_R2_D4_Stim8hr_TBCEL-1',
#  'CD4i_R2_D4_Stim8hr_TBCEL-2',
#  'CD4i_R2_D4_Stim8hr_TBCK-1',
#  'CD4i_R2_D4_Stim8hr_TBCK-2',
#  'CD4i_R2_D4_Stim8hr_TBK1-1',
#  'CD4i_R2_D4_Stim8hr_TBK1-2',
#  'CD4i_R2_D4_Stim8hr_TBKBP1-1',
#  'CD4i_R2_D4_Stim8hr_TBKBP1-2',
#  'CD4i_R2_D4_Stim8hr_TBL1X-1',
#  'CD4i_R2_D4_Stim8hr_TBL1X-2',
#  'CD4i_R2_D4_Stim8hr_TBL1XR1-1',
#  'CD4i_R2_D4_Stim8hr_TBL1XR1-2',
#  'CD4i_R2_D4_Stim8hr_TBL2-1',
#  'CD4i_R2_D4_Stim8hr_TBL2-2',
#  'CD4i_R2_D4_Stim8hr_TBL3-1',
#  'CD4i_R2_D4_Stim8hr_TBL3-2',
#  'CD4i_R2_D4_Stim8hr_TBP-1',
#  'CD4i_R2_D4_Stim8hr_TBPL1-1',
#  'CD4i_R2_D4_Stim8hr_TBPL1-2',
#  'CD4i_R2_D4_Stim8hr_TBPL2-1',
#  'CD4i_R2_D4_Stim8hr_TBPL2-2',
#  'CD4i_R2_D4_Stim8hr_TBR1-1',
#  'CD4i_R2_D4_Stim8hr_TBR1-2',
#  'CD4i_R2_D4_Stim8hr_TBRG1-1',
#  'CD4i_R2_D4_Stim8hr_TBRG1-2',
#  'CD4i_R2_D4_Stim8hr_TBRG4-1',
#  'CD4i_R2_D4_Stim8hr_TBRG4-2',
#  'CD4i_R2_D4_Stim8hr_TBX1-1',
#  'CD4i_R2_D4_Stim8hr_TBX1-2',
#  'CD4i_R2_D4_Stim8hr_TBX10-2',
#  'CD4i_R2_D4_Stim8hr_TBX15-1',
#  'CD4i_R2_D4_Stim8hr_TBX15-2',
#  'CD4i_R2_D4_Stim8hr_TBX18-1',
#  'CD4i_R2_D4_Stim8hr_TBX18-2',
#  'CD4i_R2_D4_Stim8hr_TBX19-1',
#  'CD4i_R2_D4_Stim8hr_TBX19-2',
#  'CD4i_R2_D4_Stim8hr_TBX2-1',
#  'CD4i_R2_D4_Stim8hr_TBX2-2',
#  'CD4i_R2_D4_Stim8hr_TBX20-1',
#  'CD4i_R2_D4_Stim8hr_TBX20-2',
#  'CD4i_R2_D4_Stim8hr_TBX21-1',
#  'CD4i_R2_D4_Stim8hr_TBX21-2',
#  'CD4i_R2_D4_Stim8hr_TBX22-1',
#  'CD4i_R2_D4_Stim8hr_TBX22-2',
#  'CD4i_R2_D4_Stim8hr_TBX3-1',
#  'CD4i_R2_D4_Stim8hr_TBX4-1',
#  'CD4i_R2_D4_Stim8hr_TBX4-2',
#  'CD4i_R2_D4_Stim8hr_TBX5-1',
#  'CD4i_R2_D4_Stim8hr_TBX5-2',
#  'CD4i_R2_D4_Stim8hr_TBX6-1',
#  'CD4i_R2_D4_Stim8hr_TBX6-2',
#  'CD4i_R2_D4_Stim8hr_TBXA2R-1',
#  'CD4i_R2_D4_Stim8hr_TBXA2R-2',
#  'CD4i_R2_D4_Stim8hr_TBXAS1-1',
#  'CD4i_R2_D4_Stim8hr_TBXAS1-2',
#  'CD4i_R2_D4_Stim8hr_TC2N-1',
#  'CD4i_R2_D4_Stim8hr_TC2N-2',
#  'CD4i_R2_D4_Stim8hr_TCAF1-1',
#  'CD4i_R2_D4_Stim8hr_TCAF1-2',
#  'CD4i_R2_D4_Stim8hr_TCAF2-1',
#  'CD4i_R2_D4_Stim8hr_TCAF2-2',
#  'CD4i_R2_D4_Stim8hr_TCAIM-1',
#  'CD4i_R2_D4_Stim8hr_TCAIM-2',
#  'CD4i_R2_D4_Stim8hr_TCAP-1',
#  'CD4i_R2_D4_Stim8hr_TCAP-2',
#  'CD4i_R2_D4_Stim8hr_TCEA1-1',
#  'CD4i_R2_D4_Stim8hr_TCEA1-2',
#  'CD4i_R2_D4_Stim8hr_TCEA2-1',
#  'CD4i_R2_D4_Stim8hr_TCEA3-1',
#  'CD4i_R2_D4_Stim8hr_TCEA3-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL1-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL1-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL2-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL2-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL3-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL3-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL4-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL4-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL8-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL8-2',
#  'CD4i_R2_D4_Stim8hr_TCEAL9-1',
#  'CD4i_R2_D4_Stim8hr_TCEAL9-2',
#  'CD4i_R2_D4_Stim8hr_TCEANC-1',
#  'CD4i_R2_D4_Stim8hr_TCEANC-2',
#  'CD4i_R2_D4_Stim8hr_TCEANC2-1',
#  'CD4i_R2_D4_Stim8hr_TCEANC2-2',
#  'CD4i_R2_D4_Stim8hr_TCERG1-1',
#  'CD4i_R2_D4_Stim8hr_TCERG1-2',
#  'CD4i_R2_D4_Stim8hr_TCF12-1',
#  'CD4i_R2_D4_Stim8hr_TCF12-2',
#  'CD4i_R2_D4_Stim8hr_TCF15-1',
#  'CD4i_R2_D4_Stim8hr_TCF15-2',
#  'CD4i_R2_D4_Stim8hr_TCF19-1',
#  'CD4i_R2_D4_Stim8hr_TCF19-2',
#  'CD4i_R2_D4_Stim8hr_TCF20-1',
#  'CD4i_R2_D4_Stim8hr_TCF21-1',
#  'CD4i_R2_D4_Stim8hr_TCF21-2',
#  'CD4i_R2_D4_Stim8hr_TCF23-1',
#  'CD4i_R2_D4_Stim8hr_TCF23-2',
#  'CD4i_R2_D4_Stim8hr_TCF24-1',
#  'CD4i_R2_D4_Stim8hr_TCF24-2',
#  'CD4i_R2_D4_Stim8hr_TCF25-1',
#  'CD4i_R2_D4_Stim8hr_TCF25-2',
#  'CD4i_R2_D4_Stim8hr_TCF3-1',
#  'CD4i_R2_D4_Stim8hr_TCF3-2',
#  'CD4i_R2_D4_Stim8hr_TCF4-1',
#  'CD4i_R2_D4_Stim8hr_TCF4-2',
#  'CD4i_R2_D4_Stim8hr_TCF7-1',
#  'CD4i_R2_D4_Stim8hr_TCF7-2',
#  'CD4i_R2_D4_Stim8hr_TCF7L1-1',
#  'CD4i_R2_D4_Stim8hr_TCF7L1-2',
#  'CD4i_R2_D4_Stim8hr_TCF7L2-1',
#  'CD4i_R2_D4_Stim8hr_TCF7L2-2',
#  'CD4i_R2_D4_Stim8hr_TCFL5-1',
#  'CD4i_R2_D4_Stim8hr_TCFL5-2',
#  'CD4i_R2_D4_Stim8hr_TCHP-1',
#  'CD4i_R2_D4_Stim8hr_TCHP-2',
#  'CD4i_R2_D4_Stim8hr_TCIM-1',
#  'CD4i_R2_D4_Stim8hr_TCIM-2',
#  'CD4i_R2_D4_Stim8hr_TCIRG1-1',
#  'CD4i_R2_D4_Stim8hr_TCIRG1-2',
#  'CD4i_R2_D4_Stim8hr_TCL1A-1',
#  'CD4i_R2_D4_Stim8hr_TCL1A-2',
#  'CD4i_R2_D4_Stim8hr_TCOF1-1',
#  'CD4i_R2_D4_Stim8hr_TCP11L1-1',
#  'CD4i_R2_D4_Stim8hr_TCP11L1-2',
#  'CD4i_R2_D4_Stim8hr_TCP11L2-1',
#  'CD4i_R2_D4_Stim8hr_TCP11L2-2',
#  'CD4i_R2_D4_Stim8hr_TCTA-1',
#  'CD4i_R2_D4_Stim8hr_TCTA-2',
#  'CD4i_R2_D4_Stim8hr_TCTE3-1',
#  'CD4i_R2_D4_Stim8hr_TCTE3-2',
#  'CD4i_R2_D4_Stim8hr_TCTEX1D2-1',
#  'CD4i_R2_D4_Stim8hr_TCTEX1D2-2',
#  'CD4i_R2_D4_Stim8hr_TCTEX1D4-1',
#  'CD4i_R2_D4_Stim8hr_TCTEX1D4-2',
#  'CD4i_R2_D4_Stim8hr_TCTN1-1',
#  'CD4i_R2_D4_Stim8hr_TCTN1-2',
#  'CD4i_R2_D4_Stim8hr_TCTN2-1',
#  'CD4i_R2_D4_Stim8hr_TCTN2-2',
#  'CD4i_R2_D4_Stim8hr_TCTN3-1',
#  'CD4i_R2_D4_Stim8hr_TCTN3-2',
#  'CD4i_R2_D4_Stim8hr_TDG-1',
#  'CD4i_R2_D4_Stim8hr_TDG-2',
#  'CD4i_R2_D4_Stim8hr_TDP1-1',
#  'CD4i_R2_D4_Stim8hr_TDP1-2',
#  'CD4i_R2_D4_Stim8hr_TDP2-1',
#  'CD4i_R2_D4_Stim8hr_TDP2-2',
#  'CD4i_R2_D4_Stim8hr_TDRD3-1',
#  'CD4i_R2_D4_Stim8hr_TDRD3-2',
#  'CD4i_R2_D4_Stim8hr_TDRD7-1',
#  'CD4i_R2_D4_Stim8hr_TDRD7-2',
#  'CD4i_R2_D4_Stim8hr_TDRKH-1',
#  'CD4i_R2_D4_Stim8hr_TDRKH-2',
#  'CD4i_R2_D4_Stim8hr_TEAD1-1',
#  'CD4i_R2_D4_Stim8hr_TEAD1-2',
#  'CD4i_R2_D4_Stim8hr_TEAD2-1',
#  'CD4i_R2_D4_Stim8hr_TEAD2-2',
#  'CD4i_R2_D4_Stim8hr_TEAD3-1',
#  'CD4i_R2_D4_Stim8hr_TEAD3-2',
#  'CD4i_R2_D4_Stim8hr_TEAD4-1',
#  'CD4i_R2_D4_Stim8hr_TEAD4-2',
#  'CD4i_R2_D4_Stim8hr_TEC-1',
#  'CD4i_R2_D4_Stim8hr_TEC-2',
#  'CD4i_R2_D4_Stim8hr_TECPR1-1',
#  'CD4i_R2_D4_Stim8hr_TECPR1-2',
#  'CD4i_R2_D4_Stim8hr_TECPR2-1',
#  'CD4i_R2_D4_Stim8hr_TECPR2-2',
#  'CD4i_R2_D4_Stim8hr_TECR-1',
#  'CD4i_R2_D4_Stim8hr_TECR-2',
#  'CD4i_R2_D4_Stim8hr_TEDC1-1',
#  'CD4i_R2_D4_Stim8hr_TEDC1-2',
#  'CD4i_R2_D4_Stim8hr_TEDC2-1',
#  'CD4i_R2_D4_Stim8hr_TEDC2-2',
#  'CD4i_R2_D4_Stim8hr_TEF-1',
#  'CD4i_R2_D4_Stim8hr_TEF-2',
#  'CD4i_R2_D4_Stim8hr_TEFM-1',
#  'CD4i_R2_D4_Stim8hr_TEFM-2',
#  'CD4i_R2_D4_Stim8hr_TELO2-1',
#  'CD4i_R2_D4_Stim8hr_TELO2-2',
#  'CD4i_R2_D4_Stim8hr_TEN1-2',
#  'CD4i_R2_D4_Stim8hr_TENM1-1',
#  'CD4i_R2_D4_Stim8hr_TENM1-2',
#  'CD4i_R2_D4_Stim8hr_TENM4-1',
#  'CD4i_R2_D4_Stim8hr_TENM4-2',
#  'CD4i_R2_D4_Stim8hr_TENT2-1',
#  'CD4i_R2_D4_Stim8hr_TENT2-2',
#  'CD4i_R2_D4_Stim8hr_TENT4A-1',
#  'CD4i_R2_D4_Stim8hr_TENT4A-2',
#  'CD4i_R2_D4_Stim8hr_TENT4B-1',
#  'CD4i_R2_D4_Stim8hr_TENT4B-2',
#  'CD4i_R2_D4_Stim8hr_TENT5A-1',
#  'CD4i_R2_D4_Stim8hr_TENT5A-2',
#  'CD4i_R2_D4_Stim8hr_TENT5C-1',
#  'CD4i_R2_D4_Stim8hr_TENT5C-2',
#  'CD4i_R2_D4_Stim8hr_TEP1-1',
#  'CD4i_R2_D4_Stim8hr_TEP1-2',
#  'CD4i_R2_D4_Stim8hr_TEPSIN-1',
#  'CD4i_R2_D4_Stim8hr_TEPSIN-2',
#  'CD4i_R2_D4_Stim8hr_TERB1-1',
#  'CD4i_R2_D4_Stim8hr_TERB1-2',
#  'CD4i_R2_D4_Stim8hr_TERF1-1',
#  'CD4i_R2_D4_Stim8hr_TERF1-2',
#  'CD4i_R2_D4_Stim8hr_TERF2-2',
#  'CD4i_R2_D4_Stim8hr_TERF2IP-1',
#  'CD4i_R2_D4_Stim8hr_TERF2IP-2',
#  'CD4i_R2_D4_Stim8hr_TERT-1',
#  'CD4i_R2_D4_Stim8hr_TES-1',
#  'CD4i_R2_D4_Stim8hr_TES-2',
#  'CD4i_R2_D4_Stim8hr_TESC-1',
#  'CD4i_R2_D4_Stim8hr_TESC-2',
#  'CD4i_R2_D4_Stim8hr_TESK1-1',
#  'CD4i_R2_D4_Stim8hr_TESK1-2',
#  'CD4i_R2_D4_Stim8hr_TESK2-1',
#  'CD4i_R2_D4_Stim8hr_TESK2-2',
#  'CD4i_R2_D4_Stim8hr_TESMIN-1',
#  'CD4i_R2_D4_Stim8hr_TESMIN-2',
#  'CD4i_R2_D4_Stim8hr_TESPA1-1',
#  'CD4i_R2_D4_Stim8hr_TESPA1-2',
#  'CD4i_R2_D4_Stim8hr_TET1-1',
#  'CD4i_R2_D4_Stim8hr_TET1-2',
#  'CD4i_R2_D4_Stim8hr_TET2-1',
#  'CD4i_R2_D4_Stim8hr_TET2-2',
#  'CD4i_R2_D4_Stim8hr_TET3-1',
#  'CD4i_R2_D4_Stim8hr_TET3-2',
#  'CD4i_R2_D4_Stim8hr_TEX10-2',
#  'CD4i_R2_D4_Stim8hr_TEX12-1',
#  'CD4i_R2_D4_Stim8hr_TEX12-2',
#  'CD4i_R2_D4_Stim8hr_TEX2-1',
#  'CD4i_R2_D4_Stim8hr_TEX2-2',
#  'CD4i_R2_D4_Stim8hr_TEX22-1',
#  'CD4i_R2_D4_Stim8hr_TEX22-2',
#  'CD4i_R2_D4_Stim8hr_TEX261-1',
#  'CD4i_R2_D4_Stim8hr_TEX261-2',
#  'CD4i_R2_D4_Stim8hr_TEX264-1',
#  'CD4i_R2_D4_Stim8hr_TEX264-2',
#  'CD4i_R2_D4_Stim8hr_TEX30-1',
#  'CD4i_R2_D4_Stim8hr_TEX30-2',
#  'CD4i_R2_D4_Stim8hr_TEX45-1',
#  'CD4i_R2_D4_Stim8hr_TEX45-2',
#  'CD4i_R2_D4_Stim8hr_TF-1',
#  'CD4i_R2_D4_Stim8hr_TF-2',
#  'CD4i_R2_D4_Stim8hr_TFAM-1',
#  'CD4i_R2_D4_Stim8hr_TFAM-2',
#  'CD4i_R2_D4_Stim8hr_TFAP2A-1',
#  'CD4i_R2_D4_Stim8hr_TFAP2A-2',
#  'CD4i_R2_D4_Stim8hr_TFAP2B-1',
#  'CD4i_R2_D4_Stim8hr_TFAP2B-2',
#  'CD4i_R2_D4_Stim8hr_TFAP2C-1',
#  'CD4i_R2_D4_Stim8hr_TFAP2C-2',
#  'CD4i_R2_D4_Stim8hr_TFAP2D-1',
#  'CD4i_R2_D4_Stim8hr_TFAP2D-2',
#  'CD4i_R2_D4_Stim8hr_TFAP2E-1',
#  'CD4i_R2_D4_Stim8hr_TFAP2E-2',
#  'CD4i_R2_D4_Stim8hr_TFAP4-1',
#  'CD4i_R2_D4_Stim8hr_TFAP4-2',
#  'CD4i_R2_D4_Stim8hr_TFB1M-1',
#  'CD4i_R2_D4_Stim8hr_TFB1M-2',
#  'CD4i_R2_D4_Stim8hr_TFB2M-1',
#  'CD4i_R2_D4_Stim8hr_TFB2M-2',
#  'CD4i_R2_D4_Stim8hr_TFCP2-1',
#  'CD4i_R2_D4_Stim8hr_TFCP2-2',
#  'CD4i_R2_D4_Stim8hr_TFCP2L1-1',
#  'CD4i_R2_D4_Stim8hr_TFCP2L1-2',
#  'CD4i_R2_D4_Stim8hr_TFDP1-1',
#  'CD4i_R2_D4_Stim8hr_TFDP1-2',
#  'CD4i_R2_D4_Stim8hr_TFDP2-1',
#  'CD4i_R2_D4_Stim8hr_TFDP2-2',
#  'CD4i_R2_D4_Stim8hr_TFDP3-1',
#  'CD4i_R2_D4_Stim8hr_TFDP3-2',
#  'CD4i_R2_D4_Stim8hr_TFE3-1',
#  'CD4i_R2_D4_Stim8hr_TFE3-2',
#  'CD4i_R2_D4_Stim8hr_TFEB-1',
#  'CD4i_R2_D4_Stim8hr_TFEB-2',
#  'CD4i_R2_D4_Stim8hr_TFEC-1',
#  'CD4i_R2_D4_Stim8hr_TFEC-2',
#  'CD4i_R2_D4_Stim8hr_TFF3-1',
#  'CD4i_R2_D4_Stim8hr_TFF3-2',
#  'CD4i_R2_D4_Stim8hr_TFG-1',
#  'CD4i_R2_D4_Stim8hr_TFG-2',
#  'CD4i_R2_D4_Stim8hr_TFIP11-1',
#  'CD4i_R2_D4_Stim8hr_TFIP11-2',
#  'CD4i_R2_D4_Stim8hr_TFPI-1',
#  'CD4i_R2_D4_Stim8hr_TFPI-2',
#  'CD4i_R2_D4_Stim8hr_TFPT-1',
#  'CD4i_R2_D4_Stim8hr_TFPT-2',
#  'CD4i_R2_D4_Stim8hr_TFR2-1',
#  'CD4i_R2_D4_Stim8hr_TFR2-2',
#  'CD4i_R2_D4_Stim8hr_TFRC-1',
#  'CD4i_R2_D4_Stim8hr_TG-1',
#  'CD4i_R2_D4_Stim8hr_TG-2',
#  'CD4i_R2_D4_Stim8hr_TGDS-1',
#  'CD4i_R2_D4_Stim8hr_TGDS-2',
#  'CD4i_R2_D4_Stim8hr_TGFA-1',
#  'CD4i_R2_D4_Stim8hr_TGFA-2',
#  'CD4i_R2_D4_Stim8hr_TGFB1-1',
#  'CD4i_R2_D4_Stim8hr_TGFB1-2',
#  'CD4i_R2_D4_Stim8hr_TGFB3-1',
#  'CD4i_R2_D4_Stim8hr_TGFB3-2',
#  'CD4i_R2_D4_Stim8hr_TGFBI-1',
#  'CD4i_R2_D4_Stim8hr_TGFBI-2',
#  'CD4i_R2_D4_Stim8hr_TGFBR2-1',
#  'CD4i_R2_D4_Stim8hr_TGFBR2-2',
#  'CD4i_R2_D4_Stim8hr_TGFBR3-1',
#  'CD4i_R2_D4_Stim8hr_TGFBR3-2',
#  'CD4i_R2_D4_Stim8hr_TGFBRAP1-1',
#  'CD4i_R2_D4_Stim8hr_TGFBRAP1-2',
#  'CD4i_R2_D4_Stim8hr_TGIF1-1',
#  'CD4i_R2_D4_Stim8hr_TGIF1-2',
#  'CD4i_R2_D4_Stim8hr_TGIF2-1',
#  'CD4i_R2_D4_Stim8hr_TGIF2-2',
#  'CD4i_R2_D4_Stim8hr_TGIF2-RAB5IF-1',
#  'CD4i_R2_D4_Stim8hr_TGIF2-RAB5IF-2',
#  'CD4i_R2_D4_Stim8hr_TGIF2LX-1',
#  'CD4i_R2_D4_Stim8hr_TGIF2LX-2',
#  'CD4i_R2_D4_Stim8hr_TGIF2LY-1',
#  'CD4i_R2_D4_Stim8hr_TGIF2LY-2',
#  'CD4i_R2_D4_Stim8hr_TGM1-1',
#  'CD4i_R2_D4_Stim8hr_TGM1-2',
#  'CD4i_R2_D4_Stim8hr_TGOLN2-1',
#  'CD4i_R2_D4_Stim8hr_TGOLN2-2',
#  'CD4i_R2_D4_Stim8hr_TGS1-1',
#  'CD4i_R2_D4_Stim8hr_TGS1-2',
#  'CD4i_R2_D4_Stim8hr_THADA-1',
#  'CD4i_R2_D4_Stim8hr_THADA-2',
#  'CD4i_R2_D4_Stim8hr_THAP10-1',
#  'CD4i_R2_D4_Stim8hr_THAP10-2',
#  'CD4i_R2_D4_Stim8hr_THAP11-1',
#  'CD4i_R2_D4_Stim8hr_THAP11-2',
#  'CD4i_R2_D4_Stim8hr_THAP12-1',
#  'CD4i_R2_D4_Stim8hr_THAP12-2',
#  'CD4i_R2_D4_Stim8hr_THAP2-1',
#  'CD4i_R2_D4_Stim8hr_THAP2-2',
#  'CD4i_R2_D4_Stim8hr_THAP3-1',
#  'CD4i_R2_D4_Stim8hr_THAP3-2',
#  'CD4i_R2_D4_Stim8hr_THAP4-1',
#  'CD4i_R2_D4_Stim8hr_THAP4-2',
#  'CD4i_R2_D4_Stim8hr_THAP5-1',
#  'CD4i_R2_D4_Stim8hr_THAP5-2',
#  'CD4i_R2_D4_Stim8hr_THAP6-1',
#  'CD4i_R2_D4_Stim8hr_THAP6-2',
#  'CD4i_R2_D4_Stim8hr_THAP7-1',
#  'CD4i_R2_D4_Stim8hr_THAP7-2',
#  'CD4i_R2_D4_Stim8hr_THAP8-1',
#  'CD4i_R2_D4_Stim8hr_THAP8-2',
#  'CD4i_R2_D4_Stim8hr_THAP9-1',
#  'CD4i_R2_D4_Stim8hr_THAP9-2',
#  'CD4i_R2_D4_Stim8hr_THBS1-1',
#  'CD4i_R2_D4_Stim8hr_THBS1-2',
#  'CD4i_R2_D4_Stim8hr_THBS3-1',
#  'CD4i_R2_D4_Stim8hr_THBS3-2',
#  'CD4i_R2_D4_Stim8hr_THBS4-1',
#  'CD4i_R2_D4_Stim8hr_THBS4-2',
#  'CD4i_R2_D4_Stim8hr_THEM4-1',
#  'CD4i_R2_D4_Stim8hr_THEM4-2',
#  'CD4i_R2_D4_Stim8hr_THEM5-1',
#  'CD4i_R2_D4_Stim8hr_THEM5-2',
#  'CD4i_R2_D4_Stim8hr_THEM6-1',
#  'CD4i_R2_D4_Stim8hr_THEM6-2',
#  'CD4i_R2_D4_Stim8hr_THEMIS-1',
#  'CD4i_R2_D4_Stim8hr_THEMIS-2',
#  'CD4i_R2_D4_Stim8hr_THEMIS2-1',
#  'CD4i_R2_D4_Stim8hr_THEMIS2-2',
#  'CD4i_R2_D4_Stim8hr_THG1L-1',
#  'CD4i_R2_D4_Stim8hr_THG1L-2',
#  'CD4i_R2_D4_Stim8hr_THNSL1-1',
#  'CD4i_R2_D4_Stim8hr_THNSL1-2',
#  'CD4i_R2_D4_Stim8hr_THOC2-2',
#  'CD4i_R2_D4_Stim8hr_THOC6-1',
#  'CD4i_R2_D4_Stim8hr_THOC6-2',
#  'CD4i_R2_D4_Stim8hr_THOC7-1',
#  'CD4i_R2_D4_Stim8hr_THOC7-2',
#  'CD4i_R2_D4_Stim8hr_THOP1-1',
#  'CD4i_R2_D4_Stim8hr_THOP1-2',
#  'CD4i_R2_D4_Stim8hr_THRA-1',
#  'CD4i_R2_D4_Stim8hr_THRA-2',
#  'CD4i_R2_D4_Stim8hr_THRAP3-1',
#  'CD4i_R2_D4_Stim8hr_THRAP3-2',
#  'CD4i_R2_D4_Stim8hr_THRB-1',
#  'CD4i_R2_D4_Stim8hr_THRB-2',
#  'CD4i_R2_D4_Stim8hr_THTPA-1',
#  'CD4i_R2_D4_Stim8hr_THTPA-2',
#  'CD4i_R2_D4_Stim8hr_THUMPD1-1',
#  'CD4i_R2_D4_Stim8hr_THUMPD2-1',
#  'CD4i_R2_D4_Stim8hr_THUMPD2-2',
#  'CD4i_R2_D4_Stim8hr_THUMPD3-1',
#  'CD4i_R2_D4_Stim8hr_THUMPD3-2',
#  'CD4i_R2_D4_Stim8hr_THY1-1',
#  'CD4i_R2_D4_Stim8hr_THY1-2',
#  'CD4i_R2_D4_Stim8hr_THYN1-1',
#  'CD4i_R2_D4_Stim8hr_THYN1-2',
#  'CD4i_R2_D4_Stim8hr_TIA1-1',
#  'CD4i_R2_D4_Stim8hr_TIA1-2',
#  'CD4i_R2_D4_Stim8hr_TIAF1-1',
#  'CD4i_R2_D4_Stim8hr_TIAF1-2',
#  'CD4i_R2_D4_Stim8hr_TIAL1-1',
#  'CD4i_R2_D4_Stim8hr_TIAL1-2',
#  'CD4i_R2_D4_Stim8hr_TIAM1-1',
#  'CD4i_R2_D4_Stim8hr_TIAM1-2',
#  'CD4i_R2_D4_Stim8hr_TIAM2-1',
#  'CD4i_R2_D4_Stim8hr_TIAM2-2',
#  'CD4i_R2_D4_Stim8hr_TICAM1-1',
#  'CD4i_R2_D4_Stim8hr_TICAM1-2',
#  'CD4i_R2_D4_Stim8hr_TIFA-1',
#  'CD4i_R2_D4_Stim8hr_TIFA-2',
#  'CD4i_R2_D4_Stim8hr_TIGAR-1',
#  'CD4i_R2_D4_Stim8hr_TIGAR-2',
#  'CD4i_R2_D4_Stim8hr_TIGD1-1',
#  'CD4i_R2_D4_Stim8hr_TIGD1-2',
#  'CD4i_R2_D4_Stim8hr_TIGD2-1',
#  'CD4i_R2_D4_Stim8hr_TIGD2-2',
#  'CD4i_R2_D4_Stim8hr_TIGD3-1',
#  'CD4i_R2_D4_Stim8hr_TIGD3-2',
#  'CD4i_R2_D4_Stim8hr_TIGD4-1',
#  'CD4i_R2_D4_Stim8hr_TIGD4-2',
#  'CD4i_R2_D4_Stim8hr_TIGD5-1',
#  'CD4i_R2_D4_Stim8hr_TIGD5-2',
#  'CD4i_R2_D4_Stim8hr_TIGD6-1',
#  'CD4i_R2_D4_Stim8hr_TIGD6-2',
#  'CD4i_R2_D4_Stim8hr_TIGD7-1',
#  'CD4i_R2_D4_Stim8hr_TIGD7-2',
#  'CD4i_R2_D4_Stim8hr_TIGIT-1',
#  'CD4i_R2_D4_Stim8hr_TIGIT-2',
#  'CD4i_R2_D4_Stim8hr_TIMD4-1',
#  'CD4i_R2_D4_Stim8hr_TIMD4-2',
#  'CD4i_R2_D4_Stim8hr_TIMM10-1',
#  'CD4i_R2_D4_Stim8hr_TIMM10-2',
#  'CD4i_R2_D4_Stim8hr_TIMM10B-1',
#  'CD4i_R2_D4_Stim8hr_TIMM10B-2',
#  'CD4i_R2_D4_Stim8hr_TIMM13-1',
#  'CD4i_R2_D4_Stim8hr_TIMM13-2',
#  'CD4i_R2_D4_Stim8hr_TIMM17A-1',
#  'CD4i_R2_D4_Stim8hr_TIMM17A-2',
#  'CD4i_R2_D4_Stim8hr_TIMM17B-1',
#  'CD4i_R2_D4_Stim8hr_TIMM17B-2',
#  'CD4i_R2_D4_Stim8hr_TIMM21-1',
#  'CD4i_R2_D4_Stim8hr_TIMM21-2',
#  'CD4i_R2_D4_Stim8hr_TIMM22-1',
#  'CD4i_R2_D4_Stim8hr_TIMM22-2',
#  'CD4i_R2_D4_Stim8hr_TIMM23-1',
#  'CD4i_R2_D4_Stim8hr_TIMM23-2',
#  'CD4i_R2_D4_Stim8hr_TIMM29-1',
#  'CD4i_R2_D4_Stim8hr_TIMM29-2',
#  'CD4i_R2_D4_Stim8hr_TIMM44-1',
#  'CD4i_R2_D4_Stim8hr_TIMM44-2',
#  'CD4i_R2_D4_Stim8hr_TIMM50-1',
#  'CD4i_R2_D4_Stim8hr_TIMM50-2',
#  'CD4i_R2_D4_Stim8hr_TIMM8A-1',
#  'CD4i_R2_D4_Stim8hr_TIMM8A-2',
#  'CD4i_R2_D4_Stim8hr_TIMM8B-1',
#  'CD4i_R2_D4_Stim8hr_TIMM8B-2',
#  'CD4i_R2_D4_Stim8hr_TIMM9-1',
#  'CD4i_R2_D4_Stim8hr_TIMM9-2',
#  'CD4i_R2_D4_Stim8hr_TIMMDC1-1',
#  'CD4i_R2_D4_Stim8hr_TIMMDC1-2',
#  'CD4i_R2_D4_Stim8hr_TIMP1-1',
#  'CD4i_R2_D4_Stim8hr_TIMP1-2',
#  'CD4i_R2_D4_Stim8hr_TIMP2-1',
#  'CD4i_R2_D4_Stim8hr_TIMP2-2',
#  'CD4i_R2_D4_Stim8hr_TIMP3-1',
#  'CD4i_R2_D4_Stim8hr_TIMP3-2',
#  'CD4i_R2_D4_Stim8hr_TINF2-3',
#  'CD4i_R2_D4_Stim8hr_TIPARP-1',
#  'CD4i_R2_D4_Stim8hr_TIPARP-2',
#  'CD4i_R2_D4_Stim8hr_TIPIN-1',
#  'CD4i_R2_D4_Stim8hr_TIPIN-2',
#  'CD4i_R2_D4_Stim8hr_TIPRL-1',
#  'CD4i_R2_D4_Stim8hr_TIPRL-2',
#  'CD4i_R2_D4_Stim8hr_TIRAP-1',
#  'CD4i_R2_D4_Stim8hr_TIRAP-2',
#  'CD4i_R2_D4_Stim8hr_TJAP1-2',
#  'CD4i_R2_D4_Stim8hr_TJP2-1',
#  'CD4i_R2_D4_Stim8hr_TJP2-2',
#  'CD4i_R2_D4_Stim8hr_TJP3-1',
#  'CD4i_R2_D4_Stim8hr_TJP3-2',
#  'CD4i_R2_D4_Stim8hr_TK1-1',
#  'CD4i_R2_D4_Stim8hr_TK1-2',
#  'CD4i_R2_D4_Stim8hr_TK2-1',
#  'CD4i_R2_D4_Stim8hr_TK2-2',
#  'CD4i_R2_D4_Stim8hr_TKFC-1',
#  'CD4i_R2_D4_Stim8hr_TKFC-2',
#  'CD4i_R2_D4_Stim8hr_TKT-1',
#  'CD4i_R2_D4_Stim8hr_TKT-2',
#  'CD4i_R2_D4_Stim8hr_TKTL1-1',
#  'CD4i_R2_D4_Stim8hr_TKTL1-2',
#  'CD4i_R2_D4_Stim8hr_TLCD1-1',
#  'CD4i_R2_D4_Stim8hr_TLCD1-2',
#  'CD4i_R2_D4_Stim8hr_TLDC1-1',
#  'CD4i_R2_D4_Stim8hr_TLDC1-2',
#  'CD4i_R2_D4_Stim8hr_TLDC2-1',
#  'CD4i_R2_D4_Stim8hr_TLDC2-2',
#  'CD4i_R2_D4_Stim8hr_TLE1-1',
#  'CD4i_R2_D4_Stim8hr_TLE1-2',
#  'CD4i_R2_D4_Stim8hr_TLE2-1',
#  'CD4i_R2_D4_Stim8hr_TLE2-2',
#  'CD4i_R2_D4_Stim8hr_TLE3-1',
#  'CD4i_R2_D4_Stim8hr_TLE3-2',
#  'CD4i_R2_D4_Stim8hr_TLE4-1',
#  'CD4i_R2_D4_Stim8hr_TLE4-2',
#  'CD4i_R2_D4_Stim8hr_TLK1-1',
#  'CD4i_R2_D4_Stim8hr_TLK1-2',
#  'CD4i_R2_D4_Stim8hr_TLK2-1',
#  'CD4i_R2_D4_Stim8hr_TLK2-2',
#  'CD4i_R2_D4_Stim8hr_TLN1-1',
#  'CD4i_R2_D4_Stim8hr_TLN1-2',
#  'CD4i_R2_D4_Stim8hr_TLN2-1',
#  'CD4i_R2_D4_Stim8hr_TLN2-2',
#  'CD4i_R2_D4_Stim8hr_TLNRD1-1',
#  'CD4i_R2_D4_Stim8hr_TLNRD1-2',
#  'CD4i_R2_D4_Stim8hr_TLR1-2',
#  'CD4i_R2_D4_Stim8hr_TLR2-1',
#  'CD4i_R2_D4_Stim8hr_TLR2-2',
#  'CD4i_R2_D4_Stim8hr_TLR5-1',
#  'CD4i_R2_D4_Stim8hr_TLR5-2',
#  'CD4i_R2_D4_Stim8hr_TLR6-1',
#  'CD4i_R2_D4_Stim8hr_TLR6-2',
#  'CD4i_R2_D4_Stim8hr_TLX1-1',
#  'CD4i_R2_D4_Stim8hr_TLX1-2',
#  'CD4i_R2_D4_Stim8hr_TLX2-1',
#  'CD4i_R2_D4_Stim8hr_TLX2-2',
#  'CD4i_R2_D4_Stim8hr_TLX3-1',
#  'CD4i_R2_D4_Stim8hr_TLX3-2',
#  'CD4i_R2_D4_Stim8hr_TM2D1-1',
#  'CD4i_R2_D4_Stim8hr_TM2D1-2',
#  'CD4i_R2_D4_Stim8hr_TM2D2-1',
#  'CD4i_R2_D4_Stim8hr_TM2D2-2',
#  'CD4i_R2_D4_Stim8hr_TM2D3-1',
#  'CD4i_R2_D4_Stim8hr_TM2D3-2',
#  'CD4i_R2_D4_Stim8hr_TM4SF1-1',
#  'CD4i_R2_D4_Stim8hr_TM4SF1-2',
#  'CD4i_R2_D4_Stim8hr_TM6SF1-1',
#  'CD4i_R2_D4_Stim8hr_TM6SF1-2',
#  'CD4i_R2_D4_Stim8hr_TM7SF2-1',
#  'CD4i_R2_D4_Stim8hr_TM7SF2-2',
#  'CD4i_R2_D4_Stim8hr_TM7SF3-1',
#  'CD4i_R2_D4_Stim8hr_TM7SF3-2',
#  'CD4i_R2_D4_Stim8hr_TM9SF2-1',
#  'CD4i_R2_D4_Stim8hr_TM9SF2-2',
#  'CD4i_R2_D4_Stim8hr_TM9SF3-1',
#  'CD4i_R2_D4_Stim8hr_TM9SF3-2',
#  'CD4i_R2_D4_Stim8hr_TM9SF4-1',
#  'CD4i_R2_D4_Stim8hr_TM9SF4-2',
#  'CD4i_R2_D4_Stim8hr_TMA16-2',
#  'CD4i_R2_D4_Stim8hr_TMA7-1',
#  'CD4i_R2_D4_Stim8hr_TMA7-2',
#  'CD4i_R2_D4_Stim8hr_TMBIM1-1',
#  'CD4i_R2_D4_Stim8hr_TMBIM1-2',
#  'CD4i_R2_D4_Stim8hr_TMBIM4-1',
#  'CD4i_R2_D4_Stim8hr_TMBIM4-2',
#  'CD4i_R2_D4_Stim8hr_TMBIM6-1',
#  'CD4i_R2_D4_Stim8hr_TMBIM6-2',
#  'CD4i_R2_D4_Stim8hr_TMC5-1',
#  'CD4i_R2_D4_Stim8hr_TMC5-2',
#  'CD4i_R2_D4_Stim8hr_TMC6-1',
#  'CD4i_R2_D4_Stim8hr_TMC6-2',
#  'CD4i_R2_D4_Stim8hr_TMC8-1',
#  'CD4i_R2_D4_Stim8hr_TMC8-2',
#  'CD4i_R2_D4_Stim8hr_TMCC1-1',
#  'CD4i_R2_D4_Stim8hr_TMCC1-2',
#  'CD4i_R2_D4_Stim8hr_TMCC2-1',
#  'CD4i_R2_D4_Stim8hr_TMCC2-2',
#  'CD4i_R2_D4_Stim8hr_TMCC3-1',
#  'CD4i_R2_D4_Stim8hr_TMCC3-2',
#  'CD4i_R2_D4_Stim8hr_TMCO1-1',
#  'CD4i_R2_D4_Stim8hr_TMCO1-2',
#  'CD4i_R2_D4_Stim8hr_TMCO3-1',
#  'CD4i_R2_D4_Stim8hr_TMCO3-2',
#  'CD4i_R2_D4_Stim8hr_TMCO4-1',
#  'CD4i_R2_D4_Stim8hr_TMCO4-2',
#  'CD4i_R2_D4_Stim8hr_TMCO6-1',
#  'CD4i_R2_D4_Stim8hr_TMCO6-2',
#  'CD4i_R2_D4_Stim8hr_TMED1-1',
#  'CD4i_R2_D4_Stim8hr_TMED1-2',
#  'CD4i_R2_D4_Stim8hr_TMED10-1',
#  'CD4i_R2_D4_Stim8hr_TMED10-2',
#  'CD4i_R2_D4_Stim8hr_TMED2-1',
#  'CD4i_R2_D4_Stim8hr_TMED2-2',
#  'CD4i_R2_D4_Stim8hr_TMED3-1',
#  'CD4i_R2_D4_Stim8hr_TMED3-2',
#  'CD4i_R2_D4_Stim8hr_TMED4-1',
#  'CD4i_R2_D4_Stim8hr_TMED4-2',
#  'CD4i_R2_D4_Stim8hr_TMED5-1',
#  'CD4i_R2_D4_Stim8hr_TMED5-2',
#  'CD4i_R2_D4_Stim8hr_TMED6-1',
#  'CD4i_R2_D4_Stim8hr_TMED6-2',
#  'CD4i_R2_D4_Stim8hr_TMED7-1',
#  'CD4i_R2_D4_Stim8hr_TMED7-2',
#  'CD4i_R2_D4_Stim8hr_TMED8-1',
#  'CD4i_R2_D4_Stim8hr_TMED8-2',
#  'CD4i_R2_D4_Stim8hr_TMED9-1',
#  'CD4i_R2_D4_Stim8hr_TMED9-2',
#  'CD4i_R2_D4_Stim8hr_TMEM101-1',
#  'CD4i_R2_D4_Stim8hr_TMEM101-2',
#  'CD4i_R2_D4_Stim8hr_TMEM102-1',
#  'CD4i_R2_D4_Stim8hr_TMEM102-2',
#  'CD4i_R2_D4_Stim8hr_TMEM104-1',
#  'CD4i_R2_D4_Stim8hr_TMEM104-2',
#  'CD4i_R2_D4_Stim8hr_TMEM106A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM106A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM106B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM106B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM106C-1',
#  'CD4i_R2_D4_Stim8hr_TMEM106C-2',
#  'CD4i_R2_D4_Stim8hr_TMEM107-1',
#  'CD4i_R2_D4_Stim8hr_TMEM107-2',
#  'CD4i_R2_D4_Stim8hr_TMEM109-1',
#  'CD4i_R2_D4_Stim8hr_TMEM109-2',
#  'CD4i_R2_D4_Stim8hr_TMEM11-1',
#  'CD4i_R2_D4_Stim8hr_TMEM11-2',
#  'CD4i_R2_D4_Stim8hr_TMEM110-MUSTN1-1',
#  'CD4i_R2_D4_Stim8hr_TMEM110-MUSTN1-2',
#  'CD4i_R2_D4_Stim8hr_TMEM115-1',
#  'CD4i_R2_D4_Stim8hr_TMEM115-2',
#  'CD4i_R2_D4_Stim8hr_TMEM116-1',
#  'CD4i_R2_D4_Stim8hr_TMEM116-2',
#  'CD4i_R2_D4_Stim8hr_TMEM117-1',
#  'CD4i_R2_D4_Stim8hr_TMEM117-2',
#  'CD4i_R2_D4_Stim8hr_TMEM119-1',
#  'CD4i_R2_D4_Stim8hr_TMEM119-2',
#  'CD4i_R2_D4_Stim8hr_TMEM120A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM120A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM120B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM120B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM121-1',
#  'CD4i_R2_D4_Stim8hr_TMEM121-2',
#  'CD4i_R2_D4_Stim8hr_TMEM123-1',
#  'CD4i_R2_D4_Stim8hr_TMEM123-2',
#  'CD4i_R2_D4_Stim8hr_TMEM126A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM126A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM126B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM126B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM127-1',
#  'CD4i_R2_D4_Stim8hr_TMEM127-2',
#  'CD4i_R2_D4_Stim8hr_TMEM128-1',
#  'CD4i_R2_D4_Stim8hr_TMEM128-2',
#  'CD4i_R2_D4_Stim8hr_TMEM129-1',
#  'CD4i_R2_D4_Stim8hr_TMEM129-2',
#  'CD4i_R2_D4_Stim8hr_TMEM131-1',
#  'CD4i_R2_D4_Stim8hr_TMEM131-2',
#  'CD4i_R2_D4_Stim8hr_TMEM131L-1',
#  'CD4i_R2_D4_Stim8hr_TMEM131L-2',
#  'CD4i_R2_D4_Stim8hr_TMEM134-1',
#  'CD4i_R2_D4_Stim8hr_TMEM134-2',
#  'CD4i_R2_D4_Stim8hr_TMEM135-1',
#  'CD4i_R2_D4_Stim8hr_TMEM135-2',
#  'CD4i_R2_D4_Stim8hr_TMEM136-1',
#  'CD4i_R2_D4_Stim8hr_TMEM136-2',
#  'CD4i_R2_D4_Stim8hr_TMEM138-1',
#  'CD4i_R2_D4_Stim8hr_TMEM138-2',
#  'CD4i_R2_D4_Stim8hr_TMEM140-1',
#  'CD4i_R2_D4_Stim8hr_TMEM140-2',
#  'CD4i_R2_D4_Stim8hr_TMEM141-1',
#  'CD4i_R2_D4_Stim8hr_TMEM141-2',
#  'CD4i_R2_D4_Stim8hr_TMEM143-1',
#  'CD4i_R2_D4_Stim8hr_TMEM143-2',
#  'CD4i_R2_D4_Stim8hr_TMEM147-1',
#  'CD4i_R2_D4_Stim8hr_TMEM147-2',
#  'CD4i_R2_D4_Stim8hr_TMEM14A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM14A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM14B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM14B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM14C-1',
#  'CD4i_R2_D4_Stim8hr_TMEM14C-2',
#  'CD4i_R2_D4_Stim8hr_TMEM150A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM150A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM154-1',
#  'CD4i_R2_D4_Stim8hr_TMEM154-2',
#  'CD4i_R2_D4_Stim8hr_TMEM156-1',
#  'CD4i_R2_D4_Stim8hr_TMEM156-2',
#  'CD4i_R2_D4_Stim8hr_TMEM159-1',
#  'CD4i_R2_D4_Stim8hr_TMEM159-2',
#  'CD4i_R2_D4_Stim8hr_TMEM160-1',
#  'CD4i_R2_D4_Stim8hr_TMEM160-2',
#  'CD4i_R2_D4_Stim8hr_TMEM161A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM161A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM161B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM161B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM164-1',
#  'CD4i_R2_D4_Stim8hr_TMEM164-2',
#  'CD4i_R2_D4_Stim8hr_TMEM165-1',
#  'CD4i_R2_D4_Stim8hr_TMEM165-2',
#  'CD4i_R2_D4_Stim8hr_TMEM167A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM167A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM167B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM168-1',
#  'CD4i_R2_D4_Stim8hr_TMEM168-2',
#  'CD4i_R2_D4_Stim8hr_TMEM169-1',
#  'CD4i_R2_D4_Stim8hr_TMEM169-2',
#  'CD4i_R2_D4_Stim8hr_TMEM170A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM170A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM170B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM170B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM173-1',
#  'CD4i_R2_D4_Stim8hr_TMEM173-2',
#  'CD4i_R2_D4_Stim8hr_TMEM175-2',
#  'CD4i_R2_D4_Stim8hr_TMEM176B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM176B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM177-1',
#  'CD4i_R2_D4_Stim8hr_TMEM177-2',
#  'CD4i_R2_D4_Stim8hr_TMEM178B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM178B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM179B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM179B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM18-1',
#  'CD4i_R2_D4_Stim8hr_TMEM18-2',
#  'CD4i_R2_D4_Stim8hr_TMEM181-1',
#  'CD4i_R2_D4_Stim8hr_TMEM181-2',
#  'CD4i_R2_D4_Stim8hr_TMEM182-1',
#  'CD4i_R2_D4_Stim8hr_TMEM182-2',
#  'CD4i_R2_D4_Stim8hr_TMEM183A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM183A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM184B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM184B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM184C-1',
#  'CD4i_R2_D4_Stim8hr_TMEM184C-2',
#  'CD4i_R2_D4_Stim8hr_TMEM185A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM185A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM185B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM185B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM186-1',
#  'CD4i_R2_D4_Stim8hr_TMEM186-2',
#  'CD4i_R2_D4_Stim8hr_TMEM187-1',
#  'CD4i_R2_D4_Stim8hr_TMEM187-2',
#  'CD4i_R2_D4_Stim8hr_TMEM189-1',
#  'CD4i_R2_D4_Stim8hr_TMEM189-2',
#  'CD4i_R2_D4_Stim8hr_TMEM189-UBE2V1-2',
#  'CD4i_R2_D4_Stim8hr_TMEM19-1',
#  'CD4i_R2_D4_Stim8hr_TMEM19-2',
#  'CD4i_R2_D4_Stim8hr_TMEM191B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM191B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM192-1',
#  'CD4i_R2_D4_Stim8hr_TMEM199-1',
#  'CD4i_R2_D4_Stim8hr_TMEM199-2',
#  'CD4i_R2_D4_Stim8hr_TMEM200A-1',
#  'CD4i_R2_D4_Stim8hr_TMEM200A-2',
#  'CD4i_R2_D4_Stim8hr_TMEM201-1',
#  'CD4i_R2_D4_Stim8hr_TMEM201-2',
#  'CD4i_R2_D4_Stim8hr_TMEM203-1',
#  'CD4i_R2_D4_Stim8hr_TMEM203-2',
#  'CD4i_R2_D4_Stim8hr_TMEM204-1',
#  'CD4i_R2_D4_Stim8hr_TMEM204-2',
#  'CD4i_R2_D4_Stim8hr_TMEM205-1',
#  'CD4i_R2_D4_Stim8hr_TMEM205-2',
#  'CD4i_R2_D4_Stim8hr_TMEM206-1',
#  'CD4i_R2_D4_Stim8hr_TMEM206-2',
#  'CD4i_R2_D4_Stim8hr_TMEM208-1',
#  'CD4i_R2_D4_Stim8hr_TMEM208-2',
#  'CD4i_R2_D4_Stim8hr_TMEM209-1',
#  'CD4i_R2_D4_Stim8hr_TMEM209-2',
#  'CD4i_R2_D4_Stim8hr_TMEM214-1',
#  'CD4i_R2_D4_Stim8hr_TMEM214-2',
#  'CD4i_R2_D4_Stim8hr_TMEM216-1',
#  'CD4i_R2_D4_Stim8hr_TMEM216-2',
#  'CD4i_R2_D4_Stim8hr_TMEM217-1',
#  'CD4i_R2_D4_Stim8hr_TMEM217-2',
#  'CD4i_R2_D4_Stim8hr_TMEM218-1',
#  'CD4i_R2_D4_Stim8hr_TMEM218-2',
#  'CD4i_R2_D4_Stim8hr_TMEM219-1',
#  'CD4i_R2_D4_Stim8hr_TMEM219-2',
#  'CD4i_R2_D4_Stim8hr_TMEM220-1',
#  'CD4i_R2_D4_Stim8hr_TMEM220-2',
#  'CD4i_R2_D4_Stim8hr_TMEM222-1',
#  'CD4i_R2_D4_Stim8hr_TMEM222-2',
#  'CD4i_R2_D4_Stim8hr_TMEM223-1',
#  'CD4i_R2_D4_Stim8hr_TMEM223-2',
#  'CD4i_R2_D4_Stim8hr_TMEM229B-1',
#  'CD4i_R2_D4_Stim8hr_TMEM229B-2',
#  'CD4i_R2_D4_Stim8hr_TMEM230-1',
# ...
#  'CD4i_R2_D4_Stim8hr_ZNF584-1',
#  'CD4i_R2_D4_Stim8hr_ZNF584-2',
#  'CD4i_R2_D4_Stim8hr_ZNF585A-1',
#  'CD4i_R2_D4_Stim8hr_ZNF585A-2',
#  'CD4i_R2_D4_Stim8hr_ZNF585B-1',
#  'CD4i_R2_D4_Stim8hr_ZNF585B-2',
#  'CD4i_R2_D4_Stim8hr_ZNF586-1',
#  'CD4i_R2_D4_Stim8hr_ZNF586-2',
#  'CD4i_R2_D4_Stim8hr_ZNF587-1',
#  'CD4i_R2_D4_Stim8hr_ZNF587-2',
#  'CD4i_R2_D4_Stim8hr_ZNF587B-1',
#  'CD4i_R2_D4_Stim8hr_ZNF587B-2',
#  'CD4i_R2_D4_Stim8hr_ZNF589-1',
#  'CD4i_R2_D4_Stim8hr_ZNF589-2',
#  'CD4i_R2_D4_Stim8hr_ZNF592-1',
#  'CD4i_R2_D4_Stim8hr_ZNF592-2',
#  'CD4i_R2_D4_Stim8hr_ZNF593-1',
#  'CD4i_R2_D4_Stim8hr_ZNF593-2',
#  'CD4i_R2_D4_Stim8hr_ZNF594-1',
#  'CD4i_R2_D4_Stim8hr_ZNF594-2',
#  'CD4i_R2_D4_Stim8hr_ZNF595-1',
#  'CD4i_R2_D4_Stim8hr_ZNF595-2',
#  'CD4i_R2_D4_Stim8hr_ZNF596-1',
#  'CD4i_R2_D4_Stim8hr_ZNF596-2',
#  'CD4i_R2_D4_Stim8hr_ZNF597-2',
#  'CD4i_R2_D4_Stim8hr_ZNF598-1',
#  'CD4i_R2_D4_Stim8hr_ZNF598-2',
#  'CD4i_R2_D4_Stim8hr_ZNF599-1',
#  'CD4i_R2_D4_Stim8hr_ZNF599-2',
#  'CD4i_R2_D4_Stim8hr_ZNF600-1',
#  'CD4i_R2_D4_Stim8hr_ZNF600-2',
#  'CD4i_R2_D4_Stim8hr_ZNF605-1',
#  'CD4i_R2_D4_Stim8hr_ZNF605-2',
#  'CD4i_R2_D4_Stim8hr_ZNF606-1',
#  'CD4i_R2_D4_Stim8hr_ZNF606-2',
#  'CD4i_R2_D4_Stim8hr_ZNF607-1',
#  'CD4i_R2_D4_Stim8hr_ZNF607-2',
#  'CD4i_R2_D4_Stim8hr_ZNF608-1',
#  'CD4i_R2_D4_Stim8hr_ZNF608-2',
#  'CD4i_R2_D4_Stim8hr_ZNF609-1',
#  'CD4i_R2_D4_Stim8hr_ZNF609-2',
#  'CD4i_R2_D4_Stim8hr_ZNF610-1',
#  'CD4i_R2_D4_Stim8hr_ZNF610-2',
#  'CD4i_R2_D4_Stim8hr_ZNF611-1',
#  'CD4i_R2_D4_Stim8hr_ZNF611-2',
#  'CD4i_R2_D4_Stim8hr_ZNF613-1',
#  'CD4i_R2_D4_Stim8hr_ZNF613-2',
#  'CD4i_R2_D4_Stim8hr_ZNF614-1',
#  'CD4i_R2_D4_Stim8hr_ZNF614-2',
#  'CD4i_R2_D4_Stim8hr_ZNF615-1',
#  'CD4i_R2_D4_Stim8hr_ZNF615-2',
#  'CD4i_R2_D4_Stim8hr_ZNF616-1',
#  'CD4i_R2_D4_Stim8hr_ZNF616-2',
#  'CD4i_R2_D4_Stim8hr_ZNF618-1',
#  'CD4i_R2_D4_Stim8hr_ZNF618-2',
#  'CD4i_R2_D4_Stim8hr_ZNF619-1',
#  'CD4i_R2_D4_Stim8hr_ZNF619-2',
#  'CD4i_R2_D4_Stim8hr_ZNF620-1',
#  'CD4i_R2_D4_Stim8hr_ZNF620-2',
#  'CD4i_R2_D4_Stim8hr_ZNF621-1',
#  'CD4i_R2_D4_Stim8hr_ZNF621-2',
#  'CD4i_R2_D4_Stim8hr_ZNF622-1',
#  'CD4i_R2_D4_Stim8hr_ZNF622-2',
#  'CD4i_R2_D4_Stim8hr_ZNF623-1',
#  'CD4i_R2_D4_Stim8hr_ZNF623-2',
#  'CD4i_R2_D4_Stim8hr_ZNF624-1',
#  'CD4i_R2_D4_Stim8hr_ZNF624-2',
#  'CD4i_R2_D4_Stim8hr_ZNF625-1',
#  'CD4i_R2_D4_Stim8hr_ZNF626-1',
#  'CD4i_R2_D4_Stim8hr_ZNF626-2',
#  'CD4i_R2_D4_Stim8hr_ZNF627-1',
#  'CD4i_R2_D4_Stim8hr_ZNF627-2',
#  'CD4i_R2_D4_Stim8hr_ZNF628-1',
#  'CD4i_R2_D4_Stim8hr_ZNF628-2',
#  'CD4i_R2_D4_Stim8hr_ZNF629-1',
#  'CD4i_R2_D4_Stim8hr_ZNF629-2',
#  'CD4i_R2_D4_Stim8hr_ZNF630-1',
#  'CD4i_R2_D4_Stim8hr_ZNF630-2',
#  'CD4i_R2_D4_Stim8hr_ZNF638-1',
#  'CD4i_R2_D4_Stim8hr_ZNF638-2',
#  'CD4i_R2_D4_Stim8hr_ZNF639-1',
#  'CD4i_R2_D4_Stim8hr_ZNF639-2',
#  'CD4i_R2_D4_Stim8hr_ZNF641-1',
#  'CD4i_R2_D4_Stim8hr_ZNF641-2',
#  'CD4i_R2_D4_Stim8hr_ZNF644-1',
#  'CD4i_R2_D4_Stim8hr_ZNF644-2',
#  'CD4i_R2_D4_Stim8hr_ZNF646-1',
#  'CD4i_R2_D4_Stim8hr_ZNF646-2',
#  'CD4i_R2_D4_Stim8hr_ZNF648-1',
#  'CD4i_R2_D4_Stim8hr_ZNF648-2',
#  'CD4i_R2_D4_Stim8hr_ZNF649-1',
#  'CD4i_R2_D4_Stim8hr_ZNF649-2',
#  'CD4i_R2_D4_Stim8hr_ZNF652-1',
#  'CD4i_R2_D4_Stim8hr_ZNF652-2',
#  'CD4i_R2_D4_Stim8hr_ZNF653-1',
#  'CD4i_R2_D4_Stim8hr_ZNF653-2',
#  'CD4i_R2_D4_Stim8hr_ZNF654-1',
#  'CD4i_R2_D4_Stim8hr_ZNF654-2',
#  'CD4i_R2_D4_Stim8hr_ZNF655-1',
#  'CD4i_R2_D4_Stim8hr_ZNF655-2',
#  'CD4i_R2_D4_Stim8hr_ZNF658-1',
#  'CD4i_R2_D4_Stim8hr_ZNF658-2',
#  'CD4i_R2_D4_Stim8hr_ZNF660-1',
#  'CD4i_R2_D4_Stim8hr_ZNF660-2',
#  'CD4i_R2_D4_Stim8hr_ZNF662-1',
#  'CD4i_R2_D4_Stim8hr_ZNF662-2',
#  'CD4i_R2_D4_Stim8hr_ZNF664-1',
#  'CD4i_R2_D4_Stim8hr_ZNF664-2',
#  'CD4i_R2_D4_Stim8hr_ZNF665-1',
#  'CD4i_R2_D4_Stim8hr_ZNF665-2',
#  'CD4i_R2_D4_Stim8hr_ZNF667-1',
#  'CD4i_R2_D4_Stim8hr_ZNF667-2',
#  'CD4i_R2_D4_Stim8hr_ZNF668-1',
#  'CD4i_R2_D4_Stim8hr_ZNF668-2',
#  'CD4i_R2_D4_Stim8hr_ZNF669-1',
#  'CD4i_R2_D4_Stim8hr_ZNF669-2',
#  'CD4i_R2_D4_Stim8hr_ZNF670-1',
#  'CD4i_R2_D4_Stim8hr_ZNF670-2',
#  'CD4i_R2_D4_Stim8hr_ZNF671-1',
#  'CD4i_R2_D4_Stim8hr_ZNF671-2',
#  'CD4i_R2_D4_Stim8hr_ZNF672-1',
#  'CD4i_R2_D4_Stim8hr_ZNF672-2',
#  'CD4i_R2_D4_Stim8hr_ZNF674-1',
#  'CD4i_R2_D4_Stim8hr_ZNF674-2',
#  'CD4i_R2_D4_Stim8hr_ZNF675-1',
#  'CD4i_R2_D4_Stim8hr_ZNF675-2',
#  'CD4i_R2_D4_Stim8hr_ZNF676-1',
#  'CD4i_R2_D4_Stim8hr_ZNF676-2',
#  'CD4i_R2_D4_Stim8hr_ZNF677-1',
#  'CD4i_R2_D4_Stim8hr_ZNF677-2',
#  'CD4i_R2_D4_Stim8hr_ZNF678-1',
#  'CD4i_R2_D4_Stim8hr_ZNF678-2',
#  'CD4i_R2_D4_Stim8hr_ZNF679-1',
#  'CD4i_R2_D4_Stim8hr_ZNF679-2',
#  'CD4i_R2_D4_Stim8hr_ZNF680-1',
#  'CD4i_R2_D4_Stim8hr_ZNF680-2',
#  'CD4i_R2_D4_Stim8hr_ZNF681-1',
#  'CD4i_R2_D4_Stim8hr_ZNF681-2',
#  'CD4i_R2_D4_Stim8hr_ZNF682-1',
#  'CD4i_R2_D4_Stim8hr_ZNF682-2',
#  'CD4i_R2_D4_Stim8hr_ZNF683-1',
#  'CD4i_R2_D4_Stim8hr_ZNF683-2',
#  'CD4i_R2_D4_Stim8hr_ZNF684-1',
#  'CD4i_R2_D4_Stim8hr_ZNF684-2',
#  'CD4i_R2_D4_Stim8hr_ZNF687-1',
#  'CD4i_R2_D4_Stim8hr_ZNF687-2',
#  'CD4i_R2_D4_Stim8hr_ZNF688-1',
#  'CD4i_R2_D4_Stim8hr_ZNF688-2',
#  'CD4i_R2_D4_Stim8hr_ZNF689-1',
#  'CD4i_R2_D4_Stim8hr_ZNF689-2',
#  'CD4i_R2_D4_Stim8hr_ZNF69-1',
#  'CD4i_R2_D4_Stim8hr_ZNF69-2',
#  'CD4i_R2_D4_Stim8hr_ZNF691-1',
#  'CD4i_R2_D4_Stim8hr_ZNF691-2',
#  'CD4i_R2_D4_Stim8hr_ZNF692-1',
#  'CD4i_R2_D4_Stim8hr_ZNF692-2',
#  'CD4i_R2_D4_Stim8hr_ZNF695-1',
#  'CD4i_R2_D4_Stim8hr_ZNF695-2',
#  'CD4i_R2_D4_Stim8hr_ZNF696-1',
#  'CD4i_R2_D4_Stim8hr_ZNF696-2',
#  'CD4i_R2_D4_Stim8hr_ZNF697-1',
#  'CD4i_R2_D4_Stim8hr_ZNF697-2',
#  'CD4i_R2_D4_Stim8hr_ZNF699-1',
#  'CD4i_R2_D4_Stim8hr_ZNF699-2',
#  'CD4i_R2_D4_Stim8hr_ZNF7-1',
#  'CD4i_R2_D4_Stim8hr_ZNF7-2',
#  'CD4i_R2_D4_Stim8hr_ZNF70-1',
#  'CD4i_R2_D4_Stim8hr_ZNF70-2',
#  'CD4i_R2_D4_Stim8hr_ZNF700-1',
#  'CD4i_R2_D4_Stim8hr_ZNF701-1',
#  'CD4i_R2_D4_Stim8hr_ZNF701-2',
#  'CD4i_R2_D4_Stim8hr_ZNF703-1',
#  'CD4i_R2_D4_Stim8hr_ZNF703-2',
#  'CD4i_R2_D4_Stim8hr_ZNF704-1',
#  'CD4i_R2_D4_Stim8hr_ZNF704-2',
#  'CD4i_R2_D4_Stim8hr_ZNF705A-1',
#  'CD4i_R2_D4_Stim8hr_ZNF705A-2',
#  'CD4i_R2_D4_Stim8hr_ZNF705B-1',
#  'CD4i_R2_D4_Stim8hr_ZNF705B-2',
#  'CD4i_R2_D4_Stim8hr_ZNF705D-1',
#  'CD4i_R2_D4_Stim8hr_ZNF705D-2',
#  'CD4i_R2_D4_Stim8hr_ZNF705E-1',
#  'CD4i_R2_D4_Stim8hr_ZNF705E-2',
#  'CD4i_R2_D4_Stim8hr_ZNF705G-1',
#  'CD4i_R2_D4_Stim8hr_ZNF706-1',
#  'CD4i_R2_D4_Stim8hr_ZNF706-2',
#  'CD4i_R2_D4_Stim8hr_ZNF707-1',
#  'CD4i_R2_D4_Stim8hr_ZNF707-2',
#  'CD4i_R2_D4_Stim8hr_ZNF708-1',
#  'CD4i_R2_D4_Stim8hr_ZNF708-2',
#  'CD4i_R2_D4_Stim8hr_ZNF709-1',
#  'CD4i_R2_D4_Stim8hr_ZNF71-1',
#  'CD4i_R2_D4_Stim8hr_ZNF71-2',
#  'CD4i_R2_D4_Stim8hr_ZNF710-1',
#  'CD4i_R2_D4_Stim8hr_ZNF710-2',
#  'CD4i_R2_D4_Stim8hr_ZNF711-1',
#  'CD4i_R2_D4_Stim8hr_ZNF711-2',
#  'CD4i_R2_D4_Stim8hr_ZNF713-1',
#  'CD4i_R2_D4_Stim8hr_ZNF713-2',
#  'CD4i_R2_D4_Stim8hr_ZNF714-1',
#  'CD4i_R2_D4_Stim8hr_ZNF714-2',
#  'CD4i_R2_D4_Stim8hr_ZNF716-1',
#  'CD4i_R2_D4_Stim8hr_ZNF716-2',
#  'CD4i_R2_D4_Stim8hr_ZNF717-1',
#  'CD4i_R2_D4_Stim8hr_ZNF717-2',
#  'CD4i_R2_D4_Stim8hr_ZNF718-1',
#  'CD4i_R2_D4_Stim8hr_ZNF718-2',
#  'CD4i_R2_D4_Stim8hr_ZNF720-1',
#  'CD4i_R2_D4_Stim8hr_ZNF720-2',
#  'CD4i_R2_D4_Stim8hr_ZNF721-1',
#  'CD4i_R2_D4_Stim8hr_ZNF721-2',
#  'CD4i_R2_D4_Stim8hr_ZNF726-2',
#  'CD4i_R2_D4_Stim8hr_ZNF727-1',
#  'CD4i_R2_D4_Stim8hr_ZNF727-2',
#  'CD4i_R2_D4_Stim8hr_ZNF728-1',
#  'CD4i_R2_D4_Stim8hr_ZNF728-2',
#  'CD4i_R2_D4_Stim8hr_ZNF729-1',
#  'CD4i_R2_D4_Stim8hr_ZNF730-1',
#  'CD4i_R2_D4_Stim8hr_ZNF730-2',
#  'CD4i_R2_D4_Stim8hr_ZNF732-1',
#  'CD4i_R2_D4_Stim8hr_ZNF732-2',
#  'CD4i_R2_D4_Stim8hr_ZNF735-1',
#  'CD4i_R2_D4_Stim8hr_ZNF735-2',
#  'CD4i_R2_D4_Stim8hr_ZNF736-1',
#  'CD4i_R2_D4_Stim8hr_ZNF736-2',
#  'CD4i_R2_D4_Stim8hr_ZNF737-1',
#  'CD4i_R2_D4_Stim8hr_ZNF737-2',
#  'CD4i_R2_D4_Stim8hr_ZNF74-1',
#  'CD4i_R2_D4_Stim8hr_ZNF74-2',
#  'CD4i_R2_D4_Stim8hr_ZNF740-1',
#  'CD4i_R2_D4_Stim8hr_ZNF740-2',
#  'CD4i_R2_D4_Stim8hr_ZNF746-1',
#  'CD4i_R2_D4_Stim8hr_ZNF746-2',
#  'CD4i_R2_D4_Stim8hr_ZNF747-1',
#  'CD4i_R2_D4_Stim8hr_ZNF747-2',
#  'CD4i_R2_D4_Stim8hr_ZNF749-1',
#  'CD4i_R2_D4_Stim8hr_ZNF749-2',
#  'CD4i_R2_D4_Stim8hr_ZNF750-1',
#  'CD4i_R2_D4_Stim8hr_ZNF750-2',
#  'CD4i_R2_D4_Stim8hr_ZNF75A-1',
#  'CD4i_R2_D4_Stim8hr_ZNF75A-2',
#  'CD4i_R2_D4_Stim8hr_ZNF75D-1',
#  'CD4i_R2_D4_Stim8hr_ZNF75D-2',
#  'CD4i_R2_D4_Stim8hr_ZNF76-1',
#  'CD4i_R2_D4_Stim8hr_ZNF76-2',
#  'CD4i_R2_D4_Stim8hr_ZNF761-1',
#  'CD4i_R2_D4_Stim8hr_ZNF761-2',
#  'CD4i_R2_D4_Stim8hr_ZNF764-1',
#  'CD4i_R2_D4_Stim8hr_ZNF764-2',
#  'CD4i_R2_D4_Stim8hr_ZNF765-1',
#  'CD4i_R2_D4_Stim8hr_ZNF765-2',
#  'CD4i_R2_D4_Stim8hr_ZNF766-1',
#  'CD4i_R2_D4_Stim8hr_ZNF766-2',
#  'CD4i_R2_D4_Stim8hr_ZNF768-1',
#  'CD4i_R2_D4_Stim8hr_ZNF768-2',
#  'CD4i_R2_D4_Stim8hr_ZNF77-1',
#  'CD4i_R2_D4_Stim8hr_ZNF77-2',
#  'CD4i_R2_D4_Stim8hr_ZNF770-1',
#  'CD4i_R2_D4_Stim8hr_ZNF770-2',
#  'CD4i_R2_D4_Stim8hr_ZNF771-1',
#  'CD4i_R2_D4_Stim8hr_ZNF771-2',
#  'CD4i_R2_D4_Stim8hr_ZNF772-1',
#  'CD4i_R2_D4_Stim8hr_ZNF772-2',
#  'CD4i_R2_D4_Stim8hr_ZNF773-1',
#  'CD4i_R2_D4_Stim8hr_ZNF773-2',
#  'CD4i_R2_D4_Stim8hr_ZNF774-1',
#  'CD4i_R2_D4_Stim8hr_ZNF774-2',
#  'CD4i_R2_D4_Stim8hr_ZNF775-1',
#  'CD4i_R2_D4_Stim8hr_ZNF775-2',
#  'CD4i_R2_D4_Stim8hr_ZNF776-1',
#  'CD4i_R2_D4_Stim8hr_ZNF776-2',
#  'CD4i_R2_D4_Stim8hr_ZNF777-1',
#  'CD4i_R2_D4_Stim8hr_ZNF777-2',
#  'CD4i_R2_D4_Stim8hr_ZNF778-1',
#  'CD4i_R2_D4_Stim8hr_ZNF778-2',
#  'CD4i_R2_D4_Stim8hr_ZNF780A-1',
#  'CD4i_R2_D4_Stim8hr_ZNF780A-2',
#  'CD4i_R2_D4_Stim8hr_ZNF780B-1',
#  'CD4i_R2_D4_Stim8hr_ZNF780B-2',
#  'CD4i_R2_D4_Stim8hr_ZNF781-1',
#  'CD4i_R2_D4_Stim8hr_ZNF781-2',
#  'CD4i_R2_D4_Stim8hr_ZNF782-1',
#  'CD4i_R2_D4_Stim8hr_ZNF782-2',
#  'CD4i_R2_D4_Stim8hr_ZNF783-1',
#  'CD4i_R2_D4_Stim8hr_ZNF783-2',
#  'CD4i_R2_D4_Stim8hr_ZNF784-1',
#  'CD4i_R2_D4_Stim8hr_ZNF784-2',
#  'CD4i_R2_D4_Stim8hr_ZNF785-1',
#  'CD4i_R2_D4_Stim8hr_ZNF785-2',
#  'CD4i_R2_D4_Stim8hr_ZNF786-1',
#  'CD4i_R2_D4_Stim8hr_ZNF786-2',
#  'CD4i_R2_D4_Stim8hr_ZNF787-1',
#  'CD4i_R2_D4_Stim8hr_ZNF787-2',
#  'CD4i_R2_D4_Stim8hr_ZNF789-1',
#  'CD4i_R2_D4_Stim8hr_ZNF789-2',
#  'CD4i_R2_D4_Stim8hr_ZNF79-1',
#  'CD4i_R2_D4_Stim8hr_ZNF79-2',
#  'CD4i_R2_D4_Stim8hr_ZNF790-1',
#  'CD4i_R2_D4_Stim8hr_ZNF790-2',
#  'CD4i_R2_D4_Stim8hr_ZNF791-1',
#  'CD4i_R2_D4_Stim8hr_ZNF791-2',
#  'CD4i_R2_D4_Stim8hr_ZNF792-1',
#  'CD4i_R2_D4_Stim8hr_ZNF792-2',
#  'CD4i_R2_D4_Stim8hr_ZNF793-1',
#  'CD4i_R2_D4_Stim8hr_ZNF793-2',
#  'CD4i_R2_D4_Stim8hr_ZNF799-1',
#  'CD4i_R2_D4_Stim8hr_ZNF799-2',
#  'CD4i_R2_D4_Stim8hr_ZNF8-1',
#  'CD4i_R2_D4_Stim8hr_ZNF8-2',
#  'CD4i_R2_D4_Stim8hr_ZNF80-1',
#  'CD4i_R2_D4_Stim8hr_ZNF80-2',
#  'CD4i_R2_D4_Stim8hr_ZNF800-1',
#  'CD4i_R2_D4_Stim8hr_ZNF800-2',
#  'CD4i_R2_D4_Stim8hr_ZNF804A-1',
#  'CD4i_R2_D4_Stim8hr_ZNF804A-2',
#  'CD4i_R2_D4_Stim8hr_ZNF804B-1',
#  'CD4i_R2_D4_Stim8hr_ZNF804B-2',
#  'CD4i_R2_D4_Stim8hr_ZNF805-1',
#  'CD4i_R2_D4_Stim8hr_ZNF805-2',
#  'CD4i_R2_D4_Stim8hr_ZNF808-1',
#  'CD4i_R2_D4_Stim8hr_ZNF808-2',
#  'CD4i_R2_D4_Stim8hr_ZNF81-1',
#  'CD4i_R2_D4_Stim8hr_ZNF81-2',
#  'CD4i_R2_D4_Stim8hr_ZNF813-1',
#  'CD4i_R2_D4_Stim8hr_ZNF813-2',
#  'CD4i_R2_D4_Stim8hr_ZNF814-1',
#  'CD4i_R2_D4_Stim8hr_ZNF814-2',
#  'CD4i_R2_D4_Stim8hr_ZNF816-1',
#  'CD4i_R2_D4_Stim8hr_ZNF816-2',
#  'CD4i_R2_D4_Stim8hr_ZNF821-1',
#  'CD4i_R2_D4_Stim8hr_ZNF821-2',
#  'CD4i_R2_D4_Stim8hr_ZNF823-1',
#  'CD4i_R2_D4_Stim8hr_ZNF823-2',
#  'CD4i_R2_D4_Stim8hr_ZNF827-1',
#  'CD4i_R2_D4_Stim8hr_ZNF827-2',
#  'CD4i_R2_D4_Stim8hr_ZNF829-1',
#  'CD4i_R2_D4_Stim8hr_ZNF829-2',
#  'CD4i_R2_D4_Stim8hr_ZNF83-1',
#  'CD4i_R2_D4_Stim8hr_ZNF83-2',
#  'CD4i_R2_D4_Stim8hr_ZNF831-1',
#  'CD4i_R2_D4_Stim8hr_ZNF831-2',
#  'CD4i_R2_D4_Stim8hr_ZNF835-1',
#  'CD4i_R2_D4_Stim8hr_ZNF835-2',
#  'CD4i_R2_D4_Stim8hr_ZNF836-1',
#  'CD4i_R2_D4_Stim8hr_ZNF836-2',
#  'CD4i_R2_D4_Stim8hr_ZNF837-1',
#  'CD4i_R2_D4_Stim8hr_ZNF837-2',
#  'CD4i_R2_D4_Stim8hr_ZNF839-1',
#  'CD4i_R2_D4_Stim8hr_ZNF839-2',
#  'CD4i_R2_D4_Stim8hr_ZNF84-1',
#  'CD4i_R2_D4_Stim8hr_ZNF84-2',
#  'CD4i_R2_D4_Stim8hr_ZNF841-1',
#  'CD4i_R2_D4_Stim8hr_ZNF841-2',
#  'CD4i_R2_D4_Stim8hr_ZNF843-1',
#  'CD4i_R2_D4_Stim8hr_ZNF843-2',
#  'CD4i_R2_D4_Stim8hr_ZNF844-1',
#  'CD4i_R2_D4_Stim8hr_ZNF844-2',
#  'CD4i_R2_D4_Stim8hr_ZNF845-1',
#  'CD4i_R2_D4_Stim8hr_ZNF845-2',
#  'CD4i_R2_D4_Stim8hr_ZNF846-1',
#  'CD4i_R2_D4_Stim8hr_ZNF846-2',
#  'CD4i_R2_D4_Stim8hr_ZNF85-1',
#  'CD4i_R2_D4_Stim8hr_ZNF85-2',
#  'CD4i_R2_D4_Stim8hr_ZNF850-1',
#  'CD4i_R2_D4_Stim8hr_ZNF850-2',
#  'CD4i_R2_D4_Stim8hr_ZNF852-1',
#  'CD4i_R2_D4_Stim8hr_ZNF852-2',
#  'CD4i_R2_D4_Stim8hr_ZNF853-1',
#  'CD4i_R2_D4_Stim8hr_ZNF853-2',
#  'CD4i_R2_D4_Stim8hr_ZNF860-1',
#  'CD4i_R2_D4_Stim8hr_ZNF860-2',
#  'CD4i_R2_D4_Stim8hr_ZNF862-1',
#  'CD4i_R2_D4_Stim8hr_ZNF862-2',
#  'CD4i_R2_D4_Stim8hr_ZNF865-1',
#  'CD4i_R2_D4_Stim8hr_ZNF865-2',
#  'CD4i_R2_D4_Stim8hr_ZNF878-1',
#  'CD4i_R2_D4_Stim8hr_ZNF878-2',
#  'CD4i_R2_D4_Stim8hr_ZNF879-1',
#  'CD4i_R2_D4_Stim8hr_ZNF879-2',
#  'CD4i_R2_D4_Stim8hr_ZNF880-1',
#  'CD4i_R2_D4_Stim8hr_ZNF880-2',
#  'CD4i_R2_D4_Stim8hr_ZNF883-1',
#  'CD4i_R2_D4_Stim8hr_ZNF883-2',
#  'CD4i_R2_D4_Stim8hr_ZNF888-1',
#  'CD4i_R2_D4_Stim8hr_ZNF888-2',
#  'CD4i_R2_D4_Stim8hr_ZNF891-1',
#  'CD4i_R2_D4_Stim8hr_ZNF891-2',
#  'CD4i_R2_D4_Stim8hr_ZNF90-1',
#  'CD4i_R2_D4_Stim8hr_ZNF90-2',
#  'CD4i_R2_D4_Stim8hr_ZNF91-1',
#  'CD4i_R2_D4_Stim8hr_ZNF91-2',
#  'CD4i_R2_D4_Stim8hr_ZNF92-1',
#  'CD4i_R2_D4_Stim8hr_ZNF92-2',
#  'CD4i_R2_D4_Stim8hr_ZNF93-1',
#  'CD4i_R2_D4_Stim8hr_ZNF93-2',
#  'CD4i_R2_D4_Stim8hr_ZNF98-1',
#  'CD4i_R2_D4_Stim8hr_ZNF98-2',
#  'CD4i_R2_D4_Stim8hr_ZNF99-1',
#  'CD4i_R2_D4_Stim8hr_ZNF99-2',
#  'CD4i_R2_D4_Stim8hr_ZNFX1-1',
#  'CD4i_R2_D4_Stim8hr_ZNFX1-2',
#  'CD4i_R2_D4_Stim8hr_ZNHIT1-1',
#  'CD4i_R2_D4_Stim8hr_ZNHIT1-2',
#  'CD4i_R2_D4_Stim8hr_ZNHIT2-1',
#  'CD4i_R2_D4_Stim8hr_ZNHIT3-1',
#  'CD4i_R2_D4_Stim8hr_ZNHIT3-2',
#  'CD4i_R2_D4_Stim8hr_ZNHIT6-1',
#  'CD4i_R2_D4_Stim8hr_ZNHIT6-2',
#  'CD4i_R2_D4_Stim8hr_ZNRF1-1',
#  'CD4i_R2_D4_Stim8hr_ZNRF1-2',
#  'CD4i_R2_D4_Stim8hr_ZNRF2-1',
#  'CD4i_R2_D4_Stim8hr_ZNRF2-2',
#  'CD4i_R2_D4_Stim8hr_ZNRF3-1',
#  'CD4i_R2_D4_Stim8hr_ZNRF3-2',
#  'CD4i_R2_D4_Stim8hr_ZP3-1',
#  'CD4i_R2_D4_Stim8hr_ZP3-2',
#  'CD4i_R2_D4_Stim8hr_ZPR1-1',
#  'CD4i_R2_D4_Stim8hr_ZPR1-2',
#  'CD4i_R2_D4_Stim8hr_ZRANB1-1',
#  'CD4i_R2_D4_Stim8hr_ZRANB1-2',
#  'CD4i_R2_D4_Stim8hr_ZRANB2-1',
#  'CD4i_R2_D4_Stim8hr_ZRANB2-2',
#  'CD4i_R2_D4_Stim8hr_ZRANB3-1',
#  'CD4i_R2_D4_Stim8hr_ZRANB3-2',
#  'CD4i_R2_D4_Stim8hr_ZRSR2-1',
#  'CD4i_R2_D4_Stim8hr_ZRSR2-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN1-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN1-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN10-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN10-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN12-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN12-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN16-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN16-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN18-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN18-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN2-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN2-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN20-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN20-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN21-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN21-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN22-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN22-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN23-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN23-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN25-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN25-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN26-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN26-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN29-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN29-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN30-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN31-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN31-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN32-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN32-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN4-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN4-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN5A-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN5B-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN5B-2',
#  'CD4i_R2_D4_Stim8hr_ZSCAN9-1',
#  'CD4i_R2_D4_Stim8hr_ZSCAN9-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM1-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM1-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM3-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM3-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM4-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM4-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM5-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM5-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM6-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM6-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM7-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM7-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM8-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM8-2',
#  'CD4i_R2_D4_Stim8hr_ZSWIM9-1',
#  'CD4i_R2_D4_Stim8hr_ZSWIM9-2',
#  'CD4i_R2_D4_Stim8hr_ZUP1-1',
#  'CD4i_R2_D4_Stim8hr_ZUP1-2',
#  'CD4i_R2_D4_Stim8hr_ZW10-1',
#  'CD4i_R2_D4_Stim8hr_ZW10-2',
#  'CD4i_R2_D4_Stim8hr_ZWILCH-1',
#  'CD4i_R2_D4_Stim8hr_ZWINT-1',
#  'CD4i_R2_D4_Stim8hr_ZWINT-2',
#  'CD4i_R2_D4_Stim8hr_ZXDA-1',
#  'CD4i_R2_D4_Stim8hr_ZXDA-2',
#  'CD4i_R2_D4_Stim8hr_ZXDB-1',
#  'CD4i_R2_D4_Stim8hr_ZXDB-2',
#  'CD4i_R2_D4_Stim8hr_ZXDC-1',
#  'CD4i_R2_D4_Stim8hr_ZXDC-2',
#  'CD4i_R2_D4_Stim8hr_ZYG11B-1',
#  'CD4i_R2_D4_Stim8hr_ZYG11B-2',
#  'CD4i_R2_D4_Stim8hr_ZYX-2',
#  'CD4i_R2_D4_Stim8hr_ZYX-3',
#  'CD4i_R2_D4_Stim8hr_ZZEF1-1',
#  'CD4i_R2_D4_Stim8hr_ZZEF1-2'}
# --------------------------------------------------

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv",
    dest_path="/content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_guide_info.csv"
)
# read in the guide RNA info csv
guide_info_df = pd.read_csv("/content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_guide_info.csv")

guide_info_df = guide_info_df[['sgRNA', 'seq']]

guide_info_df['sgRNA'] = guide_info_df['sgRNA'].str.replace('1-Jun','JUN-1').str.replace('2-Jun','JUN-2')

guide_info_df = guide_info_df.rename(columns={'seq': 'guide_sequence', 'sgRNA':'guide_id'})

guide_info_df
# Out:
# File /content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_guide_info.csv already exists. Skipping download.
#         guide_id        guide_sequence
# 0        ARMC5-1  CTGCCTCGCGCAGCTCGCGG
# 1         DDB1-1  GGAGTTCGCTGCGCGCTGTT
# 2       FNDC10-1  TGCCCGCTCCCCGCGATCCC
# 3         RORC-1  TCTGTGGGGCCCTGTCCATG
# 4      SLC35F6-1  GAACAGCTGGTACTTGGTCC
# ...          ...                   ...
# 26499    NTC-988  TTTCAGGCTACGGGCGCGGG
# 26500    NTC-989  TTTCCCATGATCATTTAGTG
# 26501    NTC-990  TTTCGCCCAAGAGGCTTGGG
# 26502    NTC-991  TTTCGTGCCGATGTAACACA
# 26503    NTC-992  TTTGGGTTTATCCGCCCCCA
#
# [26504 rows x 2 columns]

# %%
print("Number of overlapping guides with cur_data:")
cur_data.adata.obs['guide_id'].isin(guide_info_df['guide_id'].to_list()).value_counts()
# Out:
# Number of overlapping guides with cur_data:
# guide_id
# True    278684
# Name: count, dtype: int64

# %%
# merge cur_data.adata.obs with guide_info_df
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='guide_id', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# Number of missing guide sequences: 0
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Add additional metadata

# %%
cur_data.adata.obs
# Out:
#        10xrun_id   donor_id culture_condition guide_id perturbed_gene_name  \
# 0        CD4i_R2  CE0008162          Stim48hr   A1BG-1                A1BG
# 1        CD4i_R2  CE0008162          Stim48hr   A1BG-2                A1BG
# 2        CD4i_R2  CE0008162          Stim48hr    A2M-1                 A2M
# 3        CD4i_R2  CE0008162          Stim48hr    A2M-2                 A2M
# 4        CD4i_R2  CE0008162          Stim48hr   AAAS-1                AAAS
# ...          ...        ...               ...      ...                 ...
# 278679   CD4i_R2  CE0006864              Rest    ZYX-1                 ZYX
# 278680   CD4i_R2  CE0006864              Rest    ZYX-2                 ZYX
# 278681   CD4i_R2  CE0006864              Rest    ZYX-3                 ZYX
# 278682   CD4i_R2  CE0006864              Rest  ZZEF1-1               ZZEF1
# 278683   CD4i_R2  CE0006864              Rest  ZZEF1-2               ZZEF1
#
#        perturbed_gene_id guide_type  n_cells  total_counts  keep_min_cells  \
# 0        ENSG00000121410  targeting     26.0      326500.0            True
# 1        ENSG00000121410  targeting    160.0     2313880.0            True
# 2        ENSG00000175899  targeting      1.0       23782.0           False
# 3        ENSG00000175899  targeting     22.0      330204.0            True
# 4        ENSG00000094914  targeting     95.0     1389867.0            True
# ...                  ...        ...      ...           ...             ...
# 278679   ENSG00000159840  targeting      1.0       11009.0           False
# 278680   ENSG00000159840  targeting     39.0      318693.0            True
# 278681   ENSG00000159840  targeting     31.0      247297.0            True
# 278682   ENSG00000074755  targeting    100.0     1050023.0            True
# 278683   ENSG00000074755  targeting     55.0      405467.0            True
#
#         keep_effective_guides  keep_total_counts  keep_for_DE  \
# 0                        True               True         True
# 1                        True               True         True
# 2                        True               True        False
# 3                        True               True         True
# 4                        True               True         True
# ...                       ...                ...          ...
# 278679                   True               True        False
# 278680                   True               True         True
# 278681                   True               True         True
# 278682                   True               True         True
# 278683                   True               True         True
#
#         keep_test_genes  log10_n_cells           perturbation_name  \
# 0                  True       1.414973  CD4i_R2_D1_Stim48hr_A1BG-1
# 1                  True       2.204120  CD4i_R2_D1_Stim48hr_A1BG-2
# 2                  True       0.000000   CD4i_R2_D1_Stim48hr_A2M-1
# 3                  True       1.342423   CD4i_R2_D1_Stim48hr_A2M-2
# 4                  True       1.977724  CD4i_R2_D1_Stim48hr_AAAS-1
# ...                 ...            ...                         ...
# 278679             True       0.000000       CD4i_R2_D4_Rest_ZYX-1
# 278680             True       1.591065       CD4i_R2_D4_Rest_ZYX-2
# 278681             True       1.491362       CD4i_R2_D4_Rest_ZYX-3
# 278682             True       2.000000     CD4i_R2_D4_Rest_ZZEF1-1
# 278683             True       1.740363     CD4i_R2_D4_Rest_ZZEF1-2
#
#               guide_sequence
# 0       GGACGGCATCTCGGCCCGCC
# 1       GGGTCCCTCGCAGCGCAGGA
# 2       CAGATGGATTGTAGGGAGTA
# 3       CCAGATGGATTGTAGGGAGT
# 4       GGGCTAGATTCGTATGCGGA
# ...                      ...
# 278679  GGAGGCGGCCACCCGAGACG
# 278680  GGACCGGGACGCAGAGTCTG
# 278681  GGCCGGAGCCGAGACCGAAA
# 278682  CGCCCGCCAGCTGCTGTCGG
# 278683  TGTCGGAGGTTGACAGGTCG
#
# [278684 rows x 17 columns]

# %%
# download the metadata file
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sample_metadata.suppl_table.csv",
    dest_path="/content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_sample_metadata.csv"
)

# read in the metadata file
metadata_df = pd.read_csv("/content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_sample_metadata.csv", index_col=0)

metadata_df = (
    metadata_df[['donor_id', 'age', 'sex', 'cell_sample_id']]
    .rename(columns={'age':'developmental_stage_label',
                     'sex':'sex_label'})
    .assign(
        developmental_stage_label='adult', # since all patients are adults (22-34 yo)
        sex_label=lambda x: x['sex_label'].str.lower(),
        cell_sample_id=lambda x: x['cell_sample_id'].str.split('_').str[2],
        biological_replicate=lambda x: x['cell_sample_id'] + '_' + x['donor_id']
    )
    .drop(columns=['cell_sample_id'])
    .drop_duplicates()
)

metadata_df
# Out:
# File /content/PerturbationCatalogue/data_exploration/Perturbseq/supplementary/zhu_2025_sample_metadata.csv already exists. Skipping download.
#     donor_id developmental_stage_label sex_label biological_replicate
# 0  CE0008162                     adult    female         D1_CE0008162
# 1  CE0010866                     adult    female         D2_CE0010866
# 4  CE0008678                     adult    female         D3_CE0008678
# 5  CE0006864                     adult      male         D4_CE0006864

# %%
cur_data.adata.obs = cur_data.adata.obs.merge(metadata_df, on='donor_id', how='left')
# Out:
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# change perturbed_gene_id from categorical to string
cur_data.adata.obs['perturbed_gene_id'] = cur_data.adata.obs['perturbed_gene_id'].astype(str)
cur_data.adata.obs['perturbed_gene_name'] = cur_data.adata.obs['perturbed_gene_name'].astype(str)

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isin(['NTC']), 'perturbed_gene_id'] = 'control_nontargeting'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin(['NTC']), 'perturbed_gene_name'] = 'control_nontargeting'

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_gene_id',
    input_column_type='ensembl_gene_id',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Missing Ensembl IDs: ['ENSG00000277796', 'SGK494', 'SEPT6', 'SMIM11B', 'AKAP2', 'ENSG00000255823', 'ENSG00000256618', 'OCLM', 'ENSG00000232196', 'ENSG00000182230', 'ENSG00000148362', 'U2AF1L5', 'ENSG00000203812']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000277796': 'ENSG00000293545', 'ENSG00000255823': nan, 'ENSG00000256618': nan, 'ENSG00000232196': nan, 'ENSG00000182230': nan, 'ENSG00000148362': 'ENSG00000310560', 'ENSG00000203812': 'ENSG00000288825'}
# --------------------------------------------------
# Successfully mapped 12731 out of 12731 Ensembl IDs.
# --------------------------------------------------
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
cur_data.adata.obs
# Out:
#         log10_n_cells developmental_stage_label perturbed_gene_id  \
# index
# 0            1.414973                     adult   ENSG00000121410
# 1            2.204120                     adult   ENSG00000121410
# 2            0.000000                     adult   ENSG00000175899
# 3            1.342423                     adult   ENSG00000175899
# 4            1.977724                     adult   ENSG00000094914
# ...               ...                       ...               ...
# 278679       0.000000                     adult   ENSG00000159840
# 278680       1.591065                     adult   ENSG00000159840
# 278681       1.491362                     adult   ENSG00000159840
# 278682       2.000000                     adult   ENSG00000074755
# 278683       1.740363                     adult   ENSG00000074755
#
#         keep_for_DE  keep_total_counts 10xrun_id perturbed_gene_name  \
# index
# 0              True               True   CD4i_R2                A1BG
# 1              True               True   CD4i_R2                A1BG
# 2             False               True   CD4i_R2                 A2M
# 3              True               True   CD4i_R2                 A2M
# 4              True               True   CD4i_R2                AAAS
# ...             ...                ...       ...                 ...
# 278679        False               True   CD4i_R2                 ZYX
# 278680         True               True   CD4i_R2                 ZYX
# 278681         True               True   CD4i_R2                 ZYX
# 278682         True               True   CD4i_R2               ZZEF1
# 278683         True               True   CD4i_R2               ZZEF1
#
#                  perturbation_name guide_id sex_label biological_replicate  \
# index
# 0       CD4i_R2_D1_Stim48hr_A1BG-1   A1BG-1    female         D1_CE0008162
# 1       CD4i_R2_D1_Stim48hr_A1BG-2   A1BG-2    female         D1_CE0008162
# 2        CD4i_R2_D1_Stim48hr_A2M-1    A2M-1    female         D1_CE0008162
# 3        CD4i_R2_D1_Stim48hr_A2M-2    A2M-2    female         D1_CE0008162
# 4       CD4i_R2_D1_Stim48hr_AAAS-1   AAAS-1    female         D1_CE0008162
# ...                            ...      ...       ...                  ...
# 278679       CD4i_R2_D4_Rest_ZYX-1    ZYX-1      male         D4_CE0006864
# 278680       CD4i_R2_D4_Rest_ZYX-2    ZYX-2      male         D4_CE0006864
# 278681       CD4i_R2_D4_Rest_ZYX-3    ZYX-3      male         D4_CE0006864
# 278682     CD4i_R2_D4_Rest_ZZEF1-1  ZZEF1-1      male         D4_CE0006864
# 278683     CD4i_R2_D4_Rest_ZZEF1-2  ZZEF1-2      male         D4_CE0006864
#
#         n_cells culture_condition  keep_test_genes  total_counts  \
# index
# 0          26.0          Stim48hr             True      326500.0
# 1         160.0          Stim48hr             True     2313880.0
# 2           1.0          Stim48hr             True       23782.0
# 3          22.0          Stim48hr             True      330204.0
# 4          95.0          Stim48hr             True     1389867.0
# ...         ...               ...              ...           ...
# 278679      1.0              Rest             True       11009.0
# 278680     39.0              Rest             True      318693.0
# 278681     31.0              Rest             True      247297.0
# 278682    100.0              Rest             True     1050023.0
# 278683     55.0              Rest             True      405467.0
#
#         keep_effective_guides   donor_id        guide_sequence guide_type  \
# index
# 0                        True  CE0008162  GGACGGCATCTCGGCCCGCC  targeting
# 1                        True  CE0008162  GGGTCCCTCGCAGCGCAGGA  targeting
# 2                        True  CE0008162  CAGATGGATTGTAGGGAGTA  targeting
# 3                        True  CE0008162  CCAGATGGATTGTAGGGAGT  targeting
# 4                        True  CE0008162  GGGCTAGATTCGTATGCGGA  targeting
# ...                       ...        ...                   ...        ...
# 278679                   True  CE0006864  GGAGGCGGCCACCCGAGACG  targeting
# 278680                   True  CE0006864  GGACCGGGACGCAGAGTCTG  targeting
# 278681                   True  CE0006864  GGCCGGAGCCGAGACCGAAA  targeting
# 278682                   True  CE0006864  CGCCCGCCAGCTGCTGTCGG  targeting
# 278683                   True  CE0006864  TGTCGGAGGTTGACAGGTCG  targeting
#
#         keep_min_cells perturbed_target_ensg perturbed_target_symbol  \
# index
# 0                 True       ENSG00000121410                    A1BG
# 1                 True       ENSG00000121410                    A1BG
# 2                False       ENSG00000175899                     A2M
# 3                 True       ENSG00000175899                     A2M
# 4                 True       ENSG00000094914                    AAAS
# ...                ...                   ...                     ...
# 278679           False       ENSG00000159840                     ZYX
# 278680            True       ENSG00000159840                     ZYX
# 278681            True       ENSG00000159840                     ZYX
# 278682            True       ENSG00000074755                   ZZEF1
# 278683            True       ENSG00000074755                   ZZEF1
#
#        perturbed_target_biotype      perturbed_target_coord  \
# index
# 0                protein_coding  chr19:58345178-58353492;-1
# 1                protein_coding  chr19:58345178-58353492;-1
# 2                protein_coding    chr12:9067664-9116229;-1
# 3                protein_coding    chr12:9067664-9116229;-1
# 4                protein_coding  chr12:53307456-53324864;-1
# ...                         ...                         ...
# 278679           protein_coding  chr7:143381295-143391111;1
# 278680           protein_coding  chr7:143381295-143391111;1
# 278681           protein_coding  chr7:143381295-143391111;1
# 278682           protein_coding    chr17:4004445-4143628;-1
# 278683           protein_coding    chr17:4004445-4143628;-1
#
#        perturbed_target_chromosome original_index
# index
# 0                               19              0
# 1                               19              1
# 2                               12              2
# 3                               12              3
# 4                               12              4
# ...                            ...            ...
# 278679                           7         278679
# 278680                           7         278680
# 278681                           7         278681
# 278682                          17         278682
# 278683                          17         278683
#
# [278684 rows x 26 columns]

# %% [markdown]
# # Manually replace some genes

# %%
# define genes to replace in the cur_data.adata.obs
genes_to_replace = cur_data.adata.obs[cur_data.adata.obs['perturbed_target_symbol'].isna()]['perturbed_gene_name'].drop_duplicates().to_list()
# define columns to replace
cols_to_replace = ['perturbed_target_ensg',	'perturbed_target_symbol',	'perturbed_target_biotype',	'perturbed_target_coord',	'perturbed_target_chromosome']
# define mapping dict for renaming columns in gene_ont for replacement
gene_ont_col_mapping = {
    'ensembl_gene_id':'perturbed_target_ensg',
    'gene_symbol':'perturbed_target_symbol',
    'biotype':'perturbed_target_biotype',
    'gene_coord':'perturbed_target_coord',
    'chromosome_name':'perturbed_target_chromosome'
}
# loop through genes and fill in the missing cols
for replacement_gene in genes_to_replace:
    if replacement_gene in cur_data.gene_ont['synonym'].values:
        # subset gene_ont and get values for replacement
        replacement = (
            cur_data.gene_ont.rename(columns=gene_ont_col_mapping)
            .loc[cur_data.gene_ont['synonym'].isin([replacement_gene]), cols_to_replace]
        )[cols_to_replace].values[0]
        # replace values in cur_data.adata.obs with the values from gene_ont
        cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin([replacement_gene]), cols_to_replace] = replacement
        print(f"Replaced {replacement_gene} with {replacement}")
    else:
        print(f"No replacement found for {replacement_gene}")
# Out:
# No replacement found for AKAP2
# No replacement found for CCL3L1
# No replacement found for FAM153B
# No replacement found for MTRNR2L1
# No replacement found for MTRNR2L4
# No replacement found for MTRNR2L8
# No replacement found for OCLM
# Replaced SEPT6 with ['ENSG00000125354' 'SEPTIN6' 'protein_coding'
#  'chrX:119615724-119693949;-1' 'X']
# Replaced SGK494 with ['ENSG00000167524' 'RSKR' 'protein_coding' 'chr17:28455752-28614197;-1'
#  '17']
# No replacement found for SMIM11B
# No replacement found for U2AF1L5

# %%
# replace non-mapped perturbed_target_symbol with original gene symbols
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_target_symbol'] = cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_gene_name'].values

# %%
# replace entries in perturbed_target_ensg that are not ENSEMBL ids with NA
cur_data.adata.obs.loc[(~cur_data.adata.obs['perturbed_target_ensg'].str.startswith('ENSG')) & (cur_data.adata.obs['perturbed_target_ensg'] != 'control_nontargeting'), 'perturbed_target_ensg'] = pd.NA

# %%
cur_data.adata.obs
# Out:
#         log10_n_cells developmental_stage_label perturbed_gene_id  \
# index
# 0            1.414973                     adult   ENSG00000121410
# 1            2.204120                     adult   ENSG00000121410
# 2            0.000000                     adult   ENSG00000175899
# 3            1.342423                     adult   ENSG00000175899
# 4            1.977724                     adult   ENSG00000094914
# ...               ...                       ...               ...
# 278679       0.000000                     adult   ENSG00000159840
# 278680       1.591065                     adult   ENSG00000159840
# 278681       1.491362                     adult   ENSG00000159840
# 278682       2.000000                     adult   ENSG00000074755
# 278683       1.740363                     adult   ENSG00000074755
#
#         keep_for_DE  keep_total_counts 10xrun_id perturbed_gene_name  \
# index
# 0              True               True   CD4i_R2                A1BG
# 1              True               True   CD4i_R2                A1BG
# 2             False               True   CD4i_R2                 A2M
# 3              True               True   CD4i_R2                 A2M
# 4              True               True   CD4i_R2                AAAS
# ...             ...                ...       ...                 ...
# 278679        False               True   CD4i_R2                 ZYX
# 278680         True               True   CD4i_R2                 ZYX
# 278681         True               True   CD4i_R2                 ZYX
# 278682         True               True   CD4i_R2               ZZEF1
# 278683         True               True   CD4i_R2               ZZEF1
#
#                  perturbation_name guide_id sex_label biological_replicate  \
# index
# 0       CD4i_R2_D1_Stim48hr_A1BG-1   A1BG-1    female         D1_CE0008162
# 1       CD4i_R2_D1_Stim48hr_A1BG-2   A1BG-2    female         D1_CE0008162
# 2        CD4i_R2_D1_Stim48hr_A2M-1    A2M-1    female         D1_CE0008162
# 3        CD4i_R2_D1_Stim48hr_A2M-2    A2M-2    female         D1_CE0008162
# 4       CD4i_R2_D1_Stim48hr_AAAS-1   AAAS-1    female         D1_CE0008162
# ...                            ...      ...       ...                  ...
# 278679       CD4i_R2_D4_Rest_ZYX-1    ZYX-1      male         D4_CE0006864
# 278680       CD4i_R2_D4_Rest_ZYX-2    ZYX-2      male         D4_CE0006864
# 278681       CD4i_R2_D4_Rest_ZYX-3    ZYX-3      male         D4_CE0006864
# 278682     CD4i_R2_D4_Rest_ZZEF1-1  ZZEF1-1      male         D4_CE0006864
# 278683     CD4i_R2_D4_Rest_ZZEF1-2  ZZEF1-2      male         D4_CE0006864
#
#         n_cells culture_condition  keep_test_genes  total_counts  \
# index
# 0          26.0          Stim48hr             True      326500.0
# 1         160.0          Stim48hr             True     2313880.0
# 2           1.0          Stim48hr             True       23782.0
# 3          22.0          Stim48hr             True      330204.0
# 4          95.0          Stim48hr             True     1389867.0
# ...         ...               ...              ...           ...
# 278679      1.0              Rest             True       11009.0
# 278680     39.0              Rest             True      318693.0
# 278681     31.0              Rest             True      247297.0
# 278682    100.0              Rest             True     1050023.0
# 278683     55.0              Rest             True      405467.0
#
#         keep_effective_guides   donor_id        guide_sequence guide_type  \
# index
# 0                        True  CE0008162  GGACGGCATCTCGGCCCGCC  targeting
# 1                        True  CE0008162  GGGTCCCTCGCAGCGCAGGA  targeting
# 2                        True  CE0008162  CAGATGGATTGTAGGGAGTA  targeting
# 3                        True  CE0008162  CCAGATGGATTGTAGGGAGT  targeting
# 4                        True  CE0008162  GGGCTAGATTCGTATGCGGA  targeting
# ...                       ...        ...                   ...        ...
# 278679                   True  CE0006864  GGAGGCGGCCACCCGAGACG  targeting
# 278680                   True  CE0006864  GGACCGGGACGCAGAGTCTG  targeting
# 278681                   True  CE0006864  GGCCGGAGCCGAGACCGAAA  targeting
# 278682                   True  CE0006864  CGCCCGCCAGCTGCTGTCGG  targeting
# 278683                   True  CE0006864  TGTCGGAGGTTGACAGGTCG  targeting
#
#         keep_min_cells perturbed_target_ensg perturbed_target_symbol  \
# index
# 0                 True       ENSG00000121410                    A1BG
# 1                 True       ENSG00000121410                    A1BG
# 2                False       ENSG00000175899                     A2M
# 3                 True       ENSG00000175899                     A2M
# 4                 True       ENSG00000094914                    AAAS
# ...                ...                   ...                     ...
# 278679           False       ENSG00000159840                     ZYX
# 278680            True       ENSG00000159840                     ZYX
# 278681            True       ENSG00000159840                     ZYX
# 278682            True       ENSG00000074755                   ZZEF1
# 278683            True       ENSG00000074755                   ZZEF1
#
#        perturbed_target_biotype      perturbed_target_coord  \
# index
# 0                protein_coding  chr19:58345178-58353492;-1
# 1                protein_coding  chr19:58345178-58353492;-1
# 2                protein_coding    chr12:9067664-9116229;-1
# 3                protein_coding    chr12:9067664-9116229;-1
# 4                protein_coding  chr12:53307456-53324864;-1
# ...                         ...                         ...
# 278679           protein_coding  chr7:143381295-143391111;1
# 278680           protein_coding  chr7:143381295-143391111;1
# 278681           protein_coding  chr7:143381295-143391111;1
# 278682           protein_coding    chr17:4004445-4143628;-1
# 278683           protein_coding    chr17:4004445-4143628;-1
#
#        perturbed_target_chromosome original_index
# index
# 0                               19              0
# 1                               19              1
# 2                               12              2
# 3                               12              3
# 4                               12              4
# ...                            ...            ...
# 278679                           7         278679
# 278680                           7         278680
# 278681                           7         278681
# 278682                          17         278682
# 278683                          17         278683
#
# [278684 rows x 26 columns]

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
# cur_data.count_entries(
#     slot='obs',
#     input_column='perturbed_target_ensg',
#     count_column_name='perturbed_target_number',
#     sep='|'
# )
cur_data.adata.obs['perturbed_target_number'] = 1

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.show_obs(['perturbation_name', 'perturbed_target_chromosome_encoding'])
# Out:
# Observation data:
# DataFrame shape: (278684, 2)
# --------------------------------------------------
#                  perturbation_name  perturbed_target_chromosome_encoding
# index
# 0       CD4i_R2_D1_Stim48hr_A1BG-1                                    19
# 1       CD4i_R2_D1_Stim48hr_A1BG-2                                    19
# 2        CD4i_R2_D1_Stim48hr_A2M-1                                    12
# 3        CD4i_R2_D1_Stim48hr_A2M-2                                    12
# 4       CD4i_R2_D1_Stim48hr_AAAS-1                                    12
# ...                            ...                                   ...
# 278679       CD4i_R2_D4_Rest_ZYX-1                                     7
# 278680       CD4i_R2_D4_Rest_ZYX-2                                     7
# 278681       CD4i_R2_D4_Rest_ZYX-3                                     7
# 278682     CD4i_R2_D4_Rest_ZZEF1-1                                    17
# 278683     CD4i_R2_D4_Rest_ZZEF1-2                                    17
#
# [278684 rows x 2 columns]
# --------------------------------------------------

# %%
cur_data.adata.obs.columns
# Out:
# Index(['log10_n_cells', 'developmental_stage_label', 'perturbed_gene_id',
#        'keep_for_DE', 'keep_total_counts', '10xrun_id', 'perturbed_gene_name',
#        'perturbation_name', 'guide_id', 'sex_label', 'biological_replicate',
#        'n_cells', 'culture_condition', 'keep_test_genes', 'total_counts',
#        'keep_effective_guides', 'donor_id', 'guide_sequence', 'guide_type',
#        'keep_min_cells', 'perturbed_target_ensg', 'perturbed_target_symbol',
#        'perturbed_target_biotype', 'perturbed_target_coord',
#        'perturbed_target_chromosome', 'original_index',
#        'perturbed_target_number', 'perturbed_target_chromosome_encoding'],
#       dtype='object')

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": None,
        "treatment_id": None,
        # replicates
        "technical_replicate": None,
        # "biological_replicate": None,
        # model system
        "model_system_label": "primary_cell",
        "model_system_id": None,
        "tissue": "lymphoid tissue",
        "cell_line_label": None,
        "cell_line_id": None,
        "cell_type_label": "CD4-positive, alpha-beta T cell",
        "disease_label": "healthy",
        "disease_id": None,

        "timepoint": None,
        "species": "Homo sapiens",
        # "sex_label": "male",
        "sex_id": None,
        # "developmental_stage_label": "adolescent",
        "developmental_stage_id": None,

        "study_title": "Genome-scale perturb-seq in primary human CD4+ T cells maps context-specific regulators of T cell programs and human immune traits",
        "study_uri": "https://doi.org/10.64898/2025.12.23.696273",
        "study_year": 2025,
        "first_author": "Ronghui Zhu",
        "last_author": "Alexander Marson",

        "experiment_title": "Perturb-seq of primary human CD4-positive T cells under resting and stimulated (for 8 and 48 hr) conditions",
        "experiment_summary": """
            Isolated human CD4-positive cells from four healthy donors were stimulated with ImmunoCult CD3/CD28/CD2 activator and sequentially transduced with dCas9-KRAB-Zim3 lentivirus (next morning after stimulation) and a Perturb-seq guide library (next afternoon after stimulation, MOI 0.2).
            The library consisted all genes expressed in human CD4+ T cells, all transcription factors annotated in the Lambert et al. (2018) and non-targeting controls totalling 12,748 genes.
            The gRNA sequences were selected from hCRISPRiv2 and Dolcetto libraries.
            On day 12, cells were split into three conditions:
            (1) Rest - cells were left for 8 hr without stimulation;
            (2) Stim8hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 8 hr;
            (3) Stim48hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 48 hr.
            Cells were harvested, fixed, stored using GEM-X Flex Sample Preparation v2 Kit and sequenced using GEM-X Flex Gene Expression Human n-plex kit converted into Ultima compatible libraries for sequencing on the Ultima Genomics UG100.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_symbol'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB-Zim3",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Marson lab",
        "library_lentiviral_generation": "2",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "GEM-X Flex Gene Expression Human n-plex kit",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "scanpy",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",

        "license_label": "MIT License",
        "license_id": "SWO:9000074",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "Primary Human CD4+ T Cell Perturb-seq",
                "dataset_uri": "s3://genome-scale-tcell-perturb-seq/marson2025_data/GWCD4i.pseudobulk_merged.h5ad",
                "dataset_description": "Pseudobulk expression aggregated by guide, donor and culture condition.",
                "dataset_file_name": "GWCD4i.pseudobulk_merged.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column technical_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_line_id added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column disease_id added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %% [markdown]
# ### Curate treatment information

# %%
cur_data.adata.obs['treatment_label'] = cur_data.adata.obs['culture_condition'].map({
    'Rest':'untreated control',
    'Stim8hr': 'anti-CD3 antibody|anti-CD28 antibody|anti-CD2 antibody',
    'Stim48hr': 'anti-CD3 antibody|anti-CD28 antibody|anti-CD2 antibody'
})

cur_data.adata.obs['treatment_id'] = cur_data.adata.obs['culture_condition'].map({
    'Rest':'NCIT:C184729',
    'Stim8hr': 'EFO:0003317|EFO:0003304|NCIT:C184729',
    'Stim48hr': 'EFO:0003317|EFO:0003304|NCIT:C184729'
})

# %% [markdown]
# ### Curate timepoints

# %%
cur_data.adata.obs['timepoint'] = cur_data.adata.obs['culture_condition'].map({
    'Rest':'P12DT8H0M0S',
    'Stim8hr': 'P12DT8H0M0S',
    'Stim48hr': 'P14DT0H0M0S'
})

# %%
cur_data.adata.obs
# Out:
#         log10_n_cells developmental_stage_label perturbed_gene_id  \
# index
# 0            1.414973                     adult   ENSG00000121410
# 1            2.204120                     adult   ENSG00000121410
# 2            0.000000                     adult   ENSG00000175899
# 3            1.342423                     adult   ENSG00000175899
# 4            1.977724                     adult   ENSG00000094914
# ...               ...                       ...               ...
# 278679       0.000000                     adult   ENSG00000159840
# 278680       1.591065                     adult   ENSG00000159840
# 278681       1.491362                     adult   ENSG00000159840
# 278682       2.000000                     adult   ENSG00000074755
# 278683       1.740363                     adult   ENSG00000074755
#
#         keep_for_DE  keep_total_counts 10xrun_id perturbed_gene_name  \
# index
# 0              True               True   CD4i_R2                A1BG
# 1              True               True   CD4i_R2                A1BG
# 2             False               True   CD4i_R2                 A2M
# 3              True               True   CD4i_R2                 A2M
# 4              True               True   CD4i_R2                AAAS
# ...             ...                ...       ...                 ...
# 278679        False               True   CD4i_R2                 ZYX
# 278680         True               True   CD4i_R2                 ZYX
# 278681         True               True   CD4i_R2                 ZYX
# 278682         True               True   CD4i_R2               ZZEF1
# 278683         True               True   CD4i_R2               ZZEF1
#
#                  perturbation_name guide_id sex_label biological_replicate  \
# index
# 0       CD4i_R2_D1_Stim48hr_A1BG-1   A1BG-1    female         D1_CE0008162
# 1       CD4i_R2_D1_Stim48hr_A1BG-2   A1BG-2    female         D1_CE0008162
# 2        CD4i_R2_D1_Stim48hr_A2M-1    A2M-1    female         D1_CE0008162
# 3        CD4i_R2_D1_Stim48hr_A2M-2    A2M-2    female         D1_CE0008162
# 4       CD4i_R2_D1_Stim48hr_AAAS-1   AAAS-1    female         D1_CE0008162
# ...                            ...      ...       ...                  ...
# 278679       CD4i_R2_D4_Rest_ZYX-1    ZYX-1      male         D4_CE0006864
# 278680       CD4i_R2_D4_Rest_ZYX-2    ZYX-2      male         D4_CE0006864
# 278681       CD4i_R2_D4_Rest_ZYX-3    ZYX-3      male         D4_CE0006864
# 278682     CD4i_R2_D4_Rest_ZZEF1-1  ZZEF1-1      male         D4_CE0006864
# 278683     CD4i_R2_D4_Rest_ZZEF1-2  ZZEF1-2      male         D4_CE0006864
#
#         n_cells culture_condition  keep_test_genes  total_counts  \
# index
# 0          26.0          Stim48hr             True      326500.0
# 1         160.0          Stim48hr             True     2313880.0
# 2           1.0          Stim48hr             True       23782.0
# 3          22.0          Stim48hr             True      330204.0
# 4          95.0          Stim48hr             True     1389867.0
# ...         ...               ...              ...           ...
# 278679      1.0              Rest             True       11009.0
# 278680     39.0              Rest             True      318693.0
# 278681     31.0              Rest             True      247297.0
# 278682    100.0              Rest             True     1050023.0
# 278683     55.0              Rest             True      405467.0
#
#         keep_effective_guides   donor_id        guide_sequence guide_type  \
# index
# 0                        True  CE0008162  GGACGGCATCTCGGCCCGCC  targeting
# 1                        True  CE0008162  GGGTCCCTCGCAGCGCAGGA  targeting
# 2                        True  CE0008162  CAGATGGATTGTAGGGAGTA  targeting
# 3                        True  CE0008162  CCAGATGGATTGTAGGGAGT  targeting
# 4                        True  CE0008162  GGGCTAGATTCGTATGCGGA  targeting
# ...                       ...        ...                   ...        ...
# 278679                   True  CE0006864  GGAGGCGGCCACCCGAGACG  targeting
# 278680                   True  CE0006864  GGACCGGGACGCAGAGTCTG  targeting
# 278681                   True  CE0006864  GGCCGGAGCCGAGACCGAAA  targeting
# 278682                   True  CE0006864  CGCCCGCCAGCTGCTGTCGG  targeting
# 278683                   True  CE0006864  TGTCGGAGGTTGACAGGTCG  targeting
#
#         keep_min_cells perturbed_target_ensg perturbed_target_symbol  \
# index
# 0                 True       ENSG00000121410                    A1BG
# 1                 True       ENSG00000121410                    A1BG
# 2                False       ENSG00000175899                     A2M
# 3                 True       ENSG00000175899                     A2M
# 4                 True       ENSG00000094914                    AAAS
# ...                ...                   ...                     ...
# 278679           False       ENSG00000159840                     ZYX
# 278680            True       ENSG00000159840                     ZYX
# 278681            True       ENSG00000159840                     ZYX
# 278682            True       ENSG00000074755                   ZZEF1
# 278683            True       ENSG00000074755                   ZZEF1
#
#        perturbed_target_biotype      perturbed_target_coord  \
# index
# 0                protein_coding  chr19:58345178-58353492;-1
# 1                protein_coding  chr19:58345178-58353492;-1
# 2                protein_coding    chr12:9067664-9116229;-1
# 3                protein_coding    chr12:9067664-9116229;-1
# 4                protein_coding  chr12:53307456-53324864;-1
# ...                         ...                         ...
# 278679           protein_coding  chr7:143381295-143391111;1
# 278680           protein_coding  chr7:143381295-143391111;1
# 278681           protein_coding  chr7:143381295-143391111;1
# 278682           protein_coding    chr17:4004445-4143628;-1
# 278683           protein_coding    chr17:4004445-4143628;-1
#
#        perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0                               19              0                        1
# 1                               19              1                        1
# 2                               12              2                        1
# 3                               12              3                        1
# 4                               12              4                        1
# ...                            ...            ...                      ...
# 278679                           7         278679                        1
# 278680                           7         278680                        1
# 278681                           7         278681                        1
# 278682                          17         278682                        1
# 278683                          17         278683                        1
#
#         perturbed_target_chromosome_encoding           dataset_id  sample_id  \
# index
# 0                                         19  zhu_2025_pseudobulk          1
# 1                                         19  zhu_2025_pseudobulk          2
# 2                                         12  zhu_2025_pseudobulk          3
# 3                                         12  zhu_2025_pseudobulk          4
# 4                                         12  zhu_2025_pseudobulk          5
# ...                                      ...                  ...        ...
# 278679                                     7  zhu_2025_pseudobulk     278680
# 278680                                     7  zhu_2025_pseudobulk     278681
# 278681                                     7  zhu_2025_pseudobulk     278682
# 278682                                    17  zhu_2025_pseudobulk     278683
# 278683                                    17  zhu_2025_pseudobulk     278684
#
#        perturbation_type_label perturbation_type_id data_modality significant  \
# index
# 0                      CRISPRi                 None   Perturb-seq        None
# 1                      CRISPRi                 None   Perturb-seq        None
# 2                      CRISPRi                 None   Perturb-seq        None
# 3                      CRISPRi                 None   Perturb-seq        None
# 4                      CRISPRi                 None   Perturb-seq        None
# ...                        ...                  ...           ...         ...
# 278679                 CRISPRi                 None   Perturb-seq        None
# 278680                 CRISPRi                 None   Perturb-seq        None
# 278681                 CRISPRi                 None   Perturb-seq        None
# 278682                 CRISPRi                 None   Perturb-seq        None
# 278683                 CRISPRi                 None   Perturb-seq        None
#
#        significance_criteria score_interpretation  \
# index
# 0                       None                 None
# 1                       None                 None
# 2                       None                 None
# 3                       None                 None
# 4                       None                 None
# ...                      ...                  ...
# 278679                  None                 None
# 278680                  None                 None
# 278681                  None                 None
# 278682                  None                 None
# 278683                  None                 None
#
#                                           treatment_label  \
# index
# 0       anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1       anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2       anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3       anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4       anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                   ...
# 278679                                  untreated control
# 278680                                  untreated control
# 278681                                  untreated control
# 278682                                  untreated control
# 278683                                  untreated control
#
#                                 treatment_id technical_replicate  \
# index
# 0       EFO:0003317|EFO:0003304|NCIT:C184729                None
# 1       EFO:0003317|EFO:0003304|NCIT:C184729                None
# 2       EFO:0003317|EFO:0003304|NCIT:C184729                None
# 3       EFO:0003317|EFO:0003304|NCIT:C184729                None
# 4       EFO:0003317|EFO:0003304|NCIT:C184729                None
# ...                                      ...                 ...
# 278679                          NCIT:C184729                None
# 278680                          NCIT:C184729                None
# 278681                          NCIT:C184729                None
# 278682                          NCIT:C184729                None
# 278683                          NCIT:C184729                None
#
#        model_system_label model_system_id           tissue cell_line_label  \
# index
# 0            primary_cell            None  lymphoid tissue            None
# 1            primary_cell            None  lymphoid tissue            None
# 2            primary_cell            None  lymphoid tissue            None
# 3            primary_cell            None  lymphoid tissue            None
# 4            primary_cell            None  lymphoid tissue            None
# ...                   ...             ...              ...             ...
# 278679       primary_cell            None  lymphoid tissue            None
# 278680       primary_cell            None  lymphoid tissue            None
# 278681       primary_cell            None  lymphoid tissue            None
# 278682       primary_cell            None  lymphoid tissue            None
# 278683       primary_cell            None  lymphoid tissue            None
#
#        cell_line_id                  cell_type_label disease_label disease_id  \
# index
# 0              None  CD4-positive, alpha-beta T cell       healthy       None
# 1              None  CD4-positive, alpha-beta T cell       healthy       None
# 2              None  CD4-positive, alpha-beta T cell       healthy       None
# 3              None  CD4-positive, alpha-beta T cell       healthy       None
# 4              None  CD4-positive, alpha-beta T cell       healthy       None
# ...             ...                              ...           ...        ...
# 278679         None  CD4-positive, alpha-beta T cell       healthy       None
# 278680         None  CD4-positive, alpha-beta T cell       healthy       None
# 278681         None  CD4-positive, alpha-beta T cell       healthy       None
# 278682         None  CD4-positive, alpha-beta T cell       healthy       None
# 278683         None  CD4-positive, alpha-beta T cell       healthy       None
#
#           timepoint       species sex_id developmental_stage_id  \
# index
# 0       P14DT0H0M0S  Homo sapiens   None                   None
# 1       P14DT0H0M0S  Homo sapiens   None                   None
# 2       P14DT0H0M0S  Homo sapiens   None                   None
# 3       P14DT0H0M0S  Homo sapiens   None                   None
# 4       P14DT0H0M0S  Homo sapiens   None                   None
# ...             ...           ...    ...                    ...
# 278679  P12DT8H0M0S  Homo sapiens   None                   None
# 278680  P12DT8H0M0S  Homo sapiens   None                   None
# 278681  P12DT8H0M0S  Homo sapiens   None                   None
# 278682  P12DT8H0M0S  Homo sapiens   None                   None
# 278683  P12DT8H0M0S  Homo sapiens   None                   None
#
#                                               study_title  \
# index
# 0       Genome-scale perturb-seq in primary human CD4+...
# 1       Genome-scale perturb-seq in primary human CD4+...
# 2       Genome-scale perturb-seq in primary human CD4+...
# 3       Genome-scale perturb-seq in primary human CD4+...
# 4       Genome-scale perturb-seq in primary human CD4+...
# ...                                                   ...
# 278679  Genome-scale perturb-seq in primary human CD4+...
# 278680  Genome-scale perturb-seq in primary human CD4+...
# 278681  Genome-scale perturb-seq in primary human CD4+...
# 278682  Genome-scale perturb-seq in primary human CD4+...
# 278683  Genome-scale perturb-seq in primary human CD4+...
#
#                                          study_uri  study_year first_author  \
# index
# 0       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                            ...         ...          ...
# 278679  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278680  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278681  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278682  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278683  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#              last_author                                   experiment_title  \
# index
# 0       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                  ...                                                ...
# 278679  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278680  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278681  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278682  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278683  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                        experiment_summary  \
# index
# 0       \n            Isolated human CD4-positive cell...
# 1       \n            Isolated human CD4-positive cell...
# 2       \n            Isolated human CD4-positive cell...
# 3       \n            Isolated human CD4-positive cell...
# 4       \n            Isolated human CD4-positive cell...
# ...                                                   ...
# 278679  \n            Isolated human CD4-positive cell...
# 278680  \n            Isolated human CD4-positive cell...
# 278681  \n            Isolated human CD4-positive cell...
# 278682  \n            Isolated human CD4-positive cell...
# 278683  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets  number_of_perturbed_samples  \
# index
# 0                             12731                       278684
# 1                             12731                       278684
# 2                             12731                       278684
# 3                             12731                       278684
# 4                             12731                       278684
# ...                             ...                          ...
# 278679                        12731                       278684
# 278680                        12731                       278684
# 278681                        12731                       278684
# 278682                        12731                       278684
# 278683                        12731                       278684
#
#        library_generation_type_id library_generation_type_label  \
# index
# 0                     EFO:0022868                    endogenous
# 1                     EFO:0022868                    endogenous
# 2                     EFO:0022868                    endogenous
# 3                     EFO:0022868                    endogenous
# 4                     EFO:0022868                    endogenous
# ...                           ...                           ...
# 278679                EFO:0022868                    endogenous
# 278680                EFO:0022868                    endogenous
# 278681                EFO:0022868                    endogenous
# 278682                EFO:0022868                    endogenous
# 278683                EFO:0022868                    endogenous
#
#        library_generation_method_id library_generation_method_label  \
# index
# 0                              None                 dCas9-KRAB-Zim3
# 1                              None                 dCas9-KRAB-Zim3
# 2                              None                 dCas9-KRAB-Zim3
# 3                              None                 dCas9-KRAB-Zim3
# 4                              None                 dCas9-KRAB-Zim3
# ...                             ...                             ...
# 278679                         None                 dCas9-KRAB-Zim3
# 278680                         None                 dCas9-KRAB-Zim3
# 278681                         None                 dCas9-KRAB-Zim3
# 278682                         None                 dCas9-KRAB-Zim3
# 278683                         None                 dCas9-KRAB-Zim3
#
#        enzyme_delivery_method_id enzyme_delivery_method_label  \
# index
# 0                           None      lentivirus transduction
# 1                           None      lentivirus transduction
# 2                           None      lentivirus transduction
# 3                           None      lentivirus transduction
# 4                           None      lentivirus transduction
# ...                          ...                          ...
# 278679                      None      lentivirus transduction
# 278680                      None      lentivirus transduction
# 278681                      None      lentivirus transduction
# 278682                      None      lentivirus transduction
# 278683                      None      lentivirus transduction
#
#        library_delivery_method_id library_delivery_method_label  \
# index
# 0                            None       lentivirus transduction
# 1                            None       lentivirus transduction
# 2                            None       lentivirus transduction
# 3                            None       lentivirus transduction
# 4                            None       lentivirus transduction
# ...                           ...                           ...
# 278679                       None       lentivirus transduction
# 278680                       None       lentivirus transduction
# 278681                       None       lentivirus transduction
# 278682                       None       lentivirus transduction
# 278683                       None       lentivirus transduction
#
#        enzyme_integration_state_id enzyme_integration_state_label  \
# index
# 0                             None       random locus integration
# 1                             None       random locus integration
# 2                             None       random locus integration
# 3                             None       random locus integration
# 4                             None       random locus integration
# ...                            ...                            ...
# 278679                        None       random locus integration
# 278680                        None       random locus integration
# 278681                        None       random locus integration
# 278682                        None       random locus integration
# 278683                        None       random locus integration
#
#        library_integration_state_id library_integration_state_label  \
# index
# 0                              None        random locus integration
# 1                              None        random locus integration
# 2                              None        random locus integration
# 3                              None        random locus integration
# 4                              None        random locus integration
# ...                             ...                             ...
# 278679                         None        random locus integration
# 278680                         None        random locus integration
# 278681                         None        random locus integration
# 278682                         None        random locus integration
# 278683                         None        random locus integration
#
#        enzyme_expression_control_id    enzyme_expression_control_label  \
# index
# 0                              None  constitutive transgene expression
# 1                              None  constitutive transgene expression
# 2                              None  constitutive transgene expression
# 3                              None  constitutive transgene expression
# 4                              None  constitutive transgene expression
# ...                             ...                                ...
# 278679                         None  constitutive transgene expression
# 278680                         None  constitutive transgene expression
# 278681                         None  constitutive transgene expression
# 278682                         None  constitutive transgene expression
# 278683                         None  constitutive transgene expression
#
#        library_expression_control_id   library_expression_control_label  \
# index
# 0                               None  constitutive transgene expression
# 1                               None  constitutive transgene expression
# 2                               None  constitutive transgene expression
# 3                               None  constitutive transgene expression
# 4                               None  constitutive transgene expression
# ...                              ...                                ...
# 278679                          None  constitutive transgene expression
# 278680                          None  constitutive transgene expression
# 278681                          None  constitutive transgene expression
# 278682                          None  constitutive transgene expression
# 278683                          None  constitutive transgene expression
#
#        library_name library_uri library_format_id library_format_label  \
# index
# 0            custom        None              None               pooled
# 1            custom        None              None               pooled
# 2            custom        None              None               pooled
# 3            custom        None              None               pooled
# 4            custom        None              None               pooled
# ...             ...         ...               ...                  ...
# 278679       custom        None              None               pooled
# 278680       custom        None              None               pooled
# 278681       custom        None              None               pooled
# 278682       custom        None              None               pooled
# 278683       custom        None              None               pooled
#
#        library_scope_id library_scope_label library_perturbation_type_id  \
# index
# 0                  None             focused                         None
# 1                  None             focused                         None
# 2                  None             focused                         None
# 3                  None             focused                         None
# 4                  None             focused                         None
# ...                 ...                 ...                          ...
# 278679             None             focused                         None
# 278680             None             focused                         None
# 278681             None             focused                         None
# 278682             None             focused                         None
# 278683             None             focused                         None
#
#        library_perturbation_type_label library_manufacturer  \
# index
# 0                           inhibition           Marson lab
# 1                           inhibition           Marson lab
# 2                           inhibition           Marson lab
# 3                           inhibition           Marson lab
# 4                           inhibition           Marson lab
# ...                                ...                  ...
# 278679                      inhibition           Marson lab
# 278680                      inhibition           Marson lab
# 278681                      inhibition           Marson lab
# 278682                      inhibition           Marson lab
# 278683                      inhibition           Marson lab
#
#        library_lentiviral_generation library_grnas_per_target  \
# index
# 0                                  2                        2
# 1                                  2                        2
# 2                                  2                        2
# 3                                  2                        2
# 4                                  2                        2
# ...                              ...                      ...
# 278679                             2                        2
# 278680                             2                        2
# 278681                             2                        2
# 278682                             2                        2
# 278683                             2                        2
#
#        library_total_grnas library_total_variants readout_dimensionality_id  \
# index
# 0                    25954                   None                      None
# 1                    25954                   None                      None
# 2                    25954                   None                      None
# 3                    25954                   None                      None
# 4                    25954                   None                      None
# ...                    ...                    ...                       ...
# 278679               25954                   None                      None
# 278680               25954                   None                      None
# 278681               25954                   None                      None
# 278682               25954                   None                      None
# 278683               25954                   None                      None
#
#        readout_dimensionality_label readout_type_id readout_type_label  \
# index
# 0            high-dimensional assay            None     transcriptomic
# 1            high-dimensional assay            None     transcriptomic
# 2            high-dimensional assay            None     transcriptomic
# 3            high-dimensional assay            None     transcriptomic
# 4            high-dimensional assay            None     transcriptomic
# ...                             ...             ...                ...
# 278679       high-dimensional assay            None     transcriptomic
# 278680       high-dimensional assay            None     transcriptomic
# 278681       high-dimensional assay            None     transcriptomic
# 278682       high-dimensional assay            None     transcriptomic
# 278683       high-dimensional assay            None     transcriptomic
#
#        readout_technology_id readout_technology_label method_name_id  \
# index
# 0                       None      single-cell rna-seq           None
# 1                       None      single-cell rna-seq           None
# 2                       None      single-cell rna-seq           None
# 3                       None      single-cell rna-seq           None
# 4                       None      single-cell rna-seq           None
# ...                      ...                      ...            ...
# 278679                  None      single-cell rna-seq           None
# 278680                  None      single-cell rna-seq           None
# 278681                  None      single-cell rna-seq           None
# 278682                  None      single-cell rna-seq           None
# 278683                  None      single-cell rna-seq           None
#
#        method_name_label method_uri sequencing_library_kit_id  \
# index
# 0            Perturb-seq       None                      None
# 1            Perturb-seq       None                      None
# 2            Perturb-seq       None                      None
# 3            Perturb-seq       None                      None
# 4            Perturb-seq       None                      None
# ...                  ...        ...                       ...
# 278679       Perturb-seq       None                      None
# 278680       Perturb-seq       None                      None
# 278681       Perturb-seq       None                      None
# 278682       Perturb-seq       None                      None
# 278683       Perturb-seq       None                      None
#
#                        sequencing_library_kit_label sequencing_platform_id  \
# index
# 0       GEM-X Flex Gene Expression Human n-plex kit                   None
# 1       GEM-X Flex Gene Expression Human n-plex kit                   None
# 2       GEM-X Flex Gene Expression Human n-plex kit                   None
# 3       GEM-X Flex Gene Expression Human n-plex kit                   None
# 4       GEM-X Flex Gene Expression Human n-plex kit                   None
# ...                                             ...                    ...
# 278679  GEM-X Flex Gene Expression Human n-plex kit                   None
# 278680  GEM-X Flex Gene Expression Human n-plex kit                   None
# 278681  GEM-X Flex Gene Expression Human n-plex kit                   None
# 278682  GEM-X Flex Gene Expression Human n-plex kit                   None
# 278683  GEM-X Flex Gene Expression Human n-plex kit                   None
#
#        sequencing_platform_label sequencing_strategy_id  \
# index
# 0          Ultima Genomics UG100                   None
# 1          Ultima Genomics UG100                   None
# 2          Ultima Genomics UG100                   None
# 3          Ultima Genomics UG100                   None
# 4          Ultima Genomics UG100                   None
# ...                          ...                    ...
# 278679     Ultima Genomics UG100                   None
# 278680     Ultima Genomics UG100                   None
# 278681     Ultima Genomics UG100                   None
# 278682     Ultima Genomics UG100                   None
# 278683     Ultima Genomics UG100                   None
#
#        sequencing_strategy_label software_counts_id software_counts_label  \
# index
# 0             barcode sequencing               None            CellRanger
# 1             barcode sequencing               None            CellRanger
# 2             barcode sequencing               None            CellRanger
# 3             barcode sequencing               None            CellRanger
# 4             barcode sequencing               None            CellRanger
# ...                          ...                ...                   ...
# 278679        barcode sequencing               None            CellRanger
# 278680        barcode sequencing               None            CellRanger
# 278681        barcode sequencing               None            CellRanger
# 278682        barcode sequencing               None            CellRanger
# 278683        barcode sequencing               None            CellRanger
#
#        software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                      None                  scanpy                None
# 1                      None                  scanpy                None
# 2                      None                  scanpy                None
# 3                      None                  scanpy                None
# 4                      None                  scanpy                None
# ...                     ...                     ...                 ...
# 278679                 None                  scanpy                None
# 278680                 None                  scanpy                None
# 278681                 None                  scanpy                None
# 278682                 None                  scanpy                None
# 278683                 None                  scanpy                None
#
#        reference_genome_label license_label   license_id  \
# index
# 0                      GRCh38   MIT License  SWO:9000074
# 1                      GRCh38   MIT License  SWO:9000074
# 2                      GRCh38   MIT License  SWO:9000074
# 3                      GRCh38   MIT License  SWO:9000074
# 4                      GRCh38   MIT License  SWO:9000074
# ...                       ...           ...          ...
# 278679                 GRCh38   MIT License  SWO:9000074
# 278680                 GRCh38   MIT License  SWO:9000074
# 278681                 GRCh38   MIT License  SWO:9000074
# 278682                 GRCh38   MIT License  SWO:9000074
# 278683                 GRCh38   MIT License  SWO:9000074
#
#                                       associated_datasets
# index
# 0       [{"dataset_accession": "Primary Human CD4+ T C...
# 1       [{"dataset_accession": "Primary Human CD4+ T C...
# 2       [{"dataset_accession": "Primary Human CD4+ T C...
# 3       [{"dataset_accession": "Primary Human CD4+ T C...
# 4       [{"dataset_accession": "Primary Human CD4+ T C...
# ...                                                   ...
# 278679  [{"dataset_accession": "Primary Human CD4+ T C...
# 278680  [{"dataset_accession": "Primary Human CD4+ T C...
# 278681  [{"dataset_accession": "Primary Human CD4+ T C...
# 278682  [{"dataset_accession": "Primary Human CD4+ T C...
# 278683  [{"dataset_accession": "Primary Human CD4+ T C...
#
# [278684 rows x 113 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#       input_column input_column_lower       name_lower     ontology_id
# 0  lymphoid tissue    lymphoid tissue  lymphoid tissue  UBERON:0001744
# --------------------------------------------------
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                       input_column               input_column_lower  \
# 0  CD4-positive, alpha-beta T cell  cd4-positive, alpha-beta t cell
#
#                         name_lower ontology_id
# 0  cd4-positive, alpha-beta t cell  CL:0000624
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Warning: No disease ontology terms could be mapped from `disease_label` column to ontology terms. Map the terms manually or check the input column for errors.

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-02-09 16:10:32,971 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
#                  dataset_id sample_id data_modality significant  \
# 0       zhu_2025_pseudobulk         1   Perturb-seq        <NA>
# 1       zhu_2025_pseudobulk         2   Perturb-seq        <NA>
# 2       zhu_2025_pseudobulk         3   Perturb-seq        <NA>
# 3       zhu_2025_pseudobulk         4   Perturb-seq        <NA>
# 4       zhu_2025_pseudobulk         5   Perturb-seq        <NA>
# ...                     ...       ...           ...         ...
# 278679  zhu_2025_pseudobulk    278680   Perturb-seq        <NA>
# 278680  zhu_2025_pseudobulk    278681   Perturb-seq        <NA>
# 278681  zhu_2025_pseudobulk    278682   Perturb-seq        <NA>
# 278682  zhu_2025_pseudobulk    278683   Perturb-seq        <NA>
# 278683  zhu_2025_pseudobulk    278684   Perturb-seq        <NA>
#
#        significance_criteria           perturbation_name  \
# 0                       <NA>  CD4i_R2_D1_Stim48hr_A1BG-1
# 1                       <NA>  CD4i_R2_D1_Stim48hr_A1BG-2
# 2                       <NA>   CD4i_R2_D1_Stim48hr_A2M-1
# 3                       <NA>   CD4i_R2_D1_Stim48hr_A2M-2
# 4                       <NA>  CD4i_R2_D1_Stim48hr_AAAS-1
# ...                      ...                         ...
# 278679                  <NA>       CD4i_R2_D4_Rest_ZYX-1
# 278680                  <NA>       CD4i_R2_D4_Rest_ZYX-2
# 278681                  <NA>       CD4i_R2_D4_Rest_ZYX-3
# 278682                  <NA>     CD4i_R2_D4_Rest_ZZEF1-1
# 278683                  <NA>     CD4i_R2_D4_Rest_ZZEF1-2
#
#             perturbed_target_coord perturbed_target_chromosome  \
# 0       chr19:58345178-58353492;-1                          19
# 1       chr19:58345178-58353492;-1                          19
# 2         chr12:9067664-9116229;-1                          12
# 3         chr12:9067664-9116229;-1                          12
# 4       chr12:53307456-53324864;-1                          12
# ...                            ...                         ...
# 278679  chr7:143381295-143391111;1                           7
# 278680  chr7:143381295-143391111;1                           7
# 278681  chr7:143381295-143391111;1                           7
# 278682    chr17:4004445-4143628;-1                          17
# 278683    chr17:4004445-4143628;-1                          17
#
#         perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                         19                        1
# 1                                         19                        1
# 2                                         12                        1
# 3                                         12                        1
# 4                                         12                        1
# ...                                      ...                      ...
# 278679                                     7                        1
# 278680                                     7                        1
# 278681                                     7                        1
# 278682                                    17                        1
# 278683                                    17                        1
#
#        perturbed_target_ensg perturbed_target_symbol perturbed_target_biotype  \
# 0            ENSG00000121410                    A1BG           protein_coding
# 1            ENSG00000121410                    A1BG           protein_coding
# 2            ENSG00000175899                     A2M           protein_coding
# 3            ENSG00000175899                     A2M           protein_coding
# 4            ENSG00000094914                    AAAS           protein_coding
# ...                      ...                     ...                      ...
# 278679       ENSG00000159840                     ZYX           protein_coding
# 278680       ENSG00000159840                     ZYX           protein_coding
# 278681       ENSG00000159840                     ZYX           protein_coding
# 278682       ENSG00000074755                   ZZEF1           protein_coding
# 278683       ENSG00000074755                   ZZEF1           protein_coding
#
#               guide_sequence perturbation_type_label perturbation_type_id  \
# 0       GGACGGCATCTCGGCCCGCC                 CRISPRi                 <NA>
# 1       GGGTCCCTCGCAGCGCAGGA                 CRISPRi                 <NA>
# 2       CAGATGGATTGTAGGGAGTA                 CRISPRi                 <NA>
# 3       CCAGATGGATTGTAGGGAGT                 CRISPRi                 <NA>
# 4       GGGCTAGATTCGTATGCGGA                 CRISPRi                 <NA>
# ...                      ...                     ...                  ...
# 278679  GGAGGCGGCCACCCGAGACG                 CRISPRi                 <NA>
# 278680  GGACCGGGACGCAGAGTCTG                 CRISPRi                 <NA>
# 278681  GGCCGGAGCCGAGACCGAAA                 CRISPRi                 <NA>
# 278682  CGCCCGCCAGCTGCTGTCGG                 CRISPRi                 <NA>
# 278683  TGTCGGAGGTTGACAGGTCG                 CRISPRi                 <NA>
#
#           timepoint                                    treatment_label  \
# 0       P14DT0H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1       P14DT0H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2       P14DT0H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3       P14DT0H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4       P14DT0H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...             ...                                                ...
# 278679  P12DT8H0M0S                                  untreated control
# 278680  P12DT8H0M0S                                  untreated control
# 278681  P12DT8H0M0S                                  untreated control
# 278682  P12DT8H0M0S                                  untreated control
# 278683  P12DT8H0M0S                                  untreated control
#
#                                 treatment_id technical_replicate  \
# 0       EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
# 1       EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
# 2       EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
# 3       EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
# 4       EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
# ...                                      ...                 ...
# 278679                          NCIT:C184729                <NA>
# 278680                          NCIT:C184729                <NA>
# 278681                          NCIT:C184729                <NA>
# 278682                          NCIT:C184729                <NA>
# 278683                          NCIT:C184729                <NA>
#
#        biological_replicate model_system_label model_system_id       species  \
# 0              D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 1              D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2              D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 3              D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 4              D1_CE0008162       primary_cell            <NA>  Homo sapiens
# ...                     ...                ...             ...           ...
# 278679         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 278680         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 278681         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 278682         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 278683         D4_CE0006864       primary_cell            <NA>  Homo sapiens
#
#            tissue_label       tissue_id                  cell_type_label  \
# 0       lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1       lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2       lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3       lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4       lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                 ...             ...                              ...
# 278679  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 278680  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 278681  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 278682  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 278683  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#        cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0        CL:0000624            <NA>         <NA>    female   <NA>
# 1        CL:0000624            <NA>         <NA>    female   <NA>
# 2        CL:0000624            <NA>         <NA>    female   <NA>
# 3        CL:0000624            <NA>         <NA>    female   <NA>
# 4        CL:0000624            <NA>         <NA>    female   <NA>
# ...             ...             ...          ...       ...    ...
# 278679   CL:0000624            <NA>         <NA>      male   <NA>
# 278680   CL:0000624            <NA>         <NA>      male   <NA>
# 278681   CL:0000624            <NA>         <NA>      male   <NA>
# 278682   CL:0000624            <NA>         <NA>      male   <NA>
# 278683   CL:0000624            <NA>         <NA>      male   <NA>
#
#        developmental_stage_label developmental_stage_id disease_label  \
# 0                          adult                   <NA>       healthy
# 1                          adult                   <NA>       healthy
# 2                          adult                   <NA>       healthy
# 3                          adult                   <NA>       healthy
# 4                          adult                   <NA>       healthy
# ...                          ...                    ...           ...
# 278679                     adult                   <NA>       healthy
# 278680                     adult                   <NA>       healthy
# 278681                     adult                   <NA>       healthy
# 278682                     adult                   <NA>       healthy
# 278683                     adult                   <NA>       healthy
#
#        disease_id                                        study_title  \
# 0            <NA>  Genome-scale perturb-seq in primary human CD4+...
# 1            <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2            <NA>  Genome-scale perturb-seq in primary human CD4+...
# 3            <NA>  Genome-scale perturb-seq in primary human CD4+...
# 4            <NA>  Genome-scale perturb-seq in primary human CD4+...
# ...           ...                                                ...
# 278679       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 278680       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 278681       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 278682       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 278683       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                          study_uri  study_year first_author  \
# 0       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4       https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                            ...         ...          ...
# 278679  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278680  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278681  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278682  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 278683  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#              last_author                                   experiment_title  \
# 0       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4       Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                  ...                                                ...
# 278679  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278680  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278681  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278682  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 278683  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                        experiment_summary  \
# 0
#             Isolated human CD4-positive cells...
# 1
#             Isolated human CD4-positive cells...
# 2
#             Isolated human CD4-positive cells...
# 3
#             Isolated human CD4-positive cells...
# 4
#             Isolated human CD4-positive cells...
# ...                                                   ...
# 278679
#             Isolated human CD4-positive cells...
# 278680
#             Isolated human CD4-positive cells...
# 278681
#             Isolated human CD4-positive cells...
# 278682
#             Isolated human CD4-positive cells...
# 278683
#             Isolated human CD4-positive cells...
#
#        number_of_perturbed_targets number_of_perturbed_samples  \
# 0                            12731                      278684
# 1                            12731                      278684
# 2                            12731                      278684
# 3                            12731                      278684
# 4                            12731                      278684
# ...                            ...                         ...
# 278679                       12731                      278684
# 278680                       12731                      278684
# 278681                       12731                      278684
# 278682                       12731                      278684
# 278683                       12731                      278684
#
#        library_generation_type_id library_generation_type_label  \
# 0                     EFO:0022868                    endogenous
# 1                     EFO:0022868                    endogenous
# 2                     EFO:0022868                    endogenous
# 3                     EFO:0022868                    endogenous
# 4                     EFO:0022868                    endogenous
# ...                           ...                           ...
# 278679                EFO:0022868                    endogenous
# 278680                EFO:0022868                    endogenous
# 278681                EFO:0022868                    endogenous
# 278682                EFO:0022868                    endogenous
# 278683                EFO:0022868                    endogenous
#
#        library_generation_method_id library_generation_method_label  \
# 0                              <NA>                 dCas9-KRAB-Zim3
# 1                              <NA>                 dCas9-KRAB-Zim3
# 2                              <NA>                 dCas9-KRAB-Zim3
# 3                              <NA>                 dCas9-KRAB-Zim3
# 4                              <NA>                 dCas9-KRAB-Zim3
# ...                             ...                             ...
# 278679                         <NA>                 dCas9-KRAB-Zim3
# 278680                         <NA>                 dCas9-KRAB-Zim3
# 278681                         <NA>                 dCas9-KRAB-Zim3
# 278682                         <NA>                 dCas9-KRAB-Zim3
# 278683                         <NA>                 dCas9-KRAB-Zim3
#
#        enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                           <NA>      lentivirus transduction
# 1                           <NA>      lentivirus transduction
# 2                           <NA>      lentivirus transduction
# 3                           <NA>      lentivirus transduction
# 4                           <NA>      lentivirus transduction
# ...                          ...                          ...
# 278679                      <NA>      lentivirus transduction
# 278680                      <NA>      lentivirus transduction
# 278681                      <NA>      lentivirus transduction
# 278682                      <NA>      lentivirus transduction
# 278683                      <NA>      lentivirus transduction
#
#        library_delivery_method_id library_delivery_method_label  \
# 0                            <NA>       lentivirus transduction
# 1                            <NA>       lentivirus transduction
# 2                            <NA>       lentivirus transduction
# 3                            <NA>       lentivirus transduction
# 4                            <NA>       lentivirus transduction
# ...                           ...                           ...
# 278679                       <NA>       lentivirus transduction
# 278680                       <NA>       lentivirus transduction
# 278681                       <NA>       lentivirus transduction
# 278682                       <NA>       lentivirus transduction
# 278683                       <NA>       lentivirus transduction
#
#        enzyme_integration_state_id enzyme_integration_state_label  \
# 0                             <NA>       random locus integration
# 1                             <NA>       random locus integration
# 2                             <NA>       random locus integration
# 3                             <NA>       random locus integration
# 4                             <NA>       random locus integration
# ...                            ...                            ...
# 278679                        <NA>       random locus integration
# 278680                        <NA>       random locus integration
# 278681                        <NA>       random locus integration
# 278682                        <NA>       random locus integration
# 278683                        <NA>       random locus integration
#
#        library_integration_state_id library_integration_state_label  \
# 0                              <NA>        random locus integration
# 1                              <NA>        random locus integration
# 2                              <NA>        random locus integration
# 3                              <NA>        random locus integration
# 4                              <NA>        random locus integration
# ...                             ...                             ...
# 278679                         <NA>        random locus integration
# 278680                         <NA>        random locus integration
# 278681                         <NA>        random locus integration
# 278682                         <NA>        random locus integration
# 278683                         <NA>        random locus integration
#
#        enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                              <NA>  constitutive transgene expression
# 1                              <NA>  constitutive transgene expression
# 2                              <NA>  constitutive transgene expression
# 3                              <NA>  constitutive transgene expression
# 4                              <NA>  constitutive transgene expression
# ...                             ...                                ...
# 278679                         <NA>  constitutive transgene expression
# 278680                         <NA>  constitutive transgene expression
# 278681                         <NA>  constitutive transgene expression
# 278682                         <NA>  constitutive transgene expression
# 278683                         <NA>  constitutive transgene expression
#
#        library_expression_control_id   library_expression_control_label  \
# 0                               <NA>  constitutive transgene expression
# 1                               <NA>  constitutive transgene expression
# 2                               <NA>  constitutive transgene expression
# 3                               <NA>  constitutive transgene expression
# 4                               <NA>  constitutive transgene expression
# ...                              ...                                ...
# 278679                          <NA>  constitutive transgene expression
# 278680                          <NA>  constitutive transgene expression
# 278681                          <NA>  constitutive transgene expression
# 278682                          <NA>  constitutive transgene expression
# 278683                          <NA>  constitutive transgene expression
#
#        library_name library_uri library_format_id library_format_label  \
# 0            custom        <NA>              <NA>               pooled
# 1            custom        <NA>              <NA>               pooled
# 2            custom        <NA>              <NA>               pooled
# 3            custom        <NA>              <NA>               pooled
# 4            custom        <NA>              <NA>               pooled
# ...             ...         ...               ...                  ...
# 278679       custom        <NA>              <NA>               pooled
# 278680       custom        <NA>              <NA>               pooled
# 278681       custom        <NA>              <NA>               pooled
# 278682       custom        <NA>              <NA>               pooled
# 278683       custom        <NA>              <NA>               pooled
#
#        library_scope_id library_scope_label library_perturbation_type_id  \
# 0                  <NA>             focused                         <NA>
# 1                  <NA>             focused                         <NA>
# 2                  <NA>             focused                         <NA>
# 3                  <NA>             focused                         <NA>
# 4                  <NA>             focused                         <NA>
# ...                 ...                 ...                          ...
# 278679             <NA>             focused                         <NA>
# 278680             <NA>             focused                         <NA>
# 278681             <NA>             focused                         <NA>
# 278682             <NA>             focused                         <NA>
# 278683             <NA>             focused                         <NA>
#
#        library_perturbation_type_label library_manufacturer  \
# 0                           inhibition           Marson lab
# 1                           inhibition           Marson lab
# 2                           inhibition           Marson lab
# 3                           inhibition           Marson lab
# 4                           inhibition           Marson lab
# ...                                ...                  ...
# 278679                      inhibition           Marson lab
# 278680                      inhibition           Marson lab
# 278681                      inhibition           Marson lab
# 278682                      inhibition           Marson lab
# 278683                      inhibition           Marson lab
#
#        library_lentiviral_generation library_grnas_per_target  \
# 0                                  2                        2
# 1                                  2                        2
# 2                                  2                        2
# 3                                  2                        2
# 4                                  2                        2
# ...                              ...                      ...
# 278679                             2                        2
# 278680                             2                        2
# 278681                             2                        2
# 278682                             2                        2
# 278683                             2                        2
#
#        library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                    25954                    <NA>                      <NA>
# 1                    25954                    <NA>                      <NA>
# 2                    25954                    <NA>                      <NA>
# 3                    25954                    <NA>                      <NA>
# 4                    25954                    <NA>                      <NA>
# ...                    ...                     ...                       ...
# 278679               25954                    <NA>                      <NA>
# 278680               25954                    <NA>                      <NA>
# 278681               25954                    <NA>                      <NA>
# 278682               25954                    <NA>                      <NA>
# 278683               25954                    <NA>                      <NA>
#
#        readout_dimensionality_label readout_type_id readout_type_label  \
# 0            high-dimensional assay            <NA>     transcriptomic
# 1            high-dimensional assay            <NA>     transcriptomic
# 2            high-dimensional assay            <NA>     transcriptomic
# 3            high-dimensional assay            <NA>     transcriptomic
# 4            high-dimensional assay            <NA>     transcriptomic
# ...                             ...             ...                ...
# 278679       high-dimensional assay            <NA>     transcriptomic
# 278680       high-dimensional assay            <NA>     transcriptomic
# 278681       high-dimensional assay            <NA>     transcriptomic
# 278682       high-dimensional assay            <NA>     transcriptomic
# 278683       high-dimensional assay            <NA>     transcriptomic
#
#        readout_technology_id readout_technology_label method_name_id  \
# 0                       <NA>      single-cell rna-seq           <NA>
# 1                       <NA>      single-cell rna-seq           <NA>
# 2                       <NA>      single-cell rna-seq           <NA>
# 3                       <NA>      single-cell rna-seq           <NA>
# 4                       <NA>      single-cell rna-seq           <NA>
# ...                      ...                      ...            ...
# 278679                  <NA>      single-cell rna-seq           <NA>
# 278680                  <NA>      single-cell rna-seq           <NA>
# 278681                  <NA>      single-cell rna-seq           <NA>
# 278682                  <NA>      single-cell rna-seq           <NA>
# 278683                  <NA>      single-cell rna-seq           <NA>
#
#        method_name_label method_uri sequencing_library_kit_id  \
# 0            Perturb-seq       <NA>                      <NA>
# 1            Perturb-seq       <NA>                      <NA>
# 2            Perturb-seq       <NA>                      <NA>
# 3            Perturb-seq       <NA>                      <NA>
# 4            Perturb-seq       <NA>                      <NA>
# ...                  ...        ...                       ...
# 278679       Perturb-seq       <NA>                      <NA>
# 278680       Perturb-seq       <NA>                      <NA>
# 278681       Perturb-seq       <NA>                      <NA>
# 278682       Perturb-seq       <NA>                      <NA>
# 278683       Perturb-seq       <NA>                      <NA>
#
#                        sequencing_library_kit_label sequencing_platform_id  \
# 0       GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 1       GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2       GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 3       GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 4       GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# ...                                             ...                    ...
# 278679  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 278680  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 278681  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 278682  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 278683  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#        sequencing_platform_label sequencing_strategy_id  \
# 0          Ultima Genomics UG100                   <NA>
# 1          Ultima Genomics UG100                   <NA>
# 2          Ultima Genomics UG100                   <NA>
# 3          Ultima Genomics UG100                   <NA>
# 4          Ultima Genomics UG100                   <NA>
# ...                          ...                    ...
# 278679     Ultima Genomics UG100                   <NA>
# 278680     Ultima Genomics UG100                   <NA>
# 278681     Ultima Genomics UG100                   <NA>
# 278682     Ultima Genomics UG100                   <NA>
# 278683     Ultima Genomics UG100                   <NA>
#
#        sequencing_strategy_label software_counts_id software_counts_label  \
# 0             barcode sequencing               <NA>            CellRanger
# 1             barcode sequencing               <NA>            CellRanger
# 2             barcode sequencing               <NA>            CellRanger
# 3             barcode sequencing               <NA>            CellRanger
# 4             barcode sequencing               <NA>            CellRanger
# ...                          ...                ...                   ...
# 278679        barcode sequencing               <NA>            CellRanger
# 278680        barcode sequencing               <NA>            CellRanger
# 278681        barcode sequencing               <NA>            CellRanger
# 278682        barcode sequencing               <NA>            CellRanger
# 278683        barcode sequencing               <NA>            CellRanger
#
#        software_analysis_id software_analysis_label score_interpretation  \
# 0                      <NA>                  scanpy                 <NA>
# 1                      <NA>                  scanpy                 <NA>
# 2                      <NA>                  scanpy                 <NA>
# 3                      <NA>                  scanpy                 <NA>
# 4                      <NA>                  scanpy                 <NA>
# ...                     ...                     ...                  ...
# 278679                 <NA>                  scanpy                 <NA>
# 278680                 <NA>                  scanpy                 <NA>
# 278681                 <NA>                  scanpy                 <NA>
# 278682                 <NA>                  scanpy                 <NA>
# 278683                 <NA>                  scanpy                 <NA>
#
#        reference_genome_id reference_genome_label  \
# 0                     <NA>                 GRCh38
# 1                     <NA>                 GRCh38
# 2                     <NA>                 GRCh38
# 3                     <NA>                 GRCh38
# 4                     <NA>                 GRCh38
# ...                    ...                    ...
# 278679                <NA>                 GRCh38
# 278680                <NA>                 GRCh38
# 278681                <NA>                 GRCh38
# 278682                <NA>                 GRCh38
# 278683                <NA>                 GRCh38
#
#                                       associated_datasets license_label  \
# 0       [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1       [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2       [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3       [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4       [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                   ...           ...
# 278679  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 278680  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 278681  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 278682  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 278683  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#          license_id
# 0       SWO:9000074
# 1       SWO:9000074
# 2       SWO:9000074
# 3       SWO:9000074
# 4       SWO:9000074
# ...             ...
# 278679  SWO:9000074
# 278680  SWO:9000074
# 278681  SWO:9000074
# 278682  SWO:9000074
# 278683  SWO:9000074
#
# [278684 rows x 99 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ids",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# Missing Ensembl IDs: ['CUSTOM001_PuroR', 'ENSG00000148362', 'ENSG00000139656']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000148362': 'ENSG00000310560', 'ENSG00000139656': 'ENSG00000226519'}
# --------------------------------------------------
# Successfully mapped 18129 out of 18129 Ensembl IDs.
# --------------------------------------------------
# /usr/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# replace gene symbols that are NOT ENSG with original provided gene symbol
cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_symbol'] = cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_name']

# %%
cur_data.adata.var.loc[cur_data.adata.var['ensembl_gene_id'] == 'CUSTOM001_PuroR', 'ensembl_gene_id'] = None

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-02-09 16:11:52,418 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
#        ensembl_gene_id gene_symbol
# index
# 0                 None       PuroR
# 1      ENSG00000000003      TSPAN6
# 2      ENSG00000000005        TNMD
# 3      ENSG00000000419        DPM1
# 4      ENSG00000000457       SCYL3
# ...                ...         ...
# 18124  ENSG00000291110     TRIM16L
# 18125  ENSG00000291122    CASTOR3P
# 18126  ENSG00000291135     FCGR1BP
# 18127  ENSG00000291145     PPP5D1P
# 18128  ENSG00000291237        SOD2
#
# [18129 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data_h5ad()
# Out:
# /content/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ... storing 'dataset_id' as categorical
# ... storing 'data_modality' as categorical
# ... storing 'significance_criteria' as categorical
# ... storing 'perturbed_target_coord' as categorical
# ... storing 'perturbed_target_chromosome' as categorical
# ... storing 'perturbed_target_ensg' as categorical
# ... storing 'perturbed_target_symbol' as categorical
# ... storing 'perturbed_target_biotype' as categorical
# ... storing 'guide_sequence' as categorical
# ... storing 'perturbation_type_label' as categorical
# ... storing 'perturbation_type_id' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'treatment_label' as categorical
# ... storing 'treatment_id' as categorical
# ... storing 'technical_replicate' as categorical
# ... storing 'biological_replicate' as categorical
# ... storing 'model_system_label' as categorical
# ... storing 'model_system_id' as categorical
# ... storing 'species' as categorical
# ... storing 'tissue_label' as categorical
# ... storing 'tissue_id' as categorical
# ... storing 'cell_type_label' as categorical
# ... storing 'cell_type_id' as categorical
# ... storing 'cell_line_label' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'sex_label' as categorical
# ... storing 'sex_id' as categorical
# ... storing 'developmental_stage_label' as categorical
# ... storing 'developmental_stage_id' as categorical
# ... storing 'disease_label' as categorical
# ... storing 'disease_id' as categorical
# ... storing 'study_title' as categorical
# ... storing 'study_uri' as categorical
# ... storing 'first_author' as categorical
# ... storing 'last_author' as categorical
# ... storing 'experiment_title' as categorical
# ... storing 'experiment_summary' as categorical
# ... storing 'number_of_perturbed_targets' as categorical
# ... storing 'number_of_perturbed_samples' as categorical
# ... storing 'library_generation_type_id' as categorical
# ... storing 'library_generation_type_label' as categorical
# ... storing 'library_generation_method_id' as categorical
# ... storing 'library_generation_method_label' as categorical
# ... storing 'enzyme_delivery_method_id' as categorical
# ... storing 'enzyme_delivery_method_label' as categorical
# ... storing 'library_delivery_method_id' as categorical
# ... storing 'library_delivery_method_label' as categorical
# ... storing 'enzyme_integration_state_id' as categorical
# ... storing 'enzyme_integration_state_label' as categorical
# ... storing 'library_integration_state_id' as categorical
# ... storing 'library_integration_state_label' as categorical
# ... storing 'enzyme_expression_control_id' as categorical
# ... storing 'enzyme_expression_control_label' as categorical
# ... storing 'library_expression_control_id' as categorical
# ... storing 'library_expression_control_label' as categorical
# ... storing 'library_name' as categorical
# ... storing 'library_uri' as categorical
# ... storing 'library_format_id' as categorical
# ... storing 'library_format_label' as categorical
# ... storing 'library_scope_id' as categorical
# ... storing 'library_scope_label' as categorical
# ... storing 'library_perturbation_type_id' as categorical
# ... storing 'library_perturbation_type_label' as categorical
# ... storing 'library_manufacturer' as categorical
# ... storing 'library_lentiviral_generation' as categorical
# ... storing 'library_grnas_per_target' as categorical
# ... storing 'library_total_grnas' as categorical
# ... storing 'readout_dimensionality_id' as categorical
# ... storing 'readout_dimensionality_label' as categorical
# ... storing 'readout_type_id' as categorical
# ... storing 'readout_type_label' as categorical
# ... storing 'readout_technology_id' as categorical
# ... storing 'readout_technology_label' as categorical
# ... storing 'method_name_id' as categorical
# ... storing 'method_name_label' as categorical
# ... storing 'method_uri' as categorical
# ... storing 'sequencing_library_kit_id' as categorical
# ... storing 'sequencing_library_kit_label' as categorical
# ... storing 'sequencing_platform_id' as categorical
# ... storing 'sequencing_platform_label' as categorical
# ... storing 'sequencing_strategy_id' as categorical
# ... storing 'sequencing_strategy_label' as categorical
# ... storing 'software_counts_id' as categorical
# ... storing 'software_counts_label' as categorical
# ... storing 'software_analysis_id' as categorical
# ... storing 'software_analysis_label' as categorical
# ... storing 'score_interpretation' as categorical
# ... storing 'reference_genome_id' as categorical
# ... storing 'reference_genome_label' as categorical
# ... storing 'associated_datasets' as categorical
# ... storing 'license_label' as categorical
# ... storing 'license_id' as categorical
# ... storing 'ensembl_gene_id' as categorical
# ... storing 'gene_symbol' as categorical
# ✅ Curated h5ad data saved to /content/PerturbationCatalogue/data_exploration/Perturbseq/curated/h5ad/zhu_2025_pseudobulk_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to /content/PerturbationCatalogue/data_exploration/Perturbseq/curated/parquet/zhu_2025_pseudobulk_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
upload_parquet_to_bq(
    parquet_path='/content/PerturbationCatalogue/data_exploration/Perturbseq/curated/parquet/zhu_2025_pseudobulk_curated_metadata.parquet',
    bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
    bq_table_name='metadata',
    key_columns=['dataset_id', 'sample_id'],
    verbose=True
)
# Out:
# Staging table: loading `.parquet` file /content/PerturbationCatalogue/data_exploration/Perturbseq/curated/parquet/GWCD4i.pseudobulk_merged_curated_metadata.parquet to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging...
# Staging table: loaded 278684 rows to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.perturb_seq.metadata with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp /content/PerturbationCatalogue/data_exploration/Perturbseq/curated/h5ad/zhu_2025_pseudobulk_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
# Out:
# WARNING: Parallel composite upload was turned ON to get the best performance on
# uploading large objects. If you would like to opt-out and instead
# perform a normal upload, run:
# `gcloud config set storage/parallel_composite_upload_enabled False`
# If you would like to disable this warning, run:
# `gcloud config set storage/parallel_composite_upload_enabled True`
# Note that with parallel composite uploads, your object might be
# uploaded as a composite object
# (https://cloud.google.com/storage/docs/composite-objects), which means
# that any user who downloads your object will need to use crc32c
# checksums to verify data integrity. gcloud storage is capable of
# computing crc32c checksums, but this might pose a problem for other
# clients.
#
# Copying file:///content/PerturbationCatalogue/data_exploration/Perturbseq/curated/h5ad/zhu_2025_pseudobulk_curated.h5ad to gs://perturbation-catalogue-lake/perturbseq/curated/zhu_2025_pseudobulk_curated.h5ad
#
# Average throughput: 65.9MiB/s

# %%
cur_data.adata.obs[cur_data.adata.obs['sample_id'] == '92281']
# Out:
#                 dataset_id sample_id data_modality  significant  \
# 92280  zhu_2025_pseudobulk     92281   Perturb-seq          NaN
#
#       significance_criteria             perturbation_name  \
# 92280                  <NA>  CD4i_R1_D1_Stim8hr_SMIM11B-2
#
#       perturbed_target_coord perturbed_target_chromosome  \
# 92280                    NaN                         NaN
#
#        perturbed_target_chromosome_encoding  perturbed_target_number  \
# 92280                                     0                        1
#
#       perturbed_target_ensg perturbed_target_symbol perturbed_target_biotype  \
# 92280                  <NA>                 SMIM11B                     <NA>
#
#              guide_sequence perturbation_type_label perturbation_type_id  \
# 92280  CTTACTGCTCCCGGCAGCGG                 CRISPRi                 <NA>
#
#          timepoint                                    treatment_label  \
# 92280  P12DT8H0M0S  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                treatment_id technical_replicate  \
# 92280  EFO:0003317|EFO:0003304|NCIT:C184729                <NA>
#
#       biological_replicate model_system_label model_system_id       species  \
# 92280         D1_CE0008162       primary_cell            <NA>  Homo sapiens
#
#           tissue_label       tissue_id                  cell_type_label  \
# 92280  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#       cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 92280   CL:0000624            <NA>         <NA>    female   <NA>
#
#       developmental_stage_label developmental_stage_id disease_label  \
# 92280                     adult                   <NA>       healthy
#
#       disease_id                                        study_title  \
# 92280       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                         study_uri  study_year first_author  \
# 92280  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#             last_author                                   experiment_title  \
# 92280  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                       experiment_summary  \
# 92280  \n            Isolated human CD4-positive cell...
#
#       number_of_perturbed_targets number_of_perturbed_samples  \
# 92280                       12731                      278684
#
#       library_generation_type_id library_generation_type_label  \
# 92280                EFO:0022868                    endogenous
#
#       library_generation_method_id library_generation_method_label  \
# 92280                         <NA>                 dCas9-KRAB-Zim3
#
#       enzyme_delivery_method_id enzyme_delivery_method_label  \
# 92280                      <NA>      lentivirus transduction
#
#       library_delivery_method_id library_delivery_method_label  \
# 92280                       <NA>       lentivirus transduction
#
#       enzyme_integration_state_id enzyme_integration_state_label  \
# 92280                        <NA>       random locus integration
#
#       library_integration_state_id library_integration_state_label  \
# 92280                         <NA>        random locus integration
#
#       enzyme_expression_control_id    enzyme_expression_control_label  \
# 92280                         <NA>  constitutive transgene expression
#
#       library_expression_control_id   library_expression_control_label  \
# 92280                          <NA>  constitutive transgene expression
#
#       library_name library_uri library_format_id library_format_label  \
# 92280       custom        <NA>              <NA>               pooled
#
#       library_scope_id library_scope_label library_perturbation_type_id  \
# 92280             <NA>             focused                         <NA>
#
#       library_perturbation_type_label library_manufacturer  \
# 92280                      inhibition           Marson lab
#
#       library_lentiviral_generation library_grnas_per_target  \
# 92280                             2                        2
#
#       library_total_grnas  library_total_variants readout_dimensionality_id  \
# 92280               25954                    <NA>                      <NA>
#
#       readout_dimensionality_label readout_type_id readout_type_label  \
# 92280       high-dimensional assay            <NA>     transcriptomic
#
#       readout_technology_id readout_technology_label method_name_id  \
# 92280                  <NA>      single-cell rna-seq           <NA>
#
#       method_name_label method_uri sequencing_library_kit_id  \
# 92280       Perturb-seq       <NA>                      <NA>
#
#                       sequencing_library_kit_label sequencing_platform_id  \
# 92280  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#       sequencing_platform_label sequencing_strategy_id  \
# 92280     Ultima Genomics UG100                   <NA>
#
#       sequencing_strategy_label software_counts_id software_counts_label  \
# 92280        barcode sequencing               <NA>            CellRanger
#
#       software_analysis_id software_analysis_label score_interpretation  \
# 92280                 <NA>                  scanpy                 <NA>
#
#       reference_genome_id reference_genome_label  \
# 92280                <NA>                 GRCh38
#
#                                      associated_datasets license_label  \
# 92280  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#         license_id
# 92280  SWO:9000074

# %%
cur_data.gene_ont[cur_data.gene_ont['synonym'] == 'SMIM11B']
# Out:
# Empty DataFrame
# Columns: [ensembl_gene_id, gene_symbol, chromosome_name, gene_coord, biotype, description, synonym_type, synonym]
# Index: []
