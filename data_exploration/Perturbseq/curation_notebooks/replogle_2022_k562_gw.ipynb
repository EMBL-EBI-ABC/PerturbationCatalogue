# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)

# %% [markdown]
# # Download data

# %%
noncurated_path = "../non_curated/h5ad/replogle_2022_k562_gw_raw.h5ad"
download_file(
    url="https://ndownloader.figshare.com/files/35775507",
    dest_path=noncurated_path
)
# Out:
# 2026-04-23 11:52:17,838 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): ndownloader.figshare.com:443
# 2026-04-23 11:52:17,911 DEBUG urllib3.connectionpool: https://ndownloader.figshare.com:443 "GET /files/35775507 HTTP/1.1" 302 0
# 2026-04-23 11:52:17,913 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): s3-eu-west-1.amazonaws.com:443
# 2026-04-23 11:52:18,170 DEBUG urllib3.connectionpool: https://s3-eu-west-1.amazonaws.com:443 "GET /ptemp-plus-8475456492/35775507/K562_gwps_raw_singlecell_01.h5ad?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA3OGA3B5WLN3GODUZ/20260423/eu-west-1/s3/aws4_request&X-Amz-Date=20260423T105217Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=af480a31af7f00290a6b1646e0249f08bed27fd7c04ff9738b8f9f97a433fc03 HTTP/1.1" 200 65830941948
# Downloaded https://ndownloader.figshare.com/files/35775507 to ../non_curated/h5ad/replogle_2022_k562_gw_raw.h5ad

# %% [markdown]
# # Initialise the dataset object

# %%
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from ../non_curated/h5ad/replogle_2022_k562_gw_raw.h5ad

# %%
cur_data.adata.obs
# Out:
#                       gem_group     gene          gene_id         transcript  \
# cell_barcode
# AAACCCAAGAAACCAT-157        157     CTSC  ENSG00000109861               P1P2
# AAACCCAAGAAACCAT-207        207    CWC25  ENSG00000273559               P1P2
# AAACCCAAGAAACCAT-29          29  PDE4DIP  ENSG00000178104  ENST00000313431.9
# AAACCCAAGAAAGCGA-149        149    ZZEF1  ENSG00000074755               P1P2
# AAACCCAAGAAATCCA-172        172   SNAPIN  ENSG00000143553               P1P2
# ...                         ...      ...              ...                ...
# TTTGTTGTCTTTCCAA-201        201    SCRIB  ENSG00000180900               P1P2
# TTTGTTGTCTTTCGAT-79          79    CADM4  ENSG00000105767               P1P2
# TTTGTTGTCTTTCTAG-218        218   SLC4A7  ENSG00000033867               P1P2
# TTTGTTGTCTTTGCGC-169        169  TMEM131  ENSG00000075568               P1P2
# TTTGTTGTCTTTGCGC-213        213    SRP14  ENSG00000140319               P1P2
#
#                                                      gene_transcript  \
# cell_barcode
# AAACCCAAGAAACCAT-157                  1946_CTSC_P1P2_ENSG00000109861
# AAACCCAAGAAACCAT-207                 1973_CWC25_P1P2_ENSG00000273559
# TTTGTTGTCTTTCCAA-201           1.151834             10302.698242
# TTTGTTGTCTTTCGAT-79            0.935249              6882.660156
# TTTGTTGTCTTTCTAG-218           1.000028             11376.682617
# TTTGTTGTCTTTGCGC-169           1.023092             10417.442383
# TTTGTTGTCTTTGCGC-213           1.398296             13078.065430
#
# [1989578 rows x 11 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Add cell barcodes to the obs slot

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.astype(str)

print(cur_data.adata.obs[['cell_barcode']].head())
# Out:
#                               cell_barcode
# cell_barcode
# AAACCCAAGAAACCAT-157  AAACCCAAGAAACCAT-157
# AAACCCAAGAAACCAT-207  AAACCCAAGAAACCAT-207
# AAACCCAAGAAACCAT-29    AAACCCAAGAAACCAT-29
# AAACCCAAGAAAGCGA-149  AAACCCAAGAAAGCGA-149
# AAACCCAAGAAATCCA-172  AAACCCAAGAAATCCA-172

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'sgID_AB')
# Out:
# Unique values in adata.obs.sgID_AB: 11187
# --------------------------------------------------
# {'A1BG_+_58858964.23-P1|A1BG_-_58858788.23-P1',
#  'A1BG_-_58864840.23-P2|A1BG_-_58864822.23-P2',
#  'AAAS_-_53715438.23-P1P2|AAAS_+_53715355.23-P1P2',
#  'AACS_+_125549983.23-P1P2|AACS_-_125550169.23-P1P2',
#  'AAED1_-_99417574.23-P1P2|AAED1_+_99417525.23-P1P2',
#  'AAGAB_-_67546997.23-P1P2|AAGAB_-_67546928.23-P1P2',
#  'AAK1_-_69870791.23-P1P2|AAK1_-_69870794.23-P1P2',
#  'AAMDC_-_77532236.23-P1P2|AAMDC_-_77532222.23-P1P2',
#  'AAMP_+_219134851.23-P1P2|AAMP_+_219134841.23-P1P2',
#  'AAR2_-_34824434.23-P1P2|AAR2_+_34824488.23-P1P2',
#  'AARS2_+_44281027.23-P1P2|AARS2_+_44281044.23-P1P2',
#  'AARSD1_+_41132061.23-P2|AARSD1_-_41132037.23-P2',
#  'AARSD1_-_41116425.23-P1|AARSD1_+_41116412.23-P1',
#  'AARS_+_70323362.23-P1P2|AARS_-_70323332.23-P1P2',
#  'AASDHPPT_+_105948405.23-P1P2|AASDHPPT_+_105948450.23-P1P2',
#  'AASDH_-_57253588.23-P1P2|AASDH_+_57253570.23-P1P2',
#  'AATF_-_35306286.23-P1P2|AATF_-_35306346.23-P1P2',
#  'ABCA7_+_1041311.23-P2|ABCA7_-_1041459.23-P2',
#  'ABCA7_-_1040133.23-P1|ABCA7_+_1040185.23-P1',
#  'ABCA8_+_66951401.23-P1P2|ABCA8_-_66951525.23-P1P2',
#  'ABCB10_+_229694285.23-P1P2|ABCB10_-_229694297.23-P1P2',
#  'ABCB6_-_220083604.23-P1P2|ABCB6_+_220083613.23-P1P2',
#  'ABCB7_-_74376019.23-P1P2|ABCB7_+_74375885.23-P1P2',
#  'ABCB8_-_150725551.23-P1P2|ABCB8_-_150725580.23-P1P2',
#  'BOLA2_-_29466260.23-ENST00000330978.3|BOLA2_+_29466246.23-ENST00000330978.3',
#  'BOLA3_-_74375058.23-P1P2|BOLA3_+_74374936.23-P1P2',
#  'BOP1_+_145515084.23-P1|BOP1_+_145515090.23-P1',
#  'BOP1_-_145512830.23-P2|BOP1_+_145512867.23-P2',
# ...
#  'non-targeting_01161|non-targeting_02504',
#  'non-targeting_01177|non-targeting_02711',
#  'non-targeting_01185|non-targeting_02678',
#  'non-targeting_01188|non-targeting_03030',
#  'non-targeting_01190|non-targeting_00619',
#  'non-targeting_01196|non-targeting_03048',
#  'non-targeting_01197|non-targeting_02671',
#  'non-targeting_01209|non-targeting_00834',
#  'non-targeting_01215|non-targeting_02173',
#  'non-targeting_01218|non-targeting_02001',
#  'non-targeting_01224|non-targeting_00504',
#  'non-targeting_01232|non-targeting_02028',
#  'non-targeting_01236|non-targeting_03229',
#  'non-targeting_01241|non-targeting_00165',
#  'non-targeting_01245|non-targeting_02634',
#  'non-targeting_01258|non-targeting_03183',
#  'non-targeting_01269|non-targeting_02539',
#  'non-targeting_01278|non-targeting_02363',
#  'non-targeting_01281|non-targeting_01871',
#  'non-targeting_01283|non-targeting_03681',
#  'non-targeting_01291|non-targeting_03673',
#  'non-targeting_01294|non-targeting_01201',
#  'non-targeting_01298|non-targeting_02984',
#  'non-targeting_01332|non-targeting_02054',
#  'non-targeting_01339|non-targeting_02089',
#  'non-targeting_01344|non-targeting_02013',
#  'non-targeting_01348|non-targeting_02617',
#  'non-targeting_01355|non-targeting_01062',
#  'non-targeting_01357|non-targeting_02697',
#  'non-targeting_01367|non-targeting_02185',
#  'non-targeting_01371|non-targeting_00870',
#  'non-targeting_01373|non-targeting_01032',
#  'non-targeting_01376|non-targeting_00354',
#  'non-targeting_01392|non-targeting_01404',
#  'non-targeting_01395|non-targeting_02523',
#  'non-targeting_01399|non-targeting_00303',
#  'non-targeting_01412|non-targeting_02078',
#  'non-targeting_01421|non-targeting_02598',
#  'non-targeting_01426|non-targeting_02531',
#  'non-targeting_01435|non-targeting_00348',
#  'non-targeting_01469|non-targeting_02714',
#  'non-targeting_01471|non-targeting_03683',
#  'non-targeting_01485|non-targeting_00292',
#  'non-targeting_01495|non-targeting_00655',
#  'non-targeting_01498|non-targeting_01333',
#  'non-targeting_01522|non-targeting_01520',
#  'non-targeting_01524|non-targeting_03498',
#  'non-targeting_01525|non-targeting_01380',
#  'non-targeting_01527|non-targeting_03765',
#  'non-targeting_01530|non-targeting_03007',
#  'non-targeting_01532|non-targeting_02599',
#  'non-targeting_01538|non-targeting_00001',
#  'non-targeting_01542|non-targeting_01896',
#  'non-targeting_01550|non-targeting_03505',
#  'non-targeting_01566|non-targeting_03182',
#  'non-targeting_01591|non-targeting_00063',
#  'non-targeting_01603|non-targeting_01563',
#  'non-targeting_01607|non-targeting_01052',
#  'non-targeting_01611|non-targeting_01672',
#  'non-targeting_01615|non-targeting_02905',
#  'non-targeting_01628|non-targeting_03433',
#  'non-targeting_01633|non-targeting_00310',
#  'non-targeting_01636|non-targeting_02405',
#  'non-targeting_01647|non-targeting_03039',
#  'non-targeting_01655|non-targeting_03541',
#  'non-targeting_01656|non-targeting_03669',
#  'non-targeting_01660|non-targeting_01229',
#  'non-targeting_01666|non-targeting_00671',
#  'non-targeting_01705|non-targeting_02538',
#  'non-targeting_01712|non-targeting_03276',
#  'non-targeting_01717|non-targeting_01814',
#  'non-targeting_01721|non-targeting_01433',
#  'non-targeting_01723|non-targeting_01138',
#  'non-targeting_01725|non-targeting_00813',
#  'non-targeting_01730|non-targeting_03520',
#  'non-targeting_01734|non-targeting_03775',
#  'non-targeting_01736|non-targeting_01474',
#  'non-targeting_01744|non-targeting_03196',
#  'non-targeting_01763|non-targeting_02345',
#  'non-targeting_01779|non-targeting_03361',
#  'non-targeting_01792|non-targeting_02575',
#  'non-targeting_01798|non-targeting_01119',
#  'non-targeting_01806|non-targeting_01016',
#  'non-targeting_01813|non-targeting_00122',
#  'non-targeting_01817|non-targeting_03136',
#  'non-targeting_01822|non-targeting_02548',
#  'non-targeting_01823|non-targeting_00796',
#  'non-targeting_01826|non-targeting_03083',
#  'non-targeting_01833|non-targeting_01864',
#  'non-targeting_01849|non-targeting_03668',
#  'non-targeting_01853|non-targeting_01794',
#  'non-targeting_01855|non-targeting_02924',
#  'non-targeting_01861|non-targeting_01704',
#  'non-targeting_01869|non-targeting_02165',
#  'non-targeting_01881|non-targeting_00848',
#  'non-targeting_01894|non-targeting_01677',
#  'non-targeting_01900|non-targeting_01280',
#  'non-targeting_01907|non-targeting_01998',
#  'non-targeting_01910|non-targeting_02981',
#  'non-targeting_01923|non-targeting_01156',
#  'non-targeting_01936|non-targeting_01870',
#  'non-targeting_01938|non-targeting_03442',
#  'non-targeting_01939|non-targeting_03024',
#  'non-targeting_01945|non-targeting_00636',
#  'non-targeting_01948|non-targeting_02744',
#  'non-targeting_01957|non-targeting_01159',
#  'non-targeting_01958|non-targeting_03465',
#  'non-targeting_01961|non-targeting_00390',
#  'non-targeting_01967|non-targeting_00082',
#  'non-targeting_01976|non-targeting_00463',
#  'non-targeting_01987|non-targeting_02992',
#  'non-targeting_01989|non-targeting_01304',
#  'non-targeting_01999|non-targeting_01911',
#  'non-targeting_02010|non-targeting_01147',
#  'non-targeting_02021|non-targeting_00117',
#  'non-targeting_02030|non-targeting_01760',
#  'non-targeting_02035|non-targeting_03407',
#  'non-targeting_02037|non-targeting_02869',
#  'non-targeting_02038|non-targeting_01350',
#  'non-targeting_02039|non-targeting_01077',
#  'non-targeting_02046|non-targeting_01500',
#  'non-targeting_02049|non-targeting_03476',
#  'non-targeting_02052|non-targeting_01483',
#  'non-targeting_02053|non-targeting_02584',
#  'non-targeting_02057|non-targeting_01508',
#  'non-targeting_02068|non-targeting_01588',
#  'non-targeting_02080|non-targeting_00151',
#  'non-targeting_02097|non-targeting_02279',
#  'non-targeting_02126|non-targeting_02323',
#  'non-targeting_02138|non-targeting_02804',
#  'non-targeting_02142|non-targeting_02703',
#  'non-targeting_02154|non-targeting_01007',
#  'non-targeting_02155|non-targeting_00500',
#  'non-targeting_02167|non-targeting_00049',
#  'non-targeting_02191|non-targeting_03218',
#  'non-targeting_02196|non-targeting_03224',
#  'non-targeting_02200|non-targeting_01033',
#  'non-targeting_02214|non-targeting_03351',
#  'non-targeting_02227|non-targeting_00139',
#  'non-targeting_02242|non-targeting_02371',
#  'non-targeting_02244|non-targeting_01027',
#  'non-targeting_02247|non-targeting_03104',
#  'non-targeting_02248|non-targeting_02255',
#  'non-targeting_02253|non-targeting_03421',
#  'non-targeting_02259|non-targeting_02171',
#  'non-targeting_02273|non-targeting_03719',
#  'non-targeting_02274|non-targeting_01075',
#  'non-targeting_02278|non-targeting_02815',
#  'non-targeting_02293|non-targeting_03178',
#  'non-targeting_02297|non-targeting_01410',
#  'non-targeting_02307|non-targeting_02721',
#  'non-targeting_02314|non-targeting_02526',
#  'non-targeting_02332|non-targeting_03333',
#  'non-targeting_02354|non-targeting_01234',
#  'non-targeting_02358|non-targeting_00822',
#  'non-targeting_02364|non-targeting_02477',
#  'non-targeting_02374|non-targeting_01832',
#  'non-targeting_02396|non-targeting_00565',
#  'non-targeting_02432|non-targeting_01810',
#  'non-targeting_02438|non-targeting_00448',
#  'non-targeting_02443|non-targeting_00307',
#  'non-targeting_02444|non-targeting_03378',
#  'non-targeting_02446|non-targeting_00513',
#  'non-targeting_02448|non-targeting_02256',
#  'non-targeting_02451|non-targeting_02032',
#  'non-targeting_02455|non-targeting_01880',
#  'non-targeting_02458|non-targeting_03087',
#  'non-targeting_02459|non-targeting_01512',
#  'non-targeting_02461|non-targeting_00432',
#  'non-targeting_02462|non-targeting_01640',
#  'non-targeting_02465|non-targeting_01624',
#  'non-targeting_02478|non-targeting_03310',
#  'non-targeting_02481|non-targeting_02587',
#  'non-targeting_02484|non-targeting_03585',
#  'non-targeting_02487|non-targeting_02435',
#  'non-targeting_02488|non-targeting_02609',
#  'non-targeting_02493|non-targeting_02549',
#  'non-targeting_02498|non-targeting_03354',
#  'non-targeting_02501|non-targeting_02402',
#  'non-targeting_02505|non-targeting_01287',
#  'non-targeting_02510|non-targeting_02947',
#  'non-targeting_02511|non-targeting_01851',
#  'non-targeting_02514|non-targeting_02058',
#  'non-targeting_02520|non-targeting_01428',
#  'non-targeting_02521|non-targeting_01091',
#  'non-targeting_02533|non-targeting_03168',
#  'non-targeting_02537|non-targeting_03399',
#  'non-targeting_02544|non-targeting_00995',
#  'non-targeting_02567|non-targeting_02708',
#  'non-targeting_02570|non-targeting_01477',
#  'non-targeting_02573|non-targeting_00654',
#  'non-targeting_02577|non-targeting_00178',
#  'non-targeting_02578|non-targeting_02124',
#  'non-targeting_02596|non-targeting_01746',
#  'non-targeting_02597|non-targeting_01282',
#  'non-targeting_02607|non-targeting_01402',
#  'non-targeting_02608|non-targeting_01901',
#  'non-targeting_02610|non-targeting_00150',
#  'non-targeting_02611|non-targeting_00353',
#  'non-targeting_02621|non-targeting_02020',
#  'non-targeting_02624|non-targeting_01182',
#  'non-targeting_02627|non-targeting_03573',
#  'non-targeting_02628|non-targeting_01634',
#  'non-targeting_02637|non-targeting_00926',
#  'non-targeting_02640|non-targeting_01574',
#  'non-targeting_02649|non-targeting_02725',
#  'non-targeting_02654|non-targeting_02082',
#  'non-targeting_02659|non-targeting_00060',
#  'non-targeting_02668|non-targeting_03017',
#  'non-targeting_02684|non-targeting_03653',
#  'non-targeting_02691|non-targeting_01195',
#  'non-targeting_02698|non-targeting_03556',
#  'non-targeting_02705|non-targeting_01092',
#  'non-targeting_02734|non-targeting_02732',
#  'non-targeting_02738|non-targeting_00469',
#  'non-targeting_02741|non-targeting_00859',
#  'non-targeting_02750|non-targeting_00617',
#  'non-targeting_02755|non-targeting_00566',
#  'non-targeting_02766|non-targeting_01799',
#  'non-targeting_02774|non-targeting_00697',
#  'non-targeting_02778|non-targeting_00801',
#  'non-targeting_02779|non-targeting_03470',
#  'non-targeting_02787|non-targeting_01465',
#  'non-targeting_02789|non-targeting_00992',
#  'non-targeting_02790|non-targeting_01697',
#  'non-targeting_02797|non-targeting_02967',
#  'non-targeting_02801|non-targeting_02839',
#  'non-targeting_02802|non-targeting_02033',
#  'non-targeting_02816|non-targeting_02012',
#  'non-targeting_02819|non-targeting_01549',
#  'non-targeting_02821|non-targeting_02347',
#  'non-targeting_02823|non-targeting_00887',
#  'non-targeting_02825|non-targeting_01847',
#  'non-targeting_02829|non-targeting_01335',
#  'non-targeting_02836|non-targeting_03210',
#  'non-targeting_02845|non-targeting_01741',
#  'non-targeting_02846|non-targeting_02817',
#  'non-targeting_02855|non-targeting_01051',
#  'non-targeting_02860|non-targeting_03270',
#  'non-targeting_02872|non-targeting_01067',
#  'non-targeting_02877|non-targeting_03592',
#  'non-targeting_02879|non-targeting_00558',
#  'non-targeting_02894|non-targeting_01038',
#  'non-targeting_02902|non-targeting_02884',
#  'non-targeting_02908|non-targeting_02422',
#  'non-targeting_02921|non-targeting_01004',
#  'non-targeting_02937|non-targeting_00325',
#  'non-targeting_02961|non-targeting_01457',
#  'non-targeting_02963|non-targeting_00641',
#  'non-targeting_02969|non-targeting_00236',
#  'non-targeting_02989|non-targeting_02406',
#  'non-targeting_02999|non-targeting_03659',
#  'non-targeting_03027|non-targeting_00744',
#  'non-targeting_03028|non-targeting_01238',
#  'non-targeting_03035|non-targeting_03777',
#  'non-targeting_03043|non-targeting_00703',
#  'non-targeting_03044|non-targeting_00667',
#  'non-targeting_03045|non-targeting_02403',
#  'non-targeting_03049|non-targeting_00739',
#  'non-targeting_03052|non-targeting_02210',
#  'non-targeting_03056|non-targeting_00625',
#  'non-targeting_03060|non-targeting_03678',
#  'non-targeting_03063|non-targeting_02055',
#  'non-targeting_03068|non-targeting_00091',
#  'non-targeting_03080|non-targeting_01844',
#  'non-targeting_03089|non-targeting_01127',
#  'non-targeting_03114|non-targeting_00481',
#  'non-targeting_03116|non-targeting_00126',
#  'non-targeting_03120|non-targeting_02862',
#  'non-targeting_03123|non-targeting_03725',
#  'non-targeting_03135|non-targeting_02838',
#  'non-targeting_03141|non-targeting_03160',
#  'non-targeting_03149|non-targeting_03036',
#  'non-targeting_03155|non-targeting_01225',
#  'non-targeting_03158|non-targeting_03436',
#  'non-targeting_03162|non-targeting_00358',
#  'non-targeting_03171|non-targeting_03032',
#  'non-targeting_03176|non-targeting_02026',
#  'non-targeting_03181|non-targeting_01276',
#  'non-targeting_03185|non-targeting_00576',
#  'non-targeting_03195|non-targeting_01057',
#  'non-targeting_03215|non-targeting_02798',
#  'non-targeting_03216|non-targeting_03157',
#  'non-targeting_03219|non-targeting_01733',
#  'non-targeting_03240|non-targeting_03788',
#  'non-targeting_03248|non-targeting_02361',
#  'non-targeting_03258|non-targeting_01564',
#  'non-targeting_03262|non-targeting_01338',
#  'non-targeting_03275|non-targeting_01954',
#  'non-targeting_03294|non-targeting_03094',
#  'non-targeting_03296|non-targeting_03317',
#  'non-targeting_03306|non-targeting_03356',
#  'non-targeting_03307|non-targeting_01551',
#  'non-targeting_03318|non-targeting_00221',
#  'non-targeting_03324|non-targeting_02161',
#  'non-targeting_03335|non-targeting_03594',
#  'non-targeting_03340|non-targeting_02859',
#  'non-targeting_03342|non-targeting_01473',
#  'non-targeting_03346|non-targeting_01783',
#  'non-targeting_03370|non-targeting_03288',
#  'non-targeting_03398|non-targeting_02889',
#  'non-targeting_03424|non-targeting_00110',
#  'non-targeting_03426|non-targeting_02982',
#  'non-targeting_03429|non-targeting_00079',
#  'non-targeting_03441|non-targeting_00663',
#  'non-targeting_03446|non-targeting_00668',
#  'non-targeting_03454|non-targeting_01173',
#  'non-targeting_03462|non-targeting_00434',
#  'non-targeting_03467|non-targeting_01317',
#  'non-targeting_03468|non-targeting_01711',
#  'non-targeting_03471|non-targeting_03652',
#  'non-targeting_03477|non-targeting_02464',
#  'non-targeting_03478|non-targeting_00527',
#  'non-targeting_03482|non-targeting_02176',
#  'non-targeting_03483|non-targeting_01497',
#  'non-targeting_03484|non-targeting_02953',
#  'non-targeting_03489|non-targeting_02373',
#  'non-targeting_03491|non-targeting_01510',
#  'non-targeting_03492|non-targeting_00459',
#  'non-targeting_03504|non-targeting_02717',
#  'non-targeting_03514|non-targeting_00735',
#  'non-targeting_03521|non-targeting_02629',
#  'non-targeting_03522|non-targeting_02177',
#  'non-targeting_03523|non-targeting_00802',
#  'non-targeting_03526|non-targeting_01571',
#  'non-targeting_03530|non-targeting_01407',
#  'non-targeting_03535|non-targeting_03661',
#  'non-targeting_03548|non-targeting_00145',
#  'non-targeting_03549|non-targeting_01559',
#  'non-targeting_03552|non-targeting_01537',
#  'non-targeting_03553|non-targeting_03304',
#  'non-targeting_03554|non-targeting_01676',
#  'non-targeting_03559|non-targeting_03602',
#  'non-targeting_03560|non-targeting_02075',
#  'non-targeting_03591|non-targeting_02077',
#  'non-targeting_03600|non-targeting_00547',
#  'non-targeting_03615|non-targeting_02225',
#  'non-targeting_03617|non-targeting_01158',
#  'non-targeting_03623|non-targeting_02639',
#  'non-targeting_03624|non-targeting_03589',
#  'non-targeting_03629|non-targeting_02182',
#  'non-targeting_03630|non-targeting_02353',
#  'non-targeting_03631|non-targeting_02264',
#  'non-targeting_03639|non-targeting_01632',
#  'non-targeting_03647|non-targeting_00899',
#  'non-targeting_03649|non-targeting_00208',
#  'non-targeting_03665|non-targeting_03703',
#  'non-targeting_03674|non-targeting_00904',
#  'non-targeting_03685|non-targeting_02934',
#  'non-targeting_03695|non-targeting_03558',
#  'non-targeting_03711|non-targeting_02359',
#  'non-targeting_03715|non-targeting_02480',
#  'non-targeting_03721|non-targeting_02172',
#  'non-targeting_03735|non-targeting_03577',
#  'non-targeting_03750|non-targeting_03232',
#  'non-targeting_03751|non-targeting_00758',
#  'non-targeting_03754|non-targeting_02423',
#  'non-targeting_03756|non-targeting_01543',
#  'non-targeting_03758|non-targeting_00493',
#  'non-targeting_03778|non-targeting_00397',
#  'non-targeting_03783|non-targeting_02098',
#  'non-targeting_03787|non-targeting_00777'}
# --------------------------------------------------

# %% [markdown]
# ### Rename `sgID_AB` to `perturbation_name`

# %%
cur_data.rename_columns(slot = 'obs', name_dict = {'sgID_AB': 'perturbation_name'})
# Out:
# Renamed columns in adata.obs: {'sgID_AB': 'perturbation_name'}

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://ars.els-cdn.com/content/image/1-s2.0-S0092867422005979-mmc1.xlsx",
    dest_path="../supplementary/replogle_2022_guide_info.xlsx"
)

# read in the guide RNA spreadsheet
# guides for the K562 essential day 6 library are in "TabB_K562_day6_library"
guide_info_df = pd.read_excel("../supplementary/replogle_2022_guide_info.xlsx", sheet_name="TabA_K562_day8_library")

# create perturbation_name column in guide_info_df
guide_info_df['perturbation_name'] = guide_info_df['sgID_A'] + '|' + guide_info_df['sgID_B']
# replace commas with hyphens in perturbation_name
guide_info_df['perturbation_name'] = guide_info_df['perturbation_name'].str.replace(',', '-')
# check that all perturbation names in cur_data are in guide_info_df
print(f"All perturbation names in cur_data are in guide_info_df: {cur_data.adata.obs['perturbation_name'].isin(guide_info_df['perturbation_name']).all()}")
# create guide_sequence column in guide_info_df
guide_info_df['guide_sequence'] = guide_info_df['targeting sequence A'] + '|' + guide_info_df['targeting sequence B']
# subset for necessary columns
guide_info_df = guide_info_df[['perturbation_name', 'guide_sequence']]
# merge cur_data.adata.obs with guide_info_df on perturbation_name
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='perturbation_name', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# File ../supplementary/replogle_2022_guide_info.xlsx already exists. Skipping download.
# All perturbation names in cur_data are in guide_info_df: True
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Number of missing guide sequences: 0

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='gene',
    input_column_type='gene_symbol',
    multiple_entries=False
)
# Out:
# Mapping gene symbols: 100%|██████████████████████████████████| 9867/9867 [00:00<00:00, 25539.50it/s]
# --------------------------------------------------
# Successfully mapped 9862 out of 9867 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['non-targeting', 'AC015871.1', 'MTRNR2L1', 'AC118549.1', 'MTRNR2L8']
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
cur_data.count_entries(
    slot='obs',
    input_column='perturbed_target_symbol',
    count_column_name='perturbed_target_number',
    sep='|'
)
# Out:
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.show_obs(['perturbation_name', 'perturbed_target_chromosome_encoding'])
# Out:
# Observation data:
# DataFrame shape: (1989578, 2)
# --------------------------------------------------
#                                          perturbation_name  \
# index
# 0          CTSC_-_88070848.23-P1P2|CTSC_-_88070918.23-P1P2
# 1        CWC25_+_36981555.23-P1P2|CWC25_+_36981567.23-P1P2
# 2        PDE4DIP_+_144932474.23-ENST00000313431.9|PDE4D...
# 3          ZZEF1_+_4046247.23-P1P2|ZZEF1_+_4046255.23-P1P2
# 4        SNAPIN_+_153631238.23-P1P2|SNAPIN_-_153631252....
# ...                                                    ...
# 1989573  SCRIB_-_144897465.23-P1P2|SCRIB_-_144897339.23...
# 1989574  CADM4_+_44143915.23-P1P2|CADM4_+_44143932.23-P1P2
# 1989575  SLC4A7_+_27525847.23-P1P2|SLC4A7_+_27525631.23...
# 1989576  TMEM131_-_98612356.23-P1P2|TMEM131_-_98612239....
# 1989577  SRP14_+_40331287.23-P1P2|SRP14_-_40330986.23-P1P2
#
#          perturbed_target_chromosome_encoding
# index
# 0                                          11
# 1                                          17
# 2                                           1
# 3                                          17
# 4                                           1
# ...                                       ...
# 1989573                                     8
# 1989574                                    19
# 1989575                                     3
# 1989576                                     2
# 1989577                                    15
#
# [1989578 rows x 2 columns]
# --------------------------------------------------

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": None,
        "treatment_id": None,
        # replicates
        "technical_replicate": None,
        "biological_replicate": None,
        # model system
        "model_system_label": "cell_line",
        "model_system_id": None,
        "tissue": "blood",
        "cell_line_label": "K 562 cell",
        "cell_type_label": "lymphoblast",
        "disease_label": "chronic myelogenous leukemia, BCR-ABL1 positive",

        "timepoint": "P8DT0H0M0S",
        "species": "Homo sapiens",
        "sex_label": "female",
        "sex_id": None,
        "developmental_stage_label": "adult",
        "developmental_stage_id": None,

        "study_title": "Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq",
        "study_uri": "https://doi.org/10.1016/j.cell.2022.05.013",
        "study_year": 2022,
        "first_author": "Joseph M Replogle",
        "last_author": "Jonathan S Weissman",

        "experiment_title": "K562 day 8 essential-scale Perturb-seq experiment",
        "experiment_summary": """
            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.
            A total of 9,866 genes were targeted.
            Cells were sampled at day 8 after lentiviral transduction.
            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_coord'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Weissman Lab",
        "library_lentiviral_generation": "3",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "10x Genomics Single Cell 3-prime v3",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "custom",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",
        
        "license_label": "CC BY 4.0",
        "license_id": "SWO:1000065",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "K562_gwps_raw_bulk_01",
                "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443",
                "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell",
                "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad",
            },
            {
                "dataset_accession": "K562_gwps_normalized_bulk_01",
                "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217",
                "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell",
                "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad",
            },
            {
                "dataset_accession": "K562_gwps_raw_singlecell_01",
                "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507",
                "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell",
                "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad",
            },
            {
                "dataset_accession": "K562_gwps_normalized_singlecell_01",
                "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440",
                "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell",
                "dataset_file_name": "K562_gwps_normalized_singlecell_01.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#                  gene_id                             guide_sequence     gene  \
# index
# 0        ENSG00000109861  GGCCCAGCACCCATGCTGCA|GTAGCGGTGAGTCCACCACG     CTSC
# 1        ENSG00000273559  GTCTAGAGCGGTGGTGAAAC|GCCGGAAGTGACCTCTAGAG    CWC25
# 2        ENSG00000178104  GGGCGCGCAGCGGTACCTAG|GGAGCCGGAAGCCCGCTGAC  PDE4DIP
# 3        ENSG00000074755  GGCTGCTGTCGGAGGTTGAC|GGCCCGCCAGCTGCTGTCGG    ZZEF1
# 4        ENSG00000143553  GGTCCCTGCCCCCGATACAG|GGGTTCCGCCGCTGTATCGG   SNAPIN
# ...                  ...                                        ...      ...
# 1989573  ENSG00000180900  GCGGTAGATCTCCTCCGGCA|GCTGCCGCCGGAGGAATCAC    SCRIB
# 1989574  ENSG00000105767  GCCGGGCCCGGCGCTTCCAG|GGGCGGCGGCACCATGGGCC    CADM4
# 1989575  ENSG00000033867  GAGCTTCAGGTTCCACGCCG|GGTACCGTAGCGGCCGTCAC   SLC4A7
# 1989576  ENSG00000075568  GACAAGCAGTCGGAGCGGAG|GGCGGCGCCGGGAGCGACAA  TMEM131
# 1989577  ENSG00000140319  GGTTGGAGAGCGAGCAGGTA|GACAGGGTGGGGAAAGGTAG    SRP14
#
#                 transcript  z_gemgroup_UMI          cell_barcode  gem_group  \
# index
# 0                     P1P2        0.470687  AAACCCAAGAAACCAT-157        157
# 1                     P1P2        0.824790  AAACCCAAGAAACCAT-207        207
# 2        ENST00000313431.9        2.627126   AAACCCAAGAAACCAT-29         29
# 3                     P1P2        0.918149  AAACCCAAGAAAGCGA-149        149
# 4                     P1P2       -0.230920  AAACCCAAGAAATCCA-172        172
# ...                    ...             ...                   ...        ...
# 1989573               P1P2       -0.441665  TTTGTTGTCTTTCCAA-201        201
# 1989574               P1P2       -1.208969   TTTGTTGTCTTTCGAT-79         79
# 1989575               P1P2       -0.109167  TTTGTTGTCTTTCTAG-218        218
# 1989576               P1P2       -0.358464  TTTGTTGTCTTTGCGC-169        169
# 1989577               P1P2        0.284907  TTTGTTGTCTTTGCGC-213        213
#
#          UMI_count  core_adjusted_UMI_count  core_scale_factor  ...  \
# index                                                           ...
# 0          14709.0             13992.900391           1.051176  ...
# 1          16162.0             15038.004883           1.074744  ...
# 2          33297.0             22613.423828           1.472444  ...
# 3           7435.0             15476.669922           0.480401  ...
# 4           7755.0             11147.856445           0.695649  ...
# ...            ...                      ...                ...  ...
# 1989573    11867.0             10302.698242           1.151834  ...
# 1989574     6437.0              6882.660156           0.935249  ...
# 1989575    11377.0             11376.682617           1.000028  ...
# 1989576    10658.0             10417.442383           1.023092  ...
# 1989577    18287.0             13078.065430           1.398296  ...
#
#         sequencing_strategy_label  software_counts_id software_counts_label  \
# index
# 0              barcode sequencing                None            CellRanger
# 1              barcode sequencing                None            CellRanger
# 2              barcode sequencing                None            CellRanger
# 3              barcode sequencing                None            CellRanger
# 4              barcode sequencing                None            CellRanger
# ...                           ...                 ...                   ...
# 1989573        barcode sequencing                None            CellRanger
# 1989574        barcode sequencing                None            CellRanger
# 1989575        barcode sequencing                None            CellRanger
# 1989576        barcode sequencing                None            CellRanger
# 1989577        barcode sequencing                None            CellRanger
#
#         software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                       None                  custom                None
# 1                       None                  custom                None
# 2                       None                  custom                None
# 3                       None                  custom                None
# 4                       None                  custom                None
# ...                      ...                     ...                 ...
# 1989573                 None                  custom                None
# 1989574                 None                  custom                None
# 1989575                 None                  custom                None
# 1989576                 None                  custom                None
# 1989577                 None                  custom                None
#
#         reference_genome_label license_label   license_id  \
# index
# 0                       GRCh38     CC BY 4.0  SWO:1000065
# 1                       GRCh38     CC BY 4.0  SWO:1000065
# 2                       GRCh38     CC BY 4.0  SWO:1000065
# 3                       GRCh38     CC BY 4.0  SWO:1000065
# 4                       GRCh38     CC BY 4.0  SWO:1000065
# ...                        ...           ...          ...
# 1989573                 GRCh38     CC BY 4.0  SWO:1000065
# 1989574                 GRCh38     CC BY 4.0  SWO:1000065
# 1989575                 GRCh38     CC BY 4.0  SWO:1000065
# 1989576                 GRCh38     CC BY 4.0  SWO:1000065
# 1989577                 GRCh38     CC BY 4.0  SWO:1000065
#
#                                        associated_datasets
# index
# 0        [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 1        [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 2        [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 3        [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 4        [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# ...                                                    ...
# 1989573  [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 1989574  [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 1989575  [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 1989576  [{"dataset_accession": "K562_gwps_raw_bulk_01"...
# 1989577  [{"dataset_accession": "K562_gwps_raw_bulk_01"...
#
# [1989578 rows x 107 columns]

# %% [markdown]
# ### Curate replicate information

# %%
cur_data.adata.obs['technical_replicate'] = cur_data.adata.obs['gem_group'].astype(str)

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower name_lower     ontology_id
# 0        blood              blood      blood  UBERON:0000178
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower   name_lower ontology_id
# 0  lymphoblast        lymphoblast  lymphoblast  CL:0017005
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell line information

# %%
cur_data.standardize_ontology(
    input_column='cell_line_label',
    column_type='term_name',
    ontology_type='cell_line',
    overwrite=True
)
# Out:
# Mapped 1 cell_line ontology terms from `cell_line_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#   input_column input_column_lower  name_lower  ontology_id
# 0   K 562 cell         k 562 cell  k 562 cell  CLO:0007050
# --------------------------------------------------
# Overwriting column cell_line_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Mapped 1 disease ontology terms from `disease_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                                       input_column  \
# 0  chronic myelogenous leukemia, BCR-ABL1 positive
#
#                                 input_column_lower  \
# 0  chronic myelogenous leukemia, bcr-abl1 positive
#
#                                         name_lower    ontology_id
# 0  chronic myelogenous leukemia, bcr-abl1 positive  MONDO:0011996
# --------------------------------------------------
# Overwriting column disease_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-04-23 13:27:31,571 DEBUG curation_tools.curation_tools: Applying dtype casting on adata.obs for columns: ['dataset_id', 'sample_id', 'cell_barcode', 'data_modality', 'significant', 'significance_criteria', 'perturbation_name', 'perturbed_target_coord', 'perturbed_target_chromosome', 'perturbed_target_chromosome_encoding', 'perturbed_target_number', 'perturbed_target_ensg', 'perturbed_target_symbol', 'perturbed_target_biotype', 'guide_sequence', 'perturbation_type_label', 'perturbation_type_id', 'timepoint', 'treatment_label', 'treatment_id', 'technical_replicate', 'biological_replicate', 'model_system_label', 'model_system_id', 'species', 'tissue_label', 'tissue_id', 'cell_type_label', 'cell_type_id', 'cell_line_label', 'cell_line_id', 'sex_label', 'sex_id', 'developmental_stage_label', 'developmental_stage_id', 'disease_label', 'disease_id', 'study_title', 'study_uri', 'study_year', 'first_author', 'last_author', 'experiment_title', 'experiment_summary', 'number_of_perturbed_targets', 'number_of_perturbed_samples', 'library_generation_type_id', 'library_generation_type_label', 'library_generation_method_id', 'library_generation_method_label', 'enzyme_delivery_method_id', 'enzyme_delivery_method_label', 'library_delivery_method_id', 'library_delivery_method_label', 'enzyme_integration_state_id', 'enzyme_integration_state_label', 'library_integration_state_id', 'library_integration_state_label', 'enzyme_expression_control_id', 'enzyme_expression_control_label', 'library_expression_control_id', 'library_expression_control_label', 'library_name', 'library_uri', 'library_format_id', 'library_format_label', 'library_scope_id', 'library_scope_label', 'library_perturbation_type_id', 'library_perturbation_type_label', 'library_manufacturer', 'library_lentiviral_generation', 'library_grnas_per_target', 'library_total_grnas', 'library_total_variants', 'readout_dimensionality_id', 'readout_dimensionality_label', 'readout_type_id', 'readout_type_label', 'readout_technology_id', 'readout_technology_label', 'method_name_id', 'method_name_label', 'method_uri', 'sequencing_library_kit_id', 'sequencing_library_kit_label', 'sequencing_platform_id', 'sequencing_platform_label', 'sequencing_strategy_id', 'sequencing_strategy_label', 'software_counts_id', 'software_counts_label', 'software_analysis_id', 'software_analysis_label', 'score_interpretation', 'reference_genome_id', 'reference_genome_label', 'associated_datasets', 'license_label', 'license_id']
# 2026-04-23 13:28:19,798 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
# 2026-04-23 13:28:19,818 DEBUG curation_tools.curation_tools: Validated adata.obs preview (shape=(1989578, 100)):
#                   dataset_id sample_id          cell_barcode data_modality significant significance_criteria                                                                  perturbation_name      perturbed_target_coord perturbed_target_chromosome  perturbed_target_chromosome_encoding  perturbed_target_number perturbed_target_ensg perturbed_target_symbol perturbed_target_biotype                             guide_sequence perturbation_type_label perturbation_type_id   timepoint treatment_label treatment_id technical_replicate biological_replicate model_system_label model_system_id       species tissue_label       tissue_id cell_type_label cell_type_id cell_line_label cell_line_id sex_label sex_id developmental_stage_label developmental_stage_id                                    disease_label     disease_id                                                                           study_title                                   study_uri  study_year       first_author          last_author                                   experiment_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                experiment_summary number_of_perturbed_targets number_of_perturbed_samples library_generation_type_id library_generation_type_label library_generation_method_id library_generation_method_label enzyme_delivery_method_id enzyme_delivery_method_label library_delivery_method_id library_delivery_method_label enzyme_integration_state_id enzyme_integration_state_label library_integration_state_id library_integration_state_label enzyme_expression_control_id    enzyme_expression_control_label library_expression_control_id   library_expression_control_label library_name library_uri library_format_id library_format_label library_scope_id library_scope_label library_perturbation_type_id library_perturbation_type_label library_manufacturer library_lentiviral_generation library_grnas_per_target library_total_grnas  library_total_variants readout_dimensionality_id readout_dimensionality_label readout_type_id readout_type_label readout_technology_id readout_technology_label method_name_id method_name_label method_uri sequencing_library_kit_id         sequencing_library_kit_label sequencing_platform_id sequencing_platform_label sequencing_strategy_id sequencing_strategy_label software_counts_id software_counts_label software_analysis_id software_analysis_label score_interpretation reference_genome_id reference_genome_label                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 associ ...
# 0  replogle_2022_k562_gw_raw         1  AAACCCAAGAAACCAT-157   Perturb-seq        <NA>                  <NA>                                    CTSC_-_88070848.23-P1P2|CTSC_-_88070918.23-P1P2  chr11:88265069-88359684;-1                          11                                    11                        1       ENSG00000109861                    CTSC           protein_coding  GGCCCAGCACCCATGCTGCA|GTAGCGGTGAGTCCACCACG                 CRISPRi                 <NA>  P8DT0H0M0S            <NA>         <NA>                 157                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq  https://doi.org/10.1016/j.cell.2022.05.013        2022  Joseph M Replogle  Jonathan S Weissman  K562 day 8 essential-scale Perturb-seq experiment  \n            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.\n            A total of 9,866 genes were targeted.\n            Cells were sampled at day 8 after lentiviral transduction.\n            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.\n                                    9861                     1989578                EFO:0022868                    endogenous                         <NA>                      dCas9-KRAB                      <NA>      lentivirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition         Weissman Lab                             3                        2               22308                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime v3                   <NA>     Ultima Genomics UG100                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  custom                 <NA>                <NA>                 GRCh38  [{"dataset_accession": "K562_gwps_raw_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443", "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217", "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_raw_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507", "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440", "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_singlece ...
# 1  replogle_2022_k562_gw_raw         2  AAACCCAAGAAACCAT-207   Perturb-seq        <NA>                  <NA>                                  CWC25_+_36981555.23-P1P2|CWC25_+_36981567.23-P1P2  chr17:38800441-38825646;-1                          17                                    17                        1       ENSG00000273559                   CWC25           protein_coding  GTCTAGAGCGGTGGTGAAAC|GCCGGAAGTGACCTCTAGAG                 CRISPRi                 <NA>  P8DT0H0M0S            <NA>         <NA>                 207                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq  https://doi.org/10.1016/j.cell.2022.05.013        2022  Joseph M Replogle  Jonathan S Weissman  K562 day 8 essential-scale Perturb-seq experiment  \n            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.\n            A total of 9,866 genes were targeted.\n            Cells were sampled at day 8 after lentiviral transduction.\n            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.\n                                    9861                     1989578                EFO:0022868                    endogenous                         <NA>                      dCas9-KRAB                      <NA>      lentivirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition         Weissman Lab                             3                        2               22308                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime v3                   <NA>     Ultima Genomics UG100                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  custom                 <NA>                <NA>                 GRCh38  [{"dataset_accession": "K562_gwps_raw_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443", "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217", "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_raw_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507", "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440", "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_singlece ...
# 2  replogle_2022_k562_gw_raw         3   AAACCCAAGAAACCAT-29   Perturb-seq        <NA>                  <NA>  PDE4DIP_+_144932474.23-ENST00000313431.9|PDE4DIP_+_144932182.23-ENST00000313431.9  chr1:148808140-149048286;1                           1                                     1                        1       ENSG00000178104                 PDE4DIP           protein_coding  GGGCGCGCAGCGGTACCTAG|GGAGCCGGAAGCCCGCTGAC                 CRISPRi                 <NA>  P8DT0H0M0S            <NA>         <NA>                  29                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq  https://doi.org/10.1016/j.cell.2022.05.013        2022  Joseph M Replogle  Jonathan S Weissman  K562 day 8 essential-scale Perturb-seq experiment  \n            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.\n            A total of 9,866 genes were targeted.\n            Cells were sampled at day 8 after lentiviral transduction.\n            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.\n                                    9861                     1989578                EFO:0022868                    endogenous                         <NA>                      dCas9-KRAB                      <NA>      lentivirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition         Weissman Lab                             3                        2               22308                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime v3                   <NA>     Ultima Genomics UG100                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  custom                 <NA>                <NA>                 GRCh38  [{"dataset_accession": "K562_gwps_raw_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443", "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217", "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_raw_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507", "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440", "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_singlece ...
# 3  replogle_2022_k562_gw_raw         4  AAACCCAAGAAAGCGA-149   Perturb-seq        <NA>                  <NA>                                    ZZEF1_+_4046247.23-P1P2|ZZEF1_+_4046255.23-P1P2    chr17:4004445-4143628;-1                          17                                    17                        1       ENSG00000074755                   ZZEF1           protein_coding  GGCTGCTGTCGGAGGTTGAC|GGCCCGCCAGCTGCTGTCGG                 CRISPRi                 <NA>  P8DT0H0M0S            <NA>         <NA>                 149                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq  https://doi.org/10.1016/j.cell.2022.05.013        2022  Joseph M Replogle  Jonathan S Weissman  K562 day 8 essential-scale Perturb-seq experiment  \n            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.\n            A total of 9,866 genes were targeted.\n            Cells were sampled at day 8 after lentiviral transduction.\n            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.\n                                    9861                     1989578                EFO:0022868                    endogenous                         <NA>                      dCas9-KRAB                      <NA>      lentivirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition         Weissman Lab                             3                        2               22308                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime v3                   <NA>     Ultima Genomics UG100                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  custom                 <NA>                <NA>                 GRCh38  [{"dataset_accession": "K562_gwps_raw_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443", "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217", "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_raw_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507", "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440", "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_singlece ...
# 4  replogle_2022_k562_gw_raw         5  AAACCCAAGAAATCCA-172   Perturb-seq        <NA>                  <NA>                              SNAPIN_+_153631238.23-P1P2|SNAPIN_-_153631252.23-P1P2  chr1:153658696-153663930;1                           1                                     1                        1       ENSG00000143553                  SNAPIN           protein_coding  GGTCCCTGCCCCCGATACAG|GGGTTCCGCCGCTGTATCGG                 CRISPRi                 <NA>  P8DT0H0M0S            <NA>         <NA>                 172                 <NA>          cell_line            <NA>  Homo sapiens        blood  UBERON:0000178     lymphoblast   CL:0017005      K 562 cell  CLO:0007050    female   <NA>                     adult                   <NA>  chronic myelogenous leukemia, BCR-ABL1 positive  MONDO:0011996  Mapping information-rich genotype-phenotype landscapes with genome-scale Perturb-seq  https://doi.org/10.1016/j.cell.2022.05.013        2022  Joseph M Replogle  Jonathan S Weissman  K562 day 8 essential-scale Perturb-seq experiment  \n            K562 chronic myeloid leukemia cells were transduced with a sgRNA library targeting genes expressed in K562 cells, transcription factors as detailed in Lambert et al. (2018) and Cancer Dependency Map common essential genes.\n            A total of 9,866 genes were targeted.\n            Cells were sampled at day 8 after lentiviral transduction.\n            Multiplexed CRISPRi library containing two distinct guides targeting the same gene were used.\n                                    9861                     1989578                EFO:0022868                    endogenous                         <NA>                      dCas9-KRAB                      <NA>      lentivirus transduction                       <NA>       lentivirus transduction                        <NA>       random locus integration                         <NA>        random locus integration                         <NA>  constitutive transgene expression                          <NA>  constitutive transgene expression       custom        <NA>              <NA>               pooled             <NA>             focused                         <NA>                      inhibition         Weissman Lab                             3                        2               22308                    <NA>                      <NA>       high-dimensional assay            <NA>     transcriptomic                  <NA>      single-cell rna-seq           <NA>       Perturb-seq       <NA>                      <NA>  10x Genomics Single Cell 3-prime v3                   <NA>     Ultima Genomics UG100                   <NA>        barcode sequencing               <NA>            CellRanger                 <NA>                  custom                 <NA>                <NA>                 GRCh38  [{"dataset_accession": "K562_gwps_raw_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774443", "dataset_description": "Raw, pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_bulk_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35773217", "dataset_description": "Gemgroup Z-normalized pseudo-bulk expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_bulk_01.h5ad"}, {"dataset_accession": "K562_gwps_raw_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35775507", "dataset_description": "Raw, single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_raw_singlecell_01.h5ad"}, {"dataset_accession": "K562_gwps_normalized_singlecell_01", "dataset_uri": "https://plus.figshare.com/ndownloader/files/35774440", "dataset_description": "Gemgroup Z-normalized single-cell expression data for genes expressed at >0.01 UMI per cell", "dataset_file_name": "K562_gwps_normalized_singlece ...
#                         dataset_id sample_id          cell_barcode  \
# 0        replogle_2022_k562_gw_raw         1  AAACCCAAGAAACCAT-157
# 1        replogle_2022_k562_gw_raw         2  AAACCCAAGAAACCAT-207
# 2        replogle_2022_k562_gw_raw         3   AAACCCAAGAAACCAT-29
# 3        replogle_2022_k562_gw_raw         4  AAACCCAAGAAAGCGA-149
# 4        replogle_2022_k562_gw_raw         5  AAACCCAAGAAATCCA-172
# 3                  CellRanger                 <NA>                  custom
# 4                  CellRanger                 <NA>                  custom
# ...                       ...                  ...                     ...
# 1989573            CellRanger                 <NA>                  custom
# 1989574            CellRanger                 <NA>                  custom
# 1989575            CellRanger                 <NA>                  custom
# 1989576            CellRanger                 <NA>                  custom
# 1989577            CellRanger                 <NA>                  custom
#
#         score_interpretation reference_genome_id reference_genome_label  \
# 0                       <NA>                <NA>                 GRCh38
# 1                       <NA>                <NA>                 GRCh38
# 2                       <NA>                <NA>                 GRCh38
# 3                       <NA>                <NA>                 GRCh38
# 4                       <NA>                <NA>                 GRCh38
# ...                      ...                 ...                    ...
# 1989573                 <NA>                <NA>                 GRCh38
# 1989574                 <NA>                <NA>                 GRCh38
# 1989575                 <NA>                <NA>                 GRCh38
# 1989576                 <NA>                <NA>                 GRCh38
# 1989577                 <NA>                <NA>                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 1        [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 2        [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 3        [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 4        [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# ...                                                    ...           ...
# 1989573  [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 1989574  [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 1989575  [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 1989576  [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
# 1989577  [{"dataset_accession": "K562_gwps_raw_bulk_01"...     CC BY 4.0
#
#           license_id
# 0        SWO:1000065
# 1        SWO:1000065
# 2        SWO:1000065
# 3        SWO:1000065
# 4        SWO:1000065
# ...              ...
# 1989573  SWO:1000065
# 1989574  SWO:1000065
# 1989575  SWO:1000065
# 1989576  SWO:1000065
# 1989577  SWO:1000065
#
# [1989578 rows x 100 columns]

# %%
cur_data.adata.obs[['library_total_grnas', 'library_total_variants']]
# Out:
#         library_total_grnas  library_total_variants
# 0                     22308                    <NA>
# 1                     22308                    <NA>
# 2                     22308                    <NA>
# 3                     22308                    <NA>
# 4                     22308                    <NA>
# ...                     ...                     ...
# 1989573               22308                    <NA>
# 1989574               22308                    <NA>
# 1989575               22308                    <NA>
# 1989576               22308                    <NA>
# 1989577               22308                    <NA>
#
# [1989578 rows x 2 columns]

# %%
cur_data.show_obs(['perturbation_name', 'perturbed_target_symbol', 'perturbed_target_ensg', 'perturbed_target_coord'])
# Out:
# Observation data:
# DataFrame shape: (1989578, 4)
# --------------------------------------------------
#                                          perturbation_name  \
# 0          CTSC_-_88070848.23-P1P2|CTSC_-_88070918.23-P1P2
# 1        CWC25_+_36981555.23-P1P2|CWC25_+_36981567.23-P1P2
# 2        PDE4DIP_+_144932474.23-ENST00000313431.9|PDE4D...
# 3          ZZEF1_+_4046247.23-P1P2|ZZEF1_+_4046255.23-P1P2
# 4        SNAPIN_+_153631238.23-P1P2|SNAPIN_-_153631252....
# ...                                                    ...
# 1989573  SCRIB_-_144897465.23-P1P2|SCRIB_-_144897339.23...
# 1989574  CADM4_+_44143915.23-P1P2|CADM4_+_44143932.23-P1P2
# 1989575  SLC4A7_+_27525847.23-P1P2|SLC4A7_+_27525631.23...
# 1989576  TMEM131_-_98612356.23-P1P2|TMEM131_-_98612239....
# 1989577  SRP14_+_40331287.23-P1P2|SRP14_-_40330986.23-P1P2
#
#         perturbed_target_symbol perturbed_target_ensg  \
# 0                          CTSC       ENSG00000109861
# 1                         CWC25       ENSG00000273559
# 2                       PDE4DIP       ENSG00000178104
# 3                         ZZEF1       ENSG00000074755
# 4                        SNAPIN       ENSG00000143553
# ...                         ...                   ...
# 1989573                   SCRIB       ENSG00000180900
# 1989574                   CADM4       ENSG00000105767
# 1989575                  SLC4A7       ENSG00000033867
# 1989576                 TMEM131       ENSG00000075568
# 1989577                   SRP14       ENSG00000140319
#
#               perturbed_target_coord
# 0         chr11:88265069-88359684;-1
# 1         chr17:38800441-38825646;-1
# 2         chr1:148808140-149048286;1
# 3           chr17:4004445-4143628;-1
# 4         chr1:153658696-153663930;1
# ...                              ...
# 1989573  chr8:143790920-143815773;-1
# 1989574   chr19:43622366-43639850;-1
# 1989575    chr3:27372723-27484451;-1
# 1989576    chr2:97756333-97996226;-1
# 1989577   chr15:40035690-40039181;-1
#
# [1989578 rows x 4 columns]
# --------------------------------------------------

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.show_var()
# Out:
# Variable data:
# DataFrame shape: (8248, 12)
# --------------------------------------------------
#                   gene_name         chr   start      end           class  \
# gene_id
# ENSG00000237491   LINC01409        chr1  778747   810065  gene_version10
# ENSG00000228794   LINC01128        chr1  825138   868202   gene_version9
# ENSG00000188976       NOC2L        chr1  944203   959309  gene_version11
# ENSG00000187961      KLHL17        chr1  960584   965719  gene_version14
# ENSG00000188290        HES4        chr1  998962  1000172  gene_version10
# ...                     ...         ...     ...      ...             ...
# ENSG00000198727      MT-CYB        chrM   14747    15887   gene_version2
# ENSG00000278704  BX004987.1  GL000009.2   56140    58376   gene_version1
# ENSG00000278384  AL354822.1  GL000218.1   51867    54893   gene_version1
# ENSG00000271254  AC240274.1  KI270711.1    4612    29626   gene_version6
# ENSG00000276345  AC004556.3  KI270721.1    2585    11802   gene_version1
#
#                 strand  length  in_matrix        mean        std        cv  \
# gene_id
# ENSG00000237491      +   31318       True    0.116626   0.349971  3.000803
# ENSG00000228794      +   43064       True    0.182850   0.437274  2.391434
# ENSG00000188976      -   15106       True    1.415674   1.397208  0.986957
# ENSG00000187961      +    5135       True    0.105599   0.330678  3.131439
# ENSG00000188290      -    1210       True    0.242700   0.550596  2.268630
# ...                ...     ...        ...         ...        ...       ...
# ENSG00000198727      +    1140       True  116.549202  59.102600  0.507104
# ENSG00000278704      -    2236       True    0.195008   0.455099  2.333745
# ENSG00000278384      -    3026       True    0.190869   0.450850  2.362089
# ENSG00000271254      -   25014       True    0.163767   0.427101  2.607982
# ENSG00000276345      +    9217       True    0.295477   0.575876  1.948971
#
#                       fano
# gene_id
# ENSG00000237491   1.050194
# ENSG00000228794   1.045713
# ENSG00000188976   1.378984
# ENSG00000187961   1.035497
# ENSG00000188290   1.249098
# ...                    ...
# ENSG00000198727  29.971182
# ENSG00000278704   1.062085
# ENSG00000278384   1.064948
# ENSG00000271254   1.113872
# ENSG00000276345   1.122365
#
# [8248 rows x 12 columns]
# --------------------------------------------------

# %%
cur_data.create_columns(
    slot = 'var',
    col_dict={'gene_ensembl_id': cur_data.adata.var.index},
    overwrite=True
)
# Out:
# Column gene_ensembl_id added to adata.var

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ensembl_id",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# 2026-04-23 13:28:51,546 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): rest.ensembl.org:443
# Missing Ensembl IDs: ['ENSG00000283633', 'ENSG00000255823', 'ENSG00000112096', 'ENSG00000278384', 'ENSG00000228434', 'ENSG00000278704', 'ENSG00000239467', 'ENSG00000235111', 'ENSG00000276345', 'ENSG00000271109', 'ENSG00000215067', 'ENSG00000215271', 'ENSG00000233937', 'ENSG00000287263', 'ENSG00000130723', 'ENSG00000272316', 'ENSG00000269028', 'ENSG00000264920', 'ENSG00000148362', 'ENSG00000271254']; attempting to fetch latest IDs...
# 2026-04-23 13:28:52,038 DEBUG urllib3.connectionpool: https://rest.ensembl.org:443 "POST /archive/id HTTP/1.1" 200 4001
# Fetched latest Ensembl IDs: {'ENSG00000283633': 'ENSG00000290418', 'ENSG00000255823': nan, 'ENSG00000112096': 'ENSG00000291237', 'ENSG00000228434': 'ENSG00000290758', 'ENSG00000239467': 'ENSG00000204334', 'ENSG00000235111': 'ENSG00000188511', 'ENSG00000271109': 'ENSG00000267767', 'ENSG00000215067': 'ENSG00000267532', 'ENSG00000215271': 'ENSG00000290292', 'ENSG00000233937': nan, 'ENSG00000287263': 'ENSG00000177738', 'ENSG00000130723': nan, 'ENSG00000272316': 'ENSG00000290555', 'ENSG00000269028': nan, 'ENSG00000264920': 'ENSG00000234494', 'ENSG00000148362': 'ENSG00000310560'}
# --------------------------------------------------
# Successfully mapped 8248 out of 8248 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-04-23 13:28:53,273 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
# 2026-04-23 13:28:53,282 DEBUG curation_tools.curation_tools: Validated adata.var preview (shape=(8248, 2)):
#        ensembl_gene_id gene_symbol
# index
# 0      ENSG00000237491   LINC01409
# 1      ENSG00000228794   LINC01128
# 2      ENSG00000188976       NOC2L
# 3      ENSG00000187961      KLHL17
# 4      ENSG00000188290        HES4
#        ensembl_gene_id gene_symbol
# index
# 0      ENSG00000237491   LINC01409
# 1      ENSG00000228794   LINC01128
# 2      ENSG00000188976       NOC2L
# 3      ENSG00000187961      KLHL17
# 4      ENSG00000188290        HES4
# ...                ...         ...
# 8243   ENSG00000198727      MT-CYB
# 8244   ENSG00000278704         NaN
# 8245   ENSG00000278384         NaN
# 8246   ENSG00000271254         NaN
# 8247   ENSG00000276345         NaN
#
# [8248 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data_h5ad()
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ... storing 'dataset_id' as categorical
# ... storing 'data_modality' as categorical
# ... storing 'significance_criteria' as categorical
# ... storing 'perturbation_name' as categorical
# ... storing 'perturbed_target_coord' as categorical
# ... storing 'perturbed_target_chromosome' as categorical
# ... storing 'perturbed_target_ensg' as categorical
# ... storing 'perturbed_target_symbol' as categorical
# ... storing 'perturbed_target_biotype' as categorical
# ... storing 'guide_sequence' as categorical
# ... storing 'perturbation_type_label' as categorical
# ... storing 'perturbation_type_id' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'treatment_label' as categorical
# ... storing 'treatment_id' as categorical
# ... storing 'technical_replicate' as categorical
# ... storing 'biological_replicate' as categorical
# ... storing 'model_system_label' as categorical
# ... storing 'model_system_id' as categorical
# ... storing 'species' as categorical
# ... storing 'tissue_label' as categorical
# ... storing 'tissue_id' as categorical
# ... storing 'cell_type_label' as categorical
# ... storing 'cell_type_id' as categorical
# ... storing 'cell_line_label' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'sex_label' as categorical
# ... storing 'sex_id' as categorical
# ... storing 'developmental_stage_label' as categorical
# ... storing 'developmental_stage_id' as categorical
# ... storing 'disease_label' as categorical
# ... storing 'disease_id' as categorical
# ... storing 'study_title' as categorical
# ... storing 'study_uri' as categorical
# ... storing 'first_author' as categorical
# ... storing 'last_author' as categorical
# ... storing 'experiment_title' as categorical
# ... storing 'experiment_summary' as categorical
# ... storing 'number_of_perturbed_targets' as categorical
# ... storing 'number_of_perturbed_samples' as categorical
# ... storing 'library_generation_type_id' as categorical
# ... storing 'library_generation_type_label' as categorical
# ... storing 'library_generation_method_id' as categorical
# ... storing 'library_generation_method_label' as categorical
# ... storing 'enzyme_delivery_method_id' as categorical
# ... storing 'enzyme_delivery_method_label' as categorical
# ... storing 'library_delivery_method_id' as categorical
# ... storing 'library_delivery_method_label' as categorical
# ... storing 'enzyme_integration_state_id' as categorical
# ... storing 'enzyme_integration_state_label' as categorical
# ... storing 'library_integration_state_id' as categorical
# ... storing 'library_integration_state_label' as categorical
# ... storing 'enzyme_expression_control_id' as categorical
# ... storing 'enzyme_expression_control_label' as categorical
# ... storing 'library_expression_control_id' as categorical
# ... storing 'library_expression_control_label' as categorical
# ... storing 'library_name' as categorical
# ... storing 'library_uri' as categorical
# ... storing 'library_format_id' as categorical
# ... storing 'library_format_label' as categorical
# ... storing 'library_scope_id' as categorical
# ... storing 'library_scope_label' as categorical
# ... storing 'library_perturbation_type_id' as categorical
# ... storing 'library_perturbation_type_label' as categorical
# ... storing 'library_manufacturer' as categorical
# ... storing 'library_lentiviral_generation' as categorical
# ... storing 'library_grnas_per_target' as categorical
# ... storing 'library_total_grnas' as categorical
# ... storing 'readout_dimensionality_id' as categorical
# ... storing 'readout_dimensionality_label' as categorical
# ... storing 'readout_type_id' as categorical
# ... storing 'readout_type_label' as categorical
# ... storing 'readout_technology_id' as categorical
# ... storing 'readout_technology_label' as categorical
# ... storing 'method_name_id' as categorical
# ... storing 'method_name_label' as categorical
# ... storing 'method_uri' as categorical
# ... storing 'sequencing_library_kit_id' as categorical
# ... storing 'sequencing_library_kit_label' as categorical
# ... storing 'sequencing_platform_id' as categorical
# ... storing 'sequencing_platform_label' as categorical
# ... storing 'sequencing_strategy_id' as categorical
# ... storing 'sequencing_strategy_label' as categorical
# ... storing 'software_counts_id' as categorical
# ... storing 'software_counts_label' as categorical
# ... storing 'software_analysis_id' as categorical
# ... storing 'software_analysis_label' as categorical
# ... storing 'score_interpretation' as categorical
# ... storing 'reference_genome_id' as categorical
# ... storing 'reference_genome_label' as categorical
# ... storing 'associated_datasets' as categorical
# ... storing 'license_label' as categorical
# ... storing 'license_id' as categorical
# ... storing 'ensembl_gene_id' as categorical
# ... storing 'gene_symbol' as categorical
# 2026-04-23 13:29:45,402 DEBUG h5py._conv: Creating converter from 5 to 3
# ✅ Curated h5ad data saved to ../curated/h5ad/replogle_2022_k562_gw_raw_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/replogle_2022_k562_gw_raw_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
upload_parquet_to_bq(
    parquet_path='../curated/parquet/replogle_2022_k562_gw_raw_curated_metadata.parquet',
    bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
    bq_table_name='metadata',
    key_columns=['dataset_id', 'sample_id'],
    verbose=True
)
# Out:
# 2026-04-23 13:39:50,526 DEBUG google.auth._default: Checking '' for explicit credentials as part of auth process...
# 2026-04-23 13:39:50,527 DEBUG google.auth._default: Checking Cloud SDK credentials as part of auth process...
# 2026-04-23 13:39:53,138 DEBUG google.auth._default: Checking '' for explicit credentials as part of auth process...
# 2026-04-23 13:39:53,139 DEBUG google.auth._default: Checking Cloud SDK credentials as part of auth process...
# 2026-04-23 13:39:53,859 DEBUG google.cloud.bigquery.opentelemetry_tracing: This service is instrumented using OpenTelemetry. OpenTelemetry or one of its components could not be imported; please add compatible versions of opentelemetry-api and opentelemetry-instrumentation packages in order to get BigQuery Tracing data.
# 2026-04-23 13:39:53,861 DEBUG urllib3.util.retry: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2026-04-23 13:39:53,864 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2026-04-23 13:39:53,919 DEBUG urllib3.connectionpool: https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# 2026-04-23 13:39:53,922 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): bigquery.googleapis.com:443
# 2026-04-23 13:39:54,136 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# Staging table: loading `.parquet` file ../curated/parquet/replogle_2022_k562_gw_raw_curated_metadata.parquet to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging...
# 2026-04-23 13:39:54,634 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?uploadType=resumable HTTP/1.1" 200 0
# 2026-04-23 13:39:55,788 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "PUT /upload/bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?uploadType=resumable&upload_id=AMNfjG1nARsLyagZEvruK_yZfk0Rc7G2UFMoZguvnH3uoJTuhy0BbiiYl6P0cwABtoAP93-EOETckrM7rSSQ-ydG_3rdqTCXpk9mZu-0ft_Sa24 HTTP/1.1" 200 14124
# 2026-04-23 13:39:55,949 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:39:56,738 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:39:57,467 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:39:57,971 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:00,789 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:04,014 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:07,522 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/6f408826-2d43-4619-94f3-144c45ebee62?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:07,684 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata_staging?prettyPrint=false HTTP/1.1" 200 None
# Staging table: loaded 1989578 rows to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# 2026-04-23 13:40:09,241 DEBUG urllib3.util.retry: Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# 2026-04-23 13:40:09,244 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): oauth2.googleapis.com:443
# 2026-04-23 13:40:09,297 DEBUG urllib3.connectionpool: https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# 2026-04-23 13:40:09,298 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): bigquery.googleapis.com:443
# 2026-04-23 13:40:09,679 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:09,834 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/d44934d3-855e-469e-8fa2-4b71dfeb0f9d?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:09,982 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/d44934d3-855e-469e-8fa2-4b71dfeb0f9d?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:10,116 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/d44934d3-855e-469e-8fa2-4b71dfeb0f9d?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:10,435 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:10,559 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/acdf93c0-4b2d-447f-80ae-bcdb2694c838?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:10,698 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/acdf93c0-4b2d-447f-80ae-bcdb2694c838?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:10,810 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/acdf93c0-4b2d-447f-80ae-bcdb2694c838?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:11,423 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:11,503 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/48ec6a27-0813-4644-b793-5f1b1511ba7a?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:21,487 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/48ec6a27-0813-4644-b793-5f1b1511ba7a?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:21,641 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/48ec6a27-0813-4644-b793-5f1b1511ba7a?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:26,914 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/48ec6a27-0813-4644-b793-5f1b1511ba7a?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:27,016 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/48ec6a27-0813-4644-b793-5f1b1511ba7a?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging
# 2026-04-23 13:40:27,244 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:27,424 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:27,959 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs?prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:28,076 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/ef84df7e-72bf-4ac4-bfe4-dc67beda124d?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:38,052 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/ef84df7e-72bf-4ac4-bfe4-dc67beda124d?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:38,095 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/ef84df7e-72bf-4ac4-bfe4-dc67beda124d?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:38,792 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/queries/ef84df7e-72bf-4ac4-bfe4-dc67beda124d?maxResults=0&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:38,923 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/prj-ext-dev-pertcat-437314/jobs/ef84df7e-72bf-4ac4-bfe4-dc67beda124d?projection=full&location=europe-west2&prettyPrint=false HTTP/1.1" 200 None
# 2026-04-23 13:40:39,064 DEBUG urllib3.connectionpool: https://bigquery.googleapis.com:443 "DELETE /bigquery/v2/projects/prj-ext-dev-pertcat-437314/datasets/perturb_seq/tables/metadata_staging?prettyPrint=false HTTP/1.1" 204 0
# Merge completed: staging → prj-ext-dev-pertcat-437314.perturb_seq.metadata with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.perturb_seq.metadata_staging

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/replogle_2022_k562_gw_raw_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
# Out:
# WARNING: Parallel composite upload was turned ON to get the best performance on
# uploading large objects. If you would like to opt-out and instead
# perform a normal upload, run:
# `gcloud config set storage/parallel_composite_upload_enabled False`
# If you would like to disable this warning, run:
# `gcloud config set storage/parallel_composite_upload_enabled True`
# Note that with parallel composite uploads, your object might be
# uploaded as a composite object
# (https://cloud.google.com/storage/docs/composite-objects), which means
# that any user who downloads your object will need to use crc32c
# checksums to verify data integrity. gcloud storage is capable of
# computing crc32c checksums, but this might pose a problem for other
# clients.
#
# Copying file://../curated/h5ad/replogle_2022_k562_gw_raw_curated.h5ad to gs://perturbation-catalogue-lake/perturbseq/curated/replogle_2022_k562_gw_raw_curated.h5ad
#   Completed files 32/1 | 61.6GiB/61.6GiB | 184.3MiB/s
#
# Average throughput: 305.1MiB/s
