# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)
# show all columns
pd.set_option('display.max_columns', None)
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/.venv/lib/python3.12/site-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# # Download data

# %%
# !aws s3 cp --no-sign-request s3://genome-scale-tcell-perturb-seq/marson2025_data/D1_Rest.assigned_guide.h5ad ../non_curated/h5ad/zhu_2025_D1_rest_cl.h5ad
# !mv /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/D1_Rest.assigned_guide.h5ad /content/PerturbationCatalogue/data_exploration/Perturbseq/non_curated/h5ad/zhu_2025_pseudobulk.h5ad
# Out:
# UsageError: Line magic function `%aws` not found.

# %%
# !pwd
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/Perturbseq/curation_notebooks

# %% [markdown]
# # Initialise the dataset object

# %%
noncurated_path = '../non_curated/h5ad/zhu_2025_D1_rest_cl.h5ad'
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from ../non_curated/h5ad/zhu_2025_D1_rest_cl.h5ad

# %%
cur_data.adata.obs
# Out:
#                                                        lane_id  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  CD4i_R1L08
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  CD4i_R1L08
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  CD4i_R1L08
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...  CD4i_R1L08
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...  CD4i_R1L08
# ...                                                        ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  CD4i_R1L21
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...  CD4i_R1L21
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...  CD4i_R1L21
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...  CD4i_R1L21
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  CD4i_R1L21
#
#                                                     n_genes_by_counts  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...               1953
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...               4576
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...               1890
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...               5070
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...               4881
# ...                                                               ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...               2725
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...               4145
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...               3504
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...               2624
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...               3231
#
#                                                     total_counts  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        2969.0
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...       13363.0
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        3016.0
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...       16130.0
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...       13876.0
# ...                                                          ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...        5182.0
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...       10171.0
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...        9302.0
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...        4919.0
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...        6540.0
#
#                                                     pct_counts_mt  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...       0.269451
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...       1.017735
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...       0.397878
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...       0.440174
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...       0.317094
# ...                                                           ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...       0.135083
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...       0.304788
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...       0.225758
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...       0.203293
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...       0.030581
#
#                                                     top_guide_UMI_counts  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                   NaN
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                  22.0
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                   9.0
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...                  10.0
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...                 102.0
# ...                                                                  ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...                   NaN
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...                   NaN
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...                   NaN
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...                  25.0
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...                  42.0
#
#                                                      guide_id  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        NaN
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...    NTC-461
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  PLA2G10-2
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...  ATXN7L3-1
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...     EVI5-1
# ...                                                       ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...        NaN
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...        NaN
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...        NaN
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...   KIF18A-2
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...   ZNF442-2
#
#                                                    perturbed_gene_name  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                 NaN
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                 NTC
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...             PLA2G10
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...             ATXN7L3
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...                EVI5
# ...                                                                ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...                 NaN
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...                 NaN
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...                 NaN
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...              KIF18A
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...              ZNF442
#
#                                                    perturbed_gene_id  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...               NaN
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...               NTC
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...   ENSG00000069764
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...   ENSG00000087152
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...   ENSG00000067208
# ...                                                              ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...               NaN
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...               NaN
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...               NaN
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...   ENSG00000121621
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...   ENSG00000198342
#
#                                                        guide_type     PuroR  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...            NaN  2.100727
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  non-targeting  1.431987
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...      targeting  1.209989
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...      targeting  1.015303
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...      targeting  2.463184
# ...                                                           ...       ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...            NaN  1.451924
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...            NaN  1.466352
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...            NaN  0.000000
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...      targeting  1.492056
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...      targeting  2.538781
#
#                                                                guide_group  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...                no sgRNA
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  targeting single sgRNA
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  targeting single sgRNA
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...  targeting single sgRNA
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...  targeting single sgRNA
# ...                                                                    ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...                no sgRNA
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...                no sgRNA
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...                no sgRNA
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...  targeting single sgRNA
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  targeting single sgRNA
#
#                                                     low_quality  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        False
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        False
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...        False
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...        False
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...        False
# ...                                                         ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...        False
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...        False
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...        False
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...        False
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...        False
#
#                                                                   cell_barcode  \
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAACCGGTATGTTGAC-1
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAATACCGATGTTGAC-1
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAATCACGATGTTGAC-1
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAACAAAGAAACGGGAA-1
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAACAAAGAACTTTAGG-1
# ...                                                                        ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTGTGACTAACGGGAA-1
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTGTGACTATGTTGAC-1
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTAACCAAGTAGGCT-1
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTCGCCTACTTTAGG-1
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTGTTGAAACGGGAA-1
#
#                                                                         perturbation_name
# AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08
# AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08
# AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08
# AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08
# AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08_CD4i_R1_D...  AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08
# ...                                                                                   ...
# TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21
# TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21
# TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21
# TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21_CD4i_R1_D...  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21
#
# [2548393 rows x 14 columns]

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ENSG00000000460  ENSG00000000460  Gene Expression  GRCh38  C1orf112  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
#
# [18130 rows x 5 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Since for multi-guide perturbations the identities of said guides are unknown, we are filtering out these cells.

# %%
print(f"Number of cells before filtering: {cur_data.adata.n_obs}")
cur_data.adata = cur_data.adata[cur_data.adata.obs['guide_id'] != 'multi_sgRNA']
print(f"Number of cells after filtering: {cur_data.adata.n_obs}")
# Out:
# Number of cells before filtering: 3074496
# Number of cells after filtering: 2548393

# %% [markdown]
# ### Add `index` as `perturbation_name`

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]
cur_data.adata.obs['perturbation_name'] = cur_data.adata.obs['cell_barcode'] +'_'+cur_data.adata.obs['lane_id'].astype(str)
# Out:
# /tmp/ipykernel_2509942/2231587657.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'perturbation_name')

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv",
    dest_path="../supplementary/zhu_2025_guide_info.csv"
)
# read in the guide RNA info csv
guide_info_df = pd.read_csv("../supplementary/zhu_2025_guide_info.csv")

guide_info_df = guide_info_df[['sgRNA', 'seq']]

guide_info_df['sgRNA'] = guide_info_df['sgRNA'].str.replace('1-Jun','JUN-1').str.replace('2-Jun','JUN-2')

guide_info_df = guide_info_df.rename(columns={'seq': 'guide_sequence', 'sgRNA':'guide_id'})

guide_info_df
# Out:
# Downloaded https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv to ../supplementary/zhu_2025_guide_info.csv
#         guide_id        guide_sequence
# 0        ARMC5-1  CTGCCTCGCGCAGCTCGCGG
# 1         DDB1-1  GGAGTTCGCTGCGCGCTGTT
# 2       FNDC10-1  TGCCCGCTCCCCGCGATCCC
# 3         RORC-1  TCTGTGGGGCCCTGTCCATG
# 4      SLC35F6-1  GAACAGCTGGTACTTGGTCC
# ...          ...                   ...
# 26499    NTC-988  TTTCAGGCTACGGGCGCGGG
# 26500    NTC-989  TTTCCCATGATCATTTAGTG
# 26501    NTC-990  TTTCGCCCAAGAGGCTTGGG
# 26502    NTC-991  TTTCGTGCCGATGTAACACA
# 26503    NTC-992  TTTGGGTTTATCCGCCCCCA
#
# [26504 rows x 2 columns]

# %%
print("Number of overlapping guides with cur_data:")
cur_data.adata.obs['guide_id'].isin(guide_info_df['guide_id'].to_list()).value_counts()
# Out:
# Number of overlapping guides with cur_data:
# guide_id
# True     1754014
# False     794379
# Name: count, dtype: int64

# %%
# merge cur_data.adata.obs with guide_info_df
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='guide_id', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Number of missing guide sequences: 794379

# %%
cur_data.adata.obs
# Out:
#             lane_id  n_genes_by_counts  total_counts  pct_counts_mt  \
# 0        CD4i_R1L08               1953        2969.0       0.269451
# 1        CD4i_R1L08               4576       13363.0       1.017735
# 2        CD4i_R1L08               1890        3016.0       0.397878
# 3        CD4i_R1L08               5070       16130.0       0.440174
# 4        CD4i_R1L08               4881       13876.0       0.317094
# ...             ...                ...           ...            ...
# 2548388  CD4i_R1L21               2725        5182.0       0.135083
# 2548389  CD4i_R1L21               4145       10171.0       0.304788
# 2548390  CD4i_R1L21               3504        9302.0       0.225758
# 2548391  CD4i_R1L21               2624        4919.0       0.203293
# 2548392  CD4i_R1L21               3231        6540.0       0.030581
#
#          top_guide_UMI_counts   guide_id   perturbed_gene_name  \
# 0                         NaN        NaN       control_casonly
# 1                        22.0    NTC-461  control_nontargeting
# 2                         9.0  PLA2G10-2               PLA2G10
# 3                        10.0  ATXN7L3-1               ATXN7L3
# 4                       102.0     EVI5-1                  EVI5
# ...                       ...        ...                   ...
# 2548388                   NaN        NaN       control_casonly
# 2548389                   NaN        NaN       control_casonly
# 2548390                   NaN        NaN       control_casonly
# 2548391                  25.0   KIF18A-2                KIF18A
# 2548392                  42.0   ZNF442-2                ZNF442
#
#             perturbed_gene_id     guide_type     PuroR  \
# 0             control_casonly            NaN  2.100727
# 1        control_nontargeting  non-targeting  1.431987
# 2             ENSG00000069764      targeting  1.209989
# 3             ENSG00000087152      targeting  1.015303
# 4             ENSG00000067208      targeting  2.463184
# ...                       ...            ...       ...
# 2548388       control_casonly            NaN  1.451924
# 2548389       control_casonly            NaN  1.466352
# 2548390       control_casonly            NaN  0.000000
# 2548391       ENSG00000121621      targeting  1.492056
# 2548392       ENSG00000198342      targeting  2.538781
#
#                     guide_group  low_quality                cell_barcode  \
# 0                      no sgRNA        False  AAACAAGCAAACCGGTATGTTGAC-1
# 1        targeting single sgRNA        False  AAACAAGCAAATACCGATGTTGAC-1
# 2        targeting single sgRNA        False  AAACAAGCAAATCACGATGTTGAC-1
# 3        targeting single sgRNA        False  AAACAAGCAACAAAGAAACGGGAA-1
# 4        targeting single sgRNA        False  AAACAAGCAACAAAGAACTTTAGG-1
# ...                         ...          ...                         ...
# 2548388                no sgRNA        False  TTTGTGAGTTGTGACTAACGGGAA-1
# 2548389                no sgRNA        False  TTTGTGAGTTGTGACTATGTTGAC-1
# 2548390                no sgRNA        False  TTTGTGAGTTTAACCAAGTAGGCT-1
# 2548391  targeting single sgRNA        False  TTTGTGAGTTTCGCCTACTTTAGG-1
# 2548392  targeting single sgRNA        False  TTTGTGAGTTTGTTGAAACGGGAA-1
#
#                              perturbation_name        guide_sequence
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08                   NaN
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08  TGGGAATTCCTCGGCCGATT
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08  GGGTGCTGCAGGGCCACCGG
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08  GAGCGCGTGCATCTGCCCCG
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08  GGAGGAACCAGCTGGCCAGC
# ...                                        ...                   ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21                   NaN
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21                   NaN
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21                   NaN
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21  AGGCGGACATTAAAGTGAAG
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21  GCTGGCAGCGGGGAACCTTG
#
# [2548393 rows x 15 columns]

# %%
# change perturbed_gene_id from categorical to string
cur_data.adata.obs['perturbed_gene_id'] = cur_data.adata.obs['perturbed_gene_id'].astype(str)
cur_data.adata.obs['perturbed_gene_name'] = cur_data.adata.obs['perturbed_gene_name'].astype(str)

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isin(['NTC']), 'perturbed_gene_id'] = 'control_nontargeting'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin(['NTC']), 'perturbed_gene_name'] = 'control_nontargeting'

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isna(), 'perturbed_gene_id'] = 'control_casonly'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isna(), 'perturbed_gene_name'] = 'control_casonly'

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_gene_id',
    input_column_type='ensembl_gene_id',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Missing Ensembl IDs: ['AKAP2', 'ENSG00000277796', 'LUZP6', 'ENSG00000203812', 'ENSG00000255823', 'ENSG00000182230', 'ENSG00000148362', 'ENSG00000232196', 'OCLM', 'ENSG00000256618', 'SEPT6', 'U2AF1L5', 'SMIM11B', 'SGK494']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000277796': 'ENSG00000293545', 'ENSG00000203812': 'ENSG00000288825', 'ENSG00000255823': nan, 'ENSG00000182230': nan, 'ENSG00000148362': 'ENSG00000310560', 'ENSG00000232196': nan, 'ENSG00000256618': nan}
# --------------------------------------------------
# Successfully mapped 12101 out of 12101 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
cur_data.adata.obs
# Out:
#          top_guide_UMI_counts     PuroR   guide_id   perturbed_gene_name  \
# index
# 0                         NaN  2.100727        NaN       control_casonly
# 1                        22.0  1.431987    NTC-461  control_nontargeting
# 2                         9.0  1.209989  PLA2G10-2               PLA2G10
# 3                        10.0  1.015303  ATXN7L3-1               ATXN7L3
# 4                       102.0  2.463184     EVI5-1                  EVI5
# ...                       ...       ...        ...                   ...
# 2548388                   NaN  1.451924        NaN       control_casonly
# 2548389                   NaN  1.466352        NaN       control_casonly
# 2548390                   NaN  0.000000        NaN       control_casonly
# 2548391                  25.0  1.492056   KIF18A-2                KIF18A
# 2548392                  42.0  2.538781   ZNF442-2                ZNF442
#
#                guide_sequence             guide_group  n_genes_by_counts  \
# index
# 0                         NaN                no sgRNA               1953
# 1        TGGGAATTCCTCGGCCGATT  targeting single sgRNA               4576
# 2        GGGTGCTGCAGGGCCACCGG  targeting single sgRNA               1890
# 3        GAGCGCGTGCATCTGCCCCG  targeting single sgRNA               5070
# 4        GGAGGAACCAGCTGGCCAGC  targeting single sgRNA               4881
# ...                       ...                     ...                ...
# 2548388                   NaN                no sgRNA               2725
# 2548389                   NaN                no sgRNA               4145
# 2548390                   NaN                no sgRNA               3504
# 2548391  AGGCGGACATTAAAGTGAAG  targeting single sgRNA               2624
# 2548392  GCTGGCAGCGGGGAACCTTG  targeting single sgRNA               3231
#
#                              perturbation_name     perturbed_gene_id  \
# index
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08       control_casonly
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08  control_nontargeting
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08       ENSG00000069764
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08       ENSG00000087152
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08       ENSG00000067208
# ...                                        ...                   ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21       control_casonly
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21       control_casonly
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21       control_casonly
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21       ENSG00000121621
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21       ENSG00000198342
#
#          total_counts                cell_barcode     lane_id  low_quality  \
# index
# 0              2969.0  AAACAAGCAAACCGGTATGTTGAC-1  CD4i_R1L08        False
# 1             13363.0  AAACAAGCAAATACCGATGTTGAC-1  CD4i_R1L08        False
# 2              3016.0  AAACAAGCAAATCACGATGTTGAC-1  CD4i_R1L08        False
# 3             16130.0  AAACAAGCAACAAAGAAACGGGAA-1  CD4i_R1L08        False
# 4             13876.0  AAACAAGCAACAAAGAACTTTAGG-1  CD4i_R1L08        False
# ...               ...                         ...         ...          ...
# 2548388        5182.0  TTTGTGAGTTGTGACTAACGGGAA-1  CD4i_R1L21        False
# 2548389       10171.0  TTTGTGAGTTGTGACTATGTTGAC-1  CD4i_R1L21        False
# 2548390        9302.0  TTTGTGAGTTTAACCAAGTAGGCT-1  CD4i_R1L21        False
# 2548391        4919.0  TTTGTGAGTTTCGCCTACTTTAGG-1  CD4i_R1L21        False
# 2548392        6540.0  TTTGTGAGTTTGTTGAAACGGGAA-1  CD4i_R1L21        False
#
#          pct_counts_mt     guide_type perturbed_target_ensg  \
# index
# 0             0.269451            NaN       control_casonly
# 1             1.017735  non-targeting  control_nontargeting
# 2             0.397878      targeting       ENSG00000069764
# 3             0.440174      targeting       ENSG00000087152
# 4             0.317094      targeting       ENSG00000067208
# ...                ...            ...                   ...
# 2548388       0.135083            NaN       control_casonly
# 2548389       0.304788            NaN       control_casonly
# 2548390       0.225758            NaN       control_casonly
# 2548391       0.203293      targeting       ENSG00000121621
# 2548392       0.030581      targeting       ENSG00000198342
#
#         perturbed_target_symbol perturbed_target_biotype  \
# index
# 0               control_casonly          control_casonly
# 1          control_nontargeting     control_nontargeting
# 2                       PLA2G10           protein_coding
# 3                       ATXN7L3           protein_coding
# 4                          EVI5           protein_coding
# ...                         ...                      ...
# 2548388         control_casonly          control_casonly
# 2548389         control_casonly          control_casonly
# 2548390         control_casonly          control_casonly
# 2548391                  KIF18A           protein_coding
# 2548392                  ZNF442           protein_coding
#
#              perturbed_target_coord perturbed_target_chromosome original_index
# index
# 0                   control_casonly             control_casonly              0
# 1              control_nontargeting        control_nontargeting              1
# 2        chr16:14672548-14694308;-1                          16              2
# 3        chr17:44191805-44200961;-1                          17              3
# 4         chr1:92508696-92792416;-1                           1              4
# ...                             ...                         ...            ...
# 2548388             control_casonly             control_casonly        2548388
# 2548389             control_casonly             control_casonly        2548389
# 2548390             control_casonly             control_casonly        2548390
# 2548391  chr11:28020618-28108183;-1                          11        2548391
# 2548392  chr19:12345944-12365905;-1                          19        2548392
#
# [2548393 rows x 21 columns]

# %% [markdown]
# # Manually replace some genes

# %%
# define genes to replace in the cur_data.adata.obs
genes_to_replace = cur_data.adata.obs[cur_data.adata.obs['perturbed_target_symbol'].isna()]['perturbed_gene_name'].drop_duplicates().to_list()
# define columns to replace
cols_to_replace = ['perturbed_target_ensg',	'perturbed_target_symbol',	'perturbed_target_biotype',	'perturbed_target_coord',	'perturbed_target_chromosome']
# define mapping dict for renaming columns in gene_ont for replacement
gene_ont_col_mapping = {
    'ensembl_gene_id':'perturbed_target_ensg',
    'gene_symbol':'perturbed_target_symbol',
    'biotype':'perturbed_target_biotype',
    'gene_coord':'perturbed_target_coord',
    'chromosome_name':'perturbed_target_chromosome'
}
# loop through genes and fill in the missing cols
for replacement_gene in genes_to_replace:
    if replacement_gene in cur_data.gene_ont['synonym'].values:
        # subset gene_ont and get values for replacement
        replacement = (
            cur_data.gene_ont.rename(columns=gene_ont_col_mapping)
            .loc[cur_data.gene_ont['synonym'].isin([replacement_gene]), cols_to_replace]
        )[cols_to_replace].values[0]
        # replace values in cur_data.adata.obs with the values from gene_ont
        cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin([replacement_gene]), cols_to_replace] = replacement
        print(f"Replaced {replacement_gene} with {replacement}")
    else:
        print(f"No replacement found for {replacement_gene}")
# Out:
# No replacement found for MTRNR2L1
# No replacement found for FAM153B
# No replacement found for AKAP2
# Replaced SEPT6 with ['ENSG00000125354' 'SEPTIN6' 'protein_coding'
#  'chrX:119615724-119693949;-1' 'X']
# No replacement found for SMIM11B
# No replacement found for MTRNR2L4
# No replacement found for LUZP6
# No replacement found for OCLM
# Replaced SGK494 with ['ENSG00000167524' 'RSKR' 'protein_coding' 'chr17:28455752-28614197;-1'
#  '17']
# No replacement found for U2AF1L5
# No replacement found for CCL3L1
# No replacement found for MTRNR2L8

# %%
# replace non-mapped perturbed_target_symbol with original gene symbols
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_target_symbol'] = cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_gene_name'].values

# %%
# replace entries in perturbed_target_ensg that are not ENSEMBL ids with NA
cur_data.adata.obs.loc[(~cur_data.adata.obs['perturbed_target_ensg'].str.startswith('ENSG')) & (cur_data.adata.obs['perturbed_target_ensg'] != 'control_nontargeting'), 'perturbed_target_ensg'] = pd.NA

# %%
cur_data.adata.obs
# Out:
#          top_guide_UMI_counts     PuroR   guide_id   perturbed_gene_name  \
# index
# 0                         NaN  2.100727        NaN       control_casonly
# 1                        22.0  1.431987    NTC-461  control_nontargeting
# 2                         9.0  1.209989  PLA2G10-2               PLA2G10
# 3                        10.0  1.015303  ATXN7L3-1               ATXN7L3
# 4                       102.0  2.463184     EVI5-1                  EVI5
# ...                       ...       ...        ...                   ...
# 2548388                   NaN  1.451924        NaN       control_casonly
# 2548389                   NaN  1.466352        NaN       control_casonly
# 2548390                   NaN  0.000000        NaN       control_casonly
# 2548391                  25.0  1.492056   KIF18A-2                KIF18A
# 2548392                  42.0  2.538781   ZNF442-2                ZNF442
#
#                guide_sequence             guide_group  n_genes_by_counts  \
# index
# 0                         NaN                no sgRNA               1953
# 1        TGGGAATTCCTCGGCCGATT  targeting single sgRNA               4576
# 2        GGGTGCTGCAGGGCCACCGG  targeting single sgRNA               1890
# 3        GAGCGCGTGCATCTGCCCCG  targeting single sgRNA               5070
# 4        GGAGGAACCAGCTGGCCAGC  targeting single sgRNA               4881
# ...                       ...                     ...                ...
# 2548388                   NaN                no sgRNA               2725
# 2548389                   NaN                no sgRNA               4145
# 2548390                   NaN                no sgRNA               3504
# 2548391  AGGCGGACATTAAAGTGAAG  targeting single sgRNA               2624
# 2548392  GCTGGCAGCGGGGAACCTTG  targeting single sgRNA               3231
#
#                              perturbation_name     perturbed_gene_id  \
# index
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08       control_casonly
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08  control_nontargeting
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08       ENSG00000069764
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08       ENSG00000087152
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08       ENSG00000067208
# ...                                        ...                   ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21       control_casonly
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21       control_casonly
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21       control_casonly
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21       ENSG00000121621
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21       ENSG00000198342
#
#          total_counts                cell_barcode     lane_id  low_quality  \
# index
# 0              2969.0  AAACAAGCAAACCGGTATGTTGAC-1  CD4i_R1L08        False
# 1             13363.0  AAACAAGCAAATACCGATGTTGAC-1  CD4i_R1L08        False
# 2              3016.0  AAACAAGCAAATCACGATGTTGAC-1  CD4i_R1L08        False
# 3             16130.0  AAACAAGCAACAAAGAAACGGGAA-1  CD4i_R1L08        False
# 4             13876.0  AAACAAGCAACAAAGAACTTTAGG-1  CD4i_R1L08        False
# ...               ...                         ...         ...          ...
# 2548388        5182.0  TTTGTGAGTTGTGACTAACGGGAA-1  CD4i_R1L21        False
# 2548389       10171.0  TTTGTGAGTTGTGACTATGTTGAC-1  CD4i_R1L21        False
# 2548390        9302.0  TTTGTGAGTTTAACCAAGTAGGCT-1  CD4i_R1L21        False
# 2548391        4919.0  TTTGTGAGTTTCGCCTACTTTAGG-1  CD4i_R1L21        False
# 2548392        6540.0  TTTGTGAGTTTGTTGAAACGGGAA-1  CD4i_R1L21        False
#
#          pct_counts_mt     guide_type perturbed_target_ensg  \
# index
# 0             0.269451            NaN                   NaN
# 1             1.017735  non-targeting  control_nontargeting
# 2             0.397878      targeting       ENSG00000069764
# 3             0.440174      targeting       ENSG00000087152
# 4             0.317094      targeting       ENSG00000067208
# ...                ...            ...                   ...
# 2548388       0.135083            NaN                   NaN
# 2548389       0.304788            NaN                   NaN
# 2548390       0.225758            NaN                   NaN
# 2548391       0.203293      targeting       ENSG00000121621
# 2548392       0.030581      targeting       ENSG00000198342
#
#         perturbed_target_symbol perturbed_target_biotype  \
# index
# 0               control_casonly          control_casonly
# 1          control_nontargeting     control_nontargeting
# 2                       PLA2G10           protein_coding
# 3                       ATXN7L3           protein_coding
# 4                          EVI5           protein_coding
# ...                         ...                      ...
# 2548388         control_casonly          control_casonly
# 2548389         control_casonly          control_casonly
# 2548390         control_casonly          control_casonly
# 2548391                  KIF18A           protein_coding
# 2548392                  ZNF442           protein_coding
#
#              perturbed_target_coord perturbed_target_chromosome original_index
# index
# 0                   control_casonly             control_casonly              0
# 1              control_nontargeting        control_nontargeting              1
# 2        chr16:14672548-14694308;-1                          16              2
# 3        chr17:44191805-44200961;-1                          17              3
# 4         chr1:92508696-92792416;-1                           1              4
# ...                             ...                         ...            ...
# 2548388             control_casonly             control_casonly        2548388
# 2548389             control_casonly             control_casonly        2548389
# 2548390             control_casonly             control_casonly        2548390
# 2548391  chr11:28020618-28108183;-1                          11        2548391
# 2548392  chr19:12345944-12365905;-1                          19        2548392
#
# [2548393 rows x 21 columns]

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
# cur_data.count_entries(
#     slot='obs',
#     input_column='perturbed_target_ensg',
#     count_column_name='perturbed_target_number',
#     sep='|'
# )
cur_data.adata.obs['perturbed_target_number'] = 1

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.adata.obs[['perturbation_name', 'perturbed_target_chromosome_encoding']]
# Out:
#                              perturbation_name  \
# index
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08
# ...                                        ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           0
# 2                                          16
# 3                                          17
# 4                                           1
# ...                                       ...
# 2548388                                     0
# 2548389                                     0
# 2548390                                     0
# 2548391                                    11
# 2548392                                    19
#
# [2548393 rows x 2 columns]

# %%
cur_data.adata.obs
# Out:
#          top_guide_UMI_counts     PuroR   guide_id   perturbed_gene_name  \
# index
# 0                         NaN  2.100727        NaN       control_casonly
# 1                        22.0  1.431987    NTC-461  control_nontargeting
# 2                         9.0  1.209989  PLA2G10-2               PLA2G10
# 3                        10.0  1.015303  ATXN7L3-1               ATXN7L3
# 4                       102.0  2.463184     EVI5-1                  EVI5
# ...                       ...       ...        ...                   ...
# 2548388                   NaN  1.451924        NaN       control_casonly
# 2548389                   NaN  1.466352        NaN       control_casonly
# 2548390                   NaN  0.000000        NaN       control_casonly
# 2548391                  25.0  1.492056   KIF18A-2                KIF18A
# 2548392                  42.0  2.538781   ZNF442-2                ZNF442
#
#                guide_sequence             guide_group  n_genes_by_counts  \
# index
# 0                         NaN                no sgRNA               1953
# 1        TGGGAATTCCTCGGCCGATT  targeting single sgRNA               4576
# 2        GGGTGCTGCAGGGCCACCGG  targeting single sgRNA               1890
# 3        GAGCGCGTGCATCTGCCCCG  targeting single sgRNA               5070
# 4        GGAGGAACCAGCTGGCCAGC  targeting single sgRNA               4881
# ...                       ...                     ...                ...
# 2548388                   NaN                no sgRNA               2725
# 2548389                   NaN                no sgRNA               4145
# 2548390                   NaN                no sgRNA               3504
# 2548391  AGGCGGACATTAAAGTGAAG  targeting single sgRNA               2624
# 2548392  GCTGGCAGCGGGGAACCTTG  targeting single sgRNA               3231
#
#                              perturbation_name     perturbed_gene_id  \
# index
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08       control_casonly
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08  control_nontargeting
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08       ENSG00000069764
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08       ENSG00000087152
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08       ENSG00000067208
# ...                                        ...                   ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21       control_casonly
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21       control_casonly
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21       control_casonly
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21       ENSG00000121621
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21       ENSG00000198342
#
#          total_counts                cell_barcode     lane_id  low_quality  \
# index
# 0              2969.0  AAACAAGCAAACCGGTATGTTGAC-1  CD4i_R1L08        False
# 1             13363.0  AAACAAGCAAATACCGATGTTGAC-1  CD4i_R1L08        False
# 2              3016.0  AAACAAGCAAATCACGATGTTGAC-1  CD4i_R1L08        False
# 3             16130.0  AAACAAGCAACAAAGAAACGGGAA-1  CD4i_R1L08        False
# 4             13876.0  AAACAAGCAACAAAGAACTTTAGG-1  CD4i_R1L08        False
# ...               ...                         ...         ...          ...
# 2548388        5182.0  TTTGTGAGTTGTGACTAACGGGAA-1  CD4i_R1L21        False
# 2548389       10171.0  TTTGTGAGTTGTGACTATGTTGAC-1  CD4i_R1L21        False
# 2548390        9302.0  TTTGTGAGTTTAACCAAGTAGGCT-1  CD4i_R1L21        False
# 2548391        4919.0  TTTGTGAGTTTCGCCTACTTTAGG-1  CD4i_R1L21        False
# 2548392        6540.0  TTTGTGAGTTTGTTGAAACGGGAA-1  CD4i_R1L21        False
#
#          pct_counts_mt     guide_type perturbed_target_ensg  \
# index
# 0             0.269451            NaN                   NaN
# 1             1.017735  non-targeting  control_nontargeting
# 2             0.397878      targeting       ENSG00000069764
# 3             0.440174      targeting       ENSG00000087152
# 4             0.317094      targeting       ENSG00000067208
# ...                ...            ...                   ...
# 2548388       0.135083            NaN                   NaN
# 2548389       0.304788            NaN                   NaN
# 2548390       0.225758            NaN                   NaN
# 2548391       0.203293      targeting       ENSG00000121621
# 2548392       0.030581      targeting       ENSG00000198342
#
#         perturbed_target_symbol perturbed_target_biotype  \
# index
# 0               control_casonly          control_casonly
# 1          control_nontargeting     control_nontargeting
# 2                       PLA2G10           protein_coding
# 3                       ATXN7L3           protein_coding
# 4                          EVI5           protein_coding
# ...                         ...                      ...
# 2548388         control_casonly          control_casonly
# 2548389         control_casonly          control_casonly
# 2548390         control_casonly          control_casonly
# 2548391                  KIF18A           protein_coding
# 2548392                  ZNF442           protein_coding
#
#              perturbed_target_coord perturbed_target_chromosome  \
# index
# 0                   control_casonly             control_casonly
# 1              control_nontargeting        control_nontargeting
# 2        chr16:14672548-14694308;-1                          16
# 3        chr17:44191805-44200961;-1                          17
# 4         chr1:92508696-92792416;-1                           1
# ...                             ...                         ...
# 2548388             control_casonly             control_casonly
# 2548389             control_casonly             control_casonly
# 2548390             control_casonly             control_casonly
# 2548391  chr11:28020618-28108183;-1                          11
# 2548392  chr19:12345944-12365905;-1                          19
#
#         original_index  perturbed_target_number  \
# index
# 0                    0                        1
# 1                    1                        1
# 2                    2                        1
# 3                    3                        1
# 4                    4                        1
# ...                ...                      ...
# 2548388        2548388                        1
# 2548389        2548389                        1
# 2548390        2548390                        1
# 2548391        2548391                        1
# 2548392        2548392                        1
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           0
# 2                                          16
# 3                                          17
# 4                                           1
# ...                                       ...
# 2548388                                     0
# 2548389                                     0
# 2548390                                     0
# 2548391                                    11
# 2548392                                    19
#
# [2548393 rows x 23 columns]

# %% [markdown]
# ### Curate replicates

# %%
cur_data.adata.obs = cur_data.adata.obs.rename(columns={'lane_id':'technical_replicate'})

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": "untreated control",
        "treatment_id": "NCIT:C184729",
        # replicates
        # "technical_replicate": None,
        "biological_replicate": "D1_CE0008162",
        # model system
        "model_system_label": "primary_cell",
        "model_system_id": None,
        "tissue": "lymphoid tissue",
        "cell_line_label": None,
        "cell_line_id": None,
        "cell_type_label": "CD4-positive, alpha-beta T cell",
        "disease_label": "healthy",
        "disease_id": None,

        "timepoint": "P12DT8H0M0S",
        "species": "Homo sapiens",
        "sex_label": "female",
        "sex_id": None,
        "developmental_stage_label": "adult",
        "developmental_stage_id": None,

        "study_title": "Genome-scale perturb-seq in primary human CD4+ T cells maps context-specific regulators of T cell programs and human immune traits",
        "study_uri": "https://doi.org/10.64898/2025.12.23.696273",
        "study_year": 2025,
        "first_author": "Ronghui Zhu",
        "last_author": "Alexander Marson",

        "experiment_title": "Perturb-seq of primary human CD4-positive T cells for patient D1_CE0008162 under resting conditions",
        "experiment_summary": """
            Isolated human CD4-positive cells from four healthy donors were stimulated with ImmunoCult CD3/CD28/CD2 activator and sequentially transduced with dCas9-KRAB-Zim3 lentivirus (next morning after stimulation) and a Perturb-seq guide library (next afternoon after stimulation, MOI 0.2).
            The library consisted all genes expressed in human CD4+ T cells, all transcription factors annotated in the Lambert et al. (2018) and non-targeting controls totalling 12,748 genes.
            The gRNA sequences were selected from hCRISPRiv2 and Dolcetto libraries.
            On day 12, cells were split into three conditions:
            (1) Rest - cells were left for 8 hr without stimulation;
            (2) Stim8hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 8 hr;
            (3) Stim48hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 48 hr.
            Cells were harvested, fixed, stored using GEM-X Flex Sample Preparation v2 Kit and sequenced using GEM-X Flex Gene Expression Human n-plex kit converted into Ultima compatible libraries for sequencing on the Ultima Genomics UG100.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_symbol'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB-Zim3",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Marson lab",
        "library_lentiviral_generation": "2",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "GEM-X Flex Gene Expression Human n-plex kit",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "scanpy",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",

        "license_label": "MIT License",
        "license_id": "SWO:9000074",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "Primary Human CD4+ T Cell Perturb-seq",
                "dataset_uri": "s3://genome-scale-tcell-perturb-seq/marson2025_data/D1_Rest.assigned_guide.h5ad",
                "dataset_description": "Cell expression profiles for cells from donor D1_CE0008162 under resting conditions.",
                "dataset_file_name": "D1_Rest.assigned_guide.h5ad.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column biological_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_line_id added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column disease_id added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#          top_guide_UMI_counts     PuroR   guide_id   perturbed_gene_name  \
# index
# 0                         NaN  2.100727        NaN       control_casonly
# 1                        22.0  1.431987    NTC-461  control_nontargeting
# 2                         9.0  1.209989  PLA2G10-2               PLA2G10
# 3                        10.0  1.015303  ATXN7L3-1               ATXN7L3
# 4                       102.0  2.463184     EVI5-1                  EVI5
# ...                       ...       ...        ...                   ...
# 2548388                   NaN  1.451924        NaN       control_casonly
# 2548389                   NaN  1.466352        NaN       control_casonly
# 2548390                   NaN  0.000000        NaN       control_casonly
# 2548391                  25.0  1.492056   KIF18A-2                KIF18A
# 2548392                  42.0  2.538781   ZNF442-2                ZNF442
#
#                guide_sequence             guide_group  n_genes_by_counts  \
# index
# 0                         NaN                no sgRNA               1953
# 1        TGGGAATTCCTCGGCCGATT  targeting single sgRNA               4576
# 2        GGGTGCTGCAGGGCCACCGG  targeting single sgRNA               1890
# 3        GAGCGCGTGCATCTGCCCCG  targeting single sgRNA               5070
# 4        GGAGGAACCAGCTGGCCAGC  targeting single sgRNA               4881
# ...                       ...                     ...                ...
# 2548388                   NaN                no sgRNA               2725
# 2548389                   NaN                no sgRNA               4145
# 2548390                   NaN                no sgRNA               3504
# 2548391  AGGCGGACATTAAAGTGAAG  targeting single sgRNA               2624
# 2548392  GCTGGCAGCGGGGAACCTTG  targeting single sgRNA               3231
#
#                              perturbation_name     perturbed_gene_id  \
# index
# 0        AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08       control_casonly
# 1        AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08  control_nontargeting
# 2        AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08       ENSG00000069764
# 3        AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08       ENSG00000087152
# 4        AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08       ENSG00000067208
# ...                                        ...                   ...
# 2548388  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21       control_casonly
# 2548389  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21       control_casonly
# 2548390  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21       control_casonly
# 2548391  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21       ENSG00000121621
# 2548392  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21       ENSG00000198342
#
#          total_counts                cell_barcode technical_replicate  \
# index
# 0              2969.0  AAACAAGCAAACCGGTATGTTGAC-1          CD4i_R1L08
# 1             13363.0  AAACAAGCAAATACCGATGTTGAC-1          CD4i_R1L08
# 2              3016.0  AAACAAGCAAATCACGATGTTGAC-1          CD4i_R1L08
# 3             16130.0  AAACAAGCAACAAAGAAACGGGAA-1          CD4i_R1L08
# 4             13876.0  AAACAAGCAACAAAGAACTTTAGG-1          CD4i_R1L08
# ...               ...                         ...                 ...
# 2548388        5182.0  TTTGTGAGTTGTGACTAACGGGAA-1          CD4i_R1L21
# 2548389       10171.0  TTTGTGAGTTGTGACTATGTTGAC-1          CD4i_R1L21
# 2548390        9302.0  TTTGTGAGTTTAACCAAGTAGGCT-1          CD4i_R1L21
# 2548391        4919.0  TTTGTGAGTTTCGCCTACTTTAGG-1          CD4i_R1L21
# 2548392        6540.0  TTTGTGAGTTTGTTGAAACGGGAA-1          CD4i_R1L21
#
#          low_quality  pct_counts_mt     guide_type perturbed_target_ensg  \
# index
# 0              False       0.269451            NaN                   NaN
# 1              False       1.017735  non-targeting  control_nontargeting
# 2              False       0.397878      targeting       ENSG00000069764
# 3              False       0.440174      targeting       ENSG00000087152
# 4              False       0.317094      targeting       ENSG00000067208
# ...              ...            ...            ...                   ...
# 2548388        False       0.135083            NaN                   NaN
# 2548389        False       0.304788            NaN                   NaN
# 2548390        False       0.225758            NaN                   NaN
# 2548391        False       0.203293      targeting       ENSG00000121621
# 2548392        False       0.030581      targeting       ENSG00000198342
#
#         perturbed_target_symbol perturbed_target_biotype  \
# index
# 0               control_casonly          control_casonly
# 1          control_nontargeting     control_nontargeting
# 2                       PLA2G10           protein_coding
# 3                       ATXN7L3           protein_coding
# 4                          EVI5           protein_coding
# ...                         ...                      ...
# 2548388         control_casonly          control_casonly
# 2548389         control_casonly          control_casonly
# 2548390         control_casonly          control_casonly
# 2548391                  KIF18A           protein_coding
# 2548392                  ZNF442           protein_coding
#
#              perturbed_target_coord perturbed_target_chromosome  \
# index
# 0                   control_casonly             control_casonly
# 1              control_nontargeting        control_nontargeting
# 2        chr16:14672548-14694308;-1                          16
# 3        chr17:44191805-44200961;-1                          17
# 4         chr1:92508696-92792416;-1                           1
# ...                             ...                         ...
# 2548388             control_casonly             control_casonly
# 2548389             control_casonly             control_casonly
# 2548390             control_casonly             control_casonly
# 2548391  chr11:28020618-28108183;-1                          11
# 2548392  chr19:12345944-12365905;-1                          19
#
#         original_index  perturbed_target_number  \
# index
# 0                    0                        1
# 1                    1                        1
# 2                    2                        1
# 3                    3                        1
# 4                    4                        1
# ...                ...                      ...
# 2548388        2548388                        1
# 2548389        2548389                        1
# 2548390        2548390                        1
# 2548391        2548391                        1
# 2548392        2548392                        1
#
#          perturbed_target_chromosome_encoding           dataset_id  sample_id  \
# index
# 0                                           0  zhu_2025_D1_rest_cl          1
# 1                                           0  zhu_2025_D1_rest_cl          2
# 2                                          16  zhu_2025_D1_rest_cl          3
# 3                                          17  zhu_2025_D1_rest_cl          4
# 4                                           1  zhu_2025_D1_rest_cl          5
# ...                                       ...                  ...        ...
# 2548388                                     0  zhu_2025_D1_rest_cl    2548389
# 2548389                                     0  zhu_2025_D1_rest_cl    2548390
# 2548390                                     0  zhu_2025_D1_rest_cl    2548391
# 2548391                                    11  zhu_2025_D1_rest_cl    2548392
# 2548392                                    19  zhu_2025_D1_rest_cl    2548393
#
#         perturbation_type_label perturbation_type_id data_modality  \
# index
# 0                       CRISPRi                 None   Perturb-seq
# 1                       CRISPRi                 None   Perturb-seq
# 2                       CRISPRi                 None   Perturb-seq
# 3                       CRISPRi                 None   Perturb-seq
# 4                       CRISPRi                 None   Perturb-seq
# ...                         ...                  ...           ...
# 2548388                 CRISPRi                 None   Perturb-seq
# 2548389                 CRISPRi                 None   Perturb-seq
# 2548390                 CRISPRi                 None   Perturb-seq
# 2548391                 CRISPRi                 None   Perturb-seq
# 2548392                 CRISPRi                 None   Perturb-seq
#
#         significant significance_criteria score_interpretation  \
# index
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
# ...             ...                   ...                  ...
# 2548388        None                  None                 None
# 2548389        None                  None                 None
# 2548390        None                  None                 None
# 2548391        None                  None                 None
# 2548392        None                  None                 None
#
#            treatment_label  treatment_id biological_replicate  \
# index
# 0        untreated control  NCIT:C184729         D1_CE0008162
# 1        untreated control  NCIT:C184729         D1_CE0008162
# 2        untreated control  NCIT:C184729         D1_CE0008162
# 3        untreated control  NCIT:C184729         D1_CE0008162
# 4        untreated control  NCIT:C184729         D1_CE0008162
# ...                    ...           ...                  ...
# 2548388  untreated control  NCIT:C184729         D1_CE0008162
# 2548389  untreated control  NCIT:C184729         D1_CE0008162
# 2548390  untreated control  NCIT:C184729         D1_CE0008162
# 2548391  untreated control  NCIT:C184729         D1_CE0008162
# 2548392  untreated control  NCIT:C184729         D1_CE0008162
#
#         model_system_label model_system_id           tissue cell_line_label  \
# index
# 0             primary_cell            None  lymphoid tissue            None
# 1             primary_cell            None  lymphoid tissue            None
# 2             primary_cell            None  lymphoid tissue            None
# 3             primary_cell            None  lymphoid tissue            None
# 4             primary_cell            None  lymphoid tissue            None
# ...                    ...             ...              ...             ...
# 2548388       primary_cell            None  lymphoid tissue            None
# 2548389       primary_cell            None  lymphoid tissue            None
# 2548390       primary_cell            None  lymphoid tissue            None
# 2548391       primary_cell            None  lymphoid tissue            None
# 2548392       primary_cell            None  lymphoid tissue            None
#
#         cell_line_id                  cell_type_label disease_label  \
# index
# 0               None  CD4-positive, alpha-beta T cell       healthy
# 1               None  CD4-positive, alpha-beta T cell       healthy
# 2               None  CD4-positive, alpha-beta T cell       healthy
# 3               None  CD4-positive, alpha-beta T cell       healthy
# 4               None  CD4-positive, alpha-beta T cell       healthy
# ...              ...                              ...           ...
# 2548388         None  CD4-positive, alpha-beta T cell       healthy
# 2548389         None  CD4-positive, alpha-beta T cell       healthy
# 2548390         None  CD4-positive, alpha-beta T cell       healthy
# 2548391         None  CD4-positive, alpha-beta T cell       healthy
# 2548392         None  CD4-positive, alpha-beta T cell       healthy
#
#         disease_id    timepoint       species sex_label sex_id  \
# index
# 0             None  P12DT8H0M0S  Homo sapiens    female   None
# 1             None  P12DT8H0M0S  Homo sapiens    female   None
# 2             None  P12DT8H0M0S  Homo sapiens    female   None
# 3             None  P12DT8H0M0S  Homo sapiens    female   None
# 4             None  P12DT8H0M0S  Homo sapiens    female   None
# ...            ...          ...           ...       ...    ...
# 2548388       None  P12DT8H0M0S  Homo sapiens    female   None
# 2548389       None  P12DT8H0M0S  Homo sapiens    female   None
# 2548390       None  P12DT8H0M0S  Homo sapiens    female   None
# 2548391       None  P12DT8H0M0S  Homo sapiens    female   None
# 2548392       None  P12DT8H0M0S  Homo sapiens    female   None
#
#         developmental_stage_label developmental_stage_id  \
# index
# 0                           adult                   None
# 1                           adult                   None
# 2                           adult                   None
# 3                           adult                   None
# 4                           adult                   None
# ...                           ...                    ...
# 2548388                     adult                   None
# 2548389                     adult                   None
# 2548390                     adult                   None
# 2548391                     adult                   None
# 2548392                     adult                   None
#
#                                                study_title  \
# index
# 0        Genome-scale perturb-seq in primary human CD4+...
# 1        Genome-scale perturb-seq in primary human CD4+...
# 2        Genome-scale perturb-seq in primary human CD4+...
# 3        Genome-scale perturb-seq in primary human CD4+...
# 4        Genome-scale perturb-seq in primary human CD4+...
# ...                                                    ...
# 2548388  Genome-scale perturb-seq in primary human CD4+...
# 2548389  Genome-scale perturb-seq in primary human CD4+...
# 2548390  Genome-scale perturb-seq in primary human CD4+...
# 2548391  Genome-scale perturb-seq in primary human CD4+...
# 2548392  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# index
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2548388  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548389  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548390  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548391  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548392  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# index
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2548388  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548389  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548390  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548391  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548392  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# index
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2548388  \n            Isolated human CD4-positive cell...
# 2548389  \n            Isolated human CD4-positive cell...
# 2548390  \n            Isolated human CD4-positive cell...
# 2548391  \n            Isolated human CD4-positive cell...
# 2548392  \n            Isolated human CD4-positive cell...
#
#          number_of_perturbed_targets  number_of_perturbed_samples  \
# index
# 0                              12101                      2548393
# 1                              12101                      2548393
# 2                              12101                      2548393
# 3                              12101                      2548393
# 4                              12101                      2548393
# ...                              ...                          ...
# 2548388                        12101                      2548393
# 2548389                        12101                      2548393
# 2548390                        12101                      2548393
# 2548391                        12101                      2548393
# 2548392                        12101                      2548393
#
#         library_generation_type_id library_generation_type_label  \
# index
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2548388                EFO:0022868                    endogenous
# 2548389                EFO:0022868                    endogenous
# 2548390                EFO:0022868                    endogenous
# 2548391                EFO:0022868                    endogenous
# 2548392                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# index
# 0                               None                 dCas9-KRAB-Zim3
# 1                               None                 dCas9-KRAB-Zim3
# 2                               None                 dCas9-KRAB-Zim3
# 3                               None                 dCas9-KRAB-Zim3
# 4                               None                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2548388                         None                 dCas9-KRAB-Zim3
# 2548389                         None                 dCas9-KRAB-Zim3
# 2548390                         None                 dCas9-KRAB-Zim3
# 2548391                         None                 dCas9-KRAB-Zim3
# 2548392                         None                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# index
# 0                            None      lentivirus transduction
# 1                            None      lentivirus transduction
# 2                            None      lentivirus transduction
# 3                            None      lentivirus transduction
# 4                            None      lentivirus transduction
# ...                           ...                          ...
# 2548388                      None      lentivirus transduction
# 2548389                      None      lentivirus transduction
# 2548390                      None      lentivirus transduction
# 2548391                      None      lentivirus transduction
# 2548392                      None      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# index
# 0                             None       lentivirus transduction
# 1                             None       lentivirus transduction
# 2                             None       lentivirus transduction
# 3                             None       lentivirus transduction
# 4                             None       lentivirus transduction
# ...                            ...                           ...
# 2548388                       None       lentivirus transduction
# 2548389                       None       lentivirus transduction
# 2548390                       None       lentivirus transduction
# 2548391                       None       lentivirus transduction
# 2548392                       None       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# index
# 0                              None       random locus integration
# 1                              None       random locus integration
# 2                              None       random locus integration
# 3                              None       random locus integration
# 4                              None       random locus integration
# ...                             ...                            ...
# 2548388                        None       random locus integration
# 2548389                        None       random locus integration
# 2548390                        None       random locus integration
# 2548391                        None       random locus integration
# 2548392                        None       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# index
# 0                               None        random locus integration
# 1                               None        random locus integration
# 2                               None        random locus integration
# 3                               None        random locus integration
# 4                               None        random locus integration
# ...                              ...                             ...
# 2548388                         None        random locus integration
# 2548389                         None        random locus integration
# 2548390                         None        random locus integration
# 2548391                         None        random locus integration
# 2548392                         None        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# index
# 0                               None  constitutive transgene expression
# 1                               None  constitutive transgene expression
# 2                               None  constitutive transgene expression
# 3                               None  constitutive transgene expression
# 4                               None  constitutive transgene expression
# ...                              ...                                ...
# 2548388                         None  constitutive transgene expression
# 2548389                         None  constitutive transgene expression
# 2548390                         None  constitutive transgene expression
# 2548391                         None  constitutive transgene expression
# 2548392                         None  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# index
# 0                                None  constitutive transgene expression
# 1                                None  constitutive transgene expression
# 2                                None  constitutive transgene expression
# 3                                None  constitutive transgene expression
# 4                                None  constitutive transgene expression
# ...                               ...                                ...
# 2548388                          None  constitutive transgene expression
# 2548389                          None  constitutive transgene expression
# 2548390                          None  constitutive transgene expression
# 2548391                          None  constitutive transgene expression
# 2548392                          None  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# index
# 0             custom        None              None               pooled
# 1             custom        None              None               pooled
# 2             custom        None              None               pooled
# 3             custom        None              None               pooled
# 4             custom        None              None               pooled
# ...              ...         ...               ...                  ...
# 2548388       custom        None              None               pooled
# 2548389       custom        None              None               pooled
# 2548390       custom        None              None               pooled
# 2548391       custom        None              None               pooled
# 2548392       custom        None              None               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# index
# 0                   None             focused                         None
# 1                   None             focused                         None
# 2                   None             focused                         None
# 3                   None             focused                         None
# 4                   None             focused                         None
# ...                  ...                 ...                          ...
# 2548388             None             focused                         None
# 2548389             None             focused                         None
# 2548390             None             focused                         None
# 2548391             None             focused                         None
# 2548392             None             focused                         None
#
#         library_perturbation_type_label library_manufacturer  \
# index
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2548388                      inhibition           Marson lab
# 2548389                      inhibition           Marson lab
# 2548390                      inhibition           Marson lab
# 2548391                      inhibition           Marson lab
# 2548392                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# index
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2548388                             2                        2
# 2548389                             2                        2
# 2548390                             2                        2
# 2548391                             2                        2
# 2548392                             2                        2
#
#         library_total_grnas library_total_variants readout_dimensionality_id  \
# index
# 0                     23255                   None                      None
# 1                     23255                   None                      None
# 2                     23255                   None                      None
# 3                     23255                   None                      None
# 4                     23255                   None                      None
# ...                     ...                    ...                       ...
# 2548388               23255                   None                      None
# 2548389               23255                   None                      None
# 2548390               23255                   None                      None
# 2548391               23255                   None                      None
# 2548392               23255                   None                      None
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# index
# 0             high-dimensional assay            None     transcriptomic
# 1             high-dimensional assay            None     transcriptomic
# 2             high-dimensional assay            None     transcriptomic
# 3             high-dimensional assay            None     transcriptomic
# 4             high-dimensional assay            None     transcriptomic
# ...                              ...             ...                ...
# 2548388       high-dimensional assay            None     transcriptomic
# 2548389       high-dimensional assay            None     transcriptomic
# 2548390       high-dimensional assay            None     transcriptomic
# 2548391       high-dimensional assay            None     transcriptomic
# 2548392       high-dimensional assay            None     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# index
# 0                        None      single-cell rna-seq           None
# 1                        None      single-cell rna-seq           None
# 2                        None      single-cell rna-seq           None
# 3                        None      single-cell rna-seq           None
# 4                        None      single-cell rna-seq           None
# ...                       ...                      ...            ...
# 2548388                  None      single-cell rna-seq           None
# 2548389                  None      single-cell rna-seq           None
# 2548390                  None      single-cell rna-seq           None
# 2548391                  None      single-cell rna-seq           None
# 2548392                  None      single-cell rna-seq           None
#
#         method_name_label method_uri sequencing_library_kit_id  \
# index
# 0             Perturb-seq       None                      None
# 1             Perturb-seq       None                      None
# 2             Perturb-seq       None                      None
# 3             Perturb-seq       None                      None
# 4             Perturb-seq       None                      None
# ...                   ...        ...                       ...
# 2548388       Perturb-seq       None                      None
# 2548389       Perturb-seq       None                      None
# 2548390       Perturb-seq       None                      None
# 2548391       Perturb-seq       None                      None
# 2548392       Perturb-seq       None                      None
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# index
# 0        GEM-X Flex Gene Expression Human n-plex kit                   None
# 1        GEM-X Flex Gene Expression Human n-plex kit                   None
# 2        GEM-X Flex Gene Expression Human n-plex kit                   None
# 3        GEM-X Flex Gene Expression Human n-plex kit                   None
# 4        GEM-X Flex Gene Expression Human n-plex kit                   None
# ...                                              ...                    ...
# 2548388  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2548389  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2548390  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2548391  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2548392  GEM-X Flex Gene Expression Human n-plex kit                   None
#
#         sequencing_platform_label sequencing_strategy_id  \
# index
# 0           Ultima Genomics UG100                   None
# 1           Ultima Genomics UG100                   None
# 2           Ultima Genomics UG100                   None
# 3           Ultima Genomics UG100                   None
# 4           Ultima Genomics UG100                   None
# ...                           ...                    ...
# 2548388     Ultima Genomics UG100                   None
# 2548389     Ultima Genomics UG100                   None
# 2548390     Ultima Genomics UG100                   None
# 2548391     Ultima Genomics UG100                   None
# 2548392     Ultima Genomics UG100                   None
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# index
# 0              barcode sequencing               None            CellRanger
# 1              barcode sequencing               None            CellRanger
# 2              barcode sequencing               None            CellRanger
# 3              barcode sequencing               None            CellRanger
# 4              barcode sequencing               None            CellRanger
# ...                           ...                ...                   ...
# 2548388        barcode sequencing               None            CellRanger
# 2548389        barcode sequencing               None            CellRanger
# 2548390        barcode sequencing               None            CellRanger
# 2548391        barcode sequencing               None            CellRanger
# 2548392        barcode sequencing               None            CellRanger
#
#         software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                       None                  scanpy                None
# 1                       None                  scanpy                None
# 2                       None                  scanpy                None
# 3                       None                  scanpy                None
# 4                       None                  scanpy                None
# ...                      ...                     ...                 ...
# 2548388                 None                  scanpy                None
# 2548389                 None                  scanpy                None
# 2548390                 None                  scanpy                None
# 2548391                 None                  scanpy                None
# 2548392                 None                  scanpy                None
#
#         reference_genome_label license_label   license_id  \
# index
# 0                       GRCh38   MIT License  SWO:9000074
# 1                       GRCh38   MIT License  SWO:9000074
# 2                       GRCh38   MIT License  SWO:9000074
# 3                       GRCh38   MIT License  SWO:9000074
# 4                       GRCh38   MIT License  SWO:9000074
# ...                        ...           ...          ...
# 2548388                 GRCh38   MIT License  SWO:9000074
# 2548389                 GRCh38   MIT License  SWO:9000074
# 2548390                 GRCh38   MIT License  SWO:9000074
# 2548391                 GRCh38   MIT License  SWO:9000074
# 2548392                 GRCh38   MIT License  SWO:9000074
#
#                                        associated_datasets
# index
# 0        [{"dataset_accession": "Primary Human CD4+ T C...
# 1        [{"dataset_accession": "Primary Human CD4+ T C...
# 2        [{"dataset_accession": "Primary Human CD4+ T C...
# 3        [{"dataset_accession": "Primary Human CD4+ T C...
# 4        [{"dataset_accession": "Primary Human CD4+ T C...
# ...                                                    ...
# 2548388  [{"dataset_accession": "Primary Human CD4+ T C...
# 2548389  [{"dataset_accession": "Primary Human CD4+ T C...
# 2548390  [{"dataset_accession": "Primary Human CD4+ T C...
# 2548391  [{"dataset_accession": "Primary Human CD4+ T C...
# 2548392  [{"dataset_accession": "Primary Human CD4+ T C...
#
# [2548393 rows x 110 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#       input_column input_column_lower       name_lower     ontology_id
# 0  lymphoid tissue    lymphoid tissue  lymphoid tissue  UBERON:0001744
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                       input_column               input_column_lower  \
# 0  CD4-positive, alpha-beta T cell  cd4-positive, alpha-beta t cell
#
#                         name_lower ontology_id
# 0  cd4-positive, alpha-beta t cell  CL:0000624
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Warning: No disease ontology terms could be mapped from `disease_label` column to ontology terms. Map the terms manually or check the input column for errors.

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-02-12 13:17:41,180 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
#                   dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D1_rest_cl         1   Perturb-seq        <NA>
# 1        zhu_2025_D1_rest_cl         2   Perturb-seq        <NA>
# 2        zhu_2025_D1_rest_cl         3   Perturb-seq        <NA>
# 3        zhu_2025_D1_rest_cl         4   Perturb-seq        <NA>
# 4        zhu_2025_D1_rest_cl         5   Perturb-seq        <NA>
# ...                      ...       ...           ...         ...
# 2548388  zhu_2025_D1_rest_cl   2548389   Perturb-seq        <NA>
# 2548389  zhu_2025_D1_rest_cl   2548390   Perturb-seq        <NA>
# 2548390  zhu_2025_D1_rest_cl   2548391   Perturb-seq        <NA>
# 2548391  zhu_2025_D1_rest_cl   2548392   Perturb-seq        <NA>
# 2548392  zhu_2025_D1_rest_cl   2548393   Perturb-seq        <NA>
#
#         significance_criteria                      perturbation_name  \
# 0                        <NA>  AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08
# 1                        <NA>  AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08
# 2                        <NA>  AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08
# 3                        <NA>  AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08
# 4                        <NA>  AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08
# ...                       ...                                    ...
# 2548388                  <NA>  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21
# 2548389                  <NA>  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21
# 2548390                  <NA>  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21
# 2548391                  <NA>  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21
# 2548392                  <NA>  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21
#
#              perturbed_target_coord perturbed_target_chromosome  \
# 0                   control_casonly             control_casonly
# 1              control_nontargeting        control_nontargeting
# 2        chr16:14672548-14694308;-1                          16
# 3        chr17:44191805-44200961;-1                          17
# 4         chr1:92508696-92792416;-1                           1
# ...                             ...                         ...
# 2548388             control_casonly             control_casonly
# 2548389             control_casonly             control_casonly
# 2548390             control_casonly             control_casonly
# 2548391  chr11:28020618-28108183;-1                          11
# 2548392  chr19:12345944-12365905;-1                          19
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           0                        1
# 1                                           0                        1
# 2                                          16                        1
# 3                                          17                        1
# 4                                           1                        1
# ...                                       ...                      ...
# 2548388                                     0                        1
# 2548389                                     0                        1
# 2548390                                     0                        1
# 2548391                                    11                        1
# 2548392                                    19                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0                        <NA>         control_casonly
# 1        control_nontargeting    control_nontargeting
# 2             ENSG00000069764                 PLA2G10
# 3             ENSG00000087152                 ATXN7L3
# 4             ENSG00000067208                    EVI5
# ...                       ...                     ...
# 2548388                  <NA>         control_casonly
# 2548389                  <NA>         control_casonly
# 2548390                  <NA>         control_casonly
# 2548391       ENSG00000121621                  KIF18A
# 2548392       ENSG00000198342                  ZNF442
#
#         perturbed_target_biotype        guide_sequence  \
# 0                control_casonly                  <NA>
# 1           control_nontargeting  TGGGAATTCCTCGGCCGATT
# 2                 protein_coding  GGGTGCTGCAGGGCCACCGG
# 3                 protein_coding  GAGCGCGTGCATCTGCCCCG
# 4                 protein_coding  GGAGGAACCAGCTGGCCAGC
# ...                          ...                   ...
# 2548388          control_casonly                  <NA>
# 2548389          control_casonly                  <NA>
# 2548390          control_casonly                  <NA>
# 2548391           protein_coding  AGGCGGACATTAAAGTGAAG
# 2548392           protein_coding  GCTGGCAGCGGGGAACCTTG
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                 <NA>  P12DT8H0M0S
# 1                       CRISPRi                 <NA>  P12DT8H0M0S
# 2                       CRISPRi                 <NA>  P12DT8H0M0S
# 3                       CRISPRi                 <NA>  P12DT8H0M0S
# 4                       CRISPRi                 <NA>  P12DT8H0M0S
# ...                         ...                  ...          ...
# 2548388                 CRISPRi                 <NA>  P12DT8H0M0S
# 2548389                 CRISPRi                 <NA>  P12DT8H0M0S
# 2548390                 CRISPRi                 <NA>  P12DT8H0M0S
# 2548391                 CRISPRi                 <NA>  P12DT8H0M0S
# 2548392                 CRISPRi                 <NA>  P12DT8H0M0S
#
#            treatment_label  treatment_id technical_replicate  \
# 0        untreated control  NCIT:C184729          CD4i_R1L08
# 1        untreated control  NCIT:C184729          CD4i_R1L08
# 2        untreated control  NCIT:C184729          CD4i_R1L08
# 3        untreated control  NCIT:C184729          CD4i_R1L08
# 4        untreated control  NCIT:C184729          CD4i_R1L08
# ...                    ...           ...                 ...
# 2548388  untreated control  NCIT:C184729          CD4i_R1L21
# 2548389  untreated control  NCIT:C184729          CD4i_R1L21
# 2548390  untreated control  NCIT:C184729          CD4i_R1L21
# 2548391  untreated control  NCIT:C184729          CD4i_R1L21
# 2548392  untreated control  NCIT:C184729          CD4i_R1L21
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 1               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 3               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 4               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# ...                      ...                ...             ...           ...
# 2548388         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2548389         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2548390         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2548391         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2548392         D1_CE0008162       primary_cell            <NA>  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2548388  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548389  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548390  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548391  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548392  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624            <NA>         <NA>    female   <NA>
# 1         CL:0000624            <NA>         <NA>    female   <NA>
# 2         CL:0000624            <NA>         <NA>    female   <NA>
# 3         CL:0000624            <NA>         <NA>    female   <NA>
# 4         CL:0000624            <NA>         <NA>    female   <NA>
# ...              ...             ...          ...       ...    ...
# 2548388   CL:0000624            <NA>         <NA>    female   <NA>
# 2548389   CL:0000624            <NA>         <NA>    female   <NA>
# 2548390   CL:0000624            <NA>         <NA>    female   <NA>
# 2548391   CL:0000624            <NA>         <NA>    female   <NA>
# 2548392   CL:0000624            <NA>         <NA>    female   <NA>
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                   <NA>       healthy
# 1                           adult                   <NA>       healthy
# 2                           adult                   <NA>       healthy
# 3                           adult                   <NA>       healthy
# 4                           adult                   <NA>       healthy
# ...                           ...                    ...           ...
# 2548388                     adult                   <NA>       healthy
# 2548389                     adult                   <NA>       healthy
# 2548390                     adult                   <NA>       healthy
# 2548391                     adult                   <NA>       healthy
# 2548392                     adult                   <NA>       healthy
#
#         disease_id                                        study_title  \
# 0             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 1             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 3             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 4             <NA>  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2548388       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2548389       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2548390       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2548391       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2548392       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2548388  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548389  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548390  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548391  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548392  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2548388  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548389  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548390  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548391  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548392  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2548388  \n            Isolated human CD4-positive cell...
# 2548389  \n            Isolated human CD4-positive cell...
# 2548390  \n            Isolated human CD4-positive cell...
# 2548391  \n            Isolated human CD4-positive cell...
# 2548392  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             12101                     2548393
# 1                             12101                     2548393
# 2                             12101                     2548393
# 3                             12101                     2548393
# 4                             12101                     2548393
# ...                             ...                         ...
# 2548388                       12101                     2548393
# 2548389                       12101                     2548393
# 2548390                       12101                     2548393
# 2548391                       12101                     2548393
# 2548392                       12101                     2548393
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2548388                EFO:0022868                    endogenous
# 2548389                EFO:0022868                    endogenous
# 2548390                EFO:0022868                    endogenous
# 2548391                EFO:0022868                    endogenous
# 2548392                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                               <NA>                 dCas9-KRAB-Zim3
# 1                               <NA>                 dCas9-KRAB-Zim3
# 2                               <NA>                 dCas9-KRAB-Zim3
# 3                               <NA>                 dCas9-KRAB-Zim3
# 4                               <NA>                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2548388                         <NA>                 dCas9-KRAB-Zim3
# 2548389                         <NA>                 dCas9-KRAB-Zim3
# 2548390                         <NA>                 dCas9-KRAB-Zim3
# 2548391                         <NA>                 dCas9-KRAB-Zim3
# 2548392                         <NA>                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                            <NA>      lentivirus transduction
# 1                            <NA>      lentivirus transduction
# 2                            <NA>      lentivirus transduction
# 3                            <NA>      lentivirus transduction
# 4                            <NA>      lentivirus transduction
# ...                           ...                          ...
# 2548388                      <NA>      lentivirus transduction
# 2548389                      <NA>      lentivirus transduction
# 2548390                      <NA>      lentivirus transduction
# 2548391                      <NA>      lentivirus transduction
# 2548392                      <NA>      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                             <NA>       lentivirus transduction
# 1                             <NA>       lentivirus transduction
# 2                             <NA>       lentivirus transduction
# 3                             <NA>       lentivirus transduction
# 4                             <NA>       lentivirus transduction
# ...                            ...                           ...
# 2548388                       <NA>       lentivirus transduction
# 2548389                       <NA>       lentivirus transduction
# 2548390                       <NA>       lentivirus transduction
# 2548391                       <NA>       lentivirus transduction
# 2548392                       <NA>       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                              <NA>       random locus integration
# 1                              <NA>       random locus integration
# 2                              <NA>       random locus integration
# 3                              <NA>       random locus integration
# 4                              <NA>       random locus integration
# ...                             ...                            ...
# 2548388                        <NA>       random locus integration
# 2548389                        <NA>       random locus integration
# 2548390                        <NA>       random locus integration
# 2548391                        <NA>       random locus integration
# 2548392                        <NA>       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                               <NA>        random locus integration
# 1                               <NA>        random locus integration
# 2                               <NA>        random locus integration
# 3                               <NA>        random locus integration
# 4                               <NA>        random locus integration
# ...                              ...                             ...
# 2548388                         <NA>        random locus integration
# 2548389                         <NA>        random locus integration
# 2548390                         <NA>        random locus integration
# 2548391                         <NA>        random locus integration
# 2548392                         <NA>        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                               <NA>  constitutive transgene expression
# 1                               <NA>  constitutive transgene expression
# 2                               <NA>  constitutive transgene expression
# 3                               <NA>  constitutive transgene expression
# 4                               <NA>  constitutive transgene expression
# ...                              ...                                ...
# 2548388                         <NA>  constitutive transgene expression
# 2548389                         <NA>  constitutive transgene expression
# 2548390                         <NA>  constitutive transgene expression
# 2548391                         <NA>  constitutive transgene expression
# 2548392                         <NA>  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                <NA>  constitutive transgene expression
# 1                                <NA>  constitutive transgene expression
# 2                                <NA>  constitutive transgene expression
# 3                                <NA>  constitutive transgene expression
# 4                                <NA>  constitutive transgene expression
# ...                               ...                                ...
# 2548388                          <NA>  constitutive transgene expression
# 2548389                          <NA>  constitutive transgene expression
# 2548390                          <NA>  constitutive transgene expression
# 2548391                          <NA>  constitutive transgene expression
# 2548392                          <NA>  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom        <NA>              <NA>               pooled
# 1             custom        <NA>              <NA>               pooled
# 2             custom        <NA>              <NA>               pooled
# 3             custom        <NA>              <NA>               pooled
# 4             custom        <NA>              <NA>               pooled
# ...              ...         ...               ...                  ...
# 2548388       custom        <NA>              <NA>               pooled
# 2548389       custom        <NA>              <NA>               pooled
# 2548390       custom        <NA>              <NA>               pooled
# 2548391       custom        <NA>              <NA>               pooled
# 2548392       custom        <NA>              <NA>               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                   <NA>             focused                         <NA>
# 1                   <NA>             focused                         <NA>
# 2                   <NA>             focused                         <NA>
# 3                   <NA>             focused                         <NA>
# 4                   <NA>             focused                         <NA>
# ...                  ...                 ...                          ...
# 2548388             <NA>             focused                         <NA>
# 2548389             <NA>             focused                         <NA>
# 2548390             <NA>             focused                         <NA>
# 2548391             <NA>             focused                         <NA>
# 2548392             <NA>             focused                         <NA>
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2548388                      inhibition           Marson lab
# 2548389                      inhibition           Marson lab
# 2548390                      inhibition           Marson lab
# 2548391                      inhibition           Marson lab
# 2548392                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2548388                             2                        2
# 2548389                             2                        2
# 2548390                             2                        2
# 2548391                             2                        2
# 2548392                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     23255                    <NA>                      <NA>
# 1                     23255                    <NA>                      <NA>
# 2                     23255                    <NA>                      <NA>
# 3                     23255                    <NA>                      <NA>
# 4                     23255                    <NA>                      <NA>
# ...                     ...                     ...                       ...
# 2548388               23255                    <NA>                      <NA>
# 2548389               23255                    <NA>                      <NA>
# 2548390               23255                    <NA>                      <NA>
# 2548391               23255                    <NA>                      <NA>
# 2548392               23255                    <NA>                      <NA>
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay            <NA>     transcriptomic
# 1             high-dimensional assay            <NA>     transcriptomic
# 2             high-dimensional assay            <NA>     transcriptomic
# 3             high-dimensional assay            <NA>     transcriptomic
# 4             high-dimensional assay            <NA>     transcriptomic
# ...                              ...             ...                ...
# 2548388       high-dimensional assay            <NA>     transcriptomic
# 2548389       high-dimensional assay            <NA>     transcriptomic
# 2548390       high-dimensional assay            <NA>     transcriptomic
# 2548391       high-dimensional assay            <NA>     transcriptomic
# 2548392       high-dimensional assay            <NA>     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                        <NA>      single-cell rna-seq           <NA>
# 1                        <NA>      single-cell rna-seq           <NA>
# 2                        <NA>      single-cell rna-seq           <NA>
# 3                        <NA>      single-cell rna-seq           <NA>
# 4                        <NA>      single-cell rna-seq           <NA>
# ...                       ...                      ...            ...
# 2548388                  <NA>      single-cell rna-seq           <NA>
# 2548389                  <NA>      single-cell rna-seq           <NA>
# 2548390                  <NA>      single-cell rna-seq           <NA>
# 2548391                  <NA>      single-cell rna-seq           <NA>
# 2548392                  <NA>      single-cell rna-seq           <NA>
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq       <NA>                      <NA>
# 1             Perturb-seq       <NA>                      <NA>
# 2             Perturb-seq       <NA>                      <NA>
# 3             Perturb-seq       <NA>                      <NA>
# 4             Perturb-seq       <NA>                      <NA>
# ...                   ...        ...                       ...
# 2548388       Perturb-seq       <NA>                      <NA>
# 2548389       Perturb-seq       <NA>                      <NA>
# 2548390       Perturb-seq       <NA>                      <NA>
# 2548391       Perturb-seq       <NA>                      <NA>
# 2548392       Perturb-seq       <NA>                      <NA>
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 1        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 3        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 4        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# ...                                              ...                    ...
# 2548388  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2548389  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2548390  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2548391  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2548392  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                   <NA>
# 1           Ultima Genomics UG100                   <NA>
# 2           Ultima Genomics UG100                   <NA>
# 3           Ultima Genomics UG100                   <NA>
# 4           Ultima Genomics UG100                   <NA>
# ...                           ...                    ...
# 2548388     Ultima Genomics UG100                   <NA>
# 2548389     Ultima Genomics UG100                   <NA>
# 2548390     Ultima Genomics UG100                   <NA>
# 2548391     Ultima Genomics UG100                   <NA>
# 2548392     Ultima Genomics UG100                   <NA>
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing               <NA>            CellRanger
# 1              barcode sequencing               <NA>            CellRanger
# 2              barcode sequencing               <NA>            CellRanger
# 3              barcode sequencing               <NA>            CellRanger
# 4              barcode sequencing               <NA>            CellRanger
# ...                           ...                ...                   ...
# 2548388        barcode sequencing               <NA>            CellRanger
# 2548389        barcode sequencing               <NA>            CellRanger
# 2548390        barcode sequencing               <NA>            CellRanger
# 2548391        barcode sequencing               <NA>            CellRanger
# 2548392        barcode sequencing               <NA>            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                       <NA>                  scanpy                 <NA>
# 1                       <NA>                  scanpy                 <NA>
# 2                       <NA>                  scanpy                 <NA>
# 3                       <NA>                  scanpy                 <NA>
# 4                       <NA>                  scanpy                 <NA>
# ...                      ...                     ...                  ...
# 2548388                 <NA>                  scanpy                 <NA>
# 2548389                 <NA>                  scanpy                 <NA>
# 2548390                 <NA>                  scanpy                 <NA>
# 2548391                 <NA>                  scanpy                 <NA>
# 2548392                 <NA>                  scanpy                 <NA>
#
#         reference_genome_id reference_genome_label  \
# 0                      <NA>                 GRCh38
# 1                      <NA>                 GRCh38
# 2                      <NA>                 GRCh38
# 3                      <NA>                 GRCh38
# 4                      <NA>                 GRCh38
# ...                     ...                    ...
# 2548388                <NA>                 GRCh38
# 2548389                <NA>                 GRCh38
# 2548390                <NA>                 GRCh38
# 2548391                <NA>                 GRCh38
# 2548392                <NA>                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2548388  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548389  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548390  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548391  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548392  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2548388  SWO:9000074
# 2548389  SWO:9000074
# 2548390  SWO:9000074
# 2548391  SWO:9000074
# 2548392  SWO:9000074
#
# [2548393 rows x 99 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.adata.var
# Out:
#          feature_types     mt  genome         gene_ids gene_name  \
# index
# 0      Gene Expression  False  GRCh38  ENSG00000000003    TSPAN6
# 1      Gene Expression  False  GRCh38  ENSG00000000005      TNMD
# 2      Gene Expression  False  GRCh38  ENSG00000000419      DPM1
# 3      Gene Expression  False  GRCh38  ENSG00000000457     SCYL3
# 4      Gene Expression  False  GRCh38  ENSG00000000460  C1orf112
# ...                ...    ...     ...              ...       ...
# 18125  Gene Expression  False  GRCh38  ENSG00000291122  CASTOR3P
# 18126  Gene Expression  False  GRCh38  ENSG00000291135   FCGR1BP
# 18127  Gene Expression  False  GRCh38  ENSG00000291145   PPP5D1P
# 18128  Gene Expression  False  GRCh38  ENSG00000291237      SOD2
# 18129  Gene Expression  False  GRCh38  CUSTOM001_PuroR     PuroR
#
#        ensembl_gene_id gene_symbol   original_index
# index
# 0      ENSG00000000003      TSPAN6  ENSG00000000003
# 1      ENSG00000000005        TNMD  ENSG00000000005
# 2      ENSG00000000419        DPM1  ENSG00000000419
# 3      ENSG00000000457       SCYL3  ENSG00000000457
# 4      ENSG00000000460       FIRRM  ENSG00000000460
# ...                ...         ...              ...
# 18125  ENSG00000291122    CASTOR3P  ENSG00000291122
# 18126  ENSG00000291135     FCGR1BP  ENSG00000291135
# 18127  ENSG00000291145     PPP5D1P  ENSG00000291145
# 18128  ENSG00000291237        SOD2  ENSG00000291237
# 18129              NaN       PuroR  CUSTOM001_PuroR
#
# [18130 rows x 8 columns]

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ids",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# Missing Ensembl IDs: ['ENSG00000148362', 'ENSG00000139656', 'CUSTOM001_PuroR']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000148362': 'ENSG00000310560', 'ENSG00000139656': 'ENSG00000226519'}
# --------------------------------------------------
# Successfully mapped 18130 out of 18130 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# replace gene symbols that are NOT ENSG with original provided gene symbol
cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_symbol'] = cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_name']

# %%
cur_data.adata.var.loc[cur_data.adata.var['ensembl_gene_id'] == 'CUSTOM001_PuroR', 'ensembl_gene_id'] = None

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-02-12 13:24:29,161 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
#        ensembl_gene_id gene_symbol
# index
# 0      ENSG00000000003      TSPAN6
# 1      ENSG00000000005        TNMD
# 2      ENSG00000000419        DPM1
# 3      ENSG00000000457       SCYL3
# 4      ENSG00000000460       FIRRM
# ...                ...         ...
# 18125  ENSG00000291122    CASTOR3P
# 18126  ENSG00000291135     FCGR1BP
# 18127  ENSG00000291145     PPP5D1P
# 18128  ENSG00000291237        SOD2
# 18129              NaN       PuroR
#
# [18130 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
# Use 'object' to force standard Python strings (NumPy compatible)
cur_data.adata.obs.index = cur_data.adata.obs.index.astype("object")

# It is safer to do the same for the var index just in case
cur_data.adata.var.index = cur_data.adata.var.index.astype("object")

# %%
import pandas as pd
import numpy as np

def convert_arrow_to_object(df):
    """
    Recursively converts all Arrow-backed string columns and categories 
    in a DataFrame to standard Python objects (numpy-compatible).
    """
    # 1. Fix Index
    if "arrow" in str(df.index.dtype).lower() or isinstance(df.index.dtype, pd.StringDtype):
        df.index = df.index.astype("object")
        
    for col in df.columns:
        col_dtype = df[col].dtype
        
        # 2. Fix Categorical Columns
        if isinstance(col_dtype, pd.CategoricalDtype):
            if "arrow" in str(col_dtype.categories.dtype).lower() or \
               isinstance(col_dtype.categories.dtype, pd.StringDtype):
                # Convert categories to object
                new_categories = df[col].cat.categories.astype("object")
                df[col] = df[col].cat.rename_categories(new_categories)
        
        # 3. Fix Standard String/Arrow Columns (e.g., sample_id)
        elif "arrow" in str(col_dtype).lower() or isinstance(col_dtype, pd.StringDtype):
            df[col] = df[col].astype("object")

# --- Apply the fix ---

print("Cleaning obs...")
convert_arrow_to_object(cur_data.adata.obs)

print("Cleaning var...")
convert_arrow_to_object(cur_data.adata.var)
# Out:
# Cleaning obs...
# Cleaning var...

# %%
import pandas as pd
import numpy as np

def clean_adata_for_saving(adata):
    # 1. Fix Index
    adata.obs.index = adata.obs.index.astype("object")
    adata.var.index = adata.var.index.astype("object")
    
    for df in [adata.obs, adata.var]:
        for col in df.columns:
            # --- Fix 1: Convert Arrow/StringDtype to Object ---
            if "arrow" in str(df[col].dtype).lower() or isinstance(df[col].dtype, pd.StringDtype):
                df[col] = df[col].astype("object")
            
            # --- Fix 2: Handle Object columns with NaNs ---
            # If a column is object type and has NaNs, it will break h5py.
            # We convert these to 'category', which handles NaNs gracefully.
            if df[col].dtype == "object":
                if df[col].isnull().any():
                    print(f"Converting mixed-type column '{col}' to categorical...")
                    df[col] = df[col].astype("category")

            # --- Fix 3: Ensure Categories are Standard Objects ---
            # If we created a categorical, ensure its internal list of categories is not Arrow
            if isinstance(df[col].dtype, pd.CategoricalDtype):
                if df[col].cat.categories.dtype != "object":
                    new_cats = df[col].cat.categories.astype("object")
                    df[col] = df[col].cat.rename_categories(new_cats)

# Apply the comprehensive fix
clean_adata_for_saving(cur_data.adata)
# Out:
# Converting mixed-type column 'significant' to categorical...

# %%
cur_data.adata.obs['dataset_id'].dtype
# Out:
# CategoricalDtype(categories=['zhu_2025_D1_rest_cl'], ordered=False, categories_dtype=object)

# %%
cur_data.adata.obs['significant'].dtype
# Out:
# CategoricalDtype(categories=[], ordered=False, categories_dtype=object)

# %%
cur_data.adata.obs['significant']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 2548388    NaN
# 2548389    NaN
# 2548390    NaN
# 2548391    NaN
# 2548392    NaN
# Name: significant, Length: 2548393, dtype: category
# Categories (0, object): []

# %%
cur_data.adata.obs
# Out:
#                   dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D1_rest_cl         1   Perturb-seq         NaN
# 1        zhu_2025_D1_rest_cl         2   Perturb-seq         NaN
# 2        zhu_2025_D1_rest_cl         3   Perturb-seq         NaN
# 3        zhu_2025_D1_rest_cl         4   Perturb-seq         NaN
# 4        zhu_2025_D1_rest_cl         5   Perturb-seq         NaN
# ...                      ...       ...           ...         ...
# 2548388  zhu_2025_D1_rest_cl   2548389   Perturb-seq         NaN
# 2548389  zhu_2025_D1_rest_cl   2548390   Perturb-seq         NaN
# 2548390  zhu_2025_D1_rest_cl   2548391   Perturb-seq         NaN
# 2548391  zhu_2025_D1_rest_cl   2548392   Perturb-seq         NaN
# 2548392  zhu_2025_D1_rest_cl   2548393   Perturb-seq         NaN
#
#         significance_criteria                      perturbation_name  \
# 0                         NaN  AAACAAGCAAACCGGTATGTTGAC-1_CD4i_R1L08
# 1                         NaN  AAACAAGCAAATACCGATGTTGAC-1_CD4i_R1L08
# 2                         NaN  AAACAAGCAAATCACGATGTTGAC-1_CD4i_R1L08
# 3                         NaN  AAACAAGCAACAAAGAAACGGGAA-1_CD4i_R1L08
# 4                         NaN  AAACAAGCAACAAAGAACTTTAGG-1_CD4i_R1L08
# ...                       ...                                    ...
# 2548388                   NaN  TTTGTGAGTTGTGACTAACGGGAA-1_CD4i_R1L21
# 2548389                   NaN  TTTGTGAGTTGTGACTATGTTGAC-1_CD4i_R1L21
# 2548390                   NaN  TTTGTGAGTTTAACCAAGTAGGCT-1_CD4i_R1L21
# 2548391                   NaN  TTTGTGAGTTTCGCCTACTTTAGG-1_CD4i_R1L21
# 2548392                   NaN  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R1L21
#
#              perturbed_target_coord perturbed_target_chromosome  \
# 0                   control_casonly             control_casonly
# 1              control_nontargeting        control_nontargeting
# 2        chr16:14672548-14694308;-1                          16
# 3        chr17:44191805-44200961;-1                          17
# 4         chr1:92508696-92792416;-1                           1
# ...                             ...                         ...
# 2548388             control_casonly             control_casonly
# 2548389             control_casonly             control_casonly
# 2548390             control_casonly             control_casonly
# 2548391  chr11:28020618-28108183;-1                          11
# 2548392  chr19:12345944-12365905;-1                          19
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           0                        1
# 1                                           0                        1
# 2                                          16                        1
# 3                                          17                        1
# 4                                           1                        1
# ...                                       ...                      ...
# 2548388                                     0                        1
# 2548389                                     0                        1
# 2548390                                     0                        1
# 2548391                                    11                        1
# 2548392                                    19                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0                         NaN         control_casonly
# 1        control_nontargeting    control_nontargeting
# 2             ENSG00000069764                 PLA2G10
# 3             ENSG00000087152                 ATXN7L3
# 4             ENSG00000067208                    EVI5
# ...                       ...                     ...
# 2548388                   NaN         control_casonly
# 2548389                   NaN         control_casonly
# 2548390                   NaN         control_casonly
# 2548391       ENSG00000121621                  KIF18A
# 2548392       ENSG00000198342                  ZNF442
#
#         perturbed_target_biotype        guide_sequence  \
# 0                control_casonly                   NaN
# 1           control_nontargeting  TGGGAATTCCTCGGCCGATT
# 2                 protein_coding  GGGTGCTGCAGGGCCACCGG
# 3                 protein_coding  GAGCGCGTGCATCTGCCCCG
# 4                 protein_coding  GGAGGAACCAGCTGGCCAGC
# ...                          ...                   ...
# 2548388          control_casonly                   NaN
# 2548389          control_casonly                   NaN
# 2548390          control_casonly                   NaN
# 2548391           protein_coding  AGGCGGACATTAAAGTGAAG
# 2548392           protein_coding  GCTGGCAGCGGGGAACCTTG
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                  NaN  P12DT8H0M0S
# 1                       CRISPRi                  NaN  P12DT8H0M0S
# 2                       CRISPRi                  NaN  P12DT8H0M0S
# 3                       CRISPRi                  NaN  P12DT8H0M0S
# 4                       CRISPRi                  NaN  P12DT8H0M0S
# ...                         ...                  ...          ...
# 2548388                 CRISPRi                  NaN  P12DT8H0M0S
# 2548389                 CRISPRi                  NaN  P12DT8H0M0S
# 2548390                 CRISPRi                  NaN  P12DT8H0M0S
# 2548391                 CRISPRi                  NaN  P12DT8H0M0S
# 2548392                 CRISPRi                  NaN  P12DT8H0M0S
#
#            treatment_label  treatment_id technical_replicate  \
# 0        untreated control  NCIT:C184729          CD4i_R1L08
# 1        untreated control  NCIT:C184729          CD4i_R1L08
# 2        untreated control  NCIT:C184729          CD4i_R1L08
# 3        untreated control  NCIT:C184729          CD4i_R1L08
# 4        untreated control  NCIT:C184729          CD4i_R1L08
# ...                    ...           ...                 ...
# 2548388  untreated control  NCIT:C184729          CD4i_R1L21
# 2548389  untreated control  NCIT:C184729          CD4i_R1L21
# 2548390  untreated control  NCIT:C184729          CD4i_R1L21
# 2548391  untreated control  NCIT:C184729          CD4i_R1L21
# 2548392  untreated control  NCIT:C184729          CD4i_R1L21
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 1               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 3               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 4               D1_CE0008162       primary_cell             NaN  Homo sapiens
# ...                      ...                ...             ...           ...
# 2548388         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2548389         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2548390         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2548391         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2548392         D1_CE0008162       primary_cell             NaN  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2548388  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548389  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548390  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548391  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2548392  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624             NaN          NaN    female    NaN
# 1         CL:0000624             NaN          NaN    female    NaN
# 2         CL:0000624             NaN          NaN    female    NaN
# 3         CL:0000624             NaN          NaN    female    NaN
# 4         CL:0000624             NaN          NaN    female    NaN
# ...              ...             ...          ...       ...    ...
# 2548388   CL:0000624             NaN          NaN    female    NaN
# 2548389   CL:0000624             NaN          NaN    female    NaN
# 2548390   CL:0000624             NaN          NaN    female    NaN
# 2548391   CL:0000624             NaN          NaN    female    NaN
# 2548392   CL:0000624             NaN          NaN    female    NaN
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                    NaN       healthy
# 1                           adult                    NaN       healthy
# 2                           adult                    NaN       healthy
# 3                           adult                    NaN       healthy
# 4                           adult                    NaN       healthy
# ...                           ...                    ...           ...
# 2548388                     adult                    NaN       healthy
# 2548389                     adult                    NaN       healthy
# 2548390                     adult                    NaN       healthy
# 2548391                     adult                    NaN       healthy
# 2548392                     adult                    NaN       healthy
#
#         disease_id                                        study_title  \
# 0              NaN  Genome-scale perturb-seq in primary human CD4+...
# 1              NaN  Genome-scale perturb-seq in primary human CD4+...
# 2              NaN  Genome-scale perturb-seq in primary human CD4+...
# 3              NaN  Genome-scale perturb-seq in primary human CD4+...
# 4              NaN  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2548388        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2548389        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2548390        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2548391        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2548392        NaN  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2548388  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548389  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548390  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548391  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2548392  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2548388  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548389  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548390  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548391  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2548392  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2548388  \n            Isolated human CD4-positive cell...
# 2548389  \n            Isolated human CD4-positive cell...
# 2548390  \n            Isolated human CD4-positive cell...
# 2548391  \n            Isolated human CD4-positive cell...
# 2548392  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             12101                     2548393
# 1                             12101                     2548393
# 2                             12101                     2548393
# 3                             12101                     2548393
# 4                             12101                     2548393
# ...                             ...                         ...
# 2548388                       12101                     2548393
# 2548389                       12101                     2548393
# 2548390                       12101                     2548393
# 2548391                       12101                     2548393
# 2548392                       12101                     2548393
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2548388                EFO:0022868                    endogenous
# 2548389                EFO:0022868                    endogenous
# 2548390                EFO:0022868                    endogenous
# 2548391                EFO:0022868                    endogenous
# 2548392                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                                NaN                 dCas9-KRAB-Zim3
# 1                                NaN                 dCas9-KRAB-Zim3
# 2                                NaN                 dCas9-KRAB-Zim3
# 3                                NaN                 dCas9-KRAB-Zim3
# 4                                NaN                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2548388                          NaN                 dCas9-KRAB-Zim3
# 2548389                          NaN                 dCas9-KRAB-Zim3
# 2548390                          NaN                 dCas9-KRAB-Zim3
# 2548391                          NaN                 dCas9-KRAB-Zim3
# 2548392                          NaN                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                             NaN      lentivirus transduction
# 1                             NaN      lentivirus transduction
# 2                             NaN      lentivirus transduction
# 3                             NaN      lentivirus transduction
# 4                             NaN      lentivirus transduction
# ...                           ...                          ...
# 2548388                       NaN      lentivirus transduction
# 2548389                       NaN      lentivirus transduction
# 2548390                       NaN      lentivirus transduction
# 2548391                       NaN      lentivirus transduction
# 2548392                       NaN      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                              NaN       lentivirus transduction
# 1                              NaN       lentivirus transduction
# 2                              NaN       lentivirus transduction
# 3                              NaN       lentivirus transduction
# 4                              NaN       lentivirus transduction
# ...                            ...                           ...
# 2548388                        NaN       lentivirus transduction
# 2548389                        NaN       lentivirus transduction
# 2548390                        NaN       lentivirus transduction
# 2548391                        NaN       lentivirus transduction
# 2548392                        NaN       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                               NaN       random locus integration
# 1                               NaN       random locus integration
# 2                               NaN       random locus integration
# 3                               NaN       random locus integration
# 4                               NaN       random locus integration
# ...                             ...                            ...
# 2548388                         NaN       random locus integration
# 2548389                         NaN       random locus integration
# 2548390                         NaN       random locus integration
# 2548391                         NaN       random locus integration
# 2548392                         NaN       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                                NaN        random locus integration
# 1                                NaN        random locus integration
# 2                                NaN        random locus integration
# 3                                NaN        random locus integration
# 4                                NaN        random locus integration
# ...                              ...                             ...
# 2548388                          NaN        random locus integration
# 2548389                          NaN        random locus integration
# 2548390                          NaN        random locus integration
# 2548391                          NaN        random locus integration
# 2548392                          NaN        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                                NaN  constitutive transgene expression
# 1                                NaN  constitutive transgene expression
# 2                                NaN  constitutive transgene expression
# 3                                NaN  constitutive transgene expression
# 4                                NaN  constitutive transgene expression
# ...                              ...                                ...
# 2548388                          NaN  constitutive transgene expression
# 2548389                          NaN  constitutive transgene expression
# 2548390                          NaN  constitutive transgene expression
# 2548391                          NaN  constitutive transgene expression
# 2548392                          NaN  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                 NaN  constitutive transgene expression
# 1                                 NaN  constitutive transgene expression
# 2                                 NaN  constitutive transgene expression
# 3                                 NaN  constitutive transgene expression
# 4                                 NaN  constitutive transgene expression
# ...                               ...                                ...
# 2548388                           NaN  constitutive transgene expression
# 2548389                           NaN  constitutive transgene expression
# 2548390                           NaN  constitutive transgene expression
# 2548391                           NaN  constitutive transgene expression
# 2548392                           NaN  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom         NaN               NaN               pooled
# 1             custom         NaN               NaN               pooled
# 2             custom         NaN               NaN               pooled
# 3             custom         NaN               NaN               pooled
# 4             custom         NaN               NaN               pooled
# ...              ...         ...               ...                  ...
# 2548388       custom         NaN               NaN               pooled
# 2548389       custom         NaN               NaN               pooled
# 2548390       custom         NaN               NaN               pooled
# 2548391       custom         NaN               NaN               pooled
# 2548392       custom         NaN               NaN               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                    NaN             focused                          NaN
# 1                    NaN             focused                          NaN
# 2                    NaN             focused                          NaN
# 3                    NaN             focused                          NaN
# 4                    NaN             focused                          NaN
# ...                  ...                 ...                          ...
# 2548388              NaN             focused                          NaN
# 2548389              NaN             focused                          NaN
# 2548390              NaN             focused                          NaN
# 2548391              NaN             focused                          NaN
# 2548392              NaN             focused                          NaN
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2548388                      inhibition           Marson lab
# 2548389                      inhibition           Marson lab
# 2548390                      inhibition           Marson lab
# 2548391                      inhibition           Marson lab
# 2548392                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2548388                             2                        2
# 2548389                             2                        2
# 2548390                             2                        2
# 2548391                             2                        2
# 2548392                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     23255                    <NA>                       NaN
# 1                     23255                    <NA>                       NaN
# 2                     23255                    <NA>                       NaN
# 3                     23255                    <NA>                       NaN
# 4                     23255                    <NA>                       NaN
# ...                     ...                     ...                       ...
# 2548388               23255                    <NA>                       NaN
# 2548389               23255                    <NA>                       NaN
# 2548390               23255                    <NA>                       NaN
# 2548391               23255                    <NA>                       NaN
# 2548392               23255                    <NA>                       NaN
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay             NaN     transcriptomic
# 1             high-dimensional assay             NaN     transcriptomic
# 2             high-dimensional assay             NaN     transcriptomic
# 3             high-dimensional assay             NaN     transcriptomic
# 4             high-dimensional assay             NaN     transcriptomic
# ...                              ...             ...                ...
# 2548388       high-dimensional assay             NaN     transcriptomic
# 2548389       high-dimensional assay             NaN     transcriptomic
# 2548390       high-dimensional assay             NaN     transcriptomic
# 2548391       high-dimensional assay             NaN     transcriptomic
# 2548392       high-dimensional assay             NaN     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                         NaN      single-cell rna-seq            NaN
# 1                         NaN      single-cell rna-seq            NaN
# 2                         NaN      single-cell rna-seq            NaN
# 3                         NaN      single-cell rna-seq            NaN
# 4                         NaN      single-cell rna-seq            NaN
# ...                       ...                      ...            ...
# 2548388                   NaN      single-cell rna-seq            NaN
# 2548389                   NaN      single-cell rna-seq            NaN
# 2548390                   NaN      single-cell rna-seq            NaN
# 2548391                   NaN      single-cell rna-seq            NaN
# 2548392                   NaN      single-cell rna-seq            NaN
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq        NaN                       NaN
# 1             Perturb-seq        NaN                       NaN
# 2             Perturb-seq        NaN                       NaN
# 3             Perturb-seq        NaN                       NaN
# 4             Perturb-seq        NaN                       NaN
# ...                   ...        ...                       ...
# 2548388       Perturb-seq        NaN                       NaN
# 2548389       Perturb-seq        NaN                       NaN
# 2548390       Perturb-seq        NaN                       NaN
# 2548391       Perturb-seq        NaN                       NaN
# 2548392       Perturb-seq        NaN                       NaN
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 1        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 3        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 4        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# ...                                              ...                    ...
# 2548388  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2548389  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2548390  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2548391  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2548392  GEM-X Flex Gene Expression Human n-plex kit                    NaN
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                    NaN
# 1           Ultima Genomics UG100                    NaN
# 2           Ultima Genomics UG100                    NaN
# 3           Ultima Genomics UG100                    NaN
# 4           Ultima Genomics UG100                    NaN
# ...                           ...                    ...
# 2548388     Ultima Genomics UG100                    NaN
# 2548389     Ultima Genomics UG100                    NaN
# 2548390     Ultima Genomics UG100                    NaN
# 2548391     Ultima Genomics UG100                    NaN
# 2548392     Ultima Genomics UG100                    NaN
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing                NaN            CellRanger
# 1              barcode sequencing                NaN            CellRanger
# 2              barcode sequencing                NaN            CellRanger
# 3              barcode sequencing                NaN            CellRanger
# 4              barcode sequencing                NaN            CellRanger
# ...                           ...                ...                   ...
# 2548388        barcode sequencing                NaN            CellRanger
# 2548389        barcode sequencing                NaN            CellRanger
# 2548390        barcode sequencing                NaN            CellRanger
# 2548391        barcode sequencing                NaN            CellRanger
# 2548392        barcode sequencing                NaN            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                        NaN                  scanpy                  NaN
# 1                        NaN                  scanpy                  NaN
# 2                        NaN                  scanpy                  NaN
# 3                        NaN                  scanpy                  NaN
# 4                        NaN                  scanpy                  NaN
# ...                      ...                     ...                  ...
# 2548388                  NaN                  scanpy                  NaN
# 2548389                  NaN                  scanpy                  NaN
# 2548390                  NaN                  scanpy                  NaN
# 2548391                  NaN                  scanpy                  NaN
# 2548392                  NaN                  scanpy                  NaN
#
#         reference_genome_id reference_genome_label  \
# 0                       NaN                 GRCh38
# 1                       NaN                 GRCh38
# 2                       NaN                 GRCh38
# 3                       NaN                 GRCh38
# 4                       NaN                 GRCh38
# ...                     ...                    ...
# 2548388                 NaN                 GRCh38
# 2548389                 NaN                 GRCh38
# 2548390                 NaN                 GRCh38
# 2548391                 NaN                 GRCh38
# 2548392                 NaN                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2548388  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548389  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548390  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548391  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2548392  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2548388  SWO:9000074
# 2548389  SWO:9000074
# 2548390  SWO:9000074
# 2548391  SWO:9000074
# 2548392  SWO:9000074
#
# [2548393 rows x 99 columns]

# %%
cur_data.save_curated_data_h5ad()
# Out:
# ✅ Curated h5ad data saved to ../curated/h5ad/zhu_2025_D1_rest_cl_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/zhu_2025_D1_rest_cl_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
# upload_parquet_to_bq(
#     parquet_path='../curated/parquet/zhu_2025_D1_rest_cl_curated_metadata.parquet',
#     bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
#     bq_table_name='metadata',
#     key_columns=['dataset_id', 'sample_id'],
#     verbose=True
# )

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/zhu_2025_D1_rest_cl_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
# Out:
# /bin/sh: line 1: gcloud: command not found
