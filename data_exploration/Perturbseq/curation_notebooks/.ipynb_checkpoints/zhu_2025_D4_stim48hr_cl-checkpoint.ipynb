# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)
# show all columns
pd.set_option('display.max_columns', None)
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/.venv/lib/python3.12/site-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# # Download data

# %% [markdown]
# Download the data from AWS as such:
#
# `!aws s3 cp --no-sign-request s3://genome-scale-tcell-perturb-seq/marson2025_data/{name_of_the_file}.h5ad ..aa/non_curated/h5ad/{name_of_the_file}.h5ad`

# %% [markdown]
# # Initialise the dataset object

# %%
noncurated_path = '../non_curated/h5ad/zhu_2025_D4_stim48hr_cl.h5ad'
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from ../non_curated/h5ad/zhu_2025_D4_stim48hr_cl.h5ad

# %%
cur_data.adata.obs
# Out:
#                                                        lane_id  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...  CD4i_R2L41
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  CD4i_R2L41
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...  CD4i_R2L41
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  CD4i_R2L41
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...  CD4i_R2L41
# ...                                                        ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...  CD4i_R2L36
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  CD4i_R2L36
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  CD4i_R2L36
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  CD4i_R2L36
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  CD4i_R2L36
#
#                                                     n_genes_by_counts  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...               6739
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...               5907
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...               3868
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...               5914
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...               5828
# ...                                                               ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...               4647
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...               3795
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...               4135
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...               4897
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...               4801
#
#                                                     total_counts  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...       33708.0
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...       19897.0
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...        9237.0
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...       20720.0
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...       19086.0
# ...                                                          ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...       10932.0
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...        8155.0
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...       10237.0
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...       13835.0
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...       12453.0
#
#                                                     pct_counts_mt  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...       1.302361
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...       0.638287
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...       0.086608
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...       0.115830
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...       1.152677
# ...                                                           ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...       0.146359
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...       0.147149
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...       0.488424
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...       1.633538
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...       0.907412
#
#                                                     top_guide_UMI_counts  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...                1862.0
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...                 110.0
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...                  92.0
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...                 275.0
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...                   NaN
# ...                                                                  ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...                  17.0
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...                 447.0
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...                 169.0
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...                  71.0
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...                  56.0
#
#                                                       guide_id  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...    NDUFB5-1
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  SERPINB9-1
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...    ZNF33A-2
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...      LYG1-1
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...         NaN
# ...                                                        ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...    HIF1AN-1
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...    TXNRD2-2
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...    ZYG11B-1
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...   PPP2R3C-1
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...       DEK-2
#
#                                                    perturbed_gene_name  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...              NDUFB5
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...            SERPINB9
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...              ZNF33A
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...                LYG1
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...                 NaN
# ...                                                                ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...              HIF1AN
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...              TXNRD2
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...              ZYG11B
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...             PPP2R3C
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...                 DEK
#
#                                                    perturbed_gene_id  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...   ENSG00000136521
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...   ENSG00000170542
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...   ENSG00000189180
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...   ENSG00000144214
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...               NaN
# ...                                                              ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...   ENSG00000166135
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...   ENSG00000184470
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...   ENSG00000162378
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...   ENSG00000092020
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...   ENSG00000124795
#
#                                                    guide_type     PuroR  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...  targeting  3.264477
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  targeting  2.623981
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...  targeting  1.401497
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  targeting  1.628095
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...        NaN  0.908886
# ...                                                       ...       ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...  targeting  4.133083
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  targeting  2.579297
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  targeting  3.714791
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  targeting  2.988620
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  targeting  3.088817
#
#                                                                guide_group  \
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...                no sgRNA
# ...                                                                    ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...  targeting single sgRNA
#
#                                                     low_quality
# AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41_CD4i_R2_D...        False
# AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...        False
# AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41_CD4i_R2_D...        False
# AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41_CD4i_R2_D...        False
# AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41_CD4i_R2_D...        False
# ...                                                         ...
# TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36_CD4i_R2_D...        False
# TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36_CD4i_R2_D...        False
# TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36_CD4i_R2_D...        False
# TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36_CD4i_R2_D...        False
# TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36_CD4i_R2_D...        False
#
# [2815784 rows x 12 columns]

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Since for multi-guide perturbations the identities of said guides are unknown, we are filtering out these cells.

# %%
print(f"Number of cells before filtering: {cur_data.adata.n_obs}")
cur_data.adata = cur_data.adata[cur_data.adata.obs['guide_id'] != 'multi_sgRNA']
print(f"Number of cells after filtering: {cur_data.adata.n_obs}")
# Out:
# Number of cells before filtering: 2815784
# Number of cells after filtering: 2208902

# %% [markdown]
# ### Add `index` as `perturbation_name`

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]
cur_data.adata.obs['perturbation_name'] = cur_data.adata.obs['cell_barcode'] +'_'+cur_data.adata.obs['lane_id'].astype(str)
# Out:
# /tmp/ipykernel_129282/2231587657.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'perturbation_name')

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv",
    dest_path="../supplementary/zhu_2025_guide_info.csv"
)
# read in the guide RNA info csv
guide_info_df = pd.read_csv("../supplementary/zhu_2025_guide_info.csv")

guide_info_df = guide_info_df[['sgRNA', 'seq']]

guide_info_df['sgRNA'] = guide_info_df['sgRNA'].str.replace('1-Jun','JUN-1').str.replace('2-Jun','JUN-2')

guide_info_df = guide_info_df.rename(columns={'seq': 'guide_sequence', 'sgRNA':'guide_id'})

guide_info_df
# Out:
# File ../supplementary/zhu_2025_guide_info.csv already exists. Skipping download.
#         guide_id        guide_sequence
# 0        ARMC5-1  CTGCCTCGCGCAGCTCGCGG
# 1         DDB1-1  GGAGTTCGCTGCGCGCTGTT
# 2       FNDC10-1  TGCCCGCTCCCCGCGATCCC
# 3         RORC-1  TCTGTGGGGCCCTGTCCATG
# 4      SLC35F6-1  GAACAGCTGGTACTTGGTCC
# ...          ...                   ...
# 26499    NTC-988  TTTCAGGCTACGGGCGCGGG
# 26500    NTC-989  TTTCCCATGATCATTTAGTG
# 26501    NTC-990  TTTCGCCCAAGAGGCTTGGG
# 26502    NTC-991  TTTCGTGCCGATGTAACACA
# 26503    NTC-992  TTTGGGTTTATCCGCCCCCA
#
# [26504 rows x 2 columns]

# %%
print("Number of overlapping guides with cur_data:")
cur_data.adata.obs['guide_id'].isin(guide_info_df['guide_id'].to_list()).value_counts()
# Out:
# Number of overlapping guides with cur_data:
# guide_id
# True     1888192
# False     320710
# Name: count, dtype: int64

# %%
# merge cur_data.adata.obs with guide_info_df
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='guide_id', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Number of missing guide sequences: 320710

# %%
cur_data.adata.obs
# Out:
#             lane_id  n_genes_by_counts  total_counts  pct_counts_mt  \
# 0        CD4i_R2L41               6739       33708.0       1.302361
# 1        CD4i_R2L41               5907       19897.0       0.638287
# 2        CD4i_R2L41               3868        9237.0       0.086608
# 3        CD4i_R2L41               5914       20720.0       0.115830
# 4        CD4i_R2L41               5828       19086.0       1.152677
# ...             ...                ...           ...            ...
# 2208897  CD4i_R2L36               4647       10932.0       0.146359
# 2208898  CD4i_R2L36               3795        8155.0       0.147149
# 2208899  CD4i_R2L36               4135       10237.0       0.488424
# 2208900  CD4i_R2L36               4897       13835.0       1.633538
# 2208901  CD4i_R2L36               4801       12453.0       0.907412
#
#          top_guide_UMI_counts    guide_id perturbed_gene_name  \
# 0                      1862.0    NDUFB5-1              NDUFB5
# 1                       110.0  SERPINB9-1            SERPINB9
# 2                        92.0    ZNF33A-2              ZNF33A
# 3                       275.0      LYG1-1                LYG1
# 4                         NaN         NaN                 NaN
# ...                       ...         ...                 ...
# 2208897                  17.0    HIF1AN-1              HIF1AN
# 2208898                 447.0    TXNRD2-2              TXNRD2
# 2208899                 169.0    ZYG11B-1              ZYG11B
# 2208900                  71.0   PPP2R3C-1             PPP2R3C
# 2208901                  56.0       DEK-2                 DEK
#
#         perturbed_gene_id guide_type     PuroR             guide_group  \
# 0         ENSG00000136521  targeting  3.264477  targeting single sgRNA
# 1         ENSG00000170542  targeting  2.623981  targeting single sgRNA
# 2         ENSG00000189180  targeting  1.401497  targeting single sgRNA
# 3         ENSG00000144214  targeting  1.628095  targeting single sgRNA
# 4                     NaN        NaN  0.908886                no sgRNA
# ...                   ...        ...       ...                     ...
# 2208897   ENSG00000166135  targeting  4.133083  targeting single sgRNA
# 2208898   ENSG00000184470  targeting  2.579297  targeting single sgRNA
# 2208899   ENSG00000162378  targeting  3.714791  targeting single sgRNA
# 2208900   ENSG00000092020  targeting  2.988620  targeting single sgRNA
# 2208901   ENSG00000124795  targeting  3.088817  targeting single sgRNA
#
#          low_quality                cell_barcode  \
# 0              False  AAACAAGCAAACCCAAATACGTCA-1
# 1              False  AAACAAGCAACAAAGAAACGCCGA-1
# 2              False  AAACAAGCAACGTTAGATCATGTG-1
# 3              False  AAACAAGCAACTAAGTAACGCCGA-1
# 4              False  AAACAAGCAACTAAGTATACGTCA-1
# ...              ...                         ...
# 2208897        False  TTTGTGAGTTGTTGGTATTCGGTT-1
# 2208898        False  TTTGTGAGTTTACCGGATCATGTG-1
# 2208899        False  TTTGTGAGTTTACGACATACGTCA-1
# 2208900        False  TTTGTGAGTTTGCATAATACGTCA-1
# 2208901        False  TTTGTGAGTTTGCTCCATCATGTG-1
#
#                              perturbation_name        guide_sequence
# 0        AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41  GCGGCGGGTTTCGGTTACTG
# 1        AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41  TCCAGGCTCGGAGCGCGGCA
# 2        AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41  GAGGCCCGGGGACCTCATAG
# 3        AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41  GAGGCATGGATCTTACACTC
# 4        AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41                   NaN
# ...                                        ...                   ...
# 2208897  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36  AGGGCTCCAGCCTCCTCCCG
# 2208898  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36  GGGCGCTGCGGGGATTAGGA
# 2208899  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36  GCTCCTAGCTTGAGGGAAAG
# 2208900  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36  GCCCGGCCCTAAACTCCTAG
# 2208901  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36  GACGCCGAGGAGAAGGCGCG
#
# [2208902 rows x 15 columns]

# %%
# change perturbed_gene_id from categorical to string
cur_data.adata.obs['perturbed_gene_id'] = cur_data.adata.obs['perturbed_gene_id'].astype(str)
cur_data.adata.obs['perturbed_gene_name'] = cur_data.adata.obs['perturbed_gene_name'].astype(str)

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isin(['NTC']), 'perturbed_gene_id'] = 'control_nontargeting'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin(['NTC']), 'perturbed_gene_name'] = 'control_nontargeting'

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isna(), 'perturbed_gene_id'] = 'control_casonly'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isna(), 'perturbed_gene_name'] = 'control_casonly'

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_gene_id',
    input_column_type='ensembl_gene_id',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Missing Ensembl IDs: ['ENSG00000182230', 'ENSG00000277796', 'ENSG00000148362', 'SGK494', 'LUZP6', 'ENSG00000256618', 'ENSG00000232196', 'SEPT6', 'U2AF1L5', 'ENSG00000203812', 'ENSG00000255823', 'AKAP2', 'OCLM', 'SMIM11B']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000182230': nan, 'ENSG00000277796': 'ENSG00000293545', 'ENSG00000148362': 'ENSG00000310560', 'ENSG00000256618': nan, 'ENSG00000232196': nan, 'ENSG00000203812': 'ENSG00000288825', 'ENSG00000255823': nan}
# --------------------------------------------------
# Successfully mapped 12423 out of 12423 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
cur_data.adata.obs
# Out:
#                     guide_group  n_genes_by_counts guide_type  low_quality  \
# index
# 0        targeting single sgRNA               6739  targeting        False
# 1        targeting single sgRNA               5907  targeting        False
# 2        targeting single sgRNA               3868  targeting        False
# 3        targeting single sgRNA               5914  targeting        False
# 4                      no sgRNA               5828        NaN        False
# ...                         ...                ...        ...          ...
# 2208897  targeting single sgRNA               4647  targeting        False
# 2208898  targeting single sgRNA               3795  targeting        False
# 2208899  targeting single sgRNA               4135  targeting        False
# 2208900  targeting single sgRNA               4897  targeting        False
# 2208901  targeting single sgRNA               4801  targeting        False
#
#             lane_id        guide_sequence    guide_id perturbed_gene_id  \
# index
# 0        CD4i_R2L41  GCGGCGGGTTTCGGTTACTG    NDUFB5-1   ENSG00000136521
# 1        CD4i_R2L41  TCCAGGCTCGGAGCGCGGCA  SERPINB9-1   ENSG00000170542
# 2        CD4i_R2L41  GAGGCCCGGGGACCTCATAG    ZNF33A-2   ENSG00000189180
# 3        CD4i_R2L41  GAGGCATGGATCTTACACTC      LYG1-1   ENSG00000144214
# 4        CD4i_R2L41                   NaN         NaN               nan
# ...             ...                   ...         ...               ...
# 2208897  CD4i_R2L36  AGGGCTCCAGCCTCCTCCCG    HIF1AN-1   ENSG00000166135
# 2208898  CD4i_R2L36  GGGCGCTGCGGGGATTAGGA    TXNRD2-2   ENSG00000184470
# 2208899  CD4i_R2L36  GCTCCTAGCTTGAGGGAAAG    ZYG11B-1   ENSG00000162378
# 2208900  CD4i_R2L36  GCCCGGCCCTAAACTCCTAG   PPP2R3C-1   ENSG00000092020
# 2208901  CD4i_R2L36  GACGCCGAGGAGAAGGCGCG       DEK-2   ENSG00000124795
#
#          top_guide_UMI_counts perturbed_gene_name                cell_barcode  \
# index
# 0                      1862.0              NDUFB5  AAACAAGCAAACCCAAATACGTCA-1
# 1                       110.0            SERPINB9  AAACAAGCAACAAAGAAACGCCGA-1
# 2                        92.0              ZNF33A  AAACAAGCAACGTTAGATCATGTG-1
# 3                       275.0                LYG1  AAACAAGCAACTAAGTAACGCCGA-1
# 4                         NaN                 nan  AAACAAGCAACTAAGTATACGTCA-1
# ...                       ...                 ...                         ...
# 2208897                  17.0              HIF1AN  TTTGTGAGTTGTTGGTATTCGGTT-1
# 2208898                 447.0              TXNRD2  TTTGTGAGTTTACCGGATCATGTG-1
# 2208899                 169.0              ZYG11B  TTTGTGAGTTTACGACATACGTCA-1
# 2208900                  71.0             PPP2R3C  TTTGTGAGTTTGCATAATACGTCA-1
# 2208901                  56.0                 DEK  TTTGTGAGTTTGCTCCATCATGTG-1
#
#          total_counts                      perturbation_name  pct_counts_mt  \
# index
# 0             33708.0  AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41       1.302361
# 1             19897.0  AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41       0.638287
# 2              9237.0  AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41       0.086608
# 3             20720.0  AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41       0.115830
# 4             19086.0  AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41       1.152677
# ...               ...                                    ...            ...
# 2208897       10932.0  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36       0.146359
# 2208898        8155.0  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36       0.147149
# 2208899       10237.0  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36       0.488424
# 2208900       13835.0  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36       1.633538
# 2208901       12453.0  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36       0.907412
#
#             PuroR perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        3.264477       ENSG00000136521                  NDUFB5
# 1        2.623981       ENSG00000170542                SERPINB9
# 2        1.401497       ENSG00000189180                  ZNF33A
# 3        1.628095       ENSG00000144214                    LYG1
# 4        0.908886                   nan                     NaN
# ...           ...                   ...                     ...
# 2208897  4.133083       ENSG00000166135                  HIF1AN
# 2208898  2.579297       ENSG00000184470                  TXNRD2
# 2208899  3.714791       ENSG00000162378                  ZYG11B
# 2208900  2.988620       ENSG00000092020                 PPP2R3C
# 2208901  3.088817       ENSG00000124795                     DEK
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                 protein_coding   chr3:179604690-179627647;1
# 1                 protein_coding      chr6:2887169-2903309;-1
# 2                 protein_coding    chr10:38010295-38065088;1
# 3                 protein_coding    chr2:99284238-99306110;-1
# 4                            NaN                          NaN
# ...                          ...                          ...
# 2208897           protein_coding  chr10:100529072-100559998;1
# 2208898           protein_coding   chr22:19875517-19941820;-1
# 2208899           protein_coding     chr1:52726447-52827336;1
# 2208900           protein_coding   chr14:35085467-35122532;-1
# 2208901           protein_coding    chr6:18223860-18265997;-1
#
#         perturbed_target_chromosome original_index
# index
# 0                                 3              0
# 1                                 6              1
# 2                                10              2
# 3                                 2              3
# 4                               NaN              4
# ...                             ...            ...
# 2208897                          10        2208897
# 2208898                          22        2208898
# 2208899                           1        2208899
# 2208900                          14        2208900
# 2208901                           6        2208901
#
# [2208902 rows x 21 columns]

# %% [markdown]
# # Manually replace some genes

# %%
# define genes to replace in the cur_data.adata.obs
genes_to_replace = cur_data.adata.obs[cur_data.adata.obs['perturbed_target_symbol'].isna()]['perturbed_gene_name'].drop_duplicates().to_list()
# define columns to replace
cols_to_replace = ['perturbed_target_ensg',	'perturbed_target_symbol',	'perturbed_target_biotype',	'perturbed_target_coord',	'perturbed_target_chromosome']
# define mapping dict for renaming columns in gene_ont for replacement
gene_ont_col_mapping = {
    'ensembl_gene_id':'perturbed_target_ensg',
    'gene_symbol':'perturbed_target_symbol',
    'biotype':'perturbed_target_biotype',
    'gene_coord':'perturbed_target_coord',
    'chromosome_name':'perturbed_target_chromosome'
}
# loop through genes and fill in the missing cols
for replacement_gene in genes_to_replace:
    if replacement_gene in cur_data.gene_ont['synonym'].values:
        # subset gene_ont and get values for replacement
        replacement = (
            cur_data.gene_ont.rename(columns=gene_ont_col_mapping)
            .loc[cur_data.gene_ont['synonym'].isin([replacement_gene]), cols_to_replace]
        )[cols_to_replace].values[0]
        # replace values in cur_data.adata.obs with the values from gene_ont
        cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin([replacement_gene]), cols_to_replace] = replacement
        print(f"Replaced {replacement_gene} with {replacement}")
    else:
        print(f"No replacement found for {replacement_gene}")
# Out:
# No replacement found for nan
# No replacement found for SMIM11B
# No replacement found for AKAP2
# No replacement found for OCLM
# Replaced SGK494 with ['ENSG00000167524' 'RSKR' 'protein_coding' 'chr17:28455752-28614197;-1'
#  '17']
# No replacement found for LUZP6
# Replaced SEPT6 with ['ENSG00000125354' 'SEPTIN6' 'protein_coding'
#  'chrX:119615724-119693949;-1' 'X']
# No replacement found for FAM153B
# No replacement found for CCL3L1
# No replacement found for MTRNR2L4
# No replacement found for MTRNR2L8
# No replacement found for MTRNR2L1
# No replacement found for U2AF1L5

# %%
# replace non-mapped perturbed_target_symbol with original gene symbols
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_target_symbol'] = cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_gene_name'].values

# %%
# replace entries in perturbed_target_ensg that are not ENSEMBL ids with NA
cur_data.adata.obs.loc[(~cur_data.adata.obs['perturbed_target_ensg'].str.startswith('ENSG')) & (cur_data.adata.obs['perturbed_target_ensg'] != 'control_nontargeting'), 'perturbed_target_ensg'] = pd.NA

# %%
cur_data.adata.obs
# Out:
#                     guide_group  n_genes_by_counts guide_type  low_quality  \
# index
# 0        targeting single sgRNA               6739  targeting        False
# 1        targeting single sgRNA               5907  targeting        False
# 2        targeting single sgRNA               3868  targeting        False
# 3        targeting single sgRNA               5914  targeting        False
# 4                      no sgRNA               5828        NaN        False
# ...                         ...                ...        ...          ...
# 2208897  targeting single sgRNA               4647  targeting        False
# 2208898  targeting single sgRNA               3795  targeting        False
# 2208899  targeting single sgRNA               4135  targeting        False
# 2208900  targeting single sgRNA               4897  targeting        False
# 2208901  targeting single sgRNA               4801  targeting        False
#
#             lane_id        guide_sequence    guide_id perturbed_gene_id  \
# index
# 0        CD4i_R2L41  GCGGCGGGTTTCGGTTACTG    NDUFB5-1   ENSG00000136521
# 1        CD4i_R2L41  TCCAGGCTCGGAGCGCGGCA  SERPINB9-1   ENSG00000170542
# 2        CD4i_R2L41  GAGGCCCGGGGACCTCATAG    ZNF33A-2   ENSG00000189180
# 3        CD4i_R2L41  GAGGCATGGATCTTACACTC      LYG1-1   ENSG00000144214
# 4        CD4i_R2L41                   NaN         NaN               nan
# ...             ...                   ...         ...               ...
# 2208897  CD4i_R2L36  AGGGCTCCAGCCTCCTCCCG    HIF1AN-1   ENSG00000166135
# 2208898  CD4i_R2L36  GGGCGCTGCGGGGATTAGGA    TXNRD2-2   ENSG00000184470
# 2208899  CD4i_R2L36  GCTCCTAGCTTGAGGGAAAG    ZYG11B-1   ENSG00000162378
# 2208900  CD4i_R2L36  GCCCGGCCCTAAACTCCTAG   PPP2R3C-1   ENSG00000092020
# 2208901  CD4i_R2L36  GACGCCGAGGAGAAGGCGCG       DEK-2   ENSG00000124795
#
#          top_guide_UMI_counts perturbed_gene_name                cell_barcode  \
# index
# 0                      1862.0              NDUFB5  AAACAAGCAAACCCAAATACGTCA-1
# 1                       110.0            SERPINB9  AAACAAGCAACAAAGAAACGCCGA-1
# 2                        92.0              ZNF33A  AAACAAGCAACGTTAGATCATGTG-1
# 3                       275.0                LYG1  AAACAAGCAACTAAGTAACGCCGA-1
# 4                         NaN                 nan  AAACAAGCAACTAAGTATACGTCA-1
# ...                       ...                 ...                         ...
# 2208897                  17.0              HIF1AN  TTTGTGAGTTGTTGGTATTCGGTT-1
# 2208898                 447.0              TXNRD2  TTTGTGAGTTTACCGGATCATGTG-1
# 2208899                 169.0              ZYG11B  TTTGTGAGTTTACGACATACGTCA-1
# 2208900                  71.0             PPP2R3C  TTTGTGAGTTTGCATAATACGTCA-1
# 2208901                  56.0                 DEK  TTTGTGAGTTTGCTCCATCATGTG-1
#
#          total_counts                      perturbation_name  pct_counts_mt  \
# index
# 0             33708.0  AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41       1.302361
# 1             19897.0  AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41       0.638287
# 2              9237.0  AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41       0.086608
# 3             20720.0  AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41       0.115830
# 4             19086.0  AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41       1.152677
# ...               ...                                    ...            ...
# 2208897       10932.0  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36       0.146359
# 2208898        8155.0  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36       0.147149
# 2208899       10237.0  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36       0.488424
# 2208900       13835.0  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36       1.633538
# 2208901       12453.0  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36       0.907412
#
#             PuroR perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        3.264477       ENSG00000136521                  NDUFB5
# 1        2.623981       ENSG00000170542                SERPINB9
# 2        1.401497       ENSG00000189180                  ZNF33A
# 3        1.628095       ENSG00000144214                    LYG1
# 4        0.908886                  <NA>                     nan
# ...           ...                   ...                     ...
# 2208897  4.133083       ENSG00000166135                  HIF1AN
# 2208898  2.579297       ENSG00000184470                  TXNRD2
# 2208899  3.714791       ENSG00000162378                  ZYG11B
# 2208900  2.988620       ENSG00000092020                 PPP2R3C
# 2208901  3.088817       ENSG00000124795                     DEK
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                 protein_coding   chr3:179604690-179627647;1
# 1                 protein_coding      chr6:2887169-2903309;-1
# 2                 protein_coding    chr10:38010295-38065088;1
# 3                 protein_coding    chr2:99284238-99306110;-1
# 4                            NaN                          NaN
# ...                          ...                          ...
# 2208897           protein_coding  chr10:100529072-100559998;1
# 2208898           protein_coding   chr22:19875517-19941820;-1
# 2208899           protein_coding     chr1:52726447-52827336;1
# 2208900           protein_coding   chr14:35085467-35122532;-1
# 2208901           protein_coding    chr6:18223860-18265997;-1
#
#         perturbed_target_chromosome original_index
# index
# 0                                 3              0
# 1                                 6              1
# 2                                10              2
# 3                                 2              3
# 4                               NaN              4
# ...                             ...            ...
# 2208897                          10        2208897
# 2208898                          22        2208898
# 2208899                           1        2208899
# 2208900                          14        2208900
# 2208901                           6        2208901
#
# [2208902 rows x 21 columns]

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
# cur_data.count_entries(
#     slot='obs',
#     input_column='perturbed_target_ensg',
#     count_column_name='perturbed_target_number',
#     sep='|'
# )
cur_data.adata.obs['perturbed_target_number'] = 1

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.adata.obs[['perturbation_name', 'perturbed_target_chromosome_encoding']]
# Out:
#                              perturbation_name  \
# index
# 0        AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41
# 1        AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41
# 2        AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41
# 3        AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41
# 4        AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41
# ...                                        ...
# 2208897  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36
# 2208898  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36
# 2208899  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36
# 2208900  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36
# 2208901  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           3
# 1                                           6
# 2                                          10
# 3                                           2
# 4                                           0
# ...                                       ...
# 2208897                                    10
# 2208898                                    22
# 2208899                                     1
# 2208900                                    14
# 2208901                                     6
#
# [2208902 rows x 2 columns]

# %%
cur_data.adata.obs
# Out:
#                     guide_group  n_genes_by_counts guide_type  low_quality  \
# index
# 0        targeting single sgRNA               6739  targeting        False
# 1        targeting single sgRNA               5907  targeting        False
# 2        targeting single sgRNA               3868  targeting        False
# 3        targeting single sgRNA               5914  targeting        False
# 4                      no sgRNA               5828        NaN        False
# ...                         ...                ...        ...          ...
# 2208897  targeting single sgRNA               4647  targeting        False
# 2208898  targeting single sgRNA               3795  targeting        False
# 2208899  targeting single sgRNA               4135  targeting        False
# 2208900  targeting single sgRNA               4897  targeting        False
# 2208901  targeting single sgRNA               4801  targeting        False
#
#             lane_id        guide_sequence    guide_id perturbed_gene_id  \
# index
# 0        CD4i_R2L41  GCGGCGGGTTTCGGTTACTG    NDUFB5-1   ENSG00000136521
# 1        CD4i_R2L41  TCCAGGCTCGGAGCGCGGCA  SERPINB9-1   ENSG00000170542
# 2        CD4i_R2L41  GAGGCCCGGGGACCTCATAG    ZNF33A-2   ENSG00000189180
# 3        CD4i_R2L41  GAGGCATGGATCTTACACTC      LYG1-1   ENSG00000144214
# 4        CD4i_R2L41                   NaN         NaN               nan
# ...             ...                   ...         ...               ...
# 2208897  CD4i_R2L36  AGGGCTCCAGCCTCCTCCCG    HIF1AN-1   ENSG00000166135
# 2208898  CD4i_R2L36  GGGCGCTGCGGGGATTAGGA    TXNRD2-2   ENSG00000184470
# 2208899  CD4i_R2L36  GCTCCTAGCTTGAGGGAAAG    ZYG11B-1   ENSG00000162378
# 2208900  CD4i_R2L36  GCCCGGCCCTAAACTCCTAG   PPP2R3C-1   ENSG00000092020
# 2208901  CD4i_R2L36  GACGCCGAGGAGAAGGCGCG       DEK-2   ENSG00000124795
#
#          top_guide_UMI_counts perturbed_gene_name                cell_barcode  \
# index
# 0                      1862.0              NDUFB5  AAACAAGCAAACCCAAATACGTCA-1
# 1                       110.0            SERPINB9  AAACAAGCAACAAAGAAACGCCGA-1
# 2                        92.0              ZNF33A  AAACAAGCAACGTTAGATCATGTG-1
# 3                       275.0                LYG1  AAACAAGCAACTAAGTAACGCCGA-1
# 4                         NaN                 nan  AAACAAGCAACTAAGTATACGTCA-1
# ...                       ...                 ...                         ...
# 2208897                  17.0              HIF1AN  TTTGTGAGTTGTTGGTATTCGGTT-1
# 2208898                 447.0              TXNRD2  TTTGTGAGTTTACCGGATCATGTG-1
# 2208899                 169.0              ZYG11B  TTTGTGAGTTTACGACATACGTCA-1
# 2208900                  71.0             PPP2R3C  TTTGTGAGTTTGCATAATACGTCA-1
# 2208901                  56.0                 DEK  TTTGTGAGTTTGCTCCATCATGTG-1
#
#          total_counts                      perturbation_name  pct_counts_mt  \
# index
# 0             33708.0  AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41       1.302361
# 1             19897.0  AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41       0.638287
# 2              9237.0  AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41       0.086608
# 3             20720.0  AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41       0.115830
# 4             19086.0  AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41       1.152677
# ...               ...                                    ...            ...
# 2208897       10932.0  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36       0.146359
# 2208898        8155.0  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36       0.147149
# 2208899       10237.0  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36       0.488424
# 2208900       13835.0  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36       1.633538
# 2208901       12453.0  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36       0.907412
#
#             PuroR perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        3.264477       ENSG00000136521                  NDUFB5
# 1        2.623981       ENSG00000170542                SERPINB9
# 2        1.401497       ENSG00000189180                  ZNF33A
# 3        1.628095       ENSG00000144214                    LYG1
# 4        0.908886                  <NA>                     nan
# ...           ...                   ...                     ...
# 2208897  4.133083       ENSG00000166135                  HIF1AN
# 2208898  2.579297       ENSG00000184470                  TXNRD2
# 2208899  3.714791       ENSG00000162378                  ZYG11B
# 2208900  2.988620       ENSG00000092020                 PPP2R3C
# 2208901  3.088817       ENSG00000124795                     DEK
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                 protein_coding   chr3:179604690-179627647;1
# 1                 protein_coding      chr6:2887169-2903309;-1
# 2                 protein_coding    chr10:38010295-38065088;1
# 3                 protein_coding    chr2:99284238-99306110;-1
# 4                            NaN                          NaN
# ...                          ...                          ...
# 2208897           protein_coding  chr10:100529072-100559998;1
# 2208898           protein_coding   chr22:19875517-19941820;-1
# 2208899           protein_coding     chr1:52726447-52827336;1
# 2208900           protein_coding   chr14:35085467-35122532;-1
# 2208901           protein_coding    chr6:18223860-18265997;-1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0                                 3              0                        1
# 1                                 6              1                        1
# 2                                10              2                        1
# 3                                 2              3                        1
# 4                               NaN              4                        1
# ...                             ...            ...                      ...
# 2208897                          10        2208897                        1
# 2208898                          22        2208898                        1
# 2208899                           1        2208899                        1
# 2208900                          14        2208900                        1
# 2208901                           6        2208901                        1
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           3
# 1                                           6
# 2                                          10
# 3                                           2
# 4                                           0
# ...                                       ...
# 2208897                                    10
# 2208898                                    22
# 2208899                                     1
# 2208900                                    14
# 2208901                                     6
#
# [2208902 rows x 23 columns]

# %% [markdown]
# ### Curate replicates

# %%
cur_data.adata.obs = cur_data.adata.obs.rename(columns={'lane_id':'technical_replicate'})

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": "anti-CD3 antibody|anti-CD28 antibody|anti-CD2 antibody",
        "treatment_id": "EFO:0003317|EFO:0003304|NCIT:C184729",
        # replicates
        # "technical_replicate": None,
        "biological_replicate": "D4_CE0006864",
        # model system
        "model_system_label": "primary_cell",
        "model_system_id": None,
        "tissue": "lymphoid tissue",
        "cell_line_label": None,
        "cell_line_id": None,
        "cell_type_label": "CD4-positive, alpha-beta T cell",
        "disease_label": "healthy",
        "disease_id": None,

        "timepoint": "P14DT0H0M0S",
        "species": "Homo sapiens",
        "sex_label": "male",
        "sex_id": None,
        "developmental_stage_label": "adult",
        "developmental_stage_id": None,

        "study_title": "Genome-scale perturb-seq in primary human CD4+ T cells maps context-specific regulators of T cell programs and human immune traits",
        "study_uri": "https://doi.org/10.64898/2025.12.23.696273",
        "study_year": 2025,
        "first_author": "Ronghui Zhu",
        "last_author": "Alexander Marson",

        "experiment_title": "Perturb-seq of primary human CD4-positive T cells for patient D4_CE0006864, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator",
        "experiment_summary": """
            Isolated human CD4-positive cells from four healthy donors were stimulated with ImmunoCult CD3/CD28/CD2 activator and sequentially transduced with dCas9-KRAB-Zim3 lentivirus (next morning after stimulation) and a Perturb-seq guide library (next afternoon after stimulation, MOI 0.2).
            The library consisted all genes expressed in human CD4+ T cells, all transcription factors annotated in the Lambert et al. (2018) and non-targeting controls totalling 12,748 genes.
            The gRNA sequences were selected from hCRISPRiv2 and Dolcetto libraries.
            On day 12, cells were split into three conditions:
            (1) Rest - cells were left for 8 hr without stimulation;
            (2) Stim8hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 8 hr;
            (3) Stim48hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 48 hr.
            Cells were harvested, fixed, stored using GEM-X Flex Sample Preparation v2 Kit and sequenced using GEM-X Flex Gene Expression Human n-plex kit converted into Ultima compatible libraries for sequencing on the Ultima Genomics UG100.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_symbol'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB-Zim3",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Marson lab",
        "library_lentiviral_generation": "2",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "GEM-X Flex Gene Expression Human n-plex kit",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "scanpy",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",

        "license_label": "MIT License",
        "license_id": "SWO:9000074",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "Primary Human CD4+ T Cell Perturb-seq",
                "dataset_uri": "s3://genome-scale-tcell-perturb-seq/marson2025_data/D4_Stim48hr.assigned_guide.h5ad",
                "dataset_description": "Cell expression profiles for cells from donor D4_CE0006864, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator.",
                "dataset_file_name": "D4_Stim48hr.assigned_guide.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column biological_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_line_id added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column disease_id added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#                     guide_group  n_genes_by_counts guide_type  low_quality  \
# index
# 0        targeting single sgRNA               6739  targeting        False
# 1        targeting single sgRNA               5907  targeting        False
# 2        targeting single sgRNA               3868  targeting        False
# 3        targeting single sgRNA               5914  targeting        False
# 4                      no sgRNA               5828        NaN        False
# ...                         ...                ...        ...          ...
# 2208897  targeting single sgRNA               4647  targeting        False
# 2208898  targeting single sgRNA               3795  targeting        False
# 2208899  targeting single sgRNA               4135  targeting        False
# 2208900  targeting single sgRNA               4897  targeting        False
# 2208901  targeting single sgRNA               4801  targeting        False
#
#         technical_replicate        guide_sequence    guide_id  \
# index
# 0                CD4i_R2L41  GCGGCGGGTTTCGGTTACTG    NDUFB5-1
# 1                CD4i_R2L41  TCCAGGCTCGGAGCGCGGCA  SERPINB9-1
# 2                CD4i_R2L41  GAGGCCCGGGGACCTCATAG    ZNF33A-2
# 3                CD4i_R2L41  GAGGCATGGATCTTACACTC      LYG1-1
# 4                CD4i_R2L41                   NaN         NaN
# ...                     ...                   ...         ...
# 2208897          CD4i_R2L36  AGGGCTCCAGCCTCCTCCCG    HIF1AN-1
# 2208898          CD4i_R2L36  GGGCGCTGCGGGGATTAGGA    TXNRD2-2
# 2208899          CD4i_R2L36  GCTCCTAGCTTGAGGGAAAG    ZYG11B-1
# 2208900          CD4i_R2L36  GCCCGGCCCTAAACTCCTAG   PPP2R3C-1
# 2208901          CD4i_R2L36  GACGCCGAGGAGAAGGCGCG       DEK-2
#
#         perturbed_gene_id  top_guide_UMI_counts perturbed_gene_name  \
# index
# 0         ENSG00000136521                1862.0              NDUFB5
# 1         ENSG00000170542                 110.0            SERPINB9
# 2         ENSG00000189180                  92.0              ZNF33A
# 3         ENSG00000144214                 275.0                LYG1
# 4                     nan                   NaN                 nan
# ...                   ...                   ...                 ...
# 2208897   ENSG00000166135                  17.0              HIF1AN
# 2208898   ENSG00000184470                 447.0              TXNRD2
# 2208899   ENSG00000162378                 169.0              ZYG11B
# 2208900   ENSG00000092020                  71.0             PPP2R3C
# 2208901   ENSG00000124795                  56.0                 DEK
#
#                        cell_barcode  total_counts  \
# index
# 0        AAACAAGCAAACCCAAATACGTCA-1       33708.0
# 1        AAACAAGCAACAAAGAAACGCCGA-1       19897.0
# 2        AAACAAGCAACGTTAGATCATGTG-1        9237.0
# 3        AAACAAGCAACTAAGTAACGCCGA-1       20720.0
# 4        AAACAAGCAACTAAGTATACGTCA-1       19086.0
# ...                             ...           ...
# 2208897  TTTGTGAGTTGTTGGTATTCGGTT-1       10932.0
# 2208898  TTTGTGAGTTTACCGGATCATGTG-1        8155.0
# 2208899  TTTGTGAGTTTACGACATACGTCA-1       10237.0
# 2208900  TTTGTGAGTTTGCATAATACGTCA-1       13835.0
# 2208901  TTTGTGAGTTTGCTCCATCATGTG-1       12453.0
#
#                              perturbation_name  pct_counts_mt     PuroR  \
# index
# 0        AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41       1.302361  3.264477
# 1        AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41       0.638287  2.623981
# 2        AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41       0.086608  1.401497
# 3        AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41       0.115830  1.628095
# 4        AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41       1.152677  0.908886
# ...                                        ...            ...       ...
# 2208897  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36       0.146359  4.133083
# 2208898  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36       0.147149  2.579297
# 2208899  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36       0.488424  3.714791
# 2208900  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36       1.633538  2.988620
# 2208901  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36       0.907412  3.088817
#
#         perturbed_target_ensg perturbed_target_symbol  \
# index
# 0             ENSG00000136521                  NDUFB5
# 1             ENSG00000170542                SERPINB9
# 2             ENSG00000189180                  ZNF33A
# 3             ENSG00000144214                    LYG1
# 4                        <NA>                     nan
# ...                       ...                     ...
# 2208897       ENSG00000166135                  HIF1AN
# 2208898       ENSG00000184470                  TXNRD2
# 2208899       ENSG00000162378                  ZYG11B
# 2208900       ENSG00000092020                 PPP2R3C
# 2208901       ENSG00000124795                     DEK
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                 protein_coding   chr3:179604690-179627647;1
# 1                 protein_coding      chr6:2887169-2903309;-1
# 2                 protein_coding    chr10:38010295-38065088;1
# 3                 protein_coding    chr2:99284238-99306110;-1
# 4                            NaN                          NaN
# ...                          ...                          ...
# 2208897           protein_coding  chr10:100529072-100559998;1
# 2208898           protein_coding   chr22:19875517-19941820;-1
# 2208899           protein_coding     chr1:52726447-52827336;1
# 2208900           protein_coding   chr14:35085467-35122532;-1
# 2208901           protein_coding    chr6:18223860-18265997;-1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0                                 3              0                        1
# 1                                 6              1                        1
# 2                                10              2                        1
# 3                                 2              3                        1
# 4                               NaN              4                        1
# ...                             ...            ...                      ...
# 2208897                          10        2208897                        1
# 2208898                          22        2208898                        1
# 2208899                           1        2208899                        1
# 2208900                          14        2208900                        1
# 2208901                           6        2208901                        1
#
#          perturbed_target_chromosome_encoding               dataset_id  \
# index
# 0                                           3  zhu_2025_D4_stim48hr_cl
# 1                                           6  zhu_2025_D4_stim48hr_cl
# 2                                          10  zhu_2025_D4_stim48hr_cl
# 3                                           2  zhu_2025_D4_stim48hr_cl
# 4                                           0  zhu_2025_D4_stim48hr_cl
# ...                                       ...                      ...
# 2208897                                    10  zhu_2025_D4_stim48hr_cl
# 2208898                                    22  zhu_2025_D4_stim48hr_cl
# 2208899                                     1  zhu_2025_D4_stim48hr_cl
# 2208900                                    14  zhu_2025_D4_stim48hr_cl
# 2208901                                     6  zhu_2025_D4_stim48hr_cl
#
#          sample_id perturbation_type_label perturbation_type_id data_modality  \
# index
# 0                1                 CRISPRi                 None   Perturb-seq
# 1                2                 CRISPRi                 None   Perturb-seq
# 2                3                 CRISPRi                 None   Perturb-seq
# 3                4                 CRISPRi                 None   Perturb-seq
# 4                5                 CRISPRi                 None   Perturb-seq
# ...            ...                     ...                  ...           ...
# 2208897    2208898                 CRISPRi                 None   Perturb-seq
# 2208898    2208899                 CRISPRi                 None   Perturb-seq
# 2208899    2208900                 CRISPRi                 None   Perturb-seq
# 2208900    2208901                 CRISPRi                 None   Perturb-seq
# 2208901    2208902                 CRISPRi                 None   Perturb-seq
#
#         significant significance_criteria score_interpretation  \
# index
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
# ...             ...                   ...                  ...
# 2208897        None                  None                 None
# 2208898        None                  None                 None
# 2208899        None                  None                 None
# 2208900        None                  None                 None
# 2208901        None                  None                 None
#
#                                            treatment_label  \
# index
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2208897  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208898  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208899  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208900  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208901  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id biological_replicate  \
# index
# 0        EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 1        EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 2        EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 3        EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 4        EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# ...                                       ...                  ...
# 2208897  EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 2208898  EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 2208899  EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 2208900  EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
# 2208901  EFO:0003317|EFO:0003304|NCIT:C184729         D4_CE0006864
#
#         model_system_label model_system_id           tissue cell_line_label  \
# index
# 0             primary_cell            None  lymphoid tissue            None
# 1             primary_cell            None  lymphoid tissue            None
# 2             primary_cell            None  lymphoid tissue            None
# 3             primary_cell            None  lymphoid tissue            None
# 4             primary_cell            None  lymphoid tissue            None
# ...                    ...             ...              ...             ...
# 2208897       primary_cell            None  lymphoid tissue            None
# 2208898       primary_cell            None  lymphoid tissue            None
# 2208899       primary_cell            None  lymphoid tissue            None
# 2208900       primary_cell            None  lymphoid tissue            None
# 2208901       primary_cell            None  lymphoid tissue            None
#
#         cell_line_id                  cell_type_label disease_label  \
# index
# 0               None  CD4-positive, alpha-beta T cell       healthy
# 1               None  CD4-positive, alpha-beta T cell       healthy
# 2               None  CD4-positive, alpha-beta T cell       healthy
# 3               None  CD4-positive, alpha-beta T cell       healthy
# 4               None  CD4-positive, alpha-beta T cell       healthy
# ...              ...                              ...           ...
# 2208897         None  CD4-positive, alpha-beta T cell       healthy
# 2208898         None  CD4-positive, alpha-beta T cell       healthy
# 2208899         None  CD4-positive, alpha-beta T cell       healthy
# 2208900         None  CD4-positive, alpha-beta T cell       healthy
# 2208901         None  CD4-positive, alpha-beta T cell       healthy
#
#         disease_id    timepoint       species sex_label sex_id  \
# index
# 0             None  P14DT0H0M0S  Homo sapiens      male   None
# 1             None  P14DT0H0M0S  Homo sapiens      male   None
# 2             None  P14DT0H0M0S  Homo sapiens      male   None
# 3             None  P14DT0H0M0S  Homo sapiens      male   None
# 4             None  P14DT0H0M0S  Homo sapiens      male   None
# ...            ...          ...           ...       ...    ...
# 2208897       None  P14DT0H0M0S  Homo sapiens      male   None
# 2208898       None  P14DT0H0M0S  Homo sapiens      male   None
# 2208899       None  P14DT0H0M0S  Homo sapiens      male   None
# 2208900       None  P14DT0H0M0S  Homo sapiens      male   None
# 2208901       None  P14DT0H0M0S  Homo sapiens      male   None
#
#         developmental_stage_label developmental_stage_id  \
# index
# 0                           adult                   None
# 1                           adult                   None
# 2                           adult                   None
# 3                           adult                   None
# 4                           adult                   None
# ...                           ...                    ...
# 2208897                     adult                   None
# 2208898                     adult                   None
# 2208899                     adult                   None
# 2208900                     adult                   None
# 2208901                     adult                   None
#
#                                                study_title  \
# index
# 0        Genome-scale perturb-seq in primary human CD4+...
# 1        Genome-scale perturb-seq in primary human CD4+...
# 2        Genome-scale perturb-seq in primary human CD4+...
# 3        Genome-scale perturb-seq in primary human CD4+...
# 4        Genome-scale perturb-seq in primary human CD4+...
# ...                                                    ...
# 2208897  Genome-scale perturb-seq in primary human CD4+...
# 2208898  Genome-scale perturb-seq in primary human CD4+...
# 2208899  Genome-scale perturb-seq in primary human CD4+...
# 2208900  Genome-scale perturb-seq in primary human CD4+...
# 2208901  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# index
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2208897  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208898  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208899  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208900  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208901  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# index
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2208897  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208898  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208899  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208900  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208901  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# index
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2208897  \n            Isolated human CD4-positive cell...
# 2208898  \n            Isolated human CD4-positive cell...
# 2208899  \n            Isolated human CD4-positive cell...
# 2208900  \n            Isolated human CD4-positive cell...
# 2208901  \n            Isolated human CD4-positive cell...
#
#          number_of_perturbed_targets  number_of_perturbed_samples  \
# index
# 0                              12423                      2208902
# 1                              12423                      2208902
# 2                              12423                      2208902
# 3                              12423                      2208902
# 4                              12423                      2208902
# ...                              ...                          ...
# 2208897                        12423                      2208902
# 2208898                        12423                      2208902
# 2208899                        12423                      2208902
# 2208900                        12423                      2208902
# 2208901                        12423                      2208902
#
#         library_generation_type_id library_generation_type_label  \
# index
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2208897                EFO:0022868                    endogenous
# 2208898                EFO:0022868                    endogenous
# 2208899                EFO:0022868                    endogenous
# 2208900                EFO:0022868                    endogenous
# 2208901                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# index
# 0                               None                 dCas9-KRAB-Zim3
# 1                               None                 dCas9-KRAB-Zim3
# 2                               None                 dCas9-KRAB-Zim3
# 3                               None                 dCas9-KRAB-Zim3
# 4                               None                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2208897                         None                 dCas9-KRAB-Zim3
# 2208898                         None                 dCas9-KRAB-Zim3
# 2208899                         None                 dCas9-KRAB-Zim3
# 2208900                         None                 dCas9-KRAB-Zim3
# 2208901                         None                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# index
# 0                            None      lentivirus transduction
# 1                            None      lentivirus transduction
# 2                            None      lentivirus transduction
# 3                            None      lentivirus transduction
# 4                            None      lentivirus transduction
# ...                           ...                          ...
# 2208897                      None      lentivirus transduction
# 2208898                      None      lentivirus transduction
# 2208899                      None      lentivirus transduction
# 2208900                      None      lentivirus transduction
# 2208901                      None      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# index
# 0                             None       lentivirus transduction
# 1                             None       lentivirus transduction
# 2                             None       lentivirus transduction
# 3                             None       lentivirus transduction
# 4                             None       lentivirus transduction
# ...                            ...                           ...
# 2208897                       None       lentivirus transduction
# 2208898                       None       lentivirus transduction
# 2208899                       None       lentivirus transduction
# 2208900                       None       lentivirus transduction
# 2208901                       None       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# index
# 0                              None       random locus integration
# 1                              None       random locus integration
# 2                              None       random locus integration
# 3                              None       random locus integration
# 4                              None       random locus integration
# ...                             ...                            ...
# 2208897                        None       random locus integration
# 2208898                        None       random locus integration
# 2208899                        None       random locus integration
# 2208900                        None       random locus integration
# 2208901                        None       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# index
# 0                               None        random locus integration
# 1                               None        random locus integration
# 2                               None        random locus integration
# 3                               None        random locus integration
# 4                               None        random locus integration
# ...                              ...                             ...
# 2208897                         None        random locus integration
# 2208898                         None        random locus integration
# 2208899                         None        random locus integration
# 2208900                         None        random locus integration
# 2208901                         None        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# index
# 0                               None  constitutive transgene expression
# 1                               None  constitutive transgene expression
# 2                               None  constitutive transgene expression
# 3                               None  constitutive transgene expression
# 4                               None  constitutive transgene expression
# ...                              ...                                ...
# 2208897                         None  constitutive transgene expression
# 2208898                         None  constitutive transgene expression
# 2208899                         None  constitutive transgene expression
# 2208900                         None  constitutive transgene expression
# 2208901                         None  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# index
# 0                                None  constitutive transgene expression
# 1                                None  constitutive transgene expression
# 2                                None  constitutive transgene expression
# 3                                None  constitutive transgene expression
# 4                                None  constitutive transgene expression
# ...                               ...                                ...
# 2208897                          None  constitutive transgene expression
# 2208898                          None  constitutive transgene expression
# 2208899                          None  constitutive transgene expression
# 2208900                          None  constitutive transgene expression
# 2208901                          None  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# index
# 0             custom        None              None               pooled
# 1             custom        None              None               pooled
# 2             custom        None              None               pooled
# 3             custom        None              None               pooled
# 4             custom        None              None               pooled
# ...              ...         ...               ...                  ...
# 2208897       custom        None              None               pooled
# 2208898       custom        None              None               pooled
# 2208899       custom        None              None               pooled
# 2208900       custom        None              None               pooled
# 2208901       custom        None              None               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# index
# 0                   None             focused                         None
# 1                   None             focused                         None
# 2                   None             focused                         None
# 3                   None             focused                         None
# 4                   None             focused                         None
# ...                  ...                 ...                          ...
# 2208897             None             focused                         None
# 2208898             None             focused                         None
# 2208899             None             focused                         None
# 2208900             None             focused                         None
# 2208901             None             focused                         None
#
#         library_perturbation_type_label library_manufacturer  \
# index
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2208897                      inhibition           Marson lab
# 2208898                      inhibition           Marson lab
# 2208899                      inhibition           Marson lab
# 2208900                      inhibition           Marson lab
# 2208901                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# index
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2208897                             2                        2
# 2208898                             2                        2
# 2208899                             2                        2
# 2208900                             2                        2
# 2208901                             2                        2
#
#         library_total_grnas library_total_variants readout_dimensionality_id  \
# index
# 0                     24803                   None                      None
# 1                     24803                   None                      None
# 2                     24803                   None                      None
# 3                     24803                   None                      None
# 4                     24803                   None                      None
# ...                     ...                    ...                       ...
# 2208897               24803                   None                      None
# 2208898               24803                   None                      None
# 2208899               24803                   None                      None
# 2208900               24803                   None                      None
# 2208901               24803                   None                      None
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# index
# 0             high-dimensional assay            None     transcriptomic
# 1             high-dimensional assay            None     transcriptomic
# 2             high-dimensional assay            None     transcriptomic
# 3             high-dimensional assay            None     transcriptomic
# 4             high-dimensional assay            None     transcriptomic
# ...                              ...             ...                ...
# 2208897       high-dimensional assay            None     transcriptomic
# 2208898       high-dimensional assay            None     transcriptomic
# 2208899       high-dimensional assay            None     transcriptomic
# 2208900       high-dimensional assay            None     transcriptomic
# 2208901       high-dimensional assay            None     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# index
# 0                        None      single-cell rna-seq           None
# 1                        None      single-cell rna-seq           None
# 2                        None      single-cell rna-seq           None
# 3                        None      single-cell rna-seq           None
# 4                        None      single-cell rna-seq           None
# ...                       ...                      ...            ...
# 2208897                  None      single-cell rna-seq           None
# 2208898                  None      single-cell rna-seq           None
# 2208899                  None      single-cell rna-seq           None
# 2208900                  None      single-cell rna-seq           None
# 2208901                  None      single-cell rna-seq           None
#
#         method_name_label method_uri sequencing_library_kit_id  \
# index
# 0             Perturb-seq       None                      None
# 1             Perturb-seq       None                      None
# 2             Perturb-seq       None                      None
# 3             Perturb-seq       None                      None
# 4             Perturb-seq       None                      None
# ...                   ...        ...                       ...
# 2208897       Perturb-seq       None                      None
# 2208898       Perturb-seq       None                      None
# 2208899       Perturb-seq       None                      None
# 2208900       Perturb-seq       None                      None
# 2208901       Perturb-seq       None                      None
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# index
# 0        GEM-X Flex Gene Expression Human n-plex kit                   None
# 1        GEM-X Flex Gene Expression Human n-plex kit                   None
# 2        GEM-X Flex Gene Expression Human n-plex kit                   None
# 3        GEM-X Flex Gene Expression Human n-plex kit                   None
# 4        GEM-X Flex Gene Expression Human n-plex kit                   None
# ...                                              ...                    ...
# 2208897  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2208898  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2208899  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2208900  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2208901  GEM-X Flex Gene Expression Human n-plex kit                   None
#
#         sequencing_platform_label sequencing_strategy_id  \
# index
# 0           Ultima Genomics UG100                   None
# 1           Ultima Genomics UG100                   None
# 2           Ultima Genomics UG100                   None
# 3           Ultima Genomics UG100                   None
# 4           Ultima Genomics UG100                   None
# ...                           ...                    ...
# 2208897     Ultima Genomics UG100                   None
# 2208898     Ultima Genomics UG100                   None
# 2208899     Ultima Genomics UG100                   None
# 2208900     Ultima Genomics UG100                   None
# 2208901     Ultima Genomics UG100                   None
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# index
# 0              barcode sequencing               None            CellRanger
# 1              barcode sequencing               None            CellRanger
# 2              barcode sequencing               None            CellRanger
# 3              barcode sequencing               None            CellRanger
# 4              barcode sequencing               None            CellRanger
# ...                           ...                ...                   ...
# 2208897        barcode sequencing               None            CellRanger
# 2208898        barcode sequencing               None            CellRanger
# 2208899        barcode sequencing               None            CellRanger
# 2208900        barcode sequencing               None            CellRanger
# 2208901        barcode sequencing               None            CellRanger
#
#         software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                       None                  scanpy                None
# 1                       None                  scanpy                None
# 2                       None                  scanpy                None
# 3                       None                  scanpy                None
# 4                       None                  scanpy                None
# ...                      ...                     ...                 ...
# 2208897                 None                  scanpy                None
# 2208898                 None                  scanpy                None
# 2208899                 None                  scanpy                None
# 2208900                 None                  scanpy                None
# 2208901                 None                  scanpy                None
#
#         reference_genome_label license_label   license_id  \
# index
# 0                       GRCh38   MIT License  SWO:9000074
# 1                       GRCh38   MIT License  SWO:9000074
# 2                       GRCh38   MIT License  SWO:9000074
# 3                       GRCh38   MIT License  SWO:9000074
# 4                       GRCh38   MIT License  SWO:9000074
# ...                        ...           ...          ...
# 2208897                 GRCh38   MIT License  SWO:9000074
# 2208898                 GRCh38   MIT License  SWO:9000074
# 2208899                 GRCh38   MIT License  SWO:9000074
# 2208900                 GRCh38   MIT License  SWO:9000074
# 2208901                 GRCh38   MIT License  SWO:9000074
#
#                                        associated_datasets
# index
# 0        [{"dataset_accession": "Primary Human CD4+ T C...
# 1        [{"dataset_accession": "Primary Human CD4+ T C...
# 2        [{"dataset_accession": "Primary Human CD4+ T C...
# 3        [{"dataset_accession": "Primary Human CD4+ T C...
# 4        [{"dataset_accession": "Primary Human CD4+ T C...
# ...                                                    ...
# 2208897  [{"dataset_accession": "Primary Human CD4+ T C...
# 2208898  [{"dataset_accession": "Primary Human CD4+ T C...
# 2208899  [{"dataset_accession": "Primary Human CD4+ T C...
# 2208900  [{"dataset_accession": "Primary Human CD4+ T C...
# 2208901  [{"dataset_accession": "Primary Human CD4+ T C...
#
# [2208902 rows x 110 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#       input_column input_column_lower       name_lower     ontology_id
# 0  lymphoid tissue    lymphoid tissue  lymphoid tissue  UBERON:0001744
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                       input_column               input_column_lower  \
# 0  CD4-positive, alpha-beta T cell  cd4-positive, alpha-beta t cell
#
#                         name_lower ontology_id
# 0  cd4-positive, alpha-beta t cell  CL:0000624
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Warning: No disease ontology terms could be mapped from `disease_label` column to ontology terms. Map the terms manually or check the input column for errors.

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-02-18 10:57:03,060 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
#                       dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D4_stim48hr_cl         1   Perturb-seq        <NA>
# 1        zhu_2025_D4_stim48hr_cl         2   Perturb-seq        <NA>
# 2        zhu_2025_D4_stim48hr_cl         3   Perturb-seq        <NA>
# 3        zhu_2025_D4_stim48hr_cl         4   Perturb-seq        <NA>
# 4        zhu_2025_D4_stim48hr_cl         5   Perturb-seq        <NA>
# ...                          ...       ...           ...         ...
# 2208897  zhu_2025_D4_stim48hr_cl   2208898   Perturb-seq        <NA>
# 2208898  zhu_2025_D4_stim48hr_cl   2208899   Perturb-seq        <NA>
# 2208899  zhu_2025_D4_stim48hr_cl   2208900   Perturb-seq        <NA>
# 2208900  zhu_2025_D4_stim48hr_cl   2208901   Perturb-seq        <NA>
# 2208901  zhu_2025_D4_stim48hr_cl   2208902   Perturb-seq        <NA>
#
#         significance_criteria                      perturbation_name  \
# 0                        <NA>  AAACAAGCAAACCCAAATACGTCA-1_CD4i_R2L41
# 1                        <NA>  AAACAAGCAACAAAGAAACGCCGA-1_CD4i_R2L41
# 2                        <NA>  AAACAAGCAACGTTAGATCATGTG-1_CD4i_R2L41
# 3                        <NA>  AAACAAGCAACTAAGTAACGCCGA-1_CD4i_R2L41
# 4                        <NA>  AAACAAGCAACTAAGTATACGTCA-1_CD4i_R2L41
# ...                       ...                                    ...
# 2208897                  <NA>  TTTGTGAGTTGTTGGTATTCGGTT-1_CD4i_R2L36
# 2208898                  <NA>  TTTGTGAGTTTACCGGATCATGTG-1_CD4i_R2L36
# 2208899                  <NA>  TTTGTGAGTTTACGACATACGTCA-1_CD4i_R2L36
# 2208900                  <NA>  TTTGTGAGTTTGCATAATACGTCA-1_CD4i_R2L36
# 2208901                  <NA>  TTTGTGAGTTTGCTCCATCATGTG-1_CD4i_R2L36
#
#               perturbed_target_coord perturbed_target_chromosome  \
# 0         chr3:179604690-179627647;1                           3
# 1            chr6:2887169-2903309;-1                           6
# 2          chr10:38010295-38065088;1                          10
# 3          chr2:99284238-99306110;-1                           2
# 4                               <NA>                        <NA>
# ...                              ...                         ...
# 2208897  chr10:100529072-100559998;1                          10
# 2208898   chr22:19875517-19941820;-1                          22
# 2208899     chr1:52726447-52827336;1                           1
# 2208900   chr14:35085467-35122532;-1                          14
# 2208901    chr6:18223860-18265997;-1                           6
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           3                        1
# 1                                           6                        1
# 2                                          10                        1
# 3                                           2                        1
# 4                                           0                        1
# ...                                       ...                      ...
# 2208897                                    10                        1
# 2208898                                    22                        1
# 2208899                                     1                        1
# 2208900                                    14                        1
# 2208901                                     6                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0             ENSG00000136521                  NDUFB5
# 1             ENSG00000170542                SERPINB9
# 2             ENSG00000189180                  ZNF33A
# 3             ENSG00000144214                    LYG1
# 4                        <NA>                     nan
# ...                       ...                     ...
# 2208897       ENSG00000166135                  HIF1AN
# 2208898       ENSG00000184470                  TXNRD2
# 2208899       ENSG00000162378                  ZYG11B
# 2208900       ENSG00000092020                 PPP2R3C
# 2208901       ENSG00000124795                     DEK
#
#         perturbed_target_biotype        guide_sequence  \
# 0                 protein_coding  GCGGCGGGTTTCGGTTACTG
# 1                 protein_coding  TCCAGGCTCGGAGCGCGGCA
# 2                 protein_coding  GAGGCCCGGGGACCTCATAG
# 3                 protein_coding  GAGGCATGGATCTTACACTC
# 4                           <NA>                  <NA>
# ...                          ...                   ...
# 2208897           protein_coding  AGGGCTCCAGCCTCCTCCCG
# 2208898           protein_coding  GGGCGCTGCGGGGATTAGGA
# 2208899           protein_coding  GCTCCTAGCTTGAGGGAAAG
# 2208900           protein_coding  GCCCGGCCCTAAACTCCTAG
# 2208901           protein_coding  GACGCCGAGGAGAAGGCGCG
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                 <NA>  P14DT0H0M0S
# 1                       CRISPRi                 <NA>  P14DT0H0M0S
# 2                       CRISPRi                 <NA>  P14DT0H0M0S
# 3                       CRISPRi                 <NA>  P14DT0H0M0S
# 4                       CRISPRi                 <NA>  P14DT0H0M0S
# ...                         ...                  ...          ...
# 2208897                 CRISPRi                 <NA>  P14DT0H0M0S
# 2208898                 CRISPRi                 <NA>  P14DT0H0M0S
# 2208899                 CRISPRi                 <NA>  P14DT0H0M0S
# 2208900                 CRISPRi                 <NA>  P14DT0H0M0S
# 2208901                 CRISPRi                 <NA>  P14DT0H0M0S
#
#                                            treatment_label  \
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2208897  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208898  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208899  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208900  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2208901  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id technical_replicate  \
# 0        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L41
# 1        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L41
# 2        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L41
# 3        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L41
# 4        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L41
# ...                                       ...                 ...
# 2208897  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L36
# 2208898  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L36
# 2208899  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L36
# 2208900  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L36
# 2208901  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L36
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 1               D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 2               D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 3               D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 4               D4_CE0006864       primary_cell            <NA>  Homo sapiens
# ...                      ...                ...             ...           ...
# 2208897         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 2208898         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 2208899         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 2208900         D4_CE0006864       primary_cell            <NA>  Homo sapiens
# 2208901         D4_CE0006864       primary_cell            <NA>  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2208897  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2208898  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2208899  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2208900  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2208901  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624            <NA>         <NA>      male   <NA>
# 1         CL:0000624            <NA>         <NA>      male   <NA>
# 2         CL:0000624            <NA>         <NA>      male   <NA>
# 3         CL:0000624            <NA>         <NA>      male   <NA>
# 4         CL:0000624            <NA>         <NA>      male   <NA>
# ...              ...             ...          ...       ...    ...
# 2208897   CL:0000624            <NA>         <NA>      male   <NA>
# 2208898   CL:0000624            <NA>         <NA>      male   <NA>
# 2208899   CL:0000624            <NA>         <NA>      male   <NA>
# 2208900   CL:0000624            <NA>         <NA>      male   <NA>
# 2208901   CL:0000624            <NA>         <NA>      male   <NA>
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                   <NA>       healthy
# 1                           adult                   <NA>       healthy
# 2                           adult                   <NA>       healthy
# 3                           adult                   <NA>       healthy
# 4                           adult                   <NA>       healthy
# ...                           ...                    ...           ...
# 2208897                     adult                   <NA>       healthy
# 2208898                     adult                   <NA>       healthy
# 2208899                     adult                   <NA>       healthy
# 2208900                     adult                   <NA>       healthy
# 2208901                     adult                   <NA>       healthy
#
#         disease_id                                        study_title  \
# 0             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 1             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 3             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 4             <NA>  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2208897       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2208898       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2208899       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2208900       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2208901       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2208897  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208898  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208899  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208900  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2208901  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2208897  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208898  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208899  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208900  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2208901  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2208897  \n            Isolated human CD4-positive cell...
# 2208898  \n            Isolated human CD4-positive cell...
# 2208899  \n            Isolated human CD4-positive cell...
# 2208900  \n            Isolated human CD4-positive cell...
# 2208901  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             12423                     2208902
# 1                             12423                     2208902
# 2                             12423                     2208902
# 3                             12423                     2208902
# 4                             12423                     2208902
# ...                             ...                         ...
# 2208897                       12423                     2208902
# 2208898                       12423                     2208902
# 2208899                       12423                     2208902
# 2208900                       12423                     2208902
# 2208901                       12423                     2208902
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2208897                EFO:0022868                    endogenous
# 2208898                EFO:0022868                    endogenous
# 2208899                EFO:0022868                    endogenous
# 2208900                EFO:0022868                    endogenous
# 2208901                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                               <NA>                 dCas9-KRAB-Zim3
# 1                               <NA>                 dCas9-KRAB-Zim3
# 2                               <NA>                 dCas9-KRAB-Zim3
# 3                               <NA>                 dCas9-KRAB-Zim3
# 4                               <NA>                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2208897                         <NA>                 dCas9-KRAB-Zim3
# 2208898                         <NA>                 dCas9-KRAB-Zim3
# 2208899                         <NA>                 dCas9-KRAB-Zim3
# 2208900                         <NA>                 dCas9-KRAB-Zim3
# 2208901                         <NA>                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                            <NA>      lentivirus transduction
# 1                            <NA>      lentivirus transduction
# 2                            <NA>      lentivirus transduction
# 3                            <NA>      lentivirus transduction
# 4                            <NA>      lentivirus transduction
# ...                           ...                          ...
# 2208897                      <NA>      lentivirus transduction
# 2208898                      <NA>      lentivirus transduction
# 2208899                      <NA>      lentivirus transduction
# 2208900                      <NA>      lentivirus transduction
# 2208901                      <NA>      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                             <NA>       lentivirus transduction
# 1                             <NA>       lentivirus transduction
# 2                             <NA>       lentivirus transduction
# 3                             <NA>       lentivirus transduction
# 4                             <NA>       lentivirus transduction
# ...                            ...                           ...
# 2208897                       <NA>       lentivirus transduction
# 2208898                       <NA>       lentivirus transduction
# 2208899                       <NA>       lentivirus transduction
# 2208900                       <NA>       lentivirus transduction
# 2208901                       <NA>       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                              <NA>       random locus integration
# 1                              <NA>       random locus integration
# 2                              <NA>       random locus integration
# 3                              <NA>       random locus integration
# 4                              <NA>       random locus integration
# ...                             ...                            ...
# 2208897                        <NA>       random locus integration
# 2208898                        <NA>       random locus integration
# 2208899                        <NA>       random locus integration
# 2208900                        <NA>       random locus integration
# 2208901                        <NA>       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                               <NA>        random locus integration
# 1                               <NA>        random locus integration
# 2                               <NA>        random locus integration
# 3                               <NA>        random locus integration
# 4                               <NA>        random locus integration
# ...                              ...                             ...
# 2208897                         <NA>        random locus integration
# 2208898                         <NA>        random locus integration
# 2208899                         <NA>        random locus integration
# 2208900                         <NA>        random locus integration
# 2208901                         <NA>        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                               <NA>  constitutive transgene expression
# 1                               <NA>  constitutive transgene expression
# 2                               <NA>  constitutive transgene expression
# 3                               <NA>  constitutive transgene expression
# 4                               <NA>  constitutive transgene expression
# ...                              ...                                ...
# 2208897                         <NA>  constitutive transgene expression
# 2208898                         <NA>  constitutive transgene expression
# 2208899                         <NA>  constitutive transgene expression
# 2208900                         <NA>  constitutive transgene expression
# 2208901                         <NA>  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                <NA>  constitutive transgene expression
# 1                                <NA>  constitutive transgene expression
# 2                                <NA>  constitutive transgene expression
# 3                                <NA>  constitutive transgene expression
# 4                                <NA>  constitutive transgene expression
# ...                               ...                                ...
# 2208897                          <NA>  constitutive transgene expression
# 2208898                          <NA>  constitutive transgene expression
# 2208899                          <NA>  constitutive transgene expression
# 2208900                          <NA>  constitutive transgene expression
# 2208901                          <NA>  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom        <NA>              <NA>               pooled
# 1             custom        <NA>              <NA>               pooled
# 2             custom        <NA>              <NA>               pooled
# 3             custom        <NA>              <NA>               pooled
# 4             custom        <NA>              <NA>               pooled
# ...              ...         ...               ...                  ...
# 2208897       custom        <NA>              <NA>               pooled
# 2208898       custom        <NA>              <NA>               pooled
# 2208899       custom        <NA>              <NA>               pooled
# 2208900       custom        <NA>              <NA>               pooled
# 2208901       custom        <NA>              <NA>               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                   <NA>             focused                         <NA>
# 1                   <NA>             focused                         <NA>
# 2                   <NA>             focused                         <NA>
# 3                   <NA>             focused                         <NA>
# 4                   <NA>             focused                         <NA>
# ...                  ...                 ...                          ...
# 2208897             <NA>             focused                         <NA>
# 2208898             <NA>             focused                         <NA>
# 2208899             <NA>             focused                         <NA>
# 2208900             <NA>             focused                         <NA>
# 2208901             <NA>             focused                         <NA>
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2208897                      inhibition           Marson lab
# 2208898                      inhibition           Marson lab
# 2208899                      inhibition           Marson lab
# 2208900                      inhibition           Marson lab
# 2208901                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2208897                             2                        2
# 2208898                             2                        2
# 2208899                             2                        2
# 2208900                             2                        2
# 2208901                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     24803                    <NA>                      <NA>
# 1                     24803                    <NA>                      <NA>
# 2                     24803                    <NA>                      <NA>
# 3                     24803                    <NA>                      <NA>
# 4                     24803                    <NA>                      <NA>
# ...                     ...                     ...                       ...
# 2208897               24803                    <NA>                      <NA>
# 2208898               24803                    <NA>                      <NA>
# 2208899               24803                    <NA>                      <NA>
# 2208900               24803                    <NA>                      <NA>
# 2208901               24803                    <NA>                      <NA>
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay            <NA>     transcriptomic
# 1             high-dimensional assay            <NA>     transcriptomic
# 2             high-dimensional assay            <NA>     transcriptomic
# 3             high-dimensional assay            <NA>     transcriptomic
# 4             high-dimensional assay            <NA>     transcriptomic
# ...                              ...             ...                ...
# 2208897       high-dimensional assay            <NA>     transcriptomic
# 2208898       high-dimensional assay            <NA>     transcriptomic
# 2208899       high-dimensional assay            <NA>     transcriptomic
# 2208900       high-dimensional assay            <NA>     transcriptomic
# 2208901       high-dimensional assay            <NA>     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                        <NA>      single-cell rna-seq           <NA>
# 1                        <NA>      single-cell rna-seq           <NA>
# 2                        <NA>      single-cell rna-seq           <NA>
# 3                        <NA>      single-cell rna-seq           <NA>
# 4                        <NA>      single-cell rna-seq           <NA>
# ...                       ...                      ...            ...
# 2208897                  <NA>      single-cell rna-seq           <NA>
# 2208898                  <NA>      single-cell rna-seq           <NA>
# 2208899                  <NA>      single-cell rna-seq           <NA>
# 2208900                  <NA>      single-cell rna-seq           <NA>
# 2208901                  <NA>      single-cell rna-seq           <NA>
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq       <NA>                      <NA>
# 1             Perturb-seq       <NA>                      <NA>
# 2             Perturb-seq       <NA>                      <NA>
# 3             Perturb-seq       <NA>                      <NA>
# 4             Perturb-seq       <NA>                      <NA>
# ...                   ...        ...                       ...
# 2208897       Perturb-seq       <NA>                      <NA>
# 2208898       Perturb-seq       <NA>                      <NA>
# 2208899       Perturb-seq       <NA>                      <NA>
# 2208900       Perturb-seq       <NA>                      <NA>
# 2208901       Perturb-seq       <NA>                      <NA>
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 1        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 3        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 4        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# ...                                              ...                    ...
# 2208897  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2208898  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2208899  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2208900  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2208901  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                   <NA>
# 1           Ultima Genomics UG100                   <NA>
# 2           Ultima Genomics UG100                   <NA>
# 3           Ultima Genomics UG100                   <NA>
# 4           Ultima Genomics UG100                   <NA>
# ...                           ...                    ...
# 2208897     Ultima Genomics UG100                   <NA>
# 2208898     Ultima Genomics UG100                   <NA>
# 2208899     Ultima Genomics UG100                   <NA>
# 2208900     Ultima Genomics UG100                   <NA>
# 2208901     Ultima Genomics UG100                   <NA>
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing               <NA>            CellRanger
# 1              barcode sequencing               <NA>            CellRanger
# 2              barcode sequencing               <NA>            CellRanger
# 3              barcode sequencing               <NA>            CellRanger
# 4              barcode sequencing               <NA>            CellRanger
# ...                           ...                ...                   ...
# 2208897        barcode sequencing               <NA>            CellRanger
# 2208898        barcode sequencing               <NA>            CellRanger
# 2208899        barcode sequencing               <NA>            CellRanger
# 2208900        barcode sequencing               <NA>            CellRanger
# 2208901        barcode sequencing               <NA>            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                       <NA>                  scanpy                 <NA>
# 1                       <NA>                  scanpy                 <NA>
# 2                       <NA>                  scanpy                 <NA>
# 3                       <NA>                  scanpy                 <NA>
# 4                       <NA>                  scanpy                 <NA>
# ...                      ...                     ...                  ...
# 2208897                 <NA>                  scanpy                 <NA>
# 2208898                 <NA>                  scanpy                 <NA>
# 2208899                 <NA>                  scanpy                 <NA>
# 2208900                 <NA>                  scanpy                 <NA>
# 2208901                 <NA>                  scanpy                 <NA>
#
#         reference_genome_id reference_genome_label  \
# 0                      <NA>                 GRCh38
# 1                      <NA>                 GRCh38
# 2                      <NA>                 GRCh38
# 3                      <NA>                 GRCh38
# 4                      <NA>                 GRCh38
# ...                     ...                    ...
# 2208897                <NA>                 GRCh38
# 2208898                <NA>                 GRCh38
# 2208899                <NA>                 GRCh38
# 2208900                <NA>                 GRCh38
# 2208901                <NA>                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2208897  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2208898  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2208899  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2208900  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2208901  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2208897  SWO:9000074
# 2208898  SWO:9000074
# 2208899  SWO:9000074
# 2208900  SWO:9000074
# 2208901  SWO:9000074
#
# [2208902 rows x 99 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ids",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# Missing Ensembl IDs: ['ENSG00000148362', 'CUSTOM001_PuroR', 'ENSG00000139656']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000148362': 'ENSG00000310560', 'ENSG00000139656': 'ENSG00000226519'}
# --------------------------------------------------
# Successfully mapped 18130 out of 18130 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# replace gene symbols that are NOT ENSG with original provided gene symbol
cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_symbol'] = cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_name']

# %%
cur_data.adata.var.loc[cur_data.adata.var['ensembl_gene_id'] == 'CUSTOM001_PuroR', 'ensembl_gene_id'] = None

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-02-18 10:59:03,521 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
#        ensembl_gene_id gene_symbol
# index
# 0                 None       PuroR
# 1      ENSG00000000003      TSPAN6
# 2      ENSG00000000005        TNMD
# 3      ENSG00000000419        DPM1
# 4      ENSG00000000457       SCYL3
# ...                ...         ...
# 18125  ENSG00000291110     TRIM16L
# 18126  ENSG00000291122    CASTOR3P
# 18127  ENSG00000291135     FCGR1BP
# 18128  ENSG00000291145     PPP5D1P
# 18129  ENSG00000291237        SOD2
#
# [18130 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data_h5ad()
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ... storing 'dataset_id' as categorical
# ... storing 'data_modality' as categorical
# ... storing 'significance_criteria' as categorical
# ... storing 'perturbed_target_coord' as categorical
# ... storing 'perturbed_target_chromosome' as categorical
# ... storing 'perturbed_target_ensg' as categorical
# ... storing 'perturbed_target_symbol' as categorical
# ... storing 'perturbed_target_biotype' as categorical
# ... storing 'guide_sequence' as categorical
# ... storing 'perturbation_type_label' as categorical
# ... storing 'perturbation_type_id' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'treatment_label' as categorical
# ... storing 'treatment_id' as categorical
# ... storing 'technical_replicate' as categorical
# ... storing 'biological_replicate' as categorical
# ... storing 'model_system_label' as categorical
# ... storing 'model_system_id' as categorical
# ... storing 'species' as categorical
# ... storing 'tissue_label' as categorical
# ... storing 'tissue_id' as categorical
# ... storing 'cell_type_label' as categorical
# ... storing 'cell_type_id' as categorical
# ... storing 'cell_line_label' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'sex_label' as categorical
# ... storing 'sex_id' as categorical
# ... storing 'developmental_stage_label' as categorical
# ... storing 'developmental_stage_id' as categorical
# ... storing 'disease_label' as categorical
# ... storing 'disease_id' as categorical
# ... storing 'study_title' as categorical
# ... storing 'study_uri' as categorical
# ... storing 'first_author' as categorical
# ... storing 'last_author' as categorical
# ... storing 'experiment_title' as categorical
# ... storing 'experiment_summary' as categorical
# ... storing 'number_of_perturbed_targets' as categorical
# ... storing 'number_of_perturbed_samples' as categorical
# ... storing 'library_generation_type_id' as categorical
# ... storing 'library_generation_type_label' as categorical
# ... storing 'library_generation_method_id' as categorical
# ... storing 'library_generation_method_label' as categorical
# ... storing 'enzyme_delivery_method_id' as categorical
# ... storing 'enzyme_delivery_method_label' as categorical
# ... storing 'library_delivery_method_id' as categorical
# ... storing 'library_delivery_method_label' as categorical
# ... storing 'enzyme_integration_state_id' as categorical
# ... storing 'enzyme_integration_state_label' as categorical
# ... storing 'library_integration_state_id' as categorical
# ... storing 'library_integration_state_label' as categorical
# ... storing 'enzyme_expression_control_id' as categorical
# ... storing 'enzyme_expression_control_label' as categorical
# ... storing 'library_expression_control_id' as categorical
# ... storing 'library_expression_control_label' as categorical
# ... storing 'library_name' as categorical
# ... storing 'library_uri' as categorical
# ... storing 'library_format_id' as categorical
# ... storing 'library_format_label' as categorical
# ... storing 'library_scope_id' as categorical
# ... storing 'library_scope_label' as categorical
# ... storing 'library_perturbation_type_id' as categorical
# ... storing 'library_perturbation_type_label' as categorical
# ... storing 'library_manufacturer' as categorical
# ... storing 'library_lentiviral_generation' as categorical
# ... storing 'library_grnas_per_target' as categorical
# ... storing 'library_total_grnas' as categorical
# ... storing 'readout_dimensionality_id' as categorical
# ... storing 'readout_dimensionality_label' as categorical
# ... storing 'readout_type_id' as categorical
# ... storing 'readout_type_label' as categorical
# ... storing 'readout_technology_id' as categorical
# ... storing 'readout_technology_label' as categorical
# ... storing 'method_name_id' as categorical
# ... storing 'method_name_label' as categorical
# ... storing 'method_uri' as categorical
# ... storing 'sequencing_library_kit_id' as categorical
# ... storing 'sequencing_library_kit_label' as categorical
# ... storing 'sequencing_platform_id' as categorical
# ... storing 'sequencing_platform_label' as categorical
# ... storing 'sequencing_strategy_id' as categorical
# ... storing 'sequencing_strategy_label' as categorical
# ... storing 'software_counts_id' as categorical
# ... storing 'software_counts_label' as categorical
# ... storing 'software_analysis_id' as categorical
# ... storing 'software_analysis_label' as categorical
# ... storing 'score_interpretation' as categorical
# ... storing 'reference_genome_id' as categorical
# ... storing 'reference_genome_label' as categorical
# ... storing 'associated_datasets' as categorical
# ... storing 'license_label' as categorical
# ... storing 'license_id' as categorical
# ... storing 'ensembl_gene_id' as categorical
# ... storing 'gene_symbol' as categorical
# ✅ Curated h5ad data saved to ../curated/h5ad/zhu_2025_D4_stim48hr_cl_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/zhu_2025_D4_stim48hr_cl_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
# upload_parquet_to_bq(
#     parquet_path='../curated/parquet/zhu_2025_D1_rest_cl_curated_metadata.parquet',
#     bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
#     bq_table_name='metadata',
#     key_columns=['dataset_id', 'sample_id'],
#     verbose=True
# )

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/zhu_2025_D4_stim48hr_cl_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
