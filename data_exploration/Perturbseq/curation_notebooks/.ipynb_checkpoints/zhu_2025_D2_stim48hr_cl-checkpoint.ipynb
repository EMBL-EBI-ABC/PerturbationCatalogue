# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)
# show all columns
pd.set_option('display.max_columns', None)
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/.venv/lib/python3.12/site-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# # Download data

# %% [markdown]
# Download the data from AWS as such:
#
# `!aws s3 cp --no-sign-request s3://genome-scale-tcell-perturb-seq/marson2025_data/{name_of_the_file}.h5ad ..aa/non_curated/h5ad/{name_of_the_file}.h5ad`

# %% [markdown]
# # Initialise the dataset object

# %%
noncurated_path = '../non_curated/h5ad/zhu_2025_D2_stim48hr_cl.h5ad'
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from ../non_curated/h5ad/zhu_2025_D1_stim48hr_cl.h5ad

# %%
cur_data.adata.obs
# Out:
#                                                        lane_id  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  CD4i_R2L38
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  CD4i_R2L38
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...  CD4i_R2L38
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  CD4i_R2L38
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...  CD4i_R2L38
# ...                                                        ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...  CD4i_R2L46
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  CD4i_R2L46
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  CD4i_R2L46
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  CD4i_R2L46
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  CD4i_R2L46
#
#                                                     n_genes_by_counts  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...               4142
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...               5232
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...               4886
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...               6017
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...                707
# ...                                                               ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...               2210
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               3809
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               4318
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               3165
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               6192
#
#                                                     total_counts  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...        9505.0
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...       14889.0
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...       12758.0
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...       22995.0
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...        1043.0
# ...                                                          ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...        4219.0
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        7672.0
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       11558.0
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        6554.0
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       25029.0
#
#                                                     pct_counts_mt  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...       0.789058
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...       0.067164
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...       1.841982
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...       0.365297
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...       0.000000
# ...                                                           ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...       0.142214
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       0.052138
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       0.510469
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       0.030516
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...       0.039954
#
#                                                     top_guide_UMI_counts  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...                  72.0
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...                 543.0
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...                 145.0
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...                 432.0
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...                 575.0
# ...                                                                  ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...                 189.0
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                   NaN
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                 164.0
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                 349.0
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                 502.0
#
#                                                       guide_id  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...     NTC-622
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...      IDH1-1
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...    FKBP14-2
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  HLA-DPA1-2
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...     SIN3B-2
# ...                                                        ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...    HIGD2A-1
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...         NaN
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...    HECTD3-1
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...      CLK2-2
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...     EP300-1
#
#                                                    perturbed_gene_name  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...                 NTC
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...                IDH1
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...              FKBP14
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...            HLA-DPA1
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...               SIN3B
# ...                                                                ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...              HIGD2A
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                 NaN
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...              HECTD3
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                CLK2
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               EP300
#
#                                                    perturbed_gene_id  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...               NTC
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...   ENSG00000138413
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...   ENSG00000106080
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...   ENSG00000231389
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...   ENSG00000127511
# ...                                                              ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...   ENSG00000146066
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...               NaN
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...   ENSG00000126107
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...   ENSG00000176444
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...   ENSG00000100393
#
#                                                        guide_type     PuroR  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  non-targeting  2.604399
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...      targeting  1.608901
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...      targeting  3.036213
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...      targeting  2.880512
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...      targeting  2.725601
# ...                                                           ...       ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...      targeting  2.610916
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...            NaN  0.000000
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...      targeting  3.570286
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...      targeting  1.958516
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...      targeting  3.316843
#
#                                                                guide_group  \
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...  targeting single sgRNA
# ...                                                                    ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...                no sgRNA
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...  targeting single sgRNA
#
#                                                     low_quality
# AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...        False
# AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...        False
# AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...        False
# AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38_CD4i_R2_D...        False
# AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38_CD4i_R2_D...        False
# ...                                                         ...
# TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46_CD4i_R2_D...        False
# TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        False
# TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        False
# TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        False
# TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46_CD4i_R2_D...        False
#
# [2805354 rows x 12 columns]

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Since for multi-guide perturbations the identities of said guides are unknown, we are filtering out these cells.

# %%
print(f"Number of cells before filtering: {cur_data.adata.n_obs}")
cur_data.adata = cur_data.adata[cur_data.adata.obs['guide_id'] != 'multi_sgRNA']
print(f"Number of cells after filtering: {cur_data.adata.n_obs}")
# Out:
# Number of cells before filtering: 2805354
# Number of cells after filtering: 2240829

# %% [markdown]
# ### Add `index` as `perturbation_name`

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]
cur_data.adata.obs['perturbation_name'] = cur_data.adata.obs['cell_barcode'] +'_'+cur_data.adata.obs['lane_id'].astype(str)
# Out:
# /tmp/ipykernel_1457522/2231587657.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'perturbation_name')

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv",
    dest_path="../supplementary/zhu_2025_guide_info.csv"
)
# read in the guide RNA info csv
guide_info_df = pd.read_csv("../supplementary/zhu_2025_guide_info.csv")

guide_info_df = guide_info_df[['sgRNA', 'seq']]

guide_info_df['sgRNA'] = guide_info_df['sgRNA'].str.replace('1-Jun','JUN-1').str.replace('2-Jun','JUN-2')

guide_info_df = guide_info_df.rename(columns={'seq': 'guide_sequence', 'sgRNA':'guide_id'})

guide_info_df
# Out:
# File ../supplementary/zhu_2025_guide_info.csv already exists. Skipping download.
#         guide_id        guide_sequence
# 0        ARMC5-1  CTGCCTCGCGCAGCTCGCGG
# 1         DDB1-1  GGAGTTCGCTGCGCGCTGTT
# 2       FNDC10-1  TGCCCGCTCCCCGCGATCCC
# 3         RORC-1  TCTGTGGGGCCCTGTCCATG
# 4      SLC35F6-1  GAACAGCTGGTACTTGGTCC
# ...          ...                   ...
# 26499    NTC-988  TTTCAGGCTACGGGCGCGGG
# 26500    NTC-989  TTTCCCATGATCATTTAGTG
# 26501    NTC-990  TTTCGCCCAAGAGGCTTGGG
# 26502    NTC-991  TTTCGTGCCGATGTAACACA
# 26503    NTC-992  TTTGGGTTTATCCGCCCCCA
#
# [26504 rows x 2 columns]

# %%
print("Number of overlapping guides with cur_data:")
cur_data.adata.obs['guide_id'].isin(guide_info_df['guide_id'].to_list()).value_counts()
# Out:
# Number of overlapping guides with cur_data:
# guide_id
# True     1663277
# False     577552
# Name: count, dtype: int64

# %%
# merge cur_data.adata.obs with guide_info_df
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='guide_id', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Number of missing guide sequences: 577552

# %%
cur_data.adata.obs
# Out:
#             lane_id  n_genes_by_counts  total_counts  pct_counts_mt  \
# 0        CD4i_R2L38               4142        9505.0       0.789058
# 1        CD4i_R2L38               5232       14889.0       0.067164
# 2        CD4i_R2L38               4886       12758.0       1.841982
# 3        CD4i_R2L38               6017       22995.0       0.365297
# 4        CD4i_R2L38                707        1043.0       0.000000
# ...             ...                ...           ...            ...
# 2240824  CD4i_R2L46               2210        4219.0       0.142214
# 2240825  CD4i_R2L46               3809        7672.0       0.052138
# 2240826  CD4i_R2L46               4318       11558.0       0.510469
# 2240827  CD4i_R2L46               3165        6554.0       0.030516
# 2240828  CD4i_R2L46               6192       25029.0       0.039954
#
#          top_guide_UMI_counts    guide_id perturbed_gene_name  \
# 0                        72.0     NTC-622                 NTC
# 1                       543.0      IDH1-1                IDH1
# 2                       145.0    FKBP14-2              FKBP14
# 3                       432.0  HLA-DPA1-2            HLA-DPA1
# 4                       575.0     SIN3B-2               SIN3B
# ...                       ...         ...                 ...
# 2240824                 189.0    HIGD2A-1              HIGD2A
# 2240825                   NaN         NaN                 NaN
# 2240826                 164.0    HECTD3-1              HECTD3
# 2240827                 349.0      CLK2-2                CLK2
# 2240828                 502.0     EP300-1               EP300
#
#         perturbed_gene_id     guide_type     PuroR             guide_group  \
# 0                     NTC  non-targeting  2.604399  targeting single sgRNA
# 1         ENSG00000138413      targeting  1.608901  targeting single sgRNA
# 2         ENSG00000106080      targeting  3.036213  targeting single sgRNA
# 3         ENSG00000231389      targeting  2.880512  targeting single sgRNA
# 4         ENSG00000127511      targeting  2.725601  targeting single sgRNA
# ...                   ...            ...       ...                     ...
# 2240824   ENSG00000146066      targeting  2.610916  targeting single sgRNA
# 2240825               NaN            NaN  0.000000                no sgRNA
# 2240826   ENSG00000126107      targeting  3.570286  targeting single sgRNA
# 2240827   ENSG00000176444      targeting  1.958516  targeting single sgRNA
# 2240828   ENSG00000100393      targeting  3.316843  targeting single sgRNA
#
#          low_quality                cell_barcode  \
# 0              False  AAACAAGCAACCCTATAACGGGAA-1
# 1              False  AAACAAGCAACTAAACAACGGGAA-1
# 2              False  AAACAAGCAACTAAACATGTTGAC-1
# 3              False  AAACAAGCAAGAAATGAACGGGAA-1
# 4              False  AAACAAGCAAGGCCATATGTTGAC-1
# ...              ...                         ...
# 2240824        False  TTTGTGAGTTTCGCCTATGTTGAC-1
# 2240825        False  TTTGTGAGTTTGACTAAACGGGAA-1
# 2240826        False  TTTGTGAGTTTGGCCAAACGGGAA-1
# 2240827        False  TTTGTGAGTTTGTCAAAACGGGAA-1
# 2240828        False  TTTGTGAGTTTGTTGAAACGGGAA-1
#
#                              perturbation_name        guide_sequence
# 0        AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38  ATTTAGTAATGCACACCCAG
# 1        AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38  ACTTCAGAAGCGGAGGCACT
# 2        AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38  GTGACCCTTGAGAAAAGAGT
# 3        AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38  TGAGCACAGGAACAGTGATG
# 4        AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38  GCGTGCGCCATGTCCGAAGT
# ...                                        ...                   ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46  GCGGGAGCAGCGGGTTTAGG
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46                   NaN
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46  TGGCGGAGGTGAGCACCTAG
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46  GCCGGAGACCGAGCTGGGAT
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46  AGCCTAGCACACAAACAAGA
#
# [2240829 rows x 15 columns]

# %%
# change perturbed_gene_id from categorical to string
cur_data.adata.obs['perturbed_gene_id'] = cur_data.adata.obs['perturbed_gene_id'].astype(str)
cur_data.adata.obs['perturbed_gene_name'] = cur_data.adata.obs['perturbed_gene_name'].astype(str)

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isin(['NTC']), 'perturbed_gene_id'] = 'control_nontargeting'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin(['NTC']), 'perturbed_gene_name'] = 'control_nontargeting'

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isna(), 'perturbed_gene_id'] = 'control_casonly'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isna(), 'perturbed_gene_name'] = 'control_casonly'

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_gene_id',
    input_column_type='ensembl_gene_id',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Missing Ensembl IDs: ['ENSG00000182230', 'U2AF1L5', 'ENSG00000148362', 'ENSG00000256618', 'AKAP2', 'ENSG00000277796', 'SMIM11B', 'SGK494', 'ENSG00000232196', 'LUZP6', 'OCLM', 'ENSG00000255823', 'SEPT6', 'ENSG00000203812']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000182230': nan, 'ENSG00000148362': 'ENSG00000310560', 'ENSG00000256618': nan, 'ENSG00000277796': 'ENSG00000293545', 'ENSG00000232196': nan, 'ENSG00000255823': nan, 'ENSG00000203812': 'ENSG00000288825'}
# --------------------------------------------------
# Successfully mapped 12171 out of 12171 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
cur_data.adata.obs
# Out:
#           perturbed_gene_name     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0        control_nontargeting  control_nontargeting                  72.0
# 1                        IDH1       ENSG00000138413                 543.0
# 2                      FKBP14       ENSG00000106080                 145.0
# 3                    HLA-DPA1       ENSG00000231389                 432.0
# 4                       SIN3B       ENSG00000127511                 575.0
# ...                       ...                   ...                   ...
# 2240824                HIGD2A       ENSG00000146066                 189.0
# 2240825       control_casonly       control_casonly                   NaN
# 2240826                HECTD3       ENSG00000126107                 164.0
# 2240827                  CLK2       ENSG00000176444                 349.0
# 2240828                 EP300       ENSG00000100393                 502.0
#
#             lane_id  pct_counts_mt    guide_id     guide_type  \
# index
# 0        CD4i_R2L38       0.789058     NTC-622  non-targeting
# 1        CD4i_R2L38       0.067164      IDH1-1      targeting
# 2        CD4i_R2L38       1.841982    FKBP14-2      targeting
# 3        CD4i_R2L38       0.365297  HLA-DPA1-2      targeting
# 4        CD4i_R2L38       0.000000     SIN3B-2      targeting
# ...             ...            ...         ...            ...
# 2240824  CD4i_R2L46       0.142214    HIGD2A-1      targeting
# 2240825  CD4i_R2L46       0.052138         NaN            NaN
# 2240826  CD4i_R2L46       0.510469    HECTD3-1      targeting
# 2240827  CD4i_R2L46       0.030516      CLK2-2      targeting
# 2240828  CD4i_R2L46       0.039954     EP300-1      targeting
#
#          n_genes_by_counts  low_quality  total_counts     PuroR  \
# index
# 0                     4142        False        9505.0  2.604399
# 1                     5232        False       14889.0  1.608901
# 2                     4886        False       12758.0  3.036213
# 3                     6017        False       22995.0  2.880512
# 4                      707        False        1043.0  2.725601
# ...                    ...          ...           ...       ...
# 2240824               2210        False        4219.0  2.610916
# 2240825               3809        False        7672.0  0.000000
# 2240826               4318        False       11558.0  3.570286
# 2240827               3165        False        6554.0  1.958516
# 2240828               6192        False       25029.0  3.316843
#
#                        cell_barcode        guide_sequence  \
# index
# 0        AAACAAGCAACCCTATAACGGGAA-1  ATTTAGTAATGCACACCCAG
# 1        AAACAAGCAACTAAACAACGGGAA-1  ACTTCAGAAGCGGAGGCACT
# 2        AAACAAGCAACTAAACATGTTGAC-1  GTGACCCTTGAGAAAAGAGT
# 3        AAACAAGCAAGAAATGAACGGGAA-1  TGAGCACAGGAACAGTGATG
# 4        AAACAAGCAAGGCCATATGTTGAC-1  GCGTGCGCCATGTCCGAAGT
# ...                             ...                   ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1  GCGGGAGCAGCGGGTTTAGG
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1                   NaN
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1  TGGCGGAGGTGAGCACCTAG
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1  GCCGGAGACCGAGCTGGGAT
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1  AGCCTAGCACACAAACAAGA
#
#                     guide_group                      perturbation_name  \
# index
# 0        targeting single sgRNA  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1        targeting single sgRNA  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2        targeting single sgRNA  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3        targeting single sgRNA  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4        targeting single sgRNA  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                         ...                                    ...
# 2240824  targeting single sgRNA  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                no sgRNA  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826  targeting single sgRNA  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827  targeting single sgRNA  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828  targeting single sgRNA  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#         perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825       control_casonly         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0           control_nontargeting         control_nontargeting
# 1                 protein_coding  chr2:208236224-208266095;-1
# 2                 protein_coding    chr7:30010587-30026702;-1
# 3                 protein_coding    chr6:33064569-33080781;-1
# 4                 protein_coding    chr19:16829387-16880355;1
# ...                          ...                          ...
# 2240824           protein_coding   chr5:176388751-176389761;1
# 2240825          control_casonly              control_casonly
# 2240826           protein_coding    chr1:45002540-45011369;-1
# 2240827           protein_coding  chr1:155262868-155278491;-1
# 2240828           protein_coding    chr22:41091816-41180077;1
#
#         perturbed_target_chromosome original_index
# index
# 0              control_nontargeting              0
# 1                                 2              1
# 2                                 7              2
# 3                                 6              3
# 4                                19              4
# ...                             ...            ...
# 2240824                           5        2240824
# 2240825             control_casonly        2240825
# 2240826                           1        2240826
# 2240827                           1        2240827
# 2240828                          22        2240828
#
# [2240829 rows x 21 columns]

# %% [markdown]
# # Manually replace some genes

# %%
# define genes to replace in the cur_data.adata.obs
genes_to_replace = cur_data.adata.obs[cur_data.adata.obs['perturbed_target_symbol'].isna()]['perturbed_gene_name'].drop_duplicates().to_list()
# define columns to replace
cols_to_replace = ['perturbed_target_ensg',	'perturbed_target_symbol',	'perturbed_target_biotype',	'perturbed_target_coord',	'perturbed_target_chromosome']
# define mapping dict for renaming columns in gene_ont for replacement
gene_ont_col_mapping = {
    'ensembl_gene_id':'perturbed_target_ensg',
    'gene_symbol':'perturbed_target_symbol',
    'biotype':'perturbed_target_biotype',
    'gene_coord':'perturbed_target_coord',
    'chromosome_name':'perturbed_target_chromosome'
}
# loop through genes and fill in the missing cols
for replacement_gene in genes_to_replace:
    if replacement_gene in cur_data.gene_ont['synonym'].values:
        # subset gene_ont and get values for replacement
        replacement = (
            cur_data.gene_ont.rename(columns=gene_ont_col_mapping)
            .loc[cur_data.gene_ont['synonym'].isin([replacement_gene]), cols_to_replace]
        )[cols_to_replace].values[0]
        # replace values in cur_data.adata.obs with the values from gene_ont
        cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin([replacement_gene]), cols_to_replace] = replacement
        print(f"Replaced {replacement_gene} with {replacement}")
    else:
        print(f"No replacement found for {replacement_gene}")
# Out:
# No replacement found for FAM153B
# Replaced SGK494 with ['ENSG00000167524' 'RSKR' 'protein_coding' 'chr17:28455752-28614197;-1'
#  '17']
# Replaced SEPT6 with ['ENSG00000125354' 'SEPTIN6' 'protein_coding'
#  'chrX:119615724-119693949;-1' 'X']
# No replacement found for MTRNR2L4
# No replacement found for MTRNR2L1
# No replacement found for OCLM
# No replacement found for AKAP2
# No replacement found for U2AF1L5
# No replacement found for SMIM11B
# No replacement found for CCL3L1
# No replacement found for LUZP6
# No replacement found for MTRNR2L8

# %%
# replace non-mapped perturbed_target_symbol with original gene symbols
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_target_symbol'] = cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_gene_name'].values

# %%
# replace entries in perturbed_target_ensg that are not ENSEMBL ids with NA
cur_data.adata.obs.loc[(~cur_data.adata.obs['perturbed_target_ensg'].str.startswith('ENSG')) & (cur_data.adata.obs['perturbed_target_ensg'] != 'control_nontargeting'), 'perturbed_target_ensg'] = pd.NA

# %%
cur_data.adata.obs
# Out:
#           perturbed_gene_name     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0        control_nontargeting  control_nontargeting                  72.0
# 1                        IDH1       ENSG00000138413                 543.0
# 2                      FKBP14       ENSG00000106080                 145.0
# 3                    HLA-DPA1       ENSG00000231389                 432.0
# 4                       SIN3B       ENSG00000127511                 575.0
# ...                       ...                   ...                   ...
# 2240824                HIGD2A       ENSG00000146066                 189.0
# 2240825       control_casonly       control_casonly                   NaN
# 2240826                HECTD3       ENSG00000126107                 164.0
# 2240827                  CLK2       ENSG00000176444                 349.0
# 2240828                 EP300       ENSG00000100393                 502.0
#
#             lane_id  pct_counts_mt    guide_id     guide_type  \
# index
# 0        CD4i_R2L38       0.789058     NTC-622  non-targeting
# 1        CD4i_R2L38       0.067164      IDH1-1      targeting
# 2        CD4i_R2L38       1.841982    FKBP14-2      targeting
# 3        CD4i_R2L38       0.365297  HLA-DPA1-2      targeting
# 4        CD4i_R2L38       0.000000     SIN3B-2      targeting
# ...             ...            ...         ...            ...
# 2240824  CD4i_R2L46       0.142214    HIGD2A-1      targeting
# 2240825  CD4i_R2L46       0.052138         NaN            NaN
# 2240826  CD4i_R2L46       0.510469    HECTD3-1      targeting
# 2240827  CD4i_R2L46       0.030516      CLK2-2      targeting
# 2240828  CD4i_R2L46       0.039954     EP300-1      targeting
#
#          n_genes_by_counts  low_quality  total_counts     PuroR  \
# index
# 0                     4142        False        9505.0  2.604399
# 1                     5232        False       14889.0  1.608901
# 2                     4886        False       12758.0  3.036213
# 3                     6017        False       22995.0  2.880512
# 4                      707        False        1043.0  2.725601
# ...                    ...          ...           ...       ...
# 2240824               2210        False        4219.0  2.610916
# 2240825               3809        False        7672.0  0.000000
# 2240826               4318        False       11558.0  3.570286
# 2240827               3165        False        6554.0  1.958516
# 2240828               6192        False       25029.0  3.316843
#
#                        cell_barcode        guide_sequence  \
# index
# 0        AAACAAGCAACCCTATAACGGGAA-1  ATTTAGTAATGCACACCCAG
# 1        AAACAAGCAACTAAACAACGGGAA-1  ACTTCAGAAGCGGAGGCACT
# 2        AAACAAGCAACTAAACATGTTGAC-1  GTGACCCTTGAGAAAAGAGT
# 3        AAACAAGCAAGAAATGAACGGGAA-1  TGAGCACAGGAACAGTGATG
# 4        AAACAAGCAAGGCCATATGTTGAC-1  GCGTGCGCCATGTCCGAAGT
# ...                             ...                   ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1  GCGGGAGCAGCGGGTTTAGG
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1                   NaN
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1  TGGCGGAGGTGAGCACCTAG
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1  GCCGGAGACCGAGCTGGGAT
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1  AGCCTAGCACACAAACAAGA
#
#                     guide_group                      perturbation_name  \
# index
# 0        targeting single sgRNA  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1        targeting single sgRNA  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2        targeting single sgRNA  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3        targeting single sgRNA  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4        targeting single sgRNA  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                         ...                                    ...
# 2240824  targeting single sgRNA  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                no sgRNA  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826  targeting single sgRNA  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827  targeting single sgRNA  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828  targeting single sgRNA  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#         perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825                   NaN         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0           control_nontargeting         control_nontargeting
# 1                 protein_coding  chr2:208236224-208266095;-1
# 2                 protein_coding    chr7:30010587-30026702;-1
# 3                 protein_coding    chr6:33064569-33080781;-1
# 4                 protein_coding    chr19:16829387-16880355;1
# ...                          ...                          ...
# 2240824           protein_coding   chr5:176388751-176389761;1
# 2240825          control_casonly              control_casonly
# 2240826           protein_coding    chr1:45002540-45011369;-1
# 2240827           protein_coding  chr1:155262868-155278491;-1
# 2240828           protein_coding    chr22:41091816-41180077;1
#
#         perturbed_target_chromosome original_index
# index
# 0              control_nontargeting              0
# 1                                 2              1
# 2                                 7              2
# 3                                 6              3
# 4                                19              4
# ...                             ...            ...
# 2240824                           5        2240824
# 2240825             control_casonly        2240825
# 2240826                           1        2240826
# 2240827                           1        2240827
# 2240828                          22        2240828
#
# [2240829 rows x 21 columns]

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
# cur_data.count_entries(
#     slot='obs',
#     input_column='perturbed_target_ensg',
#     count_column_name='perturbed_target_number',
#     sep='|'
# )
cur_data.adata.obs['perturbed_target_number'] = 1

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.adata.obs[['perturbation_name', 'perturbed_target_chromosome_encoding']]
# Out:
#                              perturbation_name  \
# index
# 0        AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1        AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2        AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3        AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4        AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                                        ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           2
# 2                                           7
# 3                                           6
# 4                                          19
# ...                                       ...
# 2240824                                     5
# 2240825                                     0
# 2240826                                     1
# 2240827                                     1
# 2240828                                    22
#
# [2240829 rows x 2 columns]

# %%
cur_data.adata.obs
# Out:
#           perturbed_gene_name     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0        control_nontargeting  control_nontargeting                  72.0
# 1                        IDH1       ENSG00000138413                 543.0
# 2                      FKBP14       ENSG00000106080                 145.0
# 3                    HLA-DPA1       ENSG00000231389                 432.0
# 4                       SIN3B       ENSG00000127511                 575.0
# ...                       ...                   ...                   ...
# 2240824                HIGD2A       ENSG00000146066                 189.0
# 2240825       control_casonly       control_casonly                   NaN
# 2240826                HECTD3       ENSG00000126107                 164.0
# 2240827                  CLK2       ENSG00000176444                 349.0
# 2240828                 EP300       ENSG00000100393                 502.0
#
#             lane_id  pct_counts_mt    guide_id     guide_type  \
# index
# 0        CD4i_R2L38       0.789058     NTC-622  non-targeting
# 1        CD4i_R2L38       0.067164      IDH1-1      targeting
# 2        CD4i_R2L38       1.841982    FKBP14-2      targeting
# 3        CD4i_R2L38       0.365297  HLA-DPA1-2      targeting
# 4        CD4i_R2L38       0.000000     SIN3B-2      targeting
# ...             ...            ...         ...            ...
# 2240824  CD4i_R2L46       0.142214    HIGD2A-1      targeting
# 2240825  CD4i_R2L46       0.052138         NaN            NaN
# 2240826  CD4i_R2L46       0.510469    HECTD3-1      targeting
# 2240827  CD4i_R2L46       0.030516      CLK2-2      targeting
# 2240828  CD4i_R2L46       0.039954     EP300-1      targeting
#
#          n_genes_by_counts  low_quality  total_counts     PuroR  \
# index
# 0                     4142        False        9505.0  2.604399
# 1                     5232        False       14889.0  1.608901
# 2                     4886        False       12758.0  3.036213
# 3                     6017        False       22995.0  2.880512
# 4                      707        False        1043.0  2.725601
# ...                    ...          ...           ...       ...
# 2240824               2210        False        4219.0  2.610916
# 2240825               3809        False        7672.0  0.000000
# 2240826               4318        False       11558.0  3.570286
# 2240827               3165        False        6554.0  1.958516
# 2240828               6192        False       25029.0  3.316843
#
#                        cell_barcode        guide_sequence  \
# index
# 0        AAACAAGCAACCCTATAACGGGAA-1  ATTTAGTAATGCACACCCAG
# 1        AAACAAGCAACTAAACAACGGGAA-1  ACTTCAGAAGCGGAGGCACT
# 2        AAACAAGCAACTAAACATGTTGAC-1  GTGACCCTTGAGAAAAGAGT
# 3        AAACAAGCAAGAAATGAACGGGAA-1  TGAGCACAGGAACAGTGATG
# 4        AAACAAGCAAGGCCATATGTTGAC-1  GCGTGCGCCATGTCCGAAGT
# ...                             ...                   ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1  GCGGGAGCAGCGGGTTTAGG
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1                   NaN
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1  TGGCGGAGGTGAGCACCTAG
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1  GCCGGAGACCGAGCTGGGAT
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1  AGCCTAGCACACAAACAAGA
#
#                     guide_group                      perturbation_name  \
# index
# 0        targeting single sgRNA  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1        targeting single sgRNA  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2        targeting single sgRNA  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3        targeting single sgRNA  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4        targeting single sgRNA  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                         ...                                    ...
# 2240824  targeting single sgRNA  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                no sgRNA  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826  targeting single sgRNA  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827  targeting single sgRNA  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828  targeting single sgRNA  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#         perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825                   NaN         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0           control_nontargeting         control_nontargeting
# 1                 protein_coding  chr2:208236224-208266095;-1
# 2                 protein_coding    chr7:30010587-30026702;-1
# 3                 protein_coding    chr6:33064569-33080781;-1
# 4                 protein_coding    chr19:16829387-16880355;1
# ...                          ...                          ...
# 2240824           protein_coding   chr5:176388751-176389761;1
# 2240825          control_casonly              control_casonly
# 2240826           protein_coding    chr1:45002540-45011369;-1
# 2240827           protein_coding  chr1:155262868-155278491;-1
# 2240828           protein_coding    chr22:41091816-41180077;1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0              control_nontargeting              0                        1
# 1                                 2              1                        1
# 2                                 7              2                        1
# 3                                 6              3                        1
# 4                                19              4                        1
# ...                             ...            ...                      ...
# 2240824                           5        2240824                        1
# 2240825             control_casonly        2240825                        1
# 2240826                           1        2240826                        1
# 2240827                           1        2240827                        1
# 2240828                          22        2240828                        1
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           2
# 2                                           7
# 3                                           6
# 4                                          19
# ...                                       ...
# 2240824                                     5
# 2240825                                     0
# 2240826                                     1
# 2240827                                     1
# 2240828                                    22
#
# [2240829 rows x 23 columns]

# %% [markdown]
# ### Curate replicates

# %%
cur_data.adata.obs = cur_data.adata.obs.rename(columns={'lane_id':'technical_replicate'})

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": "anti-CD3 antibody|anti-CD28 antibody|anti-CD2 antibody",
        "treatment_id": "EFO:0003317|EFO:0003304|NCIT:C184729",
        # replicates
        # "technical_replicate": None,
        "biological_replicate": "D2_CE0010866",
        # model system
        "model_system_label": "primary_cell",
        "model_system_id": None,
        "tissue": "lymphoid tissue",
        "cell_line_label": None,
        "cell_line_id": None,
        "cell_type_label": "CD4-positive, alpha-beta T cell",
        "disease_label": "healthy",
        "disease_id": None,

        "timepoint": "P14DT0H0M0S",
        "species": "Homo sapiens",
        "sex_label": "female",
        "sex_id": None,
        "developmental_stage_label": "adult",
        "developmental_stage_id": None,

        "study_title": "Genome-scale perturb-seq in primary human CD4+ T cells maps context-specific regulators of T cell programs and human immune traits",
        "study_uri": "https://doi.org/10.64898/2025.12.23.696273",
        "study_year": 2025,
        "first_author": "Ronghui Zhu",
        "last_author": "Alexander Marson",

        "experiment_title": "Perturb-seq of primary human CD4-positive T cells for patient D2_CE0010866, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator",
        "experiment_summary": """
            Isolated human CD4-positive cells from four healthy donors were stimulated with ImmunoCult CD3/CD28/CD2 activator and sequentially transduced with dCas9-KRAB-Zim3 lentivirus (next morning after stimulation) and a Perturb-seq guide library (next afternoon after stimulation, MOI 0.2).
            The library consisted all genes expressed in human CD4+ T cells, all transcription factors annotated in the Lambert et al. (2018) and non-targeting controls totalling 12,748 genes.
            The gRNA sequences were selected from hCRISPRiv2 and Dolcetto libraries.
            On day 12, cells were split into three conditions:
            (1) Rest - cells were left for 8 hr without stimulation;
            (2) Stim8hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 8 hr;
            (3) Stim48hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 48 hr.
            Cells were harvested, fixed, stored using GEM-X Flex Sample Preparation v2 Kit and sequenced using GEM-X Flex Gene Expression Human n-plex kit converted into Ultima compatible libraries for sequencing on the Ultima Genomics UG100.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_symbol'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB-Zim3",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Marson lab",
        "library_lentiviral_generation": "2",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "GEM-X Flex Gene Expression Human n-plex kit",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "scanpy",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",

        "license_label": "MIT License",
        "license_id": "SWO:9000074",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "Primary Human CD4+ T Cell Perturb-seq",
                "dataset_uri": "s3://genome-scale-tcell-perturb-seq/marson2025_data/D2_Stim48hr.assigned_guide.h5ad",
                "dataset_description": "Cell expression profiles for cells from donor D2_CE0010866, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator.",
                "dataset_file_name": "D2_Stim48hr.assigned_guide.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column biological_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_line_id added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column disease_id added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#           perturbed_gene_name     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0        control_nontargeting  control_nontargeting                  72.0
# 1                        IDH1       ENSG00000138413                 543.0
# 2                      FKBP14       ENSG00000106080                 145.0
# 3                    HLA-DPA1       ENSG00000231389                 432.0
# 4                       SIN3B       ENSG00000127511                 575.0
# ...                       ...                   ...                   ...
# 2240824                HIGD2A       ENSG00000146066                 189.0
# 2240825       control_casonly       control_casonly                   NaN
# 2240826                HECTD3       ENSG00000126107                 164.0
# 2240827                  CLK2       ENSG00000176444                 349.0
# 2240828                 EP300       ENSG00000100393                 502.0
#
#         technical_replicate  pct_counts_mt    guide_id     guide_type  \
# index
# 0                CD4i_R2L38       0.789058     NTC-622  non-targeting
# 1                CD4i_R2L38       0.067164      IDH1-1      targeting
# 2                CD4i_R2L38       1.841982    FKBP14-2      targeting
# 3                CD4i_R2L38       0.365297  HLA-DPA1-2      targeting
# 4                CD4i_R2L38       0.000000     SIN3B-2      targeting
# ...                     ...            ...         ...            ...
# 2240824          CD4i_R2L46       0.142214    HIGD2A-1      targeting
# 2240825          CD4i_R2L46       0.052138         NaN            NaN
# 2240826          CD4i_R2L46       0.510469    HECTD3-1      targeting
# 2240827          CD4i_R2L46       0.030516      CLK2-2      targeting
# 2240828          CD4i_R2L46       0.039954     EP300-1      targeting
#
#          n_genes_by_counts  low_quality  total_counts     PuroR  \
# index
# 0                     4142        False        9505.0  2.604399
# 1                     5232        False       14889.0  1.608901
# 2                     4886        False       12758.0  3.036213
# 3                     6017        False       22995.0  2.880512
# 4                      707        False        1043.0  2.725601
# ...                    ...          ...           ...       ...
# 2240824               2210        False        4219.0  2.610916
# 2240825               3809        False        7672.0  0.000000
# 2240826               4318        False       11558.0  3.570286
# 2240827               3165        False        6554.0  1.958516
# 2240828               6192        False       25029.0  3.316843
#
#                        cell_barcode        guide_sequence  \
# index
# 0        AAACAAGCAACCCTATAACGGGAA-1  ATTTAGTAATGCACACCCAG
# 1        AAACAAGCAACTAAACAACGGGAA-1  ACTTCAGAAGCGGAGGCACT
# 2        AAACAAGCAACTAAACATGTTGAC-1  GTGACCCTTGAGAAAAGAGT
# 3        AAACAAGCAAGAAATGAACGGGAA-1  TGAGCACAGGAACAGTGATG
# 4        AAACAAGCAAGGCCATATGTTGAC-1  GCGTGCGCCATGTCCGAAGT
# ...                             ...                   ...
# 2240824  TTTGTGAGTTTCGCCTATGTTGAC-1  GCGGGAGCAGCGGGTTTAGG
# 2240825  TTTGTGAGTTTGACTAAACGGGAA-1                   NaN
# 2240826  TTTGTGAGTTTGGCCAAACGGGAA-1  TGGCGGAGGTGAGCACCTAG
# 2240827  TTTGTGAGTTTGTCAAAACGGGAA-1  GCCGGAGACCGAGCTGGGAT
# 2240828  TTTGTGAGTTTGTTGAAACGGGAA-1  AGCCTAGCACACAAACAAGA
#
#                     guide_group                      perturbation_name  \
# index
# 0        targeting single sgRNA  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1        targeting single sgRNA  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2        targeting single sgRNA  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3        targeting single sgRNA  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4        targeting single sgRNA  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                         ...                                    ...
# 2240824  targeting single sgRNA  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                no sgRNA  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826  targeting single sgRNA  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827  targeting single sgRNA  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828  targeting single sgRNA  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#         perturbed_target_ensg perturbed_target_symbol  \
# index
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825                   NaN         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0           control_nontargeting         control_nontargeting
# 1                 protein_coding  chr2:208236224-208266095;-1
# 2                 protein_coding    chr7:30010587-30026702;-1
# 3                 protein_coding    chr6:33064569-33080781;-1
# 4                 protein_coding    chr19:16829387-16880355;1
# ...                          ...                          ...
# 2240824           protein_coding   chr5:176388751-176389761;1
# 2240825          control_casonly              control_casonly
# 2240826           protein_coding    chr1:45002540-45011369;-1
# 2240827           protein_coding  chr1:155262868-155278491;-1
# 2240828           protein_coding    chr22:41091816-41180077;1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0              control_nontargeting              0                        1
# 1                                 2              1                        1
# 2                                 7              2                        1
# 3                                 6              3                        1
# 4                                19              4                        1
# ...                             ...            ...                      ...
# 2240824                           5        2240824                        1
# 2240825             control_casonly        2240825                        1
# 2240826                           1        2240826                        1
# 2240827                           1        2240827                        1
# 2240828                          22        2240828                        1
#
#          perturbed_target_chromosome_encoding               dataset_id  \
# index
# 0                                           0  zhu_2025_D1_stim48hr_cl
# 1                                           2  zhu_2025_D1_stim48hr_cl
# 2                                           7  zhu_2025_D1_stim48hr_cl
# 3                                           6  zhu_2025_D1_stim48hr_cl
# 4                                          19  zhu_2025_D1_stim48hr_cl
# ...                                       ...                      ...
# 2240824                                     5  zhu_2025_D1_stim48hr_cl
# 2240825                                     0  zhu_2025_D1_stim48hr_cl
# 2240826                                     1  zhu_2025_D1_stim48hr_cl
# 2240827                                     1  zhu_2025_D1_stim48hr_cl
# 2240828                                    22  zhu_2025_D1_stim48hr_cl
#
#          sample_id perturbation_type_label perturbation_type_id data_modality  \
# index
# 0                1                 CRISPRi                 None   Perturb-seq
# 1                2                 CRISPRi                 None   Perturb-seq
# 2                3                 CRISPRi                 None   Perturb-seq
# 3                4                 CRISPRi                 None   Perturb-seq
# 4                5                 CRISPRi                 None   Perturb-seq
# ...            ...                     ...                  ...           ...
# 2240824    2240825                 CRISPRi                 None   Perturb-seq
# 2240825    2240826                 CRISPRi                 None   Perturb-seq
# 2240826    2240827                 CRISPRi                 None   Perturb-seq
# 2240827    2240828                 CRISPRi                 None   Perturb-seq
# 2240828    2240829                 CRISPRi                 None   Perturb-seq
#
#         significant significance_criteria score_interpretation  \
# index
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
# ...             ...                   ...                  ...
# 2240824        None                  None                 None
# 2240825        None                  None                 None
# 2240826        None                  None                 None
# 2240827        None                  None                 None
# 2240828        None                  None                 None
#
#                                            treatment_label  \
# index
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2240824  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240825  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240826  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240827  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240828  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id biological_replicate  \
# index
# 0        EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 1        EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 2        EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 3        EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 4        EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# ...                                       ...                  ...
# 2240824  EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 2240825  EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 2240826  EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 2240827  EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
# 2240828  EFO:0003317|EFO:0003304|NCIT:C184729         D1_CE0008162
#
#         model_system_label model_system_id           tissue cell_line_label  \
# index
# 0             primary_cell            None  lymphoid tissue            None
# 1             primary_cell            None  lymphoid tissue            None
# 2             primary_cell            None  lymphoid tissue            None
# 3             primary_cell            None  lymphoid tissue            None
# 4             primary_cell            None  lymphoid tissue            None
# ...                    ...             ...              ...             ...
# 2240824       primary_cell            None  lymphoid tissue            None
# 2240825       primary_cell            None  lymphoid tissue            None
# 2240826       primary_cell            None  lymphoid tissue            None
# 2240827       primary_cell            None  lymphoid tissue            None
# 2240828       primary_cell            None  lymphoid tissue            None
#
#         cell_line_id                  cell_type_label disease_label  \
# index
# 0               None  CD4-positive, alpha-beta T cell       healthy
# 1               None  CD4-positive, alpha-beta T cell       healthy
# 2               None  CD4-positive, alpha-beta T cell       healthy
# 3               None  CD4-positive, alpha-beta T cell       healthy
# 4               None  CD4-positive, alpha-beta T cell       healthy
# ...              ...                              ...           ...
# 2240824         None  CD4-positive, alpha-beta T cell       healthy
# 2240825         None  CD4-positive, alpha-beta T cell       healthy
# 2240826         None  CD4-positive, alpha-beta T cell       healthy
# 2240827         None  CD4-positive, alpha-beta T cell       healthy
# 2240828         None  CD4-positive, alpha-beta T cell       healthy
#
#         disease_id    timepoint       species sex_label sex_id  \
# index
# 0             None  P14DT0H0M0S  Homo sapiens    female   None
# 1             None  P14DT0H0M0S  Homo sapiens    female   None
# 2             None  P14DT0H0M0S  Homo sapiens    female   None
# 3             None  P14DT0H0M0S  Homo sapiens    female   None
# 4             None  P14DT0H0M0S  Homo sapiens    female   None
# ...            ...          ...           ...       ...    ...
# 2240824       None  P14DT0H0M0S  Homo sapiens    female   None
# 2240825       None  P14DT0H0M0S  Homo sapiens    female   None
# 2240826       None  P14DT0H0M0S  Homo sapiens    female   None
# 2240827       None  P14DT0H0M0S  Homo sapiens    female   None
# 2240828       None  P14DT0H0M0S  Homo sapiens    female   None
#
#         developmental_stage_label developmental_stage_id  \
# index
# 0                           adult                   None
# 1                           adult                   None
# 2                           adult                   None
# 3                           adult                   None
# 4                           adult                   None
# ...                           ...                    ...
# 2240824                     adult                   None
# 2240825                     adult                   None
# 2240826                     adult                   None
# 2240827                     adult                   None
# 2240828                     adult                   None
#
#                                                study_title  \
# index
# 0        Genome-scale perturb-seq in primary human CD4+...
# 1        Genome-scale perturb-seq in primary human CD4+...
# 2        Genome-scale perturb-seq in primary human CD4+...
# 3        Genome-scale perturb-seq in primary human CD4+...
# 4        Genome-scale perturb-seq in primary human CD4+...
# ...                                                    ...
# 2240824  Genome-scale perturb-seq in primary human CD4+...
# 2240825  Genome-scale perturb-seq in primary human CD4+...
# 2240826  Genome-scale perturb-seq in primary human CD4+...
# 2240827  Genome-scale perturb-seq in primary human CD4+...
# 2240828  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# index
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2240824  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240825  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240826  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240827  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240828  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# index
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2240824  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240825  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240826  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240827  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240828  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# index
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2240824  \n            Isolated human CD4-positive cell...
# 2240825  \n            Isolated human CD4-positive cell...
# 2240826  \n            Isolated human CD4-positive cell...
# 2240827  \n            Isolated human CD4-positive cell...
# 2240828  \n            Isolated human CD4-positive cell...
#
#          number_of_perturbed_targets  number_of_perturbed_samples  \
# index
# 0                              12171                      2240829
# 1                              12171                      2240829
# 2                              12171                      2240829
# 3                              12171                      2240829
# 4                              12171                      2240829
# ...                              ...                          ...
# 2240824                        12171                      2240829
# 2240825                        12171                      2240829
# 2240826                        12171                      2240829
# 2240827                        12171                      2240829
# 2240828                        12171                      2240829
#
#         library_generation_type_id library_generation_type_label  \
# index
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2240824                EFO:0022868                    endogenous
# 2240825                EFO:0022868                    endogenous
# 2240826                EFO:0022868                    endogenous
# 2240827                EFO:0022868                    endogenous
# 2240828                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# index
# 0                               None                 dCas9-KRAB-Zim3
# 1                               None                 dCas9-KRAB-Zim3
# 2                               None                 dCas9-KRAB-Zim3
# 3                               None                 dCas9-KRAB-Zim3
# 4                               None                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2240824                         None                 dCas9-KRAB-Zim3
# 2240825                         None                 dCas9-KRAB-Zim3
# 2240826                         None                 dCas9-KRAB-Zim3
# 2240827                         None                 dCas9-KRAB-Zim3
# 2240828                         None                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# index
# 0                            None      lentivirus transduction
# 1                            None      lentivirus transduction
# 2                            None      lentivirus transduction
# 3                            None      lentivirus transduction
# 4                            None      lentivirus transduction
# ...                           ...                          ...
# 2240824                      None      lentivirus transduction
# 2240825                      None      lentivirus transduction
# 2240826                      None      lentivirus transduction
# 2240827                      None      lentivirus transduction
# 2240828                      None      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# index
# 0                             None       lentivirus transduction
# 1                             None       lentivirus transduction
# 2                             None       lentivirus transduction
# 3                             None       lentivirus transduction
# 4                             None       lentivirus transduction
# ...                            ...                           ...
# 2240824                       None       lentivirus transduction
# 2240825                       None       lentivirus transduction
# 2240826                       None       lentivirus transduction
# 2240827                       None       lentivirus transduction
# 2240828                       None       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# index
# 0                              None       random locus integration
# 1                              None       random locus integration
# 2                              None       random locus integration
# 3                              None       random locus integration
# 4                              None       random locus integration
# ...                             ...                            ...
# 2240824                        None       random locus integration
# 2240825                        None       random locus integration
# 2240826                        None       random locus integration
# 2240827                        None       random locus integration
# 2240828                        None       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# index
# 0                               None        random locus integration
# 1                               None        random locus integration
# 2                               None        random locus integration
# 3                               None        random locus integration
# 4                               None        random locus integration
# ...                              ...                             ...
# 2240824                         None        random locus integration
# 2240825                         None        random locus integration
# 2240826                         None        random locus integration
# 2240827                         None        random locus integration
# 2240828                         None        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# index
# 0                               None  constitutive transgene expression
# 1                               None  constitutive transgene expression
# 2                               None  constitutive transgene expression
# 3                               None  constitutive transgene expression
# 4                               None  constitutive transgene expression
# ...                              ...                                ...
# 2240824                         None  constitutive transgene expression
# 2240825                         None  constitutive transgene expression
# 2240826                         None  constitutive transgene expression
# 2240827                         None  constitutive transgene expression
# 2240828                         None  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# index
# 0                                None  constitutive transgene expression
# 1                                None  constitutive transgene expression
# 2                                None  constitutive transgene expression
# 3                                None  constitutive transgene expression
# 4                                None  constitutive transgene expression
# ...                               ...                                ...
# 2240824                          None  constitutive transgene expression
# 2240825                          None  constitutive transgene expression
# 2240826                          None  constitutive transgene expression
# 2240827                          None  constitutive transgene expression
# 2240828                          None  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# index
# 0             custom        None              None               pooled
# 1             custom        None              None               pooled
# 2             custom        None              None               pooled
# 3             custom        None              None               pooled
# 4             custom        None              None               pooled
# ...              ...         ...               ...                  ...
# 2240824       custom        None              None               pooled
# 2240825       custom        None              None               pooled
# 2240826       custom        None              None               pooled
# 2240827       custom        None              None               pooled
# 2240828       custom        None              None               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# index
# 0                   None             focused                         None
# 1                   None             focused                         None
# 2                   None             focused                         None
# 3                   None             focused                         None
# 4                   None             focused                         None
# ...                  ...                 ...                          ...
# 2240824             None             focused                         None
# 2240825             None             focused                         None
# 2240826             None             focused                         None
# 2240827             None             focused                         None
# 2240828             None             focused                         None
#
#         library_perturbation_type_label library_manufacturer  \
# index
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2240824                      inhibition           Marson lab
# 2240825                      inhibition           Marson lab
# 2240826                      inhibition           Marson lab
# 2240827                      inhibition           Marson lab
# 2240828                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# index
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2240824                             2                        2
# 2240825                             2                        2
# 2240826                             2                        2
# 2240827                             2                        2
# 2240828                             2                        2
#
#         library_total_grnas library_total_variants readout_dimensionality_id  \
# index
# 0                     23876                   None                      None
# 1                     23876                   None                      None
# 2                     23876                   None                      None
# 3                     23876                   None                      None
# 4                     23876                   None                      None
# ...                     ...                    ...                       ...
# 2240824               23876                   None                      None
# 2240825               23876                   None                      None
# 2240826               23876                   None                      None
# 2240827               23876                   None                      None
# 2240828               23876                   None                      None
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# index
# 0             high-dimensional assay            None     transcriptomic
# 1             high-dimensional assay            None     transcriptomic
# 2             high-dimensional assay            None     transcriptomic
# 3             high-dimensional assay            None     transcriptomic
# 4             high-dimensional assay            None     transcriptomic
# ...                              ...             ...                ...
# 2240824       high-dimensional assay            None     transcriptomic
# 2240825       high-dimensional assay            None     transcriptomic
# 2240826       high-dimensional assay            None     transcriptomic
# 2240827       high-dimensional assay            None     transcriptomic
# 2240828       high-dimensional assay            None     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# index
# 0                        None      single-cell rna-seq           None
# 1                        None      single-cell rna-seq           None
# 2                        None      single-cell rna-seq           None
# 3                        None      single-cell rna-seq           None
# 4                        None      single-cell rna-seq           None
# ...                       ...                      ...            ...
# 2240824                  None      single-cell rna-seq           None
# 2240825                  None      single-cell rna-seq           None
# 2240826                  None      single-cell rna-seq           None
# 2240827                  None      single-cell rna-seq           None
# 2240828                  None      single-cell rna-seq           None
#
#         method_name_label method_uri sequencing_library_kit_id  \
# index
# 0             Perturb-seq       None                      None
# 1             Perturb-seq       None                      None
# 2             Perturb-seq       None                      None
# 3             Perturb-seq       None                      None
# 4             Perturb-seq       None                      None
# ...                   ...        ...                       ...
# 2240824       Perturb-seq       None                      None
# 2240825       Perturb-seq       None                      None
# 2240826       Perturb-seq       None                      None
# 2240827       Perturb-seq       None                      None
# 2240828       Perturb-seq       None                      None
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# index
# 0        GEM-X Flex Gene Expression Human n-plex kit                   None
# 1        GEM-X Flex Gene Expression Human n-plex kit                   None
# 2        GEM-X Flex Gene Expression Human n-plex kit                   None
# 3        GEM-X Flex Gene Expression Human n-plex kit                   None
# 4        GEM-X Flex Gene Expression Human n-plex kit                   None
# ...                                              ...                    ...
# 2240824  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2240825  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2240826  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2240827  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2240828  GEM-X Flex Gene Expression Human n-plex kit                   None
#
#         sequencing_platform_label sequencing_strategy_id  \
# index
# 0           Ultima Genomics UG100                   None
# 1           Ultima Genomics UG100                   None
# 2           Ultima Genomics UG100                   None
# 3           Ultima Genomics UG100                   None
# 4           Ultima Genomics UG100                   None
# ...                           ...                    ...
# 2240824     Ultima Genomics UG100                   None
# 2240825     Ultima Genomics UG100                   None
# 2240826     Ultima Genomics UG100                   None
# 2240827     Ultima Genomics UG100                   None
# 2240828     Ultima Genomics UG100                   None
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# index
# 0              barcode sequencing               None            CellRanger
# 1              barcode sequencing               None            CellRanger
# 2              barcode sequencing               None            CellRanger
# 3              barcode sequencing               None            CellRanger
# 4              barcode sequencing               None            CellRanger
# ...                           ...                ...                   ...
# 2240824        barcode sequencing               None            CellRanger
# 2240825        barcode sequencing               None            CellRanger
# 2240826        barcode sequencing               None            CellRanger
# 2240827        barcode sequencing               None            CellRanger
# 2240828        barcode sequencing               None            CellRanger
#
#         software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                       None                  scanpy                None
# 1                       None                  scanpy                None
# 2                       None                  scanpy                None
# 3                       None                  scanpy                None
# 4                       None                  scanpy                None
# ...                      ...                     ...                 ...
# 2240824                 None                  scanpy                None
# 2240825                 None                  scanpy                None
# 2240826                 None                  scanpy                None
# 2240827                 None                  scanpy                None
# 2240828                 None                  scanpy                None
#
#         reference_genome_label license_label   license_id  \
# index
# 0                       GRCh38   MIT License  SWO:9000074
# 1                       GRCh38   MIT License  SWO:9000074
# 2                       GRCh38   MIT License  SWO:9000074
# 3                       GRCh38   MIT License  SWO:9000074
# 4                       GRCh38   MIT License  SWO:9000074
# ...                        ...           ...          ...
# 2240824                 GRCh38   MIT License  SWO:9000074
# 2240825                 GRCh38   MIT License  SWO:9000074
# 2240826                 GRCh38   MIT License  SWO:9000074
# 2240827                 GRCh38   MIT License  SWO:9000074
# 2240828                 GRCh38   MIT License  SWO:9000074
#
#                                        associated_datasets
# index
# 0        [{"dataset_accession": "Primary Human CD4+ T C...
# 1        [{"dataset_accession": "Primary Human CD4+ T C...
# 2        [{"dataset_accession": "Primary Human CD4+ T C...
# 3        [{"dataset_accession": "Primary Human CD4+ T C...
# 4        [{"dataset_accession": "Primary Human CD4+ T C...
# ...                                                    ...
# 2240824  [{"dataset_accession": "Primary Human CD4+ T C...
# 2240825  [{"dataset_accession": "Primary Human CD4+ T C...
# 2240826  [{"dataset_accession": "Primary Human CD4+ T C...
# 2240827  [{"dataset_accession": "Primary Human CD4+ T C...
# 2240828  [{"dataset_accession": "Primary Human CD4+ T C...
#
# [2240829 rows x 110 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#       input_column input_column_lower       name_lower     ontology_id
# 0  lymphoid tissue    lymphoid tissue  lymphoid tissue  UBERON:0001744
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                       input_column               input_column_lower  \
# 0  CD4-positive, alpha-beta T cell  cd4-positive, alpha-beta t cell
#
#                         name_lower ontology_id
# 0  cd4-positive, alpha-beta t cell  CL:0000624
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Warning: No disease ontology terms could be mapped from `disease_label` column to ontology terms. Map the terms manually or check the input column for errors.

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-02-13 13:57:11,126 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
#                       dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D1_stim48hr_cl         1   Perturb-seq        <NA>
# 1        zhu_2025_D1_stim48hr_cl         2   Perturb-seq        <NA>
# 2        zhu_2025_D1_stim48hr_cl         3   Perturb-seq        <NA>
# 3        zhu_2025_D1_stim48hr_cl         4   Perturb-seq        <NA>
# 4        zhu_2025_D1_stim48hr_cl         5   Perturb-seq        <NA>
# ...                          ...       ...           ...         ...
# 2240824  zhu_2025_D1_stim48hr_cl   2240825   Perturb-seq        <NA>
# 2240825  zhu_2025_D1_stim48hr_cl   2240826   Perturb-seq        <NA>
# 2240826  zhu_2025_D1_stim48hr_cl   2240827   Perturb-seq        <NA>
# 2240827  zhu_2025_D1_stim48hr_cl   2240828   Perturb-seq        <NA>
# 2240828  zhu_2025_D1_stim48hr_cl   2240829   Perturb-seq        <NA>
#
#         significance_criteria                      perturbation_name  \
# 0                        <NA>  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1                        <NA>  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2                        <NA>  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3                        <NA>  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4                        <NA>  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                       ...                                    ...
# 2240824                  <NA>  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                  <NA>  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826                  <NA>  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827                  <NA>  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828                  <NA>  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#               perturbed_target_coord perturbed_target_chromosome  \
# 0               control_nontargeting        control_nontargeting
# 1        chr2:208236224-208266095;-1                           2
# 2          chr7:30010587-30026702;-1                           7
# 3          chr6:33064569-33080781;-1                           6
# 4          chr19:16829387-16880355;1                          19
# ...                              ...                         ...
# 2240824   chr5:176388751-176389761;1                           5
# 2240825              control_casonly             control_casonly
# 2240826    chr1:45002540-45011369;-1                           1
# 2240827  chr1:155262868-155278491;-1                           1
# 2240828    chr22:41091816-41180077;1                          22
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           0                        1
# 1                                           2                        1
# 2                                           7                        1
# 3                                           6                        1
# 4                                          19                        1
# ...                                       ...                      ...
# 2240824                                     5                        1
# 2240825                                     0                        1
# 2240826                                     1                        1
# 2240827                                     1                        1
# 2240828                                    22                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825                  <NA>         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype        guide_sequence  \
# 0           control_nontargeting  ATTTAGTAATGCACACCCAG
# 1                 protein_coding  ACTTCAGAAGCGGAGGCACT
# 2                 protein_coding  GTGACCCTTGAGAAAAGAGT
# 3                 protein_coding  TGAGCACAGGAACAGTGATG
# 4                 protein_coding  GCGTGCGCCATGTCCGAAGT
# ...                          ...                   ...
# 2240824           protein_coding  GCGGGAGCAGCGGGTTTAGG
# 2240825          control_casonly                  <NA>
# 2240826           protein_coding  TGGCGGAGGTGAGCACCTAG
# 2240827           protein_coding  GCCGGAGACCGAGCTGGGAT
# 2240828           protein_coding  AGCCTAGCACACAAACAAGA
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                 <NA>  P14DT0H0M0S
# 1                       CRISPRi                 <NA>  P14DT0H0M0S
# 2                       CRISPRi                 <NA>  P14DT0H0M0S
# 3                       CRISPRi                 <NA>  P14DT0H0M0S
# 4                       CRISPRi                 <NA>  P14DT0H0M0S
# ...                         ...                  ...          ...
# 2240824                 CRISPRi                 <NA>  P14DT0H0M0S
# 2240825                 CRISPRi                 <NA>  P14DT0H0M0S
# 2240826                 CRISPRi                 <NA>  P14DT0H0M0S
# 2240827                 CRISPRi                 <NA>  P14DT0H0M0S
# 2240828                 CRISPRi                 <NA>  P14DT0H0M0S
#
#                                            treatment_label  \
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2240824  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240825  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240826  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240827  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240828  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id technical_replicate  \
# 0        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 1        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 2        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 3        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 4        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# ...                                       ...                 ...
# 2240824  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240825  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240826  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240827  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240828  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 1               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 3               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 4               D1_CE0008162       primary_cell            <NA>  Homo sapiens
# ...                      ...                ...             ...           ...
# 2240824         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2240825         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2240826         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2240827         D1_CE0008162       primary_cell            <NA>  Homo sapiens
# 2240828         D1_CE0008162       primary_cell            <NA>  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2240824  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240825  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240826  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240827  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240828  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624            <NA>         <NA>    female   <NA>
# 1         CL:0000624            <NA>         <NA>    female   <NA>
# 2         CL:0000624            <NA>         <NA>    female   <NA>
# 3         CL:0000624            <NA>         <NA>    female   <NA>
# 4         CL:0000624            <NA>         <NA>    female   <NA>
# ...              ...             ...          ...       ...    ...
# 2240824   CL:0000624            <NA>         <NA>    female   <NA>
# 2240825   CL:0000624            <NA>         <NA>    female   <NA>
# 2240826   CL:0000624            <NA>         <NA>    female   <NA>
# 2240827   CL:0000624            <NA>         <NA>    female   <NA>
# 2240828   CL:0000624            <NA>         <NA>    female   <NA>
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                   <NA>       healthy
# 1                           adult                   <NA>       healthy
# 2                           adult                   <NA>       healthy
# 3                           adult                   <NA>       healthy
# 4                           adult                   <NA>       healthy
# ...                           ...                    ...           ...
# 2240824                     adult                   <NA>       healthy
# 2240825                     adult                   <NA>       healthy
# 2240826                     adult                   <NA>       healthy
# 2240827                     adult                   <NA>       healthy
# 2240828                     adult                   <NA>       healthy
#
#         disease_id                                        study_title  \
# 0             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 1             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 3             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 4             <NA>  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2240824       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2240825       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2240826       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2240827       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2240828       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2240824  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240825  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240826  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240827  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240828  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2240824  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240825  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240826  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240827  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240828  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2240824  \n            Isolated human CD4-positive cell...
# 2240825  \n            Isolated human CD4-positive cell...
# 2240826  \n            Isolated human CD4-positive cell...
# 2240827  \n            Isolated human CD4-positive cell...
# 2240828  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             12171                     2240829
# 1                             12171                     2240829
# 2                             12171                     2240829
# 3                             12171                     2240829
# 4                             12171                     2240829
# ...                             ...                         ...
# 2240824                       12171                     2240829
# 2240825                       12171                     2240829
# 2240826                       12171                     2240829
# 2240827                       12171                     2240829
# 2240828                       12171                     2240829
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2240824                EFO:0022868                    endogenous
# 2240825                EFO:0022868                    endogenous
# 2240826                EFO:0022868                    endogenous
# 2240827                EFO:0022868                    endogenous
# 2240828                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                               <NA>                 dCas9-KRAB-Zim3
# 1                               <NA>                 dCas9-KRAB-Zim3
# 2                               <NA>                 dCas9-KRAB-Zim3
# 3                               <NA>                 dCas9-KRAB-Zim3
# 4                               <NA>                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2240824                         <NA>                 dCas9-KRAB-Zim3
# 2240825                         <NA>                 dCas9-KRAB-Zim3
# 2240826                         <NA>                 dCas9-KRAB-Zim3
# 2240827                         <NA>                 dCas9-KRAB-Zim3
# 2240828                         <NA>                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                            <NA>      lentivirus transduction
# 1                            <NA>      lentivirus transduction
# 2                            <NA>      lentivirus transduction
# 3                            <NA>      lentivirus transduction
# 4                            <NA>      lentivirus transduction
# ...                           ...                          ...
# 2240824                      <NA>      lentivirus transduction
# 2240825                      <NA>      lentivirus transduction
# 2240826                      <NA>      lentivirus transduction
# 2240827                      <NA>      lentivirus transduction
# 2240828                      <NA>      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                             <NA>       lentivirus transduction
# 1                             <NA>       lentivirus transduction
# 2                             <NA>       lentivirus transduction
# 3                             <NA>       lentivirus transduction
# 4                             <NA>       lentivirus transduction
# ...                            ...                           ...
# 2240824                       <NA>       lentivirus transduction
# 2240825                       <NA>       lentivirus transduction
# 2240826                       <NA>       lentivirus transduction
# 2240827                       <NA>       lentivirus transduction
# 2240828                       <NA>       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                              <NA>       random locus integration
# 1                              <NA>       random locus integration
# 2                              <NA>       random locus integration
# 3                              <NA>       random locus integration
# 4                              <NA>       random locus integration
# ...                             ...                            ...
# 2240824                        <NA>       random locus integration
# 2240825                        <NA>       random locus integration
# 2240826                        <NA>       random locus integration
# 2240827                        <NA>       random locus integration
# 2240828                        <NA>       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                               <NA>        random locus integration
# 1                               <NA>        random locus integration
# 2                               <NA>        random locus integration
# 3                               <NA>        random locus integration
# 4                               <NA>        random locus integration
# ...                              ...                             ...
# 2240824                         <NA>        random locus integration
# 2240825                         <NA>        random locus integration
# 2240826                         <NA>        random locus integration
# 2240827                         <NA>        random locus integration
# 2240828                         <NA>        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                               <NA>  constitutive transgene expression
# 1                               <NA>  constitutive transgene expression
# 2                               <NA>  constitutive transgene expression
# 3                               <NA>  constitutive transgene expression
# 4                               <NA>  constitutive transgene expression
# ...                              ...                                ...
# 2240824                         <NA>  constitutive transgene expression
# 2240825                         <NA>  constitutive transgene expression
# 2240826                         <NA>  constitutive transgene expression
# 2240827                         <NA>  constitutive transgene expression
# 2240828                         <NA>  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                <NA>  constitutive transgene expression
# 1                                <NA>  constitutive transgene expression
# 2                                <NA>  constitutive transgene expression
# 3                                <NA>  constitutive transgene expression
# 4                                <NA>  constitutive transgene expression
# ...                               ...                                ...
# 2240824                          <NA>  constitutive transgene expression
# 2240825                          <NA>  constitutive transgene expression
# 2240826                          <NA>  constitutive transgene expression
# 2240827                          <NA>  constitutive transgene expression
# 2240828                          <NA>  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom        <NA>              <NA>               pooled
# 1             custom        <NA>              <NA>               pooled
# 2             custom        <NA>              <NA>               pooled
# 3             custom        <NA>              <NA>               pooled
# 4             custom        <NA>              <NA>               pooled
# ...              ...         ...               ...                  ...
# 2240824       custom        <NA>              <NA>               pooled
# 2240825       custom        <NA>              <NA>               pooled
# 2240826       custom        <NA>              <NA>               pooled
# 2240827       custom        <NA>              <NA>               pooled
# 2240828       custom        <NA>              <NA>               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                   <NA>             focused                         <NA>
# 1                   <NA>             focused                         <NA>
# 2                   <NA>             focused                         <NA>
# 3                   <NA>             focused                         <NA>
# 4                   <NA>             focused                         <NA>
# ...                  ...                 ...                          ...
# 2240824             <NA>             focused                         <NA>
# 2240825             <NA>             focused                         <NA>
# 2240826             <NA>             focused                         <NA>
# 2240827             <NA>             focused                         <NA>
# 2240828             <NA>             focused                         <NA>
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2240824                      inhibition           Marson lab
# 2240825                      inhibition           Marson lab
# 2240826                      inhibition           Marson lab
# 2240827                      inhibition           Marson lab
# 2240828                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2240824                             2                        2
# 2240825                             2                        2
# 2240826                             2                        2
# 2240827                             2                        2
# 2240828                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     23876                    <NA>                      <NA>
# 1                     23876                    <NA>                      <NA>
# 2                     23876                    <NA>                      <NA>
# 3                     23876                    <NA>                      <NA>
# 4                     23876                    <NA>                      <NA>
# ...                     ...                     ...                       ...
# 2240824               23876                    <NA>                      <NA>
# 2240825               23876                    <NA>                      <NA>
# 2240826               23876                    <NA>                      <NA>
# 2240827               23876                    <NA>                      <NA>
# 2240828               23876                    <NA>                      <NA>
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay            <NA>     transcriptomic
# 1             high-dimensional assay            <NA>     transcriptomic
# 2             high-dimensional assay            <NA>     transcriptomic
# 3             high-dimensional assay            <NA>     transcriptomic
# 4             high-dimensional assay            <NA>     transcriptomic
# ...                              ...             ...                ...
# 2240824       high-dimensional assay            <NA>     transcriptomic
# 2240825       high-dimensional assay            <NA>     transcriptomic
# 2240826       high-dimensional assay            <NA>     transcriptomic
# 2240827       high-dimensional assay            <NA>     transcriptomic
# 2240828       high-dimensional assay            <NA>     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                        <NA>      single-cell rna-seq           <NA>
# 1                        <NA>      single-cell rna-seq           <NA>
# 2                        <NA>      single-cell rna-seq           <NA>
# 3                        <NA>      single-cell rna-seq           <NA>
# 4                        <NA>      single-cell rna-seq           <NA>
# ...                       ...                      ...            ...
# 2240824                  <NA>      single-cell rna-seq           <NA>
# 2240825                  <NA>      single-cell rna-seq           <NA>
# 2240826                  <NA>      single-cell rna-seq           <NA>
# 2240827                  <NA>      single-cell rna-seq           <NA>
# 2240828                  <NA>      single-cell rna-seq           <NA>
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq       <NA>                      <NA>
# 1             Perturb-seq       <NA>                      <NA>
# 2             Perturb-seq       <NA>                      <NA>
# 3             Perturb-seq       <NA>                      <NA>
# 4             Perturb-seq       <NA>                      <NA>
# ...                   ...        ...                       ...
# 2240824       Perturb-seq       <NA>                      <NA>
# 2240825       Perturb-seq       <NA>                      <NA>
# 2240826       Perturb-seq       <NA>                      <NA>
# 2240827       Perturb-seq       <NA>                      <NA>
# 2240828       Perturb-seq       <NA>                      <NA>
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 1        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 3        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 4        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# ...                                              ...                    ...
# 2240824  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2240825  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2240826  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2240827  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2240828  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                   <NA>
# 1           Ultima Genomics UG100                   <NA>
# 2           Ultima Genomics UG100                   <NA>
# 3           Ultima Genomics UG100                   <NA>
# 4           Ultima Genomics UG100                   <NA>
# ...                           ...                    ...
# 2240824     Ultima Genomics UG100                   <NA>
# 2240825     Ultima Genomics UG100                   <NA>
# 2240826     Ultima Genomics UG100                   <NA>
# 2240827     Ultima Genomics UG100                   <NA>
# 2240828     Ultima Genomics UG100                   <NA>
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing               <NA>            CellRanger
# 1              barcode sequencing               <NA>            CellRanger
# 2              barcode sequencing               <NA>            CellRanger
# 3              barcode sequencing               <NA>            CellRanger
# 4              barcode sequencing               <NA>            CellRanger
# ...                           ...                ...                   ...
# 2240824        barcode sequencing               <NA>            CellRanger
# 2240825        barcode sequencing               <NA>            CellRanger
# 2240826        barcode sequencing               <NA>            CellRanger
# 2240827        barcode sequencing               <NA>            CellRanger
# 2240828        barcode sequencing               <NA>            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                       <NA>                  scanpy                 <NA>
# 1                       <NA>                  scanpy                 <NA>
# 2                       <NA>                  scanpy                 <NA>
# 3                       <NA>                  scanpy                 <NA>
# 4                       <NA>                  scanpy                 <NA>
# ...                      ...                     ...                  ...
# 2240824                 <NA>                  scanpy                 <NA>
# 2240825                 <NA>                  scanpy                 <NA>
# 2240826                 <NA>                  scanpy                 <NA>
# 2240827                 <NA>                  scanpy                 <NA>
# 2240828                 <NA>                  scanpy                 <NA>
#
#         reference_genome_id reference_genome_label  \
# 0                      <NA>                 GRCh38
# 1                      <NA>                 GRCh38
# 2                      <NA>                 GRCh38
# 3                      <NA>                 GRCh38
# 4                      <NA>                 GRCh38
# ...                     ...                    ...
# 2240824                <NA>                 GRCh38
# 2240825                <NA>                 GRCh38
# 2240826                <NA>                 GRCh38
# 2240827                <NA>                 GRCh38
# 2240828                <NA>                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2240824  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240825  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240826  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240827  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240828  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2240824  SWO:9000074
# 2240825  SWO:9000074
# 2240826  SWO:9000074
# 2240827  SWO:9000074
# 2240828  SWO:9000074
#
# [2240829 rows x 99 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ids",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# Missing Ensembl IDs: ['ENSG00000148362', 'CUSTOM001_PuroR', 'ENSG00000139656']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000148362': 'ENSG00000310560', 'ENSG00000139656': 'ENSG00000226519'}
# --------------------------------------------------
# Successfully mapped 18130 out of 18130 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# replace gene symbols that are NOT ENSG with original provided gene symbol
cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_symbol'] = cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_name']

# %%
cur_data.adata.var.loc[cur_data.adata.var['ensembl_gene_id'] == 'CUSTOM001_PuroR', 'ensembl_gene_id'] = None

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-02-13 14:01:11,510 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
#        ensembl_gene_id gene_symbol
# index
# 0                  NaN       PuroR
# 1      ENSG00000000003      TSPAN6
# 2      ENSG00000000005        TNMD
# 3      ENSG00000000419        DPM1
# 4      ENSG00000000457       SCYL3
# ...                ...         ...
# 18125  ENSG00000291110     TRIM16L
# 18126  ENSG00000291122    CASTOR3P
# 18127  ENSG00000291135     FCGR1BP
# 18128  ENSG00000291145     PPP5D1P
# 18129  ENSG00000291237        SOD2
#
# [18130 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
import pandas as pd
import numpy as np

def clean_adata_for_h5ad(adata):
    """
    Fixed cleaning function.
    Ensures that columns converted to Categorical during the process
    are immediately checked for Arrow-backed categories.
    """
    for attr in ['obs', 'var']:
        df = getattr(adata, attr)

        # 1. Fix Index
        if hasattr(df.index, "dtype") and ("arrow" in str(df.index.dtype).lower() or isinstance(df.index.dtype, pd.StringDtype)):
            df.index = df.index.astype("object")

        for col in df.columns:
            # 2. Fix Arrow Strings -> Object
            # (Do this first so we can check for NaNs properly)
            if "arrow" in str(df[col].dtype).lower() or isinstance(df[col].dtype, pd.StringDtype):
                df[col] = df[col].astype("object")

            # 3. Fix Object w/ NaNs -> Category
            # (h5py cannot write object columns with NaNs)
            if df[col].dtype == "object" and df[col].isnull().any():
                df[col] = df[col].astype("category")

            # 4. Fix Categorical Registry (The "Final Sweep")
            # We check this LAST. Whether it started as categorical or BECAME categorical 
            # in step 3, we must ensure the lookup table (categories) is not Arrow.
            if isinstance(df[col].dtype, pd.CategoricalDtype):
                if df[col].cat.categories.dtype != "object":
                    print(f"[{attr}] Fixing Arrow categories in '{col}'")
                    try:
                        new_cats = df[col].cat.categories.astype("object")
                        df[col] = df[col].cat.rename_categories(new_cats)
                    except Exception as e:
                        print(f"Could not fix {col}: {e}")

    return adata

# --- Apply & Save ---
clean_adata_for_h5ad(cur_data.adata)
# cur_data.adata.write_h5ad("fixed_data.h5ad")
# Out:
# Cleaning obs...
# Cleaning var...

# %%
cur_data.adata.obs['dataset_id'].dtype
# Out:
# CategoricalDtype(categories=['zhu_2025_D1_stim48hr_cl'], ordered=False, categories_dtype=object)

# %%
cur_data.adata.obs['significant'].dtype
# Out:
# CategoricalDtype(categories=[], ordered=False, categories_dtype=object)

# %%
cur_data.adata.obs['significant']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 2240824    NaN
# 2240825    NaN
# 2240826    NaN
# 2240827    NaN
# 2240828    NaN
# Name: significant, Length: 2240829, dtype: category
# Categories (0, object): []

# %%
cur_data.adata.obs
# Out:
#                       dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D1_stim48hr_cl         1   Perturb-seq         NaN
# 1        zhu_2025_D1_stim48hr_cl         2   Perturb-seq         NaN
# 2        zhu_2025_D1_stim48hr_cl         3   Perturb-seq         NaN
# 3        zhu_2025_D1_stim48hr_cl         4   Perturb-seq         NaN
# 4        zhu_2025_D1_stim48hr_cl         5   Perturb-seq         NaN
# ...                          ...       ...           ...         ...
# 2240824  zhu_2025_D1_stim48hr_cl   2240825   Perturb-seq         NaN
# 2240825  zhu_2025_D1_stim48hr_cl   2240826   Perturb-seq         NaN
# 2240826  zhu_2025_D1_stim48hr_cl   2240827   Perturb-seq         NaN
# 2240827  zhu_2025_D1_stim48hr_cl   2240828   Perturb-seq         NaN
# 2240828  zhu_2025_D1_stim48hr_cl   2240829   Perturb-seq         NaN
#
#         significance_criteria                      perturbation_name  \
# 0                         NaN  AAACAAGCAACCCTATAACGGGAA-1_CD4i_R2L38
# 1                         NaN  AAACAAGCAACTAAACAACGGGAA-1_CD4i_R2L38
# 2                         NaN  AAACAAGCAACTAAACATGTTGAC-1_CD4i_R2L38
# 3                         NaN  AAACAAGCAAGAAATGAACGGGAA-1_CD4i_R2L38
# 4                         NaN  AAACAAGCAAGGCCATATGTTGAC-1_CD4i_R2L38
# ...                       ...                                    ...
# 2240824                   NaN  TTTGTGAGTTTCGCCTATGTTGAC-1_CD4i_R2L46
# 2240825                   NaN  TTTGTGAGTTTGACTAAACGGGAA-1_CD4i_R2L46
# 2240826                   NaN  TTTGTGAGTTTGGCCAAACGGGAA-1_CD4i_R2L46
# 2240827                   NaN  TTTGTGAGTTTGTCAAAACGGGAA-1_CD4i_R2L46
# 2240828                   NaN  TTTGTGAGTTTGTTGAAACGGGAA-1_CD4i_R2L46
#
#               perturbed_target_coord perturbed_target_chromosome  \
# 0               control_nontargeting        control_nontargeting
# 1        chr2:208236224-208266095;-1                           2
# 2          chr7:30010587-30026702;-1                           7
# 3          chr6:33064569-33080781;-1                           6
# 4          chr19:16829387-16880355;1                          19
# ...                              ...                         ...
# 2240824   chr5:176388751-176389761;1                           5
# 2240825              control_casonly             control_casonly
# 2240826    chr1:45002540-45011369;-1                           1
# 2240827  chr1:155262868-155278491;-1                           1
# 2240828    chr22:41091816-41180077;1                          22
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           0                        1
# 1                                           2                        1
# 2                                           7                        1
# 3                                           6                        1
# 4                                          19                        1
# ...                                       ...                      ...
# 2240824                                     5                        1
# 2240825                                     0                        1
# 2240826                                     1                        1
# 2240827                                     1                        1
# 2240828                                    22                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0        control_nontargeting    control_nontargeting
# 1             ENSG00000138413                    IDH1
# 2             ENSG00000106080                  FKBP14
# 3             ENSG00000231389                HLA-DPA1
# 4             ENSG00000127511                   SIN3B
# ...                       ...                     ...
# 2240824       ENSG00000146066                  HIGD2A
# 2240825                   NaN         control_casonly
# 2240826       ENSG00000126107                  HECTD3
# 2240827       ENSG00000176444                    CLK2
# 2240828       ENSG00000100393                   EP300
#
#         perturbed_target_biotype        guide_sequence  \
# 0           control_nontargeting  ATTTAGTAATGCACACCCAG
# 1                 protein_coding  ACTTCAGAAGCGGAGGCACT
# 2                 protein_coding  GTGACCCTTGAGAAAAGAGT
# 3                 protein_coding  TGAGCACAGGAACAGTGATG
# 4                 protein_coding  GCGTGCGCCATGTCCGAAGT
# ...                          ...                   ...
# 2240824           protein_coding  GCGGGAGCAGCGGGTTTAGG
# 2240825          control_casonly                   NaN
# 2240826           protein_coding  TGGCGGAGGTGAGCACCTAG
# 2240827           protein_coding  GCCGGAGACCGAGCTGGGAT
# 2240828           protein_coding  AGCCTAGCACACAAACAAGA
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                  NaN  P14DT0H0M0S
# 1                       CRISPRi                  NaN  P14DT0H0M0S
# 2                       CRISPRi                  NaN  P14DT0H0M0S
# 3                       CRISPRi                  NaN  P14DT0H0M0S
# 4                       CRISPRi                  NaN  P14DT0H0M0S
# ...                         ...                  ...          ...
# 2240824                 CRISPRi                  NaN  P14DT0H0M0S
# 2240825                 CRISPRi                  NaN  P14DT0H0M0S
# 2240826                 CRISPRi                  NaN  P14DT0H0M0S
# 2240827                 CRISPRi                  NaN  P14DT0H0M0S
# 2240828                 CRISPRi                  NaN  P14DT0H0M0S
#
#                                            treatment_label  \
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2240824  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240825  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240826  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240827  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2240828  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id technical_replicate  \
# 0        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 1        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 2        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 3        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# 4        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L38
# ...                                       ...                 ...
# 2240824  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240825  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240826  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240827  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
# 2240828  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L46
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 1               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 3               D1_CE0008162       primary_cell             NaN  Homo sapiens
# 4               D1_CE0008162       primary_cell             NaN  Homo sapiens
# ...                      ...                ...             ...           ...
# 2240824         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2240825         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2240826         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2240827         D1_CE0008162       primary_cell             NaN  Homo sapiens
# 2240828         D1_CE0008162       primary_cell             NaN  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2240824  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240825  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240826  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240827  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2240828  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624             NaN          NaN    female    NaN
# 1         CL:0000624             NaN          NaN    female    NaN
# 2         CL:0000624             NaN          NaN    female    NaN
# 3         CL:0000624             NaN          NaN    female    NaN
# 4         CL:0000624             NaN          NaN    female    NaN
# ...              ...             ...          ...       ...    ...
# 2240824   CL:0000624             NaN          NaN    female    NaN
# 2240825   CL:0000624             NaN          NaN    female    NaN
# 2240826   CL:0000624             NaN          NaN    female    NaN
# 2240827   CL:0000624             NaN          NaN    female    NaN
# 2240828   CL:0000624             NaN          NaN    female    NaN
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                    NaN       healthy
# 1                           adult                    NaN       healthy
# 2                           adult                    NaN       healthy
# 3                           adult                    NaN       healthy
# 4                           adult                    NaN       healthy
# ...                           ...                    ...           ...
# 2240824                     adult                    NaN       healthy
# 2240825                     adult                    NaN       healthy
# 2240826                     adult                    NaN       healthy
# 2240827                     adult                    NaN       healthy
# 2240828                     adult                    NaN       healthy
#
#         disease_id                                        study_title  \
# 0              NaN  Genome-scale perturb-seq in primary human CD4+...
# 1              NaN  Genome-scale perturb-seq in primary human CD4+...
# 2              NaN  Genome-scale perturb-seq in primary human CD4+...
# 3              NaN  Genome-scale perturb-seq in primary human CD4+...
# 4              NaN  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2240824        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2240825        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2240826        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2240827        NaN  Genome-scale perturb-seq in primary human CD4+...
# 2240828        NaN  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2240824  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240825  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240826  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240827  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2240828  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2240824  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240825  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240826  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240827  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2240828  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2240824  \n            Isolated human CD4-positive cell...
# 2240825  \n            Isolated human CD4-positive cell...
# 2240826  \n            Isolated human CD4-positive cell...
# 2240827  \n            Isolated human CD4-positive cell...
# 2240828  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             12171                     2240829
# 1                             12171                     2240829
# 2                             12171                     2240829
# 3                             12171                     2240829
# 4                             12171                     2240829
# ...                             ...                         ...
# 2240824                       12171                     2240829
# 2240825                       12171                     2240829
# 2240826                       12171                     2240829
# 2240827                       12171                     2240829
# 2240828                       12171                     2240829
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2240824                EFO:0022868                    endogenous
# 2240825                EFO:0022868                    endogenous
# 2240826                EFO:0022868                    endogenous
# 2240827                EFO:0022868                    endogenous
# 2240828                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                                NaN                 dCas9-KRAB-Zim3
# 1                                NaN                 dCas9-KRAB-Zim3
# 2                                NaN                 dCas9-KRAB-Zim3
# 3                                NaN                 dCas9-KRAB-Zim3
# 4                                NaN                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2240824                          NaN                 dCas9-KRAB-Zim3
# 2240825                          NaN                 dCas9-KRAB-Zim3
# 2240826                          NaN                 dCas9-KRAB-Zim3
# 2240827                          NaN                 dCas9-KRAB-Zim3
# 2240828                          NaN                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                             NaN      lentivirus transduction
# 1                             NaN      lentivirus transduction
# 2                             NaN      lentivirus transduction
# 3                             NaN      lentivirus transduction
# 4                             NaN      lentivirus transduction
# ...                           ...                          ...
# 2240824                       NaN      lentivirus transduction
# 2240825                       NaN      lentivirus transduction
# 2240826                       NaN      lentivirus transduction
# 2240827                       NaN      lentivirus transduction
# 2240828                       NaN      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                              NaN       lentivirus transduction
# 1                              NaN       lentivirus transduction
# 2                              NaN       lentivirus transduction
# 3                              NaN       lentivirus transduction
# 4                              NaN       lentivirus transduction
# ...                            ...                           ...
# 2240824                        NaN       lentivirus transduction
# 2240825                        NaN       lentivirus transduction
# 2240826                        NaN       lentivirus transduction
# 2240827                        NaN       lentivirus transduction
# 2240828                        NaN       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                               NaN       random locus integration
# 1                               NaN       random locus integration
# 2                               NaN       random locus integration
# 3                               NaN       random locus integration
# 4                               NaN       random locus integration
# ...                             ...                            ...
# 2240824                         NaN       random locus integration
# 2240825                         NaN       random locus integration
# 2240826                         NaN       random locus integration
# 2240827                         NaN       random locus integration
# 2240828                         NaN       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                                NaN        random locus integration
# 1                                NaN        random locus integration
# 2                                NaN        random locus integration
# 3                                NaN        random locus integration
# 4                                NaN        random locus integration
# ...                              ...                             ...
# 2240824                          NaN        random locus integration
# 2240825                          NaN        random locus integration
# 2240826                          NaN        random locus integration
# 2240827                          NaN        random locus integration
# 2240828                          NaN        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                                NaN  constitutive transgene expression
# 1                                NaN  constitutive transgene expression
# 2                                NaN  constitutive transgene expression
# 3                                NaN  constitutive transgene expression
# 4                                NaN  constitutive transgene expression
# ...                              ...                                ...
# 2240824                          NaN  constitutive transgene expression
# 2240825                          NaN  constitutive transgene expression
# 2240826                          NaN  constitutive transgene expression
# 2240827                          NaN  constitutive transgene expression
# 2240828                          NaN  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                 NaN  constitutive transgene expression
# 1                                 NaN  constitutive transgene expression
# 2                                 NaN  constitutive transgene expression
# 3                                 NaN  constitutive transgene expression
# 4                                 NaN  constitutive transgene expression
# ...                               ...                                ...
# 2240824                           NaN  constitutive transgene expression
# 2240825                           NaN  constitutive transgene expression
# 2240826                           NaN  constitutive transgene expression
# 2240827                           NaN  constitutive transgene expression
# 2240828                           NaN  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom         NaN               NaN               pooled
# 1             custom         NaN               NaN               pooled
# 2             custom         NaN               NaN               pooled
# 3             custom         NaN               NaN               pooled
# 4             custom         NaN               NaN               pooled
# ...              ...         ...               ...                  ...
# 2240824       custom         NaN               NaN               pooled
# 2240825       custom         NaN               NaN               pooled
# 2240826       custom         NaN               NaN               pooled
# 2240827       custom         NaN               NaN               pooled
# 2240828       custom         NaN               NaN               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                    NaN             focused                          NaN
# 1                    NaN             focused                          NaN
# 2                    NaN             focused                          NaN
# 3                    NaN             focused                          NaN
# 4                    NaN             focused                          NaN
# ...                  ...                 ...                          ...
# 2240824              NaN             focused                          NaN
# 2240825              NaN             focused                          NaN
# 2240826              NaN             focused                          NaN
# 2240827              NaN             focused                          NaN
# 2240828              NaN             focused                          NaN
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2240824                      inhibition           Marson lab
# 2240825                      inhibition           Marson lab
# 2240826                      inhibition           Marson lab
# 2240827                      inhibition           Marson lab
# 2240828                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2240824                             2                        2
# 2240825                             2                        2
# 2240826                             2                        2
# 2240827                             2                        2
# 2240828                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     23876                    <NA>                       NaN
# 1                     23876                    <NA>                       NaN
# 2                     23876                    <NA>                       NaN
# 3                     23876                    <NA>                       NaN
# 4                     23876                    <NA>                       NaN
# ...                     ...                     ...                       ...
# 2240824               23876                    <NA>                       NaN
# 2240825               23876                    <NA>                       NaN
# 2240826               23876                    <NA>                       NaN
# 2240827               23876                    <NA>                       NaN
# 2240828               23876                    <NA>                       NaN
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay             NaN     transcriptomic
# 1             high-dimensional assay             NaN     transcriptomic
# 2             high-dimensional assay             NaN     transcriptomic
# 3             high-dimensional assay             NaN     transcriptomic
# 4             high-dimensional assay             NaN     transcriptomic
# ...                              ...             ...                ...
# 2240824       high-dimensional assay             NaN     transcriptomic
# 2240825       high-dimensional assay             NaN     transcriptomic
# 2240826       high-dimensional assay             NaN     transcriptomic
# 2240827       high-dimensional assay             NaN     transcriptomic
# 2240828       high-dimensional assay             NaN     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                         NaN      single-cell rna-seq            NaN
# 1                         NaN      single-cell rna-seq            NaN
# 2                         NaN      single-cell rna-seq            NaN
# 3                         NaN      single-cell rna-seq            NaN
# 4                         NaN      single-cell rna-seq            NaN
# ...                       ...                      ...            ...
# 2240824                   NaN      single-cell rna-seq            NaN
# 2240825                   NaN      single-cell rna-seq            NaN
# 2240826                   NaN      single-cell rna-seq            NaN
# 2240827                   NaN      single-cell rna-seq            NaN
# 2240828                   NaN      single-cell rna-seq            NaN
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq        NaN                       NaN
# 1             Perturb-seq        NaN                       NaN
# 2             Perturb-seq        NaN                       NaN
# 3             Perturb-seq        NaN                       NaN
# 4             Perturb-seq        NaN                       NaN
# ...                   ...        ...                       ...
# 2240824       Perturb-seq        NaN                       NaN
# 2240825       Perturb-seq        NaN                       NaN
# 2240826       Perturb-seq        NaN                       NaN
# 2240827       Perturb-seq        NaN                       NaN
# 2240828       Perturb-seq        NaN                       NaN
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 1        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 3        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 4        GEM-X Flex Gene Expression Human n-plex kit                    NaN
# ...                                              ...                    ...
# 2240824  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2240825  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2240826  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2240827  GEM-X Flex Gene Expression Human n-plex kit                    NaN
# 2240828  GEM-X Flex Gene Expression Human n-plex kit                    NaN
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                    NaN
# 1           Ultima Genomics UG100                    NaN
# 2           Ultima Genomics UG100                    NaN
# 3           Ultima Genomics UG100                    NaN
# 4           Ultima Genomics UG100                    NaN
# ...                           ...                    ...
# 2240824     Ultima Genomics UG100                    NaN
# 2240825     Ultima Genomics UG100                    NaN
# 2240826     Ultima Genomics UG100                    NaN
# 2240827     Ultima Genomics UG100                    NaN
# 2240828     Ultima Genomics UG100                    NaN
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing                NaN            CellRanger
# 1              barcode sequencing                NaN            CellRanger
# 2              barcode sequencing                NaN            CellRanger
# 3              barcode sequencing                NaN            CellRanger
# 4              barcode sequencing                NaN            CellRanger
# ...                           ...                ...                   ...
# 2240824        barcode sequencing                NaN            CellRanger
# 2240825        barcode sequencing                NaN            CellRanger
# 2240826        barcode sequencing                NaN            CellRanger
# 2240827        barcode sequencing                NaN            CellRanger
# 2240828        barcode sequencing                NaN            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                        NaN                  scanpy                  NaN
# 1                        NaN                  scanpy                  NaN
# 2                        NaN                  scanpy                  NaN
# 3                        NaN                  scanpy                  NaN
# 4                        NaN                  scanpy                  NaN
# ...                      ...                     ...                  ...
# 2240824                  NaN                  scanpy                  NaN
# 2240825                  NaN                  scanpy                  NaN
# 2240826                  NaN                  scanpy                  NaN
# 2240827                  NaN                  scanpy                  NaN
# 2240828                  NaN                  scanpy                  NaN
#
#         reference_genome_id reference_genome_label  \
# 0                       NaN                 GRCh38
# 1                       NaN                 GRCh38
# 2                       NaN                 GRCh38
# 3                       NaN                 GRCh38
# 4                       NaN                 GRCh38
# ...                     ...                    ...
# 2240824                 NaN                 GRCh38
# 2240825                 NaN                 GRCh38
# 2240826                 NaN                 GRCh38
# 2240827                 NaN                 GRCh38
# 2240828                 NaN                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2240824  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240825  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240826  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240827  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2240828  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2240824  SWO:9000074
# 2240825  SWO:9000074
# 2240826  SWO:9000074
# 2240827  SWO:9000074
# 2240828  SWO:9000074
#
# [2240829 rows x 99 columns]

# %%
cur_data.save_curated_data_h5ad()
# Out:
# ✅ Curated h5ad data saved to ../curated/h5ad/zhu_2025_D1_stim48hr_cl_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/zhu_2025_D1_stim48hr_cl_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
# upload_parquet_to_bq(
#     parquet_path='../curated/parquet/zhu_2025_D1_rest_cl_curated_metadata.parquet',
#     bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
#     bq_table_name='metadata',
#     key_columns=['dataset_id', 'sample_id'],
#     verbose=True
# )

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/zhu_2025_D2_stim48hr_cl_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
# Out:
# /bin/sh: line 1: gcloud: command not found
