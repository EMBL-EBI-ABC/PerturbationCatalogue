# %% [markdown]
# # Import

# %%
from pathlib import Path
import pandas as pd

from curation_tools.biogrid_curation_tools import (
    process_biogrid_screen,
    compare_metadata_biogrid
)
# Out:
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/.venv/lib/python3.12/site-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# 📝 Define the id of the Biogrid paper and paths/directories

# %%
gc_fname = "25307932" # PMID of the Biogrid paper

data_dir = Path("../supplementary/temp/biogrid/data")
biogrid_metadata_path = Path("../../text_extraction/biogrid_curated_metadata.csv")
curated_gemini_dir = Path("../../text_extraction/curated_gemini")
non_curated_h5ad_dir = Path("../non_curated/h5ad")
curated_parquet_dir = Path("../curated/parquet")
crispr_studies_path = Path("../crispr_studies.xlsx")

# BigQuery dataset id
bq_dataset_id = "prj-ext-dev-pertcat-437314.crispr"

# %% [markdown]
# Read metadata files

# %%
gc_metadata_df = pd.read_json(curated_gemini_dir / f"{gc_fname}.json")
gc_metadata_df = gc_metadata_df.set_index("gemini_" + gc_metadata_df.index.astype(str))
bg_metadata_all = pd.read_csv(biogrid_metadata_path)
bg_metadata_df = bg_metadata_all[bg_metadata_all["SOURCE_ID"] == gc_fname]
all_screen_ids = bg_metadata_df["#SCREEN_ID"].values

crispr_studies_df = pd.read_excel(crispr_studies_path)

print(f"Screen ids in the study:\n{all_screen_ids}")
# Out:
# Screen ids in the study:
# [   5    6 1161 1162]

# %% [markdown]
# 📝 Select the `screen_id` to analyse from above
#
# 📝 Define `index_prefix`

# %%
biogrid_screen_id = "biogrid_5" # biogrid screen id to analyse - select from above
gemini_id = "gemini_2" # corresponding gemini id - examine the comparison table below to identify the correct gemini id

# %% [markdown]
# Create the comparison table between Biogrid and Gemini-curated metadata
#
# **Manually examine the potential discrepancies to validate the curation process!**

# %%
compare_metadata_biogrid(
    bg_metadata_df=bg_metadata_df,
    gc_metadata_df=gc_metadata_df,
    biogrid_screen_id=biogrid_screen_id,
    gemini_id=gemini_id # gemini id - None to see all gemini entries
)

# %% [markdown]
# Use the data from the comparison table, biogrid page of the screen and the original study to update the `crispr_studies.xlsx` file.
#
# Then run the cell below to process the Biogrid screen and upload to BigQuery.

# %%
for dataset_id in crispr_studies_df['dataset_id']:
    print(f"Processing dataset_id: {dataset_id}")
    biogrid_screen_path = (data_dir / f"BIOGRID-ORCS-SCREEN_{dataset_id.lstrip('biogrid_')}-1.1.17.screen.tab.txt")
    curated_metadata_dict = crispr_studies_df[crispr_studies_df['dataset_id'] == dataset_id].to_dict(orient='records')[0]

    process_biogrid_screen(
        biogrid_dataset_id=dataset_id,
        biogrid_screen_path=biogrid_screen_path,
        biogrid_metadata_df=bg_metadata_all,
        curated_metadata_dict=curated_metadata_dict,
        non_curated_h5ad_dir=non_curated_h5ad_dir,
        upload_to_bq=True, # set to True to upload to BigQuery
        bq_dataset_id=bq_dataset_id,
        bq_metadata_table_name="metadata_upd",
        bq_data_table_name="data_upd",
        extra_data_columns = ['significant', 'significance_criteria', 'perturbed_target_symbol', 'perturbed_target_ensg']
    )
# Out:
# Processing dataset_id: biogrid_1161
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/biogrid_curation_tools.py:293: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   OBS_df = OBS_df.replace({None: np.nan})
# ✅ Saved AnnData object to ../non_curated/h5ad/biogrid_1161.h5ad
# Loading data from ../non_curated/h5ad/biogrid_1161.h5ad
# Column perturbation_name has no NA entries in adata.obs
# Mapping gene symbols: 100%|████████████████████████████████| 15964/15964 [00:00<00:00, 55380.56it/s]
# --------------------------------------------------
# Successfully mapped 15932 out of 15964 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['MTRNR2L7', 'GPR75-ASB3', 'MTRNR2L1', 'MTRNR2L2', 'MTRNR2L3', 'MTRNR2L4', 'MTRNR2L5', 'MTRNR2L6', 'MTRNR2L8', 'MTRNR2L9', 'MTRNR2L10', 'PHOSPHO2-KLHL23', 'TNFAIP8L2-SCNM1', 'SPHAR', 'AKAP2', 'TMEM155', 'LINC01599', 'FAM153B', '391322', '401052', 'PGBD3', 'CRIPAK', 'GSTT1', 'FLJ44635', 'PRY2', 'BAGE', 'CCL3L1', 'GTF2H2C_2', 'LUZP6', 'BAGE5', 'BAGE4', 'BAGE3']
# --------------------------------------------------
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Matched columns of adata.obs to the obs_schema.
#                          dataset_id              sample_id  data_modality  \
# index
# biogrid_1161_A1BG      biogrid_1161      biogrid_1161_A1BG  CRISPR screen
# biogrid_1161_NAT2      biogrid_1161      biogrid_1161_NAT2  CRISPR screen
# biogrid_1161_ADA       biogrid_1161       biogrid_1161_ADA  CRISPR screen
# biogrid_1161_CDH2      biogrid_1161      biogrid_1161_CDH2  CRISPR screen
# biogrid_1161_AKT3      biogrid_1161      biogrid_1161_AKT3  CRISPR screen
# ...                             ...                    ...            ...
# biogrid_1161_PTBP3     biogrid_1161     biogrid_1161_PTBP3  CRISPR screen
# biogrid_1161_KCNE2     biogrid_1161     biogrid_1161_KCNE2  CRISPR screen
# biogrid_1161_DGCR2     biogrid_1161     biogrid_1161_DGCR2  CRISPR screen
# biogrid_1161_CASP8AP2  biogrid_1161  biogrid_1161_CASP8AP2  CRISPR screen
# biogrid_1161_SCO2      biogrid_1161      biogrid_1161_SCO2  CRISPR screen
#
#                       significant significance_criteria  \
# index
# biogrid_1161_A1BG           False                     -
# biogrid_1161_NAT2           False                     -
# biogrid_1161_ADA            False                     -
# biogrid_1161_CDH2           False                     -
# biogrid_1161_AKT3           False                     -
# ...                           ...                   ...
# biogrid_1161_PTBP3          False                     -
# biogrid_1161_KCNE2          False                     -
# biogrid_1161_DGCR2          False                     -
# biogrid_1161_CASP8AP2        True                     -
# biogrid_1161_SCO2           False                     -
#
#                            perturbation_name       perturbed_target_coord  \
# index
# biogrid_1161_A1BG          biogrid_1161_A1BG   chr19:58345178-58353492;-1
# biogrid_1161_NAT2          biogrid_1161_NAT2     chr8:18391252-18401218;1
# biogrid_1161_ADA            biogrid_1161_ADA   chr20:44584896-44652252;-1
# biogrid_1161_CDH2          biogrid_1161_CDH2   chr18:27932879-28177946;-1
# biogrid_1161_AKT3          biogrid_1161_AKT3  chr1:243488233-243851079;-1
# ...                                      ...                          ...
# biogrid_1161_PTBP3        biogrid_1161_PTBP3  chr9:112215071-112333695;-1
# biogrid_1161_KCNE2        biogrid_1161_KCNE2    chr21:34180729-34371381;1
# biogrid_1161_DGCR2        biogrid_1161_DGCR2   chr22:19036280-19122461;-1
# biogrid_1161_CASP8AP2  biogrid_1161_CASP8AP2     chr6:89829894-89874436;1
# biogrid_1161_SCO2          biogrid_1161_SCO2   chr22:50523564-50526461;-1
#
#                       perturbed_target_chromosome  \
# index
# biogrid_1161_A1BG                              19
# biogrid_1161_NAT2                               8
# biogrid_1161_ADA                               20
# biogrid_1161_CDH2                              18
# biogrid_1161_AKT3                               1
# ...                                           ...
# biogrid_1161_PTBP3                              9
# biogrid_1161_KCNE2                             21
# biogrid_1161_DGCR2                             22
# biogrid_1161_CASP8AP2                           6
# biogrid_1161_SCO2                              22
#
#                        perturbed_target_chromosome_encoding  \
# index
# biogrid_1161_A1BG                                        19
# biogrid_1161_NAT2                                         8
# biogrid_1161_ADA                                         20
# biogrid_1161_CDH2                                        18
# biogrid_1161_AKT3                                         1
# ...                                                     ...
# biogrid_1161_PTBP3                                        9
# biogrid_1161_KCNE2                                       21
# biogrid_1161_DGCR2                                       22
# biogrid_1161_CASP8AP2                                     6
# biogrid_1161_SCO2                                        22
#
#                        perturbed_target_number  ... software_counts_id  \
# index                                           ...
# biogrid_1161_A1BG                            1  ...               <NA>
# biogrid_1161_NAT2                            1  ...               <NA>
# biogrid_1161_ADA                             1  ...               <NA>
# biogrid_1161_CDH2                            1  ...               <NA>
# biogrid_1161_AKT3                            1  ...               <NA>
# ...                                        ...  ...                ...
# biogrid_1161_PTBP3                           1  ...               <NA>
# biogrid_1161_KCNE2                           1  ...               <NA>
# biogrid_1161_DGCR2                           1  ...               <NA>
# biogrid_1161_CASP8AP2                        1  ...               <NA>
# biogrid_1161_SCO2                            1  ...               <NA>
#
#                       software_counts_label software_analysis_id  \
# index
# biogrid_1161_A1BG                    custom                 <NA>
# biogrid_1161_NAT2                    custom                 <NA>
# biogrid_1161_ADA                     custom                 <NA>
# biogrid_1161_CDH2                    custom                 <NA>
# biogrid_1161_AKT3                    custom                 <NA>
# ...                                     ...                  ...
# biogrid_1161_PTBP3                   custom                 <NA>
# biogrid_1161_KCNE2                   custom                 <NA>
# biogrid_1161_DGCR2                   custom                 <NA>
# biogrid_1161_CASP8AP2                custom                 <NA>
# biogrid_1161_SCO2                    custom                 <NA>
#
#                       software_analysis_label  \
# index
# biogrid_1161_A1BG                      custom
# biogrid_1161_NAT2                      custom
# biogrid_1161_ADA                       custom
# biogrid_1161_CDH2                      custom
# biogrid_1161_AKT3                      custom
# ...                                       ...
# biogrid_1161_PTBP3                     custom
# biogrid_1161_KCNE2                     custom
# biogrid_1161_DGCR2                     custom
# biogrid_1161_CASP8AP2                  custom
# biogrid_1161_SCO2                      custom
#
#                                                     score_interpretation  \
# index
# biogrid_1161_A1BG      Positive rho score shows that inhibition of th...
# biogrid_1161_NAT2      Positive rho score shows that inhibition of th...
# biogrid_1161_ADA       Positive rho score shows that inhibition of th...
# biogrid_1161_CDH2      Positive rho score shows that inhibition of th...
# biogrid_1161_AKT3      Positive rho score shows that inhibition of th...
# ...                                                                  ...
# biogrid_1161_PTBP3     Positive rho score shows that inhibition of th...
# biogrid_1161_KCNE2     Positive rho score shows that inhibition of th...
# biogrid_1161_DGCR2     Positive rho score shows that inhibition of th...
# biogrid_1161_CASP8AP2  Positive rho score shows that inhibition of th...
# biogrid_1161_SCO2      Positive rho score shows that inhibition of th...
#
#                       reference_genome_id reference_genome_label  \
# index
# biogrid_1161_A1BG                    <NA>                   <NA>
# biogrid_1161_NAT2                    <NA>                   <NA>
# biogrid_1161_ADA                     <NA>                   <NA>
# biogrid_1161_CDH2                    <NA>                   <NA>
# biogrid_1161_AKT3                    <NA>                   <NA>
# ...                                   ...                    ...
# biogrid_1161_PTBP3                   <NA>                   <NA>
# biogrid_1161_KCNE2                   <NA>                   <NA>
# biogrid_1161_DGCR2                   <NA>                   <NA>
# biogrid_1161_CASP8AP2                <NA>                   <NA>
# biogrid_1161_SCO2                    <NA>                   <NA>
#
#                                                      associated_datasets  \
# index
# biogrid_1161_A1BG      [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_NAT2      [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_ADA       [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_CDH2      [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_AKT3      [{"dataset_accession": "Gilbert LA (2014) - 1-...
# ...                                                                  ...
# biogrid_1161_PTBP3     [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_KCNE2     [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_DGCR2     [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_CASP8AP2  [{"dataset_accession": "Gilbert LA (2014) - 1-...
# biogrid_1161_SCO2      [{"dataset_accession": "Gilbert LA (2014) - 1-...
#
#                       license_label   license_id
# index
# biogrid_1161_A1BG       MIT License  SWO:9000074
# biogrid_1161_NAT2       MIT License  SWO:9000074
# biogrid_1161_ADA        MIT License  SWO:9000074
# biogrid_1161_CDH2       MIT License  SWO:9000074
# biogrid_1161_AKT3       MIT License  SWO:9000074
# ...                             ...          ...
# biogrid_1161_PTBP3      MIT License  SWO:9000074
# biogrid_1161_KCNE2      MIT License  SWO:9000074
# biogrid_1161_DGCR2      MIT License  SWO:9000074
# biogrid_1161_CASP8AP2   MIT License  SWO:9000074
# biogrid_1161_SCO2       MIT License  SWO:9000074
#
# [15964 rows x 99 columns]
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ✅ Curated h5ad data saved to ../curated/h5ad/biogrid_1161_curated.h5ad
# ✅ Metadata saved to ../curated/parquet/biogrid_1161_curated_metadata.parquet
# Processing data...
# Saving data to ../curated/parquet/biogrid_1161_curated_data.parquet...
# ✅ Data saved to ../curated/parquet/biogrid_1161_curated_data.parquet
# Uploading metadata Parquet to BigQuery: ../curated/parquet/biogrid_1161_curated_metadata.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_1161_curated_metadata.parquet to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging...
# Staging table: loaded 15964 rows to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.metadata_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Uploading data Parquet to BigQuery: ../curated/parquet/biogrid_1161_curated_data.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_1161_curated_data.parquet to prj-ext-dev-pertcat-437314.crispr.data_upd_staging...
# Staging table: loaded 15964 rows to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.data_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Processing dataset_id: biogrid_5
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/biogrid_curation_tools.py:293: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   OBS_df = OBS_df.replace({None: np.nan})
# ✅ Saved AnnData object to ../non_curated/h5ad/biogrid_5.h5ad
# Loading data from ../non_curated/h5ad/biogrid_5.h5ad
# Column perturbation_name has no NA entries in adata.obs
# Mapping gene symbols: 100%|████████████████████████████████| 15964/15964 [00:00<00:00, 56051.62it/s]
# --------------------------------------------------
# Successfully mapped 15929 out of 15964 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['BAGE', 'GSTT1', 'CCL3L1', 'SPHAR', 'AKAP2', 'BAGE5', 'BAGE4', 'BAGE3', 'TMEM155', 'LINC01599', 'FAM153B', 'PGBD3', 'CRIPAK', 'LOC391322', 'FLJ44635', 'LOC401052', 'PRY2', 'LOC728392', 'GTF2H2C_2', 'LUZP6', 'LOC100130705', 'MTRNR2L7', 'GPR75-ASB3', 'MTRNR2L1', 'MTRNR2L2', 'MTRNR2L3', 'MTRNR2L4', 'MTRNR2L5', 'MTRNR2L6', 'MTRNR2L8', 'MTRNR2L9', 'MTRNR2L10', 'PHOSPHO2-KLHL23', 'ZNF664-RFLNA', 'TNFAIP8L2-SCNM1']
# --------------------------------------------------
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Matched columns of adata.obs to the obs_schema.
#                          dataset_id                 sample_id  data_modality  \
# index
# biogrid_5_A1BG            biogrid_5            biogrid_5_A1BG  CRISPR screen
# biogrid_5_A2M             biogrid_5             biogrid_5_A2M  CRISPR screen
# biogrid_5_NAT1            biogrid_5            biogrid_5_NAT1  CRISPR screen
# biogrid_5_NAT2            biogrid_5            biogrid_5_NAT2  CRISPR screen
# biogrid_5_SERPINA3        biogrid_5        biogrid_5_SERPINA3  CRISPR screen
# ...                             ...                       ...            ...
# biogrid_5_PTGES3L-AARSD1  biogrid_5  biogrid_5_PTGES3L-AARSD1  CRISPR screen
# biogrid_5_PYURF           biogrid_5           biogrid_5_PYURF  CRISPR screen
# biogrid_5_CSAG2           biogrid_5           biogrid_5_CSAG2  CRISPR screen
# biogrid_5_GAGE10          biogrid_5          biogrid_5_GAGE10  CRISPR screen
# biogrid_5_UPK3B           biogrid_5           biogrid_5_UPK3B  CRISPR screen
#
#                          significant               significance_criteria  \
# index
# biogrid_5_A1BG                 False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_A2M                  False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_NAT1                 False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_NAT2                 False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_SERPINA3             False  Gamma (normalized log2e/t) <= -0.1
# ...                              ...                                 ...
# biogrid_5_PTGES3L-AARSD1       False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_PYURF                False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_CSAG2                False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_GAGE10               False  Gamma (normalized log2e/t) <= -0.1
# biogrid_5_UPK3B                False  Gamma (normalized log2e/t) <= -0.1
#
#                                  perturbation_name  \
# index
# biogrid_5_A1BG                      biogrid_5_A1BG
# biogrid_5_A2M                        biogrid_5_A2M
# biogrid_5_NAT1                      biogrid_5_NAT1
# biogrid_5_NAT2                      biogrid_5_NAT2
# biogrid_5_SERPINA3              biogrid_5_SERPINA3
# ...                                            ...
# biogrid_5_PTGES3L-AARSD1  biogrid_5_PTGES3L-AARSD1
# biogrid_5_PYURF                    biogrid_5_PYURF
# biogrid_5_CSAG2                    biogrid_5_CSAG2
# biogrid_5_GAGE10                  biogrid_5_GAGE10
# biogrid_5_UPK3B                    biogrid_5_UPK3B
#
#                                perturbed_target_coord  \
# index
# biogrid_5_A1BG             chr19:58345178-58353492;-1
# biogrid_5_A2M                chr12:9067664-9116229;-1
# biogrid_5_NAT1               chr8:18170399-18223739;1
# biogrid_5_NAT2               chr8:18391252-18401218;1
# biogrid_5_SERPINA3          chr14:94612377-94624645;1
# ...                                               ...
# biogrid_5_PTGES3L-AARSD1   chr17:42950526-42980528;-1
# biogrid_5_PYURF             chr4:88520998-88523776;-1
# biogrid_5_CSAG2           chrX:152708261-152721661;-1
# biogrid_5_GAGE10             chrX:49303646-49319841;1
# biogrid_5_UPK3B              chr7:76510525-76516522;1
#
#                          perturbed_target_chromosome  \
# index
# biogrid_5_A1BG                                    19
# biogrid_5_A2M                                     12
# biogrid_5_NAT1                                     8
# biogrid_5_NAT2                                     8
# biogrid_5_SERPINA3                                14
# ...                                              ...
# biogrid_5_PTGES3L-AARSD1                          17
# biogrid_5_PYURF                                    4
# biogrid_5_CSAG2                                    X
# biogrid_5_GAGE10                                   X
# biogrid_5_UPK3B                                    7
#
#                           perturbed_target_chromosome_encoding  \
# index
# biogrid_5_A1BG                                              19
# biogrid_5_A2M                                               12
# biogrid_5_NAT1                                               8
# biogrid_5_NAT2                                               8
# biogrid_5_SERPINA3                                          14
# ...                                                        ...
# biogrid_5_PTGES3L-AARSD1                                    17
# biogrid_5_PYURF                                              4
# biogrid_5_CSAG2                                             23
# biogrid_5_GAGE10                                            23
# biogrid_5_UPK3B                                              7
#
#                           perturbed_target_number  ... software_counts_id  \
# index                                              ...
# biogrid_5_A1BG                                  1  ...               <NA>
# biogrid_5_A2M                                   1  ...               <NA>
# biogrid_5_NAT1                                  1  ...               <NA>
# biogrid_5_NAT2                                  1  ...               <NA>
# biogrid_5_SERPINA3                              1  ...               <NA>
# ...                                           ...  ...                ...
# biogrid_5_PTGES3L-AARSD1                        1  ...               <NA>
# biogrid_5_PYURF                                 1  ...               <NA>
# biogrid_5_CSAG2                                 1  ...               <NA>
# biogrid_5_GAGE10                                1  ...               <NA>
# biogrid_5_UPK3B                                 1  ...               <NA>
#
#                          software_counts_label software_analysis_id  \
# index
# biogrid_5_A1BG                          custom                 <NA>
# biogrid_5_A2M                           custom                 <NA>
# biogrid_5_NAT1                          custom                 <NA>
# biogrid_5_NAT2                          custom                 <NA>
# biogrid_5_SERPINA3                      custom                 <NA>
# ...                                        ...                  ...
# biogrid_5_PTGES3L-AARSD1                custom                 <NA>
# biogrid_5_PYURF                         custom                 <NA>
# biogrid_5_CSAG2                         custom                 <NA>
# biogrid_5_GAGE10                        custom                 <NA>
# biogrid_5_UPK3B                         custom                 <NA>
#
#                          software_analysis_label  \
# index
# biogrid_5_A1BG                            custom
# biogrid_5_A2M                             custom
# biogrid_5_NAT1                            custom
# biogrid_5_NAT2                            custom
# biogrid_5_SERPINA3                        custom
# ...                                          ...
# biogrid_5_PTGES3L-AARSD1                  custom
# biogrid_5_PYURF                           custom
# biogrid_5_CSAG2                           custom
# biogrid_5_GAGE10                          custom
# biogrid_5_UPK3B                           custom
#
#                                                        score_interpretation  \
# index
# biogrid_5_A1BG            Inhibition of hit genes results in decreased f...
# biogrid_5_A2M             Inhibition of hit genes results in decreased f...
# biogrid_5_NAT1            Inhibition of hit genes results in decreased f...
# biogrid_5_NAT2            Inhibition of hit genes results in decreased f...
# biogrid_5_SERPINA3        Inhibition of hit genes results in decreased f...
# ...                                                                     ...
# biogrid_5_PTGES3L-AARSD1  Inhibition of hit genes results in decreased f...
# biogrid_5_PYURF           Inhibition of hit genes results in decreased f...
# biogrid_5_CSAG2           Inhibition of hit genes results in decreased f...
# biogrid_5_GAGE10          Inhibition of hit genes results in decreased f...
# biogrid_5_UPK3B           Inhibition of hit genes results in decreased f...
#
#                          reference_genome_id reference_genome_label  \
# index
# biogrid_5_A1BG                          <NA>                   <NA>
# biogrid_5_A2M                           <NA>                   <NA>
# biogrid_5_NAT1                          <NA>                   <NA>
# biogrid_5_NAT2                          <NA>                   <NA>
# biogrid_5_SERPINA3                      <NA>                   <NA>
# ...                                      ...                    ...
# biogrid_5_PTGES3L-AARSD1                <NA>                   <NA>
# biogrid_5_PYURF                         <NA>                   <NA>
# biogrid_5_CSAG2                         <NA>                   <NA>
# biogrid_5_GAGE10                        <NA>                   <NA>
# biogrid_5_UPK3B                         <NA>                   <NA>
#
#                                                         associated_datasets  \
# index
# biogrid_5_A1BG            [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_A2M             [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_NAT1            [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_NAT2            [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_SERPINA3        [{"dataset_accession": "Gilbert LA (2014) - 2-...
# ...                                                                     ...
# biogrid_5_PTGES3L-AARSD1  [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_PYURF           [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_CSAG2           [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_GAGE10          [{"dataset_accession": "Gilbert LA (2014) - 2-...
# biogrid_5_UPK3B           [{"dataset_accession": "Gilbert LA (2014) - 2-...
#
#                          license_label   license_id
# index
# biogrid_5_A1BG             MIT License  SWO:9000074
# biogrid_5_A2M              MIT License  SWO:9000074
# biogrid_5_NAT1             MIT License  SWO:9000074
# biogrid_5_NAT2             MIT License  SWO:9000074
# biogrid_5_SERPINA3         MIT License  SWO:9000074
# ...                                ...          ...
# biogrid_5_PTGES3L-AARSD1   MIT License  SWO:9000074
# biogrid_5_PYURF            MIT License  SWO:9000074
# biogrid_5_CSAG2            MIT License  SWO:9000074
# biogrid_5_GAGE10           MIT License  SWO:9000074
# biogrid_5_UPK3B            MIT License  SWO:9000074
#
# [15964 rows x 99 columns]
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ✅ Curated h5ad data saved to ../curated/h5ad/biogrid_5_curated.h5ad
# ✅ Metadata saved to ../curated/parquet/biogrid_5_curated_metadata.parquet
# Processing data...
# Saving data to ../curated/parquet/biogrid_5_curated_data.parquet...
# ✅ Data saved to ../curated/parquet/biogrid_5_curated_data.parquet
# Uploading metadata Parquet to BigQuery: ../curated/parquet/biogrid_5_curated_metadata.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_5_curated_metadata.parquet to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging...
# Staging table: loaded 15964 rows to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.metadata_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Uploading data Parquet to BigQuery: ../curated/parquet/biogrid_5_curated_data.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_5_curated_data.parquet to prj-ext-dev-pertcat-437314.crispr.data_upd_staging...
# Staging table: loaded 15964 rows to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.data_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Processing dataset_id: biogrid_2362
# ✅ Saved AnnData object to ../non_curated/h5ad/biogrid_2362.h5ad
# Loading data from ../non_curated/h5ad/biogrid_2362.h5ad
# Column perturbation_name has no NA entries in adata.obs
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/biogrid_curation_tools.py:293: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   OBS_df = OBS_df.replace({None: np.nan})
# Mapping gene symbols: 100%|██████████████████████████████████| 2839/2839 [00:00<00:00, 51705.76it/s]
# --------------------------------------------------
# Successfully mapped 2826 out of 2839 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['LOC100129636', 'MTRNR2L1', 'MTRNR2L6', 'LILRA3', 'GTPBP6_X', 'ASMT_X', 'ZBED1_X', 'LOC339862', 'CCL4L1', 'PRY2', 'LOC554223', 'LUZP6', 'PRY']
# --------------------------------------------------
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Matched columns of adata.obs to the obs_schema.
#                              dataset_id                  sample_id  \
# index
# biogrid_2362_POM121C       biogrid_2362       biogrid_2362_POM121C
# biogrid_2362_CTAGE4        biogrid_2362        biogrid_2362_CTAGE4
# biogrid_2362_CXorf51A      biogrid_2362      biogrid_2362_CXorf51A
# biogrid_2362_TEX13C        biogrid_2362        biogrid_2362_TEX13C
# biogrid_2362_LOC100129636  biogrid_2362  biogrid_2362_LOC100129636
# ...                                 ...                        ...
# biogrid_2362_MED12         biogrid_2362         biogrid_2362_MED12
# biogrid_2362_NUP153        biogrid_2362        biogrid_2362_NUP153
# biogrid_2362_RBX1          biogrid_2362          biogrid_2362_RBX1
# biogrid_2362_THOC1         biogrid_2362         biogrid_2362_THOC1
# biogrid_2362_SCO2          biogrid_2362          biogrid_2362_SCO2
#
#                            data_modality significant  \
# index
# biogrid_2362_POM121C       CRISPR screen       False
# biogrid_2362_CTAGE4        CRISPR screen       False
# biogrid_2362_CXorf51A      CRISPR screen       False
# biogrid_2362_TEX13C        CRISPR screen       False
# biogrid_2362_LOC100129636  CRISPR screen       False
# ...                                  ...         ...
# biogrid_2362_MED12         CRISPR screen        True
# biogrid_2362_NUP153        CRISPR screen        True
# biogrid_2362_RBX1          CRISPR screen        True
# biogrid_2362_THOC1         CRISPR screen       False
# biogrid_2362_SCO2          CRISPR screen       False
#
#                                                        significance_criteria  \
# index
# biogrid_2362_POM121C       CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_CTAGE4        CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_CXorf51A      CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_TEX13C        CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_LOC100129636  CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# ...                                                                      ...
# biogrid_2362_MED12         CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_NUP153        CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_RBX1          CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_THOC1         CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
# biogrid_2362_SCO2          CRISPR Score (CS) < -1.0 AND (FDR) < 0.05 OR (...
#
#                                    perturbation_name  \
# index
# biogrid_2362_POM121C            biogrid_2362_POM121C
# biogrid_2362_CTAGE4              biogrid_2362_CTAGE4
# biogrid_2362_CXorf51A          biogrid_2362_CXorf51A
# biogrid_2362_TEX13C              biogrid_2362_TEX13C
# biogrid_2362_LOC100129636  biogrid_2362_LOC100129636
# ...                                              ...
# biogrid_2362_MED12                biogrid_2362_MED12
# biogrid_2362_NUP153              biogrid_2362_NUP153
# biogrid_2362_RBX1                  biogrid_2362_RBX1
# biogrid_2362_THOC1                biogrid_2362_THOC1
# biogrid_2362_SCO2                  biogrid_2362_SCO2
#
#                                 perturbed_target_coord  \
# index
# biogrid_2362_POM121C         chr7:75416784-75486358;-1
# biogrid_2362_CTAGE4         chr7:144183466-144186080;1
# biogrid_2362_CXorf51A      chrX:146814106-146814744;-1
# biogrid_2362_TEX13C         chrX:125319871-125325216;1
# biogrid_2362_LOC100129636                         <NA>
# ...                                                ...
# biogrid_2362_MED12            chrX:71118543-71144103;1
# biogrid_2362_NUP153          chr6:17614707-17706935;-1
# biogrid_2362_RBX1            chr22:40951277-40973539;1
# biogrid_2362_THOC1              chr18:214515-268053;-1
# biogrid_2362_SCO2           chr22:50523564-50526461;-1
#
#                           perturbed_target_chromosome  \
# index
# biogrid_2362_POM121C                                7
# biogrid_2362_CTAGE4                                 7
# biogrid_2362_CXorf51A                               X
# biogrid_2362_TEX13C                                 X
# biogrid_2362_LOC100129636                        <NA>
# ...                                               ...
# biogrid_2362_MED12                                  X
# biogrid_2362_NUP153                                 6
# biogrid_2362_RBX1                                  22
# biogrid_2362_THOC1                                 18
# biogrid_2362_SCO2                                  22
#
#                            perturbed_target_chromosome_encoding  \
# index
# biogrid_2362_POM121C                                          7
# biogrid_2362_CTAGE4                                           7
# biogrid_2362_CXorf51A                                        23
# biogrid_2362_TEX13C                                          23
# biogrid_2362_LOC100129636                                     0
# ...                                                         ...
# biogrid_2362_MED12                                           23
# biogrid_2362_NUP153                                           6
# biogrid_2362_RBX1                                            22
# biogrid_2362_THOC1                                           18
# biogrid_2362_SCO2                                            22
#
#                            perturbed_target_number  ... software_counts_id  \
# index                                               ...
# biogrid_2362_POM121C                             1  ...               <NA>
# biogrid_2362_CTAGE4                              1  ...               <NA>
# biogrid_2362_CXorf51A                            1  ...               <NA>
# biogrid_2362_TEX13C                              1  ...               <NA>
# biogrid_2362_LOC100129636                        1  ...               <NA>
# ...                                            ...  ...                ...
# biogrid_2362_MED12                               1  ...               <NA>
# biogrid_2362_NUP153                              1  ...               <NA>
# biogrid_2362_RBX1                                1  ...               <NA>
# biogrid_2362_THOC1                               1  ...               <NA>
# biogrid_2362_SCO2                                1  ...               <NA>
#
#                           software_counts_label software_analysis_id  \
# index
# biogrid_2362_POM121C                     custom                 <NA>
# biogrid_2362_CTAGE4                      custom                 <NA>
# biogrid_2362_CXorf51A                    custom                 <NA>
# biogrid_2362_TEX13C                      custom                 <NA>
# biogrid_2362_LOC100129636                custom                 <NA>
# ...                                         ...                  ...
# biogrid_2362_MED12                       custom                 <NA>
# biogrid_2362_NUP153                      custom                 <NA>
# biogrid_2362_RBX1                        custom                 <NA>
# biogrid_2362_THOC1                       custom                 <NA>
# biogrid_2362_SCO2                        custom                 <NA>
#
#                           software_analysis_label  \
# index
# biogrid_2362_POM121C                       custom
# biogrid_2362_CTAGE4                        custom
# biogrid_2362_CXorf51A                      custom
# biogrid_2362_TEX13C                        custom
# biogrid_2362_LOC100129636                  custom
# ...                                           ...
# biogrid_2362_MED12                         custom
# biogrid_2362_NUP153                        custom
# biogrid_2362_RBX1                          custom
# biogrid_2362_THOC1                         custom
# biogrid_2362_SCO2                          custom
#
#                                                         score_interpretation  \
# index
# biogrid_2362_POM121C       Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_CTAGE4        Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_CXorf51A      Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_TEX13C        Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_LOC100129636  Significantly depleted genes (negative CRSIPR ...
# ...                                                                      ...
# biogrid_2362_MED12         Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_NUP153        Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_RBX1          Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_THOC1         Significantly depleted genes (negative CRSIPR ...
# biogrid_2362_SCO2          Significantly depleted genes (negative CRSIPR ...
#
#                           reference_genome_id reference_genome_label  \
# index
# biogrid_2362_POM121C                     <NA>                   <NA>
# biogrid_2362_CTAGE4                      <NA>                   <NA>
# biogrid_2362_CXorf51A                    <NA>                   <NA>
# biogrid_2362_TEX13C                      <NA>                   <NA>
# biogrid_2362_LOC100129636                <NA>                   <NA>
# ...                                       ...                    ...
# biogrid_2362_MED12                       <NA>                   <NA>
# biogrid_2362_NUP153                      <NA>                   <NA>
# biogrid_2362_RBX1                        <NA>                   <NA>
# biogrid_2362_THOC1                       <NA>                   <NA>
# biogrid_2362_SCO2                        <NA>                   <NA>
#
#                                                          associated_datasets  \
# index
# biogrid_2362_POM121C       [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_CTAGE4        [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_CXorf51A      [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_TEX13C        [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_LOC100129636  [{"dataset_accession": "Panea RI (2019) - 1-PM...
# ...                                                                      ...
# biogrid_2362_MED12         [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_NUP153        [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_RBX1          [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_THOC1         [{"dataset_accession": "Panea RI (2019) - 1-PM...
# biogrid_2362_SCO2          [{"dataset_accession": "Panea RI (2019) - 1-PM...
#
#                           license_label   license_id
# index
# biogrid_2362_POM121C        MIT License  SWO:9000074
# biogrid_2362_CTAGE4         MIT License  SWO:9000074
# biogrid_2362_CXorf51A       MIT License  SWO:9000074
# biogrid_2362_TEX13C         MIT License  SWO:9000074
# biogrid_2362_LOC100129636   MIT License  SWO:9000074
# ...                                 ...          ...
# biogrid_2362_MED12          MIT License  SWO:9000074
# biogrid_2362_NUP153         MIT License  SWO:9000074
# biogrid_2362_RBX1           MIT License  SWO:9000074
# biogrid_2362_THOC1          MIT License  SWO:9000074
# biogrid_2362_SCO2           MIT License  SWO:9000074
#
# [2839 rows x 99 columns]
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ✅ Curated h5ad data saved to ../curated/h5ad/biogrid_2362_curated.h5ad
# ✅ Metadata saved to ../curated/parquet/biogrid_2362_curated_metadata.parquet
# Processing data...
# Saving data to ../curated/parquet/biogrid_2362_curated_data.parquet...
# ✅ Data saved to ../curated/parquet/biogrid_2362_curated_data.parquet
# Uploading metadata Parquet to BigQuery: ../curated/parquet/biogrid_2362_curated_metadata.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_2362_curated_metadata.parquet to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging...
# Staging table: loaded 2839 rows to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.metadata_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Uploading data Parquet to BigQuery: ../curated/parquet/biogrid_2362_curated_data.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_2362_curated_data.parquet to prj-ext-dev-pertcat-437314.crispr.data_upd_staging...
# Staging table: loaded 5678 rows to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.data_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Processing dataset_id: biogrid_2363
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/biogrid_curation_tools.py:293: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   OBS_df = OBS_df.replace({None: np.nan})
# ✅ Saved AnnData object to ../non_curated/h5ad/biogrid_2363.h5ad
# Loading data from ../non_curated/h5ad/biogrid_2363.h5ad
# Column perturbation_name has no NA entries in adata.obs
# Mapping gene symbols: 100%|██████████████████████████████████| 2839/2839 [00:00<00:00, 54238.75it/s]
# --------------------------------------------------
# Successfully mapped 2826 out of 2839 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['LOC100129636', 'MTRNR2L1', 'MTRNR2L6', 'LILRA3', 'GTPBP6_X', 'ASMT_X', 'ZBED1_X', 'LOC339862', 'CCL4L1', 'PRY2', 'LOC554223', 'LUZP6', 'PRY']
# --------------------------------------------------
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Matched columns of adata.obs to the obs_schema.
#                              dataset_id                  sample_id  \
# index
# biogrid_2363_POM121C       biogrid_2363       biogrid_2363_POM121C
# biogrid_2363_CTAGE4        biogrid_2363        biogrid_2363_CTAGE4
# biogrid_2363_CXorf51A      biogrid_2363      biogrid_2363_CXorf51A
# biogrid_2363_TEX13C        biogrid_2363        biogrid_2363_TEX13C
# biogrid_2363_LOC100129636  biogrid_2363  biogrid_2363_LOC100129636
# ...                                 ...                        ...
# biogrid_2363_MED12         biogrid_2363         biogrid_2363_MED12
# biogrid_2363_NUP153        biogrid_2363        biogrid_2363_NUP153
# biogrid_2363_RBX1          biogrid_2363          biogrid_2363_RBX1
# biogrid_2363_THOC1         biogrid_2363         biogrid_2363_THOC1
# biogrid_2363_SCO2          biogrid_2363          biogrid_2363_SCO2
#
#                            data_modality significant  \
# index
# biogrid_2363_POM121C       CRISPR screen       False
# biogrid_2363_CTAGE4        CRISPR screen       False
# biogrid_2363_CXorf51A      CRISPR screen       False
# biogrid_2363_TEX13C        CRISPR screen       False
# biogrid_2363_LOC100129636  CRISPR screen       False
# ...                                  ...         ...
# biogrid_2363_MED12         CRISPR screen        True
# biogrid_2363_NUP153        CRISPR screen       False
# biogrid_2363_RBX1          CRISPR screen        True
# biogrid_2363_THOC1         CRISPR screen        True
# biogrid_2363_SCO2          CRISPR screen        True
#
#                                                        significance_criteria  \
# index
# ...
# biogrid_6_UPK3B            MIT License  SWO:9000074
#
# [15965 rows x 99 columns]
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ✅ Curated h5ad data saved to ../curated/h5ad/biogrid_6_curated.h5ad
# ✅ Metadata saved to ../curated/parquet/biogrid_6_curated_metadata.parquet
# Processing data...
# Saving data to ../curated/parquet/biogrid_6_curated_data.parquet...
# ✅ Data saved to ../curated/parquet/biogrid_6_curated_data.parquet
# Uploading metadata Parquet to BigQuery: ../curated/parquet/biogrid_6_curated_metadata.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_6_curated_metadata.parquet to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging...
# Staging table: loaded 15965 rows to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.metadata_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Uploading data Parquet to BigQuery: ../curated/parquet/biogrid_6_curated_data.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_6_curated_data.parquet to prj-ext-dev-pertcat-437314.crispr.data_upd_staging...
# Staging table: loaded 15965 rows to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.data_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Processing dataset_id: biogrid_1162
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/biogrid_curation_tools.py:293: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   OBS_df = OBS_df.replace({None: np.nan})
# ✅ Saved AnnData object to ../non_curated/h5ad/biogrid_1162.h5ad
# Loading data from ../non_curated/h5ad/biogrid_1162.h5ad
# Column perturbation_name has no NA entries in adata.obs
# Mapping gene symbols: 100%|████████████████████████████████| 15965/15965 [00:00<00:00, 61494.18it/s]
# --------------------------------------------------
# Successfully mapped 15933 out of 15965 gene symbols.
# --------------------------------------------------
# Couldn't map gene symbols: ['MTRNR2L7', 'GPR75-ASB3', 'MTRNR2L1', 'MTRNR2L2', 'MTRNR2L3', 'MTRNR2L4', 'MTRNR2L5', 'MTRNR2L6', 'MTRNR2L8', 'MTRNR2L9', 'MTRNR2L10', 'PHOSPHO2-KLHL23', 'TNFAIP8L2-SCNM1', 'SPHAR', 'AKAP2', 'TMEM155', 'LINC01599', 'FAM153B', '391322', '401052', 'PGBD3', 'CRIPAK', 'GSTT1', 'FLJ44635', 'PRY2', 'BAGE', 'CCL3L1', 'GTF2H2C_2', 'LUZP6', 'BAGE5', 'BAGE4', 'BAGE3']
# --------------------------------------------------
# Counted entries in column perturbed_target_symbol of adata.obs and stored in perturbed_target_number
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.
# Column technical_replicate added to adata.obs
# Column biological_replicate added to adata.obs
# Matched columns of adata.obs to the obs_schema.
#                          dataset_id              sample_id  data_modality  \
# index
# biogrid_1162_A1BG      biogrid_1162      biogrid_1162_A1BG  CRISPR screen
# biogrid_1162_NAT2      biogrid_1162      biogrid_1162_NAT2  CRISPR screen
# biogrid_1162_ADA       biogrid_1162       biogrid_1162_ADA  CRISPR screen
# biogrid_1162_CDH2      biogrid_1162      biogrid_1162_CDH2  CRISPR screen
# biogrid_1162_AKT3      biogrid_1162      biogrid_1162_AKT3  CRISPR screen
# ...                             ...                    ...            ...
# biogrid_1162_PTBP3     biogrid_1162     biogrid_1162_PTBP3  CRISPR screen
# biogrid_1162_KCNE2     biogrid_1162     biogrid_1162_KCNE2  CRISPR screen
# biogrid_1162_DGCR2     biogrid_1162     biogrid_1162_DGCR2  CRISPR screen
# biogrid_1162_CASP8AP2  biogrid_1162  biogrid_1162_CASP8AP2  CRISPR screen
# biogrid_1162_SCO2      biogrid_1162      biogrid_1162_SCO2  CRISPR screen
#
#                       significant significance_criteria  \
# index
# biogrid_1162_A1BG           False                     -
# biogrid_1162_NAT2           False                     -
# biogrid_1162_ADA            False                     -
# biogrid_1162_CDH2           False                     -
# biogrid_1162_AKT3           False                     -
# ...                           ...                   ...
# biogrid_1162_PTBP3          False                     -
# biogrid_1162_KCNE2          False                     -
# biogrid_1162_DGCR2          False                     -
# biogrid_1162_CASP8AP2       False                     -
# biogrid_1162_SCO2           False                     -
#
#                            perturbation_name       perturbed_target_coord  \
# index
# biogrid_1162_A1BG          biogrid_1162_A1BG   chr19:58345178-58353492;-1
# biogrid_1162_NAT2          biogrid_1162_NAT2     chr8:18391252-18401218;1
# biogrid_1162_ADA            biogrid_1162_ADA   chr20:44584896-44652252;-1
# biogrid_1162_CDH2          biogrid_1162_CDH2   chr18:27932879-28177946;-1
# biogrid_1162_AKT3          biogrid_1162_AKT3  chr1:243488233-243851079;-1
# ...                                      ...                          ...
# biogrid_1162_PTBP3        biogrid_1162_PTBP3  chr9:112215071-112333695;-1
# biogrid_1162_KCNE2        biogrid_1162_KCNE2    chr21:34180729-34371381;1
# biogrid_1162_DGCR2        biogrid_1162_DGCR2   chr22:19036280-19122461;-1
# biogrid_1162_CASP8AP2  biogrid_1162_CASP8AP2     chr6:89829894-89874436;1
# biogrid_1162_SCO2          biogrid_1162_SCO2   chr22:50523564-50526461;-1
#
#                       perturbed_target_chromosome  \
# index
# biogrid_1162_A1BG                              19
# biogrid_1162_NAT2                               8
# biogrid_1162_ADA                               20
# biogrid_1162_CDH2                              18
# biogrid_1162_AKT3                               1
# ...                                           ...
# biogrid_1162_PTBP3                              9
# biogrid_1162_KCNE2                             21
# biogrid_1162_DGCR2                             22
# biogrid_1162_CASP8AP2                           6
# biogrid_1162_SCO2                              22
#
#                        perturbed_target_chromosome_encoding  \
# index
# biogrid_1162_A1BG                                        19
# biogrid_1162_NAT2                                         8
# biogrid_1162_ADA                                         20
# biogrid_1162_CDH2                                        18
# biogrid_1162_AKT3                                         1
# ...                                                     ...
# biogrid_1162_PTBP3                                        9
# biogrid_1162_KCNE2                                       21
# biogrid_1162_DGCR2                                       22
# biogrid_1162_CASP8AP2                                     6
# biogrid_1162_SCO2                                        22
#
#                        perturbed_target_number  ... software_counts_id  \
# index                                           ...
# biogrid_1162_A1BG                            1  ...               <NA>
# biogrid_1162_NAT2                            1  ...               <NA>
# biogrid_1162_ADA                             1  ...               <NA>
# biogrid_1162_CDH2                            1  ...               <NA>
# biogrid_1162_AKT3                            1  ...               <NA>
# ...                                        ...  ...                ...
# biogrid_1162_PTBP3                           1  ...               <NA>
# biogrid_1162_KCNE2                           1  ...               <NA>
# biogrid_1162_DGCR2                           1  ...               <NA>
# biogrid_1162_CASP8AP2                        1  ...               <NA>
# biogrid_1162_SCO2                            1  ...               <NA>
#
#                       software_counts_label software_analysis_id  \
# index
# biogrid_1162_A1BG                    custom                 <NA>
# biogrid_1162_NAT2                    custom                 <NA>
# biogrid_1162_ADA                     custom                 <NA>
# biogrid_1162_CDH2                    custom                 <NA>
# biogrid_1162_AKT3                    custom                 <NA>
# ...                                     ...                  ...
# biogrid_1162_PTBP3                   custom                 <NA>
# biogrid_1162_KCNE2                   custom                 <NA>
# biogrid_1162_DGCR2                   custom                 <NA>
# biogrid_1162_CASP8AP2                custom                 <NA>
# biogrid_1162_SCO2                    custom                 <NA>
#
#                       software_analysis_label  \
# index
# biogrid_1162_A1BG                      custom
# biogrid_1162_NAT2                      custom
# biogrid_1162_ADA                       custom
# biogrid_1162_CDH2                      custom
# biogrid_1162_AKT3                      custom
# ...                                       ...
# biogrid_1162_PTBP3                     custom
# biogrid_1162_KCNE2                     custom
# biogrid_1162_DGCR2                     custom
# biogrid_1162_CASP8AP2                  custom
# biogrid_1162_SCO2                      custom
#
#                                                     score_interpretation  \
# index
# biogrid_1162_A1BG      Negative rho scores indicate activation of the...
# biogrid_1162_NAT2      Negative rho scores indicate activation of the...
# biogrid_1162_ADA       Negative rho scores indicate activation of the...
# biogrid_1162_CDH2      Negative rho scores indicate activation of the...
# biogrid_1162_AKT3      Negative rho scores indicate activation of the...
# ...                                                                  ...
# biogrid_1162_PTBP3     Negative rho scores indicate activation of the...
# biogrid_1162_KCNE2     Negative rho scores indicate activation of the...
# biogrid_1162_DGCR2     Negative rho scores indicate activation of the...
# biogrid_1162_CASP8AP2  Negative rho scores indicate activation of the...
# biogrid_1162_SCO2      Negative rho scores indicate activation of the...
#
#                       reference_genome_id reference_genome_label  \
# index
# biogrid_1162_A1BG                    <NA>                   <NA>
# biogrid_1162_NAT2                    <NA>                   <NA>
# biogrid_1162_ADA                     <NA>                   <NA>
# biogrid_1162_CDH2                    <NA>                   <NA>
# biogrid_1162_AKT3                    <NA>                   <NA>
# ...                                   ...                    ...
# biogrid_1162_PTBP3                   <NA>                   <NA>
# biogrid_1162_KCNE2                   <NA>                   <NA>
# biogrid_1162_DGCR2                   <NA>                   <NA>
# biogrid_1162_CASP8AP2                <NA>                   <NA>
# biogrid_1162_SCO2                    <NA>                   <NA>
#
#                                                      associated_datasets  \
# index
# biogrid_1162_A1BG      [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_NAT2      [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_ADA       [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_CDH2      [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_AKT3      [{"dataset_accession": "Gilbert LA (2014) - 4-...
# ...                                                                  ...
# biogrid_1162_PTBP3     [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_KCNE2     [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_DGCR2     [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_CASP8AP2  [{"dataset_accession": "Gilbert LA (2014) - 4-...
# biogrid_1162_SCO2      [{"dataset_accession": "Gilbert LA (2014) - 4-...
#
#                       license_label   license_id
# index
# biogrid_1162_A1BG       MIT License  SWO:9000074
# biogrid_1162_NAT2       MIT License  SWO:9000074
# biogrid_1162_ADA        MIT License  SWO:9000074
# biogrid_1162_CDH2       MIT License  SWO:9000074
# biogrid_1162_AKT3       MIT License  SWO:9000074
# ...                             ...          ...
# biogrid_1162_PTBP3      MIT License  SWO:9000074
# biogrid_1162_KCNE2      MIT License  SWO:9000074
# biogrid_1162_DGCR2      MIT License  SWO:9000074
# biogrid_1162_CASP8AP2   MIT License  SWO:9000074
# biogrid_1162_SCO2       MIT License  SWO:9000074
#
# [15965 rows x 99 columns]
# /Users/zakirov/Documents/GitHub/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ✅ Curated h5ad data saved to ../curated/h5ad/biogrid_1162_curated.h5ad
# ✅ Metadata saved to ../curated/parquet/biogrid_1162_curated_metadata.parquet
# Processing data...
# Saving data to ../curated/parquet/biogrid_1162_curated_data.parquet...
# ✅ Data saved to ../curated/parquet/biogrid_1162_curated_data.parquet
# Uploading metadata Parquet to BigQuery: ../curated/parquet/biogrid_1162_curated_metadata.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_1162_curated_metadata.parquet to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging...
# Staging table: loaded 15965 rows to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.metadata_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.metadata_upd_staging
# Uploading data Parquet to BigQuery: ../curated/parquet/biogrid_1162_curated_data.parquet
# Staging table: loading `.parquet` file ../curated/parquet/biogrid_1162_curated_data.parquet to prj-ext-dev-pertcat-437314.crispr.data_upd_staging...
# Staging table: loaded 15965 rows to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Staging table: added ingested_at timestamp column to prj-ext-dev-pertcat-437314.crispr.data_upd_staging
# Merge completed: staging → prj-ext-dev-pertcat-437314.crispr.data_upd with type-safe casting.
# Staging table: deleted prj-ext-dev-pertcat-437314.crispr.data_upd_staging

# %%
crispr_studies_df
