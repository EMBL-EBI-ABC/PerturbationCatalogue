# %% [markdown]
# # Import

# %%
import pandas as pd
import json

from curation_tools.curation_tools import (
    CuratedDataset,
    ObsSchema,
    VarSchema,
    Experiment,
    download_file,
    upload_parquet_to_bq
)

import logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[
        logging.FileHandler("curation.log"),
        logging.StreamHandler(),  # keep console output too
    ],
    force=True,
)
# show all columns
pd.set_option('display.max_columns', None)
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/.venv/lib/python3.12/site-packages/pandera/_pandas_deprecated.py:157: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# # Download data

# %% [markdown]
# Download the data from AWS as such:
#
# `!aws s3 cp --no-sign-request s3://genome-scale-tcell-perturb-seq/marson2025_data/{name_of_the_file}.h5ad ..aa/non_curated/h5ad/{name_of_the_file}.h5ad`

# %% [markdown]
# # Initialise the dataset object

# %%
noncurated_path = '../non_curated/h5ad/zhu_2025_D3_stim48hr_cl.h5ad'
cur_data = CuratedDataset(
    obs_schema=ObsSchema,
    var_schema=VarSchema,
    exp_metadata_schema=Experiment,
    noncurated_path=noncurated_path
)

cur_data.load_data()
# Out:
# Loading data from ../non_curated/h5ad/zhu_2025_D3_stim48hr_cl.h5ad

# %%
cur_data.adata.obs
# Out:
#                                                        lane_id  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...  CD4i_R2L32
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...  CD4i_R2L32
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...  CD4i_R2L32
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...  CD4i_R2L32
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...  CD4i_R2L32
# ...                                                        ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...  CD4i_R2L48
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...  CD4i_R2L48
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...  CD4i_R2L48
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...  CD4i_R2L48
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...  CD4i_R2L48
#
#                                                     n_genes_by_counts  \
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...       0.307259
#
#                                                     top_guide_UMI_counts  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...                   NaN
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...                 297.0
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...                  21.0
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...                 155.0
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...                 931.0
# ...                                                                  ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...                 528.0
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...                  75.0
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...                  47.0
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...                 428.0
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...                 120.0
#
#                                                        guide_id  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...          NaN
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...       ALX3-2
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...    FAM210B-1
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...      NTC-846
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...      GATA1-1
# ...                                                         ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...      IFRD1-2
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...     GALNT1-1
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...       CTSK-1
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...  multi_sgRNA
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...     LIN28B-1
#
#                                                    perturbed_gene_name  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...                 NaN
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...                ALX3
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...             FAM210B
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...                 NTC
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...               GATA1
# ...                                                                ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...               IFRD1
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...              GALNT1
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...                CTSK
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...                 NaN
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...              LIN28B
#
#                                                    perturbed_gene_id  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...               NaN
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...   ENSG00000156150
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...   ENSG00000124098
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...               NTC
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...   ENSG00000102145
# ...                                                              ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...   ENSG00000006652
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...   ENSG00000141429
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...   ENSG00000143387
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...               NaN
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...   ENSG00000187772
#
#                                                        guide_type     PuroR  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...            NaN  3.134436
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...      targeting  3.277925
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...      targeting  3.827360
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...  non-targeting  1.744745
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...      targeting  3.230057
# ...                                                           ...       ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...      targeting  2.604208
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...      targeting  1.620248
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...      targeting  2.911565
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...      targeting  2.565821
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...      targeting  3.133394
#
#                                                                guide_group  \
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...                no sgRNA
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...  targeting single sgRNA
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...  targeting single sgRNA
# ...                                                                    ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...  targeting single sgRNA
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...             multi sgRNA
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...  targeting single sgRNA
#
#                                                     low_quality
# AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32_CD4i_R2_D...        False
# AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...        False
# AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32_CD4i_R2_D...        False
# AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...        False
# AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32_CD4i_R2_D...        False
# ...                                                         ...
# TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48_CD4i_R2_D...        False
# TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48_CD4i_R2_D...        False
# TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48_CD4i_R2_D...        False
# TTTGTGAGTTTCCTCAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...        False
# TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48_CD4i_R2_D...        False
#
# [2607532 rows x 12 columns]

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %% [markdown]
# # OBS slot curation

# %% [markdown]
# ### Since for multi-guide perturbations the identities of said guides are unknown, we are filtering out these cells.

# %%
print(f"Number of cells before filtering: {cur_data.adata.n_obs}")
cur_data.adata = cur_data.adata[cur_data.adata.obs['guide_id'] != 'multi_sgRNA']
print(f"Number of cells after filtering: {cur_data.adata.n_obs}")
# Out:
# Number of cells before filtering: 2607532
# Number of cells after filtering: 2160401

# %% [markdown]
# ### Add `index` as `perturbation_name`

# %%
cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]
cur_data.adata.obs['perturbation_name'] = cur_data.adata.obs['cell_barcode'] +'_'+cur_data.adata.obs['lane_id'].astype(str)
# Out:
# /tmp/ipykernel_124898/2231587657.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   cur_data.adata.obs['cell_barcode'] = cur_data.adata.obs.index.str.split('_').str[0]

# %% [markdown]
# ### Show unique perturbations

# %%
cur_data.show_unique(slot = 'obs', column = 'perturbation_name')
# Out:
# Unique values in adata.obs.perturbation_name: 2160401
# --------------------------------------------------
# {'AAACAAGCAAACAAGAACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCAAACAAGAACTACTCA-1_CD4i_R2L46',
#  'AAACAAGCAAACAAGAAGAGGCAA-1_CD4i_R2L43',
#  'AAACAAGCAAACAATCACTACTCA-1_CD4i_R2L37',
#  'AAACAAGCAAACAATCAGAGGCAA-1_CD4i_R2L30',
#  'AAACAAGCAAACAATCAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCAAACAATCAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAAACACGCACTACTCA-1_CD4i_R2L33',
#  'AAACAAGCAAACACGCAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCAAACACGCAGTGAGTG-1_CD4i_R2L28',
#  'AAACAAGCAAACACGCAGTGAGTG-1_CD4i_R2L35',
#  'AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L41',
#  'AAACAAGCAAACCCAAAGAGGCAA-1_CD4i_R2L27',
#  'AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAAACCGGTACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCAAACCGGTAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCAAACCGTAAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAAACCTGAAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCAAACGGGAACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCAAACGGTCACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCAAACGGTCAGTGAGTG-1_CD4i_R2L31',
#  'AAACAAGCAAACGGTCAGTGAGTG-1_CD4i_R2L48',
#  'AAACAAGCAAACTGGCACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAAACTGGCAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAAACTGGCAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCAAACTTCCACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCAAACTTCCACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAATAGAAGACAGTCTG-1_CD4i_R2L36',
#  'AAACAAGCAATAGAAGACAGTCTG-1_CD4i_R2L38',
#  'AAACAAGCAATAGAAGAGAGGCAA-1_CD4i_R2L29',
#  'AAACAAGCAATAGAAGAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCAATAGAAGAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAATAGAGAACAGTCTG-1_CD4i_R2L44',
#  'AAACAAGCAATAGAGAACTACTCA-1_CD4i_R2L46',
#  'AAACAAGCAATAGAGAAGAGGCAA-1_CD4i_R2L26',
#  'AAACAAGCAATAGAGAAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAATAGCTGACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCAATAGCTGAGAGGCAA-1_CD4i_R2L31',
#  'AAACAAGCAATAGCTGAGAGGCAA-1_CD4i_R2L37',
#  'AAACAAGCAATATGCGACAGTCTG-1_CD4i_R2L26',
#  'AAACAAGCAATATGCGACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAATATGCGAGAGGCAA-1_CD4i_R2L32',
#  'AAACAAGCAATATGCGAGAGGCAA-1_CD4i_R2L42',
#  'AAACAAGCAATATGCGAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCAATATGCGAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAATATGCGAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCAATATGGTACTACTCA-1_CD4i_R2L48',
#  'AAACAAGCAATCAAACACTACTCA-1_CD4i_R2L27',
#  'AAACAAGCAATCAAACAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAATCAAGTACTACTCA-1_CD4i_R2L28',
#  'AAACAAGCAATCATCCAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCAATCCACTACAGTCTG-1_CD4i_R2L41',
#  'AAACAAGCAATCCACTAGTGAGTG-1_CD4i_R2L41',
#  'AAACAAGCAATCGTGAACTACTCA-1_CD4i_R2L30',
#  'AAACAAGCAATCGTGAAGAGGCAA-1_CD4i_R2L30',
#  'AAACAAGCAATCGTTCACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCAATCGTTCAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCAATCGTTCAGTGAGTG-1_CD4i_R2L29',
#  'AAACAAGCAATGAATCACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCAATGAATCAGTGAGTG-1_CD4i_R2L35',
#  'AAACAAGCAATGAGCCACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAATGAGCCACAGTCTG-1_CD4i_R2L45',
#  'AAACAAGCAATGAGCCACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAATGAGCCACTACTCA-1_CD4i_R2L42',
#  'AAACAAGCAATGAGCCAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCAATGAGCCAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCAATGGATTACAGTCTG-1_CD4i_R2L32',
#  'AAACAAGCAATGGATTACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCAATGGATTAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCAATGGCCGAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCAATGGGAGACAGTCTG-1_CD4i_R2L25',
#  'AAACAAGCAATGGGAGAGAGGCAA-1_CD4i_R2L28',
#  'AAACAAGCAATGGGAGAGAGGCAA-1_CD4i_R2L35',
#  'AAACAAGCAATGGGAGAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCAATGTTCCACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCAATTAGACACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAATTAGACACAGTCTG-1_CD4i_R2L38',
#  'AAACAAGCAATTAGACACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAATTAGACACTACTCA-1_CD4i_R2L27',
#  'AAACAAGCAATTAGACACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCAATTAGACACTACTCA-1_CD4i_R2L48',
#  'AAACAAGCAATTAGACAGTGAGTG-1_CD4i_R2L38',
#  'AAACAAGCAATTAGACAGTGAGTG-1_CD4i_R2L48',
#  'AAACAAGCAATTAGCGACAGTCTG-1_CD4i_R2L34',
#  'AAACAAGCAATTAGCGACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAATTAGGTACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCAATTAGGTACAGTCTG-1_CD4i_R2L36',
#  'AAACAAGCAATTAGGTACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAATTAGGTACTACTCA-1_CD4i_R2L30',
#  'AAACAAGCAATTAGGTACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCAATTAGGTAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCAATTCGGAACAGTCTG-1_CD4i_R2L34',
#  'AAACAAGCAATTCGGAACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAATTCGGAAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCAATTCGGAAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCAATTCGGAAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAATTGAACAGTGAGTG-1_CD4i_R2L31',
#  'AAACAAGCAATTGCGAACTACTCA-1_CD4i_R2L45',
#  'AAACAAGCAATTGCGAAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCAATTGCGAAGTGAGTG-1_CD4i_R2L25',
#  'AAACAAGCACAAATACACAGTCTG-1_CD4i_R2L41',
#  'AAACAAGCACAAATACACTACTCA-1_CD4i_R2L25',
#  'AAACAAGCACAAATACAGAGGCAA-1_CD4i_R2L25',
#  'AAACAAGCACAAATACAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCACAACAATACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCACAACATGAGAGGCAA-1_CD4i_R2L32',
#  'AAACAAGCACAAGCGTACAGTCTG-1_CD4i_R2L31',
#  'AAACAAGCACAAGCGTACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCACATAGATAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCACATAGTGACAGTCTG-1_CD4i_R2L29',
#  'AAACAAGCACATAGTGACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCACATAGTGACTACTCA-1_CD4i_R2L41',
#  'AAACAAGCACATAGTGAGAGGCAA-1_CD4i_R2L29',
#  'AAACAAGCACATAGTGAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCACATAGTGAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCACATGAATACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCACATGAATAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCACATGAATAGTGAGTG-1_CD4i_R2L25',
#  'AAACAAGCACATGCTTACTACTCA-1_CD4i_R2L39',
#  'AAACAAGCACATGCTTAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCACATGCTTAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCACATGCTTAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCACATTCGTAGTGAGTG-1_CD4i_R2L31',
#  'AAACAAGCACATTCGTAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCACATTGAGAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCACATTGAGAGTGAGTG-1_CD4i_R2L36',
#  'AAACAAGCACATTGTCACAGTCTG-1_CD4i_R2L36',
#  'AAACAAGCACATTGTCACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCACATTGTCAGAGGCAA-1_CD4i_R2L26',
#  'AAACAAGCACATTGTCAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCACATTGTCAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCACATTGTCAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCACCAACAAACAGTCTG-1_CD4i_R2L38',
#  'AAACAAGCACCAACAAACAGTCTG-1_CD4i_R2L47',
#  'AAACAAGCACCAACAAAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCACCAACAAAGAGGCAA-1_CD4i_R2L47',
#  'AAACAAGCACCACACCACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCACCACATTAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCACCAGCCTACAGTCTG-1_CD4i_R2L32',
#  'AAACAAGCACCAGCCTACAGTCTG-1_CD4i_R2L33',
#  'AAACAAGCACCAGCCTACAGTCTG-1_CD4i_R2L36',
#  'AAACAAGCACCAGCCTACTACTCA-1_CD4i_R2L25',
#  'AAACAAGCACCAGCCTACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCACCAGCCTACTACTCA-1_CD4i_R2L39',
#  'AAACAAGCACCAGCCTAGAGGCAA-1_CD4i_R2L25',
#  'AAACAAGCACCAGCCTAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCACCAGCCTAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCACCAGCCTAGTGAGTG-1_CD4i_R2L33',
#  'AAACAAGCACCAGCCTAGTGAGTG-1_CD4i_R2L36',
#  'AAACAAGCACTCCCAAACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCACTCCCAAAGAGGCAA-1_CD4i_R2L35',
#  'AAACAAGCACTCCCAAAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCACTCCCAAAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCACTCCCTTACTACTCA-1_CD4i_R2L28',
#  'AAACAAGCACTCCCTTAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCACTGACAAACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCACTGACAAACAGTCTG-1_CD4i_R2L40',
#  'AAACAAGCACTGACAAACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCACTGACAAAGTGAGTG-1_CD4i_R2L25',
#  'AAACAAGCACTGACAAAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCACTGACTTACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCACTGACTTACTACTCA-1_CD4i_R2L37',
#  'AAACAAGCACTGACTTACTACTCA-1_CD4i_R2L38',
#  'AAACAAGCACTGACTTACTACTCA-1_CD4i_R2L43',
#  'AAACAAGCACTGACTTAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCACTGACTTAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCACTGACTTAGTGAGTG-1_CD4i_R2L33',
#  'AAACAAGCACTGACTTAGTGAGTG-1_CD4i_R2L38',
#  'AAACAAGCACTGACTTAGTGAGTG-1_CD4i_R2L47',
#  'AAACAAGCACTGTCATACAGTCTG-1_CD4i_R2L31',
#  'AAACAAGCACTGTCATAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCACTGTCATAGAGGCAA-1_CD4i_R2L40',
#  'AAACAAGCACTGTCATAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCACTTAACCACAGTCTG-1_CD4i_R2L29',
#  'AAACAAGCACTTAACCACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCACTTAACCACTACTCA-1_CD4i_R2L48',
#  'AAACAAGCACTTAACCAGAGGCAA-1_CD4i_R2L38',
#  'AAACAAGCACTTAACCAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCACTTAACCAGTGAGTG-1_CD4i_R2L48',
#  'AAACAAGCACTTCGATACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCACTTCGATACTACTCA-1_CD4i_R2L34',
#  'AAACAAGCACTTTACAAGAGGCAA-1_CD4i_R2L30',
#  'AAACAAGCACTTTACAAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCACTTTACAAGTGAGTG-1_CD4i_R2L34',
#  'AAACAAGCACTTTATGACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCACTTTATGACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCACTTTGTAACTACTCA-1_CD4i_R2L30',
#  'AAACAAGCACTTTGTAAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCACTTTGTAAGTGAGTG-1_CD4i_R2L45',
#  'AAACAAGCAGAAACTTACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAGAAACTTACTACTCA-1_CD4i_R2L27',
#  'AAACAAGCAGAAAGGTACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAGAAAGGTAGAGGCAA-1_CD4i_R2L46',
#  'AAACAAGCAGAATCGCACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGAATCGCACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAGAATCGCAGAGGCAA-1_CD4i_R2L29',
#  'AAACAAGCAGAATCGCAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCAGAATCGCAGAGGCAA-1_CD4i_R2L42',
#  'AAACAAGCAGAATCGCAGTGAGTG-1_CD4i_R2L42',
#  'AAACAAGCAGAATGAAAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCAGAATGAAAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGACTCAAACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAGACTCAAACTACTCA-1_CD4i_R2L39',
#  'AAACAAGCAGACTCAAAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCAGACTCAAAGTGAGTG-1_CD4i_R2L34',
#  'AAACAAGCAGAGGCTTACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCAGAGGCTTACTACTCA-1_CD4i_R2L37',
#  'AAACAAGCAGAGGCTTAGTGAGTG-1_CD4i_R2L35',
#  'AAACAAGCAGAGGCTTAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAGATAACTACAGTCTG-1_CD4i_R2L47',
#  'AAACAAGCAGATAACTAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAGATAACTAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCAGATAACTAGTGAGTG-1_CD4i_R2L47',
#  'AAACAAGCAGATAGCCACAGTCTG-1_CD4i_R2L36',
#  'AAACAAGCAGATAGCCAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCAGATTGCAAGAGGCAA-1_CD4i_R2L43',
#  'AAACAAGCAGCAATTGACTACTCA-1_CD4i_R2L40',
#  'AAACAAGCAGCACCTCACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAGCACCTCACTACTCA-1_CD4i_R2L45',
#  'AAACAAGCAGCACCTCAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCAGCACCTCAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCAGCACCTCAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCAGCACCTCAGTGAGTG-1_CD4i_R2L45',
#  'AAACAAGCAGCACGTGACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGCACGTGACTACTCA-1_CD4i_R2L30',
#  'AAACAAGCAGCACGTGACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCAGCACGTGAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGCACTAAACAGTCTG-1_CD4i_R2L28',
#  'AAACAAGCAGCACTAAACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAGCACTAAAGAGGCAA-1_CD4i_R2L45',
#  'AAACAAGCAGCATTTCACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCAGCATTTCACTACTCA-1_CD4i_R2L48',
#  'AAACAAGCAGCATTTCAGAGGCAA-1_CD4i_R2L30',
#  'AAACAAGCAGCATTTCAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCAGCATTTCAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAGCATTTCAGTGAGTG-1_CD4i_R2L41',
#  'AAACAAGCAGCCAGCAACAGTCTG-1_CD4i_R2L29',
#  'AAACAAGCAGCCAGCAACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCAGCCAGCAAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGCCATAAACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCAGCCATAAAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGCCATAAAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAGCCATAAAGTGAGTG-1_CD4i_R2L35',
#  'AAACAAGCAGCCCTTAACTACTCA-1_CD4i_R2L45',
#  'AAACAAGCAGCCCTTAAGTGAGTG-1_CD4i_R2L36',
#  'AAACAAGCAGCCTATTACAGTCTG-1_CD4i_R2L29',
#  'AAACAAGCAGCCTATTACTACTCA-1_CD4i_R2L40',
#  'AAACAAGCAGCCTATTACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCAGCCTATTACTACTCA-1_CD4i_R2L47',
#  'AAACAAGCAGCCTATTAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCAGCCTGAGACAGTCTG-1_CD4i_R2L32',
#  'AAACAAGCAGCCTGAGACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAGCCTGAGAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCAGCGATCGAGAGGCAA-1_CD4i_R2L37',
#  'AAACAAGCAGCGATCGAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAGCGGATTACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCAGCGGATTACTACTCA-1_CD4i_R2L43',
#  'AAACAAGCAGCGGATTAGTGAGTG-1_CD4i_R2L46',
#  'AAACAAGCAGCTAAGCACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAGCTAAGCACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCAGCTAAGCACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCAGCTAAGCACTACTCA-1_CD4i_R2L46',
#  'AAACAAGCAGCTAAGCAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCAGCTAAGCAGAGGCAA-1_CD4i_R2L42',
#  'AAACAAGCAGCTAAGCAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAGCTAAGCAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCAGCTAGACACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGCTAGCGAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCAGCTCATTACAGTCTG-1_CD4i_R2L33',
#  'AAACAAGCAGCTCATTAGAGGCAA-1_CD4i_R2L26',
#  'AAACAAGCAGCTCATTAGAGGCAA-1_CD4i_R2L31',
#  'AAACAAGCAGCTCATTAGAGGCAA-1_CD4i_R2L33',
#  'AAACAAGCAGCTCATTAGTGAGTG-1_CD4i_R2L31',
#  'AAACAAGCAGCTCATTAGTGAGTG-1_CD4i_R2L45',
#  'AAACAAGCAGCTGCTCACTACTCA-1_CD4i_R2L42',
#  'AAACAAGCAGCTGCTCAGTGAGTG-1_CD4i_R2L29',
#  'AAACAAGCAGCTGCTCAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCAGCTTAAGAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCAGCTTAAGAGTGAGTG-1_CD4i_R2L38',
#  'AAACAAGCAGCTTTCGACAGTCTG-1_CD4i_R2L41',
#  'AAACAAGCAGCTTTCGACTACTCA-1_CD4i_R2L31',
#  'AAACAAGCAGCTTTCGAGTGAGTG-1_CD4i_R2L31',
#  'AAACAAGCAGGAATAAACAGTCTG-1_CD4i_R2L44',
#  'AAACAAGCAGGAATAAAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCAGGAATAAAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCAGGACTACACTACTCA-1_CD4i_R2L31',
#  'AAACAAGCAGGACTACAGAGGCAA-1_CD4i_R2L27',
#  'AAACAAGCAGGACTACAGAGGCAA-1_CD4i_R2L43',
#  'AAACAAGCAGGACTACAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCAGGACTACAGTGAGTG-1_CD4i_R2L26',
#  'AAACAAGCAGGAGCAAACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCAGGAGCAAAGAGGCAA-1_CD4i_R2L46',
#  'AAACAAGCAGGATCCGACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAGGATCCGACAGTCTG-1_CD4i_R2L34',
#  'AAACAAGCAGGATCCGACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCAGGATCCGACTACTCA-1_CD4i_R2L27',
#  'AAACAAGCAGGATCCGACTACTCA-1_CD4i_R2L39',
#  'AAACAAGCAGGATCCGAGTGAGTG-1_CD4i_R2L39',
#  'AAACAAGCAGGATCCGAGTGAGTG-1_CD4i_R2L48',
#  'AAACAAGCAGGATGCTACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCAGGATGCTACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGGATGCTAGAGGCAA-1_CD4i_R2L29',
#  'AAACAAGCAGGATGCTAGAGGCAA-1_CD4i_R2L37',
#  'AAACAAGCAGGATTATACAGTCTG-1_CD4i_R2L27',
#  'AAACAAGCAGGATTGCACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAGGATTGCACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAGGATTGCAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCAGGCAACTACTACTCA-1_CD4i_R2L37',
#  'AAACAAGCAGGCAACTAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCAGGCCTCTAGAGGCAA-1_CD4i_R2L25',
#  'AAACAAGCAGGCTAACACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCAGGCTAACACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCAGGCTAACAGAGGCAA-1_CD4i_R2L30',
#  'AAACAAGCAGGCTAACAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCAGGCTAACAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGGCTATAACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGGCTGTGAGAGGCAA-1_CD4i_R2L29',
#  'AAACAAGCAGGCTTAAACAGTCTG-1_CD4i_R2L40',
#  'AAACAAGCAGGGATGAACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCAGGGATGAACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCAGGGATGAACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCAGGGCTATACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCAGGTAGCTACAGTCTG-1_CD4i_R2L25',
#  'AAACAAGCAGGTAGCTAGAGGCAA-1_CD4i_R2L25',
#  'AAACAAGCAGGTAGCTAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGGTATATACAGTCTG-1_CD4i_R2L43',
#  'AAACAAGCAGGTATATACTACTCA-1_CD4i_R2L33',
#  'AAACAAGCAGGTATTGACAGTCTG-1_CD4i_R2L26',
#  'AAACAAGCAGGTATTGAGTGAGTG-1_CD4i_R2L28',
#  'AAACAAGCAGGTCAACACAGTCTG-1_CD4i_R2L43',
#  'AAACAAGCAGGTCAACAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCAGGTCAACAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCAGGTGACTAGAGGCAA-1_CD4i_R2L43',
#  'AAACAAGCAGGTGACTAGTGAGTG-1_CD4i_R2L27',
#  'AAACAAGCAGGTTTCTACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCAGGTTTCTACTACTCA-1_CD4i_R2L32',
#  'AAACAAGCAGGTTTCTAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAGGTTTCTAGTGAGTG-1_CD4i_R2L33',
#  'AAACAAGCAGTAAGGGACAGTCTG-1_CD4i_R2L33',
#  'AAACAAGCAGTAAGGGACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCAGTAAGGGAGTGAGTG-1_CD4i_R2L47',
#  'AAACAAGCAGTAAGTTACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCAGTAAGTTACTACTCA-1_CD4i_R2L46',
#  'AAACAAGCAGTAAGTTAGAGGCAA-1_CD4i_R2L26',
#  'AAACAAGCAGTAAGTTAGAGGCAA-1_CD4i_R2L46',
#  'AAACAAGCAGTAAGTTAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCAGTAATACACTACTCA-1_CD4i_R2L41',
#  'AAACAAGCAGTGAGAGAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAGTGAGGAAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCAGTTAAACACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAGTTAAACACTACTCA-1_CD4i_R2L48',
#  'AAACAAGCAGTTAAACAGAGGCAA-1_CD4i_R2L28',
#  'AAACAAGCAGTTAAACAGAGGCAA-1_CD4i_R2L34',
#  'AAACAAGCAGTTAAACAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCAGTTATCCAGTGAGTG-1_CD4i_R2L34',
#  'AAACAAGCAGTTATGGACAGTCTG-1_CD4i_R2L29',
#  'AAACAAGCAGTTATGGACTACTCA-1_CD4i_R2L40',
#  'AAACAAGCAGTTGCCCACAGTCTG-1_CD4i_R2L48',
#  'AAACAAGCAGTTGCCCAGTGAGTG-1_CD4i_R2L32',
#  'AAACAAGCAGTTGCCCAGTGAGTG-1_CD4i_R2L48',
#  'AAACAAGCATAACCAGACAGTCTG-1_CD4i_R2L42',
#  'AAACAAGCATAACCAGAGAGGCAA-1_CD4i_R2L42',
#  'AAACAAGCATAACCAGAGAGGCAA-1_CD4i_R2L44',
#  'AAACAAGCATAACCAGAGTGAGTG-1_CD4i_R2L45',
#  'AAACAAGCATAAGCCAACAGTCTG-1_CD4i_R2L28',
#  'AAACAAGCATAAGCCAACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCATAAGCCAAGAGGCAA-1_CD4i_R2L35',
#  'AAACAAGCATAAGCTGACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCATAAGCTGACTACTCA-1_CD4i_R2L34',
#  'AAACAAGCATAAGCTGAGTGAGTG-1_CD4i_R2L29',
#  'AAACAAGCATAAGCTGAGTGAGTG-1_CD4i_R2L34',
#  'AAACAAGCATAAGTCGACTACTCA-1_CD4i_R2L34',
#  'AAACAAGCATAAGTCGACTACTCA-1_CD4i_R2L35',
#  'AAACAAGCATAAGTCGACTACTCA-1_CD4i_R2L40',
#  'AAACAAGCATAAGTCGAGAGGCAA-1_CD4i_R2L35',
#  'AAACAAGCATAAGTCGAGTGAGTG-1_CD4i_R2L40',
#  'AAACAAGCATAATGACACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCATAATGACAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCATACTGAGACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCATACTGAGACAGTCTG-1_CD4i_R2L34',
#  'AAACAAGCATACTGAGACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCATACTGAGACAGTCTG-1_CD4i_R2L47',
#  'AAACAAGCATACTGAGACTACTCA-1_CD4i_R2L30',
#  'AAACAAGCATACTGAGACTACTCA-1_CD4i_R2L42',
#  'AAACAAGCATACTGAGAGAGGCAA-1_CD4i_R2L26',
#  'AAACAAGCATACTGAGAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCATACTTCAACAGTCTG-1_CD4i_R2L25',
#  'AAACAAGCATACTTCAACAGTCTG-1_CD4i_R2L28',
#  'AAACAAGCATACTTCAACTACTCA-1_CD4i_R2L41',
#  'AAACAAGCATACTTCAACTACTCA-1_CD4i_R2L42',
#  'AAACAAGCATACTTCAAGTGAGTG-1_CD4i_R2L28',
#  'AAACAAGCATACTTCAAGTGAGTG-1_CD4i_R2L36',
#  'AAACAAGCATACTTCAAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCATACTTCAAGTGAGTG-1_CD4i_R2L46',
#  'AAACAAGCATACTTGCACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCATACTTGCACTACTCA-1_CD4i_R2L26',
#  'AAACAAGCATACTTGCAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCATACTTGCAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCATAGACCAACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCATAGACCAAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCATAGACCAAGAGGCAA-1_CD4i_R2L47',
#  'AAACAAGCATAGACGCACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCATAGACGCAGAGGCAA-1_CD4i_R2L41',
#  'AAACAAGCATAGACGCAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCATAGCCGGAGAGGCAA-1_CD4i_R2L39',
#  'AAACAAGCATAGCCTTACAGTCTG-1_CD4i_R2L43',
#  'AAACAAGCATAGCCTTACAGTCTG-1_CD4i_R2L45',
#  'AAACAAGCATAGCCTTACTACTCA-1_CD4i_R2L43',
#  'AAACAAGCATAGCCTTAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCATAGCGACACTACTCA-1_CD4i_R2L29',
#  'AAACAAGCATAGCGACAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCATAGCGCGACTACTCA-1_CD4i_R2L44',
#  'AAACAAGCATAGCGCGAGAGGCAA-1_CD4i_R2L37',
#  'AAACAAGCATAGGCGTACAGTCTG-1_CD4i_R2L30',
#  'AAACAAGCATAGGCGTACAGTCTG-1_CD4i_R2L37',
#  'AAACAAGCATAGGCGTACAGTCTG-1_CD4i_R2L47',
#  'AAACAAGCATAGGCGTACTACTCA-1_CD4i_R2L43',
#  'AAACAAGCATAGGCGTAGTGAGTG-1_CD4i_R2L30',
#  'AAACAAGCATAGGCGTAGTGAGTG-1_CD4i_R2L37',
#  'AAACAAGCATAGGGTCACAGTCTG-1_CD4i_R2L39',
#  'AAACAAGCATAGGGTCACAGTCTG-1_CD4i_R2L44',
#  'AAACAAGCATAGGGTCACAGTCTG-1_CD4i_R2L46',
#  'AAACAAGCATAGGGTCACTACTCA-1_CD4i_R2L36',
#  'AAACAAGCATAGGGTCAGAGGCAA-1_CD4i_R2L36',
#  'AAACAAGCATAGGGTCAGAGGCAA-1_CD4i_R2L46',
#  'AAACAAGCATAGGGTCAGAGGCAA-1_CD4i_R2L48',
#  'AAACAAGCATAGGGTCAGTGAGTG-1_CD4i_R2L44',
#  'AAACAAGCATAGGGTCAGTGAGTG-1_CD4i_R2L46',
#  'AAACAAGCATAGTCAGACAGTCTG-1_CD4i_R2L35',
#  'AAACAAGCATAGTCAGAGAGGCAA-1_CD4i_R2L26',
#  'TTTGTGAGTTTGTCAAAGTGAGTG-1_CD4i_R2L43',
#  'TTTGTGAGTTTGTCCCACAGTCTG-1_CD4i_R2L37',
#  'TTTGTGAGTTTGTGACACAGTCTG-1_CD4i_R2L25',
#  'TTTGTGAGTTTGTGACACTACTCA-1_CD4i_R2L34',
#  'TTTGTGAGTTTGTGACAGAGGCAA-1_CD4i_R2L34',
#  'TTTGTGAGTTTGTGACAGTGAGTG-1_CD4i_R2L44',
#  'TTTGTGAGTTTGTTGAACAGTCTG-1_CD4i_R2L33',
#  'TTTGTGAGTTTGTTGAAGTGAGTG-1_CD4i_R2L33',
#  'TTTGTGAGTTTGTTGAAGTGAGTG-1_CD4i_R2L43',
#  'TTTGTGAGTTTGTTTCACAGTCTG-1_CD4i_R2L38',
#  'TTTGTGAGTTTGTTTCACTACTCA-1_CD4i_R2L38',
#  'TTTGTGAGTTTGTTTCAGAGGCAA-1_CD4i_R2L38',
#  'TTTGTGAGTTTGTTTCAGTGAGTG-1_CD4i_R2L25'}
# --------------------------------------------------

# %% [markdown]
# ### Add guide RNA information

# %%
# download the guide RNA spreadsheet
download_file(
    url="https://raw.githubusercontent.com/emdann/GWT_perturbseq_analysis_2025/refs/heads/master/metadata/suppl_tables/sgrna_library_metadata.suppl_table.csv",
    dest_path="../supplementary/zhu_2025_guide_info.csv"
)
# read in the guide RNA info csv
guide_info_df = pd.read_csv("../supplementary/zhu_2025_guide_info.csv")

guide_info_df = guide_info_df[['sgRNA', 'seq']]

guide_info_df['sgRNA'] = guide_info_df['sgRNA'].str.replace('1-Jun','JUN-1').str.replace('2-Jun','JUN-2')

guide_info_df = guide_info_df.rename(columns={'seq': 'guide_sequence', 'sgRNA':'guide_id'})

guide_info_df
# Out:
# File ../supplementary/zhu_2025_guide_info.csv already exists. Skipping download.
#         guide_id        guide_sequence
# 0        ARMC5-1  CTGCCTCGCGCAGCTCGCGG
# 1         DDB1-1  GGAGTTCGCTGCGCGCTGTT
# 2       FNDC10-1  TGCCCGCTCCCCGCGATCCC
# 3         RORC-1  TCTGTGGGGCCCTGTCCATG
# 4      SLC35F6-1  GAACAGCTGGTACTTGGTCC
# ...          ...                   ...
# 26499    NTC-988  TTTCAGGCTACGGGCGCGGG
# 26500    NTC-989  TTTCCCATGATCATTTAGTG
# 26501    NTC-990  TTTCGCCCAAGAGGCTTGGG
# 26502    NTC-991  TTTCGTGCCGATGTAACACA
# 26503    NTC-992  TTTGGGTTTATCCGCCCCCA
#
# [26504 rows x 2 columns]

# %%
print("Number of overlapping guides with cur_data:")
cur_data.adata.obs['guide_id'].isin(guide_info_df['guide_id'].to_list()).value_counts()
# Out:
# Number of overlapping guides with cur_data:
# guide_id
# True     1896516
# False     263885
# Name: count, dtype: int64

# %%
# merge cur_data.adata.obs with guide_info_df
cur_data.adata.obs = cur_data.adata.obs.merge(guide_info_df, on='guide_id', how='left')
# check that there are no missing guide sequences
print(f"Number of missing guide sequences: {cur_data.adata.obs['guide_sequence'].isna().sum()}")
# Out:
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Number of missing guide sequences: 263885

# %%
cur_data.adata.obs
# Out:
#             lane_id  n_genes_by_counts  total_counts  pct_counts_mt  \
# 0        CD4i_R2L32               5101       12866.0       1.375719
# 1        CD4i_R2L32               5994       23121.0       0.047576
# 2        CD4i_R2L32               3575        7659.0       0.287244
# 3        CD4i_R2L32               2795        5204.0       0.153728
# 4        CD4i_R2L32               6745       30883.0       0.777127
# ...             ...                ...           ...            ...
# 2160396  CD4i_R2L48               5621       18304.0       1.005245
# 2160397  CD4i_R2L48               3075        7043.0       0.070992
# 2160398  CD4i_R2L48               3497        7250.0       0.358621
# 2160399  CD4i_R2L48               3687        7890.0       0.088720
# 2160400  CD4i_R2L48               5306       15622.0       0.307259
#
#          top_guide_UMI_counts   guide_id perturbed_gene_name  \
# 0                         NaN        NaN                 NaN
# 1                       297.0     ALX3-2                ALX3
# 2                        21.0  FAM210B-1             FAM210B
# 3                       155.0    NTC-846                 NTC
# 4                       931.0    GATA1-1               GATA1
# ...                       ...        ...                 ...
# 2160396                 134.0     TPBG-2                TPBG
# 2160397                 528.0    IFRD1-2               IFRD1
# 2160398                  75.0   GALNT1-1              GALNT1
# 2160399                  47.0     CTSK-1                CTSK
# 2160400                 120.0   LIN28B-1              LIN28B
#
#         perturbed_gene_id     guide_type     PuroR             guide_group  \
# 0                     NaN            NaN  3.134436                no sgRNA
# 1         ENSG00000156150      targeting  3.277925  targeting single sgRNA
# 2         ENSG00000124098      targeting  3.827360  targeting single sgRNA
# 3                     NTC  non-targeting  1.744745  targeting single sgRNA
# 4         ENSG00000102145      targeting  3.230057  targeting single sgRNA
# ...                   ...            ...       ...                     ...
# 2160396   ENSG00000146242      targeting  2.547603  targeting single sgRNA
# 2160397   ENSG00000006652      targeting  2.604208  targeting single sgRNA
# 2160398   ENSG00000141429      targeting  1.620248  targeting single sgRNA
# 2160399   ENSG00000143387      targeting  2.911565  targeting single sgRNA
# 2160400   ENSG00000187772      targeting  3.133394  targeting single sgRNA
#
#          low_quality                cell_barcode  \
# 0              False  AAACAAGCAAACCCAAACTACTCA-1
# 1              False  AAACAAGCAAACCCAAAGTGAGTG-1
# 2              False  AAACAAGCAAACCGTAAGTGAGTG-1
# 3              False  AAACAAGCAAATACCGACAGTCTG-1
# 4              False  AAACAAGCAACCGTAAACAGTCTG-1
# ...              ...                         ...
# 2160396        False  TTTGTGAGTTGGGTTTAGAGGCAA-1
# 2160397        False  TTTGTGAGTTTACGACAGAGGCAA-1
# 2160398        False  TTTGTGAGTTTACGACAGTGAGTG-1
# 2160399        False  TTTGTGAGTTTCCTCAACAGTCTG-1
# 2160400        False  TTTGTGAGTTTGCATAACTACTCA-1
#
#                              perturbation_name        guide_sequence
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32                   NaN
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32  GGTGCAGGCCCCACGCGGAA
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32  GCTGGGTCCGGCAGGCAGGG
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32  GGGTGGTCATTCTCTACTTG
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32  GGCAAGCTCAGTGTGATCCC
# ...                                        ...                   ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48  GAACTCAGAGTTGGTTCTGG
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48  AACAGAGTCGAGAAGCGGCG
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48  GTCCAAGAGTACCCAAATCA
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48  GTATATATATAAATCATACA
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48  GCTCTCCGGCGGGCACGAGG
#
# [2160401 rows x 15 columns]

# %%
# change perturbed_gene_id from categorical to string
cur_data.adata.obs['perturbed_gene_id'] = cur_data.adata.obs['perturbed_gene_id'].astype(str)
cur_data.adata.obs['perturbed_gene_name'] = cur_data.adata.obs['perturbed_gene_name'].astype(str)

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isin(['NTC']), 'perturbed_gene_id'] = 'control_nontargeting'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin(['NTC']), 'perturbed_gene_name'] = 'control_nontargeting'

cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_id'].isna(), 'perturbed_gene_id'] = 'control_casonly'
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isna(), 'perturbed_gene_name'] = 'control_casonly'

# %% [markdown]
# ### Standardise perturbation targets

# %%
cur_data.standardize_genes(
    slot='obs',
    input_column='perturbed_gene_id',
    input_column_type='ensembl_gene_id',
    multiple_entries=False,
    # remove_version=True,
    # version_sep='.'
)
# Out:
# Missing Ensembl IDs: ['SGK494', 'AKAP2', 'ENSG00000277796', 'ENSG00000255823', 'ENSG00000182230', 'SEPT6', 'ENSG00000232196', 'SMIM11B', 'ENSG00000148362', 'LUZP6', 'ENSG00000203812', 'OCLM', 'ENSG00000256618']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000277796': 'ENSG00000293545', 'ENSG00000255823': nan, 'ENSG00000182230': nan, 'ENSG00000232196': nan, 'ENSG00000148362': 'ENSG00000310560', 'ENSG00000203812': 'ENSG00000288825', 'ENSG00000256618': nan}
# --------------------------------------------------
# Successfully mapped 11839 out of 11839 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
cur_data.adata.obs
# Out:
#                        cell_barcode  n_genes_by_counts     PuroR  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1               5101  3.134436
# 1        AAACAAGCAAACCCAAAGTGAGTG-1               5994  3.277925
# 2        AAACAAGCAAACCGTAAGTGAGTG-1               3575  3.827360
# 3        AAACAAGCAAATACCGACAGTCTG-1               2795  1.744745
# 4        AAACAAGCAACCGTAAACAGTCTG-1               6745  3.230057
# ...                             ...                ...       ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1               5621  2.547603
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1               3075  2.604208
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1               3497  1.620248
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1               3687  2.911565
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1               5306  3.133394
#
#           perturbed_gene_name   guide_id  total_counts  \
# index
# 0                         nan        NaN       12866.0
# 1                        ALX3     ALX3-2       23121.0
# 2                     FAM210B  FAM210B-1        7659.0
# 3        control_nontargeting    NTC-846        5204.0
# 4                       GATA1    GATA1-1       30883.0
# ...                       ...        ...           ...
# 2160396                  TPBG     TPBG-2       18304.0
# 2160397                 IFRD1    IFRD1-2        7043.0
# 2160398                GALNT1   GALNT1-1        7250.0
# 2160399                  CTSK     CTSK-1        7890.0
# 2160400                LIN28B   LIN28B-1       15622.0
#
#                     guide_group     lane_id     guide_type  \
# index
# 0                      no sgRNA  CD4i_R2L32            NaN
# 1        targeting single sgRNA  CD4i_R2L32      targeting
# 2        targeting single sgRNA  CD4i_R2L32      targeting
# 3        targeting single sgRNA  CD4i_R2L32  non-targeting
# 4        targeting single sgRNA  CD4i_R2L32      targeting
# ...                         ...         ...            ...
# 2160396  targeting single sgRNA  CD4i_R2L48      targeting
# 2160397  targeting single sgRNA  CD4i_R2L48      targeting
# 2160398  targeting single sgRNA  CD4i_R2L48      targeting
# 2160399  targeting single sgRNA  CD4i_R2L48      targeting
# 2160400  targeting single sgRNA  CD4i_R2L48      targeting
#
#                              perturbation_name  low_quality  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32        False
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32        False
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32        False
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32        False
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32        False
# ...                                        ...          ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48        False
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48        False
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48        False
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48        False
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48        False
#
#                guide_sequence     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0                         NaN                   nan                   NaN
# 1        GGTGCAGGCCCCACGCGGAA       ENSG00000156150                 297.0
# 2        GCTGGGTCCGGCAGGCAGGG       ENSG00000124098                  21.0
# 3        GGGTGGTCATTCTCTACTTG  control_nontargeting                 155.0
# 4        GGCAAGCTCAGTGTGATCCC       ENSG00000102145                 931.0
# ...                       ...                   ...                   ...
# 2160396  GAACTCAGAGTTGGTTCTGG       ENSG00000146242                 134.0
# 2160397  AACAGAGTCGAGAAGCGGCG       ENSG00000006652                 528.0
# 2160398  GTCCAAGAGTACCCAAATCA       ENSG00000141429                  75.0
# 2160399  GTATATATATAAATCATACA       ENSG00000143387                  47.0
# 2160400  GCTCTCCGGCGGGCACGAGG       ENSG00000187772                 120.0
#
#          pct_counts_mt perturbed_target_ensg perturbed_target_symbol  \
# index
# 0             1.375719                   nan                     NaN
# 1             0.047576       ENSG00000156150                    ALX3
# 2             0.287244       ENSG00000124098                 FAM210B
# 3             0.153728  control_nontargeting    control_nontargeting
# 4             0.777127       ENSG00000102145                   GATA1
# ...                ...                   ...                     ...
# 2160396       1.005245       ENSG00000146242                    TPBG
# 2160397       0.070992       ENSG00000006652                   IFRD1
# 2160398       0.358621       ENSG00000141429                  GALNT1
# 2160399       0.088720       ENSG00000143387                    CTSK
# 2160400       0.307259       ENSG00000187772                  LIN28B
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                            NaN                          NaN
# 1                 protein_coding  chr1:110059870-110070672;-1
# 2                 protein_coding    chr20:56358974-56368663;1
# 3           control_nontargeting         control_nontargeting
# 4                 protein_coding     chrX:48786540-48794311;1
# ...                          ...                          ...
# 2160396           protein_coding     chr6:82363206-82367420;1
# 2160397           protein_coding   chr7:112422887-112481017;1
# 2160398           protein_coding    chr18:35580892-35713370;1
# 2160399           protein_coding  chr1:150794880-150809577;-1
# 2160400           protein_coding   chr6:104936616-105083332;1
#
#         perturbed_target_chromosome original_index
# index
# 0                               NaN              0
# 1                                 1              1
# 2                                20              2
# 3              control_nontargeting              3
# 4                                 X              4
# ...                             ...            ...
# 2160396                           6        2160396
# 2160397                           7        2160397
# 2160398                          18        2160398
# 2160399                           1        2160399
# 2160400                           6        2160400
#
# [2160401 rows x 21 columns]

# %% [markdown]
# # Manually replace some genes

# %%
# define genes to replace in the cur_data.adata.obs
genes_to_replace = cur_data.adata.obs[cur_data.adata.obs['perturbed_target_symbol'].isna()]['perturbed_gene_name'].drop_duplicates().to_list()
# define columns to replace
cols_to_replace = ['perturbed_target_ensg',	'perturbed_target_symbol',	'perturbed_target_biotype',	'perturbed_target_coord',	'perturbed_target_chromosome']
# define mapping dict for renaming columns in gene_ont for replacement
gene_ont_col_mapping = {
    'ensembl_gene_id':'perturbed_target_ensg',
    'gene_symbol':'perturbed_target_symbol',
    'biotype':'perturbed_target_biotype',
    'gene_coord':'perturbed_target_coord',
    'chromosome_name':'perturbed_target_chromosome'
}
# loop through genes and fill in the missing cols
for replacement_gene in genes_to_replace:
    if replacement_gene in cur_data.gene_ont['synonym'].values:
        # subset gene_ont and get values for replacement
        replacement = (
            cur_data.gene_ont.rename(columns=gene_ont_col_mapping)
            .loc[cur_data.gene_ont['synonym'].isin([replacement_gene]), cols_to_replace]
        )[cols_to_replace].values[0]
        # replace values in cur_data.adata.obs with the values from gene_ont
        cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_gene_name'].isin([replacement_gene]), cols_to_replace] = replacement
        print(f"Replaced {replacement_gene} with {replacement}")
    else:
        print(f"No replacement found for {replacement_gene}")
# Out:
# No replacement found for nan
# No replacement found for MTRNR2L8
# No replacement found for AKAP2
# No replacement found for FAM153B
# No replacement found for OCLM
# No replacement found for LUZP6
# No replacement found for MTRNR2L1
# Replaced SGK494 with ['ENSG00000167524' 'RSKR' 'protein_coding' 'chr17:28455752-28614197;-1'
#  '17']
# Replaced SEPT6 with ['ENSG00000125354' 'SEPTIN6' 'protein_coding'
#  'chrX:119615724-119693949;-1' 'X']
# No replacement found for CCL3L1
# No replacement found for MTRNR2L4
# No replacement found for SMIM11B

# %%
# replace non-mapped perturbed_target_symbol with original gene symbols
cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_target_symbol'] = cur_data.adata.obs.loc[cur_data.adata.obs['perturbed_target_symbol'].isna(), 'perturbed_gene_name'].values

# %%
# replace entries in perturbed_target_ensg that are not ENSEMBL ids with NA
cur_data.adata.obs.loc[(~cur_data.adata.obs['perturbed_target_ensg'].str.startswith('ENSG')) & (cur_data.adata.obs['perturbed_target_ensg'] != 'control_nontargeting'), 'perturbed_target_ensg'] = pd.NA

# %%
cur_data.adata.obs
# Out:
#                        cell_barcode  n_genes_by_counts     PuroR  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1               5101  3.134436
# 1        AAACAAGCAAACCCAAAGTGAGTG-1               5994  3.277925
# 2        AAACAAGCAAACCGTAAGTGAGTG-1               3575  3.827360
# 3        AAACAAGCAAATACCGACAGTCTG-1               2795  1.744745
# 4        AAACAAGCAACCGTAAACAGTCTG-1               6745  3.230057
# ...                             ...                ...       ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1               5621  2.547603
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1               3075  2.604208
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1               3497  1.620248
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1               3687  2.911565
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1               5306  3.133394
#
#           perturbed_gene_name   guide_id  total_counts  \
# index
# 0                         nan        NaN       12866.0
# 1                        ALX3     ALX3-2       23121.0
# 2                     FAM210B  FAM210B-1        7659.0
# 3        control_nontargeting    NTC-846        5204.0
# 4                       GATA1    GATA1-1       30883.0
# ...                       ...        ...           ...
# 2160396                  TPBG     TPBG-2       18304.0
# 2160397                 IFRD1    IFRD1-2        7043.0
# 2160398                GALNT1   GALNT1-1        7250.0
# 2160399                  CTSK     CTSK-1        7890.0
# 2160400                LIN28B   LIN28B-1       15622.0
#
#                     guide_group     lane_id     guide_type  \
# index
# 0                      no sgRNA  CD4i_R2L32            NaN
# 1        targeting single sgRNA  CD4i_R2L32      targeting
# 2        targeting single sgRNA  CD4i_R2L32      targeting
# 3        targeting single sgRNA  CD4i_R2L32  non-targeting
# 4        targeting single sgRNA  CD4i_R2L32      targeting
# ...                         ...         ...            ...
# 2160396  targeting single sgRNA  CD4i_R2L48      targeting
# 2160397  targeting single sgRNA  CD4i_R2L48      targeting
# 2160398  targeting single sgRNA  CD4i_R2L48      targeting
# 2160399  targeting single sgRNA  CD4i_R2L48      targeting
# 2160400  targeting single sgRNA  CD4i_R2L48      targeting
#
#                              perturbation_name  low_quality  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32        False
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32        False
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32        False
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32        False
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32        False
# ...                                        ...          ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48        False
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48        False
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48        False
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48        False
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48        False
#
#                guide_sequence     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0                         NaN                   nan                   NaN
# 1        GGTGCAGGCCCCACGCGGAA       ENSG00000156150                 297.0
# 2        GCTGGGTCCGGCAGGCAGGG       ENSG00000124098                  21.0
# 3        GGGTGGTCATTCTCTACTTG  control_nontargeting                 155.0
# 4        GGCAAGCTCAGTGTGATCCC       ENSG00000102145                 931.0
# ...                       ...                   ...                   ...
# 2160396  GAACTCAGAGTTGGTTCTGG       ENSG00000146242                 134.0
# 2160397  AACAGAGTCGAGAAGCGGCG       ENSG00000006652                 528.0
# 2160398  GTCCAAGAGTACCCAAATCA       ENSG00000141429                  75.0
# 2160399  GTATATATATAAATCATACA       ENSG00000143387                  47.0
# 2160400  GCTCTCCGGCGGGCACGAGG       ENSG00000187772                 120.0
#
#          pct_counts_mt perturbed_target_ensg perturbed_target_symbol  \
# index
# 0             1.375719                  <NA>                     nan
# 1             0.047576       ENSG00000156150                    ALX3
# 2             0.287244       ENSG00000124098                 FAM210B
# 3             0.153728  control_nontargeting    control_nontargeting
# 4             0.777127       ENSG00000102145                   GATA1
# ...                ...                   ...                     ...
# 2160396       1.005245       ENSG00000146242                    TPBG
# 2160397       0.070992       ENSG00000006652                   IFRD1
# 2160398       0.358621       ENSG00000141429                  GALNT1
# 2160399       0.088720       ENSG00000143387                    CTSK
# 2160400       0.307259       ENSG00000187772                  LIN28B
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                            NaN                          NaN
# 1                 protein_coding  chr1:110059870-110070672;-1
# 2                 protein_coding    chr20:56358974-56368663;1
# 3           control_nontargeting         control_nontargeting
# 4                 protein_coding     chrX:48786540-48794311;1
# ...                          ...                          ...
# 2160396           protein_coding     chr6:82363206-82367420;1
# 2160397           protein_coding   chr7:112422887-112481017;1
# 2160398           protein_coding    chr18:35580892-35713370;1
# 2160399           protein_coding  chr1:150794880-150809577;-1
# 2160400           protein_coding   chr6:104936616-105083332;1
#
#         perturbed_target_chromosome original_index
# index
# 0                               NaN              0
# 1                                 1              1
# 2                                20              2
# 3              control_nontargeting              3
# 4                                 X              4
# ...                             ...            ...
# 2160396                           6        2160396
# 2160397                           7        2160397
# 2160398                          18        2160398
# 2160399                           1        2160399
# 2160400                           6        2160400
#
# [2160401 rows x 21 columns]

# %% [markdown]
# ### Add `perturbed_target_number` column

# %%
# cur_data.count_entries(
#     slot='obs',
#     input_column='perturbed_target_ensg',
#     count_column_name='perturbed_target_number',
#     sep='|'
# )
cur_data.adata.obs['perturbed_target_number'] = 1

# %% [markdown]
# ### Encode chromosomes as integers

# %%
cur_data.chromosome_encoding()
# Out:
# Chromosome encoding applied to perturbed_target_chromosome in adata.obs and stored as 'perturbed_target_chromosome_encoding'.

# %%
cur_data.adata.obs[['perturbation_name', 'perturbed_target_chromosome_encoding']]
# Out:
#                              perturbation_name  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32
# ...                                        ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           1
# 2                                          20
# 3                                           0
# 4                                          23
# ...                                       ...
# 2160396                                     6
# 2160397                                     7
# 2160398                                    18
# 2160399                                     1
# 2160400                                     6
#
# [2160401 rows x 2 columns]

# %%
cur_data.adata.obs
# Out:
#                        cell_barcode  n_genes_by_counts     PuroR  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1               5101  3.134436
# 1        AAACAAGCAAACCCAAAGTGAGTG-1               5994  3.277925
# 2        AAACAAGCAAACCGTAAGTGAGTG-1               3575  3.827360
# 3        AAACAAGCAAATACCGACAGTCTG-1               2795  1.744745
# 4        AAACAAGCAACCGTAAACAGTCTG-1               6745  3.230057
# ...                             ...                ...       ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1               5621  2.547603
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1               3075  2.604208
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1               3497  1.620248
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1               3687  2.911565
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1               5306  3.133394
#
#           perturbed_gene_name   guide_id  total_counts  \
# index
# 0                         nan        NaN       12866.0
# 1                        ALX3     ALX3-2       23121.0
# 2                     FAM210B  FAM210B-1        7659.0
# 3        control_nontargeting    NTC-846        5204.0
# 4                       GATA1    GATA1-1       30883.0
# ...                       ...        ...           ...
# 2160396                  TPBG     TPBG-2       18304.0
# 2160397                 IFRD1    IFRD1-2        7043.0
# 2160398                GALNT1   GALNT1-1        7250.0
# 2160399                  CTSK     CTSK-1        7890.0
# 2160400                LIN28B   LIN28B-1       15622.0
#
#                     guide_group     lane_id     guide_type  \
# index
# 0                      no sgRNA  CD4i_R2L32            NaN
# 1        targeting single sgRNA  CD4i_R2L32      targeting
# 2        targeting single sgRNA  CD4i_R2L32      targeting
# 3        targeting single sgRNA  CD4i_R2L32  non-targeting
# 4        targeting single sgRNA  CD4i_R2L32      targeting
# ...                         ...         ...            ...
# 2160396  targeting single sgRNA  CD4i_R2L48      targeting
# 2160397  targeting single sgRNA  CD4i_R2L48      targeting
# 2160398  targeting single sgRNA  CD4i_R2L48      targeting
# 2160399  targeting single sgRNA  CD4i_R2L48      targeting
# 2160400  targeting single sgRNA  CD4i_R2L48      targeting
#
#                              perturbation_name  low_quality  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32        False
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32        False
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32        False
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32        False
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32        False
# ...                                        ...          ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48        False
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48        False
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48        False
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48        False
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48        False
#
#                guide_sequence     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0                         NaN                   nan                   NaN
# 1        GGTGCAGGCCCCACGCGGAA       ENSG00000156150                 297.0
# 2        GCTGGGTCCGGCAGGCAGGG       ENSG00000124098                  21.0
# 3        GGGTGGTCATTCTCTACTTG  control_nontargeting                 155.0
# 4        GGCAAGCTCAGTGTGATCCC       ENSG00000102145                 931.0
# ...                       ...                   ...                   ...
# 2160396  GAACTCAGAGTTGGTTCTGG       ENSG00000146242                 134.0
# 2160397  AACAGAGTCGAGAAGCGGCG       ENSG00000006652                 528.0
# 2160398  GTCCAAGAGTACCCAAATCA       ENSG00000141429                  75.0
# 2160399  GTATATATATAAATCATACA       ENSG00000143387                  47.0
# 2160400  GCTCTCCGGCGGGCACGAGG       ENSG00000187772                 120.0
#
#          pct_counts_mt perturbed_target_ensg perturbed_target_symbol  \
# index
# 0             1.375719                  <NA>                     nan
# 1             0.047576       ENSG00000156150                    ALX3
# 2             0.287244       ENSG00000124098                 FAM210B
# 3             0.153728  control_nontargeting    control_nontargeting
# 4             0.777127       ENSG00000102145                   GATA1
# ...                ...                   ...                     ...
# 2160396       1.005245       ENSG00000146242                    TPBG
# 2160397       0.070992       ENSG00000006652                   IFRD1
# 2160398       0.358621       ENSG00000141429                  GALNT1
# 2160399       0.088720       ENSG00000143387                    CTSK
# 2160400       0.307259       ENSG00000187772                  LIN28B
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                            NaN                          NaN
# 1                 protein_coding  chr1:110059870-110070672;-1
# 2                 protein_coding    chr20:56358974-56368663;1
# 3           control_nontargeting         control_nontargeting
# 4                 protein_coding     chrX:48786540-48794311;1
# ...                          ...                          ...
# 2160396           protein_coding     chr6:82363206-82367420;1
# 2160397           protein_coding   chr7:112422887-112481017;1
# 2160398           protein_coding    chr18:35580892-35713370;1
# 2160399           protein_coding  chr1:150794880-150809577;-1
# 2160400           protein_coding   chr6:104936616-105083332;1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0                               NaN              0                        1
# 1                                 1              1                        1
# 2                                20              2                        1
# 3              control_nontargeting              3                        1
# 4                                 X              4                        1
# ...                             ...            ...                      ...
# 2160396                           6        2160396                        1
# 2160397                           7        2160397                        1
# 2160398                          18        2160398                        1
# 2160399                           1        2160399                        1
# 2160400                           6        2160400                        1
#
#          perturbed_target_chromosome_encoding
# index
# 0                                           0
# 1                                           1
# 2                                          20
# 3                                           0
# 4                                          23
# ...                                       ...
# 2160396                                     6
# 2160397                                     7
# 2160398                                    18
# 2160399                                     1
# 2160400                                     6
#
# [2160401 rows x 23 columns]

# %% [markdown]
# ### Curate replicates

# %%
cur_data.adata.obs = cur_data.adata.obs.rename(columns={'lane_id':'technical_replicate'})

# %% [markdown]
# ### Add metadata

# %%
cur_data.create_columns(
    overwrite=True,
    slot="obs",
    col_dict={
        "dataset_id": cur_data.dataset_id,
        "sample_id": range(1, cur_data.adata.obs.shape[0] + 1),
        # perturbation type
        "perturbation_type_label": "CRISPRi",
        "perturbation_type_id": None,
        "data_modality": "Perturb-seq",
        "significant": None,
        "significance_criteria": None,
        "score_interpretation": None,

        # treatment
        "treatment_label": "anti-CD3 antibody|anti-CD28 antibody|anti-CD2 antibody",
        "treatment_id": "EFO:0003317|EFO:0003304|NCIT:C184729",
        # replicates
        # "technical_replicate": None,
        "biological_replicate": "D3_CE0008678",
        # model system
        "model_system_label": "primary_cell",
        "model_system_id": None,
        "tissue": "lymphoid tissue",
        "cell_line_label": None,
        "cell_line_id": None,
        "cell_type_label": "CD4-positive, alpha-beta T cell",
        "disease_label": "healthy",
        "disease_id": None,

        "timepoint": "P14DT0H0M0S",
        "species": "Homo sapiens",
        "sex_label": "female",
        "sex_id": None,
        "developmental_stage_label": "adult",
        "developmental_stage_id": None,

        "study_title": "Genome-scale perturb-seq in primary human CD4+ T cells maps context-specific regulators of T cell programs and human immune traits",
        "study_uri": "https://doi.org/10.64898/2025.12.23.696273",
        "study_year": 2025,
        "first_author": "Ronghui Zhu",
        "last_author": "Alexander Marson",

        "experiment_title": "Perturb-seq of primary human CD4-positive T cells for patient D3_CE0008678, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator",
        "experiment_summary": """
            Isolated human CD4-positive cells from four healthy donors were stimulated with ImmunoCult CD3/CD28/CD2 activator and sequentially transduced with dCas9-KRAB-Zim3 lentivirus (next morning after stimulation) and a Perturb-seq guide library (next afternoon after stimulation, MOI 0.2).
            The library consisted all genes expressed in human CD4+ T cells, all transcription factors annotated in the Lambert et al. (2018) and non-targeting controls totalling 12,748 genes.
            The gRNA sequences were selected from hCRISPRiv2 and Dolcetto libraries.
            On day 12, cells were split into three conditions:
            (1) Rest - cells were left for 8 hr without stimulation;
            (2) Stim8hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 8 hr;
            (3) Stim48hr - cells were stimulated with ImmunoCult CD3/CD28/CD2 activator for 48 hr.
            Cells were harvested, fixed, stored using GEM-X Flex Sample Preparation v2 Kit and sequenced using GEM-X Flex Gene Expression Human n-plex kit converted into Ultima compatible libraries for sequencing on the Ultima Genomics UG100.
            """,

        "number_of_perturbed_targets": len(set(cur_data.adata.obs['perturbed_target_symbol'])),
        "number_of_perturbed_samples": cur_data.adata.obs.shape[0],

        "library_generation_type_id": "EFO:0022868",
        "library_generation_type_label": "endogenous",

        "library_generation_method_id": None,
        "library_generation_method_label": "dCas9-KRAB-Zim3",

        "enzyme_delivery_method_id": None,
        "enzyme_delivery_method_label": "lentivirus transduction",

        "library_delivery_method_id": None,
        "library_delivery_method_label": "lentivirus transduction",

        "enzyme_integration_state_id": None,
        "enzyme_integration_state_label": "random locus integration",

        "library_integration_state_id": None,
        "library_integration_state_label": "random locus integration",

        "enzyme_expression_control_id": None,
        "enzyme_expression_control_label": "constitutive transgene expression",

        "library_expression_control_id": None,
        "library_expression_control_label": "constitutive transgene expression",

        "library_name": "custom",
        "library_uri": None,

        "library_format_id": None,
        "library_format_label": "pooled",

        "library_scope_id": None,
        "library_scope_label": "focused",

        "library_perturbation_type_id": None,
        "library_perturbation_type_label": "inhibition",

        "library_manufacturer": "Marson lab",
        "library_lentiviral_generation": "2",
        "library_grnas_per_target": "2",
        "library_total_grnas": str(cur_data.adata.obs['guide_sequence'].str.split('|').explode().nunique()),
        "library_total_variants": None,

        "readout_dimensionality_id": None,
        "readout_dimensionality_label": "high-dimensional assay",

        "readout_type_id": None,
        "readout_type_label": "transcriptomic",

        "readout_technology_id": None,
        "readout_technology_label": "single-cell rna-seq",

        "method_name_id": None,
        "method_name_label": "Perturb-seq",

        "method_uri": None,

        "sequencing_library_kit_id": None,
        "sequencing_library_kit_label": "GEM-X Flex Gene Expression Human n-plex kit",

        "sequencing_platform_id": None,
        "sequencing_platform_label": "Ultima Genomics UG100",

        "sequencing_strategy_id": None,
        "sequencing_strategy_label": "barcode sequencing",

        "software_counts_id": None,
        "software_counts_label": "CellRanger",

        "software_analysis_id": None,
        "software_analysis_label": "scanpy",

        "reference_genome_id": None,
        "reference_genome_label": "GRCh38",

        "license_label": "MIT License",
        "license_id": "SWO:9000074",

        "associated_datasets": json.dumps([
            {
                "dataset_accession": "Primary Human CD4+ T Cell Perturb-seq",
                "dataset_uri": "s3://genome-scale-tcell-perturb-seq/marson2025_data/D3_Stim48hr.assigned_guide.h5ad",
                "dataset_description": "Cell expression profiles for cells from donor D3_CE0008678, stimulated for 48hr with ImmunoCult CD3/CD28/CD2 activator.",
                "dataset_file_name": "D3_Stim48hr.assigned_guide.h5ad",
            }
        ])
    }
)
# Out:
# Column dataset_id added to adata.obs
# Column sample_id added to adata.obs
# Column perturbation_type_label added to adata.obs
# Column perturbation_type_id added to adata.obs
# Column data_modality added to adata.obs
# Column significant added to adata.obs
# Column significance_criteria added to adata.obs
# Column score_interpretation added to adata.obs
# Column treatment_label added to adata.obs
# Column treatment_id added to adata.obs
# Column biological_replicate added to adata.obs
# Column model_system_label added to adata.obs
# Column model_system_id added to adata.obs
# Column tissue added to adata.obs
# Column cell_line_label added to adata.obs
# Column cell_line_id added to adata.obs
# Column cell_type_label added to adata.obs
# Column disease_label added to adata.obs
# Column disease_id added to adata.obs
# Column timepoint added to adata.obs
# Column species added to adata.obs
# Column sex_label added to adata.obs
# Column sex_id added to adata.obs
# Column developmental_stage_label added to adata.obs
# Column developmental_stage_id added to adata.obs
# Column study_title added to adata.obs
# Column study_uri added to adata.obs
# Column study_year added to adata.obs
# Column first_author added to adata.obs
# Column last_author added to adata.obs
# Column experiment_title added to adata.obs
# Column experiment_summary added to adata.obs
# Column number_of_perturbed_targets added to adata.obs
# Column number_of_perturbed_samples added to adata.obs
# Column library_generation_type_id added to adata.obs
# Column library_generation_type_label added to adata.obs
# Column library_generation_method_id added to adata.obs
# Column library_generation_method_label added to adata.obs
# Column enzyme_delivery_method_id added to adata.obs
# Column enzyme_delivery_method_label added to adata.obs
# Column library_delivery_method_id added to adata.obs
# Column library_delivery_method_label added to adata.obs
# Column enzyme_integration_state_id added to adata.obs
# Column enzyme_integration_state_label added to adata.obs
# Column library_integration_state_id added to adata.obs
# Column library_integration_state_label added to adata.obs
# Column enzyme_expression_control_id added to adata.obs
# Column enzyme_expression_control_label added to adata.obs
# Column library_expression_control_id added to adata.obs
# Column library_expression_control_label added to adata.obs
# Column library_name added to adata.obs
# Column library_uri added to adata.obs
# Column library_format_id added to adata.obs
# Column library_format_label added to adata.obs
# Column library_scope_id added to adata.obs
# Column library_scope_label added to adata.obs
# Column library_perturbation_type_id added to adata.obs
# Column library_perturbation_type_label added to adata.obs
# Column library_manufacturer added to adata.obs
# Column library_lentiviral_generation added to adata.obs
# Column library_grnas_per_target added to adata.obs
# Column library_total_grnas added to adata.obs
# Column library_total_variants added to adata.obs
# Column readout_dimensionality_id added to adata.obs
# Column readout_dimensionality_label added to adata.obs
# Column readout_type_id added to adata.obs
# Column readout_type_label added to adata.obs
# Column readout_technology_id added to adata.obs
# Column readout_technology_label added to adata.obs
# Column method_name_id added to adata.obs
# Column method_name_label added to adata.obs
# Column method_uri added to adata.obs
# Column sequencing_library_kit_id added to adata.obs
# Column sequencing_library_kit_label added to adata.obs
# Column sequencing_platform_id added to adata.obs
# Column sequencing_platform_label added to adata.obs
# Column sequencing_strategy_id added to adata.obs
# Column sequencing_strategy_label added to adata.obs
# Column software_counts_id added to adata.obs
# Column software_counts_label added to adata.obs
# Column software_analysis_id added to adata.obs
# Column software_analysis_label added to adata.obs
# Column reference_genome_id added to adata.obs
# Column reference_genome_label added to adata.obs
# Column license_label added to adata.obs
# Column license_id added to adata.obs
# Column associated_datasets added to adata.obs

# %%
cur_data.adata.obs
# Out:
#                        cell_barcode  n_genes_by_counts     PuroR  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1               5101  3.134436
# 1        AAACAAGCAAACCCAAAGTGAGTG-1               5994  3.277925
# 2        AAACAAGCAAACCGTAAGTGAGTG-1               3575  3.827360
# 3        AAACAAGCAAATACCGACAGTCTG-1               2795  1.744745
# 4        AAACAAGCAACCGTAAACAGTCTG-1               6745  3.230057
# ...                             ...                ...       ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1               5621  2.547603
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1               3075  2.604208
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1               3497  1.620248
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1               3687  2.911565
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1               5306  3.133394
#
#           perturbed_gene_name   guide_id  total_counts  \
# index
# 0                         nan        NaN       12866.0
# 1                        ALX3     ALX3-2       23121.0
# 2                     FAM210B  FAM210B-1        7659.0
# 3        control_nontargeting    NTC-846        5204.0
# 4                       GATA1    GATA1-1       30883.0
# ...                       ...        ...           ...
# 2160396                  TPBG     TPBG-2       18304.0
# 2160397                 IFRD1    IFRD1-2        7043.0
# 2160398                GALNT1   GALNT1-1        7250.0
# 2160399                  CTSK     CTSK-1        7890.0
# 2160400                LIN28B   LIN28B-1       15622.0
#
#                     guide_group technical_replicate     guide_type  \
# index
# 0                      no sgRNA          CD4i_R2L32            NaN
# 1        targeting single sgRNA          CD4i_R2L32      targeting
# 2        targeting single sgRNA          CD4i_R2L32      targeting
# 3        targeting single sgRNA          CD4i_R2L32  non-targeting
# 4        targeting single sgRNA          CD4i_R2L32      targeting
# ...                         ...                 ...            ...
# 2160396  targeting single sgRNA          CD4i_R2L48      targeting
# 2160397  targeting single sgRNA          CD4i_R2L48      targeting
# 2160398  targeting single sgRNA          CD4i_R2L48      targeting
# 2160399  targeting single sgRNA          CD4i_R2L48      targeting
# 2160400  targeting single sgRNA          CD4i_R2L48      targeting
#
#                              perturbation_name  low_quality  \
# index
# 0        AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32        False
# 1        AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32        False
# 2        AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32        False
# 3        AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32        False
# 4        AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32        False
# ...                                        ...          ...
# 2160396  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48        False
# 2160397  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48        False
# 2160398  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48        False
# 2160399  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48        False
# 2160400  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48        False
#
#                guide_sequence     perturbed_gene_id  top_guide_UMI_counts  \
# index
# 0                         NaN                   nan                   NaN
# 1        GGTGCAGGCCCCACGCGGAA       ENSG00000156150                 297.0
# 2        GCTGGGTCCGGCAGGCAGGG       ENSG00000124098                  21.0
# 3        GGGTGGTCATTCTCTACTTG  control_nontargeting                 155.0
# 4        GGCAAGCTCAGTGTGATCCC       ENSG00000102145                 931.0
# ...                       ...                   ...                   ...
# 2160396  GAACTCAGAGTTGGTTCTGG       ENSG00000146242                 134.0
# 2160397  AACAGAGTCGAGAAGCGGCG       ENSG00000006652                 528.0
# 2160398  GTCCAAGAGTACCCAAATCA       ENSG00000141429                  75.0
# 2160399  GTATATATATAAATCATACA       ENSG00000143387                  47.0
# 2160400  GCTCTCCGGCGGGCACGAGG       ENSG00000187772                 120.0
#
#          pct_counts_mt perturbed_target_ensg perturbed_target_symbol  \
# index
# 0             1.375719                  <NA>                     nan
# 1             0.047576       ENSG00000156150                    ALX3
# 2             0.287244       ENSG00000124098                 FAM210B
# 3             0.153728  control_nontargeting    control_nontargeting
# 4             0.777127       ENSG00000102145                   GATA1
# ...                ...                   ...                     ...
# 2160396       1.005245       ENSG00000146242                    TPBG
# 2160397       0.070992       ENSG00000006652                   IFRD1
# 2160398       0.358621       ENSG00000141429                  GALNT1
# 2160399       0.088720       ENSG00000143387                    CTSK
# 2160400       0.307259       ENSG00000187772                  LIN28B
#
#         perturbed_target_biotype       perturbed_target_coord  \
# index
# 0                            NaN                          NaN
# 1                 protein_coding  chr1:110059870-110070672;-1
# 2                 protein_coding    chr20:56358974-56368663;1
# 3           control_nontargeting         control_nontargeting
# 4                 protein_coding     chrX:48786540-48794311;1
# ...                          ...                          ...
# 2160396           protein_coding     chr6:82363206-82367420;1
# 2160397           protein_coding   chr7:112422887-112481017;1
# 2160398           protein_coding    chr18:35580892-35713370;1
# 2160399           protein_coding  chr1:150794880-150809577;-1
# 2160400           protein_coding   chr6:104936616-105083332;1
#
#         perturbed_target_chromosome original_index  perturbed_target_number  \
# index
# 0                               NaN              0                        1
# 1                                 1              1                        1
# 2                                20              2                        1
# 3              control_nontargeting              3                        1
# 4                                 X              4                        1
# ...                             ...            ...                      ...
# 2160396                           6        2160396                        1
# 2160397                           7        2160397                        1
# 2160398                          18        2160398                        1
# 2160399                           1        2160399                        1
# 2160400                           6        2160400                        1
#
#          perturbed_target_chromosome_encoding               dataset_id  \
# index
# 0                                           0  zhu_2025_D3_stim48hr_cl
# 1                                           1  zhu_2025_D3_stim48hr_cl
# 2                                          20  zhu_2025_D3_stim48hr_cl
# 3                                           0  zhu_2025_D3_stim48hr_cl
# 4                                          23  zhu_2025_D3_stim48hr_cl
# ...                                       ...                      ...
# 2160396                                     6  zhu_2025_D3_stim48hr_cl
# 2160397                                     7  zhu_2025_D3_stim48hr_cl
# 2160398                                    18  zhu_2025_D3_stim48hr_cl
# 2160399                                     1  zhu_2025_D3_stim48hr_cl
# 2160400                                     6  zhu_2025_D3_stim48hr_cl
#
#          sample_id perturbation_type_label perturbation_type_id data_modality  \
# index
# 0                1                 CRISPRi                 None   Perturb-seq
# 1                2                 CRISPRi                 None   Perturb-seq
# 2                3                 CRISPRi                 None   Perturb-seq
# 3                4                 CRISPRi                 None   Perturb-seq
# 4                5                 CRISPRi                 None   Perturb-seq
# ...            ...                     ...                  ...           ...
# 2160396    2160397                 CRISPRi                 None   Perturb-seq
# 2160397    2160398                 CRISPRi                 None   Perturb-seq
# 2160398    2160399                 CRISPRi                 None   Perturb-seq
# 2160399    2160400                 CRISPRi                 None   Perturb-seq
# 2160400    2160401                 CRISPRi                 None   Perturb-seq
#
#         significant significance_criteria score_interpretation  \
# index
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
# ...             ...                   ...                  ...
# 2160396        None                  None                 None
# 2160397        None                  None                 None
# 2160398        None                  None                 None
# 2160399        None                  None                 None
# 2160400        None                  None                 None
#
#                                            treatment_label  \
# index
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2160396  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160397  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160398  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160399  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160400  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id biological_replicate  \
# index
# 0        EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 1        EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 2        EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 3        EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 4        EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# ...                                       ...                  ...
# 2160396  EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 2160397  EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 2160398  EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 2160399  EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
# 2160400  EFO:0003317|EFO:0003304|NCIT:C184729         D3_CE0008678
#
#         model_system_label model_system_id           tissue cell_line_label  \
# index
# 0             primary_cell            None  lymphoid tissue            None
# 1             primary_cell            None  lymphoid tissue            None
# 2             primary_cell            None  lymphoid tissue            None
# 3             primary_cell            None  lymphoid tissue            None
# 4             primary_cell            None  lymphoid tissue            None
# ...                    ...             ...              ...             ...
# 2160396       primary_cell            None  lymphoid tissue            None
# 2160397       primary_cell            None  lymphoid tissue            None
# 2160398       primary_cell            None  lymphoid tissue            None
# 2160399       primary_cell            None  lymphoid tissue            None
# 2160400       primary_cell            None  lymphoid tissue            None
#
#         cell_line_id                  cell_type_label disease_label  \
# index
# 0               None  CD4-positive, alpha-beta T cell       healthy
# 1               None  CD4-positive, alpha-beta T cell       healthy
# 2               None  CD4-positive, alpha-beta T cell       healthy
# 3               None  CD4-positive, alpha-beta T cell       healthy
# 4               None  CD4-positive, alpha-beta T cell       healthy
# ...              ...                              ...           ...
# 2160396         None  CD4-positive, alpha-beta T cell       healthy
# 2160397         None  CD4-positive, alpha-beta T cell       healthy
# 2160398         None  CD4-positive, alpha-beta T cell       healthy
# 2160399         None  CD4-positive, alpha-beta T cell       healthy
# 2160400         None  CD4-positive, alpha-beta T cell       healthy
#
#         disease_id    timepoint       species sex_label sex_id  \
# index
# 0             None  P14DT0H0M0S  Homo sapiens    female   None
# 1             None  P14DT0H0M0S  Homo sapiens    female   None
# 2             None  P14DT0H0M0S  Homo sapiens    female   None
# 3             None  P14DT0H0M0S  Homo sapiens    female   None
# 4             None  P14DT0H0M0S  Homo sapiens    female   None
# ...            ...          ...           ...       ...    ...
# 2160396       None  P14DT0H0M0S  Homo sapiens    female   None
# 2160397       None  P14DT0H0M0S  Homo sapiens    female   None
# 2160398       None  P14DT0H0M0S  Homo sapiens    female   None
# 2160399       None  P14DT0H0M0S  Homo sapiens    female   None
# 2160400       None  P14DT0H0M0S  Homo sapiens    female   None
#
#         developmental_stage_label developmental_stage_id  \
# index
# 0                           adult                   None
# 1                           adult                   None
# 2                           adult                   None
# 3                           adult                   None
# 4                           adult                   None
# ...                           ...                    ...
# 2160396                     adult                   None
# 2160397                     adult                   None
# 2160398                     adult                   None
# 2160399                     adult                   None
# 2160400                     adult                   None
#
#                                                study_title  \
# index
# 0        Genome-scale perturb-seq in primary human CD4+...
# 1        Genome-scale perturb-seq in primary human CD4+...
# 2        Genome-scale perturb-seq in primary human CD4+...
# 3        Genome-scale perturb-seq in primary human CD4+...
# 4        Genome-scale perturb-seq in primary human CD4+...
# ...                                                    ...
# 2160396  Genome-scale perturb-seq in primary human CD4+...
# 2160397  Genome-scale perturb-seq in primary human CD4+...
# 2160398  Genome-scale perturb-seq in primary human CD4+...
# 2160399  Genome-scale perturb-seq in primary human CD4+...
# 2160400  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# index
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2160396  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160397  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160398  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160399  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160400  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# index
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2160396  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160397  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160398  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160399  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160400  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# index
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2160396  \n            Isolated human CD4-positive cell...
# 2160397  \n            Isolated human CD4-positive cell...
# 2160398  \n            Isolated human CD4-positive cell...
# 2160399  \n            Isolated human CD4-positive cell...
# 2160400  \n            Isolated human CD4-positive cell...
#
#          number_of_perturbed_targets  number_of_perturbed_samples  \
# index
# 0                              11839                      2160401
# 1                              11839                      2160401
# 2                              11839                      2160401
# 3                              11839                      2160401
# 4                              11839                      2160401
# ...                              ...                          ...
# 2160396                        11839                      2160401
# 2160397                        11839                      2160401
# 2160398                        11839                      2160401
# 2160399                        11839                      2160401
# 2160400                        11839                      2160401
#
#         library_generation_type_id library_generation_type_label  \
# index
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2160396                EFO:0022868                    endogenous
# 2160397                EFO:0022868                    endogenous
# 2160398                EFO:0022868                    endogenous
# 2160399                EFO:0022868                    endogenous
# 2160400                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# index
# 0                               None                 dCas9-KRAB-Zim3
# 1                               None                 dCas9-KRAB-Zim3
# 2                               None                 dCas9-KRAB-Zim3
# 3                               None                 dCas9-KRAB-Zim3
# 4                               None                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2160396                         None                 dCas9-KRAB-Zim3
# 2160397                         None                 dCas9-KRAB-Zim3
# 2160398                         None                 dCas9-KRAB-Zim3
# 2160399                         None                 dCas9-KRAB-Zim3
# 2160400                         None                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# index
# 0                            None      lentivirus transduction
# 1                            None      lentivirus transduction
# 2                            None      lentivirus transduction
# 3                            None      lentivirus transduction
# 4                            None      lentivirus transduction
# ...                           ...                          ...
# 2160396                      None      lentivirus transduction
# 2160397                      None      lentivirus transduction
# 2160398                      None      lentivirus transduction
# 2160399                      None      lentivirus transduction
# 2160400                      None      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# index
# 0                             None       lentivirus transduction
# 1                             None       lentivirus transduction
# 2                             None       lentivirus transduction
# 3                             None       lentivirus transduction
# 4                             None       lentivirus transduction
# ...                            ...                           ...
# 2160396                       None       lentivirus transduction
# 2160397                       None       lentivirus transduction
# 2160398                       None       lentivirus transduction
# 2160399                       None       lentivirus transduction
# 2160400                       None       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# index
# 0                              None       random locus integration
# 1                              None       random locus integration
# 2                              None       random locus integration
# 3                              None       random locus integration
# 4                              None       random locus integration
# ...                             ...                            ...
# 2160396                        None       random locus integration
# 2160397                        None       random locus integration
# 2160398                        None       random locus integration
# 2160399                        None       random locus integration
# 2160400                        None       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# index
# 0                               None        random locus integration
# 1                               None        random locus integration
# 2                               None        random locus integration
# 3                               None        random locus integration
# 4                               None        random locus integration
# ...                              ...                             ...
# 2160396                         None        random locus integration
# 2160397                         None        random locus integration
# 2160398                         None        random locus integration
# 2160399                         None        random locus integration
# 2160400                         None        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# index
# 0                               None  constitutive transgene expression
# 1                               None  constitutive transgene expression
# 2                               None  constitutive transgene expression
# 3                               None  constitutive transgene expression
# 4                               None  constitutive transgene expression
# ...                              ...                                ...
# 2160396                         None  constitutive transgene expression
# 2160397                         None  constitutive transgene expression
# 2160398                         None  constitutive transgene expression
# 2160399                         None  constitutive transgene expression
# 2160400                         None  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# index
# 0                                None  constitutive transgene expression
# 1                                None  constitutive transgene expression
# 2                                None  constitutive transgene expression
# 3                                None  constitutive transgene expression
# 4                                None  constitutive transgene expression
# ...                               ...                                ...
# 2160396                          None  constitutive transgene expression
# 2160397                          None  constitutive transgene expression
# 2160398                          None  constitutive transgene expression
# 2160399                          None  constitutive transgene expression
# 2160400                          None  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# index
# 0             custom        None              None               pooled
# 1             custom        None              None               pooled
# 2             custom        None              None               pooled
# 3             custom        None              None               pooled
# 4             custom        None              None               pooled
# ...              ...         ...               ...                  ...
# 2160396       custom        None              None               pooled
# 2160397       custom        None              None               pooled
# 2160398       custom        None              None               pooled
# 2160399       custom        None              None               pooled
# 2160400       custom        None              None               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# index
# 0                   None             focused                         None
# 1                   None             focused                         None
# 2                   None             focused                         None
# 3                   None             focused                         None
# 4                   None             focused                         None
# ...                  ...                 ...                          ...
# 2160396             None             focused                         None
# 2160397             None             focused                         None
# 2160398             None             focused                         None
# 2160399             None             focused                         None
# 2160400             None             focused                         None
#
#         library_perturbation_type_label library_manufacturer  \
# index
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2160396                      inhibition           Marson lab
# 2160397                      inhibition           Marson lab
# 2160398                      inhibition           Marson lab
# 2160399                      inhibition           Marson lab
# 2160400                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# index
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2160396                             2                        2
# 2160397                             2                        2
# 2160398                             2                        2
# 2160399                             2                        2
# 2160400                             2                        2
#
#         library_total_grnas library_total_variants readout_dimensionality_id  \
# index
# 0                     21186                   None                      None
# 1                     21186                   None                      None
# 2                     21186                   None                      None
# 3                     21186                   None                      None
# 4                     21186                   None                      None
# ...                     ...                    ...                       ...
# 2160396               21186                   None                      None
# 2160397               21186                   None                      None
# 2160398               21186                   None                      None
# 2160399               21186                   None                      None
# 2160400               21186                   None                      None
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# index
# 0             high-dimensional assay            None     transcriptomic
# 1             high-dimensional assay            None     transcriptomic
# 2             high-dimensional assay            None     transcriptomic
# 3             high-dimensional assay            None     transcriptomic
# 4             high-dimensional assay            None     transcriptomic
# ...                              ...             ...                ...
# 2160396       high-dimensional assay            None     transcriptomic
# 2160397       high-dimensional assay            None     transcriptomic
# 2160398       high-dimensional assay            None     transcriptomic
# 2160399       high-dimensional assay            None     transcriptomic
# 2160400       high-dimensional assay            None     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# index
# 0                        None      single-cell rna-seq           None
# 1                        None      single-cell rna-seq           None
# 2                        None      single-cell rna-seq           None
# 3                        None      single-cell rna-seq           None
# 4                        None      single-cell rna-seq           None
# ...                       ...                      ...            ...
# 2160396                  None      single-cell rna-seq           None
# 2160397                  None      single-cell rna-seq           None
# 2160398                  None      single-cell rna-seq           None
# 2160399                  None      single-cell rna-seq           None
# 2160400                  None      single-cell rna-seq           None
#
#         method_name_label method_uri sequencing_library_kit_id  \
# index
# 0             Perturb-seq       None                      None
# 1             Perturb-seq       None                      None
# 2             Perturb-seq       None                      None
# 3             Perturb-seq       None                      None
# 4             Perturb-seq       None                      None
# ...                   ...        ...                       ...
# 2160396       Perturb-seq       None                      None
# 2160397       Perturb-seq       None                      None
# 2160398       Perturb-seq       None                      None
# 2160399       Perturb-seq       None                      None
# 2160400       Perturb-seq       None                      None
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# index
# 0        GEM-X Flex Gene Expression Human n-plex kit                   None
# 1        GEM-X Flex Gene Expression Human n-plex kit                   None
# 2        GEM-X Flex Gene Expression Human n-plex kit                   None
# 3        GEM-X Flex Gene Expression Human n-plex kit                   None
# 4        GEM-X Flex Gene Expression Human n-plex kit                   None
# ...                                              ...                    ...
# 2160396  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2160397  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2160398  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2160399  GEM-X Flex Gene Expression Human n-plex kit                   None
# 2160400  GEM-X Flex Gene Expression Human n-plex kit                   None
#
#         sequencing_platform_label sequencing_strategy_id  \
# index
# 0           Ultima Genomics UG100                   None
# 1           Ultima Genomics UG100                   None
# 2           Ultima Genomics UG100                   None
# 3           Ultima Genomics UG100                   None
# 4           Ultima Genomics UG100                   None
# ...                           ...                    ...
# 2160396     Ultima Genomics UG100                   None
# 2160397     Ultima Genomics UG100                   None
# 2160398     Ultima Genomics UG100                   None
# 2160399     Ultima Genomics UG100                   None
# 2160400     Ultima Genomics UG100                   None
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# index
# 0              barcode sequencing               None            CellRanger
# 1              barcode sequencing               None            CellRanger
# 2              barcode sequencing               None            CellRanger
# 3              barcode sequencing               None            CellRanger
# 4              barcode sequencing               None            CellRanger
# ...                           ...                ...                   ...
# 2160396        barcode sequencing               None            CellRanger
# 2160397        barcode sequencing               None            CellRanger
# 2160398        barcode sequencing               None            CellRanger
# 2160399        barcode sequencing               None            CellRanger
# 2160400        barcode sequencing               None            CellRanger
#
#         software_analysis_id software_analysis_label reference_genome_id  \
# index
# 0                       None                  scanpy                None
# 1                       None                  scanpy                None
# 2                       None                  scanpy                None
# 3                       None                  scanpy                None
# 4                       None                  scanpy                None
# ...                      ...                     ...                 ...
# 2160396                 None                  scanpy                None
# 2160397                 None                  scanpy                None
# 2160398                 None                  scanpy                None
# 2160399                 None                  scanpy                None
# 2160400                 None                  scanpy                None
#
#         reference_genome_label license_label   license_id  \
# index
# 0                       GRCh38   MIT License  SWO:9000074
# 1                       GRCh38   MIT License  SWO:9000074
# 2                       GRCh38   MIT License  SWO:9000074
# 3                       GRCh38   MIT License  SWO:9000074
# 4                       GRCh38   MIT License  SWO:9000074
# ...                        ...           ...          ...
# 2160396                 GRCh38   MIT License  SWO:9000074
# 2160397                 GRCh38   MIT License  SWO:9000074
# 2160398                 GRCh38   MIT License  SWO:9000074
# 2160399                 GRCh38   MIT License  SWO:9000074
# 2160400                 GRCh38   MIT License  SWO:9000074
#
#                                        associated_datasets
# index
# 0        [{"dataset_accession": "Primary Human CD4+ T C...
# 1        [{"dataset_accession": "Primary Human CD4+ T C...
# 2        [{"dataset_accession": "Primary Human CD4+ T C...
# 3        [{"dataset_accession": "Primary Human CD4+ T C...
# 4        [{"dataset_accession": "Primary Human CD4+ T C...
# ...                                                    ...
# 2160396  [{"dataset_accession": "Primary Human CD4+ T C...
# 2160397  [{"dataset_accession": "Primary Human CD4+ T C...
# 2160398  [{"dataset_accession": "Primary Human CD4+ T C...
# 2160399  [{"dataset_accession": "Primary Human CD4+ T C...
# 2160400  [{"dataset_accession": "Primary Human CD4+ T C...
#
# [2160401 rows x 110 columns]

# %% [markdown]
# ### Curate tissue information

# %%
cur_data.standardize_ontology(
    input_column='tissue',
    column_type='term_name',
    ontology_type='tissue',
    overwrite=True
)
# Out:
# Mapped 1 tissue ontology terms from `tissue` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#       input_column input_column_lower       name_lower     ontology_id
# 0  lymphoid tissue    lymphoid tissue  lymphoid tissue  UBERON:0001744
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate cell type information

# %%
cur_data.standardize_ontology(
    input_column='cell_type_label',
    column_type='term_name',
    ontology_type='cell_type',
    overwrite=True
)
# Out:
# Mapped 1 cell_type ontology terms from `cell_type_label` column to ontology terms
# DataFrame shape: (1, 4)
# --------------------------------------------------
#                       input_column               input_column_lower  \
# 0  CD4-positive, alpha-beta T cell  cd4-positive, alpha-beta t cell
#
#                         name_lower ontology_id
# 0  cd4-positive, alpha-beta t cell  CL:0000624
# --------------------------------------------------
# Overwriting column cell_type_label in adata.obs
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ### Curate disease information

# %%
cur_data.standardize_ontology(
    input_column='disease_label',
    column_type='term_name',
    ontology_type='disease',
    overwrite=True
)
# Out:
# Warning: No disease ontology terms could be mapped from `disease_label` column to ontology terms. Map the terms manually or check the input column for errors.

# %% [markdown]
# ### Match schema column order

# %%
cur_data.match_schema_columns(slot='obs')
# Out:
# Matched columns of adata.obs to the obs_schema.

# %% [markdown]
# ### Validate obs metadata

# %%
cur_data.validate_data(slot='obs', verbose=True)
# Out:
# 2026-02-18 10:13:54,965 INFO curation_tools.curation_tools: adata.obs is valid according to the obs_schema.
#                       dataset_id sample_id data_modality significant  \
# 0        zhu_2025_D3_stim48hr_cl         1   Perturb-seq        <NA>
# 1        zhu_2025_D3_stim48hr_cl         2   Perturb-seq        <NA>
# 2        zhu_2025_D3_stim48hr_cl         3   Perturb-seq        <NA>
# 3        zhu_2025_D3_stim48hr_cl         4   Perturb-seq        <NA>
# 4        zhu_2025_D3_stim48hr_cl         5   Perturb-seq        <NA>
# ...                          ...       ...           ...         ...
# 2160396  zhu_2025_D3_stim48hr_cl   2160397   Perturb-seq        <NA>
# 2160397  zhu_2025_D3_stim48hr_cl   2160398   Perturb-seq        <NA>
# 2160398  zhu_2025_D3_stim48hr_cl   2160399   Perturb-seq        <NA>
# 2160399  zhu_2025_D3_stim48hr_cl   2160400   Perturb-seq        <NA>
# 2160400  zhu_2025_D3_stim48hr_cl   2160401   Perturb-seq        <NA>
#
#         significance_criteria                      perturbation_name  \
# 0                        <NA>  AAACAAGCAAACCCAAACTACTCA-1_CD4i_R2L32
# 1                        <NA>  AAACAAGCAAACCCAAAGTGAGTG-1_CD4i_R2L32
# 2                        <NA>  AAACAAGCAAACCGTAAGTGAGTG-1_CD4i_R2L32
# 3                        <NA>  AAACAAGCAAATACCGACAGTCTG-1_CD4i_R2L32
# 4                        <NA>  AAACAAGCAACCGTAAACAGTCTG-1_CD4i_R2L32
# ...                       ...                                    ...
# 2160396                  <NA>  TTTGTGAGTTGGGTTTAGAGGCAA-1_CD4i_R2L48
# 2160397                  <NA>  TTTGTGAGTTTACGACAGAGGCAA-1_CD4i_R2L48
# 2160398                  <NA>  TTTGTGAGTTTACGACAGTGAGTG-1_CD4i_R2L48
# 2160399                  <NA>  TTTGTGAGTTTCCTCAACAGTCTG-1_CD4i_R2L48
# 2160400                  <NA>  TTTGTGAGTTTGCATAACTACTCA-1_CD4i_R2L48
#
#               perturbed_target_coord perturbed_target_chromosome  \
# 0                               <NA>                        <NA>
# 1        chr1:110059870-110070672;-1                           1
# 2          chr20:56358974-56368663;1                          20
# 3               control_nontargeting        control_nontargeting
# 4           chrX:48786540-48794311;1                           X
# ...                              ...                         ...
# 2160396     chr6:82363206-82367420;1                           6
# 2160397   chr7:112422887-112481017;1                           7
# 2160398    chr18:35580892-35713370;1                          18
# 2160399  chr1:150794880-150809577;-1                           1
# 2160400   chr6:104936616-105083332;1                           6
#
#          perturbed_target_chromosome_encoding  perturbed_target_number  \
# 0                                           0                        1
# 1                                           1                        1
# 2                                          20                        1
# 3                                           0                        1
# 4                                          23                        1
# ...                                       ...                      ...
# 2160396                                     6                        1
# 2160397                                     7                        1
# 2160398                                    18                        1
# 2160399                                     1                        1
# 2160400                                     6                        1
#
#         perturbed_target_ensg perturbed_target_symbol  \
# 0                        <NA>                     nan
# 1             ENSG00000156150                    ALX3
# 2             ENSG00000124098                 FAM210B
# 3        control_nontargeting    control_nontargeting
# 4             ENSG00000102145                   GATA1
# ...                       ...                     ...
# 2160396       ENSG00000146242                    TPBG
# 2160397       ENSG00000006652                   IFRD1
# 2160398       ENSG00000141429                  GALNT1
# 2160399       ENSG00000143387                    CTSK
# 2160400       ENSG00000187772                  LIN28B
#
#         perturbed_target_biotype        guide_sequence  \
# 0                           <NA>                  <NA>
# 1                 protein_coding  GGTGCAGGCCCCACGCGGAA
# 2                 protein_coding  GCTGGGTCCGGCAGGCAGGG
# 3           control_nontargeting  GGGTGGTCATTCTCTACTTG
# 4                 protein_coding  GGCAAGCTCAGTGTGATCCC
# ...                          ...                   ...
# 2160396           protein_coding  GAACTCAGAGTTGGTTCTGG
# 2160397           protein_coding  AACAGAGTCGAGAAGCGGCG
# 2160398           protein_coding  GTCCAAGAGTACCCAAATCA
# 2160399           protein_coding  GTATATATATAAATCATACA
# 2160400           protein_coding  GCTCTCCGGCGGGCACGAGG
#
#         perturbation_type_label perturbation_type_id    timepoint  \
# 0                       CRISPRi                 <NA>  P14DT0H0M0S
# 1                       CRISPRi                 <NA>  P14DT0H0M0S
# 2                       CRISPRi                 <NA>  P14DT0H0M0S
# 3                       CRISPRi                 <NA>  P14DT0H0M0S
# 4                       CRISPRi                 <NA>  P14DT0H0M0S
# ...                         ...                  ...          ...
# 2160396                 CRISPRi                 <NA>  P14DT0H0M0S
# 2160397                 CRISPRi                 <NA>  P14DT0H0M0S
# 2160398                 CRISPRi                 <NA>  P14DT0H0M0S
# 2160399                 CRISPRi                 <NA>  P14DT0H0M0S
# 2160400                 CRISPRi                 <NA>  P14DT0H0M0S
#
#                                            treatment_label  \
# 0        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 1        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 3        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 4        anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# ...                                                    ...
# 2160396  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160397  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160398  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160399  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
# 2160400  anti-CD3 antibody|anti-CD28 antibody|anti-CD2 ...
#
#                                  treatment_id technical_replicate  \
# 0        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L32
# 1        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L32
# 2        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L32
# 3        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L32
# 4        EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L32
# ...                                       ...                 ...
# 2160396  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L48
# 2160397  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L48
# 2160398  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L48
# 2160399  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L48
# 2160400  EFO:0003317|EFO:0003304|NCIT:C184729          CD4i_R2L48
#
#         biological_replicate model_system_label model_system_id       species  \
# 0               D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 1               D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 2               D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 3               D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 4               D3_CE0008678       primary_cell            <NA>  Homo sapiens
# ...                      ...                ...             ...           ...
# 2160396         D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 2160397         D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 2160398         D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 2160399         D3_CE0008678       primary_cell            <NA>  Homo sapiens
# 2160400         D3_CE0008678       primary_cell            <NA>  Homo sapiens
#
#             tissue_label       tissue_id                  cell_type_label  \
# 0        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 1        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 3        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 4        lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# ...                  ...             ...                              ...
# 2160396  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2160397  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2160398  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2160399  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
# 2160400  lymphoid tissue  UBERON:0001744  CD4-positive, alpha-beta T cell
#
#         cell_type_id cell_line_label cell_line_id sex_label sex_id  \
# 0         CL:0000624            <NA>         <NA>    female   <NA>
# 1         CL:0000624            <NA>         <NA>    female   <NA>
# 2         CL:0000624            <NA>         <NA>    female   <NA>
# 3         CL:0000624            <NA>         <NA>    female   <NA>
# 4         CL:0000624            <NA>         <NA>    female   <NA>
# ...              ...             ...          ...       ...    ...
# 2160396   CL:0000624            <NA>         <NA>    female   <NA>
# 2160397   CL:0000624            <NA>         <NA>    female   <NA>
# 2160398   CL:0000624            <NA>         <NA>    female   <NA>
# 2160399   CL:0000624            <NA>         <NA>    female   <NA>
# 2160400   CL:0000624            <NA>         <NA>    female   <NA>
#
#         developmental_stage_label developmental_stage_id disease_label  \
# 0                           adult                   <NA>       healthy
# 1                           adult                   <NA>       healthy
# 2                           adult                   <NA>       healthy
# 3                           adult                   <NA>       healthy
# 4                           adult                   <NA>       healthy
# ...                           ...                    ...           ...
# 2160396                     adult                   <NA>       healthy
# 2160397                     adult                   <NA>       healthy
# 2160398                     adult                   <NA>       healthy
# 2160399                     adult                   <NA>       healthy
# 2160400                     adult                   <NA>       healthy
#
#         disease_id                                        study_title  \
# 0             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 1             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 3             <NA>  Genome-scale perturb-seq in primary human CD4+...
# 4             <NA>  Genome-scale perturb-seq in primary human CD4+...
# ...            ...                                                ...
# 2160396       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2160397       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2160398       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2160399       <NA>  Genome-scale perturb-seq in primary human CD4+...
# 2160400       <NA>  Genome-scale perturb-seq in primary human CD4+...
#
#                                           study_uri  study_year first_author  \
# 0        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 1        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 3        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 4        https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# ...                                             ...         ...          ...
# 2160396  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160397  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160398  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160399  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
# 2160400  https://doi.org/10.64898/2025.12.23.696273        2025  Ronghui Zhu
#
#               last_author                                   experiment_title  \
# 0        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 1        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 3        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 4        Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# ...                   ...                                                ...
# 2160396  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160397  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160398  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160399  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
# 2160400  Alexander Marson  Perturb-seq of primary human CD4-positive T ce...
#
#                                         experiment_summary  \
# 0        \n            Isolated human CD4-positive cell...
# 1        \n            Isolated human CD4-positive cell...
# 2        \n            Isolated human CD4-positive cell...
# 3        \n            Isolated human CD4-positive cell...
# 4        \n            Isolated human CD4-positive cell...
# ...                                                    ...
# 2160396  \n            Isolated human CD4-positive cell...
# 2160397  \n            Isolated human CD4-positive cell...
# 2160398  \n            Isolated human CD4-positive cell...
# 2160399  \n            Isolated human CD4-positive cell...
# 2160400  \n            Isolated human CD4-positive cell...
#
#         number_of_perturbed_targets number_of_perturbed_samples  \
# 0                             11839                     2160401
# 1                             11839                     2160401
# 2                             11839                     2160401
# 3                             11839                     2160401
# 4                             11839                     2160401
# ...                             ...                         ...
# 2160396                       11839                     2160401
# 2160397                       11839                     2160401
# 2160398                       11839                     2160401
# 2160399                       11839                     2160401
# 2160400                       11839                     2160401
#
#         library_generation_type_id library_generation_type_label  \
# 0                      EFO:0022868                    endogenous
# 1                      EFO:0022868                    endogenous
# 2                      EFO:0022868                    endogenous
# 3                      EFO:0022868                    endogenous
# 4                      EFO:0022868                    endogenous
# ...                            ...                           ...
# 2160396                EFO:0022868                    endogenous
# 2160397                EFO:0022868                    endogenous
# 2160398                EFO:0022868                    endogenous
# 2160399                EFO:0022868                    endogenous
# 2160400                EFO:0022868                    endogenous
#
#         library_generation_method_id library_generation_method_label  \
# 0                               <NA>                 dCas9-KRAB-Zim3
# 1                               <NA>                 dCas9-KRAB-Zim3
# 2                               <NA>                 dCas9-KRAB-Zim3
# 3                               <NA>                 dCas9-KRAB-Zim3
# 4                               <NA>                 dCas9-KRAB-Zim3
# ...                              ...                             ...
# 2160396                         <NA>                 dCas9-KRAB-Zim3
# 2160397                         <NA>                 dCas9-KRAB-Zim3
# 2160398                         <NA>                 dCas9-KRAB-Zim3
# 2160399                         <NA>                 dCas9-KRAB-Zim3
# 2160400                         <NA>                 dCas9-KRAB-Zim3
#
#         enzyme_delivery_method_id enzyme_delivery_method_label  \
# 0                            <NA>      lentivirus transduction
# 1                            <NA>      lentivirus transduction
# 2                            <NA>      lentivirus transduction
# 3                            <NA>      lentivirus transduction
# 4                            <NA>      lentivirus transduction
# ...                           ...                          ...
# 2160396                      <NA>      lentivirus transduction
# 2160397                      <NA>      lentivirus transduction
# 2160398                      <NA>      lentivirus transduction
# 2160399                      <NA>      lentivirus transduction
# 2160400                      <NA>      lentivirus transduction
#
#         library_delivery_method_id library_delivery_method_label  \
# 0                             <NA>       lentivirus transduction
# 1                             <NA>       lentivirus transduction
# 2                             <NA>       lentivirus transduction
# 3                             <NA>       lentivirus transduction
# 4                             <NA>       lentivirus transduction
# ...                            ...                           ...
# 2160396                       <NA>       lentivirus transduction
# 2160397                       <NA>       lentivirus transduction
# 2160398                       <NA>       lentivirus transduction
# 2160399                       <NA>       lentivirus transduction
# 2160400                       <NA>       lentivirus transduction
#
#         enzyme_integration_state_id enzyme_integration_state_label  \
# 0                              <NA>       random locus integration
# 1                              <NA>       random locus integration
# 2                              <NA>       random locus integration
# 3                              <NA>       random locus integration
# 4                              <NA>       random locus integration
# ...                             ...                            ...
# 2160396                        <NA>       random locus integration
# 2160397                        <NA>       random locus integration
# 2160398                        <NA>       random locus integration
# 2160399                        <NA>       random locus integration
# 2160400                        <NA>       random locus integration
#
#         library_integration_state_id library_integration_state_label  \
# 0                               <NA>        random locus integration
# 1                               <NA>        random locus integration
# 2                               <NA>        random locus integration
# 3                               <NA>        random locus integration
# 4                               <NA>        random locus integration
# ...                              ...                             ...
# 2160396                         <NA>        random locus integration
# 2160397                         <NA>        random locus integration
# 2160398                         <NA>        random locus integration
# 2160399                         <NA>        random locus integration
# 2160400                         <NA>        random locus integration
#
#         enzyme_expression_control_id    enzyme_expression_control_label  \
# 0                               <NA>  constitutive transgene expression
# 1                               <NA>  constitutive transgene expression
# 2                               <NA>  constitutive transgene expression
# 3                               <NA>  constitutive transgene expression
# 4                               <NA>  constitutive transgene expression
# ...                              ...                                ...
# 2160396                         <NA>  constitutive transgene expression
# 2160397                         <NA>  constitutive transgene expression
# 2160398                         <NA>  constitutive transgene expression
# 2160399                         <NA>  constitutive transgene expression
# 2160400                         <NA>  constitutive transgene expression
#
#         library_expression_control_id   library_expression_control_label  \
# 0                                <NA>  constitutive transgene expression
# 1                                <NA>  constitutive transgene expression
# 2                                <NA>  constitutive transgene expression
# 3                                <NA>  constitutive transgene expression
# 4                                <NA>  constitutive transgene expression
# ...                               ...                                ...
# 2160396                          <NA>  constitutive transgene expression
# 2160397                          <NA>  constitutive transgene expression
# 2160398                          <NA>  constitutive transgene expression
# 2160399                          <NA>  constitutive transgene expression
# 2160400                          <NA>  constitutive transgene expression
#
#         library_name library_uri library_format_id library_format_label  \
# 0             custom        <NA>              <NA>               pooled
# 1             custom        <NA>              <NA>               pooled
# 2             custom        <NA>              <NA>               pooled
# 3             custom        <NA>              <NA>               pooled
# 4             custom        <NA>              <NA>               pooled
# ...              ...         ...               ...                  ...
# 2160396       custom        <NA>              <NA>               pooled
# 2160397       custom        <NA>              <NA>               pooled
# 2160398       custom        <NA>              <NA>               pooled
# 2160399       custom        <NA>              <NA>               pooled
# 2160400       custom        <NA>              <NA>               pooled
#
#         library_scope_id library_scope_label library_perturbation_type_id  \
# 0                   <NA>             focused                         <NA>
# 1                   <NA>             focused                         <NA>
# 2                   <NA>             focused                         <NA>
# 3                   <NA>             focused                         <NA>
# 4                   <NA>             focused                         <NA>
# ...                  ...                 ...                          ...
# 2160396             <NA>             focused                         <NA>
# 2160397             <NA>             focused                         <NA>
# 2160398             <NA>             focused                         <NA>
# 2160399             <NA>             focused                         <NA>
# 2160400             <NA>             focused                         <NA>
#
#         library_perturbation_type_label library_manufacturer  \
# 0                            inhibition           Marson lab
# 1                            inhibition           Marson lab
# 2                            inhibition           Marson lab
# 3                            inhibition           Marson lab
# 4                            inhibition           Marson lab
# ...                                 ...                  ...
# 2160396                      inhibition           Marson lab
# 2160397                      inhibition           Marson lab
# 2160398                      inhibition           Marson lab
# 2160399                      inhibition           Marson lab
# 2160400                      inhibition           Marson lab
#
#         library_lentiviral_generation library_grnas_per_target  \
# 0                                   2                        2
# 1                                   2                        2
# 2                                   2                        2
# 3                                   2                        2
# 4                                   2                        2
# ...                               ...                      ...
# 2160396                             2                        2
# 2160397                             2                        2
# 2160398                             2                        2
# 2160399                             2                        2
# 2160400                             2                        2
#
#         library_total_grnas  library_total_variants readout_dimensionality_id  \
# 0                     21186                    <NA>                      <NA>
# 1                     21186                    <NA>                      <NA>
# 2                     21186                    <NA>                      <NA>
# 3                     21186                    <NA>                      <NA>
# 4                     21186                    <NA>                      <NA>
# ...                     ...                     ...                       ...
# 2160396               21186                    <NA>                      <NA>
# 2160397               21186                    <NA>                      <NA>
# 2160398               21186                    <NA>                      <NA>
# 2160399               21186                    <NA>                      <NA>
# 2160400               21186                    <NA>                      <NA>
#
#         readout_dimensionality_label readout_type_id readout_type_label  \
# 0             high-dimensional assay            <NA>     transcriptomic
# 1             high-dimensional assay            <NA>     transcriptomic
# 2             high-dimensional assay            <NA>     transcriptomic
# 3             high-dimensional assay            <NA>     transcriptomic
# 4             high-dimensional assay            <NA>     transcriptomic
# ...                              ...             ...                ...
# 2160396       high-dimensional assay            <NA>     transcriptomic
# 2160397       high-dimensional assay            <NA>     transcriptomic
# 2160398       high-dimensional assay            <NA>     transcriptomic
# 2160399       high-dimensional assay            <NA>     transcriptomic
# 2160400       high-dimensional assay            <NA>     transcriptomic
#
#         readout_technology_id readout_technology_label method_name_id  \
# 0                        <NA>      single-cell rna-seq           <NA>
# 1                        <NA>      single-cell rna-seq           <NA>
# 2                        <NA>      single-cell rna-seq           <NA>
# 3                        <NA>      single-cell rna-seq           <NA>
# 4                        <NA>      single-cell rna-seq           <NA>
# ...                       ...                      ...            ...
# 2160396                  <NA>      single-cell rna-seq           <NA>
# 2160397                  <NA>      single-cell rna-seq           <NA>
# 2160398                  <NA>      single-cell rna-seq           <NA>
# 2160399                  <NA>      single-cell rna-seq           <NA>
# 2160400                  <NA>      single-cell rna-seq           <NA>
#
#         method_name_label method_uri sequencing_library_kit_id  \
# 0             Perturb-seq       <NA>                      <NA>
# 1             Perturb-seq       <NA>                      <NA>
# 2             Perturb-seq       <NA>                      <NA>
# 3             Perturb-seq       <NA>                      <NA>
# 4             Perturb-seq       <NA>                      <NA>
# ...                   ...        ...                       ...
# 2160396       Perturb-seq       <NA>                      <NA>
# 2160397       Perturb-seq       <NA>                      <NA>
# 2160398       Perturb-seq       <NA>                      <NA>
# 2160399       Perturb-seq       <NA>                      <NA>
# 2160400       Perturb-seq       <NA>                      <NA>
#
#                         sequencing_library_kit_label sequencing_platform_id  \
# 0        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 1        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 3        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 4        GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# ...                                              ...                    ...
# 2160396  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2160397  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2160398  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2160399  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
# 2160400  GEM-X Flex Gene Expression Human n-plex kit                   <NA>
#
#         sequencing_platform_label sequencing_strategy_id  \
# 0           Ultima Genomics UG100                   <NA>
# 1           Ultima Genomics UG100                   <NA>
# 2           Ultima Genomics UG100                   <NA>
# 3           Ultima Genomics UG100                   <NA>
# 4           Ultima Genomics UG100                   <NA>
# ...                           ...                    ...
# 2160396     Ultima Genomics UG100                   <NA>
# 2160397     Ultima Genomics UG100                   <NA>
# 2160398     Ultima Genomics UG100                   <NA>
# 2160399     Ultima Genomics UG100                   <NA>
# 2160400     Ultima Genomics UG100                   <NA>
#
#         sequencing_strategy_label software_counts_id software_counts_label  \
# 0              barcode sequencing               <NA>            CellRanger
# 1              barcode sequencing               <NA>            CellRanger
# 2              barcode sequencing               <NA>            CellRanger
# 3              barcode sequencing               <NA>            CellRanger
# 4              barcode sequencing               <NA>            CellRanger
# ...                           ...                ...                   ...
# 2160396        barcode sequencing               <NA>            CellRanger
# 2160397        barcode sequencing               <NA>            CellRanger
# 2160398        barcode sequencing               <NA>            CellRanger
# 2160399        barcode sequencing               <NA>            CellRanger
# 2160400        barcode sequencing               <NA>            CellRanger
#
#         software_analysis_id software_analysis_label score_interpretation  \
# 0                       <NA>                  scanpy                 <NA>
# 1                       <NA>                  scanpy                 <NA>
# 2                       <NA>                  scanpy                 <NA>
# 3                       <NA>                  scanpy                 <NA>
# 4                       <NA>                  scanpy                 <NA>
# ...                      ...                     ...                  ...
# 2160396                 <NA>                  scanpy                 <NA>
# 2160397                 <NA>                  scanpy                 <NA>
# 2160398                 <NA>                  scanpy                 <NA>
# 2160399                 <NA>                  scanpy                 <NA>
# 2160400                 <NA>                  scanpy                 <NA>
#
#         reference_genome_id reference_genome_label  \
# 0                      <NA>                 GRCh38
# 1                      <NA>                 GRCh38
# 2                      <NA>                 GRCh38
# 3                      <NA>                 GRCh38
# 4                      <NA>                 GRCh38
# ...                     ...                    ...
# 2160396                <NA>                 GRCh38
# 2160397                <NA>                 GRCh38
# 2160398                <NA>                 GRCh38
# 2160399                <NA>                 GRCh38
# 2160400                <NA>                 GRCh38
#
#                                        associated_datasets license_label  \
# 0        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 1        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 3        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 4        [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# ...                                                    ...           ...
# 2160396  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2160397  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2160398  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2160399  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
# 2160400  [{"dataset_accession": "Primary Human CD4+ T C...   MIT License
#
#           license_id
# 0        SWO:9000074
# 1        SWO:9000074
# 2        SWO:9000074
# 3        SWO:9000074
# 4        SWO:9000074
# ...              ...
# 2160396  SWO:9000074
# 2160397  SWO:9000074
# 2160398  SWO:9000074
# 2160399  SWO:9000074
# 2160400  SWO:9000074
#
# [2160401 rows x 99 columns]

# %% [markdown]
# # VAR slot curation

# %% [markdown]
# ### Standardise genes

# %%
cur_data.adata.var
# Out:
#                         gene_ids    feature_types  genome gene_name     mt
# CUSTOM001_PuroR  CUSTOM001_PuroR  Gene Expression  GRCh38     PuroR  False
# ENSG00000000003  ENSG00000000003  Gene Expression  GRCh38    TSPAN6  False
# ENSG00000000005  ENSG00000000005  Gene Expression  GRCh38      TNMD  False
# ENSG00000000419  ENSG00000000419  Gene Expression  GRCh38      DPM1  False
# ENSG00000000457  ENSG00000000457  Gene Expression  GRCh38     SCYL3  False
# ...                          ...              ...     ...       ...    ...
# ENSG00000291110  ENSG00000291110  Gene Expression  GRCh38   TRIM16L  False
# ENSG00000291122  ENSG00000291122  Gene Expression  GRCh38  CASTOR3P  False
# ENSG00000291135  ENSG00000291135  Gene Expression  GRCh38   FCGR1BP  False
# ENSG00000291145  ENSG00000291145  Gene Expression  GRCh38   PPP5D1P  False
# ENSG00000291237  ENSG00000291237  Gene Expression  GRCh38      SOD2  False
#
# [18130 rows x 5 columns]

# %%
cur_data.standardize_genes(
    slot="var",
    input_column="gene_ids",
    input_column_type="ensembl_gene_id",
    remove_version=False,
    multiple_entries=False
)
# Out:
# Missing Ensembl IDs: ['ENSG00000148362', 'ENSG00000139656', 'CUSTOM001_PuroR']; attempting to fetch latest IDs...
# Fetched latest Ensembl IDs: {'ENSG00000148362': 'ENSG00000310560', 'ENSG00000139656': 'ENSG00000226519'}
# --------------------------------------------------
# Successfully mapped 18130 out of 18130 Ensembl IDs.
# --------------------------------------------------
# /homes/zakirov/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# replace gene symbols that are NOT ENSG with original provided gene symbol
cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_symbol'] = cur_data.adata.var.loc[(cur_data.adata.var['gene_symbol'].isna()) &
 (~cur_data.adata.var['gene_name'].str.startswith('ENSG')), 'gene_name']

# %%
cur_data.adata.var.loc[cur_data.adata.var['ensembl_gene_id'] == 'CUSTOM001_PuroR', 'ensembl_gene_id'] = None

# %% [markdown]
# ### Validate var metadata

# %%
cur_data.validate_data(slot='var')
# Out:
# 2026-02-18 10:16:41,356 INFO curation_tools.curation_tools: adata.var is valid according to the var_schema.
#        ensembl_gene_id gene_symbol
# index
# 0                 None       PuroR
# 1      ENSG00000000003      TSPAN6
# 2      ENSG00000000005        TNMD
# 3      ENSG00000000419        DPM1
# 4      ENSG00000000457       SCYL3
# ...                ...         ...
# 18125  ENSG00000291110     TRIM16L
# 18126  ENSG00000291122    CASTOR3P
# 18127  ENSG00000291135     FCGR1BP
# 18128  ENSG00000291145     PPP5D1P
# 18129  ENSG00000291237        SOD2
#
# [18130 rows x 2 columns]

# %% [markdown]
# # Save the dataset

# %%
cur_data.save_curated_data_h5ad()
# Out:
# /nfs/production/mfreeberg/perturb-seq/aleks/PerturbationCatalogue/data_exploration/curation_tools/curation_tools.py:327: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   adata.obs = adata.obs.fillna(value=np.nan)
# ... storing 'dataset_id' as categorical
# ... storing 'data_modality' as categorical
# ... storing 'significance_criteria' as categorical
# ... storing 'perturbed_target_coord' as categorical
# ... storing 'perturbed_target_chromosome' as categorical
# ... storing 'perturbed_target_ensg' as categorical
# ... storing 'perturbed_target_symbol' as categorical
# ... storing 'perturbed_target_biotype' as categorical
# ... storing 'guide_sequence' as categorical
# ... storing 'perturbation_type_label' as categorical
# ... storing 'perturbation_type_id' as categorical
# ... storing 'timepoint' as categorical
# ... storing 'treatment_label' as categorical
# ... storing 'treatment_id' as categorical
# ... storing 'technical_replicate' as categorical
# ... storing 'biological_replicate' as categorical
# ... storing 'model_system_label' as categorical
# ... storing 'model_system_id' as categorical
# ... storing 'species' as categorical
# ... storing 'tissue_label' as categorical
# ... storing 'tissue_id' as categorical
# ... storing 'cell_type_label' as categorical
# ... storing 'cell_type_id' as categorical
# ... storing 'cell_line_label' as categorical
# ... storing 'cell_line_id' as categorical
# ... storing 'sex_label' as categorical
# ... storing 'sex_id' as categorical
# ... storing 'developmental_stage_label' as categorical
# ... storing 'developmental_stage_id' as categorical
# ... storing 'disease_label' as categorical
# ... storing 'disease_id' as categorical
# ... storing 'study_title' as categorical
# ... storing 'study_uri' as categorical
# ... storing 'first_author' as categorical
# ... storing 'last_author' as categorical
# ... storing 'experiment_title' as categorical
# ... storing 'experiment_summary' as categorical
# ... storing 'number_of_perturbed_targets' as categorical
# ... storing 'number_of_perturbed_samples' as categorical
# ... storing 'library_generation_type_id' as categorical
# ... storing 'library_generation_type_label' as categorical
# ... storing 'library_generation_method_id' as categorical
# ... storing 'library_generation_method_label' as categorical
# ... storing 'enzyme_delivery_method_id' as categorical
# ... storing 'enzyme_delivery_method_label' as categorical
# ... storing 'library_delivery_method_id' as categorical
# ... storing 'library_delivery_method_label' as categorical
# ... storing 'enzyme_integration_state_id' as categorical
# ... storing 'enzyme_integration_state_label' as categorical
# ... storing 'library_integration_state_id' as categorical
# ... storing 'library_integration_state_label' as categorical
# ... storing 'enzyme_expression_control_id' as categorical
# ... storing 'enzyme_expression_control_label' as categorical
# ... storing 'library_expression_control_id' as categorical
# ... storing 'library_expression_control_label' as categorical
# ... storing 'library_name' as categorical
# ... storing 'library_uri' as categorical
# ... storing 'library_format_id' as categorical
# ... storing 'library_format_label' as categorical
# ... storing 'library_scope_id' as categorical
# ... storing 'library_scope_label' as categorical
# ... storing 'library_perturbation_type_id' as categorical
# ... storing 'library_perturbation_type_label' as categorical
# ... storing 'library_manufacturer' as categorical
# ... storing 'library_lentiviral_generation' as categorical
# ... storing 'library_grnas_per_target' as categorical
# ... storing 'library_total_grnas' as categorical
# ... storing 'readout_dimensionality_id' as categorical
# ... storing 'readout_dimensionality_label' as categorical
# ... storing 'readout_type_id' as categorical
# ... storing 'readout_type_label' as categorical
# ... storing 'readout_technology_id' as categorical
# ... storing 'readout_technology_label' as categorical
# ... storing 'method_name_id' as categorical
# ... storing 'method_name_label' as categorical
# ... storing 'method_uri' as categorical
# ... storing 'sequencing_library_kit_id' as categorical
# ... storing 'sequencing_library_kit_label' as categorical
# ... storing 'sequencing_platform_id' as categorical
# ... storing 'sequencing_platform_label' as categorical
# ... storing 'sequencing_strategy_id' as categorical
# ... storing 'sequencing_strategy_label' as categorical
# ... storing 'software_counts_id' as categorical
# ... storing 'software_counts_label' as categorical
# ... storing 'software_analysis_id' as categorical
# ... storing 'software_analysis_label' as categorical
# ... storing 'score_interpretation' as categorical
# ... storing 'reference_genome_id' as categorical
# ... storing 'reference_genome_label' as categorical
# ... storing 'associated_datasets' as categorical
# ... storing 'license_label' as categorical
# ... storing 'license_id' as categorical
# ... storing 'ensembl_gene_id' as categorical
# ... storing 'gene_symbol' as categorical
# ✅ Curated h5ad data saved to ../curated/h5ad/zhu_2025_D3_stim48hr_cl_curated.h5ad

# %%
cur_data.save_curated_data_parquet(split_metadata=True, save_metadata_only=True)
# Out:
# ✅ Metadata saved to ../curated/parquet/zhu_2025_D3_stim48hr_cl_curated_metadata.parquet

# %% [markdown]
# # Upload to BigQuery

# %%
# upload_parquet_to_bq(
#     parquet_path='../curated/parquet/zhu_2025_D1_rest_cl_curated_metadata.parquet',
#     bq_dataset_id='prj-ext-dev-pertcat-437314.perturb_seq',
#     bq_table_name='metadata',
#     key_columns=['dataset_id', 'sample_id'],
#     verbose=True
# )

# %% [markdown]
# # Upload to GC Storage

# %%
# !gcloud storage cp ../curated/h5ad/zhu_2025_D3_stim48hr_cl_curated.h5ad gs://perturbation-catalogue-lake/perturbseq/curated/
